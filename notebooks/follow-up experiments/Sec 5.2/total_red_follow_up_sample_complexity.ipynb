# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-02-09 02:15:50

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/total_red_follow_up")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (30000, 30000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=3000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "total_red_sample_complexity"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"][2:]:
    for use_attn in [False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 512 
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 1500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,176,476 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.2509923696517946, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0026377873202914283, 'overlap rate': 0.08867955879058646}
# evaluation performance: {'loss': 3.2508893728256227, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0025656496724217083, 'overlap rate': 0.08889313107517774}
#
# Current epoch: 20,
# training performance: {'loss': 3.181876611709595, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005348545434359022, 'overlap rate': 0.09083354407656964}
# evaluation performance: {'loss': 3.182366943359375, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005171760414246311, 'overlap rate': 0.09036225564494711}
#
# Current epoch: 30,
# training performance: {'loss': 3.069762706756592, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0066374596536185465, 'overlap rate': 0.12539345597992563}
# evaluation performance: {'loss': 3.071660780906677, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.006418606525957812, 'overlap rate': 0.12447510730294971}
#
# Current epoch: 40,
# training performance: {'loss': 3.0738284826278686, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.009971073334808307, 'overlap rate': 0.15164807281872195}
# evaluation performance: {'loss': 3.0775213718414305, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.009731683967036997, 'overlap rate': 0.15157201609841278}
#
# Current epoch: 50,
# training performance: {'loss': 2.8021475076675415, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01560795196282951, 'overlap rate': 0.1734158004973429}
# evaluation performance: {'loss': 2.8086114645004274, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.015628036163730374, 'overlap rate': 0.17280248158612452}
#
# Current epoch: 60,
# training performance: {'loss': 2.7739065408706667, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.02638965158738362, 'overlap rate': 0.16627066892774658}
# evaluation performance: {'loss': 2.7808945417404174, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.025887520274164272, 'overlap rate': 0.16440754563984664}
#
# Current epoch: 70,
# training performance: {'loss': 2.7128765106201174, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.038007464892305685, 'overlap rate': 0.20608023271769396}
# evaluation performance: {'loss': 2.7216925621032715, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03725621934284007, 'overlap rate': 0.20440926718519986}
#
# Current epoch: 80,
# training performance: {'loss': 2.9571557998657227, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.05189645896705018, 'overlap rate': 0.21363983672262282}
# evaluation performance: {'loss': 2.9631514072418215, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.05086990276773706, 'overlap rate': 0.21357987380673205}
#
# Current epoch: 90,
# training performance: {'loss': 2.8173953771591185, 'full sequence accuracy': 0.0017333333333333337, 'first n-symbol accuracy': 0.07739636537807262, 'overlap rate': 0.2510534559490415}
# evaluation performance: {'loss': 2.827617073059082, 'full sequence accuracy': 0.0014333333333333333, 'first n-symbol accuracy': 0.07639467326259677, 'overlap rate': 0.2500998612674113}
#
# Current epoch: 100,
# training performance: {'loss': 2.7858777761459352, 'full sequence accuracy': 0.011533333333333333, 'first n-symbol accuracy': 0.11263707646257251, 'overlap rate': 0.29225339476563894}
# evaluation performance: {'loss': 2.788915181159973, 'full sequence accuracy': 0.011033333333333334, 'first n-symbol accuracy': 0.11164591160353583, 'overlap rate': 0.29196305082584}
#
# Current epoch: 110,
# training performance: {'loss': 2.966129446029663, 'full sequence accuracy': 3.3333333333333335e-05, 'first n-symbol accuracy': 0.12115791966068434, 'overlap rate': 0.3003377968144272}
# evaluation performance: {'loss': 2.9783900499343874, 'full sequence accuracy': 3.3333333333333335e-05, 'first n-symbol accuracy': 0.1205535953326764, 'overlap rate': 0.2992487734573314}
#
# Current epoch: 120,
# training performance: {'loss': 2.6501312017440797, 'full sequence accuracy': 0.02786666666666666, 'first n-symbol accuracy': 0.18678781487723414, 'overlap rate': 0.37901696311204336}
# evaluation performance: {'loss': 2.6690985798835754, 'full sequence accuracy': 0.0263, 'first n-symbol accuracy': 0.18407717820240366, 'overlap rate': 0.3754293833433941}
#
# Current epoch: 130,
# training performance: {'loss': 2.716635596752167, 'full sequence accuracy': 0.016900000000000002, 'first n-symbol accuracy': 0.19050387696825252, 'overlap rate': 0.3861148493589048}
# evaluation performance: {'loss': 2.7346194624900817, 'full sequence accuracy': 0.0173, 'first n-symbol accuracy': 0.1897670903091488, 'overlap rate': 0.382750547544238}
#
# Current epoch: 140,
# training performance: {'loss': 2.3899099469184875, 'full sequence accuracy': 0.07776666666666666, 'first n-symbol accuracy': 0.28113687869079773, 'overlap rate': 0.48153093049593354}
# evaluation performance: {'loss': 2.422529751062393, 'full sequence accuracy': 0.0769, 'first n-symbol accuracy': 0.2764356226218142, 'overlap rate': 0.4746577181983584}
#
# Current epoch: 150,
# training performance: {'loss': 2.319868689775467, 'full sequence accuracy': 0.09116666666666665, 'first n-symbol accuracy': 0.3341224267195622, 'overlap rate': 0.5123624626055557}
# evaluation performance: {'loss': 2.3698263287544252, 'full sequence accuracy': 0.0859, 'first n-symbol accuracy': 0.32303523396412026, 'overlap rate': 0.5015195411904464}
#
# Current epoch: 160,
# training performance: {'loss': 2.250293660163879, 'full sequence accuracy': 0.15836666666666666, 'first n-symbol accuracy': 0.3491340210949533, 'overlap rate': 0.5566649909289436}
# evaluation performance: {'loss': 2.291690295934677, 'full sequence accuracy': 0.15063333333333334, 'first n-symbol accuracy': 0.34008869929524194, 'overlap rate': 0.5489874935168146}
#
# Current epoch: 170,
# training performance: {'loss': 2.112629991769791, 'full sequence accuracy': 0.20413333333333333, 'first n-symbol accuracy': 0.4045790003548578, 'overlap rate': 0.6018511740716573}
# evaluation performance: {'loss': 2.1704789221286775, 'full sequence accuracy': 0.19343333333333332, 'first n-symbol accuracy': 0.3909236645588897, 'overlap rate': 0.5910248965792251}
#
# Current epoch: 180,
# training performance: {'loss': 2.2043557167053223, 'full sequence accuracy': 0.19273333333333334, 'first n-symbol accuracy': 0.3887109016414804, 'overlap rate': 0.5968478507406714}
# evaluation performance: {'loss': 2.2687276512384416, 'full sequence accuracy': 0.18313333333333331, 'first n-symbol accuracy': 0.3784304441426881, 'overlap rate': 0.5854518636921691}
#
# Current epoch: 190,
# training performance: {'loss': 2.197897458076477, 'full sequence accuracy': 0.18019999999999997, 'first n-symbol accuracy': 0.38890792414660774, 'overlap rate': 0.6029305670123959}
# evaluation performance: {'loss': 2.2722798585891724, 'full sequence accuracy': 0.16806666666666664, 'first n-symbol accuracy': 0.376626684208416, 'overlap rate': 0.5913782625788443}
#
# Current epoch: 200,
# training performance: {'loss': 1.8656579583883286, 'full sequence accuracy': 0.2647, 'first n-symbol accuracy': 0.4821659591748627, 'overlap rate': 0.6688984655908898}
# evaluation performance: {'loss': 1.9636110216379166, 'full sequence accuracy': 0.23969999999999994, 'first n-symbol accuracy': 0.46089081675257065, 'overlap rate': 0.6524610314679773}
#
# Current epoch: 210,
# training performance: {'loss': 1.7794494926929474, 'full sequence accuracy': 0.33403333333333335, 'first n-symbol accuracy': 0.5009365986060277, 'overlap rate': 0.6986304133004188}
# evaluation performance: {'loss': 1.8762166976928711, 'full sequence accuracy': 0.30796666666666667, 'first n-symbol accuracy': 0.4810604252200964, 'overlap rate': 0.6834363595297198}
#
# Current epoch: 220,
# training performance: {'loss': 2.022658368945122, 'full sequence accuracy': 0.2513666666666666, 'first n-symbol accuracy': 0.4440980989250668, 'overlap rate': 0.6638818516741365}
# evaluation performance: {'loss': 2.115954250097275, 'full sequence accuracy': 0.23659999999999998, 'first n-symbol accuracy': 0.4310880023822679, 'overlap rate': 0.6498331855208352}
#
# Current epoch: 230,
# training performance: {'loss': 1.7739704310894013, 'full sequence accuracy': 0.2662999999999999, 'first n-symbol accuracy': 0.5132434427813526, 'overlap rate': 0.7139585822123837}
# evaluation performance: {'loss': 1.8830117464065552, 'full sequence accuracy': 0.2497666666666667, 'first n-symbol accuracy': 0.49636555603397925, 'overlap rate': 0.6964740195683091}
#
# Current epoch: 240,
# training performance: {'loss': 1.694293627142906, 'full sequence accuracy': 0.3328000000000001, 'first n-symbol accuracy': 0.5263542416546338, 'overlap rate': 0.7357647773697075}
# evaluation performance: {'loss': 1.8257615387439727, 'full sequence accuracy': 0.3050666666666667, 'first n-symbol accuracy': 0.504557374103393, 'overlap rate': 0.7150589691883177}
#
# Current epoch: 250,
# training performance: {'loss': 2.1132828831672668, 'full sequence accuracy': 0.20203333333333334, 'first n-symbol accuracy': 0.4782383248323062, 'overlap rate': 0.685318790729676}
# evaluation performance: {'loss': 2.233839821815491, 'full sequence accuracy': 0.18979999999999997, 'first n-symbol accuracy': 0.4627580526200056, 'overlap rate': 0.6676305312931977}
#
# Current epoch: 260,
# training performance: {'loss': 1.4771575316786767, 'full sequence accuracy': 0.39013333333333333, 'first n-symbol accuracy': 0.57933560511093, 'overlap rate': 0.7784871749795701}
# evaluation performance: {'loss': 1.6284288927912711, 'full sequence accuracy': 0.35609999999999997, 'first n-symbol accuracy': 0.5528948263210228, 'overlap rate': 0.7563836675068563}
#
# Current epoch: 270,
# training performance: {'loss': 1.4134126402437688, 'full sequence accuracy': 0.4219666666666666, 'first n-symbol accuracy': 0.6051514360627515, 'overlap rate': 0.7903039979913917}
# evaluation performance: {'loss': 1.5624704301357268, 'full sequence accuracy': 0.3806000000000001, 'first n-symbol accuracy': 0.5753138067475321, 'overlap rate': 0.7677960852350504}
#
# Current epoch: 280,
# training performance: {'loss': 1.0731102138757707, 'full sequence accuracy': 0.5339666666666666, 'first n-symbol accuracy': 0.6854434770083698, 'overlap rate': 0.8416918852900759}
# evaluation performance: {'loss': 1.2595081694424153, 'full sequence accuracy': 0.4807666666666667, 'first n-symbol accuracy': 0.646267504331081, 'overlap rate': 0.8148964926674184}
#
# Current epoch: 290,
# training performance: {'loss': 1.0337123084813356, 'full sequence accuracy': 0.5435999999999999, 'first n-symbol accuracy': 0.6960384423665611, 'overlap rate': 0.8529029252121167}
# evaluation performance: {'loss': 1.2441081393510103, 'full sequence accuracy': 0.4813666666666667, 'first n-symbol accuracy': 0.6509058961417262, 'overlap rate': 0.8233979195633625}
#
# Current epoch: 300,
# training performance: {'loss': 0.9643773633986712, 'full sequence accuracy': 0.5635999999999999, 'first n-symbol accuracy': 0.7269654749131635, 'overlap rate': 0.865734571897012}
# evaluation performance: {'loss': 1.1573813147842884, 'full sequence accuracy': 0.5075333333333334, 'first n-symbol accuracy': 0.68514862300093, 'overlap rate': 0.8384010174945917}
#
# Current epoch: 310,
# training performance: {'loss': 1.2201142489910126, 'full sequence accuracy': 0.4869, 'first n-symbol accuracy': 0.6696522748926972, 'overlap rate': 0.8383584117775609}
# evaluation performance: {'loss': 1.3975771576166154, 'full sequence accuracy': 0.4415000000000001, 'first n-symbol accuracy': 0.637184969340147, 'overlap rate': 0.8152570836858392}
#
# Current epoch: 320,
# training performance: {'loss': 0.9390384636819362, 'full sequence accuracy': 0.5632333333333334, 'first n-symbol accuracy': 0.7310284122412029, 'overlap rate': 0.8732597775856972}
# evaluation performance: {'loss': 1.1591823346912862, 'full sequence accuracy': 0.49903333333333333, 'first n-symbol accuracy': 0.6841981103565683, 'overlap rate': 0.8440137755884229}
#
# Current epoch: 330,
# training performance: {'loss': 0.984492152929306, 'full sequence accuracy': 0.5843, 'first n-symbol accuracy': 0.7244705444369651, 'overlap rate': 0.8703241688375174}
# evaluation performance: {'loss': 1.2009180940687656, 'full sequence accuracy': 0.5247333333333334, 'first n-symbol accuracy': 0.6819068495762246, 'overlap rate': 0.8422429854777784}
#
# Current epoch: 340,
# training performance: {'loss': 0.8010853627696634, 'full sequence accuracy': 0.6400666666666667, 'first n-symbol accuracy': 0.7656225348415491, 'overlap rate': 0.8919741681157769}
# evaluation performance: {'loss': 1.0376513961702585, 'full sequence accuracy': 0.5659, 'first n-symbol accuracy': 0.7142193432399796, 'overlap rate': 0.8608104426224749}
#
# Current epoch: 350,
# training performance: {'loss': 1.2065055668354034, 'full sequence accuracy': 0.4745333333333332, 'first n-symbol accuracy': 0.6752629844164109, 'overlap rate': 0.8465209694028933}
# evaluation performance: {'loss': 1.4314500868320466, 'full sequence accuracy': 0.4220666666666667, 'first n-symbol accuracy': 0.6326130716069784, 'overlap rate': 0.8173476041341011}
#
# Current epoch: 360,
# training performance: {'loss': 1.022561901807785, 'full sequence accuracy': 0.5488666666666667, 'first n-symbol accuracy': 0.7205575423563007, 'overlap rate': 0.8708329614439968}
# evaluation performance: {'loss': 1.2380328804254532, 'full sequence accuracy': 0.4915333333333334, 'first n-symbol accuracy': 0.6778333809653614, 'overlap rate': 0.8430918353896149}
#
# Current epoch: 370,
# training performance: {'loss': 0.8743524938821793, 'full sequence accuracy': 0.6112666666666666, 'first n-symbol accuracy': 0.7503360764361966, 'overlap rate': 0.8882446944064324}
# evaluation performance: {'loss': 1.1142200447618962, 'full sequence accuracy': 0.5423333333333333, 'first n-symbol accuracy': 0.700961404031422, 'overlap rate': 0.857940468538948}
#
# Current epoch: 380,
# training performance: {'loss': 1.1384348273277283, 'full sequence accuracy': 0.5325333333333333, 'first n-symbol accuracy': 0.708845702811481, 'overlap rate': 0.8631735836200882}
# evaluation performance: {'loss': 1.4040900021791458, 'full sequence accuracy': 0.4612, 'first n-symbol accuracy': 0.6591569498664835, 'overlap rate': 0.8295253245627373}
#
# Current epoch: 390,
# training performance: {'loss': 0.8885213382542133, 'full sequence accuracy': 0.5943333333333334, 'first n-symbol accuracy': 0.7532860922603482, 'overlap rate': 0.8872979866027857}
# evaluation performance: {'loss': 1.1431247219443321, 'full sequence accuracy': 0.5246666666666666, 'first n-symbol accuracy': 0.7010635818432307, 'overlap rate': 0.8542345657784874}
#
# Current epoch: 400,
# training performance: {'loss': 0.5843159962445498, 'full sequence accuracy': 0.6997333333333333, 'first n-symbol accuracy': 0.8158852970153234, 'overlap rate': 0.9254936831071884}
# evaluation performance: {'loss': 0.8911355439573526, 'full sequence accuracy': 0.5945666666666667, 'first n-symbol accuracy': 0.7439883220581328, 'overlap rate': 0.8869607039423896}
#
# Current epoch: 410,
# training performance: {'loss': 0.8187644772231579, 'full sequence accuracy': 0.6263333333333333, 'first n-symbol accuracy': 0.7611032387753927, 'overlap rate': 0.8984980770575204}
# evaluation performance: {'loss': 1.1091161340475082, 'full sequence accuracy': 0.5432666666666666, 'first n-symbol accuracy': 0.7022084694173766, 'overlap rate': 0.86284896435061}
#
# Current epoch: 420,
# training performance: {'loss': 0.7075885400176049, 'full sequence accuracy': 0.6698999999999999, 'first n-symbol accuracy': 0.7903370693158147, 'overlap rate': 0.9130945176765781}
# evaluation performance: {'loss': 0.9865499000996352, 'full sequence accuracy': 0.5799666666666667, 'first n-symbol accuracy': 0.7289023889942314, 'overlap rate': 0.877763798728932}
#
# Current epoch: 430,
# training performance: {'loss': 0.6529377687722444, 'full sequence accuracy': 0.7083666666666667, 'first n-symbol accuracy': 0.8126399187530282, 'overlap rate': 0.922040051600338}
# evaluation performance: {'loss': 0.9362971674650907, 'full sequence accuracy': 0.6144333333333333, 'first n-symbol accuracy': 0.7514150444434852, 'overlap rate': 0.8873785593740788}
#
# Current epoch: 440,
# training performance: {'loss': 0.43040374766569583, 'full sequence accuracy': 0.7817000000000001, 'first n-symbol accuracy': 0.8711275657706924, 'overlap rate': 0.9478880793728652}
# evaluation performance: {'loss': 0.7346833690069616, 'full sequence accuracy': 0.6702999999999999, 'first n-symbol accuracy': 0.7979823834409449, 'overlap rate': 0.9108014286247332}
#
# Current epoch: 450,
# training performance: {'loss': 0.5210177516099066, 'full sequence accuracy': 0.7499666666666667, 'first n-symbol accuracy': 0.8404975830220589, 'overlap rate': 0.9372097907524332}
# evaluation performance: {'loss': 0.808482120744884, 'full sequence accuracy': 0.6506666666666667, 'first n-symbol accuracy': 0.7746814611898926, 'overlap rate': 0.902610585758163}
#
# Current epoch: 460,
# training performance: {'loss': 0.741186860203743, 'full sequence accuracy': 0.6855, 'first n-symbol accuracy': 0.807228461874628, 'overlap rate': 0.916497482876063}
# evaluation performance: {'loss': 1.0741100668907166, 'full sequence accuracy': 0.5758999999999999, 'first n-symbol accuracy': 0.7362854104430111, 'overlap rate': 0.8767539723024912}
#
# Current epoch: 470,
# training performance: {'loss': 0.49297480592504145, 'full sequence accuracy': 0.7364666666666666, 'first n-symbol accuracy': 0.8429982594669285, 'overlap rate': 0.9411154506130153}
# evaluation performance: {'loss': 0.840294486284256, 'full sequence accuracy': 0.6154666666666666, 'first n-symbol accuracy': 0.7621549973469596, 'overlap rate': 0.9001313126120184}
#
# Current epoch: 480,
# training performance: {'loss': 0.3210082262288779, 'full sequence accuracy': 0.8291000000000001, 'first n-symbol accuracy': 0.9004736891076137, 'overlap rate': 0.9627186952736333}
# evaluation performance: {'loss': 0.6351579777896404, 'full sequence accuracy': 0.6997, 'first n-symbol accuracy': 0.8195428278593713, 'overlap rate': 0.9247731917882842}
#
# Current epoch: 490,
# training performance: {'loss': 0.294407580117695, 'full sequence accuracy': 0.8439666666666668, 'first n-symbol accuracy': 0.9038968592815936, 'overlap rate': 0.9652194094825779}
# evaluation performance: {'loss': 0.6391643892973662, 'full sequence accuracy': 0.6965333333333332, 'first n-symbol accuracy': 0.8118658805961478, 'overlap rate': 0.9244329584449703}
#
# Current epoch: 500,
# training performance: {'loss': 0.34286580004263667, 'full sequence accuracy': 0.8092, 'first n-symbol accuracy': 0.8879952450962725, 'overlap rate': 0.9601007876410244}
# evaluation performance: {'loss': 0.7033990494906902, 'full sequence accuracy': 0.6705333333333334, 'first n-symbol accuracy': 0.7992922916121853, 'overlap rate': 0.918097287128354}
#
# Current epoch: 510,
# training performance: {'loss': 0.33209829218685627, 'full sequence accuracy': 0.8236999999999999, 'first n-symbol accuracy': 0.8961983987624349, 'overlap rate': 0.962523472409804}
# evaluation performance: {'loss': 0.6589530384168029, 'full sequence accuracy': 0.6914, 'first n-symbol accuracy': 0.8116185657761751, 'overlap rate': 0.9242196949959061}
#
# Current epoch: 520,
# training performance: {'loss': 0.339818176580593, 'full sequence accuracy': 0.8261333333333333, 'first n-symbol accuracy': 0.8930892967581965, 'overlap rate': 0.9608557950737158}
# evaluation performance: {'loss': 0.6624655961059034, 'full sequence accuracy': 0.6984999999999999, 'first n-symbol accuracy': 0.8122520904323792, 'overlap rate': 0.9231980489982501}
#
# Current epoch: 530,
# training performance: {'loss': 0.2967230547219515, 'full sequence accuracy': 0.8416333333333332, 'first n-symbol accuracy': 0.9067848978772048, 'overlap rate': 0.9661164898010375}
# evaluation performance: {'loss': 0.6441365171223878, 'full sequence accuracy': 0.6955333333333333, 'first n-symbol accuracy': 0.8154577554080292, 'overlap rate': 0.9258595089729236}
#
# Current epoch: 540,
# training performance: {'loss': 0.2169671980664134, 'full sequence accuracy': 0.8725666666666665, 'first n-symbol accuracy': 0.9280810178553329, 'overlap rate': 0.9757086805198751}
# evaluation performance: {'loss': 0.544120917422697, 'full sequence accuracy': 0.7277, 'first n-symbol accuracy': 0.84212327063465, 'overlap rate': 0.936781262907953}
#
# Current epoch: 550,
# training performance: {'loss': 0.20474457936361432, 'full sequence accuracy': 0.8884000000000001, 'first n-symbol accuracy': 0.9340349350793888, 'overlap rate': 0.9772618531951194}
# evaluation performance: {'loss': 0.5683435355313122, 'full sequence accuracy': 0.7252333333333334, 'first n-symbol accuracy': 0.8347903402209722, 'overlap rate': 0.9357408992568074}
#
# Current epoch: 560,
# training performance: {'loss': 0.26127235980238767, 'full sequence accuracy': 0.8638666666666666, 'first n-symbol accuracy': 0.9179877725195308, 'overlap rate': 0.971748865005085}
# evaluation performance: {'loss': 0.5920866191387176, 'full sequence accuracy': 0.7246, 'first n-symbol accuracy': 0.8322160009215661, 'overlap rate': 0.9337223824955373}
#
# Current epoch: 570,
# training performance: {'loss': 0.23841782303061337, 'full sequence accuracy': 0.8804333333333332, 'first n-symbol accuracy': 0.9236510992036809, 'overlap rate': 0.9736762812277908}
# evaluation performance: {'loss': 0.5849292949773371, 'full sequence accuracy': 0.7258333333333333, 'first n-symbol accuracy': 0.8309365305101133, 'overlap rate': 0.9345805708837893}
#
# Current epoch: 580,
# training performance: {'loss': 0.37358235418796537, 'full sequence accuracy': 0.8218, 'first n-symbol accuracy': 0.9021176057271539, 'overlap rate': 0.9601681738895336}
# evaluation performance: {'loss': 0.7203716561198235, 'full sequence accuracy': 0.6772, 'first n-symbol accuracy': 0.8160594987658228, 'overlap rate': 0.9207985629183304}
#
# Current epoch: 590,
# training performance: {'loss': 0.16247580735944211, 'full sequence accuracy': 0.9114000000000001, 'first n-symbol accuracy': 0.9464117658403233, 'overlap rate': 0.9820944292132463}
# evaluation performance: {'loss': 0.5057667952030898, 'full sequence accuracy': 0.7468999999999999, 'first n-symbol accuracy': 0.848408687950838, 'overlap rate': 0.9425983571159785}
#
# Current epoch: 600,
# training performance: {'loss': 0.1398951746057719, 'full sequence accuracy': 0.9210999999999998, 'first n-symbol accuracy': 0.9563968504588074, 'overlap rate': 0.9852650147227514}
# evaluation performance: {'loss': 0.4824232991784811, 'full sequence accuracy': 0.7566333333333333, 'first n-symbol accuracy': 0.8592721472280946, 'overlap rate': 0.9463028353607406}
#
# Current epoch: 610,
# training performance: {'loss': 0.20366699602454902, 'full sequence accuracy': 0.8825666666666667, 'first n-symbol accuracy': 0.9397834359320573, 'overlap rate': 0.9776222238611225}
# evaluation performance: {'loss': 0.5445712927728892, 'full sequence accuracy': 0.7347333333333332, 'first n-symbol accuracy': 0.8502209907179361, 'overlap rate': 0.9378570960830229}
#
# Current epoch: 620,
# training performance: {'loss': 0.145602900441736, 'full sequence accuracy': 0.9169, 'first n-symbol accuracy': 0.9524927008320176, 'overlap rate': 0.9838458873458246}
# evaluation performance: {'loss': 0.4880409637466073, 'full sequence accuracy': 0.7547666666666666, 'first n-symbol accuracy': 0.8553325583034674, 'overlap rate': 0.9440371920861047}
#
# Current epoch: 630,
# training performance: {'loss': 0.1276746515999548, 'full sequence accuracy': 0.9228333333333332, 'first n-symbol accuracy': 0.9566982605487914, 'overlap rate': 0.9861261495534974}
# evaluation performance: {'loss': 0.4631998238619417, 'full sequence accuracy': 0.7660333333333333, 'first n-symbol accuracy': 0.8610405238322203, 'overlap rate': 0.9479698776912968}
#
# Current epoch: 640,
# training performance: {'loss': 0.12872305052587762, 'full sequence accuracy': 0.9292000000000001, 'first n-symbol accuracy': 0.9571079158601956, 'overlap rate': 0.9864270536434905}
# evaluation performance: {'loss': 0.4489680405240506, 'full sequence accuracy': 0.7760333333333332, 'first n-symbol accuracy': 0.8666516221283096, 'overlap rate': 0.9503997332432821}
#
# Current epoch: 650,
# training performance: {'loss': 0.3472339749336243, 'full sequence accuracy': 0.7933666666666666, 'first n-symbol accuracy': 0.9058707127027471, 'overlap rate': 0.9630025366505196}
# evaluation performance: {'loss': 0.7404366761446, 'full sequence accuracy': 0.613, 'first n-symbol accuracy': 0.7997185549262271, 'overlap rate': 0.9200543534414537}
#
# Current epoch: 660,
# training performance: {'loss': 0.13834510133601724, 'full sequence accuracy': 0.9138333333333334, 'first n-symbol accuracy': 0.9559912835728236, 'overlap rate': 0.9847396223021002}
# evaluation performance: {'loss': 0.46836885982193055, 'full sequence accuracy': 0.7561666666666668, 'first n-symbol accuracy': 0.8630876943043753, 'overlap rate': 0.9467788209179553}
#
# Current epoch: 670,
# training performance: {'loss': 0.051934110111324115, 'full sequence accuracy': 0.968, 'first n-symbol accuracy': 0.9835562594067362, 'overlap rate': 0.9950883486261647}
# evaluation performance: {'loss': 0.3476983921136707, 'full sequence accuracy': 0.8059333333333333, 'first n-symbol accuracy': 0.892717314171791, 'overlap rate': 0.9618563611997775}
#
# Current epoch: 680,
# training performance: {'loss': 0.10083304072031751, 'full sequence accuracy': 0.9435333333333332, 'first n-symbol accuracy': 0.968116494086136, 'overlap rate': 0.9896551939028001}
# evaluation performance: {'loss': 0.43212711163796486, 'full sequence accuracy': 0.7781333333333333, 'first n-symbol accuracy': 0.872085352683839, 'overlap rate': 0.9523755776623741}
#
# Current epoch: 690,
# training performance: {'loss': 0.26724995151162145, 'full sequence accuracy': 0.8604333333333333, 'first n-symbol accuracy': 0.9262548628684094, 'overlap rate': 0.9715372289286088}
# evaluation performance: {'loss': 0.6552660070359707, 'full sequence accuracy': 0.6983333333333334, 'first n-symbol accuracy': 0.8304838599298616, 'overlap rate': 0.928077385896594}
#
# Current epoch: 700,
# training performance: {'loss': 0.10853875493630767, 'full sequence accuracy': 0.9273333333333336, 'first n-symbol accuracy': 0.9626848827134097, 'overlap rate': 0.9887527815554469}
# evaluation performance: {'loss': 0.47213133201003077, 'full sequence accuracy': 0.7460666666666665, 'first n-symbol accuracy': 0.8566082327200535, 'overlap rate': 0.9482396257573328}
#
# Current epoch: 710,
# training performance: {'loss': 0.10681490658316761, 'full sequence accuracy': 0.9340333333333334, 'first n-symbol accuracy': 0.9635922825719596, 'overlap rate': 0.9891614847389703}
# evaluation performance: {'loss': 0.45978944627568125, 'full sequence accuracy': 0.7632666666666665, 'first n-symbol accuracy': 0.8619275174165336, 'overlap rate': 0.9504901220093668}
#
# Current epoch: 720,
# training performance: {'loss': 0.05476596208754927, 'full sequence accuracy': 0.9650333333333332, 'first n-symbol accuracy': 0.9823681721289892, 'overlap rate': 0.9948759063287949}
# evaluation performance: {'loss': 0.3552358378889039, 'full sequence accuracy': 0.8055, 'first n-symbol accuracy': 0.894717214084255, 'overlap rate': 0.9617725422287233}
#
# Current epoch: 730,
# training performance: {'loss': 0.08189317596261389, 'full sequence accuracy': 0.9512333333333333, 'first n-symbol accuracy': 0.9736397666693417, 'overlap rate': 0.9919769508468133}
# evaluation performance: {'loss': 0.42420034506358206, 'full sequence accuracy': 0.7805666666666666, 'first n-symbol accuracy': 0.8740480944014836, 'overlap rate': 0.954761685377879}
#
# Current epoch: 740,
# training performance: {'loss': 0.08392183421528898, 'full sequence accuracy': 0.9490666666666666, 'first n-symbol accuracy': 0.9710281449164677, 'overlap rate': 0.9914214319543039}
# evaluation performance: {'loss': 0.42336809332482517, 'full sequence accuracy': 0.7803666666666667, 'first n-symbol accuracy': 0.8714167404352251, 'overlap rate': 0.9545299391932334}
#
# Current epoch: 750,
# training performance: {'loss': 0.10540720807621255, 'full sequence accuracy': 0.9424666666666666, 'first n-symbol accuracy': 0.9649758871158056, 'overlap rate': 0.9893764615318548}
# evaluation performance: {'loss': 0.4614722970407456, 'full sequence accuracy': 0.7763666666666666, 'first n-symbol accuracy': 0.8658151178108711, 'overlap rate': 0.9510026635710384}
#
# Current epoch: 760,
# training performance: {'loss': 0.0908117683371529, 'full sequence accuracy': 0.9500666666666667, 'first n-symbol accuracy': 0.9700788835316392, 'overlap rate': 0.9911412310325431}
# evaluation performance: {'loss': 0.4518071792088449, 'full sequence accuracy': 0.7697999999999999, 'first n-symbol accuracy': 0.8646779203454524, 'overlap rate': 0.9522688420037217}
#
# Current epoch: 770,
# training performance: {'loss': 0.04363048311206512, 'full sequence accuracy': 0.9734, 'first n-symbol accuracy': 0.9852925859669013, 'overlap rate': 0.9959298012768565}
# evaluation performance: {'loss': 0.3678422645200044, 'full sequence accuracy': 0.8051666666666668, 'first n-symbol accuracy': 0.8888531901655513, 'overlap rate': 0.9610210024711663}
#
# Current epoch: 780,
# training performance: {'loss': 0.08413223822135478, 'full sequence accuracy': 0.9484333333333332, 'first n-symbol accuracy': 0.9728470339165444, 'overlap rate': 0.9918690466891686}
# evaluation performance: {'loss': 0.4146476806141436, 'full sequence accuracy': 0.7816333333333333, 'first n-symbol accuracy': 0.879144460998465, 'overlap rate': 0.956168323257917}
#
# Current epoch: 790,
# training performance: {'loss': 0.10764408560935408, 'full sequence accuracy': 0.9292333333333334, 'first n-symbol accuracy': 0.9640809785507491, 'overlap rate': 0.9887679361691261}
# evaluation performance: {'loss': 0.49174322932958603, 'full sequence accuracy': 0.7467666666666668, 'first n-symbol accuracy': 0.8585931485041872, 'overlap rate': 0.9480137435191984}
#
# Current epoch: 800,
# training performance: {'loss': 0.08652545055374503, 'full sequence accuracy': 0.9409333333333333, 'first n-symbol accuracy': 0.9710846399957015, 'overlap rate': 0.9914167096164948}
# evaluation performance: {'loss': 0.4371392918750644, 'full sequence accuracy': 0.7633666666666665, 'first n-symbol accuracy': 0.8698416180407131, 'overlap rate': 0.9539613109089607}
#
# Current epoch: 810,
# training performance: {'loss': 0.06911909747868776, 'full sequence accuracy': 0.9577666666666668, 'first n-symbol accuracy': 0.976790428509377, 'overlap rate': 0.9933702251413555}
# evaluation performance: {'loss': 0.4023569350130856, 'full sequence accuracy': 0.7838999999999999, 'first n-symbol accuracy': 0.879194328199767, 'overlap rate': 0.957663816484537}
#
# Current epoch: 820,
# training performance: {'loss': 0.06982939263107255, 'full sequence accuracy': 0.9621333333333333, 'first n-symbol accuracy': 0.9770062490211956, 'overlap rate': 0.9932507408687506}
# evaluation performance: {'loss': 0.40559682296589017, 'full sequence accuracy': 0.7934333333333333, 'first n-symbol accuracy': 0.8808152204952411, 'overlap rate': 0.9576415012190879}
#
# Current epoch: 830,
# training performance: {'loss': 0.03995314667117782, 'full sequence accuracy': 0.9759, 'first n-symbol accuracy': 0.9868011409059081, 'overlap rate': 0.996408819072969}
# evaluation performance: {'loss': 0.35106923829298464, 'full sequence accuracy': 0.8094666666666666, 'first n-symbol accuracy': 0.8939590019910755, 'overlap rate': 0.9632355480076166}
#
# Current epoch: 840,
# training performance: {'loss': 0.04795045009814203, 'full sequence accuracy': 0.9734333333333334, 'first n-symbol accuracy': 0.9846923966803081, 'overlap rate': 0.9956004106054157}
# evaluation performance: {'loss': 0.36946721381973474, 'full sequence accuracy': 0.8048, 'first n-symbol accuracy': 0.8907360698556511, 'overlap rate': 0.9613931096229382}
#
# Current epoch: 850,
# training performance: {'loss': 0.06704061623313465, 'full sequence accuracy': 0.9662, 'first n-symbol accuracy': 0.9790084176336858, 'overlap rate': 0.9934281955127503}
# evaluation performance: {'loss': 0.4060327547369525, 'full sequence accuracy': 0.8000666666666666, 'first n-symbol accuracy': 0.8833211014366643, 'overlap rate': 0.9574345297575281}
#
# Current epoch: 860,
# training performance: {'loss': 0.03778079408220947, 'full sequence accuracy': 0.9763333333333334, 'first n-symbol accuracy': 0.9874630821229206, 'overlap rate': 0.996531544542696}
# evaluation performance: {'loss': 0.34431725030299276, 'full sequence accuracy': 0.8139666666666667, 'first n-symbol accuracy': 0.896482939338372, 'overlap rate': 0.9641586050532298}
#
# Current epoch: 870,
# training performance: {'loss': 0.009534988144878298, 'full sequence accuracy': 0.9955, 'first n-symbol accuracy': 0.9976636297990995, 'overlap rate': 0.9994553532696553}
# evaluation performance: {'loss': 0.26643633951898665, 'full sequence accuracy': 0.8421333333333333, 'first n-symbol accuracy': 0.9161416632369663, 'overlap rate': 0.9728161601209937}
#
# Current epoch: 880,
# training performance: {'loss': 0.0025468672014540062, 'full sequence accuracy': 0.9999666666666667, 'first n-symbol accuracy': 0.9999698924731183, 'overlap rate': 0.9999827956989247}
# evaluation performance: {'loss': 0.2069000595016405, 'full sequence accuracy': 0.8699666666666668, 'first n-symbol accuracy': 0.9350450876266576, 'overlap rate': 0.9792805683464142}
#
# Current epoch: 890,
# training performance: {'loss': 0.002094247315835673, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.2022583063575439, 'full sequence accuracy': 0.8724000000000001, 'first n-symbol accuracy': 0.9373868629466175, 'overlap rate': 0.97998283303365}
#
# Current epoch: 900,
# training performance: {'loss': 0.0018906424302258529, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.20045254342257976, 'full sequence accuracy': 0.8738999999999999, 'first n-symbol accuracy': 0.9389701031065822, 'overlap rate': 0.980313107000943}
#
# Current epoch: 910,
# training performance: {'loss': 0.0017428961000405252, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.19554351794649846, 'full sequence accuracy': 0.8766, 'first n-symbol accuracy': 0.9408903064529082, 'overlap rate': 0.9809969427338459}
#
# Current epoch: 920,
# training performance: {'loss': 0.0016285879391944036, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1927075662475545, 'full sequence accuracy': 0.8787666666666667, 'first n-symbol accuracy': 0.9423960278669918, 'overlap rate': 0.9813986468160938}
#
# Current epoch: 930,
# training performance: {'loss': 0.0015364789855084383, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.19050537663861178, 'full sequence accuracy': 0.8812000000000001, 'first n-symbol accuracy': 0.9439499844351907, 'overlap rate': 0.9817889650787966}
#
# Current epoch: 940,
# training performance: {'loss': 0.0014600523907574825, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.18684228691272436, 'full sequence accuracy': 0.8834666666666665, 'first n-symbol accuracy': 0.9455951239312881, 'overlap rate': 0.9822704457191683}
#
# Current epoch: 950,
# training performance: {'loss': 0.0013951588771305978, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.18452447262825444, 'full sequence accuracy': 0.8848666666666667, 'first n-symbol accuracy': 0.9466718378400394, 'overlap rate': 0.982610041349688}
#
# Current epoch: 960,
# training performance: {'loss': 0.0013389834173722192, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1813876190339215, 'full sequence accuracy': 0.8869333333333334, 'first n-symbol accuracy': 0.9479698481800783, 'overlap rate': 0.9830232749743215}
#
# Current epoch: 970,
# training performance: {'loss': 0.0012895228050183506, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.18045627950341442, 'full sequence accuracy': 0.8885333333333334, 'first n-symbol accuracy': 0.9488999107238192, 'overlap rate': 0.9831929255755444}
#
# Current epoch: 980,
# training performance: {'loss': 0.001245303510222584, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1793373815191444, 'full sequence accuracy': 0.8897999999999998, 'first n-symbol accuracy': 0.949769386720706, 'overlap rate': 0.9833882019849718}
#
# Current epoch: 990,
# training performance: {'loss': 0.0012052078411215917, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1761102285119705, 'full sequence accuracy': 0.8911666666666667, 'first n-symbol accuracy': 0.9508522576605521, 'overlap rate': 0.9838174632236969}
#
# Current epoch: 1000,
# training performance: {'loss': 0.00116837090899935, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.17543405904143583, 'full sequence accuracy': 0.8928999999999998, 'first n-symbol accuracy': 0.951737334462023, 'overlap rate': 0.9839606411809523}
#
# Current epoch: 1010,
# training performance: {'loss': 0.0011341098026605323, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.17345469860301818, 'full sequence accuracy': 0.8943, 'first n-symbol accuracy': 0.9526000809999656, 'overlap rate': 0.984188126889145}
#
# Current epoch: 1020,
# training performance: {'loss': 0.0011018802048056386, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1718213037471287, 'full sequence accuracy': 0.8959666666666666, 'first n-symbol accuracy': 0.9534582922118202, 'overlap rate': 0.9843993944623903}
#
# Current epoch: 1030,
# training performance: {'loss': 0.001071500006946735, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1704798065504292, 'full sequence accuracy': 0.8975333333333332, 'first n-symbol accuracy': 0.9542342797198451, 'overlap rate': 0.9846004728968495}
#
# Current epoch: 1040,
# training performance: {'loss': 1.147719407081604, 'full sequence accuracy': 0.5238333333333334, 'first n-symbol accuracy': 0.7131759864736884, 'overlap rate': 0.8824314018843831}
# evaluation performance: {'loss': 1.4697503209114076, 'full sequence accuracy': 0.43260000000000004, 'first n-symbol accuracy': 0.6485847647902228, 'overlap rate': 0.8484478954087595}
#
# Current epoch: 1050,
# training performance: {'loss': 0.7193635687232017, 'full sequence accuracy': 0.6133333333333333, 'first n-symbol accuracy': 0.7861331203479744, 'overlap rate': 0.9152215417810773}
# evaluation performance: {'loss': 0.9930490136146546, 'full sequence accuracy': 0.5392999999999999, 'first n-symbol accuracy': 0.7293175511227524, 'overlap rate': 0.883170696011567}
#
# Current epoch: 1060,
# training performance: {'loss': 0.16946326079778373, 'full sequence accuracy': 0.8886, 'first n-symbol accuracy': 0.9387133273396993, 'overlap rate': 0.9809181274365626}
# evaluation performance: {'loss': 0.4244698847644031, 'full sequence accuracy': 0.7637333333333334, 'first n-symbol accuracy': 0.8612851566373637, 'overlap rate': 0.9504203031851984}
#
# Current epoch: 1070,
# training performance: {'loss': 0.1954130220459774, 'full sequence accuracy': 0.8955, 'first n-symbol accuracy': 0.9313184556399104, 'overlap rate': 0.9785799734597751}
# evaluation performance: {'loss': 0.4725241902284324, 'full sequence accuracy': 0.767, 'first n-symbol accuracy': 0.8519503710096272, 'overlap rate': 0.946362465042222}
#
# Current epoch: 1080,
# training performance: {'loss': 0.15494589294539765, 'full sequence accuracy': 0.9104333333333331, 'first n-symbol accuracy': 0.9449272362829427, 'overlap rate': 0.9833809199866588}
# evaluation performance: {'loss': 0.45694928369484844, 'full sequence accuracy': 0.7687333333333334, 'first n-symbol accuracy': 0.858433352406597, 'overlap rate': 0.9496663319159035}
#
# Current epoch: 1090,
# training performance: {'loss': 0.0681675598025322, 'full sequence accuracy': 0.9577666666666665, 'first n-symbol accuracy': 0.9763317999109876, 'overlap rate': 0.9931376667945793}
# evaluation performance: {'loss': 0.3274890886619687, 'full sequence accuracy': 0.8190999999999999, 'first n-symbol accuracy': 0.8962248520873326, 'overlap rate': 0.9642396056350362}
#
# Current epoch: 1100,
# training performance: {'loss': 0.20641740132123232, 'full sequence accuracy': 0.8987, 'first n-symbol accuracy': 0.9335546237902641, 'overlap rate': 0.9787510901868967}
# evaluation performance: {'loss': 0.5276110151782631, 'full sequence accuracy': 0.7457, 'first n-symbol accuracy': 0.8419727296096843, 'overlap rate': 0.9438522185066514}
#
# Current epoch: 1110,
# training performance: {'loss': 0.07031279536895454, 'full sequence accuracy': 0.9543666666666667, 'first n-symbol accuracy': 0.975912983322746, 'overlap rate': 0.9929151172999724}
# evaluation performance: {'loss': 0.35167403989471496, 'full sequence accuracy': 0.8026666666666668, 'first n-symbol accuracy': 0.8900323915333533, 'overlap rate': 0.9618783382122077}
#
# Current epoch: 1120,
# training performance: {'loss': 0.06035860292613506, 'full sequence accuracy': 0.9655333333333334, 'first n-symbol accuracy': 0.9790496381229724, 'overlap rate': 0.9942891026854133}
# evaluation performance: {'loss': 0.3190092870499939, 'full sequence accuracy': 0.8233333333333333, 'first n-symbol accuracy': 0.8987124682671015, 'overlap rate': 0.9661155916476389}
#
# Current epoch: 1130,
# training performance: {'loss': 0.07202578585711308, 'full sequence accuracy': 0.9605999999999998, 'first n-symbol accuracy': 0.9757603215015438, 'overlap rate': 0.9930540444108299}
# evaluation performance: {'loss': 0.35346353044733403, 'full sequence accuracy': 0.8133000000000001, 'first n-symbol accuracy': 0.8923007201995918, 'overlap rate': 0.9626484126821735}
#
# Current epoch: 1140,
# training performance: {'loss': 0.027342433587182313, 'full sequence accuracy': 0.9839666666666667, 'first n-symbol accuracy': 0.9912529643254835, 'overlap rate': 0.9976795915805537}
# evaluation performance: {'loss': 0.2820108732674271, 'full sequence accuracy': 0.8349666666666666, 'first n-symbol accuracy': 0.9106056694457104, 'overlap rate': 0.9707752855953975}
#
# Current epoch: 1150,
# training performance: {'loss': 0.03534815148450434, 'full sequence accuracy': 0.9795333333333334, 'first n-symbol accuracy': 0.9885033253695733, 'overlap rate': 0.9968365653302381}
# evaluation performance: {'loss': 0.3077436648309231, 'full sequence accuracy': 0.8281666666666666, 'first n-symbol accuracy': 0.9043506267397354, 'overlap rate': 0.9680650903789616}
#
# Current epoch: 1160,
# training performance: {'loss': 0.007900280668400228, 'full sequence accuracy': 0.9960666666666669, 'first n-symbol accuracy': 0.9982704861643251, 'overlap rate': 0.9995995975775551}
# evaluation performance: {'loss': 0.2344744703732431, 'full sequence accuracy': 0.8569000000000001, 'first n-symbol accuracy': 0.9252078379529669, 'overlap rate': 0.975886481582729}
#
# Current epoch: 1170,
# training performance: {'loss': 0.002064607379725203, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.15692266694968565, 'full sequence accuracy': 0.8964333333333332, 'first n-symbol accuracy': 0.948011149331798, 'overlap rate': 0.9843818411615874}
#
# Current epoch: 1180,
# training performance: {'loss': 0.001758433885697741, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.15383191289147363, 'full sequence accuracy': 0.8981666666666666, 'first n-symbol accuracy': 0.9502374642548217, 'overlap rate': 0.9848410723663912}
#
# Current epoch: 1190,
# training performance: {'loss': 0.001575039762246888, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.15067144013009964, 'full sequence accuracy': 0.8991, 'first n-symbol accuracy': 0.9518590779779232, 'overlap rate': 0.9852941124586823}
#
# Current epoch: 1200,
# training performance: {'loss': 0.0014458793360972778, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.14873806935502215, 'full sequence accuracy': 0.9011666666666667, 'first n-symbol accuracy': 0.9533080229327275, 'overlap rate': 0.9856166368407313}
#
# Current epoch: 1210,
# training performance: {'loss': 0.0013479372733854688, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.14737773064989595, 'full sequence accuracy': 0.9026333333333334, 'first n-symbol accuracy': 0.9543629983581402, 'overlap rate': 0.9858902167546489}
#
# Current epoch: 1220,
# training performance: {'loss': 0.0012702663443633355, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1454798449878581, 'full sequence accuracy': 0.9043666666666667, 'first n-symbol accuracy': 0.9555379653211512, 'overlap rate': 0.9861537293601825}
#
# Current epoch: 1230,
# training performance: {'loss': 0.0012067143252352253, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1435873525508214, 'full sequence accuracy': 0.9057333333333333, 'first n-symbol accuracy': 0.9564765854522271, 'overlap rate': 0.986445564092897}
#
# Current epoch: 1240,
# training performance: {'loss': 0.0011534503704751843, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.14261597978183999, 'full sequence accuracy': 0.9067333333333334, 'first n-symbol accuracy': 0.9572014718323857, 'overlap rate': 0.9865954776276811}
#
# Current epoch: 1250,
# training performance: {'loss': 0.0011079152565798723, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.14227817823993974, 'full sequence accuracy': 0.9074666666666665, 'first n-symbol accuracy': 0.9577800136463054, 'overlap rate': 0.9866509358371325}
#
# Current epoch: 1260,
# training performance: {'loss': 0.0010683084634365513, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.14035704669659027, 'full sequence accuracy': 0.9089999999999998, 'first n-symbol accuracy': 0.9587832291097463, 'overlap rate': 0.986887583586164}
#
# Current epoch: 1270,
# training performance: {'loss': 0.0010333131911465898, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.13736346085206605, 'full sequence accuracy': 0.9110666666666665, 'first n-symbol accuracy': 0.9599549765239722, 'overlap rate': 0.9872232476107827}
#
# Current epoch: 1280,
# training performance: {'loss': 0.0010019342604209668, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1351783881429583, 'full sequence accuracy': 0.9127333333333333, 'first n-symbol accuracy': 0.9610309824564901, 'overlap rate': 0.9874665075161451}
#
# Current epoch: 1290,
# training performance: {'loss': 0.000973399136273656, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.13267155545181594, 'full sequence accuracy': 0.9140333333333333, 'first n-symbol accuracy': 0.9619153827647752, 'overlap rate': 0.9877725846105827}
#
# Current epoch: 1300,
# training performance: {'loss': 0.0009470976481679827, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.13105241851881147, 'full sequence accuracy': 0.9155333333333331, 'first n-symbol accuracy': 0.9627378832662989, 'overlap rate': 0.9879587564721535}
#
# Current epoch: 1310,
# training performance: {'loss': 0.0009225405388860964, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.12804274252557662, 'full sequence accuracy': 0.9174, 'first n-symbol accuracy': 0.9638329380024571, 'overlap rate': 0.9882487864058127}
#
# Current epoch: 1320,
# training performance: {'loss': 0.0008993298179120757, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1254431702371221, 'full sequence accuracy': 0.9192666666666668, 'first n-symbol accuracy': 0.9647875029829509, 'overlap rate': 0.9885688676085135}
#
# Current epoch: 1330,
# training performance: {'loss': 0.0008771401044214144, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.12136103260563687, 'full sequence accuracy': 0.9211, 'first n-symbol accuracy': 0.9659563997755318, 'overlap rate': 0.9889497987128074}
#
# Current epoch: 1340,
# training performance: {'loss': 0.18184142112731932, 'full sequence accuracy': 0.9158666666666667, 'first n-symbol accuracy': 0.9597908500352978, 'overlap rate': 0.9824544622992635}
# evaluation performance: {'loss': 0.42115117236971855, 'full sequence accuracy': 0.7892000000000001, 'first n-symbol accuracy': 0.8932848923683269, 'overlap rate': 0.9600655149099981}
#
# Current epoch: 1350,
# training performance: {'loss': 1.271953245997429, 'full sequence accuracy': 0.4908999999999999, 'first n-symbol accuracy': 0.6850939862970449, 'overlap rate': 0.8632346073950862}
# evaluation performance: {'loss': 1.57426216006279, 'full sequence accuracy': 0.4083, 'first n-symbol accuracy': 0.6233580256511402, 'overlap rate': 0.8285906502564104}
#
# Current epoch: 1360,
# training performance: {'loss': 0.128175685624592, 'full sequence accuracy': 0.9167666666666665, 'first n-symbol accuracy': 0.9556248682291637, 'overlap rate': 0.9858282226434462}
# evaluation performance: {'loss': 0.33812633096240463, 'full sequence accuracy': 0.8038333333333332, 'first n-symbol accuracy': 0.8891326570180551, 'overlap rate': 0.9605650696212551}
#
# Current epoch: 1370,
# training performance: {'loss': 0.07819654167396947, 'full sequence accuracy': 0.9515, 'first n-symbol accuracy': 0.9712705952779862, 'overlap rate': 0.9918728870315803}
# evaluation performance: {'loss': 0.2887468442087993, 'full sequence accuracy': 0.8282666666666666, 'first n-symbol accuracy': 0.9001278604468157, 'overlap rate': 0.967562332266702}
#
# Current epoch: 1380,
# training performance: {'loss': 0.07917328220792115, 'full sequence accuracy': 0.9511, 'first n-symbol accuracy': 0.9705935587194521, 'overlap rate': 0.9916489777588657}
# evaluation performance: {'loss': 0.3129314991296269, 'full sequence accuracy': 0.8232666666666667, 'first n-symbol accuracy': 0.8957332648972114, 'overlap rate': 0.9651957517462015}
#
# Current epoch: 1390,
# training performance: {'loss': 0.07835301535669714, 'full sequence accuracy': 0.9545333333333333, 'first n-symbol accuracy': 0.9713040100683423, 'overlap rate': 0.9919513678997911}
# evaluation performance: {'loss': 0.3185903972480446, 'full sequence accuracy': 0.8260333333333332, 'first n-symbol accuracy': 0.8954265205743311, 'overlap rate': 0.9652784405258584}
#
# Current epoch: 1400,
# training performance: {'loss': 0.08382326734717935, 'full sequence accuracy': 0.9498, 'first n-symbol accuracy': 0.9697946577944402, 'overlap rate': 0.9913960831940221}
# evaluation performance: {'loss': 0.3220561905996874, 'full sequence accuracy': 0.8249000000000001, 'first n-symbol accuracy': 0.8957638922321222, 'overlap rate': 0.9650941717265742}
#
# Current epoch: 1410,
# training performance: {'loss': 0.08915339909144677, 'full sequence accuracy': 0.9498666666666665, 'first n-symbol accuracy': 0.9690728748415832, 'overlap rate': 0.9910771720019204}
# evaluation performance: {'loss': 0.33476856492925433, 'full sequence accuracy': 0.8248000000000001, 'first n-symbol accuracy': 0.8951727910781525, 'overlap rate': 0.9645770935798271}
#
# Current epoch: 1420,
# training performance: {'loss': 0.03456836706609465, 'full sequence accuracy': 0.9824999999999999, 'first n-symbol accuracy': 0.9892553881816557, 'overlap rate': 0.9967810442305728}
# evaluation performance: {'loss': 0.26890490734949707, 'full sequence accuracy': 0.8458333333333332, 'first n-symbol accuracy': 0.9138800198391653, 'overlap rate': 0.9716542625577504}
#
# Current epoch: 1430,
# training performance: {'loss': 0.013748272164957599, 'full sequence accuracy': 0.9921333333333333, 'first n-symbol accuracy': 0.9961666161853364, 'overlap rate': 0.9990007628228896}
# evaluation performance: {'loss': 0.21987124187871815, 'full sequence accuracy': 0.8616666666666666, 'first n-symbol accuracy': 0.9274088044267152, 'overlap rate': 0.9769574804531393}
#
# Current epoch: 1440,
# training performance: {'loss': 0.002120060523157008, 'full sequence accuracy': 0.9999333333333332, 'first n-symbol accuracy': 0.9999976160068114, 'overlap rate': 0.9999976160068114}
# evaluation performance: {'loss': 0.13636321008671076, 'full sequence accuracy': 0.9057333333333333, 'first n-symbol accuracy': 0.9538331549594081, 'overlap rate': 0.9862651098071424}
#
# Current epoch: 1450,
# training performance: {'loss': 0.0016294253058731557, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1264356249361299, 'full sequence accuracy': 0.9130666666666668, 'first n-symbol accuracy': 0.9579576492679862, 'overlap rate': 0.9875533413386286}
#
# Current epoch: 1460,
# training performance: {'loss': 0.0014388327384949663, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.12370519146788865, 'full sequence accuracy': 0.9157, 'first n-symbol accuracy': 0.9599991758408295, 'overlap rate': 0.9879599936491605}
#
# Current epoch: 1470,
# training performance: {'loss': 0.0013110785672324709, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.12016087183728814, 'full sequence accuracy': 0.9182666666666666, 'first n-symbol accuracy': 0.9617170017456205, 'overlap rate': 0.9883619198564201}
#
# Current epoch: 1480,
# training performance: {'loss': 0.0012166462969616988, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1184512150939554, 'full sequence accuracy': 0.9190666666666665, 'first n-symbol accuracy': 0.962660484998161, 'overlap rate': 0.988611307822076}
#
# Current epoch: 1490,
# training performance: {'loss': 0.0011430365513660945, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.11630418559070677, 'full sequence accuracy': 0.9206000000000001, 'first n-symbol accuracy': 0.9637118347891883, 'overlap rate': 0.9888437251114416}
#
# Current epoch: 1500,
# training performance: {'loss': 0.0010835978639079258, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.11421265658573247, 'full sequence accuracy': 0.9218333333333335, 'first n-symbol accuracy': 0.9646011213096081, 'overlap rate': 0.989081005056893}
#
# experiments/total_red_sample_complexity/LSTM/attn-less/3/model.pt saved!
#
# experiments/total_red_sample_complexity/LSTM/attn-less/3/training_log.json saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/training_plot.png saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_train.json saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_test.json saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_train.png saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_test.png saved!
# experiments/total_red_sample_complexity/LSTM/attn-less/3/perfs_gen.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
