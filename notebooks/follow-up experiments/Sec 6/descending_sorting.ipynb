# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-05-30 04:54:30

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/identity")


def descending_sorting(w):
    return ''.join(sorted(w, reverse=True))

def modify_dataset(ds):    
    out = []
    for t, _ in ds:
        out.append([t, descending_sorting(t)])
    
    return out

train = modify_dataset(train)
dev = modify_dataset(dev)
test = modify_dataset(test)
gen = modify_dataset(gen)

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "descending_sorting"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 512
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,176,476 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 2.3203640937805177, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03879141622266622, 'overlap rate': 0.17777614843489845}
# evaluation performance: {'loss': 2.320924091339111, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03816179292929292, 'overlap rate': 0.17649281662781663}
#
# Current epoch: 20,
# training performance: {'loss': 2.184078335762024, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.08830017857142858, 'overlap rate': 0.1973789582639583}
# evaluation performance: {'loss': 2.1885142803192137, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.08721690046065046, 'overlap rate': 0.1956083404095904}
#
# Current epoch: 30,
# training performance: {'loss': 1.9684285163879394, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.1528119552669553, 'overlap rate': 0.3284599962537462}
# evaluation performance: {'loss': 1.9757484674453736, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.1515918908868909, 'overlap rate': 0.3278783225108225}
#
# Current epoch: 40,
# training performance: {'loss': 1.52046058177948, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.25243828574203575, 'overlap rate': 0.43834920357420354}
# evaluation performance: {'loss': 1.526032316684723, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.2487593220668221, 'overlap rate': 0.43349551406926407}
#
# Current epoch: 50,
# training performance: {'loss': 1.3053897619247437, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.3403346126096126, 'overlap rate': 0.51817066003441}
# evaluation performance: {'loss': 1.3157395005226136, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.3352961180486181, 'overlap rate': 0.5140971481296481}
#
# Current epoch: 60,
# training performance: {'loss': 1.3410319447517396, 'full sequence accuracy': 0.0006000000000000001, 'first n-symbol accuracy': 0.3948464413364413, 'overlap rate': 0.5817840051615053}
# evaluation performance: {'loss': 1.3592461228370667, 'full sequence accuracy': 0.0007, 'first n-symbol accuracy': 0.38862120726495725, 'overlap rate': 0.5770598075535576}
#
# Current epoch: 70,
# training performance: {'loss': 1.0961211800575257, 'full sequence accuracy': 0.0035000000000000005, 'first n-symbol accuracy': 0.40190567224442225, 'overlap rate': 0.6169305262792762}
# evaluation performance: {'loss': 1.104103398323059, 'full sequence accuracy': 0.0039000000000000007, 'first n-symbol accuracy': 0.3941780395992896, 'overlap rate': 0.6103649413086915}
#
# Current epoch: 80,
# training performance: {'loss': 0.7977026164531708, 'full sequence accuracy': 0.0258, 'first n-symbol accuracy': 0.5049550833888334, 'overlap rate': 0.7094244336219335}
# evaluation performance: {'loss': 0.8158658802509308, 'full sequence accuracy': 0.02, 'first n-symbol accuracy': 0.49298021547896553, 'overlap rate': 0.7012552337939838}
#
# Current epoch: 90,
# training performance: {'loss': 0.7065524160861969, 'full sequence accuracy': 0.0379, 'first n-symbol accuracy': 0.5705359992784993, 'overlap rate': 0.7457578737928738}
# evaluation performance: {'loss': 0.7249376177787781, 'full sequence accuracy': 0.0337, 'first n-symbol accuracy': 0.5581609835997337, 'overlap rate': 0.7394843718781219}
#
# Current epoch: 100,
# training performance: {'loss': 0.7963989853858948, 'full sequence accuracy': 0.0868, 'first n-symbol accuracy': 0.531961605061605, 'overlap rate': 0.7295795515595515}
# evaluation performance: {'loss': 0.8160047054290771, 'full sequence accuracy': 0.08710000000000001, 'first n-symbol accuracy': 0.523768203046953, 'overlap rate': 0.7234417077367078}
#
# Current epoch: 110,
# training performance: {'loss': 0.5270360678434372, 'full sequence accuracy': 0.123, 'first n-symbol accuracy': 0.6813111155511156, 'overlap rate': 0.8176887214174716}
# evaluation performance: {'loss': 0.5549772650003433, 'full sequence accuracy': 0.10740000000000001, 'first n-symbol accuracy': 0.6623602468364969, 'overlap rate': 0.8058905237817736}
#
# Current epoch: 120,
# training performance: {'loss': 0.4792698919773102, 'full sequence accuracy': 0.20860000000000004, 'first n-symbol accuracy': 0.6661181707181708, 'overlap rate': 0.8318961811799312}
# evaluation performance: {'loss': 0.5094681292772293, 'full sequence accuracy': 0.1868, 'first n-symbol accuracy': 0.6438554951992452, 'overlap rate': 0.8218404720279722}
#
# Current epoch: 130,
# training performance: {'loss': 0.9812336027622223, 'full sequence accuracy': 0.054000000000000006, 'first n-symbol accuracy': 0.5561131988844489, 'overlap rate': 0.7360414346764348}
# evaluation performance: {'loss': 1.0242765843868256, 'full sequence accuracy': 0.046900000000000004, 'first n-symbol accuracy': 0.5416575613275614, 'overlap rate': 0.7265098595848596}
#
# Current epoch: 140,
# training performance: {'loss': 0.1869129680097103, 'full sequence accuracy': 0.7043, 'first n-symbol accuracy': 0.8703415731490732, 'overlap rate': 0.9494409471084472}
# evaluation performance: {'loss': 0.2154617950320244, 'full sequence accuracy': 0.6553000000000001, 'first n-symbol accuracy': 0.8461161408036408, 'overlap rate': 0.9388834880397379}
#
# Current epoch: 150,
# training performance: {'loss': 0.12170798256993294, 'full sequence accuracy': 0.7510000000000001, 'first n-symbol accuracy': 0.9301197083472085, 'overlap rate': 0.9701361890886891}
# evaluation performance: {'loss': 0.1466668002307415, 'full sequence accuracy': 0.7160000000000001, 'first n-symbol accuracy': 0.9110856136918637, 'overlap rate': 0.9621673426573428}
#
# Current epoch: 160,
# training performance: {'loss': 0.13364533185958863, 'full sequence accuracy': 0.7413, 'first n-symbol accuracy': 0.9205565075202575, 'overlap rate': 0.9615602269952271}
# evaluation performance: {'loss': 0.15709947869181634, 'full sequence accuracy': 0.6983999999999999, 'first n-symbol accuracy': 0.9005069759407259, 'overlap rate': 0.9535623359973361}
#
# Current epoch: 170,
# training performance: {'loss': 0.047045782394707206, 'full sequence accuracy': 0.9519000000000002, 'first n-symbol accuracy': 0.9760806260406261, 'overlap rate': 0.9926063157675656}
# evaluation performance: {'loss': 0.06641605142503977, 'full sequence accuracy': 0.9183000000000001, 'first n-symbol accuracy': 0.9573897582972583, 'overlap rate': 0.9864726126651128}
#
# Current epoch: 180,
# training performance: {'loss': 0.04263459574431181, 'full sequence accuracy': 0.9548, 'first n-symbol accuracy': 0.9825984920634921, 'overlap rate': 0.993303306970807}
# evaluation performance: {'loss': 0.058944296464323996, 'full sequence accuracy': 0.9247, 'first n-symbol accuracy': 0.9688232353757353, 'overlap rate': 0.9881964074814075}
#
# Current epoch: 190,
# training performance: {'loss': 0.1118053786456585, 'full sequence accuracy': 0.9626999999999999, 'first n-symbol accuracy': 0.9716622150072152, 'overlap rate': 0.9804966108891108}
# evaluation performance: {'loss': 0.12784791681915522, 'full sequence accuracy': 0.9446999999999999, 'first n-symbol accuracy': 0.9611824991674991, 'overlap rate': 0.976299357864358}
#
# Current epoch: 200,
# training performance: {'loss': 0.02948536965996027, 'full sequence accuracy': 0.9593, 'first n-symbol accuracy': 0.9908691731879233, 'overlap rate': 0.9940363851426353}
# evaluation performance: {'loss': 0.04177797343581915, 'full sequence accuracy': 0.942, 'first n-symbol accuracy': 0.9846669141969142, 'overlap rate': 0.9911794333444334}
#
# Current epoch: 210,
# training performance: {'loss': 0.007358556473627686, 'full sequence accuracy': 0.9983999999999998, 'first n-symbol accuracy': 0.9989499904262406, 'overlap rate': 0.9996163877788877}
# evaluation performance: {'loss': 0.01245414731092751, 'full sequence accuracy': 0.9932000000000001, 'first n-symbol accuracy': 0.9963868269230769, 'overlap rate': 0.9987132570207571}
#
# Current epoch: 220,
# training performance: {'loss': 0.009254287276417018, 'full sequence accuracy': 0.9965999999999999, 'first n-symbol accuracy': 0.9978691017316017, 'overlap rate': 0.9989437121212121}
# evaluation performance: {'loss': 0.014158321730792522, 'full sequence accuracy': 0.9912000000000001, 'first n-symbol accuracy': 0.995560279026529, 'overlap rate': 0.998063667859918}
#
# Current epoch: 230,
# training performance: {'loss': 0.013737650332041084, 'full sequence accuracy': 0.9922000000000001, 'first n-symbol accuracy': 0.9958294004606504, 'overlap rate': 0.9978133465145966}
# evaluation performance: {'loss': 0.018367522163316607, 'full sequence accuracy': 0.9852000000000001, 'first n-symbol accuracy': 0.99251500985126, 'overlap rate': 0.9966698729048729}
#
# Current epoch: 240,
# training performance: {'loss': 0.004302342887967825, 'full sequence accuracy': 0.9994, 'first n-symbol accuracy': 0.99962625, 'overlap rate': 0.9999495833333333}
# evaluation performance: {'loss': 0.007542374287731945, 'full sequence accuracy': 0.9941000000000001, 'first n-symbol accuracy': 0.9971677930402929, 'overlap rate': 0.999340782967033}
#
# Current epoch: 250,
# training performance: {'loss': 0.003214937238954008, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.007903234916739166, 'full sequence accuracy': 0.9949999999999999, 'first n-symbol accuracy': 0.997615989010989, 'overlap rate': 0.9990507051282049}
#
# Current epoch: 260,
# training performance: {'loss': 0.0026506663067266344, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.005370515468530357, 'full sequence accuracy': 0.9969000000000001, 'first n-symbol accuracy': 0.9986700915750916, 'overlap rate': 0.9995202243589745}
#
# experiments/descending_sorting/LSTM/attn-less/3/model.pt saved!
#
# experiments/descending_sorting/LSTM/attn-less/3/training_log.json saved!
# experiments/descending_sorting/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/descending_sorting/LSTM/attn-less/3/training_plot.png saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_train.json saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_test.json saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_train.png saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_test.png saved!
# experiments/descending_sorting/LSTM/attn-less/3/perfs_gen.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
