# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-05-29 13:01:52

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/identity")


def ascending_sorting(w):
    return ''.join(sorted(w))

def modify_dataset(ds):    
    out = []
    for t, _ in ds:
        out.append([t, ascending_sorting(t)])
    
    return out

train = modify_dataset(train)
dev = modify_dataset(dev)
test = modify_dataset(test)
gen = modify_dataset(gen)

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "ascending_sorting"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 512
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,176,476 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 2.3756924867630005, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.038171611166611163, 'overlap rate': 0.17464734140859142}
# evaluation performance: {'loss': 2.3774698257446287, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03915376665001665, 'overlap rate': 0.17475437978687977}
#
# Current epoch: 20,
# training performance: {'loss': 2.2116689682006836, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0792002695915196, 'overlap rate': 0.20513547397047396}
# evaluation performance: {'loss': 2.2140053510665894, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.07998198620823622, 'overlap rate': 0.20386023643023643}
#
# Current epoch: 30,
# training performance: {'loss': 2.1147634387016296, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.17103394203019204, 'overlap rate': 0.36697363553113554}
# evaluation performance: {'loss': 2.1195664286613463, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.16957481365856367, 'overlap rate': 0.36469408993783986}
#
# Current epoch: 40,
# training performance: {'loss': 1.5179622292518615, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.260086476995227, 'overlap rate': 0.4702390785603285}
# evaluation performance: {'loss': 1.5267423510551452, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.2556515680153181, 'overlap rate': 0.46778668928293926}
#
# Current epoch: 50,
# training performance: {'loss': 1.4849897027015686, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.2592044888444888, 'overlap rate': 0.4516670546120546}
# evaluation performance: {'loss': 1.497380793094635, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.25743993173493174, 'overlap rate': 0.4485408601121102}
#
# Current epoch: 60,
# training performance: {'loss': 1.2632748484611511, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.38309264818514827, 'overlap rate': 0.5531081579531579}
# evaluation performance: {'loss': 1.2766905188560487, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.3785859043734044, 'overlap rate': 0.5496743072205572}
#
# Current epoch: 70,
# training performance: {'loss': 1.0939324975013733, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.44315721195471197, 'overlap rate': 0.6081184762459764}
# evaluation performance: {'loss': 1.1111070394515992, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.43416423396048404, 'overlap rate': 0.602630397935398}
#
# Current epoch: 80,
# training performance: {'loss': 0.9707841336727142, 'full sequence accuracy': 0.008400000000000001, 'first n-symbol accuracy': 0.46040061313686315, 'overlap rate': 0.6564040072427574}
# evaluation performance: {'loss': 0.993132084608078, 'full sequence accuracy': 0.0067, 'first n-symbol accuracy': 0.45012631576756573, 'overlap rate': 0.6473179632867133}
#
# Current epoch: 90,
# training performance: {'loss': 0.6262533605098725, 'full sequence accuracy': 0.08070000000000002, 'first n-symbol accuracy': 0.5932181898656899, 'overlap rate': 0.7791159432234431}
# evaluation performance: {'loss': 0.6457834839820862, 'full sequence accuracy': 0.07880000000000001, 'first n-symbol accuracy': 0.5804585266122767, 'overlap rate': 0.771102688006438}
#
# Current epoch: 100,
# training performance: {'loss': 0.5179120987653733, 'full sequence accuracy': 0.09030000000000002, 'first n-symbol accuracy': 0.6108276887001887, 'overlap rate': 0.809952616133866}
# evaluation performance: {'loss': 0.5425816684961319, 'full sequence accuracy': 0.07720000000000002, 'first n-symbol accuracy': 0.595559078837829, 'overlap rate': 0.7998843034743036}
#
# Current epoch: 110,
# training performance: {'loss': 0.465314981341362, 'full sequence accuracy': 0.24579999999999996, 'first n-symbol accuracy': 0.6766318997668999, 'overlap rate': 0.8431483835608837}
# evaluation performance: {'loss': 0.4871931433677673, 'full sequence accuracy': 0.22719999999999999, 'first n-symbol accuracy': 0.6582451512376514, 'overlap rate': 0.8340423242035742}
#
# Current epoch: 120,
# training performance: {'loss': 0.29966867417097093, 'full sequence accuracy': 0.5005999999999999, 'first n-symbol accuracy': 0.8170366106116106, 'overlap rate': 0.9094666822066824}
# evaluation performance: {'loss': 0.32255744338035586, 'full sequence accuracy': 0.4666, 'first n-symbol accuracy': 0.7948982106782106, 'overlap rate': 0.8992747534410034}
#
# Current epoch: 130,
# training performance: {'loss': 0.3827886372804642, 'full sequence accuracy': 0.5731, 'first n-symbol accuracy': 0.8004062322399822, 'overlap rate': 0.8963728701853702}
# evaluation performance: {'loss': 0.41766502633690833, 'full sequence accuracy': 0.5364000000000002, 'first n-symbol accuracy': 0.7761327892940394, 'overlap rate': 0.8849562054612055}
#
# Current epoch: 140,
# training performance: {'loss': 0.1216536968946457, 'full sequence accuracy': 0.7981, 'first n-symbol accuracy': 0.9210981297868799, 'overlap rate': 0.9697079220779221}
# evaluation performance: {'loss': 0.1454106315970421, 'full sequence accuracy': 0.7445999999999999, 'first n-symbol accuracy': 0.8977126760739262, 'overlap rate': 0.9599614097014099}
#
# Current epoch: 150,
# training performance: {'loss': 0.3278784915804863, 'full sequence accuracy': 0.5406, 'first n-symbol accuracy': 0.8285816744366745, 'overlap rate': 0.9059517966755468}
# evaluation performance: {'loss': 0.36647433787584305, 'full sequence accuracy': 0.5081, 'first n-symbol accuracy': 0.8077894097569098, 'overlap rate': 0.8952947091797092}
#
# Current epoch: 160,
# training performance: {'loss': 0.5571276128292084, 'full sequence accuracy': 0.6537, 'first n-symbol accuracy': 0.7919710016372516, 'overlap rate': 0.8779780823343323}
# evaluation performance: {'loss': 0.5820358216762542, 'full sequence accuracy': 0.6074999999999999, 'first n-symbol accuracy': 0.7685200771450771, 'overlap rate': 0.8701248472360973}
#
# Current epoch: 170,
# training performance: {'loss': 0.07090454176068306, 'full sequence accuracy': 0.8594000000000002, 'first n-symbol accuracy': 0.9558755772005773, 'overlap rate': 0.9809014291264291}
# evaluation performance: {'loss': 0.09166540950536728, 'full sequence accuracy': 0.8209000000000002, 'first n-symbol accuracy': 0.9375845249195249, 'overlap rate': 0.9741768500943501}
#
# Current epoch: 180,
# training performance: {'loss': 0.02147807804867625, 'full sequence accuracy': 0.9887, 'first n-symbol accuracy': 0.9954617764180265, 'overlap rate': 0.9983193434343434}
# evaluation performance: {'loss': 0.03428602032363415, 'full sequence accuracy': 0.9632, 'first n-symbol accuracy': 0.9836870512820513, 'overlap rate': 0.994434088966589}
#
# Current epoch: 190,
# training performance: {'loss': 0.02292579934000969, 'full sequence accuracy': 0.9759, 'first n-symbol accuracy': 0.9903558251470752, 'overlap rate': 0.9960191473803974}
# evaluation performance: {'loss': 0.03442005757242441, 'full sequence accuracy': 0.9530000000000001, 'first n-symbol accuracy': 0.9802671636696637, 'overlap rate': 0.9922573093573094}
#
# Current epoch: 200,
# training performance: {'loss': 0.07214455865323544, 'full sequence accuracy': 0.9307000000000001, 'first n-symbol accuracy': 0.966860865939616, 'overlap rate': 0.9813036405261405}
# evaluation performance: {'loss': 0.09140537679195404, 'full sequence accuracy': 0.9117, 'first n-symbol accuracy': 0.9561741622266624, 'overlap rate': 0.9770373244810745}
#
# Current epoch: 210,
# training performance: {'loss': 0.006348282052204013, 'full sequence accuracy': 0.9997, 'first n-symbol accuracy': 0.9998869047619049, 'overlap rate': 0.9999559523809524}
# evaluation performance: {'loss': 0.011386013869196177, 'full sequence accuracy': 0.9937000000000001, 'first n-symbol accuracy': 0.9966602827727827, 'overlap rate': 0.998889024864025}
#
# Current epoch: 220,
# training performance: {'loss': 0.004989964584819972, 'full sequence accuracy': 0.9994999999999999, 'first n-symbol accuracy': 0.9996358391608393, 'overlap rate': 0.9999170766733266}
# evaluation performance: {'loss': 0.007982890121638775, 'full sequence accuracy': 0.9953, 'first n-symbol accuracy': 0.9975029932567432, 'overlap rate': 0.9993660223110222}
#
# Current epoch: 230,
# training performance: {'loss': 0.006455610226839781, 'full sequence accuracy': 0.9984999999999999, 'first n-symbol accuracy': 0.9991066233766233, 'overlap rate': 0.9995091504329003}
# evaluation performance: {'loss': 0.009912147279828787, 'full sequence accuracy': 0.9931000000000001, 'first n-symbol accuracy': 0.9966291283716284, 'overlap rate': 0.9987919813519814}
#
# Current epoch: 240,
# training performance: {'loss': 0.007742112944833934, 'full sequence accuracy': 0.9965000000000002, 'first n-symbol accuracy': 0.9978908333333333, 'overlap rate': 0.9990049496336997}
# evaluation performance: {'loss': 0.012215812201611697, 'full sequence accuracy': 0.9911999999999999, 'first n-symbol accuracy': 0.9949219046231548, 'overlap rate': 0.9980190836940837}
#
# Current epoch: 250,
# training performance: {'loss': 0.006053830916061998, 'full sequence accuracy': 0.9981, 'first n-symbol accuracy': 0.9988555906593408, 'overlap rate': 0.999293173076923}
# evaluation performance: {'loss': 0.010610545496456325, 'full sequence accuracy': 0.9929, 'first n-symbol accuracy': 0.995946380980131, 'overlap rate': 0.9983700668775668}
#
# Current epoch: 260,
# training performance: {'loss': 0.0028604029677808283, 'full sequence accuracy': 0.9997, 'first n-symbol accuracy': 0.9998275000000001, 'overlap rate': 0.9999454166666666}
# evaluation performance: {'loss': 0.005984738399274647, 'full sequence accuracy': 0.9943000000000002, 'first n-symbol accuracy': 0.9970315924353423, 'overlap rate': 0.9992267703130204}
#
# Current epoch: 270,
# training performance: {'loss': 0.010251467092894017, 'full sequence accuracy': 0.9967, 'first n-symbol accuracy': 0.9978492715617715, 'overlap rate': 0.9986222335997337}
# evaluation performance: {'loss': 0.016517594503238798, 'full sequence accuracy': 0.9922999999999998, 'first n-symbol accuracy': 0.9952355004717506, 'overlap rate': 0.9976087110112111}
#
# Current epoch: 280,
# training performance: {'loss': 0.002069862512871623, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.0045845008222386244, 'full sequence accuracy': 0.9970999999999999, 'first n-symbol accuracy': 0.998462524975025, 'overlap rate': 0.9995087162837164}
#
# experiments/ascending_sorting/LSTM/attn-less/3/model.pt saved!
#
# experiments/ascending_sorting/LSTM/attn-less/3/training_log.json saved!
# experiments/ascending_sorting/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/ascending_sorting/LSTM/attn-less/3/training_plot.png saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_train.json saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_test.json saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_train.png saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_test.png saved!
# experiments/ascending_sorting/LSTM/attn-less/3/perfs_gen.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
