# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-06-06 05:37:55

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/identity")


def quadratic_copying(w):
    return w * len(w)

def modify_dataset(ds):

    out = []
    for t, _ in ds:
        out.append([t, quadratic_copying(t)])

    return out

train = modify_dataset(train)
dev = modify_dataset(dev)
test = modify_dataset(test)
gen = modify_dataset(gen)

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder,
                                            out_seq_encoder,
                                            padding_idx=1,
                                            batch_size=1000,
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "quadratic_copying_attn_srnn_model_complexity"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss",
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN"]:
    for use_attn in [False]:
        for run_num in range(1, 4):

            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")

            embd_dim = 384
            hidden_size = 1024
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500

            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols
                           "reduction_method": "sum"}

            model = get_model(ModelConfig)

            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)

            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl,
                                     criterion, optimizer,
                                     saved_model_fp=saved_model_fp,
                                     acc_threshold=-0.1,
                                     print_eval_freq=10,
                                     max_epoch_num=max_epoch_num,
                                     train_exit_acc=0.9999,
                                     eval_exit_acc=0.995,
                                     teacher_forcing_ratio=1.0)

            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))

            train_res, dev_res = get_results(log, train_log=True)

            _, perfs_train = evaluate(model, train_dl, criterion,
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion,
                                      per_seq_len_performance=True)

            test_aggr, perfs_test = evaluate(model, test_dl, criterion,
                                             per_seq_len_performance=True)

            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion,
                                             per_seq_len_performance=True)

            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)

            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)


            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))

            clear_output(wait=True)

        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata_attn_less.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results_attn_less.csv"), index=False)
# Out:
# RNN type: SRNN; use attention: False; run num: 3
#
# The model has 5,037,084 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.802169442176819, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00018800396611323185, 'overlap rate': 0.03771098554402692}
# evaluation performance: {'loss': 3.8039908409118652, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00018161655100330505, 'overlap rate': 0.03818332200867703}
#
# Current epoch: 20,
# training performance: {'loss': 3.9925668954849245, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005046239723795919, 'overlap rate': 0.03847573333742115}
# evaluation performance: {'loss': 3.9928860425949098, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00047952291554224257, 'overlap rate': 0.03812165017594735}
#
# Current epoch: 30,
# training performance: {'loss': 4.419850397109985, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005046239723795919, 'overlap rate': 0.03829547146882483}
# evaluation performance: {'loss': 4.422591209411621, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00047952291554224257, 'overlap rate': 0.03812028442252507}
#
# Current epoch: 40,
# training performance: {'loss': 4.63165397644043, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005002319636701069, 'overlap rate': 0.038114599821965314}
# evaluation performance: {'loss': 4.631825923919678, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004778328483355158, 'overlap rate': 0.03796604411032729}
#
# Current epoch: 50,
# training performance: {'loss': 5.314042568206787, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005015272432757935, 'overlap rate': 0.03812118917159808}
# evaluation performance: {'loss': 5.317469644546509, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004868098223303464, 'overlap rate': 0.03789774363322648}
#
# Current epoch: 60,
# training performance: {'loss': 5.559540414810181, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005185515412903602, 'overlap rate': 0.038092281575180895}
# evaluation performance: {'loss': 5.560160732269287, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00044107732606887655, 'overlap rate': 0.03790025460763171}
#
# Current epoch: 70,
# training performance: {'loss': 5.499913311004638, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005002319636701069, 'overlap rate': 0.03806156121657799}
# evaluation performance: {'loss': 5.499529266357422, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004778328483355158, 'overlap rate': 0.03804582275966064}
#
# Current epoch: 80,
# training performance: {'loss': 5.635947370529175, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005061186466159087, 'overlap rate': 0.03877144217010557}
# evaluation performance: {'loss': 5.629303121566773, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00047790724731565804, 'overlap rate': 0.03817843862208058}
#
# Current epoch: 90,
# training performance: {'loss': 5.865901231765747, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004983329472155149, 'overlap rate': 0.038069609414554686}
# evaluation performance: {'loss': 5.8643899917602536, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000446849230479211, 'overlap rate': 0.03775225930685737}
#
# Current epoch: 100,
# training performance: {'loss': 6.321938514709473, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004907259927380737, 'overlap rate': 0.038131857538527485}
# evaluation performance: {'loss': 6.3228644847869875, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004877561038590944, 'overlap rate': 0.038179156720809904}
#
# Current epoch: 110,
# training performance: {'loss': 6.595822954177857, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000499488012049255, 'overlap rate': 0.0384854286972363}
# evaluation performance: {'loss': 6.592405080795288, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004928337534651597, 'overlap rate': 0.03778679952382489}
#
# Current epoch: 120,
# training performance: {'loss': 6.539845943450928, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005034566721701997, 'overlap rate': 0.037942596085786484}
# evaluation performance: {'loss': 6.540273761749267, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004394369982524955, 'overlap rate': 0.03756422267275666}
#
# Current epoch: 130,
# training performance: {'loss': 6.822772645950318, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005015272432757935, 'overlap rate': 0.037830160184700284}
# evaluation performance: {'loss': 6.824083137512207, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004868098223303464, 'overlap rate': 0.03794720268632138}
#
# Current epoch: 140,
# training performance: {'loss': 6.944584655761719, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005038017515349212, 'overlap rate': 0.03865195229123922}
# evaluation performance: {'loss': 6.942255735397339, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00048160518199123075, 'overlap rate': 0.03842052770053913}
#
# Current epoch: 150,
# training performance: {'loss': 7.119701766967774, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005051285476060077, 'overlap rate': 0.038490767028965034}
# evaluation performance: {'loss': 7.114832162857056, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000480606234742774, 'overlap rate': 0.03799598705859501}
#
# Current epoch: 160,
# training performance: {'loss': 7.108786249160767, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00046539866038021373, 'overlap rate': 0.03728247968124241}
# evaluation performance: {'loss': 7.104215860366821, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0003965229724597139, 'overlap rate': 0.03753440833853107}
#
# Current epoch: 170,
# training performance: {'loss': 7.554381704330444, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004757399986003957, 'overlap rate': 0.03750754784296163}
# evaluation performance: {'loss': 7.558664464950562, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004685787559910486, 'overlap rate': 0.03816051965986977}
#
# Current epoch: 180,
# training performance: {'loss': 7.701210355758667, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005008327686784094, 'overlap rate': 0.038154421442346875}
# evaluation performance: {'loss': 7.702673292160034, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004520402268964428, 'overlap rate': 0.037910877060397905}
#
# Current epoch: 190,
# training performance: {'loss': 7.7261643409729, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005024224479646922, 'overlap rate': 0.03753723234063576}
# evaluation performance: {'loss': 7.724468946456909, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004411496019452972, 'overlap rate': 0.03798671717756257}
#
# Current epoch: 200,
# training performance: {'loss': 7.891178894042969, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004757399986003957, 'overlap rate': 0.03829525679149511}
# evaluation performance: {'loss': 7.902337694168091, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004685787559910486, 'overlap rate': 0.03820821432872192}
#
# Current epoch: 210,
# training performance: {'loss': 7.762076473236084, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000501638489970191, 'overlap rate': 0.038182883252984176}
# evaluation performance: {'loss': 7.75924768447876, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00047561064960869204, 'overlap rate': 0.038180764355609485}
#
# Current epoch: 220,
# training performance: {'loss': 7.867762899398803, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005163096896465778, 'overlap rate': 0.03823607930246535}
# evaluation performance: {'loss': 7.8694673538208, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00047734635877314256, 'overlap rate': 0.03807254392034937}
#
# Current epoch: 230,
# training performance: {'loss': 8.033513355255128, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004803636233050884, 'overlap rate': 0.03794077043079514}
# evaluation performance: {'loss': 8.034729051589967, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00041609294601730183, 'overlap rate': 0.03835733034057275}
#
# Current epoch: 240,
# training performance: {'loss': 8.389984560012817, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00043852379508383397, 'overlap rate': 0.037877111739519506}
# evaluation performance: {'loss': 8.396312475204468, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00047143920855115886, 'overlap rate': 0.03745080702730925}
#
# Current epoch: 250,
# training performance: {'loss': 8.398654556274414, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004825270570123894, 'overlap rate': 0.03869482604557149}
# evaluation performance: {'loss': 8.40598793029785, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00048265679577178097, 'overlap rate': 0.038540420811760595}
#
# Current epoch: 260,
# training performance: {'loss': 8.42678804397583, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005150679106156758, 'overlap rate': 0.03879836989314928}
# evaluation performance: {'loss': 8.439118099212646, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004478377697342364, 'overlap rate': 0.03802251698627121}
#
# Current epoch: 270,
# training performance: {'loss': 8.698419427871704, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005052298987756515, 'overlap rate': 0.03802766110396233}
# evaluation performance: {'loss': 8.70092706680298, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00044329775158155946, 'overlap rate': 0.037799568353567944}
#
# Current epoch: 280,
# training performance: {'loss': 8.349067640304565, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005243809122526981, 'overlap rate': 0.03819972340803065}
# evaluation performance: {'loss': 8.355925798416138, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004767719035093638, 'overlap rate': 0.03781367136904039}
#
# Current epoch: 290,
# training performance: {'loss': 8.80465588569641, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005112260695632562, 'overlap rate': 0.037966492872960264}
# evaluation performance: {'loss': 8.805826950073243, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00048102329348015296, 'overlap rate': 0.03798769184644603}
#
# Current epoch: 300,
# training performance: {'loss': 8.888490629196166, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000516950941187231, 'overlap rate': 0.039908148064067006}
# evaluation performance: {'loss': 8.894612216949463, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004471481145618226, 'overlap rate': 0.03915843888620997}
#
# Current epoch: 310,
# training performance: {'loss': 9.462501192092896, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000442277091369225, 'overlap rate': 0.03836805929798888}
# evaluation performance: {'loss': 9.469383382797242, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004993139489698623, 'overlap rate': 0.03844802666657351}
#
# Current epoch: 320,
# training performance: {'loss': 8.857350492477417, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00048402853585637485, 'overlap rate': 0.037891507467939005}
# evaluation performance: {'loss': 8.852431392669677, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00046889147729634967, 'overlap rate': 0.038222828727081666}
#
# Current epoch: 330,
# training performance: {'loss': 8.754175615310668, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000511023991587432, 'overlap rate': 0.03830644247945398}
# evaluation performance: {'loss': 8.76455454826355, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004877434630360431, 'overlap rate': 0.037722685821802195}
#
# Current epoch: 340,
# training performance: {'loss': 8.922954177856445, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005048520058007093, 'overlap rate': 0.03769876036919753}
# evaluation performance: {'loss': 8.923637199401856, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004845719885454951, 'overlap rate': 0.03754450718410486}
#
# Current epoch: 350,
# training performance: {'loss': 9.261699342727661, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005038619067908083, 'overlap rate': 0.03853825447400182}
# evaluation performance: {'loss': 9.279567384719849, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00048657198854549507, 'overlap rate': 0.03772839753309088}
#
# Current epoch: 360,
# training performance: {'loss': 9.332297945022583, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000507072223706709, 'overlap rate': 0.037579020669015785}
# evaluation performance: {'loss': 9.342925786972046, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004845719885454951, 'overlap rate': 0.037026342239093936}
#
# Current epoch: 370,
# training performance: {'loss': 9.36247501373291, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000500951385484975, 'overlap rate': 0.038197633801563186}
# evaluation performance: {'loss': 9.349056291580201, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00048070928840238965, 'overlap rate': 0.03819144893291114}
#
# Current epoch: 380,
# training performance: {'loss': 9.586275196075439, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00043793664668948136, 'overlap rate': 0.03835590979515263}
# evaluation performance: {'loss': 9.595016193389892, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004662994353159354, 'overlap rate': 0.03810106994272032}
#
# Current epoch: 390,
# training performance: {'loss': 9.312709045410156, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00043179234771199273, 'overlap rate': 0.03723128929075663}
# evaluation performance: {'loss': 9.313589286804199, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004558742046799039, 'overlap rate': 0.03785752250618769}
#
# Current epoch: 400,
# training performance: {'loss': 9.20334596633911, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004851951984960796, 'overlap rate': 0.03594337554522929}
# evaluation performance: {'loss': 9.206646060943603, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00045584446652052773, 'overlap rate': 0.035885204370615764}
#
# Current epoch: 410,
# training performance: {'loss': 9.519348001480102, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00046903727808341865, 'overlap rate': 0.037651598813813}
# evaluation performance: {'loss': 9.509938812255859, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004521208352219726, 'overlap rate': 0.03769419323313356}
#
# Current epoch: 420,
# training performance: {'loss': 9.8585834980011, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00045740825856527983, 'overlap rate': 0.03808979393600877}
# evaluation performance: {'loss': 9.871323394775391, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00048157732726762843, 'overlap rate': 0.037854908530704535}
#
# Current epoch: 430,
# training performance: {'loss': 9.871966123580933, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004572746971918524, 'overlap rate': 0.03892855350997447}
# evaluation performance: {'loss': 9.867236185073853, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004831038329683265, 'overlap rate': 0.039202752064978384}
#
# Current epoch: 440,
# training performance: {'loss': 10.109081554412843, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005253710112625991, 'overlap rate': 0.038266600779988155}
# evaluation performance: {'loss': 10.108231830596925, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004779914157044858, 'overlap rate': 0.03827621195555497}
#
# Current epoch: 450,
# training performance: {'loss': 10.101021862030029, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004963254402544851, 'overlap rate': 0.03794527268573818}
# evaluation performance: {'loss': 10.104536294937134, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004916264080978167, 'overlap rate': 0.03783491993702584}
#
# Current epoch: 460,
# training performance: {'loss': 9.70918607711792, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005157706133183785, 'overlap rate': 0.04002952922769405}
# evaluation performance: {'loss': 9.705990266799926, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004481382135717236, 'overlap rate': 0.04038271770924097}
#
# Current epoch: 470,
# training performance: {'loss': 10.363823461532593, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000516950941187231, 'overlap rate': 0.03800295517688958}
# evaluation performance: {'loss': 10.358109474182129, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004471481145618226, 'overlap rate': 0.03811633495017101}
#
# Current epoch: 480,
# training performance: {'loss': 10.212547779083252, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004833388806839611, 'overlap rate': 0.03742685623386993}
# evaluation performance: {'loss': 10.21449065208435, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00046889147729634967, 'overlap rate': 0.037368598906283496}
#
# Current epoch: 490,
# training performance: {'loss': 10.077935695648193, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004506469529001099, 'overlap rate': 0.038424943446898785}
# evaluation performance: {'loss': 10.079752922058105, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004734451637661314, 'overlap rate': 0.03801209207421375}
#
# Current epoch: 500,
# training performance: {'loss': 9.831371593475343, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004546469529001099, 'overlap rate': 0.03790305741575957}
# evaluation performance: {'loss': 9.84302225112915, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0004724144505959077, 'overlap rate': 0.03758695193114559}
#
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/model.pt saved!
#
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/training_log.json saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/ModelConfig.json saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/training_plot.png saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_train.json saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_dev.json saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_test.json saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_gen.json saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_train.png saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_dev.png saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_test.png saved!
# experiments/quadratic_copying_attn_srnn_model_complexity/SRNN/attn-less/3/perfs_gen.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
