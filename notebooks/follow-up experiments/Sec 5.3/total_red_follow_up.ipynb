# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-06-03 05:03:25

# %% [markdown]
# ## Data loading and processing

# %%
task = "total_red"
train, dev, test, gen = read_datasets(f"data/{task}")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = f"{task}_follow_up"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for hs in [64, 32, 16]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; Hidden size: {hs}; run num: {run_num}\n")
            
            use_attn = True
            embd_dim = 128
            hidden_size = hs
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            folder = join(task_folder, rnn_type, f"HiddenSize-{hs}", str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; Hidden size: 16; run num: 3
#
# The model has 27,900 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.249279284477234, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0027516671974562603, 'overlap rate': 0.0761028808167116}
# evaluation performance: {'loss': 3.249764633178711, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.002814671431953209, 'overlap rate': 0.07562721610151849}
#
# Current epoch: 20,
# training performance: {'loss': 3.1768800020217896, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0039442398218478185, 'overlap rate': 0.09365186915793192}
# evaluation performance: {'loss': 3.1784659385681153, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.003737185129411621, 'overlap rate': 0.0934900934346464}
#
# Current epoch: 30,
# training performance: {'loss': 3.171317791938782, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.004165742797004248, 'overlap rate': 0.09300510762912466}
# evaluation performance: {'loss': 3.171145033836365, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.004114886930899891, 'overlap rate': 0.09389727914103851}
#
# Current epoch: 40,
# training performance: {'loss': 3.171937131881714, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.004991826163810808, 'overlap rate': 0.09224559940231486}
# evaluation performance: {'loss': 3.1731858968734743, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.004691479835728789, 'overlap rate': 0.09381687380257908}
#
# Current epoch: 50,
# training performance: {'loss': 3.1697608709335325, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005380906911230368, 'overlap rate': 0.09240713513184402}
# evaluation performance: {'loss': 3.1702802419662475, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005114609637660708, 'overlap rate': 0.09373684730063117}
#
# Current epoch: 60,
# training performance: {'loss': 3.177999711036682, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005986851976659047, 'overlap rate': 0.09356025040574498}
# evaluation performance: {'loss': 3.1782853841781615, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005852402221581468, 'overlap rate': 0.0945825914421741}
#
# Current epoch: 70,
# training performance: {'loss': 3.1761461973190306, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.006724616270547846, 'overlap rate': 0.09591923984644936}
# evaluation performance: {'loss': 3.1764100790023804, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0064516397826534485, 'overlap rate': 0.09620778269536115}
#
# Current epoch: 80,
# training performance: {'loss': 3.1871731996536257, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.008040726955009195, 'overlap rate': 0.09753989337607906}
# evaluation performance: {'loss': 3.185429811477661, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.007424135292488879, 'overlap rate': 0.09711133911170908}
#
# Current epoch: 90,
# training performance: {'loss': 3.1875682830810548, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.008448611323427797, 'overlap rate': 0.09863128515916253}
# evaluation performance: {'loss': 3.189983916282654, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.008027946764985345, 'overlap rate': 0.09765583103397955}
#
# Current epoch: 100,
# training performance: {'loss': 3.195372295379639, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.009955155445083342, 'overlap rate': 0.09957708300051954}
# evaluation performance: {'loss': 3.197550916671753, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.009377409597155158, 'overlap rate': 0.09826882323983491}
#
# Current epoch: 110,
# training performance: {'loss': 3.1960782289505003, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.010652581779993193, 'overlap rate': 0.1001628382604353}
# evaluation performance: {'loss': 3.1961525678634644, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.010094398436117057, 'overlap rate': 0.10108058503921849}
#
# Current epoch: 120,
# training performance: {'loss': 3.197150135040283, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.011747196194613684, 'overlap rate': 0.10181769771766355}
# evaluation performance: {'loss': 3.201041555404663, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.010724306988782309, 'overlap rate': 0.10084325289751894}
#
# Current epoch: 130,
# training performance: {'loss': 3.202468180656433, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0129660484774406, 'overlap rate': 0.10263439918140485}
# evaluation performance: {'loss': 3.2046682834625244, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.011881046654307247, 'overlap rate': 0.10093268663660024}
#
# Current epoch: 140,
# training performance: {'loss': 3.205287051200867, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.014042587128791062, 'overlap rate': 0.1042571135852998}
# evaluation performance: {'loss': 3.208038806915283, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.013090848050131304, 'overlap rate': 0.10282472230573989}
#
# Current epoch: 150,
# training performance: {'loss': 3.2114672899246215, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.015144995169003514, 'overlap rate': 0.10466847005339641}
# evaluation performance: {'loss': 3.210326886177063, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01421694420179788, 'overlap rate': 0.10403713399708522}
#
# Current epoch: 160,
# training performance: {'loss': 3.212331676483154, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01598473434109479, 'overlap rate': 0.10609178776956958}
# evaluation performance: {'loss': 3.21694438457489, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.015255869221973853, 'overlap rate': 0.10506800040191}
#
# Current epoch: 170,
# training performance: {'loss': 3.2175663709640503, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.016996829233557324, 'overlap rate': 0.10747427686936131}
# evaluation performance: {'loss': 3.21536180973053, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.016137357901876648, 'overlap rate': 0.10791153425894262}
#
# Current epoch: 180,
# training performance: {'loss': 3.220812273025513, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.017787426515988795, 'overlap rate': 0.10758925581134918}
# evaluation performance: {'loss': 3.222549629211426, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01712374568806208, 'overlap rate': 0.10643714268336249}
#
# Current epoch: 190,
# training performance: {'loss': 3.2206746339797974, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.018387716144391268, 'overlap rate': 0.10878330399283284}
# evaluation performance: {'loss': 3.227937436103821, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.017785402181371885, 'overlap rate': 0.10698797097103341}
#
# Current epoch: 200,
# training performance: {'loss': 3.224621605873108, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.020071089633642153, 'overlap rate': 0.11093565011822708}
# evaluation performance: {'loss': 3.2283806562423707, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.019579684032680372, 'overlap rate': 0.11002485732657093}
#
# Current epoch: 210,
# training performance: {'loss': 3.241789150238037, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.021612961920051993, 'overlap rate': 0.11243789665352344}
# evaluation performance: {'loss': 3.243520474433899, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.021332366737856434, 'overlap rate': 0.11090642551047232}
#
# Current epoch: 220,
# training performance: {'loss': 3.2376190423965454, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.02173590129937851, 'overlap rate': 0.11351805401081419}
# evaluation performance: {'loss': 3.243262767791748, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.021501394510702508, 'overlap rate': 0.11036054911467867}
#
# Current epoch: 230,
# training performance: {'loss': 3.2423290491104124, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.023844085317046147, 'overlap rate': 0.11593037465921152}
# evaluation performance: {'loss': 3.2467920780181885, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.023313841470420267, 'overlap rate': 0.11356069241030979}
#
# Current epoch: 240,
# training performance: {'loss': 3.2491061449050904, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.02374032943226591, 'overlap rate': 0.11548419685041529}
# evaluation performance: {'loss': 3.2530730962753296, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.02353292871331652, 'overlap rate': 0.1134474718290274}
#
# Current epoch: 250,
# training performance: {'loss': 3.248399019241333, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.025695766545568745, 'overlap rate': 0.11525604386880421}
# evaluation performance: {'loss': 3.2535287141799927, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.025454592964270707, 'overlap rate': 0.11334697035334047}
#
# Current epoch: 260,
# training performance: {'loss': 3.256280303001404, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.026260353512172607, 'overlap rate': 0.11688385431262723}
# evaluation performance: {'loss': 3.2585289239883424, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.025776652489922346, 'overlap rate': 0.11544046958055429}
#
# Current epoch: 270,
# training performance: {'loss': 3.253135418891907, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.02738648442372645, 'overlap rate': 0.11906894171675195}
# evaluation performance: {'loss': 3.254128360748291, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.027034851923670212, 'overlap rate': 0.11689485688240502}
#
# Current epoch: 280,
# training performance: {'loss': 3.2569096088409424, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.029131866873039362, 'overlap rate': 0.1199176087675639}
# evaluation performance: {'loss': 3.2585866928100584, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.028382593974257693, 'overlap rate': 0.11777345673571393}
#
# Current epoch: 290,
# training performance: {'loss': 3.2686681509017945, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.030932146364789147, 'overlap rate': 0.12210382487104168}
# evaluation performance: {'loss': 3.2687161207199096, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03018558456563077, 'overlap rate': 0.12129286421335947}
#
# Current epoch: 300,
# training performance: {'loss': 3.262652373313904, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.031215074095803746, 'overlap rate': 0.12293653703243601}
# evaluation performance: {'loss': 3.268124318122864, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03069863705524874, 'overlap rate': 0.12112757359549028}
#
# Current epoch: 310,
# training performance: {'loss': 3.267538332939148, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.03370549632810786, 'overlap rate': 0.12449052857844464}
# evaluation performance: {'loss': 3.2766116142272947, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03180979233152201, 'overlap rate': 0.12300102503088814}
#
# Current epoch: 320,
# training performance: {'loss': 3.2754865169525145, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.03561357221489333, 'overlap rate': 0.12790606283534942}
# evaluation performance: {'loss': 3.279163289070129, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03468796158763755, 'overlap rate': 0.1256469109066308}
#
# Current epoch: 330,
# training performance: {'loss': 3.2814579725265505, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.036864210320090296, 'overlap rate': 0.1299480157965379}
# evaluation performance: {'loss': 3.2874989032745363, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03564657332357153, 'overlap rate': 0.12833181880737415}
#
# Current epoch: 340,
# training performance: {'loss': 3.2953092575073244, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03866514888902124, 'overlap rate': 0.13201747798215452}
# evaluation performance: {'loss': 3.3017896175384522, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03694608015687395, 'overlap rate': 0.1294016815077362}
#
# Current epoch: 350,
# training performance: {'loss': 3.302201437950134, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.04050044986075872, 'overlap rate': 0.1330036083410339}
# evaluation performance: {'loss': 3.306278204917908, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03871041568520621, 'overlap rate': 0.1323422511195004}
#
# Current epoch: 360,
# training performance: {'loss': 3.3120045185089113, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.043089862980483784, 'overlap rate': 0.13575758004544916}
# evaluation performance: {'loss': 3.3141504764556884, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.04169378971689622, 'overlap rate': 0.13569341139368968}
#
# Current epoch: 370,
# training performance: {'loss': 3.3051409482955934, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.04495203097607885, 'overlap rate': 0.13853390609816552}
# evaluation performance: {'loss': 3.315743589401245, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.043056643222360656, 'overlap rate': 0.1362962863568073}
#
# Current epoch: 380,
# training performance: {'loss': 3.317854380607605, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.04775525535007124, 'overlap rate': 0.14245324282562716}
# evaluation performance: {'loss': 3.3348193883895876, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.04549975365427401, 'overlap rate': 0.1384405897064603}
#
# Current epoch: 390,
# training performance: {'loss': 3.3070669174194336, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.04858417738214725, 'overlap rate': 0.14200895439166925}
# evaluation performance: {'loss': 3.3128817319869994, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.04652640334552017, 'overlap rate': 0.13985560883803466}
#
# Current epoch: 400,
# training performance: {'loss': 3.313163089752197, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.04742272995657768, 'overlap rate': 0.1398632096282698}
# evaluation performance: {'loss': 3.321114683151245, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.045942450856454334, 'overlap rate': 0.13698434062509351}
#
# Current epoch: 410,
# training performance: {'loss': 3.314868855476379, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.04924784654481066, 'overlap rate': 0.14234846502234594}
# evaluation performance: {'loss': 3.3223364114761353, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.047732603596019815, 'overlap rate': 0.14053871307049423}
#
# Current epoch: 420,
# training performance: {'loss': 3.3030531883239744, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.053776327635897604, 'overlap rate': 0.14859300809042666}
# evaluation performance: {'loss': 3.316478204727173, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.051701163253632776, 'overlap rate': 0.1459805218382884}
#
# Current epoch: 430,
# training performance: {'loss': 3.3098137855529783, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.052300609410186674, 'overlap rate': 0.14668298423451068}
# evaluation performance: {'loss': 3.3177683115005494, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.05086015986663871, 'overlap rate': 0.14324768085548636}
#
# Current epoch: 440,
# training performance: {'loss': 3.3027780771255495, 'full sequence accuracy': 0.0005, 'first n-symbol accuracy': 0.056488549069952355, 'overlap rate': 0.15269814538754625}
# evaluation performance: {'loss': 3.315492105484009, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.054927915100303704, 'overlap rate': 0.15025733563762855}
#
# Current epoch: 450,
# training performance: {'loss': 3.298759436607361, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.05726731933123254, 'overlap rate': 0.15125770218647563}
# evaluation performance: {'loss': 3.309827995300293, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.05558771692534427, 'overlap rate': 0.14698879765676914}
#
# Current epoch: 460,
# training performance: {'loss': 3.29862699508667, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.05971440539265523, 'overlap rate': 0.15659234439451167}
# evaluation performance: {'loss': 3.3090407371521, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.057442118339783875, 'overlap rate': 0.1536574974998312}
#
# Current epoch: 470,
# training performance: {'loss': 3.308182954788208, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.058454367590611886, 'overlap rate': 0.15599420637910882}
# evaluation performance: {'loss': 3.3188848733901977, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.05615616741885128, 'overlap rate': 0.15242244292542032}
#
# Current epoch: 480,
# training performance: {'loss': 3.2915784120559692, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.06256363232223407, 'overlap rate': 0.1596794249229438}
# evaluation performance: {'loss': 3.2999966621398924, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.06002467348945215, 'overlap rate': 0.15528482001506502}
#
# Current epoch: 490,
# training performance: {'loss': 3.301789402961731, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.06317210623225161, 'overlap rate': 0.16068778822543883}
# evaluation performance: {'loss': 3.309195899963379, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.06119542588713921, 'overlap rate': 0.1585193743838827}
#
# Current epoch: 500,
# training performance: {'loss': 3.2887858867645265, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.06562208677733719, 'overlap rate': 0.16384945745861687}
# evaluation performance: {'loss': 3.2942946434020994, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.06303382227240237, 'overlap rate': 0.16180596157066288}
#
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/model.pt saved!
#
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/training_log.json saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/ModelConfig.json saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/training_plot.png saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_train.json saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_dev.json saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_test.json saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_gen.json saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_train.png saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_dev.png saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_test.png saved!
# experiments/total_red_follow_up/LSTM/HiddenSize-16/3/perfs_gen.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
