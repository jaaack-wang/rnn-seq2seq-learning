# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-06-03 07:47:33

# %% [markdown]
# ## Data loading and processing

# %%
task = "rev"
train, dev, test, gen = read_datasets(f"data/{task}")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = f"{task}_follow_up"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for hs in [64, 32, 16]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; Hidden size: {hs}; run num: {run_num}\n")
            
            use_attn = True
            embd_dim = 128
            hidden_size = hs
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            folder = join(task_folder, rnn_type, f"HiddenSize-{hs}", str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; Hidden size: 16; run num: 3
#
# The model has 27,900 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.199170780181885, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00968007992007992, 'overlap rate': 0.130300149017649}
# evaluation performance: {'loss': 3.1996140241622926, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.009737107753357753, 'overlap rate': 0.13029810009435008}
#
# Current epoch: 20,
# training performance: {'loss': 3.0553102016448976, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01756693667443668, 'overlap rate': 0.16140914807414808}
# evaluation performance: {'loss': 3.0574056625366213, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01781655663780664, 'overlap rate': 0.16147319264069265}
#
# Current epoch: 30,
# training performance: {'loss': 3.013507127761841, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.025311885753135747, 'overlap rate': 0.16901283411033413}
# evaluation performance: {'loss': 3.0156449556350706, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.025590047036297036, 'overlap rate': 0.16810206252081256}
#
# Current epoch: 40,
# training performance: {'loss': 2.9971216678619386, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03217091602841603, 'overlap rate': 0.17320574092574093}
# evaluation performance: {'loss': 2.9996710538864138, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03317342768342769, 'overlap rate': 0.17348745990120995}
#
# Current epoch: 50,
# training performance: {'loss': 2.9912165641784667, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03581887778887779, 'overlap rate': 0.17455264083139083}
# evaluation performance: {'loss': 2.996097230911255, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.036481328116328114, 'overlap rate': 0.17522852217227217}
#
# Current epoch: 60,
# training performance: {'loss': 2.995651626586914, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.040429216477966476, 'overlap rate': 0.17585156163281165}
# evaluation performance: {'loss': 2.9954401731491087, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.04203796564546565, 'overlap rate': 0.1792388997113997}
#
# Current epoch: 70,
# training performance: {'loss': 2.9931077480316164, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.04385717171717172, 'overlap rate': 0.1789272562160062}
# evaluation performance: {'loss': 2.9994930028915405, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.04507418276168276, 'overlap rate': 0.17980069264069262}
#
# Current epoch: 80,
# training performance: {'loss': 2.9949272155761717, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.04730657301032301, 'overlap rate': 0.18302250735375736}
# evaluation performance: {'loss': 2.999523735046387, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.04828898018648019, 'overlap rate': 0.18274806138306138}
#
# Current epoch: 90,
# training performance: {'loss': 2.9994779586791993, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.05109418831168831, 'overlap rate': 0.18608550394050397}
# evaluation performance: {'loss': 3.0036138534545898, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.051916046314796314, 'overlap rate': 0.18590820124320123}
#
# Current epoch: 100,
# training performance: {'loss': 3.0044415473937987, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.054402679958929966, 'overlap rate': 0.18743930597180597}
# evaluation performance: {'loss': 3.0069867372512817, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.05544489718614718, 'overlap rate': 0.18895330974580976}
#
# Current epoch: 110,
# training performance: {'loss': 3.0075689792633056, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.0574519653957154, 'overlap rate': 0.19082016802641805}
# evaluation performance: {'loss': 3.0100891828536986, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.058495629231879245, 'overlap rate': 0.19185825591075592}
#
# Current epoch: 120,
# training performance: {'loss': 3.0156179428100587, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.05999007756132757, 'overlap rate': 0.19317407772782774}
# evaluation performance: {'loss': 3.016162896156311, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.06107229922854922, 'overlap rate': 0.19395393717393716}
#
# Current epoch: 130,
# training performance: {'loss': 3.0187541484832763, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.06204711802086802, 'overlap rate': 0.1949686442723943}
# evaluation performance: {'loss': 3.023915195465088, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.06233154748029749, 'overlap rate': 0.19559417499167497}
#
# Current epoch: 140,
# training performance: {'loss': 3.010582423210144, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.06359289946164945, 'overlap rate': 0.19685248903873906}
# evaluation performance: {'loss': 3.0189076900482177, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.06461948731823733, 'overlap rate': 0.19727595543345544}
#
# Current epoch: 150,
# training performance: {'loss': 3.0146532535552977, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.06591239121989122, 'overlap rate': 0.19865659201909205}
# evaluation performance: {'loss': 3.0217046976089477, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.06569068889443892, 'overlap rate': 0.19900171370296368}
#
# Current epoch: 160,
# training performance: {'loss': 3.0106871128082275, 'full sequence accuracy': 0.0008, 'first n-symbol accuracy': 0.06812643065268066, 'overlap rate': 0.20183315712065714}
# evaluation performance: {'loss': 3.021345615386963, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.06886060037185036, 'overlap rate': 0.20210251484626482}
#
# Current epoch: 170,
# training performance: {'loss': 3.0210479974746702, 'full sequence accuracy': 0.0006000000000000001, 'first n-symbol accuracy': 0.07062599442224443, 'overlap rate': 0.20412100593850596}
# evaluation performance: {'loss': 3.0213778972625733, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.07018884892884891, 'overlap rate': 0.20433324231324232}
#
# Current epoch: 180,
# training performance: {'loss': 3.026607370376587, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.0719089373126873, 'overlap rate': 0.206773817016317}
# evaluation performance: {'loss': 3.0335997104644776, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.07148335123210124, 'overlap rate': 0.2061232851870352}
#
# Current epoch: 190,
# training performance: {'loss': 3.012937831878662, 'full sequence accuracy': 0.0014000000000000002, 'first n-symbol accuracy': 0.07408474456099458, 'overlap rate': 0.20918565517815518}
# evaluation performance: {'loss': 3.0209691762924193, 'full sequence accuracy': 0.0008, 'first n-symbol accuracy': 0.07423174297924298, 'overlap rate': 0.20840903402153402}
#
# Current epoch: 200,
# training performance: {'loss': 3.025184226036072, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.07445889443889443, 'overlap rate': 0.2110022576035076}
# evaluation performance: {'loss': 3.031811237335205, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.07479960844710845, 'overlap rate': 0.21059041916416915}
#
# Current epoch: 210,
# training performance: {'loss': 3.0238483905792237, 'full sequence accuracy': 0.0010000000000000002, 'first n-symbol accuracy': 0.07717811424686426, 'overlap rate': 0.21416854645354647}
# evaluation performance: {'loss': 3.0351670742034913, 'full sequence accuracy': 0.0006000000000000001, 'first n-symbol accuracy': 0.07683827145077146, 'overlap rate': 0.2123692958430458}
#
# Current epoch: 220,
# training performance: {'loss': 3.029991602897644, 'full sequence accuracy': 0.0009000000000000001, 'first n-symbol accuracy': 0.07931149517149516, 'overlap rate': 0.2168078391053391}
# evaluation performance: {'loss': 3.042296361923218, 'full sequence accuracy': 0.0009000000000000001, 'first n-symbol accuracy': 0.0786027786102786, 'overlap rate': 0.2147217889055389}
#
# Current epoch: 230,
# training performance: {'loss': 3.022484874725342, 'full sequence accuracy': 0.0017000000000000001, 'first n-symbol accuracy': 0.08300990398490399, 'overlap rate': 0.22042247474747478}
# evaluation performance: {'loss': 3.0308615922927857, 'full sequence accuracy': 0.0014000000000000002, 'first n-symbol accuracy': 0.0812012142024642, 'overlap rate': 0.2178263478188478}
#
# Current epoch: 240,
# training performance: {'loss': 3.025657892227173, 'full sequence accuracy': 0.0023000000000000004, 'first n-symbol accuracy': 0.08326591075591075, 'overlap rate': 0.2228257158119658}
# evaluation performance: {'loss': 3.037966561317444, 'full sequence accuracy': 0.0016, 'first n-symbol accuracy': 0.08256263472638473, 'overlap rate': 0.2201694189144189}
#
# Current epoch: 250,
# training performance: {'loss': 3.0286177158355714, 'full sequence accuracy': 0.0015, 'first n-symbol accuracy': 0.08408818278943278, 'overlap rate': 0.223845168997669}
# evaluation performance: {'loss': 3.0430712938308715, 'full sequence accuracy': 0.0013, 'first n-symbol accuracy': 0.08306825674325675, 'overlap rate': 0.22098675962925962}
#
# Current epoch: 260,
# training performance: {'loss': 3.027180552482605, 'full sequence accuracy': 0.0024000000000000002, 'first n-symbol accuracy': 0.0861904514929515, 'overlap rate': 0.22523778166278166}
# evaluation performance: {'loss': 3.0438791275024415, 'full sequence accuracy': 0.002, 'first n-symbol accuracy': 0.08526348193473195, 'overlap rate': 0.22192040542790542}
#
# Current epoch: 270,
# training performance: {'loss': 3.024447512626648, 'full sequence accuracy': 0.004600000000000001, 'first n-symbol accuracy': 0.09015373487623488, 'overlap rate': 0.23009662212787213}
# evaluation performance: {'loss': 3.037448787689209, 'full sequence accuracy': 0.0047, 'first n-symbol accuracy': 0.08905888597513598, 'overlap rate': 0.2275037456987457}
#
# Current epoch: 280,
# training performance: {'loss': 3.021375632286072, 'full sequence accuracy': 0.0051, 'first n-symbol accuracy': 0.09196544330669333, 'overlap rate': 0.23177030788655792}
# evaluation performance: {'loss': 3.0416010141372682, 'full sequence accuracy': 0.0058000000000000005, 'first n-symbol accuracy': 0.09056137015762017, 'overlap rate': 0.22760495657120655}
#
# Current epoch: 290,
# training performance: {'loss': 3.044164443016052, 'full sequence accuracy': 0.0044, 'first n-symbol accuracy': 0.09409219807969807, 'overlap rate': 0.23521617132867134}
# evaluation performance: {'loss': 3.0541629552841187, 'full sequence accuracy': 0.0046, 'first n-symbol accuracy': 0.09352228937728937, 'overlap rate': 0.23209740620490624}
#
# Current epoch: 300,
# training performance: {'loss': 3.028928542137146, 'full sequence accuracy': 0.008, 'first n-symbol accuracy': 0.09742530344655345, 'overlap rate': 0.23848738983238982}
# evaluation performance: {'loss': 3.0423456192016602, 'full sequence accuracy': 0.0066, 'first n-symbol accuracy': 0.09528476592851592, 'overlap rate': 0.233088464035964}
#
# Current epoch: 310,
# training performance: {'loss': 3.019973945617676, 'full sequence accuracy': 0.0075000000000000015, 'first n-symbol accuracy': 0.09818312062937064, 'overlap rate': 0.2405398197635697}
# evaluation performance: {'loss': 3.0339502334594726, 'full sequence accuracy': 0.0064, 'first n-symbol accuracy': 0.09699043734043736, 'overlap rate': 0.23875179861804866}
#
# Current epoch: 320,
# training performance: {'loss': 3.043885684013367, 'full sequence accuracy': 0.0086, 'first n-symbol accuracy': 0.10140504634254635, 'overlap rate': 0.2439025098512598}
# evaluation performance: {'loss': 3.0632355928421022, 'full sequence accuracy': 0.006, 'first n-symbol accuracy': 0.09850176823176823, 'overlap rate': 0.23869290112665106}
#
# Current epoch: 330,
# training performance: {'loss': 3.0213547945022583, 'full sequence accuracy': 0.0134, 'first n-symbol accuracy': 0.1074599055111555, 'overlap rate': 0.24834809218559215}
# evaluation performance: {'loss': 3.038317823410034, 'full sequence accuracy': 0.0111, 'first n-symbol accuracy': 0.10483922383172384, 'overlap rate': 0.24406123168498164}
#
# Current epoch: 340,
# training performance: {'loss': 3.027448606491089, 'full sequence accuracy': 0.0109, 'first n-symbol accuracy': 0.10897309607059606, 'overlap rate': 0.25147390553890553}
# evaluation performance: {'loss': 3.036065173149109, 'full sequence accuracy': 0.009600000000000001, 'first n-symbol accuracy': 0.10771934967809968, 'overlap rate': 0.25001700299700297}
#
# Current epoch: 350,
# training performance: {'loss': 3.016433525085449, 'full sequence accuracy': 0.019, 'first n-symbol accuracy': 0.11472599872349873, 'overlap rate': 0.2576153771228771}
# evaluation performance: {'loss': 3.023665499687195, 'full sequence accuracy': 0.0165, 'first n-symbol accuracy': 0.1140797816072816, 'overlap rate': 0.25671742493617494}
#
# Current epoch: 360,
# training performance: {'loss': 3.03853497505188, 'full sequence accuracy': 0.014100000000000001, 'first n-symbol accuracy': 0.11508705072705072, 'overlap rate': 0.2593447752247752}
# evaluation performance: {'loss': 3.047089672088623, 'full sequence accuracy': 0.0128, 'first n-symbol accuracy': 0.11539754953379952, 'overlap rate': 0.2575748477910978}
#
# Current epoch: 370,
# training performance: {'loss': 3.0234196901321413, 'full sequence accuracy': 0.019200000000000002, 'first n-symbol accuracy': 0.11939409798534797, 'overlap rate': 0.2645215637140637}
# evaluation performance: {'loss': 3.033008503913879, 'full sequence accuracy': 0.017400000000000002, 'first n-symbol accuracy': 0.11774084915084918, 'overlap rate': 0.2617864167776668}
#
# Current epoch: 380,
# training performance: {'loss': 3.0185655832290648, 'full sequence accuracy': 0.0213, 'first n-symbol accuracy': 0.12223609820734822, 'overlap rate': 0.26586067071817066}
# evaluation performance: {'loss': 3.021104335784912, 'full sequence accuracy': 0.0204, 'first n-symbol accuracy': 0.12318951312576314, 'overlap rate': 0.26543112776112776}
#
# Current epoch: 390,
# training performance: {'loss': 3.020840048789978, 'full sequence accuracy': 0.020900000000000002, 'first n-symbol accuracy': 0.12322927614052614, 'overlap rate': 0.269316858974359}
# evaluation performance: {'loss': 3.0316015481948853, 'full sequence accuracy': 0.0194, 'first n-symbol accuracy': 0.12327077519702519, 'overlap rate': 0.2677345185370185}
#
# Current epoch: 400,
# training performance: {'loss': 3.018402171134949, 'full sequence accuracy': 0.0201, 'first n-symbol accuracy': 0.12561702575202577, 'overlap rate': 0.27213907023532025}
# evaluation performance: {'loss': 3.028249669075012, 'full sequence accuracy': 0.020200000000000003, 'first n-symbol accuracy': 0.12715891095016096, 'overlap rate': 0.2726050588300588}
#
# Current epoch: 410,
# training performance: {'loss': 3.014908051490784, 'full sequence accuracy': 0.0251, 'first n-symbol accuracy': 0.13038265540015542, 'overlap rate': 0.27649167457542456}
# evaluation performance: {'loss': 3.0311969995498655, 'full sequence accuracy': 0.0228, 'first n-symbol accuracy': 0.12917978646353645, 'overlap rate': 0.2742822627372627}
#
# Current epoch: 420,
# training performance: {'loss': 3.004554641246796, 'full sequence accuracy': 0.030100000000000005, 'first n-symbol accuracy': 0.13655434537684535, 'overlap rate': 0.2823655038017538}
# evaluation performance: {'loss': 3.009518933296204, 'full sequence accuracy': 0.027700000000000002, 'first n-symbol accuracy': 0.13544812742812745, 'overlap rate': 0.2810699127261627}
#
# Current epoch: 430,
# training performance: {'loss': 2.991553246974945, 'full sequence accuracy': 0.031000000000000007, 'first n-symbol accuracy': 0.13859441475191475, 'overlap rate': 0.2852623355810856}
# evaluation performance: {'loss': 3.0018877148628236, 'full sequence accuracy': 0.029200000000000004, 'first n-symbol accuracy': 0.13904198759573758, 'overlap rate': 0.28483169913419915}
#
# Current epoch: 440,
# training performance: {'loss': 2.9598730206489563, 'full sequence accuracy': 0.038400000000000004, 'first n-symbol accuracy': 0.14452157314907313, 'overlap rate': 0.29231798118548113}
# evaluation performance: {'loss': 2.9710815072059633, 'full sequence accuracy': 0.0372, 'first n-symbol accuracy': 0.143885675990676, 'overlap rate': 0.2906980685980686}
#
# Current epoch: 450,
# training performance: {'loss': 2.951233077049255, 'full sequence accuracy': 0.027700000000000002, 'first n-symbol accuracy': 0.14666956085581084, 'overlap rate': 0.2963478987678988}
# evaluation performance: {'loss': 2.969716489315033, 'full sequence accuracy': 0.0262, 'first n-symbol accuracy': 0.14437967393717394, 'overlap rate': 0.29199474039849044}
#
# Current epoch: 460,
# training performance: {'loss': 2.961285412311554, 'full sequence accuracy': 0.03810000000000001, 'first n-symbol accuracy': 0.15183877747252747, 'overlap rate': 0.30056502095127097}
# evaluation performance: {'loss': 2.9625791668891908, 'full sequence accuracy': 0.033100000000000004, 'first n-symbol accuracy': 0.15007635531135535, 'overlap rate': 0.2985996654734155}
#
# Current epoch: 470,
# training performance: {'loss': 2.9293418645858766, 'full sequence accuracy': 0.0432, 'first n-symbol accuracy': 0.15832658549783551, 'overlap rate': 0.30672036879786885}
# evaluation performance: {'loss': 2.9230756640434263, 'full sequence accuracy': 0.044300000000000006, 'first n-symbol accuracy': 0.15984079392829395, 'overlap rate': 0.3075194243256743}
#
# Current epoch: 480,
# training performance: {'loss': 2.871586811542511, 'full sequence accuracy': 0.06200000000000001, 'first n-symbol accuracy': 0.17205101204351203, 'overlap rate': 0.31990430888555893}
# evaluation performance: {'loss': 2.8798293352127073, 'full sequence accuracy': 0.06050000000000001, 'first n-symbol accuracy': 0.17158263264513263, 'overlap rate': 0.3178044695582196}
#
# Current epoch: 490,
# training performance: {'loss': 2.863244581222534, 'full sequence accuracy': 0.057199999999999994, 'first n-symbol accuracy': 0.17475573343323347, 'overlap rate': 0.3249027586302586}
# evaluation performance: {'loss': 2.874819254875183, 'full sequence accuracy': 0.0539, 'first n-symbol accuracy': 0.17280221237096235, 'overlap rate': 0.3226899490786991}
#
# Current epoch: 500,
# training performance: {'loss': 2.8187723755836487, 'full sequence accuracy': 0.0737, 'first n-symbol accuracy': 0.18731006424131422, 'overlap rate': 0.33657887778887785}
# evaluation performance: {'loss': 2.8323604345321653, 'full sequence accuracy': 0.07089999999999999, 'first n-symbol accuracy': 0.18495861208236214, 'overlap rate': 0.3325251075313575}
#
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/model.pt saved!
#
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/training_log.json saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/ModelConfig.json saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/training_plot.png saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/perfs_train.json saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/perfs_dev.json saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/perfs_test.json saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/perfs_gen.json saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/perfs_train.png saved!
# experiments/rev_follow_up/LSTM/HiddenSize-16/3/perfs_dev.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
