# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 128
embd_dim = 128
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = True
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 1
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#1/RNN created!
# ./Experiments_Logs/Experiment#1/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#1/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#1/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.8 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#1 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.558389163017273, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.023822139063850046, 'overlap rate': 0.2561155617237091}
# evaluation performance: {'loss': 2.737353515625, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.021407311107032, 'overlap rate': 0.1741801369935274}
#
# Current epoch: 10,
# training performance: {'loss': 1.932028704881668, 'abosulate accuracy': 0.0008000000263564289, 'consecutive overlap rate': 0.1272615314461291, 'overlap rate': 0.48248606324195864}
# evaluation performance: {'loss': 2.5521233797073366, 'abosulate accuracy': 0.00025000000605359676, 'consecutive overlap rate': 0.09370582606643438, 'overlap rate': 0.27264434583485125}
#
# Current epoch: 15,
# training performance: {'loss': 1.660063225030899, 'abosulate accuracy': 0.005000000260770321, 'consecutive overlap rate': 0.23249613605439662, 'overlap rate': 0.5618449851870537}
# evaluation performance: {'loss': 2.1857870310544967, 'abosulate accuracy': 0.0023000001616310327, 'consecutive overlap rate': 0.16334845684468746, 'overlap rate': 0.39925416707992556}
#
# Current epoch: 20,
# training performance: {'loss': 0.9959778562188148, 'abosulate accuracy': 0.06220000302419067, 'consecutive overlap rate': 0.43993439972400666, 'overlap rate': 0.766733244806528}
# evaluation performance: {'loss': 1.7617542788386344, 'abosulate accuracy': 0.12315000593662262, 'consecutive overlap rate': 0.45775569416582584, 'overlap rate': 0.5885944999754429}
#
# Current epoch: 25,
# training performance: {'loss': 0.09530016500502825, 'abosulate accuracy': 0.8296000391244889, 'consecutive overlap rate': 0.9752117112278939, 'overlap rate': 0.9945476248860359}
# evaluation performance: {'loss': 0.08162087928503751, 'abosulate accuracy': 0.8758500427007675, 'consecutive overlap rate': 0.9857748210430145, 'overlap rate': 0.9959004953503608}
#
# Current epoch: 30,
# training performance: {'loss': 0.029111783625558017, 'abosulate accuracy': 0.9202000290155411, 'consecutive overlap rate': 0.9982104182243348, 'overlap rate': 0.9997339650988579}
# evaluation performance: {'loss': 0.0282430540304631, 'abosulate accuracy': 0.917700032889843, 'consecutive overlap rate': 0.9974952846765518, 'overlap rate': 0.9992733836174011}
#
# Current epoch: 35,
# training performance: {'loss': 0.019526459788903595, 'abosulate accuracy': 0.9199000284075737, 'consecutive overlap rate': 0.9983657568693161, 'overlap rate': 0.9995102599263191}
# evaluation performance: {'loss': 0.02069338159635663, 'abosulate accuracy': 0.9201500192284584, 'consecutive overlap rate': 0.9980888709425926, 'overlap rate': 0.9994652986526489}
#
# Current epoch: 40,
# training performance: {'loss': 0.010011852905154228, 'abosulate accuracy': 0.9243000045418739, 'consecutive overlap rate': 0.9997540533542633, 'overlap rate': 0.999948151409626}
# evaluation performance: {'loss': 0.010740857815835624, 'abosulate accuracy': 0.9237000107765198, 'consecutive overlap rate': 0.9995736956596375, 'overlap rate': 0.9997913181781769}
#
# Current epoch: 45,
# training performance: {'loss': 0.0066910246154293414, 'abosulate accuracy': 0.9242000058293343, 'consecutive overlap rate': 0.999714833498001, 'overlap rate': 0.9999668762087822}
# evaluation performance: {'loss': 0.007983044476713986, 'abosulate accuracy': 0.9237500086426735, 'consecutive overlap rate': 0.9996030136942864, 'overlap rate': 0.9997724086046219}
#
# Current epoch: 50,
# training performance: {'loss': 0.0049076078226789836, 'abosulate accuracy': 0.9247000038623809, 'consecutive overlap rate': 0.9999120846390724, 'overlap rate': 0.9999931901693344}
# evaluation performance: {'loss': 0.007294964406173676, 'abosulate accuracy': 0.9232000067830086, 'consecutive overlap rate': 0.999491935968399, 'overlap rate': 0.9996368691325188}
#
# Current epoch: 55,
# training performance: {'loss': 0.0038266706455033273, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.999974998831749, 'overlap rate': 0.9999983310699463}
# evaluation performance: {'loss': 0.006703591934638098, 'abosulate accuracy': 0.9230000078678131, 'consecutive overlap rate': 0.9994539588689804, 'overlap rate': 0.9996009305119514}
#
# Current epoch: 60,
# training performance: {'loss': 0.003070448205107823, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.999974998831749, 'overlap rate': 0.9999983310699463}
# evaluation performance: {'loss': 0.006060871126828715, 'abosulate accuracy': 0.9229000091552735, 'consecutive overlap rate': 0.9994002744555474, 'overlap rate': 0.9995859518647194}
#
# Current epoch: 65,
# training performance: {'loss': 0.002512226824183017, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.005769924394553527, 'abosulate accuracy': 0.9230500102043152, 'consecutive overlap rate': 0.9994237035512924, 'overlap rate': 0.9995694294571876}
#
# Current epoch: 70,
# training performance: {'loss': 0.002085750998230651, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.005514656694140285, 'abosulate accuracy': 0.9231000080704689, 'consecutive overlap rate': 0.9994584992527962, 'overlap rate': 0.9995661363005638}
#
# Current epoch: 75,
# training performance: {'loss': 0.0017514912178739905, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.005409330636030063, 'abosulate accuracy': 0.9231000080704689, 'consecutive overlap rate': 0.999462004005909, 'overlap rate': 0.9995415300130844}
#
# Current epoch: 80,
# training performance: {'loss': 0.0014842708711512386, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.005181821814039722, 'abosulate accuracy': 0.9230000093579293, 'consecutive overlap rate': 0.9994424909353257, 'overlap rate': 0.999546492099762}
#
# Current epoch: 85,
# training performance: {'loss': 0.0012672634795308114, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.00513308853842318, 'abosulate accuracy': 0.9229500100016594, 'consecutive overlap rate': 0.9994190871715546, 'overlap rate': 0.9995402619242668}
#
# Current epoch: 90,
# training performance: {'loss': 0.001088748118490912, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.005158058732922655, 'abosulate accuracy': 0.9228000104427337, 'consecutive overlap rate': 0.999384093284607, 'overlap rate': 0.9995158568024636}
#
# Current epoch: 95,
# training performance: {'loss': 0.0009403088508406654, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.005231815519800875, 'abosulate accuracy': 0.9227500095963478, 'consecutive overlap rate': 0.9993696719408035, 'overlap rate': 0.9994906455278396}
#
# Current epoch: 100,
# training performance: {'loss': 0.0008157519579981454, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0053603969965479335, 'abosulate accuracy': 0.922650009393692, 'consecutive overlap rate': 0.9993436023592949, 'overlap rate': 0.9994689255952836}
#
# Experiments_Logs/Experiment#1/RNN/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 6.490607565641403, 'abosulate accuracy': 0.02510000110778492, 'consecutive overlap rate': 0.026487973376060837, 'overlap rate': 0.18179662162438034}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.006587425584439188, 'abosulate accuracy': 0.9238500207662582, 'consecutive overlap rate': 0.9995756089687348, 'overlap rate': 0.9998242273926735}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.640502868160125, 'abosulate accuracy': 0.0036129033733760156, 'consecutive overlap rate': 0.0180024619905218, 'overlap rate': 0.15532829501936513}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.44558310607987406, 'abosulate accuracy': 0.7887894970021749, 'consecutive overlap rate': 0.92846102149863, 'overlap rate': 0.9373924920433446}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.695732355117798, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016047543764580043, 'overlap rate': 0.22494735494256018}
# evaluation performance: {'loss': 2.8316663980484007, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016598702420014887, 'overlap rate': 0.159065848775208}
#
# Current epoch: 10,
# training performance: {'loss': 1.788426047563553, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.09407116146758199, 'overlap rate': 0.5039053782820702}
# evaluation performance: {'loss': 2.2672972232103348, 'abosulate accuracy': 0.0006500000250525773, 'consecutive overlap rate': 0.08362395837903022, 'overlap rate': 0.3386857632547617}
#
# Current epoch: 15,
# training performance: {'loss': 1.3626802399754525, 'abosulate accuracy': 0.01640000076731667, 'consecutive overlap rate': 0.2592492027208209, 'overlap rate': 0.6424358665943146}
# evaluation performance: {'loss': 2.194919395446777, 'abosulate accuracy': 0.0008500000287313015, 'consecutive overlap rate': 0.20110822636634113, 'overlap rate': 0.43003545701503754}
#
# Current epoch: 20,
# training performance: {'loss': 0.6661303322762251, 'abosulate accuracy': 0.33270001454511655, 'consecutive overlap rate': 0.6206058323383331, 'overlap rate': 0.8777347385883332}
# evaluation performance: {'loss': 0.8090491965413094, 'abosulate accuracy': 0.21960000940598548, 'consecutive overlap rate': 0.5268003635108471, 'overlap rate': 0.8625880256295204}
#
# Current epoch: 25,
# training performance: {'loss': 0.04785298136994243, 'abosulate accuracy': 0.9141000285744667, 'consecutive overlap rate': 0.9938760802149773, 'overlap rate': 0.9992829635739326}
# evaluation performance: {'loss': 0.041692633647471666, 'abosulate accuracy': 0.9182000294327736, 'consecutive overlap rate': 0.9967429921030998, 'overlap rate': 0.9993524104356766}
#
# Current epoch: 30,
# training performance: {'loss': 0.29169963374733926, 'abosulate accuracy': 0.6203000243753195, 'consecutive overlap rate': 0.8517752751708031, 'overlap rate': 0.961396087706089}
# evaluation performance: {'loss': 0.16389084681868554, 'abosulate accuracy': 0.7669500336050987, 'consecutive overlap rate': 0.9066846594214439, 'overlap rate': 0.9903136670589447}
#
# Current epoch: 35,
# training performance: {'loss': 0.02063854495063424, 'abosulate accuracy': 0.921700020134449, 'consecutive overlap rate': 0.9987812161445617, 'overlap rate': 0.9998719394207001}
# evaluation performance: {'loss': 0.020733302575536072, 'abosulate accuracy': 0.9202500224113465, 'consecutive overlap rate': 0.9977654352784157, 'overlap rate': 0.9995787486433982}
#
# Current epoch: 40,
# training performance: {'loss': 0.010675330716185271, 'abosulate accuracy': 0.9225000128149986, 'consecutive overlap rate': 0.9993835315108299, 'overlap rate': 0.9999363720417023}
# evaluation performance: {'loss': 0.014257295639254153, 'abosulate accuracy': 0.920250017940998, 'consecutive overlap rate': 0.9980036616325378, 'overlap rate': 0.9993026793003082}
#
# Current epoch: 45,
# training performance: {'loss': 0.007038017467129976, 'abosulate accuracy': 0.9235000103712082, 'consecutive overlap rate': 0.9995200142264367, 'overlap rate': 0.9999635234475136}
# evaluation performance: {'loss': 0.011829839309211821, 'abosulate accuracy': 0.9202500209212303, 'consecutive overlap rate': 0.9978900402784348, 'overlap rate': 0.9992112070322037}
#
# Current epoch: 50,
# training performance: {'loss': 0.005109178065322339, 'abosulate accuracy': 0.9240000054240227, 'consecutive overlap rate': 0.9996400609612465, 'overlap rate': 0.9999785870313644}
# evaluation performance: {'loss': 0.01104877395555377, 'abosulate accuracy': 0.9204500198364258, 'consecutive overlap rate': 0.9980082377791405, 'overlap rate': 0.999127209186554}
#
# Current epoch: 55,
# training performance: {'loss': 0.00390977983479388, 'abosulate accuracy': 0.92430000603199, 'consecutive overlap rate': 0.9998259857296944, 'overlap rate': 0.9999874651432037}
# evaluation performance: {'loss': 0.009883595822611824, 'abosulate accuracy': 0.9207500204443931, 'consecutive overlap rate': 0.998205129802227, 'overlap rate': 0.9991564020514488}
#
# Current epoch: 60,
# training performance: {'loss': 0.0030918416392523794, 'abosulate accuracy': 0.9247000023722649, 'consecutive overlap rate': 0.9999912858009339, 'overlap rate': 0.9999947935342789}
# evaluation performance: {'loss': 0.009236778563354165, 'abosulate accuracy': 0.9209500193595886, 'consecutive overlap rate': 0.9982209339737892, 'overlap rate': 0.9991654381155968}
#
# Current epoch: 65,
# training performance: {'loss': 0.0025032712321262805, 'abosulate accuracy': 0.9247000023722649, 'consecutive overlap rate': 0.9999912858009339, 'overlap rate': 0.9999947935342789}
# evaluation performance: {'loss': 0.008877550333272666, 'abosulate accuracy': 0.9212500154972076, 'consecutive overlap rate': 0.9983287945389747, 'overlap rate': 0.9991584256291389}
#
# Current epoch: 70,
# training performance: {'loss': 0.002061885831062682, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.008038703555939719, 'abosulate accuracy': 0.9212500169873238, 'consecutive overlap rate': 0.9983357176184654, 'overlap rate': 0.9992000162601471}
#
# Current epoch: 75,
# training performance: {'loss': 0.0017212931357789784, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.008856057169032283, 'abosulate accuracy': 0.9213000163435936, 'consecutive overlap rate': 0.9982674464583396, 'overlap rate': 0.9991009131073951}
#
# Current epoch: 80,
# training performance: {'loss': 0.0014523733174428345, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.00809391614748165, 'abosulate accuracy': 0.9214500173926353, 'consecutive overlap rate': 0.9983835697174073, 'overlap rate': 0.9991597771644593}
#
# Current epoch: 85,
# training performance: {'loss': 0.0012365440401481465, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.00768919026304502, 'abosulate accuracy': 0.9215500161051751, 'consecutive overlap rate': 0.9984182462096214, 'overlap rate': 0.9991935417056084}
#
# Current epoch: 90,
# training performance: {'loss': 0.001060661232622806, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0069186956141493285, 'abosulate accuracy': 0.9216500118374824, 'consecutive overlap rate': 0.9985578119754791, 'overlap rate': 0.9992781475186348}
#
# Current epoch: 95,
# training performance: {'loss': 0.0009154394283541478, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.006477943010395393, 'abosulate accuracy': 0.9218500167131424, 'consecutive overlap rate': 0.998674426972866, 'overlap rate': 0.9993173688650131}
#
# Current epoch: 100,
# training performance: {'loss': 0.0007940948053146712, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0064581836413708515, 'abosulate accuracy': 0.9219000160694122, 'consecutive overlap rate': 0.9986544951796532, 'overlap rate': 0.9993081420660019}
#
# Experiments_Logs/Experiment#1/RNN/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 7.292799162864685, 'abosulate accuracy': 0.024925001087831335, 'consecutive overlap rate': 0.026158298266818748, 'overlap rate': 0.08757293785456569}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.006458831805502996, 'abosulate accuracy': 0.921975028514862, 'consecutive overlap rate': 0.9986368641257286, 'overlap rate': 0.9993003949522972}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.570304301477248, 'abosulate accuracy': 0.01742548774627428, 'consecutive overlap rate': 0.02274217780439123, 'overlap rate': 0.09095865074665316}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.14405592675106355, 'abosulate accuracy': 0.9107368713931033, 'consecutive overlap rate': 0.971276298949593, 'overlap rate': 0.9804323550901914}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.631251263618469, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.022669611289165913, 'overlap rate': 0.2465944066643715}
# evaluation performance: {'loss': 2.691097491979599, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02571711507625878, 'overlap rate': 0.20900147072970868}
#
# Current epoch: 10,
# training performance: {'loss': 1.8376689791679381, 'abosulate accuracy': 0.0006000000168569386, 'consecutive overlap rate': 0.10433742301538587, 'overlap rate': 0.5018534984439611}
# evaluation performance: {'loss': 2.302421101927757, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.10720791537314653, 'overlap rate': 0.3326522707939148}
#
# Current epoch: 15,
# training performance: {'loss': 1.4332822859287262, 'abosulate accuracy': 0.006500000227242708, 'consecutive overlap rate': 0.18816309357061983, 'overlap rate': 0.6076964467763901}
# evaluation performance: {'loss': 1.549530205130577, 'abosulate accuracy': 0.010150000412249938, 'consecutive overlap rate': 0.2149267328903079, 'overlap rate': 0.5443088918924331}
#
# Current epoch: 20,
# training performance: {'loss': 0.1940434467047453, 'abosulate accuracy': 0.7286000356078148, 'consecutive overlap rate': 0.8974134176969528, 'overlap rate': 0.9881039232015609}
# evaluation performance: {'loss': 0.16255369260907174, 'abosulate accuracy': 0.8127000391483307, 'consecutive overlap rate': 0.9307730406522751, 'overlap rate': 0.9887616261839867}
#
# Current epoch: 25,
# training performance: {'loss': 0.194173039868474, 'abosulate accuracy': 0.806300038099289, 'consecutive overlap rate': 0.9328129187226295, 'overlap rate': 0.9901956543326378}
# evaluation performance: {'loss': 0.11361374296247959, 'abosulate accuracy': 0.8897500410676003, 'consecutive overlap rate': 0.9773760735988617, 'overlap rate': 0.9979846030473709}
#
# Current epoch: 30,
# training performance: {'loss': 0.09184285141527652, 'abosulate accuracy': 0.8861000433564186, 'consecutive overlap rate': 0.9702727511525154, 'overlap rate': 0.9967815041542053}
# evaluation performance: {'loss': 0.06170270014554262, 'abosulate accuracy': 0.9115500345826149, 'consecutive overlap rate': 0.9922372788190842, 'overlap rate': 0.9992687195539475}
#
# Current epoch: 35,
# training performance: {'loss': 0.021050290437415242, 'abosulate accuracy': 0.9240000084042549, 'consecutive overlap rate': 0.9996457189321518, 'overlap rate': 0.999942609667778}
# evaluation performance: {'loss': 0.020338938711211084, 'abosulate accuracy': 0.9236500144004822, 'consecutive overlap rate': 0.9994070321321488, 'overlap rate': 0.9998343467712403}
#
# Current epoch: 40,
# training performance: {'loss': 0.012453466118313373, 'abosulate accuracy': 0.9244000062346458, 'consecutive overlap rate': 0.9998058810830116, 'overlap rate': 0.9999151304364204}
# evaluation performance: {'loss': 0.011849586921744048, 'abosulate accuracy': 0.9242500066757202, 'consecutive overlap rate': 0.9995429709553718, 'overlap rate': 0.9999663293361664}
#
# Current epoch: 45,
# training performance: {'loss': 0.007933746196795256, 'abosulate accuracy': 0.9247000023722649, 'consecutive overlap rate': 0.9999070689082146, 'overlap rate': 0.9999949410557747}
# evaluation performance: {'loss': 0.008342087070923298, 'abosulate accuracy': 0.9244500070810318, 'consecutive overlap rate': 0.9997099190950394, 'overlap rate': 0.9999149650335312}
#
# Current epoch: 50,
# training performance: {'loss': 0.005708691733889282, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999983325600624, 'overlap rate': 0.9999983310699463}
# evaluation performance: {'loss': 0.007122075057122856, 'abosulate accuracy': 0.9241500049829483, 'consecutive overlap rate': 0.9993704751133918, 'overlap rate': 0.99980259090662}
#
# Current epoch: 55,
# training performance: {'loss': 0.004384999524336308, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.00558156194165349, 'abosulate accuracy': 0.9239500075578689, 'consecutive overlap rate': 0.9993403986096382, 'overlap rate': 0.9998405858874321}
#
# Current epoch: 60,
# training performance: {'loss': 0.003489095496479422, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.004985998070333153, 'abosulate accuracy': 0.9239500060677528, 'consecutive overlap rate': 0.9993963062763214, 'overlap rate': 0.9998177915811539}
#
# Current epoch: 65,
# training performance: {'loss': 0.0028428121353499592, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.004414709151023999, 'abosulate accuracy': 0.9237000077962876, 'consecutive overlap rate': 0.9993061870336533, 'overlap rate': 0.9998076558113098}
#
# Current epoch: 70,
# training performance: {'loss': 0.002356478141155094, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.00400519726681523, 'abosulate accuracy': 0.9238000079989434, 'consecutive overlap rate': 0.9993668794631958, 'overlap rate': 0.9998000070452691}
#
# Current epoch: 75,
# training performance: {'loss': 0.0019791383267147465, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0032414985675131903, 'abosulate accuracy': 0.923900006711483, 'consecutive overlap rate': 0.9994142055511475, 'overlap rate': 0.9998478800058365}
#
# Current epoch: 80,
# training performance: {'loss': 0.0016794508585007862, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.002898236474720761, 'abosulate accuracy': 0.9240000084042549, 'consecutive overlap rate': 0.9994804814457894, 'overlap rate': 0.9998547330498695}
#
# Current epoch: 85,
# training performance: {'loss': 0.0014370006072567775, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0024976960034109653, 'abosulate accuracy': 0.9241500064730644, 'consecutive overlap rate': 0.9995375156402588, 'overlap rate': 0.9998762115836144}
#
# Current epoch: 90,
# training performance: {'loss': 0.0012379071558825672, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.002305159080424346, 'abosulate accuracy': 0.9242000058293343, 'consecutive overlap rate': 0.999578207731247, 'overlap rate': 0.9998800024390221}
#
# Current epoch: 95,
# training performance: {'loss': 0.0010724012638092973, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0022228971705771984, 'abosulate accuracy': 0.9242500051856041, 'consecutive overlap rate': 0.9995922729372978, 'overlap rate': 0.9998747885227204}
#
# Current epoch: 100,
# training performance: {'loss': 0.0009334008020232432, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.002077634401211981, 'abosulate accuracy': 0.9243500053882598, 'consecutive overlap rate': 0.9996255725622177, 'overlap rate': 0.9998739406466484}
#
# Experiments_Logs/Experiment#1/RNN/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 6.985167053341866, 'abosulate accuracy': 0.024950001019169575, 'consecutive overlap rate': 0.02637500036507845, 'overlap rate': 0.1007025090046227}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.007877995329909026, 'abosulate accuracy': 0.924650014936924, 'consecutive overlap rate': 0.999787263572216, 'overlap rate': 0.9999709218740463}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.957903160587434, 'abosulate accuracy': 0.0037222614241463523, 'consecutive overlap rate': 0.01278111757710576, 'overlap rate': 0.08072803397813151}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.5473140352405608, 'abosulate accuracy': 0.7909473980727949, 'consecutive overlap rate': 0.8857585199569401, 'overlap rate': 0.9285764286392614}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ...experiment#1 with RNN seq2seq ends.
# Start experiment#1 with RNN seq2seq...
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.6595097899436952, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02124054073356092, 'overlap rate': 0.22916286550462245}
# evaluation performance: {'loss': 2.8440853714942933, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025059711048379542, 'overlap rate': 0.15983767826110123}
#
# Current epoch: 10,
# training performance: {'loss': 2.0249572485685348, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07464335048571229, 'overlap rate': 0.4271866500377655}
# evaluation performance: {'loss': 2.382054108381271, 'abosulate accuracy': 0.0003000000084284693, 'consecutive overlap rate': 0.08924524979665875, 'overlap rate': 0.31784139610826967}
#
# Current epoch: 15,
# training performance: {'loss': 1.6552245199680329, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.14564479906111955, 'overlap rate': 0.5394204586744309}
# evaluation performance: {'loss': 2.7791490256786346, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.15216344092041253, 'overlap rate': 0.2967000428587198}
#
# Current epoch: 20,
# training performance: {'loss': 1.3183816775679589, 'abosulate accuracy': 0.013800000469200314, 'consecutive overlap rate': 0.2969184197485447, 'overlap rate': 0.659266184270382}
# evaluation performance: {'loss': 1.8055647909641266, 'abosulate accuracy': 0.020100000558886676, 'consecutive overlap rate': 0.31256977953016757, 'overlap rate': 0.5252064898610115}
#
# Current epoch: 25,
# training performance: {'loss': 0.5239627927541732, 'abosulate accuracy': 0.33690001572249456, 'consecutive overlap rate': 0.7385209105908871, 'overlap rate': 0.9031065210700036}
# evaluation performance: {'loss': 0.7749567694962025, 'abosulate accuracy': 0.33815001621842383, 'consecutive overlap rate': 0.7093161895871163, 'overlap rate': 0.8289666689932347}
#
# Current epoch: 30,
# training performance: {'loss': 0.4237472670152783, 'abosulate accuracy': 0.4341000189189799, 'consecutive overlap rate': 0.7901755481958389, 'overlap rate': 0.9282360285520553}
# evaluation performance: {'loss': 0.18264562655240296, 'abosulate accuracy': 0.7272500284016132, 'consecutive overlap rate': 0.9390416383743286, 'overlap rate': 0.9810053318738937}
#
# Current epoch: 35,
# training performance: {'loss': 0.04120426336303353, 'abosulate accuracy': 0.9151000291109085, 'consecutive overlap rate': 0.9946571171283722, 'overlap rate': 0.9992388382554054}
# evaluation performance: {'loss': 0.032145860185846684, 'abosulate accuracy': 0.9210000231862068, 'consecutive overlap rate': 0.9980122730135917, 'overlap rate': 0.9996965438127517}
#
# Current epoch: 40,
# training performance: {'loss': 0.0156603554263711, 'abosulate accuracy': 0.9233000114560127, 'consecutive overlap rate': 0.9993195876479148, 'overlap rate': 0.9999186441302299}
# evaluation performance: {'loss': 0.015264152269810437, 'abosulate accuracy': 0.9232000112533569, 'consecutive overlap rate': 0.9992622926831245, 'overlap rate': 0.9998001039028168}
#
# Current epoch: 45,
# training performance: {'loss': 0.015184256504289806, 'abosulate accuracy': 0.9201000168919563, 'consecutive overlap rate': 0.9988842993974686, 'overlap rate': 0.9996389254927636}
# evaluation performance: {'loss': 0.023105797194875776, 'abosulate accuracy': 0.9202500253915786, 'consecutive overlap rate': 0.9974024280905723, 'overlap rate': 0.9985834568738937}
#
# Current epoch: 50,
# training performance: {'loss': 0.008624136657454073, 'abosulate accuracy': 0.9233000129461288, 'consecutive overlap rate': 0.9994509488344192, 'overlap rate': 0.9997810199856758}
# evaluation performance: {'loss': 0.007341923844069243, 'abosulate accuracy': 0.9244500055909157, 'consecutive overlap rate': 0.9996699571609498, 'overlap rate': 0.9999508380889892}
#
# Current epoch: 55,
# training performance: {'loss': 0.004908663360401988, 'abosulate accuracy': 0.9248000025749207, 'consecutive overlap rate': 0.9998973056674003, 'overlap rate': 0.9999944865703583}
# evaluation performance: {'loss': 0.005352435470558703, 'abosulate accuracy': 0.9246000036597252, 'consecutive overlap rate': 0.9997660309076309, 'overlap rate': 0.9999249845743179}
#
# Current epoch: 60,
# training performance: {'loss': 0.0045783729874528944, 'abosulate accuracy': 0.9246000036597252, 'consecutive overlap rate': 0.9999308973550797, 'overlap rate': 0.9999828994274139}
# evaluation performance: {'loss': 0.004620578954927623, 'abosulate accuracy': 0.9246500045061111, 'consecutive overlap rate': 0.9997793897986412, 'overlap rate': 0.9999612182378769}
#
# Current epoch: 65,
# training performance: {'loss': 0.003122550464468077, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0034769384423270822, 'abosulate accuracy': 0.9247000023722649, 'consecutive overlap rate': 0.9998452126979828, 'overlap rate': 0.9999542981386185}
#
# Current epoch: 70,
# training performance: {'loss': 0.002494309050962329, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0029894073435571046, 'abosulate accuracy': 0.9245500043034554, 'consecutive overlap rate': 0.9998472332954407, 'overlap rate': 0.9999312430620193}
#
# Current epoch: 75,
# training performance: {'loss': 0.0020673567400081084, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.002672977329348214, 'abosulate accuracy': 0.9245000034570694, 'consecutive overlap rate': 0.9998590558767319, 'overlap rate': 0.999914088845253}
#
# Current epoch: 80,
# training performance: {'loss': 0.0017442337819375097, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0023981926089618353, 'abosulate accuracy': 0.9245000034570694, 'consecutive overlap rate': 0.9998590558767319, 'overlap rate': 0.9999149233102799}
#
# Current epoch: 85,
# training performance: {'loss': 0.0014887279859976843, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0021551045967498792, 'abosulate accuracy': 0.9245000034570694, 'consecutive overlap rate': 0.9998581930994987, 'overlap rate': 0.9999140635132789}
#
# Current epoch: 90,
# training performance: {'loss': 0.001281420441227965, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0020682454021880405, 'abosulate accuracy': 0.9243500038981438, 'consecutive overlap rate': 0.9998229429125786, 'overlap rate': 0.999897575378418}
#
# Current epoch: 95,
# training performance: {'loss': 0.0011102512071374804, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0021674182426068, 'abosulate accuracy': 0.9242500051856041, 'consecutive overlap rate': 0.9997810050845146, 'overlap rate': 0.9998651802539825}
#
# Current epoch: 100,
# training performance: {'loss': 0.0009670387880760245, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.002283258228271734, 'abosulate accuracy': 0.9240500077605247, 'consecutive overlap rate': 0.9997406274080276, 'overlap rate': 0.999831822514534}
#
# Experiments_Logs/Experiment#1/RNN/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.04089781967923045, 'abosulate accuracy': 0.8503000397235155, 'consecutive overlap rate': 0.9150295931845903, 'overlap rate': 0.9954221434891224}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.005844058329239487, 'abosulate accuracy': 0.9246250182390213, 'consecutive overlap rate': 0.9997724935412406, 'overlap rate': 0.9999461963772773}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.3049068287495644, 'abosulate accuracy': 0.40077804519284155, 'consecutive overlap rate': 0.7715007643545827, 'overlap rate': 0.9405369112568517}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.3618041216273253, 'abosulate accuracy': 0.6726052860459802, 'consecutive overlap rate': 0.9107076557059037, 'overlap rate': 0.9283500047106492}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.669222092628479, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02164779054000974, 'overlap rate': 0.23096787706017494}
# evaluation performance: {'loss': 2.7700987219810487, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024477775488048793, 'overlap rate': 0.1907905727624893}
#
# Current epoch: 10,
# training performance: {'loss': 1.8854635208845139, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.10418146047741175, 'overlap rate': 0.4772314757108688}
# evaluation performance: {'loss': 2.180365723371506, 'abosulate accuracy': 0.003200000146171078, 'consecutive overlap rate': 0.12082531191408634, 'overlap rate': 0.3602054711431265}
#
# Current epoch: 15,
# training performance: {'loss': 1.2494602262973786, 'abosulate accuracy': 0.07330000469228252, 'consecutive overlap rate': 0.4200441284105182, 'overlap rate': 0.709200131893158}
# evaluation performance: {'loss': 1.5369779452681542, 'abosulate accuracy': 0.08840000458294525, 'consecutive overlap rate': 0.4402573723345995, 'overlap rate': 0.6134279027581215}
#
# Current epoch: 20,
# training performance: {'loss': 1.0362577423453332, 'abosulate accuracy': 0.0763000033213757, 'consecutive overlap rate': 0.28045048248022797, 'overlap rate': 0.7564197450876236}
# evaluation performance: {'loss': 1.241138645261526, 'abosulate accuracy': 0.10635000455076807, 'consecutive overlap rate': 0.3019010920077562, 'overlap rate': 0.7153383500874042}
#
# Current epoch: 25,
# training performance: {'loss': 0.06683357413858175, 'abosulate accuracy': 0.8984000474214554, 'consecutive overlap rate': 0.9903893545269966, 'overlap rate': 0.9985107898712158}
# evaluation performance: {'loss': 0.0577091570943594, 'abosulate accuracy': 0.9057500422000885, 'consecutive overlap rate': 0.9942277729511261, 'overlap rate': 0.9980851978063583}
#
# Current epoch: 30,
# training performance: {'loss': 1.7171394109725953, 'abosulate accuracy': 0.01010000028181821, 'consecutive overlap rate': 0.2621236555278301, 'overlap rate': 0.5837290942668915}
# evaluation performance: {'loss': 1.2654974527657032, 'abosulate accuracy': 0.24650001328554935, 'consecutive overlap rate': 0.4547148019075394, 'overlap rate': 0.7383491598069668}
#
# Current epoch: 35,
# training performance: {'loss': 0.41048735231161115, 'abosulate accuracy': 0.4943000237923115, 'consecutive overlap rate': 0.7662953689694405, 'overlap rate': 0.9364435702562333}
# evaluation performance: {'loss': 0.2941690294072032, 'abosulate accuracy': 0.6269500237889588, 'consecutive overlap rate': 0.8611355312168598, 'overlap rate': 0.9590313762426377}
#
# Current epoch: 40,
# training performance: {'loss': 3.1324413120746613, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.037729900260455904, 'overlap rate': 0.12378494925796986}
# evaluation performance: {'loss': 3.1373954594135283, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.058106191689148545, 'overlap rate': 0.13128731790930032}
#
# Current epoch: 45,
# training performance: {'loss': 1.9709082394838333, 'abosulate accuracy': 0.01730000099632889, 'consecutive overlap rate': 0.2670647606253624, 'overlap rate': 0.4850970197468996}
# evaluation performance: {'loss': 2.049392879009247, 'abosulate accuracy': 0.07655000391532667, 'consecutive overlap rate': 0.3298907810822129, 'overlap rate': 0.47685870714485645}
#
# Current epoch: 50,
# training performance: {'loss': 3.233959811925888, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016248234326485544, 'overlap rate': 0.10163948312401772}
# evaluation performance: {'loss': 3.227611368894577, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.021433761168736964, 'overlap rate': 0.09413869008421898}
#
# Current epoch: 55,
# training performance: {'loss': 3.1103069961071013, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.039678188343532386, 'overlap rate': 0.13024502620100975}
# evaluation performance: {'loss': 3.1346858203411103, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.041183814266696574, 'overlap rate': 0.12008950114250183}
#
# Current epoch: 60,
# training performance: {'loss': 2.9328027725219727, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06787543781101704, 'overlap rate': 0.18238477893173694}
# evaluation performance: {'loss': 2.928650712966919, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08494785502552986, 'overlap rate': 0.1864982068538666}
#
# Current epoch: 65,
# training performance: {'loss': 2.274745933711529, 'abosulate accuracy': 0.0037000002223066984, 'consecutive overlap rate': 0.26125895567238333, 'overlap rate': 0.4110806152224541}
# evaluation performance: {'loss': 2.1730117380619047, 'abosulate accuracy': 0.01565000040573068, 'consecutive overlap rate': 0.29491536114364864, 'overlap rate': 0.4378384813666344}
#
# Current epoch: 70,
# training performance: {'loss': 0.807121855020523, 'abosulate accuracy': 0.32790001454995943, 'consecutive overlap rate': 0.5606181131675839, 'overlap rate': 0.8548210099339485}
# evaluation performance: {'loss': 0.8566829342395067, 'abosulate accuracy': 0.2827000134275295, 'consecutive overlap rate': 0.5683985218405724, 'overlap rate': 0.8372223004698753}
#
# Current epoch: 75,
# training performance: {'loss': 0.4854555416852236, 'abosulate accuracy': 0.5272000260883942, 'consecutive overlap rate': 0.770181980356574, 'overlap rate': 0.9326788499951363}
# evaluation performance: {'loss': 0.519855577684939, 'abosulate accuracy': 0.5279000254347921, 'consecutive overlap rate': 0.8085760898888111, 'overlap rate': 0.9266591295599937}
#
# Current epoch: 80,
# training performance: {'loss': 0.3142827064730227, 'abosulate accuracy': 0.6405000211554579, 'consecutive overlap rate': 0.7821976225823164, 'overlap rate': 0.9456669047474862}
# evaluation performance: {'loss': 0.2021470258012414, 'abosulate accuracy': 0.7774000287055969, 'consecutive overlap rate': 0.9502133071422577, 'overlap rate': 0.9784512832760811}
#
# Current epoch: 85,
# training performance: {'loss': 0.6826609641313552, 'abosulate accuracy': 0.4697000207845122, 'consecutive overlap rate': 0.8283789675682783, 'overlap rate': 0.8896656591445208}
# evaluation performance: {'loss': 3.1877486974000933, 'abosulate accuracy': 0.0006000000226777047, 'consecutive overlap rate': 0.28153236135840415, 'overlap rate': 0.34165334664285185}
#
# Current epoch: 90,
# training performance: {'loss': 0.0537369248457253, 'abosulate accuracy': 0.9177000194787979, 'consecutive overlap rate': 0.9975913599133491, 'overlap rate': 0.9996084824204445}
# evaluation performance: {'loss': 0.04503826634027064, 'abosulate accuracy': 0.9213500082492828, 'consecutive overlap rate': 0.998871922492981, 'overlap rate': 0.9998707219958305}
#
# Current epoch: 95,
# training performance: {'loss': 0.022089570690877736, 'abosulate accuracy': 0.9241000026464462, 'consecutive overlap rate': 0.9997751682996749, 'overlap rate': 0.9999807924032211}
# evaluation performance: {'loss': 0.021120670274831353, 'abosulate accuracy': 0.9242500066757202, 'consecutive overlap rate': 0.9997499361634254, 'overlap rate': 0.9999529033899307}
#
# Current epoch: 100,
# training performance: {'loss': 0.01395418206229806, 'abosulate accuracy': 0.9243000030517579, 'consecutive overlap rate': 0.9997968360781669, 'overlap rate': 0.9999841257929802}
# evaluation performance: {'loss': 0.014347508642822504, 'abosulate accuracy': 0.92430000603199, 'consecutive overlap rate': 0.9997208788990974, 'overlap rate': 0.9998763427138329}
#
# Experiments_Logs/Experiment#1/RNN/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.425262087583542, 'abosulate accuracy': 0.024700001082965172, 'consecutive overlap rate': 0.5979325048625469, 'overlap rate': 0.655922144278884}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.02668122686445713, 'abosulate accuracy': 0.9238500267267227, 'consecutive overlap rate': 0.9994789943099022, 'overlap rate': 0.9999533057212829}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.4385572571908276, 'abosulate accuracy': 0.0026641968577619524, 'consecutive overlap rate': 0.4601314950373865, 'overlap rate': 0.6435900895826279}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.15412340484755604, 'abosulate accuracy': 0.7027368633762786, 'consecutive overlap rate': 0.7840737386753684, 'overlap rate': 0.9763295289717222}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.515048545598984, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0287014355417341, 'overlap rate': 0.27768354341387746}
# evaluation performance: {'loss': 2.838812255859375, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.023431770876049994, 'overlap rate': 0.16764196939766407}
#
# Current epoch: 10,
# training performance: {'loss': 1.7607056766748428, 'abosulate accuracy': 0.0006000000284984708, 'consecutive overlap rate': 0.1080719793215394, 'overlap rate': 0.5044353127479553}
# evaluation performance: {'loss': 2.218183696269989, 'abosulate accuracy': 0.0010500000324100256, 'consecutive overlap rate': 0.10057971654459834, 'overlap rate': 0.34148858971893786}
#
# Current epoch: 15,
# training performance: {'loss': 1.2125300481915473, 'abosulate accuracy': 0.027600001299288125, 'consecutive overlap rate': 0.31413091607391835, 'overlap rate': 0.7069749400019646}
# evaluation performance: {'loss': 1.3609544083476066, 'abosulate accuracy': 0.03930000173277222, 'consecutive overlap rate': 0.39008005149662495, 'overlap rate': 0.6509189501404762}
#
# Current epoch: 20,
# training performance: {'loss': 0.8382840782403946, 'abosulate accuracy': 0.009800000535324215, 'consecutive overlap rate': 0.23513059727847577, 'overlap rate': 0.7899357050657272}
# evaluation performance: {'loss': 1.0700006559491158, 'abosulate accuracy': 0.09505000503268093, 'consecutive overlap rate': 0.34835644960403445, 'overlap rate': 0.7097250685095787}
#
# Current epoch: 25,
# training performance: {'loss': 0.08308633510023355, 'abosulate accuracy': 0.8315000385046005, 'consecutive overlap rate': 0.9527610138058662, 'overlap rate': 0.9960658416152001}
# evaluation performance: {'loss': 0.08843201175332069, 'abosulate accuracy': 0.8405500382184983, 'consecutive overlap rate': 0.9627043262124062, 'overlap rate': 0.9913163557648659}
#
# Current epoch: 30,
# training performance: {'loss': 0.03251260756514966, 'abosulate accuracy': 0.9083000376820565, 'consecutive overlap rate': 0.9923895075917244, 'overlap rate': 0.9993551820516586}
# evaluation performance: {'loss': 0.033374287839978936, 'abosulate accuracy': 0.9101000398397445, 'consecutive overlap rate': 0.9936077043414115, 'overlap rate': 0.9985412865877151}
#
# Current epoch: 35,
# training performance: {'loss': 0.23511200868524612, 'abosulate accuracy': 0.7093000234104693, 'consecutive overlap rate': 0.9099927507340908, 'overlap rate': 0.9562160938978195}
# evaluation performance: {'loss': 0.5394074497744441, 'abosulate accuracy': 0.5274500276893377, 'consecutive overlap rate': 0.858984787762165, 'overlap rate': 0.9081440150737763}
#
# Current epoch: 40,
# training performance: {'loss': 0.013662619004026055, 'abosulate accuracy': 0.9239000141620636, 'consecutive overlap rate': 0.9993902266025543, 'overlap rate': 0.999914962053299}
# evaluation performance: {'loss': 0.01325529117602855, 'abosulate accuracy': 0.9238000109791755, 'consecutive overlap rate': 0.999110659956932, 'overlap rate': 0.9998618170619011}
#
# Current epoch: 45,
# training performance: {'loss': 0.02173907863907516, 'abosulate accuracy': 0.9135000228881835, 'consecutive overlap rate': 0.9963482916355133, 'overlap rate': 0.9982882902026177}
# evaluation performance: {'loss': 0.022111576190218328, 'abosulate accuracy': 0.9182000160217285, 'consecutive overlap rate': 0.995610062777996, 'overlap rate': 0.9986032128334046}
#
# Current epoch: 50,
# training performance: {'loss': 2.102798446128145, 'abosulate accuracy': 0.4864000195637345, 'consecutive overlap rate': 0.535692852200009, 'overlap rate': 0.5808329550549388}
# evaluation performance: {'loss': 3.5985976576805117, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05602128771133721, 'overlap rate': 0.1495281348004937}
#
# Current epoch: 55,
# training performance: {'loss': 1.4767579156905413, 'abosulate accuracy': 0.41990002267993987, 'consecutive overlap rate': 0.5742967821657657, 'overlap rate': 0.661873959377408}
# evaluation performance: {'loss': 1.9257036924362183, 'abosulate accuracy': 0.03635000164504163, 'consecutive overlap rate': 0.4073024202138186, 'overlap rate': 0.5417640700936317}
#
# Current epoch: 60,
# training performance: {'loss': 1.0147639594972133, 'abosulate accuracy': 0.28510001343674957, 'consecutive overlap rate': 0.6186134748160839, 'overlap rate': 0.754261215031147}
# evaluation performance: {'loss': 1.1514230087399482, 'abosulate accuracy': 0.2168000083998777, 'consecutive overlap rate': 0.5193573102355004, 'overlap rate': 0.7362711280584335}
#
# Current epoch: 65,
# training performance: {'loss': 0.10670789154246449, 'abosulate accuracy': 0.8718000367283821, 'consecutive overlap rate': 0.9645984023809433, 'overlap rate': 0.995949313044548}
# evaluation performance: {'loss': 0.057965227589011195, 'abosulate accuracy': 0.9140000313520431, 'consecutive overlap rate': 0.9943338558077812, 'overlap rate': 0.9983814299106598}
#
# Current epoch: 70,
# training performance: {'loss': 0.017379846633411945, 'abosulate accuracy': 0.9239000082015991, 'consecutive overlap rate': 0.9994659662246704, 'overlap rate': 0.9998146548867226}
# evaluation performance: {'loss': 0.014675641199573874, 'abosulate accuracy': 0.924350006878376, 'consecutive overlap rate': 0.9997667655348778, 'overlap rate': 0.9999654337763786}
#
# Current epoch: 75,
# training performance: {'loss': 0.00940666439710185, 'abosulate accuracy': 0.9237000092864036, 'consecutive overlap rate': 0.9995497941970826, 'overlap rate': 0.9998695358633996}
# evaluation performance: {'loss': 0.00930696480209008, 'abosulate accuracy': 0.9240500077605247, 'consecutive overlap rate': 0.9996987268328666, 'overlap rate': 0.999851830303669}
#
# Current epoch: 80,
# training performance: {'loss': 0.005674865865148604, 'abosulate accuracy': 0.9237000092864036, 'consecutive overlap rate': 0.9994678005576134, 'overlap rate': 0.9999686628580093}
# evaluation performance: {'loss': 0.007906706724315881, 'abosulate accuracy': 0.9229000091552735, 'consecutive overlap rate': 0.9992548674345016, 'overlap rate': 0.9996475905179978}
#
# Current epoch: 85,
# training performance: {'loss': 0.00424825717927888, 'abosulate accuracy': 0.9239000082015991, 'consecutive overlap rate': 0.9995499923825264, 'overlap rate': 0.999973751604557}
# evaluation performance: {'loss': 0.007343844114802778, 'abosulate accuracy': 0.9222500115633011, 'consecutive overlap rate': 0.9989046454429626, 'overlap rate': 0.9995459020137787}
#
# Current epoch: 90,
# training performance: {'loss': 0.003353197069372982, 'abosulate accuracy': 0.9239000082015991, 'consecutive overlap rate': 0.999562668800354, 'overlap rate': 0.999976159632206}
# evaluation performance: {'loss': 0.006916314864065498, 'abosulate accuracy': 0.9222000136971473, 'consecutive overlap rate': 0.9988936007022857, 'overlap rate': 0.9995017617940902}
#
# Current epoch: 95,
# training performance: {'loss': 0.0027281950518954546, 'abosulate accuracy': 0.92430000603199, 'consecutive overlap rate': 0.9997797384858131, 'overlap rate': 0.9999853178858757}
# evaluation performance: {'loss': 0.006456583103863522, 'abosulate accuracy': 0.9220000132918358, 'consecutive overlap rate': 0.9988609984517097, 'overlap rate': 0.9994776114821434}
#
# Current epoch: 100,
# training performance: {'loss': 0.0022645316174020992, 'abosulate accuracy': 0.9244000047445298, 'consecutive overlap rate': 0.9998414054512977, 'overlap rate': 0.999986982345581}
# evaluation performance: {'loss': 0.005332099122460932, 'abosulate accuracy': 0.9219500109553337, 'consecutive overlap rate': 0.9988027840852738, 'overlap rate': 0.999562007188797}
#
# Experiments_Logs/Experiment#1/RNN/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/RNN/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.12069087023846806, 'abosulate accuracy': 0.7350000321865082, 'consecutive overlap rate': 0.9125141765922308, 'overlap rate': 0.9856092233210803}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.014988648984581233, 'abosulate accuracy': 0.9243000254034996, 'consecutive overlap rate': 0.9997370392084122, 'overlap rate': 0.9999358639121055}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.30716293521465793, 'abosulate accuracy': 0.4558612798490832, 'consecutive overlap rate': 0.7814836340565835, 'overlap rate': 0.9459815679057952}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.08239592847071196, 'abosulate accuracy': 0.8650526608291426, 'consecutive overlap rate': 0.977032272439254, 'overlap rate': 0.9882768235708538}
# Experiments_Logs/Experiment#1/RNN/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#1 with RNN seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#1/RNN/hyperparameters.json saved!
