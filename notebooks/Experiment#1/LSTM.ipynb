# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 128
embd_dim = 64
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = True
use_attention = True
reduction_method = torch.sum

learning_rate = 1e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 1
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#1/LSTM created!
# ./Experiments_Logs/Experiment#1/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#1/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#1/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

for lang in ["RevStr", "RedStr"]:
    print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
    print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#1 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.5234726309776305, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01416235666256398, 'overlap rate': 0.2676970325410366}
# evaluation performance: {'loss': 2.6818669557571413, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020451305236201735, 'overlap rate': 0.20003770869225262}
#
# Current epoch: 10,
# training performance: {'loss': 1.2985113978385925, 'abosulate accuracy': 0.0034000001032836735, 'consecutive overlap rate': 0.14205337651073932, 'overlap rate': 0.6728209167718887}
# evaluation performance: {'loss': 2.7234711915254595, 'abosulate accuracy': 0.0011500000488013028, 'consecutive overlap rate': 0.12599068526178597, 'overlap rate': 0.26117848716676234}
#
# Current epoch: 15,
# training performance: {'loss': 1.472710281610489, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.12561716977506876, 'overlap rate': 0.6013046041131019}
# evaluation performance: {'loss': 2.407507386803627, 'abosulate accuracy': 0.022450000984827058, 'consecutive overlap rate': 0.20492251608520745, 'overlap rate': 0.40569254085421563}
#
# Current epoch: 20,
# training performance: {'loss': 0.48165253475308417, 'abosulate accuracy': 0.2756000116816722, 'consecutive overlap rate': 0.5272719919681549, 'overlap rate': 0.903759628534317}
# evaluation performance: {'loss': 2.684575778245926, 'abosulate accuracy': 0.0989000050467439, 'consecutive overlap rate': 0.2724636230617762, 'overlap rate': 0.44290736988186835}
#
# Current epoch: 25,
# training performance: {'loss': 0.3217957090586424, 'abosulate accuracy': 0.23670001104474067, 'consecutive overlap rate': 0.5534038119018078, 'overlap rate': 0.9337403118610382}
# evaluation performance: {'loss': 1.3176747180521489, 'abosulate accuracy': 0.23290001165587454, 'consecutive overlap rate': 0.6223324961960316, 'overlap rate': 0.7450179040431977}
#
# Current epoch: 30,
# training performance: {'loss': 2.805266332626343, 'abosulate accuracy': 0.0010000000358559192, 'consecutive overlap rate': 0.1171069205738604, 'overlap rate': 0.49100708588957787}
# evaluation performance: {'loss': 3.6543275833129885, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07674175286665559, 'overlap rate': 0.159059320949018}
#
# Current epoch: 35,
# training performance: {'loss': 1.3224292501807213, 'abosulate accuracy': 0.02410000067902729, 'consecutive overlap rate': 0.21256818613037468, 'overlap rate': 0.6638470321893692}
# evaluation performance: {'loss': 2.8328333139419555, 'abosulate accuracy': 0.0176500006520655, 'consecutive overlap rate': 0.15377474743872882, 'overlap rate': 0.34234389513731}
#
# Current epoch: 40,
# training performance: {'loss': 1.740440419316292, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.09617986297234893, 'overlap rate': 0.5420226477086544}
# evaluation performance: {'loss': 2.643145340681076, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.16033968403935434, 'overlap rate': 0.3386953130364418}
#
# Current epoch: 45,
# training performance: {'loss': 0.24692565239965916, 'abosulate accuracy': 0.3558000155724585, 'consecutive overlap rate': 0.6532171458005905, 'overlap rate': 0.9576582387089729}
# evaluation performance: {'loss': 0.6710788093507289, 'abosulate accuracy': 0.5113500212319195, 'consecutive overlap rate': 0.7736438654363156, 'overlap rate': 0.8819103583693504}
#
# Current epoch: 50,
# training performance: {'loss': 1.8477878004312516, 'abosulate accuracy': 0.0023000001325272023, 'consecutive overlap rate': 0.18992713880725204, 'overlap rate': 0.5005622692406178}
# evaluation performance: {'loss': 2.652305868268013, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.28507121875882147, 'overlap rate': 0.3655778557062149}
#
# Current epoch: 55,
# training performance: {'loss': 0.5117906257510185, 'abosulate accuracy': 0.04850000225706026, 'consecutive overlap rate': 0.3087773736566305, 'overlap rate': 0.8704526752233506}
# evaluation performance: {'loss': 3.523787832260132, 'abosulate accuracy': 0.01605000060517341, 'consecutive overlap rate': 0.28511040434241297, 'overlap rate': 0.40967897325754166}
#
# Current epoch: 60,
# training performance: {'loss': 0.49188927486538886, 'abosulate accuracy': 0.21140000883024185, 'consecutive overlap rate': 0.4889046723023057, 'overlap rate': 0.8903849676251412}
# evaluation performance: {'loss': 3.8516377970576285, 'abosulate accuracy': 0.06120000306400471, 'consecutive overlap rate': 0.24561372268944978, 'overlap rate': 0.31888524256646633}
#
# Current epoch: 65,
# training performance: {'loss': 0.27162380814552306, 'abosulate accuracy': 0.2908000141615048, 'consecutive overlap rate': 0.5546420153230429, 'overlap rate': 0.9449200630187988}
# evaluation performance: {'loss': 3.584121897816658, 'abosulate accuracy': 0.15230000630253926, 'consecutive overlap rate': 0.37300341222435235, 'overlap rate': 0.4554038390517235}
#
# Current epoch: 70,
# training performance: {'loss': 0.11072178725153208, 'abosulate accuracy': 0.6479000333696604, 'consecutive overlap rate': 0.850340735912323, 'overlap rate': 0.9895714744925499}
# evaluation performance: {'loss': 0.3998226275667548, 'abosulate accuracy': 0.7003000319004059, 'consecutive overlap rate': 0.8803604781627655, 'overlap rate': 0.939004409313202}
#
# Current epoch: 75,
# training performance: {'loss': 0.05863402746617794, 'abosulate accuracy': 0.7895000383257866, 'consecutive overlap rate': 0.9296604663133621, 'overlap rate': 0.995832522213459}
# evaluation performance: {'loss': 0.23468591440469028, 'abosulate accuracy': 0.7816000416874885, 'consecutive overlap rate': 0.9323192134499549, 'overlap rate': 0.9681627944111824}
#
# Current epoch: 80,
# training performance: {'loss': 0.03676419141702354, 'abosulate accuracy': 0.858400036394596, 'consecutive overlap rate': 0.9665143847465515, 'overlap rate': 0.9982620194554329}
# evaluation performance: {'loss': 0.14533289251849055, 'abosulate accuracy': 0.8359000355005264, 'consecutive overlap rate': 0.9573263585567474, 'overlap rate': 0.9820885121822357}
#
# Current epoch: 85,
# training performance: {'loss': 0.024977763392962517, 'abosulate accuracy': 0.8883000314235687, 'consecutive overlap rate': 0.982808132469654, 'overlap rate': 0.9991061970591545}
# evaluation performance: {'loss': 0.09542036154307425, 'abosulate accuracy': 0.8707500413060189, 'consecutive overlap rate': 0.974393005669117, 'overlap rate': 0.989053362607956}
#
# Current epoch: 90,
# training performance: {'loss': 0.018701223353855313, 'abosulate accuracy': 0.8997000277042388, 'consecutive overlap rate': 0.9882418468594552, 'overlap rate': 0.9994233131408692}
# evaluation performance: {'loss': 0.07504129414446652, 'abosulate accuracy': 0.8820000410079956, 'consecutive overlap rate': 0.9808903589844704, 'overlap rate': 0.9916256874799728}
#
# Current epoch: 95,
# training performance: {'loss': 0.014492118312045933, 'abosulate accuracy': 0.9099000185728073, 'consecutive overlap rate': 0.993370720744133, 'overlap rate': 0.9996636539697648}
# evaluation performance: {'loss': 0.057623126753605904, 'abosulate accuracy': 0.8911500409245491, 'consecutive overlap rate': 0.9857008382678032, 'overlap rate': 0.9938261896371842}
#
# Current epoch: 100,
# training performance: {'loss': 0.011515384737867862, 'abosulate accuracy': 0.914200022816658, 'consecutive overlap rate': 0.995805686712265, 'overlap rate': 0.9997769266366958}
# evaluation performance: {'loss': 0.04643944601994008, 'abosulate accuracy': 0.8978000387549401, 'consecutive overlap rate': 0.9888429820537568, 'overlap rate': 0.9951896116137504}
#
# Experiments_Logs/Experiment#1/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 5.2205529540777205, 'abosulate accuracy': 0.023400001029949637, 'consecutive overlap rate': 0.04036131389439106, 'overlap rate': 0.37669335547834637}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.04371886816807091, 'abosulate accuracy': 0.8991000458598137, 'consecutive overlap rate': 0.9889303222298622, 'overlap rate': 0.9955275878310204}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.278444757769185, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028693192650473886, 'overlap rate': 0.26651316871566155}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.7137778500144026, 'abosulate accuracy': 0.5765789725394969, 'consecutive overlap rate': 0.871970429232246, 'overlap rate': 0.9093445492418188}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.6827441275119783, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01280330668669194, 'overlap rate': 0.2075315248221159}
# evaluation performance: {'loss': 2.889911437034607, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01596067222999409, 'overlap rate': 0.14803485590964555}
#
# Current epoch: 10,
# training performance: {'loss': 1.8568367540836335, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.07570414007641375, 'overlap rate': 0.5128425855189562}
# evaluation performance: {'loss': 2.5708516955375673, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.08586882632225752, 'overlap rate': 0.2630528537556529}
#
# Current epoch: 15,
# training performance: {'loss': 2.0696678310632706, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.10003026818158105, 'overlap rate': 0.4520879385061562}
# evaluation performance: {'loss': 3.2816923797130584, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02242805453715846, 'overlap rate': 0.07750444673001766}
#
# Current epoch: 20,
# training performance: {'loss': 1.7605406761169433, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.09629258969798685, 'overlap rate': 0.4612246356904507}
# evaluation performance: {'loss': 3.3747103095054625, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.051919642556458714, 'overlap rate': 0.14294957853853701}
#
# Current epoch: 25,
# training performance: {'loss': 0.9935939744114876, 'abosulate accuracy': 0.002700000139884651, 'consecutive overlap rate': 0.14390683732926846, 'overlap rate': 0.697321704775095}
# evaluation performance: {'loss': 2.2599805653095246, 'abosulate accuracy': 0.0006500000250525773, 'consecutive overlap rate': 0.2135310634970665, 'overlap rate': 0.39556328728795054}
#
# Current epoch: 30,
# training performance: {'loss': 0.46894973441958426, 'abosulate accuracy': 0.13440000617410988, 'consecutive overlap rate': 0.4080429198220372, 'overlap rate': 0.8850084409117699}
# evaluation performance: {'loss': 1.5175236135721206, 'abosulate accuracy': 0.11305000406573526, 'consecutive overlap rate': 0.4735617369413376, 'overlap rate': 0.6598503805696965}
#
# Current epoch: 35,
# training performance: {'loss': 2.477089785039425, 'abosulate accuracy': 0.0006000000052154064, 'consecutive overlap rate': 0.09586238153278828, 'overlap rate': 0.38976031094789504}
# evaluation performance: {'loss': 3.5417896270751954, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04941310426220298, 'overlap rate': 0.11924025304615497}
#
# Current epoch: 40,
# training performance: {'loss': 1.464829409122467, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1291270148009062, 'overlap rate': 0.5937676727771759}
# evaluation performance: {'loss': 3.3062476933002474, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.13200451051816345, 'overlap rate': 0.23276077285408975}
#
# Current epoch: 45,
# training performance: {'loss': 0.42834096401929855, 'abosulate accuracy': 0.1629000091110356, 'consecutive overlap rate': 0.4170382831245661, 'overlap rate': 0.9040287241339684}
# evaluation performance: {'loss': 1.7206565007567405, 'abosulate accuracy': 0.11175000467919745, 'consecutive overlap rate': 0.4251996796578169, 'overlap rate': 0.6287566967308521}
#
# Current epoch: 50,
# training performance: {'loss': 0.19603624623268842, 'abosulate accuracy': 0.4313000183319673, 'consecutive overlap rate': 0.6650933191180229, 'overlap rate': 0.9675760775804519}
# evaluation performance: {'loss': 0.6700511388480663, 'abosulate accuracy': 0.4756500231800601, 'consecutive overlap rate': 0.7262989953160286, 'overlap rate': 0.8761253371834755}
#
# Current epoch: 55,
# training performance: {'loss': 2.494962453842163, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.030453041149303316, 'overlap rate': 0.2976205673068762}
# evaluation performance: {'loss': 2.9954659402370454, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03536031348630786, 'overlap rate': 0.18820118606090547}
#
# Current epoch: 60,
# training performance: {'loss': 0.6727884419262409, 'abosulate accuracy': 0.05100000197999179, 'consecutive overlap rate': 0.34139373525977135, 'overlap rate': 0.8180499330163002}
# evaluation performance: {'loss': 2.1078507259488104, 'abosulate accuracy': 0.08265000469400548, 'consecutive overlap rate': 0.3278651338070631, 'overlap rate': 0.5466640010476113}
#
# Current epoch: 65,
# training performance: {'loss': 0.23337800465524197, 'abosulate accuracy': 0.3235000152606517, 'consecutive overlap rate': 0.6270969927310943, 'overlap rate': 0.9570414468646049}
# evaluation performance: {'loss': 1.130702728778124, 'abosulate accuracy': 0.27385001378133894, 'consecutive overlap rate': 0.5865761026740074, 'overlap rate': 0.7851225107908248}
#
# Current epoch: 70,
# training performance: {'loss': 0.10411926647648215, 'abosulate accuracy': 0.613700034096837, 'consecutive overlap rate': 0.8465496495366096, 'overlap rate': 0.9869934245944023}
# evaluation performance: {'loss': 0.3634606072679162, 'abosulate accuracy': 0.6482500292360782, 'consecutive overlap rate': 0.8545531645417214, 'overlap rate': 0.9427897721529007}
#
# Current epoch: 75,
# training performance: {'loss': 0.057849435368552804, 'abosulate accuracy': 0.7562000341713428, 'consecutive overlap rate': 0.9255690410733223, 'overlap rate': 0.994763332605362}
# evaluation performance: {'loss': 0.2409591084346175, 'abosulate accuracy': 0.7494500339031219, 'consecutive overlap rate': 0.9081731632351875, 'overlap rate': 0.9657982364296913}
#
# Current epoch: 80,
# training performance: {'loss': 0.04289116011932492, 'abosulate accuracy': 0.7918000355362892, 'consecutive overlap rate': 0.9360394090414047, 'overlap rate': 0.9959078058600426}
# evaluation performance: {'loss': 0.20346269733272493, 'abosulate accuracy': 0.7480000361800194, 'consecutive overlap rate': 0.9332042008638382, 'overlap rate': 0.9715680450201034}
#
# Current epoch: 85,
# training performance: {'loss': 0.02931621023453772, 'abosulate accuracy': 0.8623000353574752, 'consecutive overlap rate': 0.9763260737061501, 'overlap rate': 0.9981849804520607}
# evaluation performance: {'loss': 0.20748434497509152, 'abosulate accuracy': 0.7596000343561172, 'consecutive overlap rate': 0.9331144824624061, 'overlap rate': 0.972968827188015}
#
# Current epoch: 90,
# training performance: {'loss': 0.021310294535942374, 'abosulate accuracy': 0.8891000330448151, 'consecutive overlap rate': 0.9861012741923332, 'overlap rate': 0.9989541590213775}
# evaluation performance: {'loss': 0.08088739085942506, 'abosulate accuracy': 0.8512500390410424, 'consecutive overlap rate': 0.9720281839370728, 'overlap rate': 0.9905382111668587}
#
# Current epoch: 95,
# training performance: {'loss': 0.01675468774046749, 'abosulate accuracy': 0.9017000332474708, 'consecutive overlap rate': 0.9914888083934784, 'overlap rate': 0.9993325918912888}
# evaluation performance: {'loss': 0.06185882387217134, 'abosulate accuracy': 0.8655500367283822, 'consecutive overlap rate': 0.9808113098144531, 'overlap rate': 0.9928754344582558}
#
# Current epoch: 100,
# training performance: {'loss': 0.013485900347586722, 'abosulate accuracy': 0.9092000260949135, 'consecutive overlap rate': 0.9942049458622932, 'overlap rate': 0.9995557174086571}
# evaluation performance: {'loss': 0.05404734616167843, 'abosulate accuracy': 0.8748500317335128, 'consecutive overlap rate': 0.9845591440796853, 'overlap rate': 0.9938547536730766}
#
# Experiments_Logs/Experiment#1/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 5.821575939655304, 'abosulate accuracy': 0.019900000808411276, 'consecutive overlap rate': 0.026680000295164062, 'overlap rate': 0.20638252142816782}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.05286882140208036, 'abosulate accuracy': 0.8759500399231911, 'consecutive overlap rate': 0.9842515662312508, 'overlap rate': 0.9940751031041145}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.992379760742187, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018908974260932975, 'overlap rate': 0.20180433382911067}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.6072744362448391, 'abosulate accuracy': 0.49947370224215676, 'consecutive overlap rate': 0.8728068204302537, 'overlap rate': 0.9059589693420812}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.605696904659271, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012327460979577154, 'overlap rate': 0.23751653134822845}
# evaluation performance: {'loss': 2.856446439027786, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016456502524670215, 'overlap rate': 0.1634720630943775}
#
# Current epoch: 10,
# training performance: {'loss': 1.409612014889717, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.07203500964678825, 'overlap rate': 0.591869306564331}
# evaluation performance: {'loss': 2.998345896601677, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.0856495026499033, 'overlap rate': 0.22794358246028423}
#
# Current epoch: 15,
# training performance: {'loss': 0.9811555132269859, 'abosulate accuracy': 0.012200000509619714, 'consecutive overlap rate': 0.21259208163246512, 'overlap rate': 0.7441359028220177}
# evaluation performance: {'loss': 2.3198183983564378, 'abosulate accuracy': 0.03470000179368071, 'consecutive overlap rate': 0.26425159238278867, 'overlap rate': 0.43991296663880347}
#
# Current epoch: 20,
# training performance: {'loss': 0.6815150782465935, 'abosulate accuracy': 0.026300001330673693, 'consecutive overlap rate': 0.3008228238672018, 'overlap rate': 0.8360540270805359}
# evaluation performance: {'loss': 2.324127897620201, 'abosulate accuracy': 0.10200000629993156, 'consecutive overlap rate': 0.38142428919672966, 'overlap rate': 0.5086848765611649}
#
# Current epoch: 25,
# training performance: {'loss': 0.5476015876978636, 'abosulate accuracy': 0.20840000974712894, 'consecutive overlap rate': 0.4659291755408049, 'overlap rate': 0.8783473134040832}
# evaluation performance: {'loss': 2.3232796281576156, 'abosulate accuracy': 0.0808500036073383, 'consecutive overlap rate': 0.31875146105885505, 'overlap rate': 0.5405665300786495}
#
# Current epoch: 30,
# training performance: {'loss': 0.08098241360858083, 'abosulate accuracy': 0.764200036227703, 'consecutive overlap rate': 0.9130880475044251, 'overlap rate': 0.9947070851922035}
# evaluation performance: {'loss': 0.3990263851359487, 'abosulate accuracy': 0.7295000359416008, 'consecutive overlap rate': 0.8813154220581054, 'overlap rate': 0.9434752762317657}
#
# Current epoch: 35,
# training performance: {'loss': 0.039965581009164454, 'abosulate accuracy': 0.8555000320076942, 'consecutive overlap rate': 0.9629364356398582, 'overlap rate': 0.9980688408017159}
# evaluation performance: {'loss': 0.13002700549550356, 'abosulate accuracy': 0.8525500372052193, 'consecutive overlap rate': 0.9670675560832024, 'overlap rate': 0.9840265080332756}
#
# Current epoch: 40,
# training performance: {'loss': 2.855474907159805, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04508591713383794, 'overlap rate': 0.23210856802761554}
# evaluation performance: {'loss': 2.9425575494766236, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.09125682981684805, 'overlap rate': 0.22625270672142506}
#
# Current epoch: 45,
# training performance: {'loss': 2.13999420106411, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.12391736879944801, 'overlap rate': 0.43152038380503654}
# evaluation performance: {'loss': 2.518388772010803, 'abosulate accuracy': 0.0007000000216066838, 'consecutive overlap rate': 0.19254675451666117, 'overlap rate': 0.3498902514576912}
#
# Current epoch: 50,
# training performance: {'loss': 0.6677662998437881, 'abosulate accuracy': 0.0761000030557625, 'consecutive overlap rate': 0.4066985722631216, 'overlap rate': 0.8398481577634811}
# evaluation performance: {'loss': 4.237446069717407, 'abosulate accuracy': 0.05615000255056657, 'consecutive overlap rate': 0.1747078297659755, 'overlap rate': 0.24826452545821667}
#
# Current epoch: 55,
# training performance: {'loss': 0.4191141799092293, 'abosulate accuracy': 0.18890000976389273, 'consecutive overlap rate': 0.5102293573319912, 'overlap rate': 0.9115421563386917}
# evaluation performance: {'loss': 1.6422694638371467, 'abosulate accuracy': 0.2179000105592422, 'consecutive overlap rate': 0.5487290650606156, 'overlap rate': 0.6842590749263764}
#
# Current epoch: 60,
# training performance: {'loss': 0.7131243215873837, 'abosulate accuracy': 0.44050002270378175, 'consecutive overlap rate': 0.6054089747369289, 'overlap rate': 0.8648996464908123}
# evaluation performance: {'loss': 4.1811245530843735, 'abosulate accuracy': 0.010750000254483893, 'consecutive overlap rate': 0.1976754605770111, 'overlap rate': 0.29239220172166824}
#
# Current epoch: 65,
# training performance: {'loss': 2.8710962265729902, 'abosulate accuracy': 0.004000000294763595, 'consecutive overlap rate': 0.11320286612026394, 'overlap rate': 0.3582105539739132}
# evaluation performance: {'loss': 3.363659197092056, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07830393286421895, 'overlap rate': 0.16720385812222957}
#
# Current epoch: 70,
# training performance: {'loss': 0.9257383976131678, 'abosulate accuracy': 0.1980000097420998, 'consecutive overlap rate': 0.43934807693585753, 'overlap rate': 0.8372017906978726}
# evaluation performance: {'loss': 5.132765823602677, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.14380769561976195, 'overlap rate': 0.16737064998596907}
#
# Current epoch: 75,
# training performance: {'loss': 1.3312749192118645, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.17544601764529943, 'overlap rate': 0.6859661534428596}
# evaluation performance: {'loss': 3.3854786574840547, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1761818125844002, 'overlap rate': 0.2850551676005125}
#
# Current epoch: 80,
# training performance: {'loss': 0.35221851877868177, 'abosulate accuracy': 0.24610001142136753, 'consecutive overlap rate': 0.5045470794662833, 'overlap rate': 0.9319798275828362}
# evaluation performance: {'loss': 2.1224330604076385, 'abosulate accuracy': 0.10520000421092845, 'consecutive overlap rate': 0.43895025439560414, 'overlap rate': 0.597924105077982}
#
# Current epoch: 85,
# training performance: {'loss': 0.979278352856636, 'abosulate accuracy': 0.006200000224635005, 'consecutive overlap rate': 0.2411504562944174, 'overlap rate': 0.7642410174012184}
# evaluation performance: {'loss': 2.954668915271759, 'abosulate accuracy': 0.018450000940356405, 'consecutive overlap rate': 0.26915631629526615, 'overlap rate': 0.4011621169745922}
#
# Current epoch: 90,
# training performance: {'loss': 0.10055757407099009, 'abosulate accuracy': 0.6284000325948, 'consecutive overlap rate': 0.8219283252954483, 'overlap rate': 0.9881895110011101}
# evaluation performance: {'loss': 0.5368729246780276, 'abosulate accuracy': 0.6600000318139791, 'consecutive overlap rate': 0.8509749248623848, 'overlap rate': 0.9057695478200912}
#
# Current epoch: 95,
# training performance: {'loss': 0.05690279491245746, 'abosulate accuracy': 0.7562000319361687, 'consecutive overlap rate': 0.9029058262705802, 'overlap rate': 0.9945470958948135}
# evaluation performance: {'loss': 0.3389174407348037, 'abosulate accuracy': 0.7555000342428684, 'consecutive overlap rate': 0.908542937040329, 'overlap rate': 0.9508310854434967}
#
# Current epoch: 100,
# training performance: {'loss': 0.03740405603311956, 'abosulate accuracy': 0.8247000321745872, 'consecutive overlap rate': 0.9475117310881614, 'overlap rate': 0.997085727751255}
# evaluation performance: {'loss': 0.21474980032071472, 'abosulate accuracy': 0.7994000345468522, 'consecutive overlap rate': 0.9407442152500153, 'overlap rate': 0.9706877693533897}
#
# Experiments_Logs/Experiment#1/LSTM/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.817602130770683, 'abosulate accuracy': 0.01677500066580251, 'consecutive overlap rate': 0.026731666884734294, 'overlap rate': 0.3845208713784814}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.1206865561194718, 'abosulate accuracy': 0.8579750403761863, 'consecutive overlap rate': 0.9629991382360459, 'overlap rate': 0.9858297690749168}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.191294134816816, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010374410483505457, 'overlap rate': 0.28406011366075085}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.5332502721759833, 'abosulate accuracy': 0.4576316004631257, 'consecutive overlap rate': 0.6960475829086805, 'overlap rate': 0.7806504188399566}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ...experiment#1 with LSTM seq2seq ends.
# Start experiment#1 with LSTM seq2seq...
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.592995136976242, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013644961104728282, 'overlap rate': 0.23569835666567088}
# evaluation performance: {'loss': 2.9538091242313387, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.019054848863743246, 'overlap rate': 0.1381691513583064}
#
# Current epoch: 10,
# training performance: {'loss': 2.4124343246221542, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03201109354849905, 'overlap rate': 0.28952016308903694}
# evaluation performance: {'loss': 2.7210304379463195, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.02779977989848703, 'overlap rate': 0.19276763796806334}
#
# Current epoch: 15,
# training performance: {'loss': 1.4228899970650672, 'abosulate accuracy': 0.0007000000216066838, 'consecutive overlap rate': 0.1459489026106894, 'overlap rate': 0.6327464483678341}
# evaluation performance: {'loss': 2.2626081109046936, 'abosulate accuracy': 0.03055000111926347, 'consecutive overlap rate': 0.25785196125507354, 'overlap rate': 0.41667076870799064}
#
# Current epoch: 20,
# training performance: {'loss': 0.9114975832402706, 'abosulate accuracy': 0.19680000878870488, 'consecutive overlap rate': 0.43848616946488617, 'overlap rate': 0.8054266668856144}
# evaluation performance: {'loss': 2.329368048906326, 'abosulate accuracy': 0.05330000190879218, 'consecutive overlap rate': 0.3217157682403922, 'overlap rate': 0.4833701394498348}
#
# Current epoch: 25,
# training performance: {'loss': 0.3703608848154545, 'abosulate accuracy': 0.1741000077337958, 'consecutive overlap rate': 0.49468391835689546, 'overlap rate': 0.9219974845647811}
# evaluation performance: {'loss': 1.0731043502688409, 'abosulate accuracy': 0.18755000978708267, 'consecutive overlap rate': 0.6263601653277874, 'overlap rate': 0.7776739552617074}
#
# Current epoch: 30,
# training performance: {'loss': 0.07924846494570374, 'abosulate accuracy': 0.7745000340044499, 'consecutive overlap rate': 0.93037329018116, 'overlap rate': 0.9952986121177674}
# evaluation performance: {'loss': 0.2006009232252836, 'abosulate accuracy': 0.7551500372588634, 'consecutive overlap rate': 0.9330566480755806, 'overlap rate': 0.9739493891596794}
#
# Current epoch: 35,
# training performance: {'loss': 0.04189031785354018, 'abosulate accuracy': 0.8666000306606293, 'consecutive overlap rate': 0.9725575834512711, 'overlap rate': 0.9984598934650422}
# evaluation performance: {'loss': 0.10094301914796233, 'abosulate accuracy': 0.8395000398159027, 'consecutive overlap rate': 0.9680175021290779, 'overlap rate': 0.9890181645751}
#
# Current epoch: 40,
# training performance: {'loss': 0.02725461989175528, 'abosulate accuracy': 0.8918000221252441, 'consecutive overlap rate': 0.9841159760951996, 'overlap rate': 0.9990583151578903}
# evaluation performance: {'loss': 0.06661980599164963, 'abosulate accuracy': 0.8732000425457954, 'consecutive overlap rate': 0.9823607683181763, 'overlap rate': 0.9931621491909027}
#
# Current epoch: 45,
# training performance: {'loss': 2.4621453559724613, 'abosulate accuracy': 0.4993000075221062, 'consecutive overlap rate': 0.5663273588288575, 'overlap rate': 0.6935374315828085}
# evaluation performance: {'loss': 4.050712126493454, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06318548414856195, 'overlap rate': 0.10721207829192281}
#
# Current epoch: 50,
# training performance: {'loss': 1.663931056857109, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.12693838588893414, 'overlap rate': 0.5304151825606823}
# evaluation performance: {'loss': 3.322225272655487, 'abosulate accuracy': 0.00035000001662410796, 'consecutive overlap rate': 0.06876919539645314, 'overlap rate': 0.2280843161046505}
#
# Current epoch: 55,
# training performance: {'loss': 0.28326671831309796, 'abosulate accuracy': 0.265000013820827, 'consecutive overlap rate': 0.5989222005009651, 'overlap rate': 0.9420638456940651}
# evaluation performance: {'loss': 1.2249678149819374, 'abosulate accuracy': 0.3062000154517591, 'consecutive overlap rate': 0.6337077669799328, 'overlap rate': 0.7812509819865227}
#
# Current epoch: 60,
# training performance: {'loss': 0.866632473655045, 'abosulate accuracy': 0.37040001768618824, 'consecutive overlap rate': 0.5324312021955848, 'overlap rate': 0.833874186873436}
# evaluation performance: {'loss': 3.843311333656311, 'abosulate accuracy': 0.010950000601587817, 'consecutive overlap rate': 0.1445510762743652, 'overlap rate': 0.26442227270454166}
#
# Current epoch: 65,
# training performance: {'loss': 0.4036083150655031, 'abosulate accuracy': 0.16690000829985366, 'consecutive overlap rate': 0.42746601551771163, 'overlap rate': 0.9050255984067916}
# evaluation performance: {'loss': 1.7656977348029614, 'abosulate accuracy': 0.22010000924346967, 'consecutive overlap rate': 0.459742434695363, 'overlap rate': 0.6519239008426666}
#
# Current epoch: 70,
# training performance: {'loss': 0.7247478496283293, 'abosulate accuracy': 0.15120000798488037, 'consecutive overlap rate': 0.3902858830988407, 'overlap rate': 0.8369878232479095}
# evaluation performance: {'loss': 2.446798215806484, 'abosulate accuracy': 0.0841000020795036, 'consecutive overlap rate': 0.4280750948935747, 'overlap rate': 0.56310583204031}
#
# Current epoch: 75,
# training performance: {'loss': 1.0937644198536873, 'abosulate accuracy': 0.059600003785453735, 'consecutive overlap rate': 0.3146111657842994, 'overlap rate': 0.7544380098581314}
# evaluation performance: {'loss': 3.0776395350694656, 'abosulate accuracy': 0.0827500039304141, 'consecutive overlap rate': 0.23048849888145923, 'overlap rate': 0.3841459557414055}
#
# Current epoch: 80,
# training performance: {'loss': 0.14987997952848672, 'abosulate accuracy': 0.5009000238031149, 'consecutive overlap rate': 0.763960961997509, 'overlap rate': 0.9778804793953896}
# evaluation performance: {'loss': 0.6552657674998045, 'abosulate accuracy': 0.5237500261515379, 'consecutive overlap rate': 0.8048763290047646, 'overlap rate': 0.8871719017624855}
#
# Current epoch: 85,
# training performance: {'loss': 0.07053426429629325, 'abosulate accuracy': 0.7165000334382057, 'consecutive overlap rate': 0.8991296514868736, 'overlap rate': 0.992660091817379}
# evaluation performance: {'loss': 0.31682937517762183, 'abosulate accuracy': 0.7141500368714333, 'consecutive overlap rate': 0.9070360749959946, 'overlap rate': 0.9532289147377014}
#
# Current epoch: 90,
# training performance: {'loss': 0.044211531337350604, 'abosulate accuracy': 0.8080000400543212, 'consecutive overlap rate': 0.946403668820858, 'overlap rate': 0.9963769257068634}
# evaluation performance: {'loss': 0.22367951958440244, 'abosulate accuracy': 0.7708000361919403, 'consecutive overlap rate': 0.94049331843853, 'overlap rate': 0.9694887086749077}
#
# Current epoch: 95,
# training performance: {'loss': 0.02944576370064169, 'abosulate accuracy': 0.8606000348925591, 'consecutive overlap rate': 0.9728026494383812, 'overlap rate': 0.9981476068496704}
# evaluation performance: {'loss': 0.15937074329704046, 'abosulate accuracy': 0.8161000356078147, 'consecutive overlap rate': 0.956786721944809, 'overlap rate': 0.97983208745718}
#
# Current epoch: 100,
# training performance: {'loss': 0.021775821037590504, 'abosulate accuracy': 0.885600033402443, 'consecutive overlap rate': 0.9836334809660912, 'overlap rate': 0.9988959819078446}
# evaluation performance: {'loss': 0.11113127453718334, 'abosulate accuracy': 0.8520000338554382, 'consecutive overlap rate': 0.970602048933506, 'overlap rate': 0.9865567713975907}
#
# Experiments_Logs/Experiment#1/LSTM/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.0358936034142971, 'abosulate accuracy': 0.022250000937492586, 'consecutive overlap rate': 0.4134696738794446, 'overlap rate': 0.8243854455649853}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.04613648268859834, 'abosulate accuracy': 0.8935000419616699, 'consecutive overlap rate': 0.9885365560650825, 'overlap rate': 0.9956670805811882}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.0651037512287016, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.3807762507469423, 'overlap rate': 0.809280066720901}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.843627752344075, 'abosulate accuracy': 0.5435000204321879, 'consecutive overlap rate': 0.814668628730272, 'overlap rate': 0.8819784365202251}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.608244228363037, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013988678925670683, 'overlap rate': 0.22211585473269224}
# evaluation performance: {'loss': 2.9201249718666076, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01710316534154117, 'overlap rate': 0.13894362524151802}
#
# Current epoch: 10,
# training performance: {'loss': 1.8998534947633743, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.05969522842206061, 'overlap rate': 0.4824606467038393}
# evaluation performance: {'loss': 2.7224190533161163, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.0858767218887806, 'overlap rate': 0.23696386329829694}
#
# Current epoch: 15,
# training performance: {'loss': 2.7707148492336273, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07473050840198994, 'overlap rate': 0.216146844625473}
# evaluation performance: {'loss': 2.9205574810504915, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03950446615926921, 'overlap rate': 0.18219433333724738}
#
# Current epoch: 20,
# training performance: {'loss': 1.0243230789899826, 'abosulate accuracy': 0.030600000789854677, 'consecutive overlap rate': 0.20363445347175002, 'overlap rate': 0.7202288173139095}
# evaluation performance: {'loss': 3.1564543545246124, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.16007970534265042, 'overlap rate': 0.31137086302042005}
#
# Current epoch: 25,
# training performance: {'loss': 0.5468190543353557, 'abosulate accuracy': 0.18800000894116237, 'consecutive overlap rate': 0.4565563388168812, 'overlap rate': 0.8775523856282235}
# evaluation performance: {'loss': 3.490454725921154, 'abosulate accuracy': 0.035850001720245925, 'consecutive overlap rate': 0.22879069466143848, 'overlap rate': 0.3249191965907812}
#
# Current epoch: 30,
# training performance: {'loss': 0.6338873200118542, 'abosulate accuracy': 0.052800002635922286, 'consecutive overlap rate': 0.30606560967862606, 'overlap rate': 0.8441980190575122}
# evaluation performance: {'loss': 1.2330271065235139, 'abosulate accuracy': 0.14995000595226884, 'consecutive overlap rate': 0.5624800521880389, 'overlap rate': 0.7407847717404366}
#
# Current epoch: 35,
# training performance: {'loss': 0.33235746566206215, 'abosulate accuracy': 0.38380001644836736, 'consecutive overlap rate': 0.6137401990592479, 'overlap rate': 0.930670490860939}
# evaluation performance: {'loss': 2.2227460205554963, 'abosulate accuracy': 0.15990000709425659, 'consecutive overlap rate': 0.4596310146152973, 'overlap rate': 0.6206682942807674}
#
# Current epoch: 40,
# training performance: {'loss': 0.08588707624003292, 'abosulate accuracy': 0.6684000305831432, 'consecutive overlap rate': 0.863906979560852, 'overlap rate': 0.9891406461596489}
# evaluation performance: {'loss': 0.22974297115579248, 'abosulate accuracy': 0.738450038433075, 'consecutive overlap rate': 0.9020207777619362, 'overlap rate': 0.9680375754833221}
#
# Current epoch: 45,
# training performance: {'loss': 0.04221526142209768, 'abosulate accuracy': 0.831300038099289, 'consecutive overlap rate': 0.9514290422201157, 'overlap rate': 0.9972572430968285}
# evaluation performance: {'loss': 0.08592312806285918, 'abosulate accuracy': 0.8485500425100326, 'consecutive overlap rate': 0.9669012427330017, 'overlap rate': 0.9905917942523956}
#
# Current epoch: 50,
# training performance: {'loss': 0.02572637884877622, 'abosulate accuracy': 0.8848000362515449, 'consecutive overlap rate': 0.9796049639582634, 'overlap rate': 0.9989805534482002}
# evaluation performance: {'loss': 0.07053876563441008, 'abosulate accuracy': 0.870100037753582, 'consecutive overlap rate': 0.9771860137581825, 'overlap rate': 0.9919853895902634}
#
# Current epoch: 55,
# training performance: {'loss': 0.017954769218340515, 'abosulate accuracy': 0.9037000253796578, 'consecutive overlap rate': 0.989848068356514, 'overlap rate': 0.9995162233710289}
# evaluation performance: {'loss': 0.059264230402186514, 'abosulate accuracy': 0.8829000368714333, 'consecutive overlap rate': 0.9824269562959671, 'overlap rate': 0.9930998042225838}
#
# Current epoch: 60,
# training performance: {'loss': 0.013437555299606174, 'abosulate accuracy': 0.9117000192403794, 'consecutive overlap rate': 0.9935951083898544, 'overlap rate': 0.9997195646166801}
# evaluation performance: {'loss': 0.03928290689364076, 'abosulate accuracy': 0.8969500362873077, 'consecutive overlap rate': 0.9892931818962097, 'overlap rate': 0.9958950281143188}
#
# Current epoch: 65,
# training performance: {'loss': 0.010244422114919872, 'abosulate accuracy': 0.9177000194787979, 'consecutive overlap rate': 0.9966912001371384, 'overlap rate': 0.9998459056019783}
# evaluation performance: {'loss': 0.029698981973342597, 'abosulate accuracy': 0.9048500388860703, 'consecutive overlap rate': 0.9924678400158882, 'overlap rate': 0.9970697522163391}
#
# Current epoch: 70,
# training performance: {'loss': 0.00796932919183746, 'abosulate accuracy': 0.92170000821352, 'consecutive overlap rate': 0.9984899550676346, 'overlap rate': 0.9999257192015648}
# evaluation performance: {'loss': 0.022661048325244338, 'abosulate accuracy': 0.9095500409603119, 'consecutive overlap rate': 0.9943087577819825, 'overlap rate': 0.997917452454567}
#
# Current epoch: 75,
# training performance: {'loss': 0.0063327533134724945, 'abosulate accuracy': 0.9234000071883202, 'consecutive overlap rate': 0.999282243847847, 'overlap rate': 0.9999647304415703}
# evaluation performance: {'loss': 0.01896255208994262, 'abosulate accuracy': 0.912750032544136, 'consecutive overlap rate': 0.9955258324742318, 'overlap rate': 0.9982949152588845}
#
# Current epoch: 80,
# training performance: {'loss': 0.00512853644322604, 'abosulate accuracy': 0.923900006711483, 'consecutive overlap rate': 0.9996142655611038, 'overlap rate': 0.9999786481261254}
# evaluation performance: {'loss': 0.015738628926919775, 'abosulate accuracy': 0.9146500349044799, 'consecutive overlap rate': 0.9963221430778504, 'overlap rate': 0.9986017346382141}
#
# Current epoch: 85,
# training performance: {'loss': 0.0042141230223933235, 'abosulate accuracy': 0.9246000051498413, 'consecutive overlap rate': 0.9998412951827049, 'overlap rate': 0.9999928653240204}
# evaluation performance: {'loss': 0.013837524974951521, 'abosulate accuracy': 0.915450033545494, 'consecutive overlap rate': 0.9966852948069572, 'overlap rate': 0.9987568736076355}
#
# Current epoch: 90,
# training performance: {'loss': 0.003499217482749373, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.012646854156628251, 'abosulate accuracy': 0.9155500307679176, 'consecutive overlap rate': 0.996853058040142, 'overlap rate': 0.9988196164369583}
#
# Current epoch: 95,
# training performance: {'loss': 0.0029285837954375893, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.011283050474594348, 'abosulate accuracy': 0.9163000300526619, 'consecutive overlap rate': 0.9970599263906479, 'overlap rate': 0.9989319264888763}
#
# Current epoch: 100,
# training performance: {'loss': 0.0024669128615641966, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.011418333082110621, 'abosulate accuracy': 0.9162000313401222, 'consecutive overlap rate': 0.9969794109463692, 'overlap rate': 0.9988790944218635}
#
# Experiments_Logs/Experiment#1/LSTM/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.975721662119031, 'abosulate accuracy': 0.06952500357292593, 'consecutive overlap rate': 0.5040829231962561, 'overlap rate': 0.8591738369315862}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.01174368489300832, 'abosulate accuracy': 0.9167750328779221, 'consecutive overlap rate': 0.9973844096064568, 'overlap rate': 0.99891507178545}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.2344518153898179, 'abosulate accuracy': 0.007476461438402053, 'consecutive overlap rate': 0.4476908322303526, 'overlap rate': 0.7963201838154946}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.6895224532375945, 'abosulate accuracy': 0.5718947632673295, 'consecutive overlap rate': 0.8972803605230231, 'overlap rate': 0.9181749710911199}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.6748489141464233, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01343859132612124, 'overlap rate': 0.22017461527138948}
# evaluation performance: {'loss': 2.8838185369968414, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020035049016587436, 'overlap rate': 0.16282811127603053}
#
# Current epoch: 10,
# training performance: {'loss': 1.9570879355072974, 'abosulate accuracy': 0.004200000176206231, 'consecutive overlap rate': 0.10622224798426032, 'overlap rate': 0.4997015379369259}
# evaluation performance: {'loss': 2.8692843496799467, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05784871531650424, 'overlap rate': 0.20494955256581307}
#
# Current epoch: 15,
# training performance: {'loss': 1.632527419924736, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.15919158849865198, 'overlap rate': 0.5691612772643566}
# evaluation performance: {'loss': 3.0694372713565827, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.11752575226128101, 'overlap rate': 0.23644398488104343}
#
# Current epoch: 20,
# training performance: {'loss': 0.7929668024182319, 'abosulate accuracy': 0.3298000144539401, 'consecutive overlap rate': 0.5633616703562438, 'overlap rate': 0.8510897494852543}
# evaluation performance: {'loss': 2.206662004441023, 'abosulate accuracy': 0.18045000962447375, 'consecutive overlap rate': 0.3863804394379258, 'overlap rate': 0.5380691856145858}
#
# Current epoch: 25,
# training performance: {'loss': 0.7856263451278209, 'abosulate accuracy': 0.34580001811264083, 'consecutive overlap rate': 0.5300121631473302, 'overlap rate': 0.837823998183012}
# evaluation performance: {'loss': 2.123412972688675, 'abosulate accuracy': 0.12220000623492525, 'consecutive overlap rate': 0.41168295927345755, 'overlap rate': 0.5762013725936412}
#
# Current epoch: 30,
# training performance: {'loss': 1.6665908835828305, 'abosulate accuracy': 0.03740000108955428, 'consecutive overlap rate': 0.24537543724291028, 'overlap rate': 0.6626118950545787}
# evaluation performance: {'loss': 3.452494406700134, 'abosulate accuracy': 0.0005500000261235982, 'consecutive overlap rate': 0.2139008680358529, 'overlap rate': 0.33767472915351393}
#
# Current epoch: 35,
# training performance: {'loss': 0.13599977381527423, 'abosulate accuracy': 0.5970000274479389, 'consecutive overlap rate': 0.8273505181074142, 'overlap rate': 0.9861785382032394}
# evaluation performance: {'loss': 0.40932548344135283, 'abosulate accuracy': 0.6581500336527825, 'consecutive overlap rate': 0.8667675435543061, 'overlap rate': 0.9360090538859367}
#
# Current epoch: 40,
# training performance: {'loss': 0.0621860561426729, 'abosulate accuracy': 0.7676000311970711, 'consecutive overlap rate': 0.9254548251628876, 'overlap rate': 0.9950444102287292}
# evaluation performance: {'loss': 0.15582054015249014, 'abosulate accuracy': 0.8049500405788421, 'consecutive overlap rate': 0.9557271778583527, 'overlap rate': 0.9798750877380371}
#
# Current epoch: 45,
# training performance: {'loss': 0.03236935944296419, 'abosulate accuracy': 0.8629000335931778, 'consecutive overlap rate': 0.9725960239768028, 'overlap rate': 0.9984452188014984}
# evaluation performance: {'loss': 0.11721727619878948, 'abosulate accuracy': 0.8610500410199166, 'consecutive overlap rate': 0.9758924469351768, 'overlap rate': 0.985242386162281}
#
# Current epoch: 50,
# training performance: {'loss': 0.021958456141874194, 'abosulate accuracy': 0.888700021803379, 'consecutive overlap rate': 0.9839955776929855, 'overlap rate': 0.9991477772593498}
# evaluation performance: {'loss': 0.08824555834289641, 'abosulate accuracy': 0.8820500358939171, 'consecutive overlap rate': 0.9835055992007256, 'overlap rate': 0.9892880752682686}
#
# Current epoch: 55,
# training performance: {'loss': 0.016134252084884792, 'abosulate accuracy': 0.9017000213265419, 'consecutive overlap rate': 0.9893513590097427, 'overlap rate': 0.9994805887341499}
# evaluation performance: {'loss': 0.054548647231422366, 'abosulate accuracy': 0.897500042617321, 'consecutive overlap rate': 0.9902690351009369, 'overlap rate': 0.9939433693885803}
#
# Current epoch: 60,
# training performance: {'loss': 0.012430609751027078, 'abosulate accuracy': 0.9103000208735466, 'consecutive overlap rate': 0.9928716972470284, 'overlap rate': 0.999681481719017}
# evaluation performance: {'loss': 0.038174224144313484, 'abosulate accuracy': 0.9052500382065773, 'consecutive overlap rate': 0.9936011359095573, 'overlap rate': 0.9960636138916016}
#
# Current epoch: 65,
# training performance: {'loss': 0.009794659627368673, 'abosulate accuracy': 0.9153000146150589, 'consecutive overlap rate': 0.9950698167085648, 'overlap rate': 0.9997905656695366}
# evaluation performance: {'loss': 0.02836580896982923, 'abosulate accuracy': 0.9090000405907631, 'consecutive overlap rate': 0.9950649335980415, 'overlap rate': 0.99731897264719}
#
# Current epoch: 70,
# training performance: {'loss': 0.007707140507409349, 'abosulate accuracy': 0.9192000150680542, 'consecutive overlap rate': 0.997232486307621, 'overlap rate': 0.9998806148767472}
# evaluation performance: {'loss': 0.02514142874861136, 'abosulate accuracy': 0.9107000380754471, 'consecutive overlap rate': 0.995648880302906, 'overlap rate': 0.9975958704948426}
#
# Current epoch: 75,
# training performance: {'loss': 0.006172975257504732, 'abosulate accuracy': 0.9214000105857849, 'consecutive overlap rate': 0.9984987288713455, 'overlap rate': 0.9999289989471436}
# evaluation performance: {'loss': 0.020120431919349358, 'abosulate accuracy': 0.912000036239624, 'consecutive overlap rate': 0.996414715051651, 'overlap rate': 0.9980793803930282}
#
# Current epoch: 80,
# training performance: {'loss': 0.005104770313482732, 'abosulate accuracy': 0.9227000117301941, 'consecutive overlap rate': 0.9989081919193268, 'overlap rate': 0.9999524146318436}
# evaluation performance: {'loss': 0.01911941815633327, 'abosulate accuracy': 0.9125000342726708, 'consecutive overlap rate': 0.9967577800154686, 'overlap rate': 0.9981579646468163}
#
# Current epoch: 85,
# training performance: {'loss': 0.004227626335341484, 'abosulate accuracy': 0.9240000054240227, 'consecutive overlap rate': 0.999431911110878, 'overlap rate': 0.9999764814972878}
# evaluation performance: {'loss': 0.0202390072401613, 'abosulate accuracy': 0.9116500332951546, 'consecutive overlap rate': 0.996341948211193, 'overlap rate': 0.9979915782809258}
#
# Current epoch: 90,
# training performance: {'loss': 0.0034828276140615342, 'abosulate accuracy': 0.9247000038623809, 'consecutive overlap rate': 0.999879814684391, 'overlap rate': 0.9999946683645249}
# evaluation performance: {'loss': 0.02223339506890625, 'abosulate accuracy': 0.9102500364184379, 'consecutive overlap rate': 0.995686499774456, 'overlap rate': 0.9977803483605385}
#
# Current epoch: 95,
# training performance: {'loss': 0.002850606999709271, 'abosulate accuracy': 0.9248000025749207, 'consecutive overlap rate': 0.9999061301350594, 'overlap rate': 0.9999964222311973}
# evaluation performance: {'loss': 0.02247377817693632, 'abosulate accuracy': 0.9088000357151031, 'consecutive overlap rate': 0.9952359393239021, 'overlap rate': 0.9977231025695801}
#
# Current epoch: 100,
# training performance: {'loss': 0.0022869311505928636, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.023785627473262138, 'abosulate accuracy': 0.9079500362277031, 'consecutive overlap rate': 0.9949830666184425, 'overlap rate': 0.9976189956068993}
#
# Experiments_Logs/Experiment#1/LSTM/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/LSTM/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.0520423650741577, 'abosulate accuracy': 0.028525001197704115, 'consecutive overlap rate': 0.45331125520169735, 'overlap rate': 0.8578621674329042}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.021477186487754808, 'abosulate accuracy': 0.9124250426888466, 'consecutive overlap rate': 0.9963958412408829, 'overlap rate': 0.9978979885578155}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.3323205801748461, 'abosulate accuracy': 0.003200000127957713, 'consecutive overlap rate': 0.3935365078910705, 'overlap rate': 0.7945784984096405}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.576565964772415, 'abosulate accuracy': 0.6278421312055894, 'consecutive overlap rate': 0.8946374199892345, 'overlap rate': 0.9239224618987033}
# Experiments_Logs/Experiment#1/LSTM/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#1 with LSTM seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#1/LSTM/hyperparameters.json saved!
