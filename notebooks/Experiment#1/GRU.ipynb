# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 128
embd_dim = 64
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = True
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 1
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs created!
# ./Experiments_Logs/Experiment#1 created!
# ./Experiments_Logs/Experiment#1/GRU created!
# ./Experiments_Logs/Experiment#1/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#1/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#1/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.85 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training


for lang in ["RevStr", "RedStr"]:
    print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
    print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#1 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.009538164898185642, 'abosulate accuracy': 0.9221500232815742, 'consecutive overlap rate': 0.9989512592554093, 'overlap rate': 0.9992864772677421}
#
# Current epoch: 70,
# training performance: {'loss': 7.800193784532894e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.009491382603118836, 'abosulate accuracy': 0.9224000215530396, 'consecutive overlap rate': 0.9990275859832763, 'overlap rate': 0.9993002474308014}
#
# Current epoch: 75,
# training performance: {'loss': 6.542728228851047e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.009477215678998618, 'abosulate accuracy': 0.9224500209093094, 'consecutive overlap rate': 0.9990588366985321, 'overlap rate': 0.9993056043982506}
#
# Current epoch: 80,
# training performance: {'loss': 5.527210551008466e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.008137856387838838, 'abosulate accuracy': 0.922600020468235, 'consecutive overlap rate': 0.9991588369011879, 'overlap rate': 0.999398934841156}
#
# Current epoch: 85,
# training performance: {'loss': 4.697953677350597e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.008219489371367673, 'abosulate accuracy': 0.922600020468235, 'consecutive overlap rate': 0.9991588369011879, 'overlap rate': 0.999398934841156}
#
# Current epoch: 90,
# training performance: {'loss': 4.0141979206964605e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.008477604965355568, 'abosulate accuracy': 0.9227000191807747, 'consecutive overlap rate': 0.9991972640156745, 'overlap rate': 0.9993949428200721}
#
# Current epoch: 95,
# training performance: {'loss': 3.445717306931329e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.008074813166422246, 'abosulate accuracy': 0.9228500187397003, 'consecutive overlap rate': 0.9992390394210815, 'overlap rate': 0.9994335010647774}
#
# Current epoch: 100,
# training performance: {'loss': 2.9695488433389982e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.008134876566964521, 'abosulate accuracy': 0.9229000180959701, 'consecutive overlap rate': 0.9992469340562821, 'overlap rate': 0.9994352549314499}
#
# Experiments_Logs/Experiment#1/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 9.201792055368424, 'abosulate accuracy': 0.024875001073814927, 'consecutive overlap rate': 0.026128750282805414, 'overlap rate': 0.44154754355549813}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.010205081622825674, 'abosulate accuracy': 0.9222500339150429, 'consecutive overlap rate': 0.998914809525013, 'overlap rate': 0.9992904424667358}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 8.54479467945714, 'abosulate accuracy': 0.033964869052532216, 'consecutive overlap rate': 0.076074313083964, 'overlap rate': 0.40641944716053624}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.1322404466539553, 'abosulate accuracy': 0.7293421364769241, 'consecutive overlap rate': 0.8984880557185725, 'overlap rate': 0.9157639239963732}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9885707467794418, 'abosulate accuracy': 0.14230000581592323, 'consecutive overlap rate': 0.3530632474459708, 'overlap rate': 0.5720865234732628}
# evaluation performance: {'loss': 3.000201904773712, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.021120380958564056, 'abosulate accuracy': 0.920000034570694, 'consecutive overlap rate': 0.997820720076561, 'overlap rate': 0.9983719795942306}
#
# Current epoch: 75,
# training performance: {'loss': 0.0001031885632983176, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0204367055768671, 'abosulate accuracy': 0.9202500313520432, 'consecutive overlap rate': 0.9979453548789025, 'overlap rate': 0.9984553515911102}
#
# Current epoch: 80,
# training performance: {'loss': 8.649447718198645e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.019910186067136237, 'abosulate accuracy': 0.9204000324010849, 'consecutive overlap rate': 0.9980063408613205, 'overlap rate': 0.9985148578882217}
#
# Current epoch: 85,
# training performance: {'loss': 7.299087760657131e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.01937948272752692, 'abosulate accuracy': 0.9205500319600105, 'consecutive overlap rate': 0.9980663046240806, 'overlap rate': 0.9985714912414551}
#
# Current epoch: 90,
# training performance: {'loss': 6.19550475221331e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.01804695495557098, 'abosulate accuracy': 0.9208500295877456, 'consecutive overlap rate': 0.9981895163655281, 'overlap rate': 0.9986928850412369}
#
# Current epoch: 95,
# training performance: {'loss': 5.285553279463784e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.01793170948712941, 'abosulate accuracy': 0.9209500297904014, 'consecutive overlap rate': 0.9982811629772186, 'overlap rate': 0.9987261578440666}
#
# Current epoch: 100,
# training performance: {'loss': 4.529291845756234e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.016489437488598924, 'abosulate accuracy': 0.9213000297546386, 'consecutive overlap rate': 0.9984258741140366, 'overlap rate': 0.9988379418849945}
#
# Experiments_Logs/Experiment#1/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 8.13126123547554, 'abosulate accuracy': 0.02467500109632965, 'consecutive overlap rate': 0.0257133336213883, 'overlap rate': 0.45080171097069976}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.01446414920828829, 'abosulate accuracy': 0.921350035071373, 'consecutive overlap rate': 0.9986286088824272, 'overlap rate': 0.9989532858133316}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.67773047108804, 'abosulate accuracy': 0.00023225807554779515, 'consecutive overlap rate': 0.018431663588290254, 'overlap rate': 0.3485045273457804}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.5825663302281388, 'abosulate accuracy': 0.7231316097864979, 'consecutive overlap rate': 0.9391632048707259, 'overlap rate': 0.9513938881848988}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.398839357495308, 'abosulate accuracy': 0.003900000161956996, 'consecutive overlap rate': 0.24182481090538205, 'overlap rate': 0.6262752018868923}
# evaluation performance: {'loss': 4.74979954957962, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.023276602205442032, 'abosulate accuracy': 0.9178000316023827, 'consecutive overlap rate': 0.9968898132443428, 'overlap rate': 0.9981523886322975}
#
# Current epoch: 70,
# training performance: {'loss': 0.00015569320075883297, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.022865987310797208, 'abosulate accuracy': 0.9181500315666199, 'consecutive overlap rate': 0.99697545170784, 'overlap rate': 0.99823027998209}
#
# Current epoch: 75,
# training performance: {'loss': 0.00013039561963523738, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.02294948656926863, 'abosulate accuracy': 0.9182500317692757, 'consecutive overlap rate': 0.9970755100250244, 'overlap rate': 0.998238492012024}
#
# Current epoch: 80,
# training performance: {'loss': 0.00011002249357261462, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.02315334377963154, 'abosulate accuracy': 0.9184000328183174, 'consecutive overlap rate': 0.9972118601202965, 'overlap rate': 0.998251098394394}
#
# Current epoch: 85,
# training performance: {'loss': 9.341917093479424e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.022065122049389173, 'abosulate accuracy': 0.9187000319361687, 'consecutive overlap rate': 0.9973064705729484, 'overlap rate': 0.9983449876308441}
#
# Current epoch: 90,
# training performance: {'loss': 7.975153976076399e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.02156821390653931, 'abosulate accuracy': 0.9188500314950943, 'consecutive overlap rate': 0.997360710799694, 'overlap rate': 0.9983947768807411}
#
# Current epoch: 95,
# training performance: {'loss': 6.84035077028966e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.021199772737782042, 'abosulate accuracy': 0.9191500306129455, 'consecutive overlap rate': 0.9974385693669319, 'overlap rate': 0.998455998301506}
#
# Current epoch: 100,
# training performance: {'loss': 5.891033133593737e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.021955190917651635, 'abosulate accuracy': 0.919350029528141, 'consecutive overlap rate': 0.9974718958139419, 'overlap rate': 0.9984422594308853}
#
# Experiments_Logs/Experiment#1/GRU/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 11.121495062112809, 'abosulate accuracy': 0.024325001059332864, 'consecutive overlap rate': 0.02547916685580276, 'overlap rate': 0.20146335186436773}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.017600066299928586, 'abosulate accuracy': 0.9200000390410423, 'consecutive overlap rate': 0.9978952705860138, 'overlap rate': 0.9986927524209023}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 11.19427616980768, 'abosulate accuracy': 0.00012903226419321953, 'consecutive overlap rate': 0.01651119099208905, 'overlap rate': 0.13694871851513463}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.907514623340256, 'abosulate accuracy': 0.7082368725003969, 'consecutive overlap rate': 0.9138541958833996, 'overlap rate': 0.9331393634018145}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ...experiment#1 with GRU seq2seq ends.
# Start experiment#1 with GRU seq2seq...
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.006840204223499314, 'abosulate accuracy': 0.922150020301342, 'consecutive overlap rate': 0.9991490557789803, 'overlap rate': 0.9994608774781227}
#
# Current epoch: 65,
# training performance: {'loss': 0.00010487286735951784, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.006223611237419391, 'abosulate accuracy': 0.9222500205039978, 'consecutive overlap rate': 0.9992010354995727, 'overlap rate': 0.9995123028755188}
#
# Current epoch: 70,
# training performance: {'loss': 8.707785154911107e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.004790778683127428, 'abosulate accuracy': 0.9223000198602677, 'consecutive overlap rate': 0.9993144541978836, 'overlap rate': 0.9996036767959595}
#
# Current epoch: 75,
# training performance: {'loss': 7.291038359653612e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.004538889808554813, 'abosulate accuracy': 0.9223000183701515, 'consecutive overlap rate': 0.9993141159415245, 'overlap rate': 0.9996232494711876}
#
# Current epoch: 80,
# training performance: {'loss': 6.148126490188588e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.003912491188202694, 'abosulate accuracy': 0.9224500179290771, 'consecutive overlap rate': 0.9993758723139763, 'overlap rate': 0.9996683374047279}
#
# Current epoch: 85,
# training performance: {'loss': 5.215803694227361e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0034003315645804834, 'abosulate accuracy': 0.9225000187754631, 'consecutive overlap rate': 0.999409019947052, 'overlap rate': 0.9997019529342651}
#
# Current epoch: 90,
# training performance: {'loss': 4.448050099199463e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0034173625260791596, 'abosulate accuracy': 0.9224500209093094, 'consecutive overlap rate': 0.9993881970643997, 'overlap rate': 0.999695000052452}
#
# Current epoch: 95,
# training performance: {'loss': 3.810646912825177e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.003413489042350193, 'abosulate accuracy': 0.9226500183343888, 'consecutive overlap rate': 0.9994712918996811, 'overlap rate': 0.9997061774134636}
#
# Current epoch: 100,
# training performance: {'loss': 3.277698490364855e-05, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0034390005327168184, 'abosulate accuracy': 0.9226500183343888, 'consecutive overlap rate': 0.9994712918996811, 'overlap rate': 0.9997061774134636}
#
# Experiments_Logs/Experiment#1/GRU/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.5924801975488663, 'abosulate accuracy': 0.16175000690855085, 'consecutive overlap rate': 0.33315458837896583, 'overlap rate': 0.7273854788392782}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.0055128892142420225, 'abosulate accuracy': 0.922475029528141, 'consecutive overlap rate': 0.9993830338120461, 'overlap rate': 0.9995510935783386}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.2385441980054304, 'abosulate accuracy': 0.00010322581135457562, 'consecutive overlap rate': 0.3801463503991404, 'overlap rate': 0.7942068496058065}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.9442495399144766, 'abosulate accuracy': 0.6087368718765088, 'consecutive overlap rate': 0.9043253550403997, 'overlap rate': 0.9128834354250055}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.0340783298015594, 'abosulate accuracy': 0.019300000718794764, 'consecutive overlap rate': 0.29579829033464194, 'overlap rate': 0.7027814082801342}
# evaluation performance: {'loss': 2.0278823882341386, 'abosulate accuracy': 0.01660000054980628, 'consecutive overlap rate': 0.3401505403220654, 'overlap rate': 0.4905630014836788}
#
# Current epoch: 10,
# training performance: {'loss': 1.8449308782815934, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.1787302877753973, 'overlap rate': 0.44920970499515533}
# evaluation performance: {'loss': 2.1491312742233277, 'abosulate accuracy': 0.003300000092713162, 'consecutive overlap rate': 0.2760047122836113, 'overlap rate': 0.41263614818453787}
#
# Current epoch: 15,
# training performance: {'loss': 0.01668960361275822, 'abosulate accuracy': 0.8772000432014465, 'consecutive overlap rate': 0.9732516527175903, 'overlap rate': 0.9979485183954239}
# evaluation performance: {'loss': 0.44209456192329527, 'abosulate accuracy': 0.8167000398039818, 'consecutive overlap rate': 0.9341888323426246, 'overlap rate': 0.9433314099907875}
#
# Current epoch: 20,
# training performance: {'loss': 1.3838490852198446, 'abosulate accuracy': 0.6551000081002712, 'consecutive overlap rate': 0.7540303704838152, 'overlap rate': 0.7904117036610842}
# evaluation performance: {'loss': 4.132068920135498, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020448259223485366, 'overlap rate': 0.039404974691569804}
#
# Current epoch: 25,
# training performance: {'loss': 3.1792550444602967, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0050638906774111096, 'overlap rate': 0.0814398942515254}
# evaluation performance: {'loss': 3.235134643316269, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0057705799874383954, 'overlap rate': 0.07464005574584007}
#
# Current epoch: 30,
# training performance: {'loss': 3.0417173326015474, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010159404331352562, 'overlap rate': 0.11326813753694295}
# evaluation performance: {'loss': 3.133873575925827, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010802081192377955, 'overlap rate': 0.09194885734468698}
#
# Current epoch: 35,
# training performance: {'loss': 2.8837750434875487, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028346910350956024, 'overlap rate': 0.15635674707591535}
# evaluation performance: {'loss': 3.028568971157074, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028284824290312826, 'overlap rate': 0.11579034887254239}
#
# Current epoch: 40,
# training performance: {'loss': 2.664520800113678, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.053582442877814176, 'overlap rate': 0.21309658885002136}
# evaluation performance: {'loss': 2.897451239824295, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05296924063004553, 'overlap rate': 0.15556920394301416}
#
# Current epoch: 45,
# training performance: {'loss': 2.3063824504613875, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08451832169666887, 'overlap rate': 0.3046929933130741}
# evaluation performance: {'loss': 2.714114362001419, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08595377029851078, 'overlap rate': 0.21055983677506446}
#
# Current epoch: 50,
# training performance: {'loss': 2.060504561662674, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.11781657505780459, 'overlap rate': 0.3749259352684021}
# evaluation performance: {'loss': 2.667313778400421, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.10815201988443732, 'overlap rate': 0.24160617031157017}
#
# Current epoch: 55,
# training performance: {'loss': 1.6193883180618287, 'abosulate accuracy': 0.0029000001726672054, 'consecutive overlap rate': 0.18361281659454107, 'overlap rate': 0.5063002787530422}
# evaluation performance: {'loss': 2.5625245213508605, 'abosulate accuracy': 0.002000000141561031, 'consecutive overlap rate': 0.136921426653862, 'overlap rate': 0.28597376607358455}
#
# Current epoch: 60,
# training performance: {'loss': 1.236247729510069, 'abosulate accuracy': 0.028200000908691437, 'consecutive overlap rate': 0.26749798450618983, 'overlap rate': 0.6212613016366959}
# evaluation performance: {'loss': 2.4773448556661606, 'abosulate accuracy': 0.007750000368105248, 'consecutive overlap rate': 0.1733016327023506, 'overlap rate': 0.3216987334191799}
#
# Current epoch: 65,
# training performance: {'loss': 1.3085541129112244, 'abosulate accuracy': 0.013900000671856105, 'consecutive overlap rate': 0.2556286174803972, 'overlap rate': 0.6003072693943977}
# evaluation performance: {'loss': 2.785047483444214, 'abosulate accuracy': 0.005900000280234963, 'consecutive overlap rate': 0.19560996256768703, 'overlap rate': 0.32272336892783643}
#
# Current epoch: 70,
# training performance: {'loss': 1.5371771618723868, 'abosulate accuracy': 0.0005000000121071935, 'consecutive overlap rate': 0.2198560019955039, 'overlap rate': 0.5394414059817791}
# evaluation performance: {'loss': 3.32718386054039, 'abosulate accuracy': 0.0006500000366941094, 'consecutive overlap rate': 0.15943829584866762, 'overlap rate': 0.24747092835605145}
#
# Current epoch: 75,
# training performance: {'loss': 1.9507021456956863, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.13622865080833435, 'overlap rate': 0.4921275209635496}
# evaluation performance: {'loss': 4.332064551115036, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.15090414695441723, 'overlap rate': 0.2378045029938221}
#
# Current epoch: 80,
# training performance: {'loss': 0.2782969303429127, 'abosulate accuracy': 0.24130000963341444, 'consecutive overlap rate': 0.5362404197454452, 'overlap rate': 0.9222167119383812}
# evaluation performance: {'loss': 2.94503153860569, 'abosulate accuracy': 0.1347000060195569, 'consecutive overlap rate': 0.36241426356136797, 'overlap rate': 0.47506992928683756}
#
# Current epoch: 85,
# training performance: {'loss': 0.12332512801513076, 'abosulate accuracy': 0.45210001782979814, 'consecutive overlap rate': 0.7133770883083344, 'overlap rate': 0.9684742107987404}
# evaluation performance: {'loss': 2.2258233819156885, 'abosulate accuracy': 0.32750001540407536, 'consecutive overlap rate': 0.5614684574306011, 'overlap rate': 0.6447963275015354}
#
# Current epoch: 90,
# training performance: {'loss': 1.996931478381157, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.15224833209067584, 'overlap rate': 0.4218122147023678}
# evaluation performance: {'loss': 2.302905324101448, 'abosulate accuracy': 0.000800000037997961, 'consecutive overlap rate': 0.18071838822215797, 'overlap rate': 0.3532096788287163}
#
# Current epoch: 95,
# training performance: {'loss': 1.3125887662172318, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.17797598168253898, 'overlap rate': 0.6027091629803181}
# evaluation performance: {'loss': 3.5613446712493895, 'abosulate accuracy': 0.00130000002682209, 'consecutive overlap rate': 0.1922349825501442, 'overlap rate': 0.320378477498889}
#
# Current epoch: 100,
# training performance: {'loss': 3.2665413677692414, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03608320858329535, 'overlap rate': 0.11554115451872349}
# evaluation performance: {'loss': 3.1236021757125854, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.043236763682216406, 'overlap rate': 0.11005647275596857}
#
# Experiments_Logs/Experiment#1/GRU/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.3457211715169251, 'abosulate accuracy': 0.4483000211417675, 'consecutive overlap rate': 0.6233533404767513, 'overlap rate': 0.9542192358523607}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.05502058561542071, 'abosulate accuracy': 0.9051000446081161, 'consecutive overlap rate': 0.9929181650280953, 'overlap rate': 0.9941873475909233}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.8021015847882916, 'abosulate accuracy': 0.22867046729210885, 'consecutive overlap rate': 0.5190313981425377, 'overlap rate': 0.9072658988737291}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.6821960091321287, 'abosulate accuracy': 0.7508158230859983, 'consecutive overlap rate': 0.8990149513671273, 'overlap rate': 0.9235307229192633}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.6302285015583038, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.20162878157570957, 'overlap rate': 0.5134920753538609}
# evaluation performance: {'loss': 2.631179776787758, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.16719203982502223, 'overlap rate': 0.30318528935313227}
#
# Current epoch: 10,
# training performance: {'loss': 2.150551202893257, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.13279951526783407, 'overlap rate': 0.3668946694582701}
# evaluation performance: {'loss': 2.5175984382629393, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1545102743431926, 'overlap rate': 0.26750198788940904}
#
# Current epoch: 15,
# training performance: {'loss': 2.2697088003158568, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07241155533120036, 'overlap rate': 0.313270915299654}
# evaluation performance: {'loss': 2.647620439529419, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1465622391551733, 'overlap rate': 0.2399482037872076}
#
# Current epoch: 20,
# training performance: {'loss': 0.8604001581668854, 'abosulate accuracy': 0.008400000329129399, 'consecutive overlap rate': 0.22116992399096488, 'overlap rate': 0.7430788174271583}
# evaluation performance: {'loss': 2.2913485735654833, 'abosulate accuracy': 0.03720000141765922, 'consecutive overlap rate': 0.280381859280169, 'overlap rate': 0.4396727420389652}
#
# Current epoch: 25,
# training performance: {'loss': 0.0994582125917077, 'abosulate accuracy': 0.5177000265568494, 'consecutive overlap rate': 0.7589711159467697, 'overlap rate': 0.9764141827821732}
# evaluation performance: {'loss': 0.5914698332548142, 'abosulate accuracy': 0.6777500331401825, 'consecutive overlap rate': 0.8718149334192276, 'overlap rate': 0.9108928337693214}
#
# Current epoch: 30,
# training performance: {'loss': 0.006590099330060184, 'abosulate accuracy': 0.9135000243782997, 'consecutive overlap rate': 0.9944439098238945, 'overlap rate': 0.999707156419754}
# evaluation performance: {'loss': 0.11762276059016585, 'abosulate accuracy': 0.8762500435113907, 'consecutive overlap rate': 0.9764639392495156, 'overlap rate': 0.987277127802372}
#
# Current epoch: 35,
# training performance: {'loss': 0.003354327633860521, 'abosulate accuracy': 0.92210001796484, 'consecutive overlap rate': 0.9993139445781708, 'overlap rate': 0.9999101057648658}
# evaluation performance: {'loss': 0.08550693979486823, 'abosulate accuracy': 0.8876000389456749, 'consecutive overlap rate': 0.9830563008785248, 'overlap rate': 0.9915973365306854}
#
# Current epoch: 40,
# training performance: {'loss': 0.0017180356895551085, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999457612633705, 'overlap rate': 0.9999966055154801}
# evaluation performance: {'loss': 0.043015745308366604, 'abosulate accuracy': 0.9089000388979912, 'consecutive overlap rate': 0.9917015373706818, 'overlap rate': 0.9957882523536682}
#
# Current epoch: 45,
# training performance: {'loss': 0.0011625636034295894, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999457612633705, 'overlap rate': 0.9999966055154801}
# evaluation performance: {'loss': 0.04497985789785162, 'abosulate accuracy': 0.9089000418782234, 'consecutive overlap rate': 0.9917073041200638, 'overlap rate': 0.9958098292350769}
#
# Current epoch: 50,
# training performance: {'loss': 0.0008550681457563769, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999457612633705, 'overlap rate': 0.9999966055154801}
# evaluation performance: {'loss': 0.04373244814778445, 'abosulate accuracy': 0.9098000407218934, 'consecutive overlap rate': 0.99234010130167, 'overlap rate': 0.9960128799080848}
#
# Current epoch: 55,
# training performance: {'loss': 0.0006515470187878237, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999457612633705, 'overlap rate': 0.9999966055154801}
# evaluation performance: {'loss': 0.04037092703219969, 'abosulate accuracy': 0.9113000392913818, 'consecutive overlap rate': 0.9931274503469467, 'overlap rate': 0.9963931828737259}
#
# Current epoch: 60,
# training performance: {'loss': 0.0005090664533781819, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999457612633705, 'overlap rate': 0.9999983012676239}
# evaluation performance: {'loss': 0.03877698979486013, 'abosulate accuracy': 0.9123000398278236, 'consecutive overlap rate': 0.9936317518353462, 'overlap rate': 0.9966132029891014}
#
# Current epoch: 65,
# training performance: {'loss': 0.0004049424391268985, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999457612633705, 'overlap rate': 0.9999983012676239}
# evaluation performance: {'loss': 0.03862252406834159, 'abosulate accuracy': 0.9128000378608704, 'consecutive overlap rate': 0.9939724862575531, 'overlap rate': 0.9967007607221603}
#
# Current epoch: 70,
# training performance: {'loss': 0.00032636433170409875, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.03449238148750737, 'abosulate accuracy': 0.9136500373482704, 'consecutive overlap rate': 0.9943929955363273, 'overlap rate': 0.997076191008091}
#
# Current epoch: 75,
# training performance: {'loss': 0.00026686435885494577, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0317764143779641, 'abosulate accuracy': 0.9143500357866288, 'consecutive overlap rate': 0.9948304936289787, 'overlap rate': 0.9973389834165574}
#
# Current epoch: 80,
# training performance: {'loss': 0.00022086748886067652, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.030499320245871785, 'abosulate accuracy': 0.9149000376462937, 'consecutive overlap rate': 0.9951168835163117, 'overlap rate': 0.997497235238552}
#
# Current epoch: 85,
# training performance: {'loss': 0.00018454930432199035, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.030849844968906838, 'abosulate accuracy': 0.915200038254261, 'consecutive overlap rate': 0.9952553510665894, 'overlap rate': 0.9975299566984177}
#
# Current epoch: 90,
# training performance: {'loss': 0.00015542112578259548, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.030059665784210664, 'abosulate accuracy': 0.9158500373363495, 'consecutive overlap rate': 0.9955976039171219, 'overlap rate': 0.9976267904043198}
#
# Current epoch: 95,
# training performance: {'loss': 0.0001317615124207805, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.028616704385422055, 'abosulate accuracy': 0.9164500385522842, 'consecutive overlap rate': 0.9958902105689049, 'overlap rate': 0.997772391140461}
#
# Current epoch: 100,
# training performance: {'loss': 0.00011233863997404115, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.026229688627063298, 'abosulate accuracy': 0.9167000383138657, 'consecutive overlap rate': 0.9960880607366562, 'overlap rate': 0.9979750990867615}
#
# Experiments_Logs/Experiment#1/GRU/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#1/GRU/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.9492457769811153, 'abosulate accuracy': 0.0473250019014813, 'consecutive overlap rate': 0.4205250184983015, 'overlap rate': 0.8788763530552387}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.03393080313690007, 'abosulate accuracy': 0.9162000432610512, 'consecutive overlap rate': 0.9953776732087135, 'overlap rate': 0.9974574565887451}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.2991302667125577, 'abosulate accuracy': 0.0004645161510955903, 'consecutive overlap rate': 0.38808337680755123, 'overlap rate': 0.7520470180819111}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.3034299935664564, 'abosulate accuracy': 0.6648158167586907, 'consecutive overlap rate': 0.8526080133099305, 'overlap rate': 0.893706706009413}
# Experiments_Logs/Experiment#1/GRU/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#1 with GRU seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#1/GRU/hyperparameters.json saved!
