# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-01-23 01:33:04

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/input_spec_red")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (30000, 30000, 150000, 300000)

# %%
in_vocab = ascii_lowercase + "@"
out_vocab = ascii_lowercase + "@"
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "input_spec_red"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]

for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 512
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            test_aggr = evaluate(model, test_dl, criterion)
            gen_aggr = evaluate(model, gen_dl, criterion)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,177,245 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.39867688814799, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0032501594385448192, 'overlap rate': 0.08379831779973834}
# evaluation performance: {'loss': 3.4051248391469318, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.003038822903747133, 'overlap rate': 0.08282252346961376}
#
# Current epoch: 20,
# training performance: {'loss': 3.2332709630330405, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.031506862564235565, 'overlap rate': 0.15299601543038824}
# evaluation performance: {'loss': 3.2522762934366862, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.02962420612890535, 'overlap rate': 0.15018907571790316}
#
# Current epoch: 30,
# training performance: {'loss': 3.4123722553253173, 'full sequence accuracy': 0.0007666666666666667, 'first n-symbol accuracy': 0.12625420759421419, 'overlap rate': 0.28859299380461273}
# evaluation performance: {'loss': 3.4510196089744567, 'full sequence accuracy': 0.0006999999999999999, 'first n-symbol accuracy': 0.12256285316147945, 'overlap rate': 0.2827245764445082}
#
# Current epoch: 40,
# training performance: {'loss': 2.910801068941752, 'full sequence accuracy': 0.0013333333333333335, 'first n-symbol accuracy': 0.231441612456345, 'overlap rate': 0.4423560137141894}
# evaluation performance: {'loss': 3.0335063099861146, 'full sequence accuracy': 0.0013333333333333335, 'first n-symbol accuracy': 0.2166984513432073, 'overlap rate': 0.4225578450232128}
#
# Current epoch: 50,
# training performance: {'loss': 2.7943259298801424, 'full sequence accuracy': 0.0452, 'first n-symbol accuracy': 0.3384026355078822, 'overlap rate': 0.5366571526654218}
# evaluation performance: {'loss': 3.040139428774516, 'full sequence accuracy': 0.035733333333333325, 'first n-symbol accuracy': 0.3042978698135293, 'overlap rate': 0.5028151371806128}
#
# Current epoch: 60,
# training performance: {'loss': 1.619587269425392, 'full sequence accuracy': 0.26036666666666664, 'first n-symbol accuracy': 0.5389871130690398, 'overlap rate': 0.7368626141880621}
# evaluation performance: {'loss': 2.154561670621236, 'full sequence accuracy': 0.1850333333333333, 'first n-symbol accuracy': 0.44714527611824445, 'overlap rate': 0.6590871700468313}
#
# Current epoch: 70,
# training performance: {'loss': 1.2443918270369372, 'full sequence accuracy': 0.38716666666666666, 'first n-symbol accuracy': 0.6310098339454547, 'overlap rate': 0.8104176659679047}
# evaluation performance: {'loss': 1.8911829556028048, 'full sequence accuracy': 0.2545333333333333, 'first n-symbol accuracy': 0.5124371151875822, 'overlap rate': 0.7202630114408526}
#
# Current epoch: 80,
# training performance: {'loss': 1.8672059101363023, 'full sequence accuracy': 0.37920000000000004, 'first n-symbol accuracy': 0.5581191268625078, 'overlap rate': 0.7508252201314228}
# evaluation performance: {'loss': 2.528734200199445, 'full sequence accuracy': 0.2652333333333333, 'first n-symbol accuracy': 0.46047083791999655, 'overlap rate': 0.6705592211143545}
#
# Current epoch: 90,
# training performance: {'loss': 0.9951630632082621, 'full sequence accuracy': 0.5452, 'first n-symbol accuracy': 0.7070687089313326, 'overlap rate': 0.8679593330667695}
# evaluation performance: {'loss': 1.9020060569047927, 'full sequence accuracy': 0.3608666666666666, 'first n-symbol accuracy': 0.5441092574830007, 'overlap rate': 0.7541613997228969}
#
# Current epoch: 100,
# training performance: {'loss': 0.7013771093140045, 'full sequence accuracy': 0.4230666666666666, 'first n-symbol accuracy': 0.7843500845239567, 'overlap rate': 0.9028239816417702}
# evaluation performance: {'loss': 1.7054060955842336, 'full sequence accuracy': 0.22536666666666666, 'first n-symbol accuracy': 0.5899274521040136, 'overlap rate': 0.7818389508302105}
#
# Current epoch: 110,
# training performance: {'loss': 1.0382466225574414, 'full sequence accuracy': 0.5209, 'first n-symbol accuracy': 0.7545089552710201, 'overlap rate': 0.882347669092004}
# evaluation performance: {'loss': 2.0532186811168986, 'full sequence accuracy': 0.30606666666666665, 'first n-symbol accuracy': 0.5768242824417693, 'overlap rate': 0.765337324980011}
#
# Current epoch: 120,
# training performance: {'loss': 0.4032864270421366, 'full sequence accuracy': 0.6949666666666666, 'first n-symbol accuracy': 0.8704648212829145, 'overlap rate': 0.9487480826719111}
# evaluation performance: {'loss': 1.6421269672612349, 'full sequence accuracy': 0.39203333333333323, 'first n-symbol accuracy': 0.616813736083295, 'overlap rate': 0.8066886465524087}
#
# Current epoch: 130,
# training performance: {'loss': 0.31110161075678966, 'full sequence accuracy': 0.6182333333333333, 'first n-symbol accuracy': 0.8978663930100452, 'overlap rate': 0.9582240664203295}
# evaluation performance: {'loss': 1.4793166066209475, 'full sequence accuracy': 0.38600000000000007, 'first n-symbol accuracy': 0.6539897857110524, 'overlap rate': 0.8260955531949157}
#
# Current epoch: 140,
# training performance: {'loss': 0.24065868807956575, 'full sequence accuracy': 0.8382666666666668, 'first n-symbol accuracy': 0.9279452726908322, 'overlap rate': 0.9726378277986021}
# evaluation performance: {'loss': 1.466806317617496, 'full sequence accuracy': 0.5046666666666667, 'first n-symbol accuracy': 0.6668079835697157, 'overlap rate': 0.8368564939494448}
#
# Current epoch: 150,
# training performance: {'loss': 0.14538445484358817, 'full sequence accuracy': 0.8481666666666666, 'first n-symbol accuracy': 0.9532715903758029, 'overlap rate': 0.9829112308776734}
# evaluation performance: {'loss': 1.353471457088987, 'full sequence accuracy': 0.5342666666666668, 'first n-symbol accuracy': 0.6926240909613188, 'overlap rate': 0.8515719909766958}
#
# Current epoch: 160,
# training performance: {'loss': 0.1508976063070198, 'full sequence accuracy': 0.7953666666666666, 'first n-symbol accuracy': 0.9523104945846709, 'overlap rate': 0.9812065143440422}
# evaluation performance: {'loss': 1.379099514335394, 'full sequence accuracy': 0.4896333333333333, 'first n-symbol accuracy': 0.6925281099527969, 'overlap rate': 0.8504713559906498}
#
# Current epoch: 170,
# training performance: {'loss': 0.12394848448069146, 'full sequence accuracy': 0.7636666666666666, 'first n-symbol accuracy': 0.9637667413478715, 'overlap rate': 0.9832936292185831}
# evaluation performance: {'loss': 1.3812216689189276, 'full sequence accuracy': 0.41373333333333334, 'first n-symbol accuracy': 0.6938856085052548, 'overlap rate': 0.8515740853255703}
#
# Current epoch: 180,
# training performance: {'loss': 0.07827768166704724, 'full sequence accuracy': 0.9419999999999998, 'first n-symbol accuracy': 0.9781155202357733, 'overlap rate': 0.9918593027858962}
# evaluation performance: {'loss': 1.3852396453420321, 'full sequence accuracy': 0.5589000000000001, 'first n-symbol accuracy': 0.7064799239009887, 'overlap rate': 0.8575909708421201}
#
# Current epoch: 190,
# training performance: {'loss': 0.13061513223995766, 'full sequence accuracy': 0.9257333333333333, 'first n-symbol accuracy': 0.9670887643168798, 'overlap rate': 0.9858653003373632}
# evaluation performance: {'loss': 1.4483080928524334, 'full sequence accuracy': 0.5446333333333333, 'first n-symbol accuracy': 0.7050388309349975, 'overlap rate': 0.8521515133877978}
#
# Current epoch: 200,
# training performance: {'loss': 0.12476341327031454, 'full sequence accuracy': 0.9353000000000001, 'first n-symbol accuracy': 0.961909530774222, 'overlap rate': 0.9877714097838651}
# evaluation performance: {'loss': 1.6609190036853154, 'full sequence accuracy': 0.4983666666666665, 'first n-symbol accuracy': 0.6564495313988499, 'overlap rate': 0.8386066194817053}
#
# Current epoch: 210,
# training performance: {'loss': 0.0854885184400094, 'full sequence accuracy': 0.9473666666666668, 'first n-symbol accuracy': 0.9760152693176252, 'overlap rate': 0.991055348903173}
# evaluation performance: {'loss': 1.400750916947921, 'full sequence accuracy': 0.5803999999999998, 'first n-symbol accuracy': 0.7135745738142762, 'overlap rate': 0.8602732567123146}
#
# Current epoch: 220,
# training performance: {'loss': 0.031605136823297166, 'full sequence accuracy': 0.9844666666666667, 'first n-symbol accuracy': 0.9905454554261979, 'overlap rate': 0.9971853787179529}
# evaluation performance: {'loss': 1.3094800606369972, 'full sequence accuracy': 0.6097, 'first n-symbol accuracy': 0.7268071127034476, 'overlap rate': 0.87445958566254}
#
# Current epoch: 230,
# training performance: {'loss': 0.006447977221493299, 'full sequence accuracy': 0.9972333333333333, 'first n-symbol accuracy': 0.9985787389915042, 'overlap rate': 0.9996640180995571}
# evaluation performance: {'loss': 1.141865972429514, 'full sequence accuracy': 0.6467999999999999, 'first n-symbol accuracy': 0.7529531298430527, 'overlap rate': 0.8916563836205319}
#
# Current epoch: 240,
# training performance: {'loss': 0.05818235794237504, 'full sequence accuracy': 0.9695666666666667, 'first n-symbol accuracy': 0.982498768884454, 'overlap rate': 0.99461561155985}
# evaluation performance: {'loss': 1.3500602548321088, 'full sequence accuracy': 0.6101000000000003, 'first n-symbol accuracy': 0.725559283464314, 'overlap rate': 0.8729209422214007}
#
# Current epoch: 250,
# training performance: {'loss': 0.04555531602042417, 'full sequence accuracy': 0.9779, 'first n-symbol accuracy': 0.9860979591684502, 'overlap rate': 0.9960254555900419}
# evaluation performance: {'loss': 1.4375213575859864, 'full sequence accuracy': 0.5883333333333334, 'first n-symbol accuracy': 0.7084445850074622, 'overlap rate': 0.8674764488899694}
#
# Current epoch: 260,
# training performance: {'loss': 0.04177092455793172, 'full sequence accuracy': 0.9748, 'first n-symbol accuracy': 0.9888207593725836, 'overlap rate': 0.9963189483788072}
# evaluation performance: {'loss': 1.3025590817133585, 'full sequence accuracy': 0.5946666666666667, 'first n-symbol accuracy': 0.7322216714304282, 'overlap rate': 0.8781715466974155}
#
# Current epoch: 270,
# training performance: {'loss': 0.029352746997998717, 'full sequence accuracy': 0.9830666666666665, 'first n-symbol accuracy': 0.9909513329558105, 'overlap rate': 0.9974158223124977}
# evaluation performance: {'loss': 1.259261818230152, 'full sequence accuracy': 0.6291999999999999, 'first n-symbol accuracy': 0.7438463094170817, 'overlap rate': 0.8833237805327453}
#
# Current epoch: 280,
# training performance: {'loss': 0.026412636037760725, 'full sequence accuracy': 0.9882666666666666, 'first n-symbol accuracy': 0.9924464572805893, 'overlap rate': 0.9977081908385041}
# evaluation performance: {'loss': 1.2276815876364708, 'full sequence accuracy': 0.6292666666666666, 'first n-symbol accuracy': 0.7479188437227994, 'overlap rate': 0.8878509436954052}
#
# Current epoch: 290,
# training performance: {'loss': 0.017657360585872084, 'full sequence accuracy': 0.9903666666666666, 'first n-symbol accuracy': 0.9944133685128789, 'overlap rate': 0.9986253854851622}
# evaluation performance: {'loss': 1.2611348862449328, 'full sequence accuracy': 0.6286666666666668, 'first n-symbol accuracy': 0.739888039362615, 'overlap rate': 0.8858583072848962}
#
# Current epoch: 300,
# training performance: {'loss': 0.019016928165607776, 'full sequence accuracy': 0.9864333333333332, 'first n-symbol accuracy': 0.9945930782755371, 'overlap rate': 0.9983540859483022}
# evaluation performance: {'loss': 1.2164562592903774, 'full sequence accuracy': 0.6333333333333332, 'first n-symbol accuracy': 0.7480079805892306, 'overlap rate': 0.8859136474200014}
#
# Current epoch: 310,
# training performance: {'loss': 0.027994494606779576, 'full sequence accuracy': 0.9859000000000002, 'first n-symbol accuracy': 0.9913321663102714, 'overlap rate': 0.9974511019396192}
# evaluation performance: {'loss': 1.2418013165394466, 'full sequence accuracy': 0.6408000000000001, 'first n-symbol accuracy': 0.7490214943641432, 'overlap rate': 0.8858268213146532}
#
# Current epoch: 320,
# training performance: {'loss': 0.0007756228510212774, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.8864766527277728, 'full sequence accuracy': 0.7067, 'first n-symbol accuracy': 0.8029763376215512, 'overlap rate': 0.9198178329383631}
#
# Current epoch: 330,
# training performance: {'loss': 0.0006764957467870166, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.7998260722340395, 'full sequence accuracy': 0.7254333333333332, 'first n-symbol accuracy': 0.8173806180311047, 'overlap rate': 0.9280175533506924}
#
# Current epoch: 340,
# training performance: {'loss': 0.0006641181404120289, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.7330332844828565, 'full sequence accuracy': 0.7406000000000001, 'first n-symbol accuracy': 0.8295374281520478, 'overlap rate': 0.9343781409960419}
#
# Current epoch: 350,
# training performance: {'loss': 0.0006646622219705023, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.6784367520517359, 'full sequence accuracy': 0.7542666666666666, 'first n-symbol accuracy': 0.8399267738834054, 'overlap rate': 0.9396560797283006}
#
# Current epoch: 360,
# training performance: {'loss': 0.0006685677406494505, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.6257510572827111, 'full sequence accuracy': 0.7691666666666667, 'first n-symbol accuracy': 0.8510835396898592, 'overlap rate': 0.9447119278312276}
#
# Current epoch: 370,
# training performance: {'loss': 0.05211268852775296, 'full sequence accuracy': 0.9842333333333334, 'first n-symbol accuracy': 0.9878566119453048, 'overlap rate': 0.996155280969446}
# evaluation performance: {'loss': 0.902574381728967, 'full sequence accuracy': 0.6956000000000002, 'first n-symbol accuracy': 0.7923833278704089, 'overlap rate': 0.9220611186724821}
#
# Current epoch: 380,
# training performance: {'loss': 0.11444837197583789, 'full sequence accuracy': 0.9442999999999999, 'first n-symbol accuracy': 0.9581382235656078, 'overlap rate': 0.9878267996472346}
# evaluation performance: {'loss': 1.0318424210573236, 'full sequence accuracy': 0.6440999999999999, 'first n-symbol accuracy': 0.7376822387005243, 'overlap rate': 0.8889684726535557}
#
# Current epoch: 390,
# training performance: {'loss': 0.03255543775934105, 'full sequence accuracy': 0.9819333333333334, 'first n-symbol accuracy': 0.9894721674917152, 'overlap rate': 0.9970698605235774}
# evaluation performance: {'loss': 0.940615049066643, 'full sequence accuracy': 0.6637000000000001, 'first n-symbol accuracy': 0.7707447759521038, 'overlap rate': 0.9042775863219782}
#
# Current epoch: 400,
# training performance: {'loss': 0.020891264783373723, 'full sequence accuracy': 0.9551, 'first n-symbol accuracy': 0.9925840226873023, 'overlap rate': 0.9975711111061378}
# evaluation performance: {'loss': 0.9492449995751182, 'full sequence accuracy': 0.6369666666666667, 'first n-symbol accuracy': 0.7769160962030478, 'overlap rate': 0.9043604542229173}
#
# Current epoch: 410,
# training performance: {'loss': 0.0011374523581859344, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.7368710088854035, 'full sequence accuracy': 0.7168333333333333, 'first n-symbol accuracy': 0.8193575004313526, 'overlap rate': 0.929708846288873}
#
# Current epoch: 420,
# training performance: {'loss': 0.0008071980109283079, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.6528061590002229, 'full sequence accuracy': 0.7475, 'first n-symbol accuracy': 0.8379276467154015, 'overlap rate': 0.9389664216540646}
#
# Current epoch: 430,
# training performance: {'loss': 0.0007222765552190442, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.6022247943406304, 'full sequence accuracy': 0.7651333333333334, 'first n-symbol accuracy': 0.8493173507532651, 'overlap rate': 0.9443722354120343}
#
# Current epoch: 440,
# training performance: {'loss': 0.0006818194970643769, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.5557460537490745, 'full sequence accuracy': 0.7802, 'first n-symbol accuracy': 0.8598513461541815, 'overlap rate': 0.9490751496846828}
#
# Current epoch: 450,
# training performance: {'loss': 0.0006563454357092269, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.514635364478454, 'full sequence accuracy': 0.7934000000000001, 'first n-symbol accuracy': 0.8689668752053993, 'overlap rate': 0.9532182817066303}
#
# Current epoch: 460,
# training performance: {'loss': 0.0006412121001631021, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.48683543666653956, 'full sequence accuracy': 0.8047333333333334, 'first n-symbol accuracy': 0.877032028337712, 'overlap rate': 0.9562731917394413}
#
# Current epoch: 470,
# training performance: {'loss': 0.04976930042806392, 'full sequence accuracy': 0.9831333333333335, 'first n-symbol accuracy': 0.9882068767427469, 'overlap rate': 0.9963191419241644}
# evaluation performance: {'loss': 0.7703438691794873, 'full sequence accuracy': 0.7185666666666669, 'first n-symbol accuracy': 0.8153559962924307, 'overlap rate': 0.932002683243923}
#
# Current epoch: 480,
# training performance: {'loss': 0.0721195988357067, 'full sequence accuracy': 0.9590666666666668, 'first n-symbol accuracy': 0.9727196525025475, 'overlap rate': 0.9924100516435945}
# evaluation performance: {'loss': 0.8510124016242723, 'full sequence accuracy': 0.6835333333333333, 'first n-symbol accuracy': 0.773873316450904, 'overlap rate': 0.9073665800233436}
#
# Current epoch: 490,
# training performance: {'loss': 0.02106378771713935, 'full sequence accuracy': 0.9825999999999999, 'first n-symbol accuracy': 0.9932655903315926, 'overlap rate': 0.9980573952991735}
# evaluation performance: {'loss': 0.7836763634656866, 'full sequence accuracy': 0.7029666666666667, 'first n-symbol accuracy': 0.804177484326351, 'overlap rate': 0.9198359414849926}
#
# Current epoch: 500,
# training performance: {'loss': 0.005258579298000162, 'full sequence accuracy': 0.996, 'first n-symbol accuracy': 0.9994032398170237, 'overlap rate': 0.9995212103212592}
# evaluation performance: {'loss': 0.6739543988679846, 'full sequence accuracy': 0.7114333333333336, 'first n-symbol accuracy': 0.8307470306928733, 'overlap rate': 0.9335648183142982}
#
# experiments/input_spec_red/LSTM/attn-less/3/model.pt saved!
#
# experiments/input_spec_red/LSTM/attn-less/3/training_log.json saved!
# experiments/input_spec_red/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/input_spec_red/LSTM/attn-less/3/training_plot.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
