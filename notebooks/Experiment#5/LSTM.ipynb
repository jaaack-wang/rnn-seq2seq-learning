# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = True
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 5
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#5 created!
# ./Experiments_Logs/Experiment#5/LSTM created!
# ./Experiments_Logs/Experiment#5/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#5/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#5/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#5 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.8765927791595458, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.11304338844493031, 'overlap rate': 0.3963616415858269}
# evaluation performance: {'loss': 2.433229234814644, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.13421213459223508, 'overlap rate': 0.2538124691694975}
#
# Current epoch: 10,
# training performance: {'loss': 1.1664701700210571, 'abosulate accuracy': 0.01030000060563907, 'consecutive overlap rate': 0.215537996776402, 'overlap rate': 0.5983186028897762}
# evaluation performance: {'loss': 2.3511576622724535, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.21336239017546177, 'overlap rate': 0.35552110373973844}
#
# Current epoch: 15,
# training performance: {'loss': 0.9126443080604076, 'abosulate accuracy': 0.028100001416169106, 'consecutive overlap rate': 0.27558484543114903, 'overlap rate': 0.6803777411580085}
# evaluation performance: {'loss': 2.455522784590721, 'abosulate accuracy': 0.00045000002719461916, 'consecutive overlap rate': 0.242410203628242, 'overlap rate': 0.40217667892575265}
#
# Current epoch: 20,
# training performance: {'loss': 0.7255166314542294, 'abosulate accuracy': 0.08720000449102372, 'consecutive overlap rate': 0.3462210772559047, 'overlap rate': 0.7445182174444198}
# evaluation performance: {'loss': 2.333805423974991, 'abosulate accuracy': 0.015650000574532898, 'consecutive overlap rate': 0.2614912023767829, 'overlap rate': 0.44823299795389177}
#
# Current epoch: 25,
# training performance: {'loss': 0.6122991945594549, 'abosulate accuracy': 0.13590000595431775, 'consecutive overlap rate': 0.3877440795302391, 'overlap rate': 0.7826553747057915}
# evaluation performance: {'loss': 2.543221506476402, 'abosulate accuracy': 0.018000000272877514, 'consecutive overlap rate': 0.2700997581705451, 'overlap rate': 0.4580612577497959}
#
# Current epoch: 30,
# training performance: {'loss': 0.5646798279136419, 'abosulate accuracy': 0.157600008090958, 'consecutive overlap rate': 0.41225470751523974, 'overlap rate': 0.8004774391651154}
# evaluation performance: {'loss': 2.5095205873250963, 'abosulate accuracy': 0.02485000104061328, 'consecutive overlap rate': 0.26731484830379487, 'overlap rate': 0.4667446367442608}
#
# Current epoch: 35,
# training performance: {'loss': 0.4873460942879319, 'abosulate accuracy': 0.1886000090278685, 'consecutive overlap rate': 0.4389690261334181, 'overlap rate': 0.8265493482351303}
# evaluation performance: {'loss': 2.75357725918293, 'abosulate accuracy': 0.02155000137863681, 'consecutive overlap rate': 0.27713471055030825, 'overlap rate': 0.4695317894220352}
#
# Current epoch: 40,
# training performance: {'loss': 0.5032504642382264, 'abosulate accuracy': 0.1607000077026896, 'consecutive overlap rate': 0.407667276263237, 'overlap rate': 0.8190012529492379}
# evaluation performance: {'loss': 2.9796492874622347, 'abosulate accuracy': 0.015850000723730773, 'consecutive overlap rate': 0.24693484883755445, 'overlap rate': 0.4502605952322483}
#
# Current epoch: 45,
# training performance: {'loss': 0.4692831328138709, 'abosulate accuracy': 0.2069000073708594, 'consecutive overlap rate': 0.4466721773147583, 'overlap rate': 0.8319508820772171}
# evaluation performance: {'loss': 2.7540325224399567, 'abosulate accuracy': 0.03680000166059472, 'consecutive overlap rate': 0.2682700170204043, 'overlap rate': 0.4892063573002815}
#
# Current epoch: 50,
# training performance: {'loss': 0.42585543682798743, 'abosulate accuracy': 0.22890000957995654, 'consecutive overlap rate': 0.46493954546749594, 'overlap rate': 0.8485645696520805}
# evaluation performance: {'loss': 2.9389254465699195, 'abosulate accuracy': 0.02955000182846561, 'consecutive overlap rate': 0.25186584182083604, 'overlap rate': 0.4723331741988659}
#
# Current epoch: 55,
# training performance: {'loss': 0.3359237581025809, 'abosulate accuracy': 0.2806000143289566, 'consecutive overlap rate': 0.5096647065132857, 'overlap rate': 0.879527997970581}
# evaluation performance: {'loss': 2.9207425266504288, 'abosulate accuracy': 0.033050001785159114, 'consecutive overlap rate': 0.26798994150012734, 'overlap rate': 0.49053768292069433}
#
# Current epoch: 60,
# training performance: {'loss': 0.28615514021366834, 'abosulate accuracy': 0.2874000139301643, 'consecutive overlap rate': 0.5207095667719841, 'overlap rate': 0.8973404332995415}
# evaluation performance: {'loss': 3.0432560473680494, 'abosulate accuracy': 0.037900001741945744, 'consecutive overlap rate': 0.2729098107665777, 'overlap rate': 0.4988011747598648}
#
# Current epoch: 65,
# training performance: {'loss': 0.245894768438302, 'abosulate accuracy': 0.29030001456849275, 'consecutive overlap rate': 0.5271389320492744, 'overlap rate': 0.9122888520359993}
# evaluation performance: {'loss': 3.26975893676281, 'abosulate accuracy': 0.03635000110953115, 'consecutive overlap rate': 0.2575925275683403, 'overlap rate': 0.49102634489536284}
#
# Current epoch: 70,
# training performance: {'loss': 0.2580690092407167, 'abosulate accuracy': 0.2688000112073496, 'consecutive overlap rate': 0.5080136522650719, 'overlap rate': 0.9067477688193322}
# evaluation performance: {'loss': 3.3674711853265764, 'abosulate accuracy': 0.03640000080922619, 'consecutive overlap rate': 0.2654379678890109, 'overlap rate': 0.49111745581030847}
#
# Current epoch: 75,
# training performance: {'loss': 0.1975331769324839, 'abosulate accuracy': 0.33450001657474787, 'consecutive overlap rate': 0.5622444048523902, 'overlap rate': 0.9306131392717362}
# evaluation performance: {'loss': 3.561243122816086, 'abosulate accuracy': 0.035450001573190094, 'consecutive overlap rate': 0.25879262052476404, 'overlap rate': 0.49102202132344247}
#
# Current epoch: 80,
# training performance: {'loss': 0.1884654732886702, 'abosulate accuracy': 0.31290001710876825, 'consecutive overlap rate': 0.5549019180238247, 'overlap rate': 0.9327538028359413}
# evaluation performance: {'loss': 3.6380797803401945, 'abosulate accuracy': 0.030400001001544295, 'consecutive overlap rate': 0.2617986839264631, 'overlap rate': 0.4913678951561451}
#
# Current epoch: 85,
# training performance: {'loss': 0.15800337288528682, 'abosulate accuracy': 0.3548000216949731, 'consecutive overlap rate': 0.6020334854722023, 'overlap rate': 0.9449184611439705}
# evaluation performance: {'loss': 3.8456010103225706, 'abosulate accuracy': 0.031200001400429757, 'consecutive overlap rate': 0.2562902620062232, 'overlap rate': 0.48514206111431124}
#
# Current epoch: 90,
# training performance: {'loss': 0.16742053399793805, 'abosulate accuracy': 0.32870001629926265, 'consecutive overlap rate': 0.5745585341006517, 'overlap rate': 0.9407020822167397}
# evaluation performance: {'loss': 3.957219663262367, 'abosulate accuracy': 0.029600001900689676, 'consecutive overlap rate': 0.25829442832618954, 'overlap rate': 0.4872840762138367}
#
# Current epoch: 95,
# training performance: {'loss': 0.14806994483806193, 'abosulate accuracy': 0.36210001616273074, 'consecutive overlap rate': 0.6084296770393849, 'overlap rate': 0.9479040846228599}
# evaluation performance: {'loss': 4.049475598335266, 'abosulate accuracy': 0.026550000830320643, 'consecutive overlap rate': 0.25534047149121764, 'overlap rate': 0.4818536266684532}
#
# Current epoch: 100,
# training performance: {'loss': 0.16113622677512468, 'abosulate accuracy': 0.34350001366110516, 'consecutive overlap rate': 0.5799253564327955, 'overlap rate': 0.9423176318407058}
# evaluation performance: {'loss': 4.342513543367386, 'abosulate accuracy': 0.0196500011079479, 'consecutive overlap rate': 0.247584018856287, 'overlap rate': 0.4674042649567127}
#
# Current epoch: 105,
# training performance: {'loss': 0.13862778022885322, 'abosulate accuracy': 0.3641000189003535, 'consecutive overlap rate': 0.6076013810932637, 'overlap rate': 0.9513678148388862}
# evaluation performance: {'loss': 4.387948012351989, 'abosulate accuracy': 0.024300001631490886, 'consecutive overlap rate': 0.2511407433077693, 'overlap rate': 0.47519061267375945}
#
# Current epoch: 110,
# training performance: {'loss': 0.16297482242807745, 'abosulate accuracy': 0.3298000169568695, 'consecutive overlap rate': 0.5740401823073625, 'overlap rate': 0.9415868163108826}
# evaluation performance: {'loss': 4.464023014903068, 'abosulate accuracy': 0.025800000462913884, 'consecutive overlap rate': 0.2474149802699685, 'overlap rate': 0.46617069020867347}
#
# Current epoch: 115,
# training performance: {'loss': 0.13353409501723945, 'abosulate accuracy': 0.35610001559834925, 'consecutive overlap rate': 0.6048737339675426, 'overlap rate': 0.9528165251016617}
# evaluation performance: {'loss': 4.559010499715805, 'abosulate accuracy': 0.02305000110063702, 'consecutive overlap rate': 0.24987119641155003, 'overlap rate': 0.46893700435757635}
#
# Current epoch: 120,
# training performance: {'loss': 0.15916070956736802, 'abosulate accuracy': 0.31820001687156035, 'consecutive overlap rate': 0.5560489933937788, 'overlap rate': 0.9429031074047088}
# evaluation performance: {'loss': 4.611494055390358, 'abosulate accuracy': 0.027400001644855364, 'consecutive overlap rate': 0.24776908438652753, 'overlap rate': 0.47041155099868776}
#
# Current epoch: 125,
# training performance: {'loss': 0.13524683131836354, 'abosulate accuracy': 0.3638000199920498, 'consecutive overlap rate': 0.606885764747858, 'overlap rate': 0.9519460335373878}
# evaluation performance: {'loss': 4.67358889579773, 'abosulate accuracy': 0.027300001517869533, 'consecutive overlap rate': 0.24766923747956754, 'overlap rate': 0.469199039041996}
#
# Current epoch: 130,
# training performance: {'loss': 0.12108004454057664, 'abosulate accuracy': 0.3736000164994039, 'consecutive overlap rate': 0.618283511698246, 'overlap rate': 0.9574298337101936}
# evaluation performance: {'loss': 4.67371433377266, 'abosulate accuracy': 0.03125000155414455, 'consecutive overlap rate': 0.25427682176232336, 'overlap rate': 0.47783219665288923}
#
# Current epoch: 135,
# training performance: {'loss': 0.13428930791560562, 'abosulate accuracy': 0.37050001859897747, 'consecutive overlap rate': 0.5993891760706902, 'overlap rate': 0.9522390574216842}
# evaluation performance: {'loss': 4.715075615048408, 'abosulate accuracy': 0.033300001866882666, 'consecutive overlap rate': 0.25563004296272995, 'overlap rate': 0.48204432129859925}
#
# Current epoch: 140,
# training performance: {'loss': 0.1336905015865341, 'abosulate accuracy': 0.36050001517869534, 'consecutive overlap rate': 0.5994349859654904, 'overlap rate': 0.95233885794878}
# evaluation performance: {'loss': 4.8211409747600555, 'abosulate accuracy': 0.03020000128308311, 'consecutive overlap rate': 0.24892972279340028, 'overlap rate': 0.47341000437736513}
#
# Current epoch: 145,
# training performance: {'loss': 0.08745116433128715, 'abosulate accuracy': 0.44140002098865805, 'consecutive overlap rate': 0.686040610074997, 'overlap rate': 0.9700060248374939}
# evaluation performance: {'loss': 4.771321108937263, 'abosulate accuracy': 0.03965000124881044, 'consecutive overlap rate': 0.2638488387688994, 'overlap rate': 0.49209258854389193}
#
# Current epoch: 150,
# training performance: {'loss': 0.0660082516609691, 'abosulate accuracy': 0.5020000230520963, 'consecutive overlap rate': 0.7384897887706756, 'overlap rate': 0.9785382613539696}
# evaluation performance: {'loss': 4.870222344994545, 'abosulate accuracy': 0.03925000192830339, 'consecutive overlap rate': 0.257945585437119, 'overlap rate': 0.4906241945922375}
#
# Current epoch: 155,
# training performance: {'loss': 0.05568839239422232, 'abosulate accuracy': 0.5441000254824757, 'consecutive overlap rate': 0.7628813311457634, 'overlap rate': 0.9826292768120766}
# evaluation performance: {'loss': 5.053064447641373, 'abosulate accuracy': 0.039600002329098064, 'consecutive overlap rate': 0.26177533958107235, 'overlap rate': 0.4933939628303051}
#
# Current epoch: 160,
# training performance: {'loss': 0.046918368886690584, 'abosulate accuracy': 0.5834000237286091, 'consecutive overlap rate': 0.7959525406360626, 'overlap rate': 0.9857320725917816}
# evaluation performance: {'loss': 5.178185468912124, 'abosulate accuracy': 0.036350001947721464, 'consecutive overlap rate': 0.2643579974770546, 'overlap rate': 0.49299024790525436}
#
# Current epoch: 165,
# training performance: {'loss': 0.031800778344040735, 'abosulate accuracy': 0.6831000313162804, 'consecutive overlap rate': 0.8622328281402588, 'overlap rate': 0.9913220420479775}
# evaluation performance: {'loss': 5.2232934653759004, 'abosulate accuracy': 0.042950001882854846, 'consecutive overlap rate': 0.2673112677410245, 'overlap rate': 0.49790147319436073}
#
# Current epoch: 170,
# training performance: {'loss': 0.042222104080428834, 'abosulate accuracy': 0.6127000261098147, 'consecutive overlap rate': 0.8103386789560318, 'overlap rate': 0.9870477139949798}
# evaluation performance: {'loss': 5.38932945728302, 'abosulate accuracy': 0.03935000237543136, 'consecutive overlap rate': 0.264167351834476, 'overlap rate': 0.4943616218864918}
#
# Current epoch: 175,
# training performance: {'loss': 0.08927400531829335, 'abosulate accuracy': 0.4263000214006752, 'consecutive overlap rate': 0.6596271626651287, 'overlap rate': 0.9680684134364128}
# evaluation performance: {'loss': 5.51142965555191, 'abosulate accuracy': 0.03250000097323209, 'consecutive overlap rate': 0.2563018513843417, 'overlap rate': 0.4807904869318008}
#
# Current epoch: 180,
# training performance: {'loss': 0.11783453894313425, 'abosulate accuracy': 0.36470001747366043, 'consecutive overlap rate': 0.6063481815159321, 'overlap rate': 0.957774268090725}
# evaluation performance: {'loss': 5.366112571954727, 'abosulate accuracy': 0.033100001612911004, 'consecutive overlap rate': 0.26038817819207905, 'overlap rate': 0.4858304873108864}
#
# Current epoch: 185,
# training performance: {'loss': 0.09862876748666168, 'abosulate accuracy': 0.39840001966804267, 'consecutive overlap rate': 0.6387372970581054, 'overlap rate': 0.9646609768271446}
# evaluation performance: {'loss': 5.349862819910049, 'abosulate accuracy': 0.036350001447135585, 'consecutive overlap rate': 0.26128454841673376, 'overlap rate': 0.4885496273636818}
#
# Current epoch: 190,
# training performance: {'loss': 0.06046055967453867, 'abosulate accuracy': 0.5116000231355429, 'consecutive overlap rate': 0.7395159035921097, 'overlap rate': 0.979856614768505}
# evaluation performance: {'loss': 5.357419392466545, 'abosulate accuracy': 0.038900001550791784, 'consecutive overlap rate': 0.2663543101400137, 'overlap rate': 0.49707758501172067}
#
# Current epoch: 195,
# training performance: {'loss': 0.04151263632811606, 'abosulate accuracy': 0.5998000290244818, 'consecutive overlap rate': 0.8143895044922829, 'overlap rate': 0.9871384516358376}
# evaluation performance: {'loss': 5.601015901565551, 'abosulate accuracy': 0.037150002137059344, 'consecutive overlap rate': 0.2628503292798996, 'overlap rate': 0.4890802286565304}
#
# Current epoch: 200,
# training performance: {'loss': 0.04416054501198232, 'abosulate accuracy': 0.580000028386712, 'consecutive overlap rate': 0.7941515102982522, 'overlap rate': 0.9855600729584694}
# evaluation performance: {'loss': 5.593265902996063, 'abosulate accuracy': 0.039350001700222494, 'consecutive overlap rate': 0.2628428412601352, 'overlap rate': 0.49364606738090516}
#
# Experiments_Logs/Experiment#5/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 8.75089971423149, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006126172401127406, 'overlap rate': 0.04113757500890643}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.8345149755477905, 'abosulate accuracy': 0.049125002030632456, 'consecutive overlap rate': 0.2801278611645103, 'overlap rate': 0.5112178511917591}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 8.511115941693706, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0046075949024769565, 'overlap rate': 0.03777900933017654}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.3025493433600976, 'abosulate accuracy': 0.0604736857900494, 'consecutive overlap rate': 0.23646370341119013, 'overlap rate': 0.40090760941568176}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9748925656080245, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.11610918026417494, 'overlap rate': 0.37710096016526223}
# evaluation performance: {'loss': 2.467494544386864, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.13352624382823705, 'overlap rate': 0.25396466851234434}
#
# Current epoch: 10,
# training performance: {'loss': 1.0454563066363334, 'abosulate accuracy': 0.0243000004789792, 'consecutive overlap rate': 0.2576216546818614, 'overlap rate': 0.6501162208616733}
# evaluation performance: {'loss': 2.1152784556150435, 'abosulate accuracy': 0.003350000182399526, 'consecutive overlap rate': 0.25440284982323647, 'overlap rate': 0.42277529202401637}
#
# Current epoch: 15,
# training performance: {'loss': 0.7942033499479294, 'abosulate accuracy': 0.08450000517768785, 'consecutive overlap rate': 0.33634951859712603, 'overlap rate': 0.7317945376038552}
# evaluation performance: {'loss': 2.2316015481948854, 'abosulate accuracy': 0.00750000033294782, 'consecutive overlap rate': 0.27760126870125534, 'overlap rate': 0.4648373030126095}
#
# Current epoch: 20,
# training performance: {'loss': 0.6585774395614863, 'abosulate accuracy': 0.12340000499971211, 'consecutive overlap rate': 0.38450014516711234, 'overlap rate': 0.7745967373251915}
# evaluation performance: {'loss': 2.33251433968544, 'abosulate accuracy': 0.014250000525498763, 'consecutive overlap rate': 0.27751487754285337, 'overlap rate': 0.480933653563261}
#
# Current epoch: 25,
# training performance: {'loss': 0.5740371447056531, 'abosulate accuracy': 0.14380000905366613, 'consecutive overlap rate': 0.4140545479953289, 'overlap rate': 0.8009586706757545}
# evaluation performance: {'loss': 2.270914909243584, 'abosulate accuracy': 0.02255000103614293, 'consecutive overlap rate': 0.302211057767272, 'overlap rate': 0.5057055845856666}
#
# Current epoch: 30,
# training performance: {'loss': 0.4750123701989651, 'abosulate accuracy': 0.21140000922605395, 'consecutive overlap rate': 0.4559584654867649, 'overlap rate': 0.8345406949520111}
# evaluation performance: {'loss': 2.3482317209243773, 'abosulate accuracy': 0.028450001421151682, 'consecutive overlap rate': 0.302421198040247, 'overlap rate': 0.5163145966827869}
#
# Current epoch: 35,
# training performance: {'loss': 0.43624068070203065, 'abosulate accuracy': 0.20630000884411856, 'consecutive overlap rate': 0.46535520926117896, 'overlap rate': 0.8465748444199562}
# evaluation performance: {'loss': 2.3903419032692907, 'abosulate accuracy': 0.03920000210637227, 'consecutive overlap rate': 0.2973137008026242, 'overlap rate': 0.5237451441586017}
#
# Current epoch: 40,
# training performance: {'loss': 0.4176052831113338, 'abosulate accuracy': 0.22370000844821333, 'consecutive overlap rate': 0.46936653926968575, 'overlap rate': 0.853126983344555}
# evaluation performance: {'loss': 2.7611319929361344, 'abosulate accuracy': 0.02625000160187483, 'consecutive overlap rate': 0.2830095313489437, 'overlap rate': 0.5001432873308659}
#
# Current epoch: 45,
# training performance: {'loss': 0.4066646616905928, 'abosulate accuracy': 0.20920000951737167, 'consecutive overlap rate': 0.46808079183101653, 'overlap rate': 0.8572541534900665}
# evaluation performance: {'loss': 2.797605201601982, 'abosulate accuracy': 0.03480000104755163, 'consecutive overlap rate': 0.2967619737610221, 'overlap rate': 0.5172657281160354}
#
# Current epoch: 50,
# training performance: {'loss': 0.36492155995219944, 'abosulate accuracy': 0.24780001100152732, 'consecutive overlap rate': 0.49772550314664843, 'overlap rate': 0.8720005422830581}
# evaluation performance: {'loss': 2.6666257113218306, 'abosulate accuracy': 0.04615000144112855, 'consecutive overlap rate': 0.2965872701257467, 'overlap rate': 0.5266113676130771}
#
# Current epoch: 55,
# training performance: {'loss': 0.26986878653988244, 'abosulate accuracy': 0.3162000156706199, 'consecutive overlap rate': 0.5469526670873165, 'overlap rate': 0.905987249314785}
# evaluation performance: {'loss': 2.7932774096727373, 'abosulate accuracy': 0.044100002059713005, 'consecutive overlap rate': 0.29686716180294753, 'overlap rate': 0.5387964703142643}
#
# Current epoch: 60,
# training performance: {'loss': 0.2251463898923248, 'abosulate accuracy': 0.33710001220460983, 'consecutive overlap rate': 0.5581804890185594, 'overlap rate': 0.9212959289550782}
# evaluation performance: {'loss': 2.932162865996361, 'abosulate accuracy': 0.06470000286353753, 'consecutive overlap rate': 0.310115216486156, 'overlap rate': 0.547457555681467}
#
# Current epoch: 65,
# training performance: {'loss': 0.2028407075908035, 'abosulate accuracy': 0.3181000160053372, 'consecutive overlap rate': 0.5581668745726347, 'overlap rate': 0.9287093624472618}
# evaluation performance: {'loss': 3.2726992696523665, 'abosulate accuracy': 0.04580000217538327, 'consecutive overlap rate': 0.29235480930656194, 'overlap rate': 0.527354059368372}
#
# Current epoch: 70,
# training performance: {'loss': 0.18628588397987186, 'abosulate accuracy': 0.3337000168277882, 'consecutive overlap rate': 0.574606092646718, 'overlap rate': 0.9342746034264564}
# evaluation performance: {'loss': 3.3220016598701476, 'abosulate accuracy': 0.0473500017717015, 'consecutive overlap rate': 0.30241845957934854, 'overlap rate': 0.5390586107969284}
#
# Current epoch: 75,
# training performance: {'loss': 0.1710624385625124, 'abosulate accuracy': 0.355800018843729, 'consecutive overlap rate': 0.5904047284275293, 'overlap rate': 0.9404188022017479}
# evaluation performance: {'loss': 3.4458261668682098, 'abosulate accuracy': 0.04900000165798701, 'consecutive overlap rate': 0.2926198622211814, 'overlap rate': 0.5323230624198914}
#
# Current epoch: 80,
# training performance: {'loss': 0.1583274835254997, 'abosulate accuracy': 0.36750001648906616, 'consecutive overlap rate': 0.5918619215488434, 'overlap rate': 0.9445024117827415}
# evaluation performance: {'loss': 3.542599707841873, 'abosulate accuracy': 0.04295000095153227, 'consecutive overlap rate': 0.2987426821142435, 'overlap rate': 0.5327868424355984}
#
# Current epoch: 85,
# training performance: {'loss': 0.14293786019552499, 'abosulate accuracy': 0.37080001981230454, 'consecutive overlap rate': 0.6025034379214048, 'overlap rate': 0.9503826096653938}
# evaluation performance: {'loss': 3.5881384700536727, 'abosulate accuracy': 0.04585000219522044, 'consecutive overlap rate': 0.29737126678228376, 'overlap rate': 0.5334822468459606}
#
# Current epoch: 90,
# training performance: {'loss': 0.1348078111652285, 'abosulate accuracy': 0.3719000166049227, 'consecutive overlap rate': 0.62288171723485, 'overlap rate': 0.9527634456753731}
# evaluation performance: {'loss': 3.759094035625458, 'abosulate accuracy': 0.04120000168913975, 'consecutive overlap rate': 0.29828366339206697, 'overlap rate': 0.5289822854101658}
#
# Current epoch: 95,
# training performance: {'loss': 0.15514977360144258, 'abosulate accuracy': 0.3398000165820122, 'consecutive overlap rate': 0.5900591723620892, 'overlap rate': 0.9445416107773781}
# evaluation performance: {'loss': 3.8690951347351072, 'abosulate accuracy': 0.04360000198939815, 'consecutive overlap rate': 0.29215738363564014, 'overlap rate': 0.5220713131129742}
#
# Current epoch: 100,
# training performance: {'loss': 0.14265815359540285, 'abosulate accuracy': 0.35410001429263505, 'consecutive overlap rate': 0.6003456227481365, 'overlap rate': 0.9488640695810318}
# evaluation performance: {'loss': 4.099143967032433, 'abosulate accuracy': 0.033100001030834394, 'consecutive overlap rate': 0.2833029808476567, 'overlap rate': 0.5107411690056324}
#
# Current epoch: 105,
# training performance: {'loss': 0.15097181487362832, 'abosulate accuracy': 0.35020001551602037, 'consecutive overlap rate': 0.5919405825436115, 'overlap rate': 0.9465438172221183}
# evaluation performance: {'loss': 4.126204890012741, 'abosulate accuracy': 0.03440000122063793, 'consecutive overlap rate': 0.2820320188999176, 'overlap rate': 0.5153498217463494}
#
# Current epoch: 110,
# training performance: {'loss': 0.1359449630137533, 'abosulate accuracy': 0.35870001557050274, 'consecutive overlap rate': 0.6184016458690167, 'overlap rate': 0.9516125649213791}
# evaluation performance: {'loss': 3.9687559217214585, 'abosulate accuracy': 0.054300002462696284, 'consecutive overlap rate': 0.29442058354616163, 'overlap rate': 0.5323268204927445}
#
# Current epoch: 115,
# training performance: {'loss': 0.09502390469424427, 'abosulate accuracy': 0.4299000218510628, 'consecutive overlap rate': 0.6793063625693321, 'overlap rate': 0.9680821746587753}
# evaluation performance: {'loss': 4.014005821943283, 'abosulate accuracy': 0.058900003373855724, 'consecutive overlap rate': 0.30069793462753297, 'overlap rate': 0.5410366706550122}
#
# Current epoch: 120,
# training performance: {'loss': 0.0636256717494689, 'abosulate accuracy': 0.5123000223189592, 'consecutive overlap rate': 0.7566740483045578, 'overlap rate': 0.9802739918231964}
# evaluation performance: {'loss': 4.184557965397834, 'abosulate accuracy': 0.0629500021226704, 'consecutive overlap rate': 0.30061486680060623, 'overlap rate': 0.5418873101472854}
#
# Current epoch: 125,
# training performance: {'loss': 0.05834945705137216, 'abosulate accuracy': 0.5404000239446759, 'consecutive overlap rate': 0.7634230442345142, 'overlap rate': 0.9816052541136742}
# evaluation performance: {'loss': 4.4381529748439785, 'abosulate accuracy': 0.0569000024930574, 'consecutive overlap rate': 0.29490540027618406, 'overlap rate': 0.5340384230017662}
#
# Current epoch: 130,
# training performance: {'loss': 0.06411752711283043, 'abosulate accuracy': 0.5103000236675144, 'consecutive overlap rate': 0.7307169497013092, 'overlap rate': 0.9789864301681519}
# evaluation performance: {'loss': 4.45732626914978, 'abosulate accuracy': 0.060900002525886524, 'consecutive overlap rate': 0.3004645086824894, 'overlap rate': 0.5383921980857849}
#
# Current epoch: 135,
# training performance: {'loss': 0.08403200376778841, 'abosulate accuracy': 0.44740002185571937, 'consecutive overlap rate': 0.6772196024656296, 'overlap rate': 0.9708586066961289}
# evaluation performance: {'loss': 4.54211228787899, 'abosulate accuracy': 0.0559000026260037, 'consecutive overlap rate': 0.2967132840305567, 'overlap rate': 0.5345198765397072}
#
# Current epoch: 140,
# training performance: {'loss': 0.10405369375366717, 'abosulate accuracy': 0.40190001763403416, 'consecutive overlap rate': 0.6404087044298649, 'overlap rate': 0.9631177335977554}
# evaluation performance: {'loss': 4.567012444138527, 'abosulate accuracy': 0.052450003114063296, 'consecutive overlap rate': 0.29102373998612163, 'overlap rate': 0.5319785431027413}
#
# Current epoch: 145,
# training performance: {'loss': 0.08090065022697672, 'abosulate accuracy': 0.4475000208709389, 'consecutive overlap rate': 0.6887089222669601, 'overlap rate': 0.9717858150601387}
# evaluation performance: {'loss': 4.581136840581894, 'abosulate accuracy': 0.056450002256315204, 'consecutive overlap rate': 0.29382622689008714, 'overlap rate': 0.5362153463065624}
#
# Current epoch: 150,
# training performance: {'loss': 0.06371591651113703, 'abosulate accuracy': 0.4939000254496932, 'consecutive overlap rate': 0.7265991531312466, 'overlap rate': 0.9782157644629479}
# evaluation performance: {'loss': 4.6140499204397205, 'abosulate accuracy': 0.062150002078851685, 'consecutive overlap rate': 0.3005564037710428, 'overlap rate': 0.5409559786319733}
#
# Current epoch: 155,
# training performance: {'loss': 0.050622290658066046, 'abosulate accuracy': 0.5546000231057405, 'consecutive overlap rate': 0.7709473267197609, 'overlap rate': 0.983645287156105}
# evaluation performance: {'loss': 4.7298251539468765, 'abosulate accuracy': 0.0646000026841648, 'consecutive overlap rate': 0.29765772968530657, 'overlap rate': 0.5409731477499008}
#
# Current epoch: 160,
# training performance: {'loss': 0.043308507523033765, 'abosulate accuracy': 0.5900000259280205, 'consecutive overlap rate': 0.7958444282412529, 'overlap rate': 0.9862896546721458}
# evaluation performance: {'loss': 4.831376048922539, 'abosulate accuracy': 0.06220000307657756, 'consecutive overlap rate': 0.3019040374085307, 'overlap rate': 0.5458655506372452}
#
# Current epoch: 165,
# training performance: {'loss': 0.056880987831391394, 'abosulate accuracy': 0.5181000240147113, 'consecutive overlap rate': 0.749083636701107, 'overlap rate': 0.9807546883821487}
# evaluation performance: {'loss': 4.8998924642801285, 'abosulate accuracy': 0.06460000205552205, 'consecutive overlap rate': 0.29986799471080305, 'overlap rate': 0.5430986128747464}
#
# Current epoch: 170,
# training performance: {'loss': 0.053677263855934146, 'abosulate accuracy': 0.5287000255659222, 'consecutive overlap rate': 0.7588730119168758, 'overlap rate': 0.981675261259079}
# evaluation performance: {'loss': 4.959652206301689, 'abosulate accuracy': 0.061050001461990175, 'consecutive overlap rate': 0.3031206352636218, 'overlap rate': 0.5432257167994976}
#
# Current epoch: 175,
# training performance: {'loss': 0.09259701409609988, 'abosulate accuracy': 0.4238000188488513, 'consecutive overlap rate': 0.6639776051044464, 'overlap rate': 0.967330864071846}
# evaluation performance: {'loss': 4.981723350286484, 'abosulate accuracy': 0.05580000294139609, 'consecutive overlap rate': 0.29924581591039895, 'overlap rate': 0.5389289446175098}
#
# Current epoch: 180,
# training performance: {'loss': 0.13859200733713806, 'abosulate accuracy': 0.3549000185681507, 'consecutive overlap rate': 0.5862525280565023, 'overlap rate': 0.9510945722460746}
# evaluation performance: {'loss': 4.832175603508949, 'abosulate accuracy': 0.05680000230204314, 'consecutive overlap rate': 0.29805690366774795, 'overlap rate': 0.5381699442863465}
#
# Current epoch: 185,
# training performance: {'loss': 0.10201551837380976, 'abosulate accuracy': 0.3961000207578763, 'consecutive overlap rate': 0.6384319834411144, 'overlap rate': 0.9634252205491066}
# evaluation performance: {'loss': 4.8283292800188065, 'abosulate accuracy': 0.05230000203009695, 'consecutive overlap rate': 0.29650125931948423, 'overlap rate': 0.5353205189108848}
#
# Current epoch: 190,
# training performance: {'loss': 0.04788629646645859, 'abosulate accuracy': 0.5650000285357237, 'consecutive overlap rate': 0.7863249942660332, 'overlap rate': 0.9845424428582191}
# evaluation performance: {'loss': 4.828376546502113, 'abosulate accuracy': 0.05815000249422155, 'consecutive overlap rate': 0.3053347334265709, 'overlap rate': 0.5464412420988083}
#
# Current epoch: 195,
# training performance: {'loss': 0.04414299911586568, 'abosulate accuracy': 0.5823000248521566, 'consecutive overlap rate': 0.8010701537132263, 'overlap rate': 0.9856284067034722}
# evaluation performance: {'loss': 4.950430417060852, 'abosulate accuracy': 0.06285000286297873, 'consecutive overlap rate': 0.3050736103206873, 'overlap rate': 0.5466113828122616}
#
# Current epoch: 200,
# training performance: {'loss': 0.03949534855782986, 'abosulate accuracy': 0.6062000304460525, 'consecutive overlap rate': 0.8109573125839233, 'overlap rate': 0.9872509330511093}
# evaluation performance: {'loss': 5.084014976024628, 'abosulate accuracy': 0.06775000239140354, 'consecutive overlap rate': 0.3001998446881771, 'overlap rate': 0.5473897524178029}
#
# Experiments_Logs/Experiment#5/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 14.257932698726654, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005847500071104151, 'overlap rate': 0.048865421768277885}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.340069296956062, 'abosulate accuracy': 0.06445000356179661, 'consecutive overlap rate': 0.30276335068047044, 'overlap rate': 0.5444470465183258}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 14.124946132782966, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004395947072114195, 'overlap rate': 0.04805982124901587}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.135897297608225, 'abosulate accuracy': 0.1072105326150593, 'consecutive overlap rate': 0.2662124531833749, 'overlap rate': 0.4450685675991209}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.8793027758598329, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11105746598914265, 'overlap rate': 0.4096128985285759}
# evaluation performance: {'loss': 2.530753806233406, 'abosulate accuracy': 0.00035000001662410796, 'consecutive overlap rate': 0.12982592890039085, 'overlap rate': 0.2614211842417717}
#
# Current epoch: 10,
# training performance: {'loss': 1.1395718179643155, 'abosulate accuracy': 0.02270000152057037, 'consecutive overlap rate': 0.21887714546173812, 'overlap rate': 0.6034479603171349}
# evaluation performance: {'loss': 2.486048722267151, 'abosulate accuracy': 0.0017000000807456672, 'consecutive overlap rate': 0.2164663912728429, 'overlap rate': 0.35886182449758053}
#
# Current epoch: 15,
# training performance: {'loss': 0.9524848200380802, 'abosulate accuracy': 0.030500001437030733, 'consecutive overlap rate': 0.2542538920417428, 'overlap rate': 0.6591503992676735}
# evaluation performance: {'loss': 2.5399153381586075, 'abosulate accuracy': 0.003300000133458525, 'consecutive overlap rate': 0.22181010134518148, 'overlap rate': 0.37562793083488943}
#
# Current epoch: 20,
# training performance: {'loss': 0.8152700588107109, 'abosulate accuracy': 0.05630000160308555, 'consecutive overlap rate': 0.2967489344999194, 'overlap rate': 0.7058067500591279}
# evaluation performance: {'loss': 2.71965269446373, 'abosulate accuracy': 0.005400000140070915, 'consecutive overlap rate': 0.21597190871834754, 'overlap rate': 0.3793717261403799}
#
# Current epoch: 25,
# training performance: {'loss': 0.7045557085424662, 'abosulate accuracy': 0.09530000522499904, 'consecutive overlap rate': 0.3310468018054962, 'overlap rate': 0.7432500094175338}
# evaluation performance: {'loss': 2.7328551769256593, 'abosulate accuracy': 0.009200000442797318, 'consecutive overlap rate': 0.23039065524935723, 'overlap rate': 0.404473764449358}
#
# Current epoch: 30,
# training performance: {'loss': 0.6591650404036045, 'abosulate accuracy': 0.10730000531766563, 'consecutive overlap rate': 0.34942659791558983, 'overlap rate': 0.7589348003268241}
# evaluation performance: {'loss': 2.866910970211029, 'abosulate accuracy': 0.00950000052107498, 'consecutive overlap rate': 0.22836220934987067, 'overlap rate': 0.403144758567214}
#
# Current epoch: 35,
# training performance: {'loss': 0.5938503326848149, 'abosulate accuracy': 0.14840000589611008, 'consecutive overlap rate': 0.37285552974790337, 'overlap rate': 0.7827954024076462}
# evaluation performance: {'loss': 3.1803534477949142, 'abosulate accuracy': 0.011100000562146306, 'consecutive overlap rate': 0.22440097965300082, 'overlap rate': 0.3949771448969841}
#
# Current epoch: 40,
# training performance: {'loss': 0.5725386949256063, 'abosulate accuracy': 0.14360000677406787, 'consecutive overlap rate': 0.3793146448209882, 'overlap rate': 0.7899215653538704}
# evaluation performance: {'loss': 3.0795423686504364, 'abosulate accuracy': 0.016650001087691636, 'consecutive overlap rate': 0.23565924894064666, 'overlap rate': 0.4105032321065664}
#
# Current epoch: 45,
# training performance: {'loss': 0.5216876750811934, 'abosulate accuracy': 0.153600008552894, 'consecutive overlap rate': 0.39237797241657973, 'overlap rate': 0.807100297510624}
# evaluation performance: {'loss': 3.497386822104454, 'abosulate accuracy': 0.013800000614719466, 'consecutive overlap rate': 0.22573671527206898, 'overlap rate': 0.3942911796271801}
#
# Current epoch: 50,
# training performance: {'loss': 0.5518790166825056, 'abosulate accuracy': 0.1326000063214451, 'consecutive overlap rate': 0.3689482705667615, 'overlap rate': 0.7963367775082588}
# evaluation performance: {'loss': 3.555708608031273, 'abosulate accuracy': 0.015050000633345917, 'consecutive overlap rate': 0.22507665436714888, 'overlap rate': 0.3955210603773594}
#
# Current epoch: 55,
# training performance: {'loss': 0.47510944325476884, 'abosulate accuracy': 0.16520000686869024, 'consecutive overlap rate': 0.40361044853925704, 'overlap rate': 0.8238971203565597}
# evaluation performance: {'loss': 3.4861807405948637, 'abosulate accuracy': 0.021450001158518715, 'consecutive overlap rate': 0.22004609536379577, 'overlap rate': 0.4083968050777912}
#
# Current epoch: 60,
# training performance: {'loss': 0.4681106248870492, 'abosulate accuracy': 0.1842000076547265, 'consecutive overlap rate': 0.4139016192406416, 'overlap rate': 0.8289624229073524}
# evaluation performance: {'loss': 3.6575817078351975, 'abosulate accuracy': 0.015350000926991925, 'consecutive overlap rate': 0.21107998974621295, 'overlap rate': 0.40163830295205116}
#
# Current epoch: 65,
# training performance: {'loss': 0.41643667304888365, 'abosulate accuracy': 0.20550000667572021, 'consecutive overlap rate': 0.4339002564549446, 'overlap rate': 0.847263503074646}
# evaluation performance: {'loss': 3.674172747135162, 'abosulate accuracy': 0.02060000113560818, 'consecutive overlap rate': 0.2062809683382511, 'overlap rate': 0.4159645665436983}
#
# Current epoch: 70,
# training performance: {'loss': 0.3375543910544366, 'abosulate accuracy': 0.2501000124728307, 'consecutive overlap rate': 0.4627371817827225, 'overlap rate': 0.8762682065367698}
# evaluation performance: {'loss': 3.7329755425453186, 'abosulate accuracy': 0.01965000060154125, 'consecutive overlap rate': 0.21414285209029912, 'overlap rate': 0.42132292315363884}
#
# Current epoch: 75,
# training performance: {'loss': 0.2948133828118443, 'abosulate accuracy': 0.24870001132367178, 'consecutive overlap rate': 0.4805772263556719, 'overlap rate': 0.8927161067724227}
# evaluation performance: {'loss': 3.8464209735393524, 'abosulate accuracy': 0.022700000990880653, 'consecutive overlap rate': 0.21481615398079157, 'overlap rate': 0.42866571098566053}
#
# Current epoch: 80,
# training performance: {'loss': 0.25492973895743487, 'abosulate accuracy': 0.27090001046890394, 'consecutive overlap rate': 0.49995790161192416, 'overlap rate': 0.9077716812491416}
# evaluation performance: {'loss': 4.077007520198822, 'abosulate accuracy': 0.019800001085968688, 'consecutive overlap rate': 0.21532839071005583, 'overlap rate': 0.41870358064770696}
#
# Current epoch: 85,
# training performance: {'loss': 0.2507035959511995, 'abosulate accuracy': 0.27960001449100674, 'consecutive overlap rate': 0.4988396864384413, 'overlap rate': 0.9084756776690484}
# evaluation performance: {'loss': 4.436222517490387, 'abosulate accuracy': 0.01380000074277632, 'consecutive overlap rate': 0.206651190854609, 'overlap rate': 0.3970163516700268}
#
# Current epoch: 90,
# training performance: {'loss': 0.23248575455509127, 'abosulate accuracy': 0.27470001196488736, 'consecutive overlap rate': 0.5087768558412791, 'overlap rate': 0.9148817181587219}
# evaluation performance: {'loss': 4.806508231163025, 'abosulate accuracy': 0.011150000593625009, 'consecutive overlap rate': 0.20327633060514927, 'overlap rate': 0.39230650663375854}
#
# Current epoch: 95,
# training performance: {'loss': 0.22320838337764143, 'abosulate accuracy': 0.2741000093985349, 'consecutive overlap rate': 0.513264513015747, 'overlap rate': 0.9189786598086357}
# evaluation performance: {'loss': 4.8575828731060025, 'abosulate accuracy': 0.009900000609923154, 'consecutive overlap rate': 0.20588002298027278, 'overlap rate': 0.3913666170090437}
#
# Current epoch: 100,
# training performance: {'loss': 0.21825785180553794, 'abosulate accuracy': 0.27700001050252465, 'consecutive overlap rate': 0.5148332685232162, 'overlap rate': 0.9206365764141082}
# evaluation performance: {'loss': 5.024724650382995, 'abosulate accuracy': 0.008600000338628889, 'consecutive overlap rate': 0.20321770776063203, 'overlap rate': 0.3820371817797422}
#
# Current epoch: 105,
# training performance: {'loss': 0.19224841659888625, 'abosulate accuracy': 0.30800001380266623, 'consecutive overlap rate': 0.5462638940662146, 'overlap rate': 0.9313898220658302}
# evaluation performance: {'loss': 5.023151457309723, 'abosulate accuracy': 0.008050000295042992, 'consecutive overlap rate': 0.21276291869580746, 'overlap rate': 0.39818945303559306}
#
# Current epoch: 110,
# training performance: {'loss': 0.15811859713867307, 'abosulate accuracy': 0.3207000143127516, 'consecutive overlap rate': 0.5624992657452822, 'overlap rate': 0.9450661912560463}
# evaluation performance: {'loss': 4.97223778963089, 'abosulate accuracy': 0.013850000634556636, 'consecutive overlap rate': 0.20990582332015037, 'overlap rate': 0.402987078204751}
#
# Current epoch: 115,
# training performance: {'loss': 0.1402846315642819, 'abosulate accuracy': 0.3614000187255442, 'consecutive overlap rate': 0.5987407095730305, 'overlap rate': 0.9514659151434899}
# evaluation performance: {'loss': 5.159685426950455, 'abosulate accuracy': 0.015200000931508839, 'consecutive overlap rate': 0.2107541710138321, 'overlap rate': 0.40264338068664074}
#
# Current epoch: 120,
# training performance: {'loss': 0.14403775546234102, 'abosulate accuracy': 0.3474000196554698, 'consecutive overlap rate': 0.5892026573419571, 'overlap rate': 0.9488628074526787}
# evaluation performance: {'loss': 5.480795818567276, 'abosulate accuracy': 0.017700000840704888, 'consecutive overlap rate': 0.20948020741343498, 'overlap rate': 0.4018466904759407}
#
# Current epoch: 125,
# training performance: {'loss': 0.1439631198067218, 'abosulate accuracy': 0.35790001932764426, 'consecutive overlap rate': 0.5857376739382744, 'overlap rate': 0.9488924980163574}
# evaluation performance: {'loss': 5.808764350414276, 'abosulate accuracy': 0.010700000706128776, 'consecutive overlap rate': 0.199528001062572, 'overlap rate': 0.3804991073906422}
#
# Current epoch: 130,
# training performance: {'loss': 0.1360040963627398, 'abosulate accuracy': 0.36100001523736863, 'consecutive overlap rate': 0.5959304172545672, 'overlap rate': 0.951699398458004}
# evaluation performance: {'loss': 5.845311170816421, 'abosulate accuracy': 0.013050000555813313, 'consecutive overlap rate': 0.20162708684802055, 'overlap rate': 0.38987404070794585}
#
# Current epoch: 135,
# training performance: {'loss': 0.13075240864418447, 'abosulate accuracy': 0.3662000205600634, 'consecutive overlap rate': 0.6005849502980709, 'overlap rate': 0.9537517473101615}
# evaluation performance: {'loss': 5.8768513143062595, 'abosulate accuracy': 0.01520000061718747, 'consecutive overlap rate': 0.20459896121174098, 'overlap rate': 0.3926788304001093}
#
# Current epoch: 140,
# training performance: {'loss': 0.12867669938132167, 'abosulate accuracy': 0.36550001917639746, 'consecutive overlap rate': 0.6073842234909534, 'overlap rate': 0.9543814077973366}
# evaluation performance: {'loss': 5.990635281801223, 'abosulate accuracy': 0.01480000070296228, 'consecutive overlap rate': 0.2039344809949398, 'overlap rate': 0.39068085215985776}
#
# Current epoch: 145,
# training performance: {'loss': 0.11606010599061847, 'abosulate accuracy': 0.3822000170359388, 'consecutive overlap rate': 0.6251342996954918, 'overlap rate': 0.9592373430728912}
# evaluation performance: {'loss': 5.936410290002823, 'abosulate accuracy': 0.01835000069113448, 'consecutive overlap rate': 0.20845614038407803, 'overlap rate': 0.39860169738531115}
#
# Current epoch: 150,
# training performance: {'loss': 0.11806992371566594, 'abosulate accuracy': 0.3711000194074586, 'consecutive overlap rate': 0.6131544336676598, 'overlap rate': 0.9583934977650642}
# evaluation performance: {'loss': 6.168808770179749, 'abosulate accuracy': 0.013400000397814438, 'consecutive overlap rate': 0.202238355204463, 'overlap rate': 0.3902957696467638}
#
# Current epoch: 155,
# training performance: {'loss': 0.10290016843937337, 'abosulate accuracy': 0.4030000189319253, 'consecutive overlap rate': 0.6460193939507007, 'overlap rate': 0.9640211895108223}
# evaluation performance: {'loss': 6.305922746658325, 'abosulate accuracy': 0.014200000918935984, 'consecutive overlap rate': 0.19975181929767133, 'overlap rate': 0.3879955500364304}
#
# Current epoch: 160,
# training performance: {'loss': 0.10203298095148057, 'abosulate accuracy': 0.3935000173514709, 'consecutive overlap rate': 0.6346989423036575, 'overlap rate': 0.9641276359558105}
# evaluation performance: {'loss': 6.310022169351578, 'abosulate accuracy': 0.01615000040619634, 'consecutive overlap rate': 0.2028727527707815, 'overlap rate': 0.3974096216261387}
#
# Current epoch: 165,
# training performance: {'loss': 0.10043322031851858, 'abosulate accuracy': 0.40410001552663743, 'consecutive overlap rate': 0.6487026639282704, 'overlap rate': 0.9650684475898743}
# evaluation performance: {'loss': 6.273591607809067, 'abosulate accuracy': 0.015950000705197455, 'consecutive overlap rate': 0.20216720178723335, 'overlap rate': 0.40149163343012334}
#
# Current epoch: 170,
# training performance: {'loss': 0.07972311491612345, 'abosulate accuracy': 0.4497000210918486, 'consecutive overlap rate': 0.6780529618263245, 'overlap rate': 0.9726257249712944}
# evaluation performance: {'loss': 6.454975146055221, 'abosulate accuracy': 0.017250000493368133, 'consecutive overlap rate': 0.20315096210688352, 'overlap rate': 0.3990457125008106}
#
# Current epoch: 175,
# training performance: {'loss': 0.06398717271513306, 'abosulate accuracy': 0.5035000217147172, 'consecutive overlap rate': 0.7271707966923714, 'overlap rate': 0.9786607056856156}
# evaluation performance: {'loss': 6.640483433008194, 'abosulate accuracy': 0.018550001189578325, 'consecutive overlap rate': 0.20549865979701282, 'overlap rate': 0.4033220935612917}
#
# Current epoch: 180,
# training performance: {'loss': 0.0764455521479249, 'abosulate accuracy': 0.4578000235371292, 'consecutive overlap rate': 0.6850158601999283, 'overlap rate': 0.9735571160912514}
# evaluation performance: {'loss': 6.778732699155808, 'abosulate accuracy': 0.015600000601261854, 'consecutive overlap rate': 0.20270590838044883, 'overlap rate': 0.3996229823678732}
#
# Current epoch: 185,
# training performance: {'loss': 0.07178995257709175, 'abosulate accuracy': 0.46940002366900446, 'consecutive overlap rate': 0.6987774066627026, 'overlap rate': 0.9756104841828346}
# evaluation performance: {'loss': 6.718869376182556, 'abosulate accuracy': 0.019400000746827573, 'consecutive overlap rate': 0.2074201785027981, 'overlap rate': 0.40712958984076975}
#
# Current epoch: 190,
# ...
# evaluation performance: {'loss': 1.61720772087574, 'abosulate accuracy': 0.01725000063306652, 'consecutive overlap rate': 0.28935642540454865, 'overlap rate': 0.5303113982081413}
#
# Current epoch: 20,
# training performance: {'loss': 0.6888478644192219, 'abosulate accuracy': 0.13100000494159758, 'consecutive overlap rate': 0.3820907510817051, 'overlap rate': 0.7718556702136994}
# evaluation performance: {'loss': 1.5526603162288666, 'abosulate accuracy': 0.04280000187573023, 'consecutive overlap rate': 0.30975775234401226, 'overlap rate': 0.5673909425735474}
#
# Current epoch: 25,
# training performance: {'loss': 0.6223597316071391, 'abosulate accuracy': 0.1639000074705109, 'consecutive overlap rate': 0.4057741351425648, 'overlap rate': 0.7907855421304703}
# evaluation performance: {'loss': 1.530476201325655, 'abosulate accuracy': 0.05760000329464674, 'consecutive overlap rate': 0.332111032307148, 'overlap rate': 0.5940695323050023}
#
# Current epoch: 30,
# training performance: {'loss': 0.5258819148875773, 'abosulate accuracy': 0.2380000083707273, 'consecutive overlap rate': 0.45392045378685, 'overlap rate': 0.8237889379262924}
# evaluation performance: {'loss': 1.46225795596838, 'abosulate accuracy': 0.08830000443849713, 'consecutive overlap rate': 0.3488601207733154, 'overlap rate': 0.6188850328326225}
#
# Current epoch: 35,
# training performance: {'loss': 0.44665868622250854, 'abosulate accuracy': 0.2799000123515725, 'consecutive overlap rate': 0.4815748050808907, 'overlap rate': 0.8490131586790085}
# evaluation performance: {'loss': 1.4935125447809696, 'abosulate accuracy': 0.0924000047147274, 'consecutive overlap rate': 0.36269129179418086, 'overlap rate': 0.6326112419366836}
#
# Current epoch: 40,
# training performance: {'loss': 0.40517495926469566, 'abosulate accuracy': 0.29780001267790795, 'consecutive overlap rate': 0.4976521659642458, 'overlap rate': 0.8620614513754845}
# evaluation performance: {'loss': 1.5313892394304276, 'abosulate accuracy': 0.09925000573857687, 'consecutive overlap rate': 0.3647519052028656, 'overlap rate': 0.6360978305339813}
#
# Current epoch: 45,
# training performance: {'loss': 0.38730485723353925, 'abosulate accuracy': 0.2873000126332045, 'consecutive overlap rate': 0.4890151724219322, 'overlap rate': 0.867331762611866}
# evaluation performance: {'loss': 1.6211262442171575, 'abosulate accuracy': 0.08135000402107835, 'consecutive overlap rate': 0.348000605404377, 'overlap rate': 0.625596821308136}
#
# Current epoch: 50,
# training performance: {'loss': 0.36108268713578584, 'abosulate accuracy': 0.3008000157773495, 'consecutive overlap rate': 0.4978143122047186, 'overlap rate': 0.8756118088960647}
# evaluation performance: {'loss': 1.7005911141633987, 'abosulate accuracy': 0.0791000029479619, 'consecutive overlap rate': 0.3549464464187622, 'overlap rate': 0.6297749020159245}
#
# Current epoch: 55,
# training performance: {'loss': 0.33215143219567833, 'abosulate accuracy': 0.3167000150191598, 'consecutive overlap rate': 0.518011248856783, 'overlap rate': 0.8858118310570717}
# evaluation performance: {'loss': 1.8204924263060094, 'abosulate accuracy': 0.06415000293054618, 'consecutive overlap rate': 0.3443764541298151, 'overlap rate': 0.6208836130797863}
#
# Current epoch: 60,
# training performance: {'loss': 0.3255035639042035, 'abosulate accuracy': 0.30660001263022424, 'consecutive overlap rate': 0.5158387951552867, 'overlap rate': 0.887242266535759}
# evaluation performance: {'loss': 1.8427749812602996, 'abosulate accuracy': 0.07220000436063856, 'consecutive overlap rate': 0.33969954308122396, 'overlap rate': 0.6203049853444099}
#
# Current epoch: 65,
# training performance: {'loss': 0.2858368823071942, 'abosulate accuracy': 0.33920001646038145, 'consecutive overlap rate': 0.5263653684407472, 'overlap rate': 0.9017181023955345}
# evaluation performance: {'loss': 1.9526900365948676, 'abosulate accuracy': 0.06855000288342125, 'consecutive overlap rate': 0.34298962764441965, 'overlap rate': 0.6212945207953453}
#
# Current epoch: 70,
# training performance: {'loss': 0.28799639735370874, 'abosulate accuracy': 0.31600001285551116, 'consecutive overlap rate': 0.5196075309067965, 'overlap rate': 0.9003747120499611}
# evaluation performance: {'loss': 2.0086057022213937, 'abosulate accuracy': 0.06660000311094336, 'consecutive overlap rate': 0.3397291895002127, 'overlap rate': 0.6188124001026154}
#
# Current epoch: 75,
# training performance: {'loss': 0.29466262157075107, 'abosulate accuracy': 0.28800001591444013, 'consecutive overlap rate': 0.5119698733091355, 'overlap rate': 0.8966207936406135}
# evaluation performance: {'loss': 2.0243999272584916, 'abosulate accuracy': 0.06765000285231508, 'consecutive overlap rate': 0.34320956096053123, 'overlap rate': 0.6197448797523976}
#
# Current epoch: 80,
# training performance: {'loss': 0.2576375660020858, 'abosulate accuracy': 0.3357000153278932, 'consecutive overlap rate': 0.5413307677954435, 'overlap rate': 0.910620191693306}
# evaluation performance: {'loss': 2.0955904483795167, 'abosulate accuracy': 0.05850000333739445, 'consecutive overlap rate': 0.3316962204873562, 'overlap rate': 0.6157448261976242}
#
# Current epoch: 85,
# training performance: {'loss': 0.2275085560278967, 'abosulate accuracy': 0.35600001821294425, 'consecutive overlap rate': 0.5529863204807043, 'overlap rate': 0.9214963063597679}
# evaluation performance: {'loss': 2.0717004150152207, 'abosulate accuracy': 0.08845000389264897, 'consecutive overlap rate': 0.35209669806063176, 'overlap rate': 0.6309313401579857}
#
# Current epoch: 90,
# training performance: {'loss': 0.22546640334185214, 'abosulate accuracy': 0.3509000168181956, 'consecutive overlap rate': 0.5505957633256913, 'overlap rate': 0.921550078690052}
# evaluation performance: {'loss': 2.180190559476614, 'abosulate accuracy': 0.07790000431705266, 'consecutive overlap rate': 0.3393531322479248, 'overlap rate': 0.6228435434401035}
#
# Current epoch: 95,
# training performance: {'loss': 0.1844323011348024, 'abosulate accuracy': 0.38640002137981355, 'consecutive overlap rate': 0.5760418631136417, 'overlap rate': 0.9373917698860168}
# evaluation performance: {'loss': 2.187532214820385, 'abosulate accuracy': 0.0822500022884924, 'consecutive overlap rate': 0.3510321032255888, 'overlap rate': 0.6296516105532646}
#
# Current epoch: 100,
# training performance: {'loss': 0.16940202019177378, 'abosulate accuracy': 0.39770001990254966, 'consecutive overlap rate': 0.5904182970523835, 'overlap rate': 0.942284943163395}
# evaluation performance: {'loss': 2.3479332998394966, 'abosulate accuracy': 0.08385000297566876, 'consecutive overlap rate': 0.34778547175228597, 'overlap rate': 0.6251179710030556}
#
# Current epoch: 105,
# training performance: {'loss': 0.18843125782441347, 'abosulate accuracy': 0.3522000144002959, 'consecutive overlap rate': 0.5615821208804845, 'overlap rate': 0.93438168913126}
# evaluation performance: {'loss': 2.389554066210985, 'abosulate accuracy': 0.08130000400124118, 'consecutive overlap rate': 0.3453505977988243, 'overlap rate': 0.6221989683806897}
#
# Current epoch: 110,
# training performance: {'loss': 0.17575028124265374, 'abosulate accuracy': 0.36930001955479386, 'consecutive overlap rate': 0.5757347553968429, 'overlap rate': 0.9385306730866432}
# evaluation performance: {'loss': 2.423215572535992, 'abosulate accuracy': 0.07165000314707867, 'consecutive overlap rate': 0.345850433409214, 'overlap rate': 0.6232529692351818}
#
# Current epoch: 115,
# training performance: {'loss': 0.15340169442351909, 'abosulate accuracy': 0.4001000199932605, 'consecutive overlap rate': 0.6014626123011112, 'overlap rate': 0.9472929686307907}
# evaluation performance: {'loss': 2.467264461517334, 'abosulate accuracy': 0.07805000364896841, 'consecutive overlap rate': 0.3485874990001321, 'overlap rate': 0.6233802087604999}
#
# Current epoch: 120,
# training performance: {'loss': 0.15772076142020525, 'abosulate accuracy': 0.37780001836363225, 'consecutive overlap rate': 0.5912951238453388, 'overlap rate': 0.9449688270688057}
# evaluation performance: {'loss': 2.5228438794612886, 'abosulate accuracy': 0.07445000492734835, 'consecutive overlap rate': 0.34764824360609053, 'overlap rate': 0.6229476928710938}
#
# Current epoch: 125,
# training performance: {'loss': 0.1923370983451605, 'abosulate accuracy': 0.32350001607555895, 'consecutive overlap rate': 0.5561346035450697, 'overlap rate': 0.9315252050757408}
# evaluation performance: {'loss': 2.589515945315361, 'abosulate accuracy': 0.07000000295229256, 'consecutive overlap rate': 0.3403811477124691, 'overlap rate': 0.6174493163824082}
#
# Current epoch: 130,
# training performance: {'loss': 0.16280897953547538, 'abosulate accuracy': 0.3634000155259855, 'consecutive overlap rate': 0.5864801324903965, 'overlap rate': 0.9427277117967605}
# evaluation performance: {'loss': 2.598659536242485, 'abosulate accuracy': 0.06940000298200175, 'consecutive overlap rate': 0.33627200555056336, 'overlap rate': 0.6149511151015759}
#
# Current epoch: 135,
# training performance: {'loss': 0.14805259178392588, 'abosulate accuracy': 0.3761000184691511, 'consecutive overlap rate': 0.595187808573246, 'overlap rate': 0.9481861755251885}
# evaluation performance: {'loss': 2.63327471613884, 'abosulate accuracy': 0.07705000301357359, 'consecutive overlap rate': 0.34445014987140893, 'overlap rate': 0.6216122202575207}
#
# Current epoch: 140,
# training performance: {'loss': 0.1388350755441934, 'abosulate accuracy': 0.38920001935912296, 'consecutive overlap rate': 0.6099373418837786, 'overlap rate': 0.9517507508397103}
# evaluation performance: {'loss': 2.6635883510112763, 'abosulate accuracy': 0.07810000494355336, 'consecutive overlap rate': 0.34541607052087786, 'overlap rate': 0.6228956386446953}
#
# Current epoch: 145,
# training performance: {'loss': 0.1278624025755562, 'abosulate accuracy': 0.4029000158421695, 'consecutive overlap rate': 0.6197057530283928, 'overlap rate': 0.955624382197857}
# evaluation performance: {'loss': 2.719951592385769, 'abosulate accuracy': 0.07450000265380367, 'consecutive overlap rate': 0.34461890421807767, 'overlap rate': 0.6226776137948036}
#
# Current epoch: 150,
# training performance: {'loss': 0.16034738416783512, 'abosulate accuracy': 0.3558000189717859, 'consecutive overlap rate': 0.5797002535313368, 'overlap rate': 0.9430495962500572}
# evaluation performance: {'loss': 2.7215474963188173, 'abosulate accuracy': 0.0730000046256464, 'consecutive overlap rate': 0.3406841341406107, 'overlap rate': 0.6191249780356884}
#
# Current epoch: 155,
# training performance: {'loss': 0.12409100539516657, 'abosulate accuracy': 0.4048000164562836, 'consecutive overlap rate': 0.619032884389162, 'overlap rate': 0.9569350183010101}
# evaluation performance: {'loss': 2.8300797179341317, 'abosulate accuracy': 0.07180000316584483, 'consecutive overlap rate': 0.33544203769415615, 'overlap rate': 0.6175511419773102}
#
# Current epoch: 160,
# training performance: {'loss': 0.11183141212677583, 'abosulate accuracy': 0.41470002381829546, 'consecutive overlap rate': 0.6395652554929256, 'overlap rate': 0.9615220785140991}
# evaluation performance: {'loss': 2.8177613452076913, 'abosulate accuracy': 0.07890000336919911, 'consecutive overlap rate': 0.3450703978538513, 'overlap rate': 0.6247272670269013}
#
# Current epoch: 165,
# training performance: {'loss': 0.10972925170790404, 'abosulate accuracy': 0.40720002073794603, 'consecutive overlap rate': 0.6416958212852478, 'overlap rate': 0.9621753394603729}
# evaluation performance: {'loss': 2.915054814517498, 'abosulate accuracy': 0.08105000401264988, 'consecutive overlap rate': 0.343787351436913, 'overlap rate': 0.6224858120083809}
#
# Current epoch: 170,
# training performance: {'loss': 0.09277960566105321, 'abosulate accuracy': 0.44600001950748264, 'consecutive overlap rate': 0.6692081436514854, 'overlap rate': 0.9689345553517341}
# evaluation performance: {'loss': 2.9766810938715933, 'abosulate accuracy': 0.07985000487533397, 'consecutive overlap rate': 0.33969733975827693, 'overlap rate': 0.6187301233410836}
#
# Current epoch: 175,
# training performance: {'loss': 0.08628104189410805, 'abosulate accuracy': 0.46270002336241306, 'consecutive overlap rate': 0.6757718943059444, 'overlap rate': 0.9710128620266915}
# evaluation performance: {'loss': 3.0059436693787576, 'abosulate accuracy': 0.08595000440836884, 'consecutive overlap rate': 0.34778280220925806, 'overlap rate': 0.623313058912754}
#
# Current epoch: 180,
# training performance: {'loss': 0.0870280047878623, 'abosulate accuracy': 0.4670000192709267, 'consecutive overlap rate': 0.677960916608572, 'overlap rate': 0.9707249432802201}
# evaluation performance: {'loss': 3.0697057023644447, 'abosulate accuracy': 0.08030000288854353, 'consecutive overlap rate': 0.3409331988543272, 'overlap rate': 0.6208569571375847}
#
# Current epoch: 185,
# training performance: {'loss': 0.09501187606947496, 'abosulate accuracy': 0.4367000197991729, 'consecutive overlap rate': 0.6625910118222237, 'overlap rate': 0.9673880025744438}
# evaluation performance: {'loss': 3.0744091123342514, 'abosulate accuracy': 0.08215000381460413, 'consecutive overlap rate': 0.3482144517824054, 'overlap rate': 0.6246639922261238}
#
# Current epoch: 190,
# training performance: {'loss': 0.10769228029530495, 'abosulate accuracy': 0.40940001979470253, 'consecutive overlap rate': 0.6474143289029598, 'overlap rate': 0.9625222012400627}
# evaluation performance: {'loss': 3.091675578057766, 'abosulate accuracy': 0.07440000317292288, 'consecutive overlap rate': 0.34469595588743684, 'overlap rate': 0.6217504553496838}
#
# Current epoch: 195,
# training performance: {'loss': 0.08791117496439256, 'abosulate accuracy': 0.4507000162266195, 'consecutive overlap rate': 0.673042917996645, 'overlap rate': 0.9694443687796592}
# evaluation performance: {'loss': 3.1529181763529777, 'abosulate accuracy': 0.08590000296244397, 'consecutive overlap rate': 0.34674703031778337, 'overlap rate': 0.6247666336596012}
#
# Current epoch: 200,
# training performance: {'loss': 0.09840441986452789, 'abosulate accuracy': 0.4310000194236636, 'consecutive overlap rate': 0.6573617056012153, 'overlap rate': 0.9656284585595131}
# evaluation performance: {'loss': 3.18434197306633, 'abosulate accuracy': 0.08385000363341533, 'consecutive overlap rate': 0.3446684952825308, 'overlap rate': 0.6232137620449066}
#
# Experiments_Logs/Experiment#5/LSTM/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/LSTM/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 5.058257687091827, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.15325583489611744, 'overlap rate': 0.3455258697271347}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 1.5558384247124195, 'abosulate accuracy': 0.09947500530979596, 'consecutive overlap rate': 0.36306916251778604, 'overlap rate': 0.6366199851036072}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.073421262925671, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.09270885774204808, 'overlap rate': 0.26995187997817993}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.9325898815142482, 'abosulate accuracy': 0.17765790448940702, 'consecutive overlap rate': 0.32052140290799896, 'overlap rate': 0.545281846272318}
# Experiments_Logs/Experiment#5/LSTM/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#5 with LSTM seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
