# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 512
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = True 
use_attention = False
reduction_method = torch.sum

learning_rate = 1e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 5
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#5/RNN created!
# ./Experiments_Logs/Experiment#5/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#5/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#5/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#5 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
# training performance: {'loss': 1.0777334608137608, 'abosulate accuracy': 0.1193000056548044, 'consecutive overlap rate': 0.2859552888199687, 'overlap rate': 0.7146978490054607}
# evaluation performance: {'loss': 2.874738189578056, 'abosulate accuracy': 0.1229500047978945, 'consecutive overlap rate': 0.281812858954072, 'overlap rate': 0.41451804228127004}
#
# Current epoch: 55,
# training performance: {'loss': 1.0276264421641828, 'abosulate accuracy': 0.13080000660847874, 'consecutive overlap rate': 0.29876374304294584, 'overlap rate': 0.7276505991816521}
# evaluation performance: {'loss': 2.868672112375498, 'abosulate accuracy': 0.13975000391947107, 'consecutive overlap rate': 0.2964720297604799, 'overlap rate': 0.4272467836737633}
#
# Current epoch: 60,
# training performance: {'loss': 0.9947017647325993, 'abosulate accuracy': 0.1400000047753565, 'consecutive overlap rate': 0.3079772386699915, 'overlap rate': 0.7350647561252117}
# evaluation performance: {'loss': 2.9175142519176007, 'abosulate accuracy': 0.14620000781142153, 'consecutive overlap rate': 0.3004583686590195, 'overlap rate': 0.4326379597187042}
#
# Current epoch: 65,
# training performance: {'loss': 0.9379004649817944, 'abosulate accuracy': 0.15520000653341412, 'consecutive overlap rate': 0.32393781151622536, 'overlap rate': 0.7508655749261379}
# evaluation performance: {'loss': 2.9295344337821008, 'abosulate accuracy': 0.16455000842688605, 'consecutive overlap rate': 0.32138660084456205, 'overlap rate': 0.4498398587107658}
#
# Current epoch: 70,
# training performance: {'loss': 0.9467596858739853, 'abosulate accuracy': 0.15570000695297495, 'consecutive overlap rate': 0.3279945211485028, 'overlap rate': 0.7491329953074455}
# evaluation performance: {'loss': 2.982777477055788, 'abosulate accuracy': 0.15130000508506783, 'consecutive overlap rate': 0.30738584119826556, 'overlap rate': 0.4405444420874119}
#
# Current epoch: 75,
# training performance: {'loss': 0.8600977644324302, 'abosulate accuracy': 0.17370000598020852, 'consecutive overlap rate': 0.34341536462306976, 'overlap rate': 0.7695418611168862}
# evaluation performance: {'loss': 2.8964639842510223, 'abosulate accuracy': 0.17920000808080658, 'consecutive overlap rate': 0.33791036158800125, 'overlap rate': 0.46474341973662375}
#
# Current epoch: 80,
# training performance: {'loss': 0.8535028617829085, 'abosulate accuracy': 0.1787000079988502, 'consecutive overlap rate': 0.3479559188708663, 'overlap rate': 0.7712642014026642}
# evaluation performance: {'loss': 2.8995131749659775, 'abosulate accuracy': 0.18460000760969705, 'consecutive overlap rate': 0.3385579979047179, 'overlap rate': 0.46810559630393983}
#
# Current epoch: 85,
# training performance: {'loss': 0.8090548578649759, 'abosulate accuracy': 0.18480000919662415, 'consecutive overlap rate': 0.35341577269136903, 'overlap rate': 0.7818502873182297}
# evaluation performance: {'loss': 2.8920705072581767, 'abosulate accuracy': 0.19565000771544874, 'consecutive overlap rate': 0.34979677200317383, 'overlap rate': 0.4778190940618515}
#
# Current epoch: 90,
# training performance: {'loss': 0.7830805875360966, 'abosulate accuracy': 0.19640000711660832, 'consecutive overlap rate': 0.3613589718937874, 'overlap rate': 0.7870751768350601}
# evaluation performance: {'loss': 2.9280679270625116, 'abosulate accuracy': 0.19005001039477065, 'consecutive overlap rate': 0.3496137073263526, 'overlap rate': 0.48073425590991975}
#
# Current epoch: 95,
# training performance: {'loss': 0.7635970018804074, 'abosulate accuracy': 0.18910000891191886, 'consecutive overlap rate': 0.3612718887627125, 'overlap rate': 0.7909947708249092}
# evaluation performance: {'loss': 2.9334420770406724, 'abosulate accuracy': 0.2004000113811344, 'consecutive overlap rate': 0.3570156333968043, 'overlap rate': 0.4869764491915703}
#
# Current epoch: 100,
# training performance: {'loss': 0.7366013310849666, 'abosulate accuracy': 0.19960000725695864, 'consecutive overlap rate': 0.36986743211746215, 'overlap rate': 0.7969396576285362}
# evaluation performance: {'loss': 2.93789474517107, 'abosulate accuracy': 0.2008000100729987, 'consecutive overlap rate': 0.36821545027196406, 'overlap rate': 0.49615568444132807}
#
# Current epoch: 105,
# training performance: {'loss': 0.7461031649261713, 'abosulate accuracy': 0.192200009082444, 'consecutive overlap rate': 0.3641474207863212, 'overlap rate': 0.7942690581083298}
# evaluation performance: {'loss': 2.969476928934455, 'abosulate accuracy': 0.17535000810748896, 'consecutive overlap rate': 0.3500296279788017, 'overlap rate': 0.48302497491240504}
#
# Current epoch: 110,
# training performance: {'loss': 0.7133851371705532, 'abosulate accuracy': 0.19680000969674438, 'consecutive overlap rate': 0.37336328011006115, 'overlap rate': 0.8021429687738418}
# evaluation performance: {'loss': 2.9188716311007736, 'abosulate accuracy': 0.21990000789519398, 'consecutive overlap rate': 0.37584997471421955, 'overlap rate': 0.5051312807947397}
#
# Current epoch: 115,
# training performance: {'loss': 0.7463720202445984, 'abosulate accuracy': 0.1852000095299445, 'consecutive overlap rate': 0.36083642672747374, 'overlap rate': 0.7955208465456962}
# evaluation performance: {'loss': 2.9577953666448593, 'abosulate accuracy': 0.20815000953152776, 'consecutive overlap rate': 0.36283111926168204, 'overlap rate': 0.49569911099970343}
#
# Current epoch: 120,
# training performance: {'loss': 0.7166180770844222, 'abosulate accuracy': 0.19430001059081406, 'consecutive overlap rate': 0.37111912071704867, 'overlap rate': 0.8050269603729248}
# evaluation performance: {'loss': 2.973912932723761, 'abosulate accuracy': 0.2196500091115013, 'consecutive overlap rate': 0.37534866090863944, 'overlap rate': 0.5056262996047736}
#
# Current epoch: 125,
# training performance: {'loss': 0.7050279267132282, 'abosulate accuracy': 0.20670001064427196, 'consecutive overlap rate': 0.38296057991683485, 'overlap rate': 0.8104136005043984}
# evaluation performance: {'loss': 3.0308987934142353, 'abosulate accuracy': 0.20675000929040835, 'consecutive overlap rate': 0.36635646130889654, 'overlap rate': 0.5008560467511416}
#
# Current epoch: 130,
# training performance: {'loss': 0.6711089931428432, 'abosulate accuracy': 0.21110000723274425, 'consecutive overlap rate': 0.3878021012991667, 'overlap rate': 0.8155871272087097}
# evaluation performance: {'loss': 2.945464812964201, 'abosulate accuracy': 0.22580001042224468, 'consecutive overlap rate': 0.3865850787609816, 'overlap rate': 0.5174368765205145}
#
# Current epoch: 135,
# training performance: {'loss': 0.6760352101176977, 'abosulate accuracy': 0.21010000901296735, 'consecutive overlap rate': 0.3899795558303595, 'overlap rate': 0.8128634229302406}
# evaluation performance: {'loss': 3.025176746211946, 'abosulate accuracy': 0.2568000081926584, 'consecutive overlap rate': 0.40561769660562275, 'overlap rate': 0.5448760457336903}
#
# Current epoch: 185,
# training performance: {'loss': 0.5339068771339953, 'abosulate accuracy': 0.24290001159533858, 'consecutive overlap rate': 0.41872275397181513, 'overlap rate': 0.8480822131037712}
# evaluation performance: {'loss': 2.9828730115666984, 'abosulate accuracy': 0.26845000870525837, 'consecutive overlap rate': 0.41316183041781185, 'overlap rate': 0.5519022107124328}
#
# Current epoch: 190,
# training performance: {'loss': 0.5195584695786237, 'abosulate accuracy': 0.23590001091361046, 'consecutive overlap rate': 0.41929981037974356, 'overlap rate': 0.8505965769290924}
# evaluation performance: {'loss': 2.9618712019175293, 'abosulate accuracy': 0.27500001480802894, 'consecutive overlap rate': 0.42770479507744313, 'overlap rate': 0.5637237511575222}
#
# Current epoch: 195,
# training performance: {'loss': 0.4613196925260127, 'abosulate accuracy': 0.27530001346021893, 'consecutive overlap rate': 0.4518848694860935, 'overlap rate': 0.8684033080935478}
# evaluation performance: {'loss': 2.9228283977136016, 'abosulate accuracy': 0.2773500123992562, 'consecutive overlap rate': 0.43956463448703287, 'overlap rate': 0.5714382700622082}
#
# Current epoch: 200,
# training performance: {'loss': 0.4711504355072975, 'abosulate accuracy': 0.270300011895597, 'consecutive overlap rate': 0.44892537146806716, 'overlap rate': 0.8649725049734116}
# evaluation performance: {'loss': 2.968258317001164, 'abosulate accuracy': 0.29075001291930674, 'consecutive overlap rate': 0.4358091734349728, 'overlap rate': 0.5701051525771618}
#
# Experiments_Logs/Experiment#5/RNN/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 6.984107589721679, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0042236370522005014, 'overlap rate': 0.0669736439594999}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.910589300468564, 'abosulate accuracy': 0.29792501386255027, 'consecutive overlap rate': 0.44772153683006766, 'overlap rate': 0.5782811909914016}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.087260326262443, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003211529784265064, 'overlap rate': 0.20849895323476483}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.955378208113344, 'abosulate accuracy': 0.21031579953054652, 'consecutive overlap rate': 0.3414875470886105, 'overlap rate': 0.45368157091893646}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.7923298239707948, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01446001292206347, 'overlap rate': 0.2104386303573847}
# evaluation performance: {'loss': 3.0512757778167723, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014519944763742387, 'overlap rate': 0.13998279701918365}
#
# Current epoch: 10,
# training performance: {'loss': 2.318434476852417, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.04607769639696926, 'overlap rate': 0.3620696358382702}
# evaluation performance: {'loss': 3.053018534183502, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.04007251518778503, 'overlap rate': 0.1712895156815648}
#
# Current epoch: 15,
# training performance: {'loss': 1.9860436499118805, 'abosulate accuracy': 0.0016000000876374542, 'consecutive overlap rate': 0.07575388266704977, 'overlap rate': 0.45668691024184227}
# evaluation performance: {'loss': 3.0790965467691422, 'abosulate accuracy': 0.0007500000239815563, 'consecutive overlap rate': 0.06454354273155331, 'overlap rate': 0.20664551090449096}
#
# Current epoch: 20,
# training performance: {'loss': 1.7757205337285995, 'abosulate accuracy': 0.004400000243913382, 'consecutive overlap rate': 0.10546990418806672, 'overlap rate': 0.5148557879030704}
# evaluation performance: {'loss': 3.101211482286453, 'abosulate accuracy': 0.004350000212434679, 'consecutive overlap rate': 0.09443762572482228, 'overlap rate': 0.2399164190515876}
#
# Current epoch: 25,
# training performance: {'loss': 1.5971555024385453, 'abosulate accuracy': 0.013000000384636223, 'consecutive overlap rate': 0.13900737464427948, 'overlap rate': 0.5691091455519199}
# evaluation performance: {'loss': 3.12545707821846, 'abosulate accuracy': 0.012850000447360798, 'consecutive overlap rate': 0.1275217117741704, 'overlap rate': 0.2719173960387707}
#
# Current epoch: 30,
# training performance: {'loss': 1.5019748523831367, 'abosulate accuracy': 0.026100001158192755, 'consecutive overlap rate': 0.1675687932409346, 'overlap rate': 0.5964635655283927}
# evaluation performance: {'loss': 3.1299428194761276, 'abosulate accuracy': 0.028650001576170325, 'consecutive overlap rate': 0.15873450916260481, 'overlap rate': 0.29851401783525944}
#
# Current epoch: 35,
# training performance: {'loss': 1.4137750029563905, 'abosulate accuracy': 0.0340000010561198, 'consecutive overlap rate': 0.1919333143159747, 'overlap rate': 0.6200850397348404}
# evaluation performance: {'loss': 3.094672693312168, 'abosulate accuracy': 0.0386500021093525, 'consecutive overlap rate': 0.18416235568001865, 'overlap rate': 0.3207465309649706}
#
# Current epoch: 40,
# training performance: {'loss': 1.3654964476823808, 'abosulate accuracy': 0.051300002890639004, 'consecutive overlap rate': 0.2113144736737013, 'overlap rate': 0.6342896297574043}
# evaluation performance: {'loss': 3.0491436630487443, 'abosulate accuracy': 0.052300002909032625, 'consecutive overlap rate': 0.20261080674827098, 'overlap rate': 0.3394377242773771}
#
# Current epoch: 45,
# training performance: {'loss': 1.260201246291399, 'abosulate accuracy': 0.07790000325767324, 'consecutive overlap rate': 0.2395182650536299, 'overlap rate': 0.6644560113549233}
# evaluation performance: {'loss': 3.030438721179962, 'abosulate accuracy': 0.07250000396743417, 'consecutive overlap rate': 0.2264911536127329, 'overlap rate': 0.36419829837977885}
#
# Current epoch: 50,
# training performance: {'loss': 1.217576964944601, 'abosulate accuracy': 0.08370000323047862, 'consecutive overlap rate': 0.2474436044692993, 'overlap rate': 0.677859402447939}
# evaluation performance: {'loss': 3.024418757855892, 'abosulate accuracy': 0.07380000264965929, 'consecutive overlap rate': 0.23284459188580514, 'overlap rate': 0.37127016894519327}
#
# Current epoch: 55,
#
# Current epoch: 100,
# training performance: {'loss': 0.8303466875106096, 'abosulate accuracy': 0.1765000078594312, 'consecutive overlap rate': 0.3499608635902405, 'overlap rate': 0.7739001885056496}
# evaluation performance: {'loss': 2.9901682678610086, 'abosulate accuracy': 0.18450000733719207, 'consecutive overlap rate': 0.34964476246386766, 'overlap rate': 0.4779579881578684}
#
# Current epoch: 105,
# training performance: {'loss': 0.8237559661269188, 'abosulate accuracy': 0.1781000078190118, 'consecutive overlap rate': 0.3554861223325133, 'overlap rate': 0.7756148964166641}
# evaluation performance: {'loss': 3.00112368054688, 'abosulate accuracy': 0.1655000060214661, 'consecutive overlap rate': 0.3331874432042241, 'overlap rate': 0.4701624523848295}
#
# Current epoch: 110,
# training performance: {'loss': 0.7641217045485973, 'abosulate accuracy': 0.18360000770771875, 'consecutive overlap rate': 0.36393471118062737, 'overlap rate': 0.7905376866459847}
# evaluation performance: {'loss': 2.9476157050579785, 'abosulate accuracy': 0.1990500091400463, 'consecutive overlap rate': 0.3621923953294754, 'overlap rate': 0.49295780397951605}
#
# Current epoch: 115,
# training performance: {'loss': 0.7702192518860101, 'abosulate accuracy': 0.19100000843172893, 'consecutive overlap rate': 0.3689637754112482, 'overlap rate': 0.7892748817801476}
# evaluation performance: {'loss': 2.9726476676762106, 'abosulate accuracy': 0.19865001030848362, 'consecutive overlap rate': 0.3575621658936143, 'overlap rate': 0.4912594437599182}
#
# Current epoch: 120,
# training performance: {'loss': 0.7273624014109373, 'abosulate accuracy': 0.2057000089203939, 'consecutive overlap rate': 0.3737318981438875, 'overlap rate': 0.7996399864554405}
# evaluation performance: {'loss': 2.848835542425513, 'abosulate accuracy': 0.2074000086518936, 'consecutive overlap rate': 0.36487199682742355, 'overlap rate': 0.49770000465214254}
#
# Current epoch: 125,
# training performance: {'loss': 0.7084623154252767, 'abosulate accuracy': 0.2075000077020377, 'consecutive overlap rate': 0.3811319286003709, 'overlap rate': 0.8043016582727432}
# evaluation performance: {'loss': 2.96700680218637, 'abosulate accuracy': 0.2089500087313354, 'consecutive overlap rate': 0.36826598923653364, 'overlap rate': 0.502086004987359}
#
# Current epoch: 130,
# training performance: {'loss': 0.6686653945595026, 'abosulate accuracy': 0.22100001196376978, 'consecutive overlap rate': 0.3904431313276291, 'overlap rate': 0.8145485669374466}
# evaluation performance: {'loss': 2.9532482113689182, 'abosulate accuracy': 0.2282000121893361, 'consecutive overlap rate': 0.38474947605282067, 'overlap rate': 0.5168348472565413}
#
# Current epoch: 135,
# training performance: {'loss': 0.6477870052680373, 'abosulate accuracy': 0.21520000955788418, 'consecutive overlap rate': 0.38969963826239107, 'overlap rate': 0.8192815333604813}
# evaluation performance: {'loss': 2.959553262591362, 'abosulate accuracy': 0.22835000918712467, 'consecutive overlap rate': 0.38630053158849476, 'overlap rate': 0.5196268144994974}
#
# Current epoch: 140,
# training performance: {'loss': 0.6431632000952959, 'abosulate accuracy': 0.2171000100672245, 'consecutive overlap rate': 0.39487673081457614, 'overlap rate': 0.8194186389446259}
# evaluation performance: {'loss': 2.8774608651176097, 'abosulate accuracy': 0.2820000110194087, 'consecutive overlap rate': 0.4292926050722599, 'overlap rate': 0.56553985029459}
#
# Current epoch: 190,
# training performance: {'loss': 0.48341377545148134, 'abosulate accuracy': 0.27220001313835385, 'consecutive overlap rate': 0.4473206873983145, 'overlap rate': 0.8606234535574913}
# evaluation performance: {'loss': 2.8715213637799026, 'abosulate accuracy': 0.28715001456439493, 'consecutive overlap rate': 0.44249756671488283, 'overlap rate': 0.5763358324766159}
#
# Current epoch: 195,
# training performance: {'loss': 0.4895719046704471, 'abosulate accuracy': 0.274300011433661, 'consecutive overlap rate': 0.4468219455331564, 'overlap rate': 0.8581623733043671}
# evaluation performance: {'loss': 2.848293111473322, 'abosulate accuracy': 0.3005500130355358, 'consecutive overlap rate': 0.4467294991016388, 'overlap rate': 0.5801314935088158}
#
# Current epoch: 200,
# training performance: {'loss': 0.4807297517545521, 'abosulate accuracy': 0.2736000118777156, 'consecutive overlap rate': 0.45176678262650966, 'overlap rate': 0.8626654297113419}
# evaluation performance: {'loss': 2.841166797094047, 'abosulate accuracy': 0.2934500154107809, 'consecutive overlap rate': 0.43741071969270706, 'overlap rate': 0.5753541439771652}
#
# Experiments_Logs/Experiment#5/RNN/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 7.8344648540019985, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004225000050064409, 'overlap rate': 0.046652921754866836}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.888565540872514, 'abosulate accuracy': 0.3071250166743994, 'consecutive overlap rate': 0.4523186445236206, 'overlap rate': 0.5858428344130516}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.124190173610565, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0032301085109206575, 'overlap rate': 0.09899128425505853}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.9113010558250703, 'abosulate accuracy': 0.19386843030990444, 'consecutive overlap rate': 0.33134264538162633, 'overlap rate': 0.45294069224282313}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.877650707960129, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014574439986608923, 'overlap rate': 0.18972347900271416}
# evaluation performance: {'loss': 3.0540213584899902, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01490016512107104, 'overlap rate': 0.14110892973840236}
#
# Current epoch: 10,
# training performance: {'loss': 2.3113675713539124, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05307959620840848, 'overlap rate': 0.3721986047923565}
# evaluation performance: {'loss': 3.0595654428005217, 'abosulate accuracy': 0.00025000000605359676, 'consecutive overlap rate': 0.0472917078062892, 'overlap rate': 0.18420171812176706}
#
# Current epoch: 15,
# training performance: {'loss': 2.001262530684471, 'abosulate accuracy': 0.0019000000786036253, 'consecutive overlap rate': 0.09123478536494076, 'overlap rate': 0.4635338671505451}
# evaluation performance: {'loss': 3.070503631234169, 'abosulate accuracy': 0.001250000053551048, 'consecutive overlap rate': 0.07322133216075599, 'overlap rate': 0.21817607041448356}
#
# Current epoch: 20,
# training performance: {'loss': 1.801297390460968, 'abosulate accuracy': 0.0063000002759508785, 'consecutive overlap rate': 0.11526738200336695, 'overlap rate': 0.5188906051218509}
# evaluation performance: {'loss': 3.040367180109024, 'abosulate accuracy': 0.006150000222260132, 'consecutive overlap rate': 0.1039573430083692, 'overlap rate': 0.25275839809328315}
#
# Current epoch: 25,
# training performance: {'loss': 1.6436393305659294, 'abosulate accuracy': 0.014800000423565506, 'consecutive overlap rate': 0.14027292402461172, 'overlap rate': 0.5577553384006023}
# evaluation performance: {'loss': 3.0651002317667007, 'abosulate accuracy': 0.011400000477442518, 'consecutive overlap rate': 0.12927782936021687, 'overlap rate': 0.2797463372349739}
#
# Current epoch: 30,
# training performance: {'loss': 1.44651852697134, 'abosulate accuracy': 0.039200002315919844, 'consecutive overlap rate': 0.18173257848247887, 'overlap rate': 0.617327805608511}
# evaluation performance: {'loss': 3.0126729547977447, 'abosulate accuracy': 0.03505000129225664, 'consecutive overlap rate': 0.17258456936106087, 'overlap rate': 0.31771588511765003}
#
# Current epoch: 35,
# training performance: {'loss': 1.3332619950175286, 'abosulate accuracy': 0.06270000315271318, 'consecutive overlap rate': 0.21580003947019577, 'overlap rate': 0.647717522829771}
# evaluation performance: {'loss': 3.0230745926499365, 'abosulate accuracy': 0.05835000291117467, 'consecutive overlap rate': 0.20556972343474628, 'overlap rate': 0.34490421041846275}
#
# Current epoch: 40,
# training performance: {'loss': 1.2511608734726907, 'abosulate accuracy': 0.07890000268816948, 'consecutive overlap rate': 0.2403633752837777, 'overlap rate': 0.6697552055120468}
# evaluation performance: {'loss': 3.011247968673706, 'abosulate accuracy': 0.07735000453540124, 'consecutive overlap rate': 0.23160696681588888, 'overlap rate': 0.36645699068903925}
#
# Current epoch: 45,
# training performance: {'loss': 1.1826349399983882, 'abosulate accuracy': 0.09720000301022083, 'consecutive overlap rate': 0.26252828612923623, 'overlap rate': 0.6872004643082619}
# evaluation performance: {'loss': 2.956288555264473, 'abosulate accuracy': 0.09545000395737588, 'consecutive overlap rate': 0.25464815367013216, 'overlap rate': 0.38547184206545354}
#
# Current epoch: 50,
# training performance: {'loss': 1.1258735254406929, 'abosulate accuracy': 0.10700000375509262, 'consecutive overlap rate': 0.2758250145241618, 'overlap rate': 0.7010095544159413}
# evaluation performance: {'loss': 2.9231034271419047, 'abosulate accuracy': 0.11095000639907085, 'consecutive overlap rate': 0.27233041990548373, 'overlap rate': 0.4021162413060665}
#
# Current epoch: 55,
# training performance: {'loss': 1.0844604909420013, 'abosulate accuracy': 0.11380000597564503, 'consecutive overlap rate': 0.29024951793253423, 'overlap rate': 0.7113214455544948}
# evaluation performance: {'loss': 2.941866683214903, 'abosulate accuracy': 0.12260000618407503, 'consecutive overlap rate': 0.2873299825936556, 'overlap rate': 0.41677960865199565}
#
# Current epoch: 60,
#
# Current epoch: 105,
# training performance: {'loss': 0.6651865653693676, 'abosulate accuracy': 0.21750000830506905, 'consecutive overlap rate': 0.38432481829077003, 'overlap rate': 0.8171059653162956}
# evaluation performance: {'loss': 2.902566059306264, 'abosulate accuracy': 0.22240001200698317, 'consecutive overlap rate': 0.37971347495913504, 'overlap rate': 0.5126399453729391}
#
# Current epoch: 110,
# training performance: {'loss': 0.6780719647184015, 'abosulate accuracy': 0.22160001231823118, 'consecutive overlap rate': 0.38642622381448744, 'overlap rate': 0.8120437130331993}
# evaluation performance: {'loss': 2.926174246147275, 'abosulate accuracy': 0.22215001261793077, 'consecutive overlap rate': 0.37480485141277314, 'overlap rate': 0.5097786676138639}
#
# Current epoch: 115,
# training performance: {'loss': 0.6529733592644333, 'abosulate accuracy': 0.22390000903978943, 'consecutive overlap rate': 0.3912818716838956, 'overlap rate': 0.8189352035522461}
# evaluation performance: {'loss': 2.94097493737936, 'abosulate accuracy': 0.22710000933147967, 'consecutive overlap rate': 0.38390014637261627, 'overlap rate': 0.5177246641367674}
#
# Current epoch: 120,
# training performance: {'loss': 0.6483154548332095, 'abosulate accuracy': 0.2214000068139285, 'consecutive overlap rate': 0.390958546847105, 'overlap rate': 0.8195719659328461}
# evaluation performance: {'loss': 2.936735973507166, 'abosulate accuracy': 0.22980000913958065, 'consecutive overlap rate': 0.3842391362413764, 'overlap rate': 0.5167245235294103}
#
# Current epoch: 125,
# training performance: {'loss': 0.6321694329380989, 'abosulate accuracy': 0.2197000086773187, 'consecutive overlap rate': 0.39195039831101897, 'overlap rate': 0.8238211259245872}
# evaluation performance: {'loss': 2.9072686860337855, 'abosulate accuracy': 0.23220001244917512, 'consecutive overlap rate': 0.39120317101478574, 'overlap rate': 0.5246235772967338}
#
# Current epoch: 130,
# training performance: {'loss': 0.6202350117266178, 'abosulate accuracy': 0.22870001047849656, 'consecutive overlap rate': 0.4009075969457626, 'overlap rate': 0.8265413999557495}
# evaluation performance: {'loss': 2.9074749095365404, 'abosulate accuracy': 0.23280000986997038, 'consecutive overlap rate': 0.3926289569586515, 'overlap rate': 0.5253008432686329}
#
# Current epoch: 135,
# training performance: {'loss': 0.6105457058176398, 'abosulate accuracy': 0.22260001092217863, 'consecutive overlap rate': 0.3988554421812296, 'overlap rate': 0.8277726650238038}
# evaluation performance: {'loss': 2.9325860967859625, 'abosulate accuracy': 0.2442500117700547, 'consecutive overlap rate': 0.402457631751895, 'overlap rate': 0.5352602519094944}
#
# Current epoch: 140,
# training performance: {'loss': 0.5697884850203991, 'abosulate accuracy': 0.24470001137815417, 'consecutive overlap rate': 0.41640827655792234, 'overlap rate': 0.839213202893734}
# evaluation performance: {'loss': 2.949448536708951, 'abosulate accuracy': 0.25465001170523466, 'consecutive overlap rate': 0.41192703507840633, 'overlap rate': 0.5419575788080693}
#
# Current epoch: 145,
# training performance: {'loss': 0.5801768060773611, 'abosulate accuracy': 0.24170001167804003, 'consecutive overlap rate': 0.41256300546228886, 'overlap rate': 0.8352584019303322}
 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01366029419004917, 'overlap rate': 0.14395537972450256}
#
# Current epoch: 10,
# training performance: {'loss': 2.282626637816429, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.049133942415937784, 'overlap rate': 0.3749904215335846}
# evaluation performance: {'loss': 3.0887872636318208, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.04446026510559022, 'overlap rate': 0.1775367084890604}
#
# Current epoch: 15,
# training performance: {'loss': 2.029414713382721, 'abosulate accuracy': 0.0006000000168569386, 'consecutive overlap rate': 0.08042013780213893, 'overlap rate': 0.4516170367598534}
# evaluation performance: {'loss': 3.1030232846736907, 'abosulate accuracy': 0.0009500000625848771, 'consecutive overlap rate': 0.06907100128009916, 'overlap rate': 0.20677867252379656}
#
# Current epoch: 20,
# training performance: {'loss': 1.8222174376249314, 'abosulate accuracy': 0.0046000001137144865, 'consecutive overlap rate': 0.11355366576462984, 'overlap rate': 0.5096363671123981}
# evaluation performance: {'loss': 3.0259983122348784, 'abosulate accuracy': 0.0043500002939254045, 'consecutive overlap rate': 0.10032536163926124, 'overlap rate': 0.2390505162999034}
#
# Current epoch: 25,
# training performance: {'loss': 1.648971600830555, 'abosulate accuracy': 0.014600000868085772, 'consecutive overlap rate': 0.14191800253465772, 'overlap rate': 0.5582010805606842}
# evaluation performance: {'loss': 2.9856211870908735, 'abosulate accuracy': 0.010950000706361606, 'consecutive overlap rate': 0.12700758241117, 'overlap rate': 0.2718218233436346}
#
# Current epoch: 30,
# training performance: {'loss': 1.4987057074904442, 'abosulate accuracy': 0.031300001789350065, 'consecutive overlap rate': 0.16986885564401746, 'overlap rate': 0.6032813370227814}
# evaluation performance: {'loss': 3.0205059468746187, 'abosulate accuracy': 0.017750001110835002, 'consecutive overlap rate': 0.14647163404151797, 'overlap rate': 0.2915572810918093}
#
# Current epoch: 35,
# training performance: {'loss': 1.3857184782624246, 'abosulate accuracy': 0.04690000202972442, 'consecutive overlap rate': 0.1963100280612707, 'overlap rate': 0.6308799050748348}
# evaluation performance: {'loss': 2.9499039709568025, 'abosulate accuracy': 0.03615000158315525, 'consecutive overlap rate': 0.18515978697687388, 'overlap rate': 0.3282127484679222}
#
# Current epoch: 40,
# training performance: {'loss': 1.2675427459180355, 'abosulate accuracy': 0.06860000296728685, 'consecutive overlap rate': 0.23056516479700803, 'overlap rate': 0.6638742536306381}
# evaluation performance: {'loss': 2.901430469751358, 'abosulate accuracy': 0.06130000347038731, 'consecutive overlap rate': 0.21912588067352773, 'overlap rate': 0.35830451659858226}
#
# Current epoch: 45,
# training performance: {'loss': 1.2439026147127152, 'abosulate accuracy': 0.06370000368915499, 'consecutive overlap rate': 0.2339250210672617, 'overlap rate': 0.667068911343813}
# evaluation performance: {'loss': 2.9530578777194023, 'abosulate accuracy': 0.062250002281507476, 'consecutive overlap rate': 0.22311111222952604, 'overlap rate': 0.36274015046656133}
#
# Current epoch: 50,
# training performance: {'loss': 1.125043136626482, 'abosulate accuracy': 0.09560000357450918, 'consecutive overlap rate': 0.26208280473947526, 'overlap rate': 0.6990809947252273}
# evaluation performance: {'loss': 2.9185416504740713, 'abosulate accuracy': 0.09910000389791093, 'consecutive overlap rate': 0.2558917453512549, 'overlap rate': 0.3916151415556669}
#
# Current epoch: 55,
# training performance: {'loss': 1.110236570239067, 'abosulate accuracy': 0.0923000039998442, 'consecutive overlap rate': 0.26458339765667915, 'overlap rate': 0.7038201957941055}
# evaluation performance: {'loss': 2.9973844066262245, 'abosulate accuracy': 0.10310000570607372, 'consecutive overlap rate': 0.26391422711312773, 'overlap rate': 0.3980759672820568}
#
# Current epoch: 60,
# training performance: {'loss': 1.01333222463727, 'abosulate accuracy': 0.1330000060144812, 'consecutive overlap rate': 0.2997532306239009, 'overlap rate': 0.7304621741175652}
# evaluation performance: {'loss': 2.9235855519771574, 'abosulate accuracy': 0.13000000561005437, 'consecutive overlap rate': 0.29030276238918307, 'overlap rate': 0.42130311764776707}
#
# Current epoch: 65,
# training performance: {'loss': 0.9809141732752323, 'abosulate accuracy': 0.13440000485861675, 'consecutive overlap rate': 0.3006817938759923, 'overlap rate': 0.7367571868002415}
# evaluation performance: {'loss': 2.928488082438707, 'abosulate accuracy': 0.13840000645723194, 'consecutive overlap rate': 0.2990611964836717, 'overlap rate': 0.43131028302013874}
#
# Current epoch: 70,
# training performance: {'loss': 0.9339501440525055, 'abosulate accuracy': 0.1565000062575564, 'consecutive overlap rate': 0.31984135527163743, 'overlap rate': 0.7518897086381913}
# evaluation performance: {'loss': 2.897077100723982, 'abosulate accuracy': 0.13965000725002027, 'consecutive overlap rate': 0.29922446627169846, 'overlap rate': 0.43305029049515725}
#
# Current epoch: 75,
# training performance: {'loss': 0.8809609897434711, 'abosulate accuracy': 0.16600000890903174, 'consecutive overlap rate': 0.3323692498728633, 'overlap rate': 0.7631251588463783}
# evaluation performance: {'loss': 2.9549669079482555, 'abosulate accuracy': 0.15320000664214603, 'consecutive overlap rate': 0.31506034545600414, 'overlap rate': 0.4482413575053215}
#
# Current epoch: 80,
# training performance: {'loss': 0.8750974897295236, 'abosulate accuracy': 0.15480000709649175, 'consecutive overlap rate': 0.3232403976842761, 'overlap rate': 0.7618603244423866}
# evaluation performance: {'loss': 2.9912924893200397, 'abosulate accuracy': 0.15465000683325342, 'consecutive overlap rate': 0.3122525693848729, 'overlap rate': 0.44830551370978355}
#
# Current epoch: 85,
# training performance: {'loss': 0.8117037203162909, 'abosulate accuracy': 0.17820000880165027, 'consecutive overlap rate': 0.34505992792546747, 'overlap rate': 0.7807203367352485}
# evaluation performance: {'loss': 2.9266466781497003, 'abosulate accuracy': 0.1757000086887274, 'consecutive overlap rate': 0.3361446777358651, 'overlap rate': 0.4674677662551403}
#
# Current epoch: 90,
# training performance: {'loss': 0.7670810751616954, 'abosulate accuracy': 0.1920000100741163, 'consecutive overlap rate': 0.3607029069215059, 'overlap rate': 0.7904527992010116}
# evaluation performance: {'loss': 2.9323335595428945, 'abosulate accuracy': 0.18855000945623032, 'consecutive overlap rate': 0.35233172196894885, 'overlap rate': 0.48140390440821645}
#
# Current epoch: 95,
# training performance: {'loss': 0.7650644369423389, 'abosulate accuracy': 0.18610000984044744, 'consecutive overlap rate': 0.3586564915254712, 'overlap rate': 0.7895365640521049}
# evaluation performance: {'loss': 2.9817264869809152, 'abosulate accuracy': 0.1872000091825612, 'consecutive overlap rate': 0.3499336468055844, 'overlap rate': 0.4813789945095778}
#
# Current epoch: 100,
# training performance: {'loss': 0.7266475699841977, 'abosulate accuracy': 0.2020000094315037, 'consecutive overlap rate': 0.3728646008297801, 'overlap rate': 0.8007863998413086}
# evaluation performance: {'loss': 2.94306275062263, 'abosulate accuracy': 0.20090001003700309, 'consecutive overlap rate': 0.3624914487823844, 'overlap rate': 0.4897322725504637}
#
# Current epoch: 105,
# training performance: {'loss': 0.7093075003474951, 'abosulate accuracy': 0.20640001045539974, 'consecutive overlap rate': 0.37716649621725085, 'overlap rate': 0.8051541820168495}
# evaluation performance: {'loss': 2.9363821230828764, 'abosulate accuracy': 0.20530001054285094, 'consecutive overlap rate': 0.36624223086982965, 'overlap rate': 0.49372902847826483}
#
# Current epoch: 110,
# training performance: {'loss': 0.701927307061851, 'abosulate accuracy': 0.20630001018289476, 'consecutive overlap rate': 0.37894867900758983, 'overlap rate': 0.8049787387251854}
# evaluation performance: {'loss': 2.9716458223760127, 'abosulate accuracy': 0.21090001048287377, 'consecutive overlap rate': 0.3734355764463544, 'overlap rate': 0.5020106222480536}
#
# Current epoch: 115,
# training performance: {'loss': 0.6754934439435601, 'abosulate accuracy': 0.210300011432264, 'consecutive overlap rate': 0.3868668818846345, 'overlap rate': 0.8121884495019913}
# evaluation performance: {'loss': 2.9743455342948435, 'abosulate accuracy': 0.22100001194048674, 'consecutive overlap rate': 0.3795958995819092, 'overlap rate': 0.5063588045537472}
#
# Current epoch: 120,
# training performance: {'loss': 0.656278763152659, 'abosulate accuracy': 0.22660001139156521, 'consecutive overlap rate': 0.3957572946324944, 'overlap rate': 0.8180235922336578}
# evaluation performance: {'loss': 2.929553721100092, 'abosulate accuracy': 0.22935001084115356, 'consecutive overlap rate': 0.38759798631072045, 'overlap rate': 0.5124574061483145}
#
# Current epoch: 125,
# training performance: {'loss': 0.6661699987947941, 'abosulate accuracy': 0.2249000073876232, 'consecutive overlap rate': 0.3946899563074112, 'overlap rate': 0.8156435579061508}
# evaluation performance: {'loss': 2.9624945666640996, 'abosulate accuracy': 0.22325001296121627, 'consecutive overlap rate': 0.37722368724644184, 'overlap rate': 0.5055683597922325}
#
# Current epoch: 130,
# training performance: {'loss': 0.6196701917797327, 'abosulate accuracy': 0.23080001089256258, 'consecutive overlap rate': 0.4040956003591418, 'overlap rate': 0.8260593265295029}
# evaluation performance: {'loss': 2.987407109513879, 'abosulate accuracy': 0.22595001372974366, 'consecutive overlap rate': 0.3894388467073441, 'overlap rate': 0.5177542567253113}
#
# Current epoch: 135,
# training performance: {'loss': 0.6438879441469908, 'abosulate accuracy': 0.22660001192707568, 'consecutive overlap rate': 0.39803936798125505, 'overlap rate': 0.8186920925974845}
# evaluation performance: {'loss': 2.9929501907899976, 'abosulate accuracy': 0.24090001159347593, 'consecutive overlap rate': 0.3926074106246233, 'overlap rate': 0.5197490978986025}
#
# Current epoch: 140,
# training performance: {'loss': 0.5758810525760054, 'abosulate accuracy': 0.24530001354869455, 'consecutive overlap rate': 0.4188970930874348, 'overlap rate': 0.8389855399727821}
# evaluation performance: {'loss': 2.9276603387668727, 'abosulate accuracy': 0.2613000144250691, 'consecutive overlap rate': 0.4182293497025967, 'overlap rate': 0.5411319132894278}
#
# Current epoch: 145,
# training performance: {'loss': 0.5795553434640169, 'abosulate accuracy': 0.23560001131845637, 'consecutive overlap rate': 0.41507347151637075, 'overlap rate': 0.8361092507839203}
# evaluation performance: {'loss': 2.9565333425998688, 'abosulate accuracy': 0.2585000148974359, 'consecutive overlap rate': 0.41407373622059823, 'overlap rate': 0.5390992451459169}
#
# Current epoch: 150,
# training performance: {'loss': 0.5756653113290667, 'abosulate accuracy': 0.24130001137964427, 'consecutive overlap rate': 0.4190156929194927, 'overlap rate': 0.8359519347548485}
# evaluation performance: {'loss': 2.9858198469504713, 'abosulate accuracy': 0.25935001075267794, 'consecutive overlap rate': 0.4134634703397751, 'overlap rate': 0.5403534773737192}
#
# Current epoch: 155,
# training performance: {'loss': 0.5601983221247793, 'abosulate accuracy': 0.24460001266561449, 'consecutive overlap rate': 0.42415495961904526, 'overlap rate': 0.8404534459114075}
# evaluation performance: {'loss': 2.9858631705865264, 'abosulate accuracy': 0.262550012441352, 'consecutive overlap rate': 0.41478422470390797, 'overlap rate': 0.5427341558039188}
#
# Current epoch: 160,
# training performance: {'loss': 0.5348907543346286, 'abosulate accuracy': 0.26050001084804536, 'consecutive overlap rate': 0.4319917630404234, 'overlap rate': 0.8482537999749183}
# evaluation performance: {'loss': 2.9418023793026804, 'abosulate accuracy': 0.267800013627857, 'consecutive overlap rate': 0.4221635863184929, 'overlap rate': 0.5489791497588158}
#
# Current epoch: 165,
# training performance: {'loss': 0.5230594957247376, 'abosulate accuracy': 0.2616000107489526, 'consecutive overlap rate': 0.4303514499217272, 'overlap rate': 0.8507886618375778}
# evaluation performance: {'loss': 2.9399284625425937, 'abosulate accuracy': 0.2764000159688294, 'consecutive overlap rate': 0.4218110222369432, 'overlap rate': 0.54979792162776}
#
# Current epoch: 170,
# training performance: {'loss': 0.4927563589066267, 'abosulate accuracy': 0.27090001162141564, 'consecutive overlap rate': 0.4424181364476681, 'overlap rate': 0.859217369556427}
# evaluation performance: {'loss': 2.9722777284681796, 'abosulate accuracy': 0.28160001430660486, 'consecutive overlap rate': 0.4291795466095209, 'overlap rate': 0.5578067854046822}
#
# Current epoch: 175,
# training performance: {'loss': 0.4963691317476332, 'abosulate accuracy': 0.26500001065433026, 'consecutive overlap rate': 0.4338106133043766, 'overlap rate': 0.8581534460186958}
# evaluation performance: {'loss': 2.93256500530988, 'abosulate accuracy': 0.27480001403018833, 'consecutive overlap rate': 0.420835611410439, 'overlap rate': 0.5535044886171818}
#
# Current epoch: 180,
# training performance: {'loss': 0.4691655789501965, 'abosulate accuracy': 0.265500009059906, 'consecutive overlap rate': 0.44443021565675733, 'overlap rate': 0.8642053470015526}
# evaluation performance: {'loss': 2.92618910856545, 'abosulate accuracy': 0.3056500118225813, 'consecutive overlap rate': 0.44743815027177336, 'overlap rate': 0.5746388286352158}
#
# Current epoch: 185,
# training performance: {'loss': 0.448980413749814, 'abosulate accuracy': 0.28400001060217617, 'consecutive overlap rate': 0.45801449976861475, 'overlap rate': 0.8704465091228485}
# evaluation performance: {'loss': 2.9410060554742814, 'abosulate accuracy': 0.3066000136488583, 'consecutive overlap rate': 0.4503815848380327, 'overlap rate': 0.5778634652495385}
#
# Current epoch: 190,
# training performance: {'loss': 0.4482158085331321, 'abosulate accuracy': 0.2817000116221607, 'consecutive overlap rate': 0.4588580779731274, 'overlap rate': 0.8699556961655617}
# evaluation performance: {'loss': 2.957270539738238, 'abosulate accuracy': 0.3013000125065446, 'consecutive overlap rate': 0.44603630900382996, 'overlap rate': 0.5765922971069812}
#
# Current epoch: 195,
# training performance: {'loss': 0.46391440331935885, 'abosulate accuracy': 0.2674000091850758, 'consecutive overlap rate': 0.44960138350725176, 'overlap rate': 0.8646558240056038}
# evaluation performance: {'loss': 2.983809970319271, 'abosulate accuracy': 0.30240001445636155, 'consecutive overlap rate': 0.44211488105356694, 'overlap rate': 0.5742588855326176}
#
# Current epoch: 200,
# training performance: {'loss': 0.4223904483951628, 'abosulate accuracy': 0.29950001146644356, 'consecutive overlap rate': 0.469031885266304, 'overlap rate': 0.8794441223144531}
# evaluation performance: {'loss': 2.9229205005802212, 'abosulate accuracy': 0.3101500142365694, 'consecutive overlap rate': 0.4547846082597971, 'overlap rate': 0.5824696086347103}
#
# Experiments_Logs/Experiment#5/RNN/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/RNN/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 6.179324424266815, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.12795875146985053, 'overlap rate': 0.235428773984313}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.914975014515221, 'abosulate accuracy': 0.310825015604496, 'consecutive overlap rate': 0.45367981754243375, 'overlap rate': 0.5829784274101257}
# Experiments_Logs/Experiment#5/RNN/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
