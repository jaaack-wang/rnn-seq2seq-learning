# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = True
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 5
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#5/GRU created!
# ./Experiments_Logs/Experiment#5/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#5/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#5/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#5 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
# evaluation performance: {'loss': 5.630310505628586, 'abosulate accuracy': 0.0015500000794418157, 'consecutive overlap rate': 0.14314586659893394, 'overlap rate': 0.27885347567498686}
#
# Current epoch: 185,
# training performance: {'loss': 0.3737647826783359, 'abosulate accuracy': 0.18820000886917115, 'consecutive overlap rate': 0.4040367014706135, 'overlap rate': 0.8657222896814346}
# evaluation performance: {'loss': 5.845540136098862, 'abosulate accuracy': 0.000800000032177195, 'consecutive overlap rate': 0.14109241589903831, 'overlap rate': 0.2745661783963442}
#
# Current epoch: 190,
# training performance: {'loss': 0.25198780847713353, 'abosulate accuracy': 0.2613000110490248, 'consecutive overlap rate': 0.4796123197302222, 'overlap rate': 0.9116831362247467}
# evaluation performance: {'loss': 6.388834929466247, 'abosulate accuracy': 0.0013000000384636224, 'consecutive overlap rate': 0.14587031807750464, 'overlap rate': 0.2704413913190365}
#
# Current epoch: 195,
# training performance: {'loss': 0.38877087738364935, 'abosulate accuracy': 0.16970000732690096, 'consecutive overlap rate': 0.38726818803697827, 'overlap rate': 0.8610858768224716}
# evaluation performance: {'loss': 5.320736712217331, 'abosulate accuracy': 0.0012000000686384737, 'consecutive overlap rate': 0.13514365814626217, 'overlap rate': 0.2732161920517683}
#
# Current epoch: 200,
# training performance: {'loss': 0.34308597901836035, 'abosulate accuracy': 0.18930000755935908, 'consecutive overlap rate': 0.42303359918296335, 'overlap rate': 0.877622127532959}
# evaluation performance: {'loss': 6.145683515071869, 'abosulate accuracy': 0.0006000000110361725, 'consecutive overlap rate': 0.13828587383031846, 'overlap rate': 0.26492504626512525}
#
# Experiments_Logs/Experiment#5/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.7873848512768746, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00772666672419291, 'overlap rate': 0.44282046109437945}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.4206175565719605, 'abosulate accuracy': 0.0025250001257518307, 'consecutive overlap rate': 0.1420703187584877, 'overlap rate': 0.29118982069194316}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.5588770851012197, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005265716739719914, 'overlap rate': 0.4395888363161395}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.8630957791679785, 'abosulate accuracy': 0.0240263167376581, 'consecutive overlap rate': 0.16549913281280743, 'overlap rate': 0.2527042333232729}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.3024131655693054, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002344524028012529, 'overlap rate': 0.039584841066971424}
# evaluation performance: {'loss': 3.3241567850112914, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0023287548290682027, 'overlap rate': 0.04608484748750925}
#
# Current epoch: 10,
# training performance: {'loss': 3.308622258901596, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029323397611733526, 'overlap rate': 0.03793765504378825}
# evaluation performance: {'loss': 3.3114242613315583, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003009463896160014, 'overlap rate': 0.04214818943291902}
#
# Current epoch: 15,
# training performance: {'loss': 3.2832598268985747, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003913568684947677, 'overlap rate': 0.038064108602702616}
# evaluation performance: {'loss': 3.2810046792030336, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004466422973200679, 'overlap rate': 0.04693426033481955}
#
# Current epoch: 20,
# training performance: {'loss': 3.2704014241695405, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005590012899483554, 'overlap rate': 0.041155862342566255}
# evaluation performance: {'loss': 3.2659534752368926, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006484940426889807, 'overlap rate': 0.05397025169804692}
#
# Current epoch: 25,
# training performance: {'loss': 3.2559975504875185, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0073722959496080875, 'overlap rate': 0.0456299627199769}
# evaluation performance: {'loss': 3.2516283631324767, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008681374869775027, 'overlap rate': 0.05442062001675367}
#
# Current epoch: 30,
# training performance: {'loss': 3.237160336971283, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010540890588890761, 'overlap rate': 0.05443714503198862}
# evaluation performance: {'loss': 3.2386501669883727, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013026696816086768, 'overlap rate': 0.06191874714568257}
#
# Current epoch: 35,
# training performance: {'loss': 3.2170732617378235, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012114125373773276, 'overlap rate': 0.05959458057768643}
# evaluation performance: {'loss': 3.2197118759155274, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013972265738993883, 'overlap rate': 0.06674150926992298}
#
# Current epoch: 40,
# training performance: {'loss': 3.1906590282917024, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013752166670747102, 'overlap rate': 0.06441026171669365}
# evaluation performance: {'loss': 3.1956813752651216, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014953933318611234, 'overlap rate': 0.07079046731814742}
#
# Current epoch: 45,
# training performance: {'loss': 3.163373738527298, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015572944458108395, 'overlap rate': 0.0716354695148766}
# evaluation performance: {'loss': 3.1708277463912964, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016612296598032116, 'overlap rate': 0.07755536204203964}
#
# Current epoch: 50,
# training performance: {'loss': 3.1345992147922517, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.017361278855241837, 'overlap rate': 0.07768563395366072}
# evaluation performance: {'loss': 3.145986956357956, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018376291310414673, 'overlap rate': 0.08426923509687186}
#
# Current epoch: 55,
# training performance: {'loss': 3.0993243873119356, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0197114281821996, 'overlap rate': 0.0869728504680097}
# evaluation performance: {'loss': 3.122648388147354, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020872102561406793, 'overlap rate': 0.09032730404287577}
#
# Current epoch: 60,
# training performance: {'loss': 3.0628474593162536, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0225038095144555, 'overlap rate': 0.0975268205627799}
# evaluation performance: {'loss': 3.102731192111969, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024460637755692006, 'overlap rate': 0.09671154823154211}
#
# Current epoch: 65,
# training performance: {'loss': 3.0175735473632814, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025572438002564014, 'overlap rate': 0.11052960883826017}
# evaluation performance: {'loss': 3.0784665048122406, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02812092665117234, 'overlap rate': 0.10426562707871198}
#
# Current epoch: 70,
# training performance: {'loss': 2.972714501619339, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02769503160379827, 'overlap rate': 0.123300795070827}
# evaluation performance: {'loss': 3.03542183637619, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03483227710239589, 'overlap rate': 0.11053132954984904}
#
# Current epoch: 75,
# training performance: {'loss': 2.8496970891952516, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03199495086446404, 'overlap rate': 0.1484530743211508}
# evaluation performance: {'loss': 2.9870745122432707, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03478776800911874, 'overlap rate': 0.11623329613357783}
#
# Current epoch: 80,
# training performance: {'loss': 2.7656632602214812, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03853130941279233, 'overlap rate': 0.17066099159419537}
# evaluation performance: {'loss': 2.944031596183777, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04336013328284025, 'overlap rate': 0.12419320736080408}
#
# Current epoch: 85,
# training performance: {'loss': 2.6487500429153443, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04598931162618101, 'overlap rate': 0.1957157203927636}
# evaluation performance: {'loss': 2.8851044952869414, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.050176148768514395, 'overlap rate': 0.13101770877838134}
#
# Current epoch: 90,
# training performance: {'loss': 2.572874683141708, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05022808453068137, 'overlap rate': 0.216623580083251}
# evaluation performance: {'loss': 2.923482197523117, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04693434159271419, 'overlap rate': 0.12564004361629486}
#
# Current epoch: 95,
# training performance: {'loss': 2.4368556261062624, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05976358680054546, 'overlap rate': 0.2405403856188059}
# evaluation performance: {'loss': 2.820566838979721, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06300636725500226, 'overlap rate': 0.14335438907146453}
#
# Current epoch: 100,
# training performance: {'loss': 2.3057040721178055, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06690887450240553, 'overlap rate': 0.2704307585954666}
# evaluation performance: {'loss': 2.7507506012916565, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0660099561791867, 'overlap rate': 0.150587697699666}
#
# Current epoch: 105,
# training performance: {'loss': 2.2431699872016906, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07328510046936572, 'overlap rate': 0.2896449387073517}
# evaluation performance: {'loss': 2.7150291323661806, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07958982442505658, 'overlap rate': 0.16526167280972004}
#
# Current epoch: 110,
# training performance: {'loss': 2.2036663562059404, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07873846688307821, 'overlap rate': 0.3021526362746954}
# evaluation performance: {'loss': 2.772451066970825, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08086667573079467, 'overlap rate': 0.1647758526727557}
#
# Current epoch: 115,
# training performance: {'loss': 2.0521526664495466, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.09061752324923873, 'overlap rate': 0.3379212010651827}
# evaluation performance: {'loss': 2.647927623987198, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.09135084869340063, 'overlap rate': 0.18194194845855235}
#
# Current epoch: 120,
# training performance: {'loss': 2.0416879534721373, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08807017412036658, 'overlap rate': 0.3476053152233362}
# evaluation performance: {'loss': 2.686971962451935, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08975487235002219, 'overlap rate': 0.1804847301915288}
#
# Current epoch: 125,
# training performance: {'loss': 1.929865688085556, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.09720759075134992, 'overlap rate': 0.37121867947280407}
# evaluation performance: {'loss': 2.7184540271759032, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08498797197826206, 'overlap rate': 0.17898200899362565}
#
# Current epoch: 130,
# training performance: {'loss': 1.8919402703642845, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0965094038285315, 'overlap rate': 0.384328655898571}
# evaluation performance: {'loss': 2.641781833767891, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.10513664935715497, 'overlap rate': 0.2005059879273176}
#
# Current epoch: 135,
# training performance: {'loss': 1.6772594451904297, 'abosulate accuracy': 0.0003000000026077032, 'consecutive overlap rate': 0.11478221053257584, 'overlap rate': 0.4401171088218689}
# evaluation performance: {'loss': 2.6606874227523805, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11597299631685018, 'overlap rate': 0.2140294937416911}
#
# Current epoch: 140,
# training performance: {'loss': 1.5931394085288049, 'abosulate accuracy': 0.0008000000147148967, 'consecutive overlap rate': 0.1253137462772429, 'overlap rate': 0.4638633541762829}
# evaluation performance: {'loss': 2.661991387605667, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.10671991175040603, 'overlap rate': 0.2108358271420002}
#
# Current epoch: 145,
# training performance: {'loss': 1.7585878759622573, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.10830862512812019, 'overlap rate': 0.41842380315065386}
# evaluation performance: {'loss': 2.7722972095012666, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# evaluation performance: {'loss': 2.8562240272760393, 'abosulate accuracy': 0.0014500000746920706, 'consecutive overlap rate': 0.14033760204911233, 'overlap rate': 0.2719095714390278}
#
# Current epoch: 195,
# training performance: {'loss': 1.1808185912668705, 'abosulate accuracy': 0.012300000700633973, 'consecutive overlap rate': 0.19595265239477158, 'overlap rate': 0.6003774978220463}
# evaluation performance: {'loss': 2.7589717745780944, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.13013164065778254, 'overlap rate': 0.25443390719592573}
#
# Current epoch: 200,
# training performance: {'loss': 1.1501095324754715, 'abosulate accuracy': 0.0062000004574656485, 'consecutive overlap rate': 0.19956951085478067, 'overlap rate': 0.6000424228608608}
# evaluation performance: {'loss': 2.9448812663555146, 'abosulate accuracy': 0.0004000000248197466, 'consecutive overlap rate': 0.13334000622853637, 'overlap rate': 0.2670080326497555}
#
# Experiments_Logs/Experiment#5/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.7965997099876403, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00601096757745836, 'overlap rate': 0.19046634593978523}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.854893481731415, 'abosulate accuracy': 0.0014750000613275916, 'consecutive overlap rate': 0.14160096291452645, 'overlap rate': 0.2720154084265232}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.7819615502511303, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038019140836812798, 'overlap rate': 0.2473610230030552}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.100225872115085, 'abosulate accuracy': 0.04042105435540801, 'consecutive overlap rate': 0.16327669074464785, 'overlap rate': 0.2553345629651296}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9367512494325638, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.08690851666033268, 'overlap rate': 0.38188760802149774}
# evaluation performance: {'loss': 2.5846386551856995, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.11171177430078387, 'overlap rate': 0.2249816158786416}
#
# Current epoch: 10,
# training performance: {'loss': 1.5087311312556266, 'abosulate accuracy': 0.0007000000332482159, 'consecutive overlap rate': 0.14090609252452851, 'overlap rate': 0.4954232074320316}
# evaluation performance: {'loss': 2.4651703536510468, 'abosulate accuracy': 0.0003000000084284693, 'consecutive overlap rate': 0.14727317756041886, 'overlap rate': 0.26295608691871164}
#
# Current epoch: 15,
# training performance: {'loss': 1.3338300451636314, 'abosulate accuracy': 0.003300000133458525, 'consecutive overlap rate': 0.16752077620476485, 'overlap rate': 0.5447069369256496}
# evaluation performance: {'loss': 2.524347797036171, 'abosulate accuracy': 0.0002500000118743628, 'consecutive overlap rate': 0.13715822882950307, 'overlap rate': 0.25991044342517855}
#
# Current epoch: 20,
# training performance: {'loss': 1.280142217129469, 'abosulate accuracy': 0.01250000074505806, 'consecutive overlap rate': 0.1875176782719791, 'overlap rate': 0.5628702849149704}
# evaluation performance: {'loss': 6.81714483499527, 'abosulate accuracy': 0.0013000000501051546, 'consecutive overlap rate': 0.14090596325695515, 'overlap rate': 0.25366017073392866}
#
# Current epoch: 195,
# training performance: {'loss': 0.38761087879538536, 'abosulate accuracy': 0.16680000590858982, 'consecutive overlap rate': 0.38937683794647454, 'overlap rate': 0.860610967874527}
# evaluation performance: {'loss': 5.768131673336029, 'abosulate accuracy': 0.0010500000265892596, 'consecutive overlap rate': 0.1339670442044735, 'overlap rate': 0.26257573813199997}
#
# Current epoch: 200,
# training performance: {'loss': 0.2669677593745291, 'abosulate accuracy': 0.2572000132058747, 'consecutive overlap rate': 0.4666518343612552, 'overlap rate': 0.9062155842781067}
# evaluation performance: {'loss': 5.798900556564331, 'abosulate accuracy': 0.002850000065518543, 'consecutive overlap rate': 0.14472556617110968, 'overlap rate': 0.2772854778915644}
#
# Experiments_Logs/Experiment#5/GRU/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#5/GRU/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 4.1067203104496, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05270286060404032, 'overlap rate': 0.4804054284468293}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.049581980705261, 'abosulate accuracy': 0.0021250001242151483, 'consecutive overlap rate': 0.1474668557755649, 'overlap rate': 0.27095443177968265}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.620762237425773, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03225376686501887, 'overlap rate': 0.44344201837816544}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.12423218551435, 'abosulate accuracy': 0.05118421269090552, 'consecutive overlap rate': 0.1826724648769749, 'overlap rate': 0.2623301340561164}
# Experiments_Logs/Experiment#5/GRU/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#5 with GRU seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#5/GRU/hyperparameters.json saved!

# %%
from google.colab import runtime
runtime.unassign()
