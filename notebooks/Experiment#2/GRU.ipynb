# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 128
embd_dim = 64
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = True
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 2
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#2 created!
# ./Experiments_Logs/Experiment#2/GRU created!
# ./Experiments_Logs/Experiment#2/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#2/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#2/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#2 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.5388531126081944, 'abosulate accuracy': 0.01720000058412552, 'consecutive overlap rate': 0.08611333416774869, 'overlap rate': 0.6013367235660553}
# evaluation performance: {'loss': 2.395705837011337, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05668666725978255, 'overlap rate': 0.48541588373482225}
#
# Current epoch: 10,
# training performance: {'loss': 0.003962531371507793, 'abosulate accuracy': 0.9973000213503838, 'consecutive overlap rate': 0.9985866695642471, 'overlap rate': 0.9999550372362137}
# evaluation performance: {'loss': 0.013296880715643056, 'abosulate accuracy': 0.9899000376462936, 'consecutive overlap rate': 0.9950058415532113, 'overlap rate': 0.9986250512301922}
#
# Experiments_Logs/Experiment#2/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.007159761390357744, 'abosulate accuracy': 0.9938500352203846, 'consecutive overlap rate': 0.9967512600123882, 'overlap rate': 0.9992917120456696}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.0620574054075405, 'abosulate accuracy': 0.8323750421404839, 'consecutive overlap rate': 0.9120486326515674, 'overlap rate': 0.98901057690382}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.6221781476851432, 'abosulate accuracy': 0.5223716618553285, 'consecutive overlap rate': 0.7339764283549401, 'overlap rate': 0.9118747695799797}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.3072908410410349, 'abosulate accuracy': 0.3797894925013871, 'consecutive overlap rate': 0.673073864002761, 'overlap rate': 0.8171340682004627}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.4454983443021774, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.051653333776630464, 'overlap rate': 0.5612183928489685}
# evaluation performance: {'loss': 2.152554693818092, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.051439167372882365, 'overlap rate': 0.3695708729326725}
#
# Current epoch: 10,
# training performance: {'loss': 1.1319133937358856, 'abosulate accuracy': 0.005200000223703682, 'consecutive overlap rate': 0.09701666701585054, 'overlap rate': 0.6521367371082306}
# evaluation performance: {'loss': 2.56707658469677, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03786250026896596, 'overlap rate': 0.5050758846104145}
#
# Current epoch: 15,
# training performance: {'loss': 0.007419534760992974, 'abosulate accuracy': 0.9877000406384469, 'consecutive overlap rate': 0.9935100093483925, 'overlap rate': 0.9997850775718689}
# evaluation performance: {'loss': 0.03628438841551542, 'abosulate accuracy': 0.9706500485539437, 'consecutive overlap rate': 0.9841266810894013, 'overlap rate': 0.995558388531208}
#
# Current epoch: 20,
# training performance: {'loss': 0.0020191212970530614, 'abosulate accuracy': 0.9999000012874604, 'consecutive overlap rate': 0.9999766662716866, 'overlap rate': 0.9999983355402946}
# evaluation performance: {'loss': 0.018391441681887954, 'abosulate accuracy': 0.9859000362455845, 'consecutive overlap rate': 0.9921541787683964, 'overlap rate': 0.9979583904147148}
#
# Current epoch: 25,
# training performance: {'loss': 0.000977558468002826, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01284770658967318, 'abosulate accuracy': 0.9905500374734402, 'consecutive overlap rate': 0.9947716735303402, 'overlap rate': 0.9986900597810745}
#
# Current epoch: 30,
# training performance: {'loss': 0.0005752328084781766, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013067746973683824, 'abosulate accuracy': 0.9908500336110592, 'consecutive overlap rate': 0.9948483422398567, 'overlap rate': 0.9987092204391956}
#
# Current epoch: 35,
# training performance: {'loss': 0.000377716760704061, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.009758132058777846, 'abosulate accuracy': 0.9934500388801097, 'consecutive overlap rate': 0.9961133420467376, 'overlap rate': 0.9990458816289902}
#
# Current epoch: 40,
# training performance: {'loss': 0.00026637834125722295, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01039683472008619, 'abosulate accuracy': 0.9936500370502472, 'consecutive overlap rate': 0.9962516754865647, 'overlap rate': 0.9990342170000076}
#
# Current epoch: 45,
# training performance: {'loss': 0.00019598831058829092, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.007799379497009795, 'abosulate accuracy': 0.9946500286459923, 'consecutive overlap rate': 0.9969741724431515, 'overlap rate': 0.9992625370621682}
#
# Experiments_Logs/Experiment#2/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.007043392806463089, 'abosulate accuracy': 0.9951750319451094, 'consecutive overlap rate': 0.9973054267466068, 'overlap rate': 0.9993333730846643}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.06915655485354363, 'abosulate accuracy': 0.7922250360250473, 'consecutive overlap rate': 0.8703477159142494, 'overlap rate': 0.9884028509259224}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.45741752155365484, 'abosulate accuracy': 0.7621424801888005, 'consecutive overlap rate': 0.8911710677608367, 'overlap rate': 0.955801917660621}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.7443985371899448, 'abosulate accuracy': 0.6146316077670475, 'consecutive overlap rate': 0.8095593954387464, 'overlap rate': 0.9183191986460435}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.220293940603733, 'abosulate accuracy': 0.0013000000617466867, 'consecutive overlap rate': 0.08317500124685466, 'overlap rate': 0.6237833961844444}
# evaluation performance: {'loss': 1.4814367562532424, 'abosulate accuracy': 0.008200000307988375, 'consecutive overlap rate': 0.15925416834652423, 'overlap rate': 0.6198017343878746}
#
# Current epoch: 10,
# training performance: {'loss': 1.2686702370643617, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.070081667881459, 'overlap rate': 0.6124517366290092}
# evaluation performance: {'loss': 3.692083975672722, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.0836008339188993, 'overlap rate': 0.5157375518232584}
#
# Current epoch: 15,
# training performance: {'loss': 0.008258417574688792, 'abosulate accuracy': 0.9789000421762466, 'consecutive overlap rate': 0.989683347940445, 'overlap rate': 0.9996367365121841}
# evaluation performance: {'loss': 0.05677174628945068, 'abosulate accuracy': 0.9562500439584255, 'consecutive overlap rate': 0.9763841770589352, 'overlap rate': 0.9927850529551506}
#
# Current epoch: 20,
# training performance: {'loss': 0.002048702188767493, 'abosulate accuracy': 0.999000009894371, 'consecutive overlap rate': 0.9994566708803176, 'overlap rate': 0.999983349442482}
# evaluation performance: {'loss': 0.024925156161771156, 'abosulate accuracy': 0.9823000371456146, 'consecutive overlap rate': 0.9898275144398212, 'overlap rate': 0.9973500601947307}
#
# Current epoch: 25,
# training performance: {'loss': 0.0009650128282373771, 'abosulate accuracy': 0.999700003862381, 'consecutive overlap rate': 0.9998400017619133, 'overlap rate': 0.9999950066208839}
# evaluation performance: {'loss': 0.020676327649562155, 'abosulate accuracy': 0.9873500369489193, 'consecutive overlap rate': 0.992526239156723, 'overlap rate': 0.9978721417486668}
#
# Current epoch: 30,
# training performance: {'loss': 0.0005605941179965157, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.018117907075065887, 'abosulate accuracy': 0.9893500372767449, 'consecutive overlap rate': 0.9937108404934406, 'overlap rate': 0.9982433915138245}
#
# Current epoch: 35,
# training performance: {'loss': 0.00036616677170968613, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01972509185652598, 'abosulate accuracy': 0.9891000382602215, 'consecutive overlap rate': 0.9932050116360187, 'overlap rate': 0.9981708869338035}
#
# Current epoch: 40,
# training performance: {'loss': 0.00025747441359271763, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.018217847318737768, 'abosulate accuracy': 0.9912000335752964, 'consecutive overlap rate': 0.9943433433771134, 'overlap rate': 0.9983508825302124}
#
# Current epoch: 45,
# training performance: {'loss': 0.0001892249842057936, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012602322014208767, 'abosulate accuracy': 0.9929000362753868, 'consecutive overlap rate': 0.9956683434545994, 'overlap rate': 0.998842554539442}
#
# Current epoch: 50,
# training performance: {'loss': 0.00014394176068890374, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014544564571042428, 'abosulate accuracy': 0.9922000370919705, 'consecutive overlap rate': 0.995244175940752, 'overlap rate': 0.9987342201173306}
#
# Current epoch: 55,
# training performance: {'loss': 0.00011216091552341822, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014301786832038487, 'abosulate accuracy': 0.993250036239624, 'consecutive overlap rate': 0.9957483448088169, 'overlap rate': 0.9987792111933231}
#
# Current epoch: 60,
# training performance: {'loss': 8.93260503289639e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01518692434001423, 'abosulate accuracy': 0.9933500342071057, 'consecutive overlap rate': 0.9957891762256622, 'overlap rate': 0.9987492121756076}
#
# Current epoch: 65,
# training performance: {'loss': 7.239358128572349e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.011971389142854606, 'abosulate accuracy': 0.9942500345408917, 'consecutive overlap rate': 0.9965991757810115, 'overlap rate': 0.9989958792924881}
#
# Current epoch: 70,
# training performance: {'loss': 5.9328329643903996e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.011975762827296422, 'abosulate accuracy': 0.9944500386714935, 'consecutive overlap rate': 0.9965225115418435, 'overlap rate': 0.999021714925766}
#
# Current epoch: 75,
# training performance: {'loss': 4.916218031212338e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012830751206001878, 'abosulate accuracy': 0.9944000363349914, 'consecutive overlap rate': 0.9965258449316025, 'overlap rate': 0.9989733822643757}
#
# Current epoch: 80,
# training performance: {'loss': 4.1169035466737117e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012912279977990692, 'abosulate accuracy': 0.9947000294923782, 'consecutive overlap rate': 0.9967358410358429, 'overlap rate': 0.9989833690226078}
#
# Current epoch: 85,
# training performance: {'loss': 3.4709985857261924e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.011577676829620031, 'abosulate accuracy': 0.9951500311493874, 'consecutive overlap rate': 0.9970891743898391, 'overlap rate': 0.9990992069244384}
#
# Experiments_Logs/Experiment#2/GRU/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.012297764455615834, 'abosulate accuracy': 0.9951750293374062, 'consecutive overlap rate': 0.9971684966236353, 'overlap rate': 0.999035294726491}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.06476068940246478, 'abosulate accuracy': 0.9079750418663025, 'consecutive overlap rate': 0.9861944258213043, 'overlap rate': 0.994277423620224}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.4576535670988021, 'abosulate accuracy': 0.7006508131181041, 'consecutive overlap rate': 0.8393525131287113, 'overlap rate': 0.9553953986014089}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.9470843374974242, 'abosulate accuracy': 0.6330263455808898, 'consecutive overlap rate': 0.8643213463457007, 'overlap rate': 0.9085381391801333}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.3467104196548463, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.056700000260025266, 'overlap rate': 0.5921033978462219}
# evaluation performance: {'loss': 1.7255514904856681, 'abosulate accuracy': 0.0015500000736210495, 'consecutive overlap rate': 0.10315511394292116, 'overlap rate': 0.4464886043220758}
#
# Current epoch: 10,
# training performance: {'loss': 0.009790341358166189, 'abosulate accuracy': 0.9785000413656235, 'consecutive overlap rate': 0.9900600090622902, 'overlap rate': 0.9996167302131653}
# evaluation performance: {'loss': 0.03730100683169439, 'abosulate accuracy': 0.9752000451087952, 'consecutive overlap rate': 0.9880916759371757, 'overlap rate': 0.9957225680351257}
#
# Current epoch: 15,
# training performance: {'loss': 0.001537850929889828, 'abosulate accuracy': 0.9996000051498413, 'consecutive overlap rate': 0.9998783349990845, 'overlap rate': 0.9999933421611786}
# evaluation performance: {'loss': 0.01351159665355226, 'abosulate accuracy': 0.9929000332951545, 'consecutive overlap rate': 0.9964683413505554, 'overlap rate': 0.9986333787441254}
#
# Experiments_Logs/Experiment#2/GRU/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.010439337958450779, 'abosulate accuracy': 0.9949750330299139, 'consecutive overlap rate': 0.9973379246890545, 'overlap rate': 0.998989625647664}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.318231721408665, 'abosulate accuracy': 0.3250500146299601, 'consecutive overlap rate': 0.43009252902120354, 'overlap rate': 0.4535149658098817}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.5664839815708899, 'abosulate accuracy': 0.4581138510857859, 'consecutive overlap rate': 0.7440835260575818, 'overlap rate': 0.913328666071738}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.383954265694085, 'abosulate accuracy': 0.15428947987904967, 'consecutive overlap rate': 0.5478147629060244, 'overlap rate': 0.5901925448132189}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.3563399255275725, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04515833365730941, 'overlap rate': 0.5823850594460964}
# evaluation performance: {'loss': 1.6678088113665581, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.09873750135302543, 'overlap rate': 0.4652908809483051}
#
# Current epoch: 10,
# training performance: {'loss': 0.9070411704480648, 'abosulate accuracy': 0.02020000081975013, 'consecutive overlap rate': 0.12686166809871793, 'overlap rate': 0.7267050743103027}
# evaluation performance: {'loss': 1.86185202896595, 'abosulate accuracy': 0.07015000362880527, 'consecutive overlap rate': 0.17995333541184663, 'overlap rate': 0.6060792215168476}
#
# Current epoch: 15,
# training performance: {'loss': 0.005406372307334095, 'abosulate accuracy': 0.992200031876564, 'consecutive overlap rate': 0.9962233439087868, 'overlap rate': 0.9998700588941574}
# evaluation performance: {'loss': 0.041845897742314266, 'abosulate accuracy': 0.96510004773736, 'consecutive overlap rate': 0.9823261678218842, 'overlap rate': 0.9951699011027813}
#
# Current epoch: 20,
# training performance: {'loss': 0.0016946272895438596, 'abosulate accuracy': 0.9999000012874604, 'consecutive overlap rate': 0.9999966666102409, 'overlap rate': 0.9999983355402946}
# evaluation performance: {'loss': 0.022407715739973355, 'abosulate accuracy': 0.984400038421154, 'consecutive overlap rate': 0.9924282751977443, 'overlap rate': 0.9975817956030368}
#
# Current epoch: 25,
# training performance: {'loss': 0.0008569380996050313, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.015918535544187762, 'abosulate accuracy': 0.9891500346362591, 'consecutive overlap rate': 0.9947416767477989, 'overlap rate': 0.99841088950634}
#
# Current epoch: 30,
# training performance: {'loss': 0.0005167746341612656, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013907527384435524, 'abosulate accuracy': 0.9903500348329544, 'consecutive overlap rate': 0.9954508423805237, 'overlap rate': 0.9986742228269577}
#
# Current epoch: 35,
# training performance: {'loss': 0.00034575670360936783, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01545965440236614, 'abosulate accuracy': 0.9902000375092029, 'consecutive overlap rate': 0.9952250108122825, 'overlap rate': 0.9986075535416603}
#
# Current epoch: 40,
# training performance: {'loss': 0.00024650798113725616, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014206072231536382, 'abosulate accuracy': 0.9909500412642955, 'consecutive overlap rate': 0.9956498526036739, 'overlap rate': 0.9987441815435887}
#
# Current epoch: 45,
# training performance: {'loss': 0.00018358169436396565, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013411000480118673, 'abosulate accuracy': 0.9920000359416008, 'consecutive overlap rate': 0.9960955902934074, 'overlap rate': 0.9988441221415997}
#
# Current epoch: 50,
# training performance: {'loss': 0.00014098052142799133, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012257702197530307, 'abosulate accuracy': 0.9927000358700753, 'consecutive overlap rate': 0.9964633390307427, 'overlap rate': 0.9989525474607944}
#
# Current epoch: 55,
# training performance: {'loss': 0.00011075588718085782, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013304504518237082, 'abosulate accuracy': 0.9925000376999378, 'consecutive overlap rate': 0.9962771840393543, 'overlap rate': 0.9989010520279408}
#
# Current epoch: 60,
# training performance: {'loss': 8.857904322212562e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.017320038696379925, 'abosulate accuracy': 0.991950037330389, 'consecutive overlap rate': 0.9958966761827469, 'overlap rate': 0.9986517250537872}
#
# Current epoch: 65,
# training performance: {'loss': 7.249436112033436e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012598082723070548, 'abosulate accuracy': 0.992850037664175, 'consecutive overlap rate': 0.9965466767549515, 'overlap rate': 0.9989967226982117}
#
# Current epoch: 70,
# training performance: {'loss': 5.92404560848081e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012674874838376126, 'abosulate accuracy': 0.9930500350892544, 'consecutive overlap rate': 0.9966641761362552, 'overlap rate': 0.9990133889019489}
#
# Current epoch: 75,
# training performance: {'loss': 4.9115684669231995e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01406156194561845, 'abosulate accuracy': 0.9929000347852707, 'consecutive overlap rate': 0.9965850092470646, 'overlap rate': 0.9989392161369324}
#
# Current epoch: 80,
# training performance: {'loss': 4.113437908017659e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013836677183826395, 'abosulate accuracy': 0.9933500371873378, 'consecutive overlap rate': 0.9966816730797291, 'overlap rate': 0.9989758864045143}
#
# Current epoch: 85,
# training performance: {'loss': 3.470049759926042e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012787681462805267, 'abosulate accuracy': 0.9936500377953053, 'consecutive overlap rate': 0.9969458423554898, 'overlap rate': 0.9990633860230446}
#
# Current epoch: 90,
# training performance: {'loss': 2.9473921267708646e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01461361539140853, 'abosulate accuracy': 0.993100031465292, 'consecutive overlap rate': 0.9966225057840348, 'overlap rate': 0.9989558801054954}
#
# Current epoch: 95,
# training performance: {'loss': 2.5184471041939105e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014315496683320817, 'abosulate accuracy': 0.9937000371515751, 'consecutive overlap rate': 0.9968991756439209, 'overlap rate': 0.9989825509488582}
#
# Current epoch: 100,
# training performance: {'loss': 2.162491732633498e-05, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013272362930001691, 'abosulate accuracy': 0.9941500358283519, 'consecutive overlap rate': 0.9970841750502586, 'overlap rate': 0.9990633770823478}
#
# Experiments_Logs/Experiment#2/GRU/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.01147561439988749, 'abosulate accuracy': 0.9943500310182571, 'consecutive overlap rate': 0.9971833419054746, 'overlap rate': 0.9991271264851094}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 9.149462611600757, 'abosulate accuracy': 0.30072501180693506, 'consecutive overlap rate': 0.40020476849749687, 'overlap rate': 0.4277334097772837}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.9901561379432678, 'abosulate accuracy': 0.5079174906976761, 'consecutive overlap rate': 0.7831483244895935, 'overlap rate': 0.9130112094263877}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.82469078976857, 'abosulate accuracy': 0.2241579055093768, 'consecutive overlap rate': 0.5824098371361431, 'overlap rate': 0.6050521286302492}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 0.9257941320538521, 'abosulate accuracy': 0.021500000765081496, 'consecutive overlap rate': 0.1307250026613474, 'overlap rate': 0.7081234097480774}
# evaluation performance: {'loss': 1.32849483191967, 'abosulate accuracy': 0.061450002854689954, 'consecutive overlap rate': 0.21618916895240545, 'overlap rate': 0.6373292230069637}
#
# Current epoch: 10,
# training performance: {'loss': 0.0039406726195011284, 'abosulate accuracy': 0.9974000200629234, 'consecutive overlap rate': 0.9987000018358231, 'overlap rate': 0.9999550327658653}
# evaluation performance: {'loss': 0.021296452687238343, 'abosulate accuracy': 0.9886000394821167, 'consecutive overlap rate': 0.9939641743898392, 'overlap rate': 0.997780891507864}
#
# Current epoch: 15,
# training performance: {'loss': 0.0010102298925630747, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012694458998885239, 'abosulate accuracy': 0.9929000370204448, 'consecutive overlap rate': 0.9964958406984806, 'overlap rate': 0.9987642168998718}
#
# Current epoch: 20,
# training performance: {'loss': 0.0004634315861039795, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.008970857005624566, 'abosulate accuracy': 0.994650038331747, 'consecutive overlap rate': 0.9971266746520996, 'overlap rate': 0.9991875484585762}
#
# Experiments_Logs/Experiment#2/GRU/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/GRU/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.007013773497237708, 'abosulate accuracy': 0.9953500319272279, 'consecutive overlap rate': 0.9973604254424572, 'overlap rate': 0.9993712861090899}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 7.044815680477768, 'abosulate accuracy': 0.3190500155091286, 'consecutive overlap rate': 0.41739733461290596, 'overlap rate': 0.4424001254141331}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.5539127440221848, 'abosulate accuracy': 0.5332116478873837, 'consecutive overlap rate': 0.7909729996035176, 'overlap rate': 0.9203647559688938}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.274612196378018, 'abosulate accuracy': 0.22402632606558895, 'consecutive overlap rate': 0.5953840396710133, 'overlap rate': 0.6358753136898342}
# Experiments_Logs/Experiment#2/GRU/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#2 with GRU seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#2/GRU/hyperparameters.json saved!
