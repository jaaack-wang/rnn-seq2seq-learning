# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 128
embd_dim = 128
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = True
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 2
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#2/RNN created!
# ./Experiments_Logs/Experiment#2/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#2/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#2/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#2 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.922560065984726, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007900000186054967, 'overlap rate': 0.4409733794629574}
# evaluation performance: {'loss': 2.0851765379309652, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007766666873067152, 'overlap rate': 0.4286758776754141}
#
# Current epoch: 10,
# training performance: {'loss': 1.7874411940574646, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012183333587017843, 'overlap rate': 0.4787933796644211}
# evaluation performance: {'loss': 2.054404988884926, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001253333353815833, 'overlap rate': 0.46338338069617746}
#
# Current epoch: 15,
# training performance: {'loss': 1.3941623151302338, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005421666702022776, 'overlap rate': 0.5849767312407493}
# evaluation performance: {'loss': 2.4709809750318525, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006600833404809237, 'overlap rate': 0.4889658823609352}
#
# Current epoch: 20,
# training performance: {'loss': 1.0066208124160767, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.03141833362169564, 'overlap rate': 0.7099184080958366}
# evaluation performance: {'loss': 2.0610121697187425, 'abosulate accuracy': 0.0012000000569969416, 'consecutive overlap rate': 0.04083166718482971, 'overlap rate': 0.580130060762167}
#
# Current epoch: 25,
# training performance: {'loss': 0.9259078353643417, 'abosulate accuracy': 0.0072000002837739885, 'consecutive overlap rate': 0.07230166741646826, 'overlap rate': 0.7546700820326805}
# evaluation performance: {'loss': 1.6380736887454987, 'abosulate accuracy': 0.05730000282637775, 'consecutive overlap rate': 0.16629500221461058, 'overlap rate': 0.6810034021735192}
#
# Current epoch: 30,
# training performance: {'loss': 0.17837114669382573, 'abosulate accuracy': 0.4778000220656395, 'consecutive overlap rate': 0.6397716745734214, 'overlap rate': 0.9811800613999366}
# evaluation performance: {'loss': 0.42340439558029175, 'abosulate accuracy': 0.47930001989007, 'consecutive overlap rate': 0.6444377578794956, 'overlap rate': 0.923129317164421}
#
# Current epoch: 35,
# training performance: {'loss': 0.07053089449182152, 'abosulate accuracy': 0.8411000400781632, 'consecutive overlap rate': 0.9068266808986664, 'overlap rate': 0.9963184013962746}
# evaluation performance: {'loss': 0.15940506272017957, 'abosulate accuracy': 0.8120500415563583, 'consecutive overlap rate': 0.8908033438026906, 'overlap rate': 0.9783150546252728}
#
# Current epoch: 40,
# training performance: {'loss': 0.0368872351013124, 'abosulate accuracy': 0.939600045979023, 'consecutive overlap rate': 0.9662433415651321, 'overlap rate': 0.9988267213106156}
# evaluation performance: {'loss': 0.08936146590858698, 'abosulate accuracy': 0.9072000414133072, 'consecutive overlap rate': 0.9512166656553745, 'overlap rate': 0.9893806293606758}
#
# Current epoch: 45,
# training performance: {'loss': 0.022221730090677738, 'abosulate accuracy': 0.9745000451803207, 'consecutive overlap rate': 0.985133346915245, 'overlap rate': 0.9995333954691887}
# evaluation performance: {'loss': 0.05285785829182714, 'abosulate accuracy': 0.9548500433564187, 'consecutive overlap rate': 0.9770450130105018, 'overlap rate': 0.9941983945667744}
#
# Current epoch: 50,
# training performance: {'loss': 0.015007529105059803, 'abosulate accuracy': 0.9868000373244286, 'consecutive overlap rate': 0.9920783460140228, 'overlap rate': 0.9997734025120735}
# evaluation performance: {'loss': 0.03663643775507808, 'abosulate accuracy': 0.9717000484466553, 'consecutive overlap rate': 0.9858175128698349, 'overlap rate': 0.996249233931303}
#
# Current epoch: 55,
# training performance: {'loss': 0.010745461075566709, 'abosulate accuracy': 0.9932000324130058, 'consecutive overlap rate': 0.9955482855439186, 'overlap rate': 0.9998849987983703}
# evaluation performance: {'loss': 0.030784451856743545, 'abosulate accuracy': 0.9728500448167324, 'consecutive overlap rate': 0.9870416820049286, 'overlap rate': 0.9968092299997806}
#
# Current epoch: 60,
# training performance: {'loss': 0.00801060749217868, 'abosulate accuracy': 0.99640002399683, 'consecutive overlap rate': 0.9973516762256622, 'overlap rate': 0.9999400421977043}
# evaluation performance: {'loss': 0.023537548480089755, 'abosulate accuracy': 0.9815500400960445, 'consecutive overlap rate': 0.9912275120615959, 'overlap rate': 0.9976667270064354}
#
# Current epoch: 65,
# training performance: {'loss': 0.006165377178695053, 'abosulate accuracy': 0.9984000161290169, 'consecutive overlap rate': 0.9988433361053467, 'overlap rate': 0.9999733597040177}
# evaluation performance: {'loss': 0.01948487643385306, 'abosulate accuracy': 0.9849000394344329, 'consecutive overlap rate': 0.9926658436655998, 'overlap rate': 0.9980617292225361}
#
# Current epoch: 70,
# training performance: {'loss': 0.004879254940897226, 'abosulate accuracy': 0.9990000128746033, 'consecutive overlap rate': 0.9992149993777275, 'overlap rate': 0.9999833554029465}
# evaluation performance: {'loss': 0.01632410857710056, 'abosulate accuracy': 0.9873500399291515, 'consecutive overlap rate': 0.9940316759049892, 'overlap rate': 0.9983558908104897}
#
# Current epoch: 75,
# training performance: {'loss': 0.003913809824734926, 'abosulate accuracy': 0.9996000051498413, 'consecutive overlap rate': 0.9996766656637192, 'overlap rate': 0.9999933421611786}
# evaluation performance: {'loss': 0.016858741617761554, 'abosulate accuracy': 0.9870000354945659, 'consecutive overlap rate': 0.9938991770148278, 'overlap rate': 0.9982808887958526}
#
# Current epoch: 80,
# training performance: {'loss': 0.003196481749182567, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.9997999995946885, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.013796471356181427, 'abosulate accuracy': 0.9900500386953354, 'consecutive overlap rate': 0.9953766785562038, 'overlap rate': 0.9986058883368969}
#
# Current epoch: 85,
# training performance: {'loss': 0.00263945636106655, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014215734443860128, 'abosulate accuracy': 0.9900500372052192, 'consecutive overlap rate': 0.9952641777694226, 'overlap rate': 0.9985742203891277}
#
# Current epoch: 90,
# training performance: {'loss': 0.002207357052247971, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012067962682340293, 'abosulate accuracy': 0.9915500394999981, 'consecutive overlap rate': 0.9961266793310642, 'overlap rate': 0.9987417213618756}
#
# Current epoch: 95,
# training performance: {'loss': 0.0018611055158544332, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012628219957696274, 'abosulate accuracy': 0.9916500367224217, 'consecutive overlap rate': 0.9960825107991695, 'overlap rate': 0.9987092159688473}
#
# Current epoch: 100,
# training performance: {'loss': 0.0015752592822536825, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.012036754658038263, 'abosulate accuracy': 0.9916000366210938, 'consecutive overlap rate': 0.9961721993982792, 'overlap rate': 0.9988033175468445}
#
# Experiments_Logs/Experiment#2/RNN/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.013051858775725123, 'abosulate accuracy': 0.9918250363320112, 'consecutive overlap rate': 0.9962809894233942, 'overlap rate': 0.9986956439912319}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 1.6535149920731782, 'abosulate accuracy': 0.6423000309616327, 'consecutive overlap rate': 0.7385946586728096, 'overlap rate': 0.8269378513097763}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.4775230738424487, 'abosulate accuracy': 0.4464396265245253, 'consecutive overlap rate': 0.5508446381938072, 'overlap rate': 0.7035909383527694}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 2.7689730770101675, 'abosulate accuracy': 0.36497370211260494, 'consecutive overlap rate': 0.4746975593366905, 'overlap rate': 0.6756608419512448}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9273430079221725, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008133333489240613, 'overlap rate': 0.4397467143833637}
# evaluation performance: {'loss': 2.3484974652528763, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000793488720228197, 'overlap rate': 0.4396420087665319}
#
# Current epoch: 10,
# training performance: {'loss': 1.8062512874603271, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012833333574235439, 'overlap rate': 0.4738550499081612}
# evaluation performance: {'loss': 2.1098578602075575, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013491666897607502, 'overlap rate': 0.4582542147487402}
#
# Current epoch: 15,
# training performance: {'loss': 1.435325738787651, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006505000102333724, 'overlap rate': 0.575621734559536}
# evaluation performance: {'loss': 1.8335913389921188, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006735833419952542, 'overlap rate': 0.5166850533336401}
#
# Current epoch: 20,
# training performance: {'loss': 0.9194559291005134, 'abosulate accuracy': 0.003200000140350312, 'consecutive overlap rate': 0.04960333374328911, 'overlap rate': 0.7440700814127922}
# evaluation performance: {'loss': 2.0429678454995157, 'abosulate accuracy': 0.012250000541098417, 'consecutive overlap rate': 0.07935166759416461, 'overlap rate': 0.5796433933079242}
#
# Current epoch: 25,
# training performance: {'loss': 0.7259418293833733, 'abosulate accuracy': 0.04690000199479982, 'consecutive overlap rate': 0.1690983371809125, 'overlap rate': 0.8175267398357391}
# evaluation performance: {'loss': 1.1923797473311424, 'abosulate accuracy': 0.10325000402517617, 'consecutive overlap rate': 0.2505925031378865, 'overlap rate': 0.718846733123064}
#
# Current epoch: 30,
# training performance: {'loss': 0.12148529049009085, 'abosulate accuracy': 0.6584000289440155, 'consecutive overlap rate': 0.7919020965695381, 'overlap rate': 0.990386389195919}
# evaluation performance: {'loss': 0.23214844297617673, 'abosulate accuracy': 0.7113000333309174, 'consecutive overlap rate': 0.8272732846438885, 'overlap rate': 0.962378891557455}
#
# Current epoch: 35,
# training performance: {'loss': 0.050903312396258116, 'abosulate accuracy': 0.8951000437140465, 'consecutive overlap rate': 0.9422783434391022, 'overlap rate': 0.9978484094142914}
# evaluation performance: {'loss': 0.10986800990067422, 'abosulate accuracy': 0.8895000457763672, 'consecutive overlap rate': 0.9383058436214924, 'overlap rate': 0.9855833888053894}
#
# Current epoch: 40,
# training performance: {'loss': 0.02718998878262937, 'abosulate accuracy': 0.9606000483036041, 'consecutive overlap rate': 0.9778583407402038, 'overlap rate': 0.9992817312479019}
# evaluation performance: {'loss': 0.07861775872297586, 'abosulate accuracy': 0.9246000438928604, 'consecutive overlap rate': 0.9601200096309185, 'overlap rate': 0.990305059403181}
#
# Current epoch: 45,
# training performance: {'loss': 0.0168223247397691, 'abosulate accuracy': 0.9860000386834145, 'consecutive overlap rate': 0.9921183466911316, 'overlap rate': 0.9997534081339836}
# evaluation performance: {'loss': 0.04933420664165169, 'abosulate accuracy': 0.9618000470101833, 'consecutive overlap rate': 0.9803272739052773, 'overlap rate': 0.9942106813192367}
#
# Current epoch: 50,
# training performance: {'loss': 0.01149541160557419, 'abosulate accuracy': 0.9926000326871872, 'consecutive overlap rate': 0.9954150095582008, 'overlap rate': 0.9998750582337379}
# evaluation performance: {'loss': 0.05165308096911758, 'abosulate accuracy': 0.963300047069788, 'consecutive overlap rate': 0.9810537375509739, 'overlap rate': 0.9940997362136841}
#
# Current epoch: 55,
# training performance: {'loss': 0.008195171330589801, 'abosulate accuracy': 0.996900025010109, 'consecutive overlap rate': 0.9979983374476433, 'overlap rate': 0.9999467089772225}
# evaluation performance: {'loss': 0.04015159601112828, 'abosulate accuracy': 0.9737000443041325, 'consecutive overlap rate': 0.9862625107169152, 'overlap rate': 0.9954358950257302}
#
# Current epoch: 60,
# training performance: {'loss': 0.0062041380675509575, 'abosulate accuracy': 0.997900016605854, 'consecutive overlap rate': 0.9986783370375634, 'overlap rate': 0.9999650284647942}
# evaluation performance: {'loss': 0.032139129273127766, 'abosulate accuracy': 0.9802500426769256, 'consecutive overlap rate': 0.9899741753935813, 'overlap rate': 0.9960475556552411}
#
# Current epoch: 65,
# training performance: {'loss': 0.004716187936719507, 'abosulate accuracy': 0.9996000051498413, 'consecutive overlap rate': 0.9997266680002213, 'overlap rate': 0.9999933421611786}
# evaluation performance: {'loss': 0.029628938995301723, 'abosulate accuracy': 0.9820000402629375, 'consecutive overlap rate': 0.9903075098991394, 'overlap rate': 0.9967050552368164}
#
# Current epoch: 70,
# training performance: {'loss': 0.003717667836463079, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.999914999306202, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.0256720241275616, 'abosulate accuracy': 0.9839000418782234, 'consecutive overlap rate': 0.9915508449077606, 'overlap rate': 0.9970008879899979}
#
# Current epoch: 75,
# training performance: {'loss': 0.0029550380830187352, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.027382195444079115, 'abosulate accuracy': 0.9835500366985798, 'consecutive overlap rate': 0.9912466794252396, 'overlap rate': 0.9969642221927643}
#
# Current epoch: 80,
# training performance: {'loss': 0.0023949075664859267, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.02526974335487466, 'abosulate accuracy': 0.9856500387191772, 'consecutive overlap rate': 0.9926841787993907, 'overlap rate': 0.9971108943223953}
#
# Current epoch: 85,
# training performance: {'loss': 0.001961208169814199, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.022806034539826214, 'abosulate accuracy': 0.9884500361979007, 'consecutive overlap rate': 0.9940217472612858, 'overlap rate': 0.9973934821784496}
#
# Current epoch: 90,
# training performance: {'loss': 0.0016151678224559872, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.023338259584852493, 'abosulate accuracy': 0.9884500347077847, 'consecutive overlap rate': 0.9939008429646492, 'overlap rate': 0.9973867207765579}
#
# Current epoch: 95,
# training performance: {'loss': 0.001343759405426681, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.021761183577473274, 'abosulate accuracy': 0.9886000379920006, 'consecutive overlap rate': 0.9940175093710423, 'overlap rate': 0.9976525560021401}
#
# Current epoch: 100,
# training performance: {'loss': 0.0011238329723710194, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.02282248501869617, 'abosulate accuracy': 0.9897500388324261, 'consecutive overlap rate': 0.9946375161409378, 'overlap rate': 0.9976050555706024}
#
# Experiments_Logs/Experiment#2/RNN/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.02235805722812074, 'abosulate accuracy': 0.9907500382512808, 'consecutive overlap rate': 0.9947716780006886, 'overlap rate': 0.9977354727685451}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.5777805030345915, 'abosulate accuracy': 0.3603250185959041, 'consecutive overlap rate': 0.41716753426007924, 'overlap rate': 0.5615385062992573}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.687355698308637, 'abosulate accuracy': 0.42972445487976074, 'consecutive overlap rate': 0.47217407476517465, 'overlap rate': 0.6046943710696313}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.2255039889561505, 'abosulate accuracy': 0.1626842174384939, 'consecutive overlap rate': 0.282902996717511, 'overlap rate': 0.39905311598589543}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9198316961526871, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007450000179233029, 'overlap rate': 0.44049837812781334}
# evaluation performance: {'loss': 2.0824334800243376, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007716666797932703, 'overlap rate': 0.4294192124158144}
#
# Current epoch: 10,
# training performance: {'loss': 1.7714868783950806, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012183333536086138, 'overlap rate': 0.48424338921904564}
# evaluation performance: {'loss': 2.136846110224724, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013358333591895644, 'overlap rate': 0.46727504581213}
#
# Current epoch: 15,
# training performance: {'loss': 1.2898549854755401, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006750000087777153, 'overlap rate': 0.616468395292759}
# evaluation performance: {'loss': 2.0913054272532463, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0076150000793859364, 'overlap rate': 0.5099333841353655}
#
# Current epoch: 20,
# training performance: {'loss': 1.9388981372117997, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01742666686186567, 'overlap rate': 0.5482150577008724}
# evaluation performance: {'loss': 2.394820433855057, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.013939166814088822, 'overlap rate': 0.42801504358649256}
#
# Current epoch: 25,
# training performance: {'loss': 1.4417299345135688, 'abosulate accuracy': 0.011000000522471964, 'consecutive overlap rate': 0.07893833369016648, 'overlap rate': 0.6708217270672321}
# evaluation performance: {'loss': 2.72111881673336, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05115166716277599, 'overlap rate': 0.43154504261910914}
#
# Current epoch: 30,
# training performance: {'loss': 0.30933898240327834, 'abosulate accuracy': 0.21680000908672808, 'consecutive overlap rate': 0.3845966711640358, 'overlap rate': 0.9542834103107453}
# evaluation performance: {'loss': 0.5455797977745533, 'abosulate accuracy': 0.3118000149726868, 'consecutive overlap rate': 0.4892883379012346, 'overlap rate': 0.8871059067547321}
#
# Current epoch: 35,
# training performance: {'loss': 0.09318637568503618, 'abosulate accuracy': 0.7881000339984894, 'consecutive overlap rate': 0.8782600075006485, 'overlap rate': 0.9948317259550095}
# evaluation performance: {'loss': 0.15947095574811102, 'abosulate accuracy': 0.8255500428378582, 'consecutive overlap rate': 0.9012016743421555, 'overlap rate': 0.9780483916401863}
#
# Current epoch: 40,
# training performance: {'loss': 0.04242029152810574, 'abosulate accuracy': 0.9329000517725945, 'consecutive overlap rate': 0.962635013461113, 'overlap rate': 0.9986584067344666}
# evaluation performance: {'loss': 0.08919905414804816, 'abosulate accuracy': 0.9102000430226326, 'consecutive overlap rate': 0.9526075102388859, 'overlap rate': 0.9896700575947761}
#
# Current epoch: 45,
# training performance: {'loss': 0.02398485178127885, 'abosulate accuracy': 0.9730000451207161, 'consecutive overlap rate': 0.9840316787362099, 'overlap rate': 0.999508398771286}
# evaluation performance: {'loss': 0.049435419915243986, 'abosulate accuracy': 0.9546500451862812, 'consecutive overlap rate': 0.9768016800284386, 'overlap rate': 0.9948008909821511}
#
# Current epoch: 50,
# training performance: {'loss': 0.015477559436112643, 'abosulate accuracy': 0.9843000397086143, 'consecutive overlap rate': 0.989806680381298, 'overlap rate': 0.9997334107756615}
# evaluation performance: {'loss': 0.03453625978436321, 'abosulate accuracy': 0.9688500463962555, 'consecutive overlap rate': 0.9835250101983547, 'overlap rate': 0.9965033859014512}
#
# Current epoch: 55,
# training performance: {'loss': 0.01090900539420545, 'abosulate accuracy': 0.9898000359535217, 'consecutive overlap rate': 0.9923383429646492, 'overlap rate': 0.9998267352581024}
# evaluation performance: {'loss': 0.03372348040575161, 'abosulate accuracy': 0.9706000477075577, 'consecutive overlap rate': 0.9842808470129967, 'overlap rate': 0.9964617237448692}
#
# Current epoch: 60,
# training performance: {'loss': 0.007874287222512067, 'abosulate accuracy': 0.9938000291585922, 'consecutive overlap rate': 0.9949066653847695, 'overlap rate': 0.9998966559767724}
# evaluation performance: {'loss': 0.019062569638481363, 'abosulate accuracy': 0.983900037407875, 'consecutive overlap rate': 0.9908316761255265, 'overlap rate': 0.9981175638735295}
#
# Current epoch: 65,
# training performance: {'loss': 0.006001453765202313, 'abosulate accuracy': 0.9961000323295593, 'consecutive overlap rate': 0.9966299995779991, 'overlap rate': 0.9999350532889366}
# evaluation performance: {'loss': 0.016464023344451562, 'abosulate accuracy': 0.9869000367820263, 'consecutive overlap rate': 0.9925683408975601, 'overlap rate': 0.9983108967542649}
#
# Current epoch: 70,
# training performance: {'loss': 0.004689256811980158, 'abosulate accuracy': 0.9971000239253044, 'consecutive overlap rate': 0.9972949981689453, 'overlap rate': 0.9999517053365707}
# evaluation performance: {'loss': 0.014275824610376731, 'abosulate accuracy': 0.9884000398218632, 'consecutive overlap rate': 0.9934708401560783, 'overlap rate': 0.9985217221081257}
#
# Current epoch: 75,
# training performance: {'loss': 0.0037294057256076485, 'abosulate accuracy': 0.9980000168085098, 'consecutive overlap rate': 0.9980083301663398, 'overlap rate': 0.9999666944146156}
# evaluation performance: {'loss': 0.01198092101549264, 'abosulate accuracy': 0.9903500363230705, 'consecutive overlap rate': 0.9946266748011112, 'overlap rate': 0.998812559247017}
#
# Current epoch: 80,
# training performance: {'loss': 0.00303189845290035, 'abosulate accuracy': 0.9985000178217888, 'consecutive overlap rate': 0.9985083311796188, 'overlap rate': 0.9999750301241874}
# evaluation performance: {'loss': 0.012634751570294612, 'abosulate accuracy': 0.9905500367283822, 'consecutive overlap rate': 0.9946583367884159, 'overlap rate': 0.9986892208456993}
#
# Current epoch: 85,
# training performance: {'loss': 0.0024920293304603546, 'abosulate accuracy': 0.9989000111818314, 'consecutive overlap rate': 0.9988999977707863, 'overlap rate': 0.9999816849827766}
# evaluation performance: {'loss': 0.01237922498548869, 'abosulate accuracy': 0.9901500403881073, 'consecutive overlap rate': 0.9949116751551628, 'overlap rate': 0.9987325571477413}
#
# Current epoch: 90,
# training performance: {'loss': 0.0020765690511325373, 'abosulate accuracy': 0.9990000113844871, 'consecutive overlap rate': 0.9989999979734421, 'overlap rate': 0.9999833524227142}
# evaluation performance: {'loss': 0.010151945499819704, 'abosulate accuracy': 0.9926000349223614, 'consecutive overlap rate': 0.9959350101649761, 'overlap rate': 0.9989600509405137}
#
# Current epoch: 95,
# training performance: {'loss': 0.0017412854300346225, 'abosulate accuracy': 0.9993000090122223, 'consecutive overlap rate': 0.9992999985814095, 'overlap rate': 0.9999883487820626}
# evaluation performance: {'loss': 0.010538025216374081, 'abosulate accuracy': 0.992000038176775, 'consecutive overlap rate': 0.9955783404409886, 'overlap rate': 0.998910891264677}
#
# Current epoch: 100,
# training performance: {'loss': 0.001473650397383608, 'abosulate accuracy': 0.9992000088095665, 'consecutive overlap rate': 0.9991999983787536, 'overlap rate': 0.9999866232275962}
# evaluation performance: {'loss': 0.009126989328069612, 'abosulate accuracy': 0.9934500366449356, 'consecutive overlap rate': 0.9963208436965942, 'overlap rate': 0.9990633875131607}
#
# Experiments_Logs/Experiment#2/RNN/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.00868133166950429, 'abosulate accuracy': 0.9934500377625227, 'consecutive overlap rate': 0.9962916757911444, 'overlap rate': 0.9991333853453398}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.0843785990029575, 'abosulate accuracy': 0.5028500220738351, 'consecutive overlap rate': 0.5589548576623201, 'overlap rate': 0.679732932895422}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.1524398865238314, 'abosulate accuracy': 0.4624529113692622, 'consecutive overlap rate': 0.5633153734668609, 'overlap rate': 0.6732706589083518}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.6072842102301745, 'abosulate accuracy': 0.22321053898256077, 'consecutive overlap rate': 0.32371925442528565, 'overlap rate': 0.4295207083617386}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9097280949354172, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019916666875360533, 'overlap rate': 0.44527004286646843}
# evaluation performance: {'loss': 2.1791144520044328, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002175833364890423, 'overlap rate': 0.42749587520956994}
#
# Current epoch: 10,
# training performance: {'loss': 1.8158955603837967, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005650000076275319, 'overlap rate': 0.47491505071520806}
# evaluation performance: {'loss': 2.0026252448558806, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005895833391696215, 'overlap rate': 0.4615925431251526}
#
# Current epoch: 15,
# training performance: {'loss': 1.5129908204078675, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011206666741054505, 'overlap rate': 0.5546400591731071}
# evaluation performance: {'loss': 2.0003072530031205, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01128333342494443, 'overlap rate': 0.435940046235919}
#
# Current epoch: 20,
# training performance: {'loss': 1.1069035470485686, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.02912000040523708, 'overlap rate': 0.677111740410328}
# evaluation performance: {'loss': 2.090683551132679, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03486916706897318, 'overlap rate': 0.5485967129468918}
#
# Current epoch: 25,
# training performance: {'loss': 1.4554600685834884, 'abosulate accuracy': 0.00900000041583553, 'consecutive overlap rate': 0.0631433344911784, 'overlap rate': 0.6681317254900933}
# evaluation performance: {'loss': 2.3475258618593218, 'abosulate accuracy': 0.0012000000569969416, 'consecutive overlap rate': 0.0430883337277919, 'overlap rate': 0.5338083863258362}
#
# Current epoch: 30,
# training performance: {'loss': 0.24056121930480004, 'abosulate accuracy': 0.29210001416504383, 'consecutive overlap rate': 0.44876333698630333, 'overlap rate': 0.9630617409944534}
# evaluation performance: {'loss': 0.5288733221590519, 'abosulate accuracy': 0.3409500136971474, 'consecutive overlap rate': 0.5011491730809212, 'overlap rate': 0.8857267335057258}
#
# Current epoch: 35,
# training performance: {'loss': 0.0928814074024558, 'abosulate accuracy': 0.7157000288367271, 'consecutive overlap rate': 0.8318816721439362, 'overlap rate': 0.9919433861970901}
# evaluation performance: {'loss': 0.18663518484681846, 'abosulate accuracy': 0.734250033646822, 'consecutive overlap rate': 0.847012510150671, 'overlap rate': 0.9716858960688114}
#
# Current epoch: 40,
# training performance: {'loss': 0.04349520290270448, 'abosulate accuracy': 0.8930000469088555, 'consecutive overlap rate': 0.9503416761755943, 'overlap rate': 0.9976734012365341}
# evaluation performance: {'loss': 0.09568028589710594, 'abosulate accuracy': 0.8876500435173511, 'consecutive overlap rate': 0.9451600149273872, 'overlap rate': 0.9875283896923065}
#
# Current epoch: 45,
# training performance: {'loss': 0.02351281209848821, 'abosulate accuracy': 0.9591000452637672, 'consecutive overlap rate': 0.9823983430862426, 'overlap rate': 0.9992283940315246}
# evaluation performance: {'loss': 0.05871615840587765, 'abosulate accuracy': 0.9307500444352627, 'consecutive overlap rate': 0.9697633445262909, 'overlap rate': 0.9931683875620365}
#
# Current epoch: 50,
# training performance: {'loss': 0.014334871317259967, 'abosulate accuracy': 0.9833000391721726, 'consecutive overlap rate': 0.991873337328434, 'overlap rate': 0.9996950641274452}
# evaluation performance: {'loss': 0.04157295713666827, 'abosulate accuracy': 0.9639000482857227, 'consecutive overlap rate': 0.983134176582098, 'overlap rate': 0.995117561519146}
#
# Current epoch: 55,
# training performance: {'loss': 0.009322171285748481, 'abosulate accuracy': 0.9925000339746475, 'consecutive overlap rate': 0.996126675605774, 'overlap rate': 0.9998700588941574}
# evaluation performance: {'loss': 0.027757358318194748, 'abosulate accuracy': 0.9769500441849231, 'consecutive overlap rate': 0.9896100103855133, 'overlap rate': 0.9970800563693046}
#
# Current epoch: 60,
# training performance: {'loss': 0.006434770382475108, 'abosulate accuracy': 0.9979000210762023, 'consecutive overlap rate': 0.9990100026130676, 'overlap rate': 0.9999650359153748}
# evaluation performance: {'loss': 0.02705619827029295, 'abosulate accuracy': 0.978800044208765, 'consecutive overlap rate': 0.9896183408796787, 'overlap rate': 0.9971850618720055}
#
# Current epoch: 65,
# training performance: {'loss': 0.004555404663551599, 'abosulate accuracy': 0.9993000090122223, 'consecutive overlap rate': 0.9995166674256325, 'overlap rate': 0.9999883487820626}
# evaluation performance: {'loss': 0.017413477401714773, 'abosulate accuracy': 0.9862500384449959, 'consecutive overlap rate': 0.9939150109887123, 'overlap rate': 0.9982533894479275}
#
# Current epoch: 70,
# training performance: {'loss': 0.003383836580906063, 'abosulate accuracy': 0.9996000051498413, 'consecutive overlap rate': 0.9998283341526986, 'overlap rate': 0.9999933421611786}
# evaluation performance: {'loss': 0.017645631180494094, 'abosulate accuracy': 0.9891000367701054, 'consecutive overlap rate': 0.9953916743397713, 'overlap rate': 0.9981050536036491}
#
# Current epoch: 75,
# training performance: {'loss': 0.0025716189993545413, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.017063879061606713, 'abosulate accuracy': 0.9909500375390052, 'consecutive overlap rate': 0.9957908444106579, 'overlap rate': 0.9982317224144935}
#
# Current epoch: 80,
# training performance: {'loss': 0.0020050691702635957, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014429759574704803, 'abosulate accuracy': 0.9921000353991986, 'consecutive overlap rate': 0.9963383413851261, 'overlap rate': 0.998514212667942}
#
# Current epoch: 85,
# training performance: {'loss': 0.001589375315234065, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014641153707634658, 'abosulate accuracy': 0.9929000340402127, 'consecutive overlap rate': 0.9963758401572704, 'overlap rate': 0.9985125474631786}
#
# Current epoch: 90,
# training performance: {'loss': 0.001281401710002683, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01409066698543029, 'abosulate accuracy': 0.9936500392854214, 'consecutive overlap rate': 0.9969264350831508, 'overlap rate': 0.9985958121716976}
#
# Current epoch: 95,
# training performance: {'loss': 0.001045142742805183, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014416136725049, 'abosulate accuracy': 0.994100034236908, 'consecutive overlap rate': 0.9970216743648053, 'overlap rate': 0.9985867097973824}
#
# Current epoch: 100,
# training performance: {'loss': 0.0008614339094492607, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013039329223829554, 'abosulate accuracy': 0.9945000313222409, 'consecutive overlap rate': 0.9972466751933098, 'overlap rate': 0.9987233728170395}
#
# Experiments_Logs/Experiment#2/RNN/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.011280636830997537, 'abosulate accuracy': 0.9947250340133905, 'consecutive overlap rate': 0.9975370913743973, 'overlap rate': 0.9988804597407579}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.846371728740633, 'abosulate accuracy': 0.2246500109846238, 'consecutive overlap rate': 0.36895828740671277, 'overlap rate': 0.46459656301885843}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.850295205270091, 'abosulate accuracy': 0.3613692908517776, 'consecutive overlap rate': 0.37534571539971134, 'overlap rate': 0.5594217956066132}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.589244841745026, 'abosulate accuracy': 0.2510000122220893, 'consecutive overlap rate': 0.39440082082230793, 'overlap rate': 0.47105073693551514}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.905780729651451, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0027010452293325217, 'overlap rate': 0.4469632975757122}
# evaluation performance: {'loss': 2.4681071072816847, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029050000332063062, 'overlap rate': 0.43821587450802324}
#
# Current epoch: 10,
# training performance: {'loss': 1.7914934247732162, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007073333440348506, 'overlap rate': 0.4809417173266411}
# evaluation performance: {'loss': 2.1388196155428885, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007637500087730587, 'overlap rate': 0.4684075482189655}
#
# Current epoch: 15,
# training performance: {'loss': 1.5463056445121766, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01646666689775884, 'overlap rate': 0.5435950607061386}
# evaluation performance: {'loss': 1.9034560799598694, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01748500023968518, 'overlap rate': 0.5180792164057493}
#
# Current epoch: 20,
# training performance: {'loss': 1.252315840125084, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.037693333765491846, 'overlap rate': 0.6301433950662613}
# evaluation performance: {'loss': 2.1171298012137414, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.042139943782240154, 'overlap rate': 0.5047286968678236}
#
# Current epoch: 25,
# training performance: {'loss': 0.723871560394764, 'abosulate accuracy': 0.019100000779144467, 'consecutive overlap rate': 0.11093333400785924, 'overlap rate': 0.7943517521023751}
# evaluation performance: {'loss': 1.3236497178673745, 'abosulate accuracy': 0.02215000088326633, 'consecutive overlap rate': 0.12958416854962707, 'overlap rate': 0.6540417365729809}
#
# Current epoch: 30,
# training performance: {'loss': 0.5156886488199234, 'abosulate accuracy': 0.11080000472720712, 'consecutive overlap rate': 0.26712000388652085, 'overlap rate': 0.8758734211325645}
# evaluation performance: {'loss': 1.4669877484440803, 'abosulate accuracy': 0.08965000431053341, 'consecutive overlap rate': 0.24714416954666377, 'overlap rate': 0.7057717323303223}
#
# Current epoch: 35,
# training performance: {'loss': 0.11673596259206534, 'abosulate accuracy': 0.5428000263869762, 'consecutive overlap rate': 0.6940716743469239, 'overlap rate': 0.983718390762806}
# evaluation performance: {'loss': 0.5023488633334636, 'abosulate accuracy': 0.5595500286668539, 'consecutive overlap rate': 0.7132333405315876, 'overlap rate': 0.912057564407587}
#
# Current epoch: 40,
# training performance: {'loss': 0.040664064791053535, 'abosulate accuracy': 0.8530000492930412, 'consecutive overlap rate': 0.9127650126814842, 'overlap rate': 0.9964317411184311}
# evaluation performance: {'loss': 0.20404442884027957, 'abosulate accuracy': 0.8307000406086444, 'consecutive overlap rate': 0.900821677595377, 'overlap rate': 0.9687200650572777}
#
# Current epoch: 45,
# training performance: {'loss': 0.5296291075646877, 'abosulate accuracy': 0.09190000493545085, 'consecutive overlap rate': 0.2848930241540074, 'overlap rate': 0.8757212460041046}
# evaluation performance: {'loss': 1.1683439910411835, 'abosulate accuracy': 0.23905001077800989, 'consecutive overlap rate': 0.44284750558435915, 'overlap rate': 0.7748733930289745}
#
# Current epoch: 50,
# training performance: {'loss': 0.08156013656407594, 'abosulate accuracy': 0.6666000306606292, 'consecutive overlap rate': 0.7947050094604492, 'overlap rate': 0.9865667328238488}
# evaluation performance: {'loss': 0.33545615449547767, 'abosulate accuracy': 0.7774500355124474, 'consecutive overlap rate': 0.8604416765272618, 'overlap rate': 0.9499425627291203}
#
# Current epoch: 55,
# training performance: {'loss': 0.05041985400021076, 'abosulate accuracy': 0.7273000337183475, 'consecutive overlap rate': 0.8301866754889489, 'overlap rate': 0.9913967236876488}
# evaluation performance: {'loss': 0.26519902916625143, 'abosulate accuracy': 0.8537000454962254, 'consecutive overlap rate': 0.9106066778302193, 'overlap rate': 0.964582547545433}
#
# Current epoch: 60,
# training performance: {'loss': 0.012268381891772151, 'abosulate accuracy': 0.9491000473499298, 'consecutive overlap rate': 0.9698901489377022, 'overlap rate': 0.9989914238452912}
# evaluation performance: {'loss': 0.11408165181055666, 'abosulate accuracy': 0.9395500458776951, 'consecutive overlap rate': 0.9641883425414562, 'overlap rate': 0.9862008906900883}
#
# Current epoch: 65,
# training performance: {'loss': 0.00813185985898599, 'abosulate accuracy': 0.9705000460147858, 'consecutive overlap rate': 0.9826050117611885, 'overlap rate': 0.9994483947753906}
# evaluation performance: {'loss': 0.0888834926765412, 'abosulate accuracy': 0.9559500478208065, 'consecutive overlap rate': 0.9739027366042137, 'overlap rate': 0.9897627875208854}
#
# Current epoch: 70,
# training performance: {'loss': 0.0058537101722322404, 'abosulate accuracy': 0.981000043451786, 'consecutive overlap rate': 0.9887483462691307, 'overlap rate': 0.9996583938598633}
# evaluation performance: {'loss': 0.07409142921096645, 'abosulate accuracy': 0.9641500465571881, 'consecutive overlap rate': 0.9793100126087666, 'overlap rate': 0.9916950538754463}
#
# Current epoch: 75,
# training performance: {'loss': 0.004452549264533446, 'abosulate accuracy': 0.98880003541708, 'consecutive overlap rate': 0.9933266788721085, 'overlap rate': 0.9998000666499138}
# evaluation performance: {'loss': 0.05959812978398986, 'abosulate accuracy': 0.9711000464856625, 'consecutive overlap rate': 0.9833916760981083, 'overlap rate': 0.9934392221271992}
#
# Current epoch: 80,
# training performance: {'loss': 0.0034999585303012283, 'abosulate accuracy': 0.9938000351190567, 'consecutive overlap rate': 0.9963116750121117, 'overlap rate': 0.9998933956027031}
# evaluation performance: {'loss': 0.05472783122677356, 'abosulate accuracy': 0.9734500475227833, 'consecutive overlap rate': 0.9849633447825908, 'overlap rate': 0.9940650522708893}
#
# Current epoch: 85,
# training performance: {'loss': 0.0028119826165493578, 'abosulate accuracy': 0.9958000287413598, 'consecutive overlap rate': 0.9974183395504952, 'overlap rate': 0.9999300464987755}
# evaluation performance: {'loss': 0.04946624477161095, 'abosulate accuracy': 0.9768000446259976, 'consecutive overlap rate': 0.9869700156152248, 'overlap rate': 0.9947558984160423}
#
# Current epoch: 90,
# training performance: {'loss': 0.0022971129568759353, 'abosulate accuracy': 0.9975000232458114, 'consecutive overlap rate': 0.9984683379530906, 'overlap rate': 0.9999583706259727}
# evaluation performance: {'loss': 0.0467331009946065, 'abosulate accuracy': 0.9786500409245491, 'consecutive overlap rate': 0.9882075086236, 'overlap rate': 0.9951283894479275}
#
# Current epoch: 95,
# training performance: {'loss': 0.0019042868603719398, 'abosulate accuracy': 0.9985000163316726, 'consecutive overlap rate': 0.999033336341381, 'overlap rate': 0.9999750271439553}
# evaluation performance: {'loss': 0.044112464538193306, 'abosulate accuracy': 0.9803000405430794, 'consecutive overlap rate': 0.9891025133430957, 'overlap rate': 0.9955242224037647}
#
# Current epoch: 100,
# training performance: {'loss': 0.0015952652145642787, 'abosulate accuracy': 0.9992000088095665, 'consecutive overlap rate': 0.9994700014591217, 'overlap rate': 0.999986681342125}
# evaluation performance: {'loss': 0.04104350601846818, 'abosulate accuracy': 0.9819500423967839, 'consecutive overlap rate': 0.9900547146797181, 'overlap rate': 0.9959223702549934}
#
# Experiments_Logs/Experiment#2/RNN/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.042033710992109265, 'abosulate accuracy': 0.9807500399649143, 'consecutive overlap rate': 0.9896945960819721, 'overlap rate': 0.9957525543868542}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.08958518940489739, 'abosulate accuracy': 0.8974250495433808, 'consecutive overlap rate': 0.9836742058396339, 'overlap rate': 0.9911587342619896}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.5580624670751633, 'abosulate accuracy': 0.8027385877024743, 'consecutive overlap rate': 0.9040497279936267, 'overlap rate': 0.9403840195748114}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.7155555204341286, 'abosulate accuracy': 0.7379474039924773, 'consecutive overlap rate': 0.8830717441282774, 'overlap rate': 0.9188213442501268}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9058725893497468, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002113333356101066, 'overlap rate': 0.4474167160689831}
# evaluation performance: {'loss': 2.178007534146309, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002450000033422839, 'overlap rate': 0.4391642142087221}
#
# Current epoch: 10,
# training performance: {'loss': 1.783968958258629, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007090000051539392, 'overlap rate': 0.483963380753994}
# evaluation performance: {'loss': 1.9384889870882034, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007601468986831605, 'overlap rate': 0.4654711302369833}
#
# Current epoch: 15,
# training performance: {'loss': 1.4770570605993272, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014828333421610296, 'overlap rate': 0.563521720468998}
# evaluation performance: {'loss': 1.8115852326154709, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016830000188201667, 'overlap rate': 0.5145550522953272}
#
# Current epoch: 20,
# training performance: {'loss': 0.9814861789345741, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.04170166691765189, 'overlap rate': 0.711106751859188}
# evaluation performance: {'loss': 1.6630659237504006, 'abosulate accuracy': 0.0013000000617466867, 'consecutive overlap rate': 0.05130751463584602, 'overlap rate': 0.5869912780821324}
#
# Current epoch: 25,
# training performance: {'loss': 0.9077847629785538, 'abosulate accuracy': 0.0024000000790692865, 'consecutive overlap rate': 0.0769416680559516, 'overlap rate': 0.7408617392182351}
# evaluation performance: {'loss': 2.0110252782702447, 'abosulate accuracy': 0.009500000352272765, 'consecutive overlap rate': 0.10414166776463389, 'overlap rate': 0.6004384011030197}
#
# Current epoch: 30,
# training performance: {'loss': 0.2703868940472603, 'abosulate accuracy': 0.2922000122256577, 'consecutive overlap rate': 0.4801133394241333, 'overlap rate': 0.9466984167695045}
# evaluation performance: {'loss': 1.77892706990242, 'abosulate accuracy': 0.006600000243633985, 'consecutive overlap rate': 0.15336666889488698, 'overlap rate': 0.5848858945071698}
#
# Current epoch: 35,
# training performance: {'loss': 0.10233301762491465, 'abosulate accuracy': 0.6620000287890434, 'consecutive overlap rate': 0.808615006506443, 'overlap rate': 0.9895617201924324}
# evaluation performance: {'loss': 0.2157721972092986, 'abosulate accuracy': 0.6862500302493573, 'consecutive overlap rate': 0.8265525072813034, 'overlap rate': 0.9644067324697971}
#
# Current epoch: 40,
# training performance: {'loss': 0.051105356123298404, 'abosulate accuracy': 0.8567000418901444, 'consecutive overlap rate': 0.9314566776156425, 'overlap rate': 0.9966317325830459}
# evaluation performance: {'loss': 0.11787059241905809, 'abosulate accuracy': 0.834050041437149, 'consecutive overlap rate': 0.918764179944992, 'overlap rate': 0.9839983895421028}
#
# Current epoch: 45,
# training performance: {'loss': 0.029717309400439262, 'abosulate accuracy': 0.9303000405430794, 'consecutive overlap rate': 0.9709700122475624, 'overlap rate': 0.9985817298293114}
# evaluation performance: {'loss': 0.07426995523273945, 'abosulate accuracy': 0.9132500447332859, 'consecutive overlap rate': 0.9613971151411533, 'overlap rate': 0.99026058614254}
#
# Current epoch: 50,
# training performance: {'loss': 0.018845200072973967, 'abosulate accuracy': 0.963800048828125, 'consecutive overlap rate': 0.9857700139284133, 'overlap rate': 0.9993217274546623}
# evaluation performance: {'loss': 0.05101693905889988, 'abosulate accuracy': 0.9408000461757183, 'consecutive overlap rate': 0.9750158436596393, 'overlap rate': 0.9940058931708335}
#
# Current epoch: 55,
# training performance: {'loss': 0.012808308703824878, 'abosulate accuracy': 0.9805000424385071, 'consecutive overlap rate': 0.9923650100827217, 'overlap rate': 0.9996483981609344}
# evaluation performance: {'loss': 0.03941174554638564, 'abosulate accuracy': 0.9510000489652157, 'consecutive overlap rate': 0.9814475126564502, 'overlap rate': 0.9954408928751945}
#
# Current epoch: 60,
# training performance: {'loss': 0.008986111218109726, 'abosulate accuracy': 0.9882000356912612, 'consecutive overlap rate': 0.9953883439302444, 'overlap rate': 0.9997933998703956}
# evaluation performance: {'loss': 0.030257940548472105, 'abosulate accuracy': 0.970000046491623, 'consecutive overlap rate': 0.9886058449745179, 'overlap rate': 0.9964475564658641}
#
# Current epoch: 65,
# training performance: {'loss': 0.0065194993396289645, 'abosulate accuracy': 0.9943000331521035, 'consecutive overlap rate': 0.9981500104069709, 'overlap rate': 0.9999050572514534}
# evaluation performance: {'loss': 0.0251500325568486, 'abosulate accuracy': 0.9745500460267067, 'consecutive overlap rate': 0.9902575112879276, 'overlap rate': 0.9972658902406693}
#
# Current epoch: 70,
# training performance: {'loss': 0.004893623909447342, 'abosulate accuracy': 0.996900026500225, 'consecutive overlap rate': 0.9991116732358932, 'overlap rate': 0.9999483779072762}
# evaluation performance: {'loss': 0.021580876619555055, 'abosulate accuracy': 0.9805000402033329, 'consecutive overlap rate': 0.9924966782331467, 'overlap rate': 0.9976008892059326}
#
# Current epoch: 75,
# training performance: {'loss': 0.003786023135762662, 'abosulate accuracy': 0.9980000227689743, 'consecutive overlap rate': 0.9993409678339958, 'overlap rate': 0.9999666213989258}
# evaluation performance: {'loss': 0.018156985245877878, 'abosulate accuracy': 0.982200039178133, 'consecutive overlap rate': 0.9931625097990036, 'overlap rate': 0.9980408906936645}
#
# Current epoch: 80,
# training performance: {'loss': 0.0029467125015798954, 'abosulate accuracy': 0.9991000100970269, 'consecutive overlap rate': 0.9998100012540817, 'overlap rate': 0.9999850168824196}
# evaluation performance: {'loss': 0.017303266961243936, 'abosulate accuracy': 0.9858000390231609, 'consecutive overlap rate': 0.994833343476057, 'overlap rate': 0.9980417303740978}
#
# Current epoch: 85,
# training performance: {'loss': 0.002353861270239577, 'abosulate accuracy': 0.999700003862381, 'consecutive overlap rate': 0.9999899432063103, 'overlap rate': 0.9999949768185615}
# evaluation performance: {'loss': 0.015759158332366498, 'abosulate accuracy': 0.9872000373899936, 'consecutive overlap rate': 0.9953800104558468, 'overlap rate': 0.9982717290520668}
#
# Current epoch: 90,
# training performance: {'loss': 0.001885278761619702, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.9999933332204819, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.014831069175852463, 'abosulate accuracy': 0.988400037586689, 'consecutive overlap rate': 0.9958600111305713, 'overlap rate': 0.9983783841133118}
#
# Current epoch: 95,
# training performance: {'loss': 0.0015337631251895801, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014169004245195538, 'abosulate accuracy': 0.9894500359892845, 'consecutive overlap rate': 0.9962200120091438, 'overlap rate': 0.9984617166221141}
#
# Current epoch: 100,
# training performance: {'loss': 0.001264511517365463, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.014730491608497686, 'abosulate accuracy': 0.9900500364601612, 'consecutive overlap rate': 0.9962275125086307, 'overlap rate': 0.9983733877539634}
#
# Experiments_Logs/Experiment#2/RNN/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/RNN/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.011646280625427607, 'abosulate accuracy': 0.991000035777688, 'consecutive overlap rate': 0.9966470912098885, 'overlap rate': 0.9987483851611614}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.005345452576876, 'abosulate accuracy': 0.2689500138134463, 'consecutive overlap rate': 0.391379262204282, 'overlap rate': 0.5248163167387248}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.702573634732154, 'abosulate accuracy': 0.00012903226419321953, 'consecutive overlap rate': 0.004592721638900618, 'overlap rate': 0.4308199780602609}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.357000102338038, 'abosulate accuracy': 0.1023684244719334, 'consecutive overlap rate': 0.2200972645813109, 'overlap rate': 0.32277020341471624}
# Experiments_Logs/Experiment#2/RNN/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#2 with RNN seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#2/RNN/hyperparameters.json saved!
