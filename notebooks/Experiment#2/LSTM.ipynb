# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 128
embd_dim = 64
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = True
use_attention = True
reduction_method = torch.sum

learning_rate = 1e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 2
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#2/LSTM created!
# ./Experiments_Logs/Experiment#2/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#2/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#2/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#2 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9728127330541612, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0005850000095961149, 'overlap rate': 0.4176950424909592}
# evaluation performance: {'loss': 4.745836305618286, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006758333493053215, 'overlap rate': 0.41406504437327385}
#
# Current epoch: 10,
# training performance: {'loss': 1.9616986244916916, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006716666830470785, 'overlap rate': 0.42429337427020075}
# evaluation performance: {'loss': 3.3261587977409364, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006826412565715146, 'overlap rate': 0.41457082852721217}
#
# Current epoch: 15,
# training performance: {'loss': 1.9067374974489213, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009116666828049347, 'overlap rate': 0.4440250501036644}
# evaluation performance: {'loss': 3.7421975821256637, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008258333527919604, 'overlap rate': 0.4381458770483732}
#
# Current epoch: 20,
# training performance: {'loss': 1.320627899467945, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.02330500029493123, 'overlap rate': 0.6103700667619705}
# evaluation performance: {'loss': 1.9465218499302863, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.0607341674156487, 'overlap rate': 0.5746833965182304}
#
# Current epoch: 25,
# training performance: {'loss': 1.0217707708477974, 'abosulate accuracy': 0.02400000107008964, 'consecutive overlap rate': 0.13958833455108105, 'overlap rate': 0.7413067504763603}
# evaluation performance: {'loss': 1.2265487611293793, 'abosulate accuracy': 0.10160000436007977, 'consecutive overlap rate': 0.3009741701185703, 'overlap rate': 0.7207542344927788}
#
# Current epoch: 30,
# training performance: {'loss': 0.07240811651572585, 'abosulate accuracy': 0.8190000414848327, 'consecutive overlap rate': 0.9006783425807953, 'overlap rate': 0.9947483822703361}
# evaluation performance: {'loss': 0.11170638399198651, 'abosulate accuracy': 0.865250040590763, 'consecutive overlap rate': 0.9249991767108441, 'overlap rate': 0.9851983934640884}
#
# Current epoch: 35,
# training performance: {'loss': 0.021490625338628888, 'abosulate accuracy': 0.963800048828125, 'consecutive overlap rate': 0.9759400144219399, 'overlap rate': 0.9992400586605072}
# evaluation performance: {'loss': 0.03937951873522252, 'abosulate accuracy': 0.9647000469267368, 'consecutive overlap rate': 0.9803008429706097, 'overlap rate': 0.9958500571548938}
#
# Current epoch: 40,
# training performance: {'loss': 0.009951287624426186, 'abosulate accuracy': 0.9956000372767448, 'consecutive overlap rate': 0.998000006377697, 'overlap rate': 0.9999267280101776}
# evaluation performance: {'loss': 0.016300424584187567, 'abosulate accuracy': 0.9885000377893448, 'consecutive overlap rate': 0.9947466760873794, 'overlap rate': 0.9988350629806518}
#
# Current epoch: 45,
# training performance: {'loss': 1.4658928900957107, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.06395333427935838, 'overlap rate': 0.567105059325695}
# evaluation performance: {'loss': 2.4712957710027696, 'abosulate accuracy': 0.000800000037997961, 'consecutive overlap rate': 0.07266416773200035, 'overlap rate': 0.5493917241692543}
#
# Current epoch: 50,
# training performance: {'loss': 1.293810200691223, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.060830000415444375, 'overlap rate': 0.6096100583672523}
# evaluation performance: {'loss': 1.8643579587340355, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.06383500080555678, 'overlap rate': 0.5238117188215256}
#
# Current epoch: 55,
# training performance: {'loss': 0.5165942572057247, 'abosulate accuracy': 0.1476000062772073, 'consecutive overlap rate': 0.31740000247955324, 'overlap rate': 0.8579817444086075}
# evaluation performance: {'loss': 2.168663962185383, 'abosulate accuracy': 0.06290000355802476, 'consecutive overlap rate': 0.23143000323325397, 'overlap rate': 0.6514317311346531}
#
# Current epoch: 60,
# training performance: {'loss': 0.04496046304702759, 'abosulate accuracy': 0.8589000448584556, 'consecutive overlap rate': 0.9196650087833405, 'overlap rate': 0.9963867396116257}
# evaluation performance: {'loss': 0.11342873405665159, 'abosulate accuracy': 0.8632000423967838, 'consecutive overlap rate': 0.9205183461308479, 'overlap rate': 0.9840258948504925}
#
# Current epoch: 65,
# training performance: {'loss': 0.019530322588980197, 'abosulate accuracy': 0.9629000470042228, 'consecutive overlap rate': 0.9798366740345955, 'overlap rate': 0.9992817282676697}
# evaluation performance: {'loss': 0.05326996040530503, 'abosulate accuracy': 0.9414000496268272, 'consecutive overlap rate': 0.9667425118386745, 'overlap rate': 0.9936600580811501}
#
# Current epoch: 70,
# training performance: {'loss': 0.011450201459228992, 'abosulate accuracy': 0.9883000388741493, 'consecutive overlap rate': 0.9935066729784012, 'overlap rate': 0.9997884035110474}
# evaluation performance: {'loss': 0.03390249799704179, 'abosulate accuracy': 0.9660000473260879, 'consecutive overlap rate': 0.9807083889842033, 'overlap rate': 0.9962444603443146}
#
# Current epoch: 75,
# training performance: {'loss': 0.0076311198761686684, 'abosulate accuracy': 0.9958000287413598, 'consecutive overlap rate': 0.9975683376193046, 'overlap rate': 0.9999267160892487}
# evaluation performance: {'loss': 0.025376884487923235, 'abosulate accuracy': 0.9779000446200371, 'consecutive overlap rate': 0.9877275094389916, 'overlap rate': 0.9972075618803501}
#
# Current epoch: 80,
# training performance: {'loss': 0.005496312561444938, 'abosulate accuracy': 0.9991000100970269, 'consecutive overlap rate': 0.9995216682553292, 'overlap rate': 0.9999850168824196}
# evaluation performance: {'loss': 0.02071956974104978, 'abosulate accuracy': 0.982300040870905, 'consecutive overlap rate': 0.9901233434677124, 'overlap rate': 0.9977367229759693}
#
# Current epoch: 85,
# training performance: {'loss': 0.004146043374203145, 'abosulate accuracy': 0.9996000051498413, 'consecutive overlap rate': 0.9998450011014939, 'overlap rate': 0.9999933421611786}
# evaluation performance: {'loss': 0.017851391615113243, 'abosulate accuracy': 0.984950041025877, 'consecutive overlap rate': 0.9919408425688744, 'overlap rate': 0.9980292238295079}
#
# Current epoch: 90,
# training performance: {'loss': 0.0032362043857574463, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.9998850002884865, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.015492769246338866, 'abosulate accuracy': 0.9884000360965729, 'consecutive overlap rate': 0.9938850104808807, 'overlap rate': 0.998265054821968}
#
# Current epoch: 95,
# training performance: {'loss': 0.0025912552839145063, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.013915783716947771, 'abosulate accuracy': 0.9896500363945961, 'consecutive overlap rate': 0.9945033468306065, 'overlap rate': 0.9984983868896962}
#
# Current epoch: 100,
# training performance: {'loss': 0.0021137337200343607, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.010177168535301461, 'abosulate accuracy': 0.9920500352978706, 'consecutive overlap rate': 0.9958733424544335, 'overlap rate': 0.9989633888006211}
#
# Experiments_Logs/Experiment#2/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.009831121559545863, 'abosulate accuracy': 0.9916000355035066, 'consecutive overlap rate': 0.9956471215933561, 'overlap rate': 0.9989833030849695}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.1724965749308467, 'abosulate accuracy': 0.4680750234401785, 'consecutive overlap rate': 0.728788261115551, 'overlap rate': 0.7803368501365184}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.3188110805326891, 'abosulate accuracy': 0.4914629399776459, 'consecutive overlap rate': 0.7030072619838099, 'overlap rate': 0.8631540906044745}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.634254304986251, 'abosulate accuracy': 0.41271054701830606, 'consecutive overlap rate': 0.7163162819649044, 'overlap rate': 0.8037686355804142}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9772776812314987, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007335028363741003, 'overlap rate': 0.41863566264510155}
# evaluation performance: {'loss': 3.4145041346549987, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006619067942665424, 'overlap rate': 0.3475592274218798}
#
# Current epoch: 10,
# training performance: {'loss': 1.968655702471733, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000681666677701287, 'overlap rate': 0.42328337356448176}
# evaluation performance: {'loss': 3.3846708118915556, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006816666820668616, 'overlap rate': 0.3454883720725775}
#
# Current epoch: 15,
# training performance: {'loss': 1.917636176943779, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008450000161246863, 'overlap rate': 0.4406967133283615}
# evaluation performance: {'loss': 2.988539454340935, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008608333497249987, 'overlap rate': 0.43230254463851453}
#
# Current epoch: 20,
# training performance: {'loss': 1.463445433974266, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010705000103916973, 'overlap rate': 0.5681900568306446}
# evaluation performance: {'loss': 2.0288651287555695, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01985583358909935, 'overlap rate': 0.5235642224550248}
#
# Current epoch: 25,
# training performance: {'loss': 0.632330222427845, 'abosulate accuracy': 0.269900012051221, 'consecutive overlap rate': 0.4069583350326866, 'overlap rate': 0.87071672976017}
# evaluation performance: {'loss': 2.1315108492970465, 'abosulate accuracy': 0.04860000195913017, 'consecutive overlap rate': 0.14765500193461775, 'overlap rate': 0.60558006092906}
#
# Current epoch: 30,
# training performance: {'loss': 0.04505790155380964, 'abosulate accuracy': 0.9308000490069389, 'consecutive overlap rate': 0.954210014641285, 'overlap rate': 0.9983084097504615}
# evaluation performance: {'loss': 0.07055301652289928, 'abosulate accuracy': 0.9335500441491604, 'consecutive overlap rate': 0.9573900118470192, 'overlap rate': 0.9916042245924472}
#
# Current epoch: 35,
# training performance: {'loss': 0.015243383776396512, 'abosulate accuracy': 0.9834000378847122, 'consecutive overlap rate': 0.9860393017530441, 'overlap rate': 0.9996948152780533}
# evaluation performance: {'loss': 0.024986200453713536, 'abosulate accuracy': 0.9811500400304795, 'consecutive overlap rate': 0.9856425106525422, 'overlap rate': 0.9975150652229786}
#
# Current epoch: 40,
# training performance: {'loss': 0.007559382310137153, 'abosulate accuracy': 0.9961000278592109, 'consecutive overlap rate': 0.9965249985456467, 'overlap rate': 0.999935045838356}
# evaluation performance: {'loss': 0.012059622269589454, 'abosulate accuracy': 0.9925000354647636, 'consecutive overlap rate': 0.9948117032647132, 'overlap rate': 0.9990466520190239}
#
# Current epoch: 45,
# training performance: {'loss': 0.004444418859202414, 'abosulate accuracy': 0.9991000100970269, 'consecutive overlap rate': 0.9992166668176651, 'overlap rate': 0.9999850168824196}
# evaluation performance: {'loss': 0.007503397250548005, 'abosulate accuracy': 0.9959000289440155, 'consecutive overlap rate': 0.9973125070333481, 'overlap rate': 0.9995133742690087}
#
# Experiments_Logs/Experiment#2/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.0055030722272931595, 'abosulate accuracy': 0.9971500258892775, 'consecutive overlap rate': 0.998442504554987, 'overlap rate': 0.9997208643704653}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.064202960208059, 'abosulate accuracy': 0.2812500147148967, 'consecutive overlap rate': 0.3642629908863455, 'overlap rate': 0.4086571205407381}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.6502627207386878, 'abosulate accuracy': 0.5527926137370448, 'consecutive overlap rate': 0.7243200736661111, 'overlap rate': 0.8979726179953544}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.185191028016178, 'abosulate accuracy': 0.12471053418764648, 'consecutive overlap rate': 0.4175913997337614, 'overlap rate': 0.4944513302884604}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9759902089834214, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006583333481103182, 'overlap rate': 0.418311707675457}
# evaluation performance: {'loss': 5.013594263792038, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006600000167964026, 'overlap rate': 0.3221133653074503}
#
# Current epoch: 10,
# training performance: {'loss': 1.9757271856069565, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007633333538251463, 'overlap rate': 0.42116337567567824}
# evaluation performance: {'loss': 3.5767037153244017, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006700000148157414, 'overlap rate': 0.027960836188867688}
#
# Current epoch: 15,
# training performance: {'loss': 1.9080573737621307, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007583333499496803, 'overlap rate': 0.4424400463700294}
# evaluation performance: {'loss': 3.4339026302099227, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007285875890374882, 'overlap rate': 0.42656624019145967}
#
# Current epoch: 20,
# training performance: {'loss': 1.3453815758228302, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020022457907907666, 'overlap rate': 0.6061569467186928}
# evaluation performance: {'loss': 1.8976744830608367, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.04463500059209764, 'overlap rate': 0.5636750586330891}
#
# Current epoch: 25,
# training performance: {'loss': 1.6172846049070357, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.06702666711062193, 'overlap rate': 0.5579967245459556}
# evaluation performance: {'loss': 4.635674756765366, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.08546750107780099, 'overlap rate': 0.5098842151463032}
#
# Current epoch: 30,
# training performance: {'loss': 1.650565767288208, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04847000045701862, 'overlap rate': 0.521943387389183}
# evaluation performance: {'loss': 2.53772851228714, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0560075004119426, 'overlap rate': 0.2928108602762222}
#
# Current epoch: 35,
# training performance: {'loss': 0.7400475293397903, 'abosulate accuracy': 0.08610000393819064, 'consecutive overlap rate': 0.24728500209748744, 'overlap rate': 0.7914717391133308}
# evaluation performance: {'loss': 1.3023312881588935, 'abosulate accuracy': 0.1789500080049038, 'consecutive overlap rate': 0.37367333807051184, 'overlap rate': 0.7502033933997154}
#
# Current epoch: 40,
# training performance: {'loss': 0.06361771039664746, 'abosulate accuracy': 0.8409000381827354, 'consecutive overlap rate': 0.9083066761493683, 'overlap rate': 0.9957333981990815}
# evaluation performance: {'loss': 0.1203311711549759, 'abosulate accuracy': 0.8613000407814979, 'consecutive overlap rate': 0.9188458457589149, 'overlap rate': 0.9840900585055351}
#
# Current epoch: 45,
# training performance: {'loss': 0.025059152767062186, 'abosulate accuracy': 0.9582000508904457, 'consecutive overlap rate': 0.9672816768288612, 'overlap rate': 0.9991100564599037}
# evaluation performance: {'loss': 0.05593012028839439, 'abosulate accuracy': 0.9508000463247299, 'consecutive overlap rate': 0.9633483447134494, 'overlap rate': 0.9935875587165356}
#
# Current epoch: 50,
# training performance: {'loss': 0.01205028179101646, 'abosulate accuracy': 0.9933000341057777, 'consecutive overlap rate': 0.996296675503254, 'overlap rate': 0.9998850554227829}
# evaluation performance: {'loss': 0.019398852181620897, 'abosulate accuracy': 0.9818000383675098, 'consecutive overlap rate': 0.9914975091814995, 'overlap rate': 0.9985217243432999}
#
# Current epoch: 55,
# training performance: {'loss': 0.007524957717396319, 'abosulate accuracy': 0.9978000208735466, 'consecutive overlap rate': 0.9986016690731049, 'overlap rate': 0.9999633684754372}
# evaluation performance: {'loss': 0.013202749751508236, 'abosulate accuracy': 0.9863000363111496, 'consecutive overlap rate': 0.9939058400690556, 'overlap rate': 0.9989825621247291}
#
# Current epoch: 60,
# training performance: {'loss': 0.005172057228628546, 'abosulate accuracy': 0.999700003862381, 'consecutive overlap rate': 0.9998283341526986, 'overlap rate': 0.9999950066208839}
# evaluation performance: {'loss': 0.010235377046046778, 'abosulate accuracy': 0.990600036084652, 'consecutive overlap rate': 0.9958200074732304, 'overlap rate': 0.9992258869111538}
#
# Current epoch: 65,
# training performance: {'loss': 0.003793492674594745, 'abosulate accuracy': 0.9999000012874604, 'consecutive overlap rate': 0.9998999997973442, 'overlap rate': 0.9999983355402946}
# evaluation performance: {'loss': 0.007289107970427722, 'abosulate accuracy': 0.9923500344157219, 'consecutive overlap rate': 0.9968500107526779, 'overlap rate': 0.9994542181491852}
#
# Current epoch: 70,
# training performance: {'loss': 0.0028735866595525294, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.006847139255842194, 'abosulate accuracy': 0.9935000345110894, 'consecutive overlap rate': 0.997115009278059, 'overlap rate': 0.9994317181408405}
#
# Experiments_Logs/Experiment#2/LSTM/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.00534124474361306, 'abosulate accuracy': 0.9955000329762698, 'consecutive overlap rate': 0.9981433179229497, 'overlap rate': 0.9996346544474364}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 5.175346821639687, 'abosulate accuracy': 0.39530001803068443, 'consecutive overlap rate': 0.4979389005107805, 'overlap rate': 0.5366692313458771}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.3311164677143097, 'abosulate accuracy': 0.6846878632422416, 'consecutive overlap rate': 0.845912230014801, 'overlap rate': 0.9507664319007627}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.6775403824683868, 'abosulate accuracy': 0.1953157998535684, 'consecutive overlap rate': 0.5365901519238067, 'overlap rate': 0.6030730239458775}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9730806052684784, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007933333537948784, 'overlap rate': 0.42087338119745255}
# evaluation performance: {'loss': 3.5774543255567552, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007033333509752993, 'overlap rate': 0.025641669635660946}
#
# Current epoch: 10,
# training performance: {'loss': 1.9557106733322143, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011016666845534927, 'overlap rate': 0.4284550443291664}
# evaluation performance: {'loss': 3.8844243824481963, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012100000196369365, 'overlap rate': 0.03168167006224394}
#
# Current epoch: 15,
# training performance: {'loss': 1.8970839351415634, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0030116666748654097, 'overlap rate': 0.4491933785378933}
# evaluation performance: {'loss': 2.6012188524007795, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0033250000327825547, 'overlap rate': 0.30420753210783}
#
# Current epoch: 20,
# training performance: {'loss': 1.6851471781730651, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00611166674643755, 'overlap rate': 0.5026400566101075}
# evaluation performance: {'loss': 2.5976845651865004, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006944166735047474, 'overlap rate': 0.4225783787667751}
#
# Current epoch: 25,
# training performance: {'loss': 0.9069872528314591, 'abosulate accuracy': 0.006800000194925815, 'consecutive overlap rate': 0.0395450004376471, 'overlap rate': 0.7436417460441589}
# evaluation performance: {'loss': 3.4701997190713882, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03670309374574572, 'overlap rate': 0.4873130600899458}
#
# Current epoch: 30,
# training performance: {'loss': 0.7607130527496337, 'abosulate accuracy': 0.06930000316351652, 'consecutive overlap rate': 0.1480116693302989, 'overlap rate': 0.7962234020233154}
# evaluation performance: {'loss': 1.2985571190714835, 'abosulate accuracy': 0.19010000843554736, 'consecutive overlap rate': 0.2916350029408932, 'overlap rate': 0.7056908912956714}
#
# Current epoch: 35,
# training performance: {'loss': 0.07185436533764004, 'abosulate accuracy': 0.8434000432491302, 'consecutive overlap rate': 0.9106800153851509, 'overlap rate': 0.996670064330101}
# evaluation performance: {'loss': 0.1135349202901125, 'abosulate accuracy': 0.8605000421404838, 'consecutive overlap rate': 0.9244583450257778, 'overlap rate': 0.9870350576937199}
#
# Current epoch: 40,
# training performance: {'loss': 0.026278789853677154, 'abosulate accuracy': 0.973100046813488, 'consecutive overlap rate': 0.9879366785287857, 'overlap rate': 0.9994500517845154}
# evaluation performance: {'loss': 0.04433326632715762, 'abosulate accuracy': 0.9550500482320785, 'consecutive overlap rate': 0.9768758438527584, 'overlap rate': 0.9959900625050068}
#
# Current epoch: 45,
# training performance: {'loss': 0.01372858912218362, 'abosulate accuracy': 0.9940000355243683, 'consecutive overlap rate': 0.9974000051617622, 'overlap rate': 0.9998583927750587}
# evaluation performance: {'loss': 0.020673085632734, 'abosulate accuracy': 0.9838500373065472, 'consecutive overlap rate': 0.9927308425307274, 'overlap rate': 0.9985600590705872}
#
# Current epoch: 50,
# training performance: {'loss': 0.008586149872280657, 'abosulate accuracy': 0.9982000172138215, 'consecutive overlap rate': 0.9992100015282631, 'overlap rate': 0.9999316945672035}
# evaluation performance: {'loss': 0.012719341577030719, 'abosulate accuracy': 0.9916500329971314, 'consecutive overlap rate': 0.9965516775846481, 'overlap rate': 0.9992350481450558}
#
# Current epoch: 55,
# training performance: {'loss': 0.005957376433070749, 'abosulate accuracy': 0.9993000090122223, 'consecutive overlap rate': 0.9996083334088326, 'overlap rate': 0.9999466806650161}
# evaluation performance: {'loss': 0.009491284552495927, 'abosulate accuracy': 0.9941500335931778, 'consecutive overlap rate': 0.9975016765296459, 'overlap rate': 0.9994283810257911}
#
# Current epoch: 60,
# training performance: {'loss': 0.004408684727968648, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.9999349996447563, 'overlap rate': 0.9999583378434181}
# evaluation performance: {'loss': 0.007058184107881971, 'abosulate accuracy': 0.9952500313520432, 'consecutive overlap rate': 0.9981858402490615, 'overlap rate': 0.999580878764391}
#
# Experiments_Logs/Experiment#2/LSTM/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.005875696953444276, 'abosulate accuracy': 0.9964250240474939, 'consecutive overlap rate': 0.998416256904602, 'overlap rate': 0.9996471147984266}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.36119225891307, 'abosulate accuracy': 0.13455000516260043, 'consecutive overlap rate': 0.29048173893243073, 'overlap rate': 0.3474527221173048}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.2557912311246318, 'abosulate accuracy': 0.34350279396580113, 'consecutive overlap rate': 0.6495170393297749, 'overlap rate': 0.8758258273524623}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.940391284266585, 'abosulate accuracy': 0.15042105850788126, 'consecutive overlap rate': 0.5616351577796435, 'overlap rate': 0.6287321962024036}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.003762698173523, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015983333563781344, 'overlap rate': 0.4176850438117981}
# evaluation performance: {'loss': 3.709212192893028, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016233333590207621, 'overlap rate': 0.026059169508516788}
#
# Current epoch: 10,
# training performance: {'loss': 1.956761148571968, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009266666820622049, 'overlap rate': 0.42781504392623904}
# evaluation performance: {'loss': 3.8728638708591463, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0017991666827583686, 'overlap rate': 0.030681670038029553}
#
# Current epoch: 15,
# training performance: {'loss': 1.913590779900551, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0023550000420073046, 'overlap rate': 0.4441267117857933}
# evaluation performance: {'loss': 2.9140283495187758, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0026350000349339097, 'overlap rate': 0.4409383784979582}
#
# Current epoch: 20,
# training performance: {'loss': 1.800636398792267, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038583333836868404, 'overlap rate': 0.4730300471186638}
# evaluation performance: {'loss': 2.0904085382819177, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003892500029178336, 'overlap rate': 0.4547117095440626}
#
# Current epoch: 25,
# training performance: {'loss': 1.209110264480114, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011500000138767064, 'overlap rate': 0.6367867350578308}
# evaluation performance: {'loss': 1.9249533087015152, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013212500128429384, 'overlap rate': 0.5095553535968065}
#
# Current epoch: 30,
# training performance: {'loss': 1.5937301367521286, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02228129976429045, 'overlap rate': 0.547630786895752}
# evaluation performance: {'loss': 2.9604669332504274, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.023634166829288004, 'overlap rate': 0.4931317150592804}
#
# Current epoch: 35,
# training performance: {'loss': 0.7450941532850266, 'abosulate accuracy': 0.03510000183014199, 'consecutive overlap rate': 0.1097342386841774, 'overlap rate': 0.7978012368083001}
# evaluation performance: {'loss': 1.1023144736886024, 'abosulate accuracy': 0.18020000839605926, 'consecutive overlap rate': 0.27402250189334154, 'overlap rate': 0.7091850623488426}
#
# Current epoch: 40,
# training performance: {'loss': 0.07130721965804696, 'abosulate accuracy': 0.8435000404715538, 'consecutive overlap rate': 0.9042583376169204, 'overlap rate': 0.9961534038186073}
# evaluation performance: {'loss': 0.11426877034828067, 'abosulate accuracy': 0.8490500405430794, 'consecutive overlap rate': 0.909051675349474, 'overlap rate': 0.9858625635504723}
#
# Current epoch: 45,
# training performance: {'loss': 0.02460853960365057, 'abosulate accuracy': 0.9686000496149063, 'consecutive overlap rate': 0.9829733416438102, 'overlap rate': 0.9993900611996651}
# evaluation performance: {'loss': 0.0389075200073421, 'abosulate accuracy': 0.961900045722723, 'consecutive overlap rate': 0.9791291765868664, 'overlap rate': 0.9966375604271889}
#
# Current epoch: 50,
# training performance: {'loss': 0.012265190226025879, 'abosulate accuracy': 0.9916000351309776, 'consecutive overlap rate': 0.996411670744419, 'overlap rate': 0.9998550698161125}
# evaluation performance: {'loss': 0.01930258764186874, 'abosulate accuracy': 0.9843500398099423, 'consecutive overlap rate': 0.9932758465409279, 'overlap rate': 0.9986008942127228}
#
# Current epoch: 55,
# training performance: {'loss': 0.0072635657154023646, 'abosulate accuracy': 0.997700022161007, 'consecutive overlap rate': 0.9991983398795128, 'overlap rate': 0.9999617025256157}
# evaluation performance: {'loss': 0.0116183067264501, 'abosulate accuracy': 0.9918000355362893, 'consecutive overlap rate': 0.9962275087833404, 'overlap rate': 0.9992467179894448}
#
# Current epoch: 60,
# training performance: {'loss': 0.004789974680170417, 'abosulate accuracy': 0.9995000064373016, 'consecutive overlap rate': 0.999908335506916, 'overlap rate': 0.9999916777014732}
# evaluation performance: {'loss': 0.00797465440700762, 'abosulate accuracy': 0.9952500335872173, 'consecutive overlap rate': 0.997840841114521, 'overlap rate': 0.9995175465941429}
#
# Current epoch: 65,
# training performance: {'loss': 0.003367893333779648, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.9999216675758362, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.006612306580063887, 'abosulate accuracy': 0.9956500291824341, 'consecutive overlap rate': 0.9980758413672447, 'overlap rate': 0.9995150379836559}
#
# Current epoch: 70,
# training performance: {'loss': 1.7152045220136642, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.057553334068506955, 'overlap rate': 0.505740050971508}
# evaluation performance: {'loss': 3.0397625654935836, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06376666720025241, 'overlap rate': 0.11625584587454796}
#
# Current epoch: 75,
# training performance: {'loss': 1.656137576699257, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05924666728824377, 'overlap rate': 0.5212033838033676}
# evaluation performance: {'loss': 2.051318794488907, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06012385655194521, 'overlap rate': 0.4324350282549858}
#
# Current epoch: 80,
# training performance: {'loss': 0.8944171234965325, 'abosulate accuracy': 0.002800000098068267, 'consecutive overlap rate': 0.12661333438009023, 'overlap rate': 0.7306600779294967}
# evaluation performance: {'loss': 1.5857558578252793, 'abosulate accuracy': 0.01525000062538311, 'consecutive overlap rate': 0.1899016687646508, 'overlap rate': 0.6764200672507286}
#
# Current epoch: 85,
# training performance: {'loss': 0.94030552059412, 'abosulate accuracy': 0.036400001705624165, 'consecutive overlap rate': 0.22827500198036432, 'overlap rate': 0.7422350868582726}
# evaluation performance: {'loss': 1.4260275274515153, 'abosulate accuracy': 0.044100002059713005, 'consecutive overlap rate': 0.21981083564460277, 'overlap rate': 0.6512525700032711}
#
# Current epoch: 90,
# training performance: {'loss': 0.4432987108826637, 'abosulate accuracy': 0.1969000081066042, 'consecutive overlap rate': 0.3950883366167545, 'overlap rate': 0.8937784120440483}
# evaluation performance: {'loss': 3.5608148902654646, 'abosulate accuracy': 0.002350000099977478, 'consecutive overlap rate': 0.0676241674926132, 'overlap rate': 0.5035525534301997}
#
# Current epoch: 95,
# training performance: {'loss': 0.04358270391821861, 'abosulate accuracy': 0.8603000342845917, 'consecutive overlap rate': 0.9419833451509476, 'overlap rate': 0.9971067368984222}
# evaluation performance: {'loss': 0.07808724767528474, 'abosulate accuracy': 0.8645500406622887, 'consecutive overlap rate': 0.945953344553709, 'overlap rate': 0.9908408880233764}
#
# Current epoch: 100,
# training performance: {'loss': 0.01831430890597403, 'abosulate accuracy': 0.9677000492811203, 'consecutive overlap rate': 0.9886500120162964, 'overlap rate': 0.9994300529360771}
# evaluation performance: {'loss': 0.03214170560240746, 'abosulate accuracy': 0.9544500462710858, 'consecutive overlap rate': 0.9832583449780941, 'overlap rate': 0.9970750637352467}
#
# Experiments_Logs/Experiment#2/LSTM/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.005614744455670007, 'abosulate accuracy': 0.9957750309258699, 'consecutive overlap rate': 0.9982104219496251, 'overlap rate': 0.9996521223336459}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 1.8770864648744463, 'abosulate accuracy': 0.35810001734644176, 'consecutive overlap rate': 0.7201393835246563, 'overlap rate': 0.7748167745769023}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.8177581102617326, 'abosulate accuracy': 0.4275602884830967, 'consecutive overlap rate': 0.6473696235687502, 'overlap rate': 0.8120286264727192}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.8781812836072946, 'abosulate accuracy': 0.4308684420600337, 'consecutive overlap rate': 0.7503834296213953, 'overlap rate': 0.808843364056788}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.97981096804142, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007121186583390227, 'overlap rate': 0.4188089661300182}
# evaluation performance: {'loss': 4.78423905968666, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011991666848189197, 'overlap rate': 0.40742754451930524}
#
# Current epoch: 10,
# training performance: {'loss': 1.968462836742401, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011450000209151767, 'overlap rate': 0.42144338190555575}
# evaluation performance: {'loss': 6.460919082164764, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009933333567460068, 'overlap rate': 0.29109586253762243}
#
# Current epoch: 15,
# training performance: {'loss': 1.8813323646783828, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018916666915174574, 'overlap rate': 0.45287171080708505}
# evaluation performance: {'loss': 2.54431157708168, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002054166687594261, 'overlap rate': 0.4293792113661766}
#
# Current epoch: 20,
# training performance: {'loss': 1.3084628134965897, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.01411333349533379, 'overlap rate': 0.6257250607013702}
# evaluation performance: {'loss': 3.3810180723667145, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01275583349633962, 'overlap rate': 0.4875758823007345}
#
# Current epoch: 25,
# training performance: {'loss': 0.7840628787875176, 'abosulate accuracy': 0.040000002016313374, 'consecutive overlap rate': 0.13288500132039188, 'overlap rate': 0.7948417425155639}
# evaluation performance: {'loss': 1.217531618475914, 'abosulate accuracy': 0.11640000455081463, 'consecutive overlap rate': 0.23125333543866872, 'overlap rate': 0.6977608956396579}
#
# Current epoch: 30,
# training performance: {'loss': 0.06320370808243751, 'abosulate accuracy': 0.8840000435709954, 'consecutive overlap rate': 0.9269600167870522, 'overlap rate': 0.9972067460417747}
# evaluation performance: {'loss': 0.1105473511852324, 'abosulate accuracy': 0.8856500446796417, 'consecutive overlap rate': 0.9286841779947281, 'overlap rate': 0.9867583908140659}
#
# Current epoch: 35,
# training performance: {'loss': 1.7734985381364823, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04379833405837417, 'overlap rate': 0.4889767155051231}
# evaluation performance: {'loss': 2.246953549981117, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.047681667283177374, 'overlap rate': 0.41051587611436846}
#
# Current epoch: 40,
# training performance: {'loss': 0.9700945645570755, 'abosulate accuracy': 0.02990000133868307, 'consecutive overlap rate': 0.14949833508580923, 'overlap rate': 0.7081717446446418}
# evaluation performance: {'loss': 1.228176261484623, 'abosulate accuracy': 0.0874500042758882, 'consecutive overlap rate': 0.2441275015473366, 'overlap rate': 0.6695358917117119}
#
# Current epoch: 45,
# training performance: {'loss': 1.1791590988636016, 'abosulate accuracy': 0.03270000176271424, 'consecutive overlap rate': 0.14468166846781969, 'overlap rate': 0.6890617311000824}
# evaluation performance: {'loss': 2.8664866626262664, 'abosulate accuracy': 0.0009000000427477062, 'consecutive overlap rate': 0.10971315065398812, 'overlap rate': 0.5566559925675392}
#
# Current epoch: 50,
# training performance: {'loss': 1.9419448286294938, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03964833356440067, 'overlap rate': 0.4712467096745968}
# evaluation performance: {'loss': 3.224718075990677, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.045760833704844114, 'overlap rate': 0.08381667565554381}
#
# Current epoch: 55,
# training performance: {'loss': 0.9767440542578697, 'abosulate accuracy': 0.02380000111879781, 'consecutive overlap rate': 0.1288833349943161, 'overlap rate': 0.7394317455589772}
# evaluation performance: {'loss': 5.8196199297904965, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03307833366561681, 'overlap rate': 0.4472708772867918}
#
# Current epoch: 60,
# training performance: {'loss': 0.8400822699069976, 'abosulate accuracy': 0.012200000567827374, 'consecutive overlap rate': 0.16411333568394185, 'overlap rate': 0.7513834118843079}
# evaluation performance: {'loss': 2.356657922267914, 'abosulate accuracy': 0.06285000327043236, 'consecutive overlap rate': 0.23203750140964985, 'overlap rate': 0.6747425608336926}
#
# Current epoch: 65,
# training performance: {'loss': 1.9236378163099288, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016038333438336848, 'overlap rate': 0.43757337853312495}
# evaluation performance: {'loss': 3.1432674139738084, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01986500029452145, 'overlap rate': 0.07960750944912434}
#
# Current epoch: 70,
# training performance: {'loss': 1.2421172440052033, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.05221666749566793, 'overlap rate': 0.6212183967232704}
# evaluation performance: {'loss': 2.5113310515880585, 'abosulate accuracy': 0.0014500000688713044, 'consecutive overlap rate': 0.06719000115990639, 'overlap rate': 0.5377333916723728}
#
# Current epoch: 75,
# training performance: {'loss': 0.9686021581292152, 'abosulate accuracy': 0.0017000000807456672, 'consecutive overlap rate': 0.08789333458989859, 'overlap rate': 0.7089534133672715}
# evaluation performance: {'loss': 1.6574557304382325, 'abosulate accuracy': 0.004900000168709085, 'consecutive overlap rate': 0.10326940761879086, 'overlap rate': 0.5784388035535812}
#
# Current epoch: 80,
# training performance: {'loss': 0.16757587902247906, 'abosulate accuracy': 0.3909000188112259, 'consecutive overlap rate': 0.5550063028931618, 'overlap rate': 0.966886593401432}
# evaluation performance: {'loss': 0.4058853071182966, 'abosulate accuracy': 0.45510002188384535, 'consecutive overlap rate': 0.6166708394885063, 'overlap rate': 0.9231108993291854}
#
# Current epoch: 85,
# training performance: {'loss': 0.0471062839962542, 'abosulate accuracy': 0.8298000410199166, 'consecutive overlap rate': 0.9128150090575218, 'overlap rate': 0.9960267409682274}
# evaluation performance: {'loss': 0.1063025956042111, 'abosulate accuracy': 0.8144500367343426, 'consecutive overlap rate': 0.9035566754639148, 'overlap rate': 0.9857558846473694}
#
# Current epoch: 90,
# training performance: {'loss': 0.022408820688724518, 'abosulate accuracy': 0.944900044798851, 'consecutive overlap rate': 0.9759666800498963, 'overlap rate': 0.9989617258310318}
# evaluation performance: {'loss': 0.045622568228282034, 'abosulate accuracy': 0.9257500462234021, 'consecutive overlap rate': 0.96693250015378, 'overlap rate': 0.9950981147587299}
#
# Current epoch: 95,
# training performance: {'loss': 0.01338149660732597, 'abosulate accuracy': 0.9813000410795212, 'consecutive overlap rate': 0.993568341434002, 'overlap rate': 0.9996700748801232}
# evaluation performance: {'loss': 0.026496020110789685, 'abosulate accuracy': 0.9625500440597534, 'consecutive overlap rate': 0.9840833462774754, 'overlap rate': 0.9975008942186833}
#
# Current epoch: 100,
# training performance: {'loss': 0.008974896010477096, 'abosulate accuracy': 0.9932000383734703, 'consecutive overlap rate': 0.9976533457636834, 'overlap rate': 0.9998850613832474}
# evaluation performance: {'loss': 0.019643843395169825, 'abosulate accuracy': 0.9767500445246696, 'consecutive overlap rate': 0.990684175491333, 'overlap rate': 0.9981750585138798}
#
# Experiments_Logs/Experiment#2/LSTM/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#2/LSTM/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.019883684889646248, 'abosulate accuracy': 0.9748750437051058, 'consecutive overlap rate': 0.9901079278439283, 'overlap rate': 0.9981258947402238}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.0599629383534195, 'abosulate accuracy': 0.251450010179542, 'consecutive overlap rate': 0.6453967899084091, 'overlap rate': 0.6911294907331467}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.213700125294347, 'abosulate accuracy': 0.3211224677101258, 'consecutive overlap rate': 0.6131650274799716, 'overlap rate': 0.8535497926896618}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 2.4869473380477807, 'abosulate accuracy': 0.11150000476290618, 'consecutive overlap rate': 0.5431388400887188, 'overlap rate': 0.6491339967439049}
# Experiments_Logs/Experiment#2/LSTM/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#2 with LSTM seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#2/LSTM/hyperparameters.json saved!
