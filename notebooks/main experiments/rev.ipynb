# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-01-22 22:35:38

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/rev")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "rev"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 512
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,176,476 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 2.839701223373413, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.013491183538683537, 'overlap rate': 0.20154384254634256}
# evaluation performance: {'loss': 2.844562268257141, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.013969396575646578, 'overlap rate': 0.20070628649128647}
#
# Current epoch: 20,
# training performance: {'loss': 2.4799705505371095, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01303878371628372, 'overlap rate': 0.24123944083694085}
# evaluation performance: {'loss': 2.491630959510803, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01321393079143079, 'overlap rate': 0.2383767694805195}
#
# Current epoch: 30,
# training performance: {'loss': 2.2323959112167358, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.02026073093573094, 'overlap rate': 0.26940656773781774}
# evaluation performance: {'loss': 2.2481202244758607, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.020519977661227668, 'overlap rate': 0.2664314985014985}
#
# Current epoch: 40,
# training performance: {'loss': 2.0972786784172057, 'full sequence accuracy': 0.0045000000000000005, 'first n-symbol accuracy': 0.05965792721167723, 'overlap rate': 0.30850139305139307}
# evaluation performance: {'loss': 2.116493344306946, 'full sequence accuracy': 0.0035000000000000005, 'first n-symbol accuracy': 0.05843482656232655, 'overlap rate': 0.30484615925740927}
#
# Current epoch: 50,
# training performance: {'loss': 1.896131157875061, 'full sequence accuracy': 0.0425, 'first n-symbol accuracy': 0.18280907842157845, 'overlap rate': 0.4528777448939949}
# evaluation performance: {'loss': 1.937049353122711, 'full sequence accuracy': 0.036699999999999997, 'first n-symbol accuracy': 0.1699053771228771, 'overlap rate': 0.44080540986790984}
#
# Current epoch: 60,
# training performance: {'loss': 1.4870572626590728, 'full sequence accuracy': 0.1753, 'first n-symbol accuracy': 0.3903031485181485, 'overlap rate': 0.6414157163669664}
# evaluation performance: {'loss': 1.5454024791717529, 'full sequence accuracy': 0.15919999999999995, 'first n-symbol accuracy': 0.3685295962370963, 'overlap rate': 0.6267253116328118}
#
# Current epoch: 70,
# training performance: {'loss': 1.1829326927661896, 'full sequence accuracy': 0.31589999999999996, 'first n-symbol accuracy': 0.5395927525252524, 'overlap rate': 0.7483162273837274}
# evaluation performance: {'loss': 1.2691469937562943, 'full sequence accuracy': 0.27059999999999995, 'first n-symbol accuracy': 0.5034642429792429, 'overlap rate': 0.7261571119158621}
#
# Current epoch: 80,
# training performance: {'loss': 0.7780286312103272, 'full sequence accuracy': 0.511, 'first n-symbol accuracy': 0.7071006532356533, 'overlap rate': 0.8532363492063493}
# evaluation performance: {'loss': 0.9350945070385933, 'full sequence accuracy': 0.4388000000000001, 'first n-symbol accuracy': 0.6543629662004663, 'overlap rate': 0.8196830469530472}
#
# Current epoch: 90,
# training performance: {'loss': 0.6323596954345703, 'full sequence accuracy': 0.6058999999999999, 'first n-symbol accuracy': 0.7649330193417694, 'overlap rate': 0.8915272168109667}
# evaluation performance: {'loss': 0.8347208596765995, 'full sequence accuracy': 0.5056999999999998, 'first n-symbol accuracy': 0.704889449023199, 'overlap rate': 0.8534251072538572}
#
# Current epoch: 100,
# training performance: {'loss': 0.5046696897596121, 'full sequence accuracy': 0.6806, 'first n-symbol accuracy': 0.8253585965423464, 'overlap rate': 0.9200612096237097}
# evaluation performance: {'loss': 0.715843191370368, 'full sequence accuracy': 0.5695, 'first n-symbol accuracy': 0.7634524814074816, 'overlap rate': 0.8825736571761571}
#
# Current epoch: 110,
# training performance: {'loss': 0.45342973731458186, 'full sequence accuracy': 0.6822000000000001, 'first n-symbol accuracy': 0.852343638028638, 'overlap rate': 0.9301008123820624}
# evaluation performance: {'loss': 0.6965168505907059, 'full sequence accuracy': 0.5675, 'first n-symbol accuracy': 0.7835769652569653, 'overlap rate': 0.8908485057997559}
#
# Current epoch: 120,
# training performance: {'loss': 0.29176293686032295, 'full sequence accuracy': 0.8162, 'first n-symbol accuracy': 0.900509095904096, 'overlap rate': 0.9589065102952603}
# evaluation performance: {'loss': 0.5686508677899837, 'full sequence accuracy': 0.6618, 'first n-symbol accuracy': 0.8187437974525473, 'overlap rate': 0.9141171703296702}
#
# Current epoch: 130,
# training performance: {'loss': 0.40118311494588854, 'full sequence accuracy': 0.757, 'first n-symbol accuracy': 0.8642552385114886, 'overlap rate': 0.9438125947663447}
# evaluation performance: {'loss': 0.6890960022807121, 'full sequence accuracy': 0.6214, 'first n-symbol accuracy': 0.7843488503163504, 'overlap rate': 0.9002262629037631}
#
# Current epoch: 140,
# training performance: {'loss': 0.1712259895168245, 'full sequence accuracy': 0.8967999999999998, 'first n-symbol accuracy': 0.9488238618326118, 'overlap rate': 0.9790882856032856}
# evaluation performance: {'loss': 0.4776626456528902, 'full sequence accuracy': 0.7211000000000001, 'first n-symbol accuracy': 0.857144995976246, 'overlap rate': 0.9340738918026419}
#
# Current epoch: 150,
# training performance: {'loss': 0.18411526307463646, 'full sequence accuracy': 0.8891, 'first n-symbol accuracy': 0.943634833916084, 'overlap rate': 0.9772324944499944}
# evaluation performance: {'loss': 0.492249708995223, 'full sequence accuracy': 0.7195, 'first n-symbol accuracy': 0.8543149861249862, 'overlap rate': 0.9336170741758243}
#
# Current epoch: 160,
# training performance: {'loss': 0.20545683102682233, 'full sequence accuracy': 0.8802999999999999, 'first n-symbol accuracy': 0.9347278042790543, 'overlap rate': 0.9751822537185036}
# evaluation performance: {'loss': 0.5249601313844323, 'full sequence accuracy': 0.7097, 'first n-symbol accuracy': 0.8431983828671328, 'overlap rate': 0.9314535180097681}
#
# Current epoch: 170,
# training performance: {'loss': 0.12477269638329744, 'full sequence accuracy': 0.9307000000000001, 'first n-symbol accuracy': 0.9633022831335332, 'overlap rate': 0.985831032994783}
# evaluation performance: {'loss': 0.4522750070784241, 'full sequence accuracy': 0.7453000000000001, 'first n-symbol accuracy': 0.863687848124098, 'overlap rate': 0.9409334733322232}
#
# Current epoch: 180,
# training performance: {'loss': 0.10286000249907375, 'full sequence accuracy': 0.9419000000000001, 'first n-symbol accuracy': 0.9734918560606062, 'overlap rate': 0.9892674843212343}
# evaluation performance: {'loss': 0.4365000994876027, 'full sequence accuracy': 0.7542, 'first n-symbol accuracy': 0.8753340610778111, 'overlap rate': 0.9457915025252526}
#
# Current epoch: 190,
# training performance: {'loss': 0.13061150959692897, 'full sequence accuracy': 0.9248000000000001, 'first n-symbol accuracy': 0.9579514357864358, 'overlap rate': 0.9853828051115551}
# evaluation performance: {'loss': 0.48531564204022287, 'full sequence accuracy': 0.7329999999999999, 'first n-symbol accuracy': 0.8536713593351093, 'overlap rate': 0.9395582398157398}
#
# Current epoch: 200,
# training performance: {'loss': 0.05866956003010273, 'full sequence accuracy': 0.9647, 'first n-symbol accuracy': 0.9840026789876788, 'overlap rate': 0.9941488580863581}
# evaluation performance: {'loss': 0.37556474143639207, 'full sequence accuracy': 0.7841, 'first n-symbol accuracy': 0.8909416314241314, 'overlap rate': 0.9542803800366298}
#
# Current epoch: 210,
# training performance: {'loss': 0.049077686946839096, 'full sequence accuracy': 0.9721, 'first n-symbol accuracy': 0.9872951523476523, 'overlap rate': 0.9955150387112888}
# evaluation performance: {'loss': 0.3585819510743022, 'full sequence accuracy': 0.7989999999999999, 'first n-symbol accuracy': 0.898193341935842, 'overlap rate': 0.9575902443389943}
#
# Current epoch: 220,
# training performance: {'loss': 0.02313496038550511, 'full sequence accuracy': 0.9779, 'first n-symbol accuracy': 0.9940177031302031, 'overlap rate': 0.9976151977189478}
# evaluation performance: {'loss': 0.28624309045262636, 'full sequence accuracy': 0.8124, 'first n-symbol accuracy': 0.9165805867743367, 'overlap rate': 0.9650203504828505}
#
# Current epoch: 230,
# training performance: {'loss': 0.008693422563374043, 'full sequence accuracy': 0.9982000000000001, 'first n-symbol accuracy': 0.9991728571428571, 'overlap rate': 0.9997582142857142}
# evaluation performance: {'loss': 0.23752483312273398, 'full sequence accuracy': 0.8625999999999999, 'first n-symbol accuracy': 0.9325775928238429, 'overlap rate': 0.9731898239260739}
#
# Current epoch: 240,
# training performance: {'loss': 0.010014356451574714, 'full sequence accuracy': 0.9972999999999999, 'first n-symbol accuracy': 0.9987648214285715, 'overlap rate': 0.9996012500000001}
# evaluation performance: {'loss': 0.24392700574826448, 'full sequence accuracy': 0.8571000000000002, 'first n-symbol accuracy': 0.9284151146076145, 'overlap rate': 0.9722737391774892}
#
# Current epoch: 250,
# training performance: {'loss': 0.005323543085251003, 'full sequence accuracy': 0.9991999999999999, 'first n-symbol accuracy': 0.9995918452380954, 'overlap rate': 0.9998688095238094}
# evaluation performance: {'loss': 0.20006592557765543, 'full sequence accuracy': 0.8807, 'first n-symbol accuracy': 0.945038096903097, 'overlap rate': 0.9779266351703851}
#
# Current epoch: 260,
# training performance: {'loss': 0.008947816386353225, 'full sequence accuracy': 0.9972, 'first n-symbol accuracy': 0.9990557005494505, 'overlap rate': 0.9996484386446886}
# evaluation performance: {'loss': 0.23205559058114886, 'full sequence accuracy': 0.8642, 'first n-symbol accuracy': 0.9375004706404708, 'overlap rate': 0.9746250817238316}
#
# Current epoch: 270,
# training performance: {'loss': 0.008689395984401927, 'full sequence accuracy': 0.9978999999999999, 'first n-symbol accuracy': 0.998777445054945, 'overlap rate': 0.9995777106227107}
# evaluation performance: {'loss': 0.22469361149705946, 'full sequence accuracy': 0.8742000000000001, 'first n-symbol accuracy': 0.9379741333666335, 'overlap rate': 0.9761480487567991}
#
# Current epoch: 280,
# training performance: {'loss': 0.003394204512005672, 'full sequence accuracy': 0.9997999999999999, 'first n-symbol accuracy': 0.9999437499999999, 'overlap rate': 0.9999750000000001}
# evaluation performance: {'loss': 0.18355378622654825, 'full sequence accuracy': 0.8889000000000001, 'first n-symbol accuracy': 0.9517748563936064, 'overlap rate': 0.9805542855755356}
#
# Current epoch: 290,
# training performance: {'loss': 0.005238049192121253, 'full sequence accuracy': 0.9983000000000001, 'first n-symbol accuracy': 0.9993885714285715, 'overlap rate': 0.9997939285714287}
# evaluation performance: {'loss': 0.20236659233924, 'full sequence accuracy': 0.8823999999999999, 'first n-symbol accuracy': 0.9473682574370075, 'overlap rate': 0.9782541025641025}
#
# Current epoch: 300,
# training performance: {'loss': 0.0037953919963911176, 'full sequence accuracy': 0.9997, 'first n-symbol accuracy': 0.9998408333333334, 'overlap rate': 0.9999354166666666}
# evaluation performance: {'loss': 0.18613677308894694, 'full sequence accuracy': 0.8931999999999999, 'first n-symbol accuracy': 0.9503397086247087, 'overlap rate': 0.980345724830725}
#
# Current epoch: 310,
# training performance: {'loss': 0.0027777116512879728, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.18059244891628623, 'full sequence accuracy': 0.898, 'first n-symbol accuracy': 0.9531622115384616, 'overlap rate': 0.9810044877344879}
#
# Current epoch: 320,
# training performance: {'loss': 0.0027456997369881718, 'full sequence accuracy': 0.9997999999999999, 'first n-symbol accuracy': 0.9999062500000001, 'overlap rate': 0.9999750000000001}
# evaluation performance: {'loss': 0.18324713185429573, 'full sequence accuracy': 0.8953000000000001, 'first n-symbol accuracy': 0.9531777805527806, 'overlap rate': 0.9809913235375735}
#
# Current epoch: 330,
# training performance: {'loss': 0.0035438928491203113, 'full sequence accuracy': 0.9994, 'first n-symbol accuracy': 0.9997920833333334, 'overlap rate': 0.9999241666666666}
# evaluation performance: {'loss': 0.1955095969606191, 'full sequence accuracy': 0.8883000000000001, 'first n-symbol accuracy': 0.9500159299034298, 'overlap rate': 0.9801613003663006}
#
# Current epoch: 340,
# training performance: {'loss': 0.0027123156760353595, 'full sequence accuracy': 0.9997, 'first n-symbol accuracy': 0.9999062500000001, 'overlap rate': 0.9999625}
# evaluation performance: {'loss': 0.16947395165916532, 'full sequence accuracy': 0.8993, 'first n-symbol accuracy': 0.9573015605228106, 'overlap rate': 0.9825694523532024}
#
# Current epoch: 350,
# training performance: {'loss': 0.003012287028832361, 'full sequence accuracy': 0.9996, 'first n-symbol accuracy': 0.9998033333333334, 'overlap rate': 0.9999491666666666}
# evaluation performance: {'loss': 0.1880972701648716, 'full sequence accuracy': 0.8919, 'first n-symbol accuracy': 0.9496588011988012, 'overlap rate': 0.9804161467698966}
#
# Current epoch: 360,
# training performance: {'loss': 0.0028258883976377547, 'full sequence accuracy': 0.9996, 'first n-symbol accuracy': 0.9998862500000001, 'overlap rate': 0.9999491666666666}
# evaluation performance: {'loss': 0.16564958121161907, 'full sequence accuracy': 0.9025000000000001, 'first n-symbol accuracy': 0.9565962953712953, 'overlap rate': 0.9828070476745477}
#
# Current epoch: 370,
# training performance: {'loss': 0.008165782078867779, 'full sequence accuracy': 0.9968, 'first n-symbol accuracy': 0.9986110427072928, 'overlap rate': 0.9995309573759572}
# evaluation performance: {'loss': 0.24064132566563784, 'full sequence accuracy': 0.865, 'first n-symbol accuracy': 0.9349747077922078, 'overlap rate': 0.9746499734987234}
#
# Current epoch: 380,
# training performance: {'loss': 0.0030766879150178283, 'full sequence accuracy': 0.9994, 'first n-symbol accuracy': 0.999865, 'overlap rate': 0.9999291666666666}
# evaluation performance: {'loss': 0.19127250127494336, 'full sequence accuracy': 0.8885000000000002, 'first n-symbol accuracy': 0.9489815315240315, 'overlap rate': 0.980154141969142}
#
# Current epoch: 390,
# training performance: {'loss': 0.0019754134642425924, 'full sequence accuracy': 0.9997, 'first n-symbol accuracy': 0.9998854166666666, 'overlap rate': 0.9999616666666666}
# evaluation performance: {'loss': 0.1515570075600408, 'full sequence accuracy': 0.9118999999999999, 'first n-symbol accuracy': 0.9610065651015651, 'overlap rate': 0.9847499179986681}
#
# Current epoch: 400,
# training performance: {'loss': 0.001189823923050426, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1302056306740269, 'full sequence accuracy': 0.9206000000000001, 'first n-symbol accuracy': 0.9679823559773558, 'overlap rate': 0.9869472791097792}
#
# Current epoch: 410,
# training performance: {'loss': 0.0012148977140896023, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.13328481433563866, 'full sequence accuracy': 0.9187999999999998, 'first n-symbol accuracy': 0.9681611438561438, 'overlap rate': 0.9867461202686203}
#
# Current epoch: 420,
# training performance: {'loss': 0.0015580179227981717, 'full sequence accuracy': 0.9999, 'first n-symbol accuracy': 0.99995625, 'overlap rate': 0.9999874999999999}
# evaluation performance: {'loss': 0.14445140751777216, 'full sequence accuracy': 0.9141, 'first n-symbol accuracy': 0.9637892766955266, 'overlap rate': 0.9855608542846044}
#
# Current epoch: 430,
# training performance: {'loss': 0.0008229696599300951, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1255024581507314, 'full sequence accuracy': 0.9216000000000001, 'first n-symbol accuracy': 0.9707575874125874, 'overlap rate': 0.9877105121267622}
#
# Current epoch: 440,
# training performance: {'loss': 0.0005945371580310166, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.10904865812044591, 'full sequence accuracy': 0.9296, 'first n-symbol accuracy': 0.975854455960706, 'overlap rate': 0.9893828710178709}
#
# Current epoch: 450,
# training performance: {'loss': 0.0005553325769142248, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.10658104012254625, 'full sequence accuracy': 0.93, 'first n-symbol accuracy': 0.9766640942390943, 'overlap rate': 0.9895761677211679}
#
# Current epoch: 460,
# training performance: {'loss': 0.0005397586384788156, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.10566205107606948, 'full sequence accuracy': 0.9307000000000001, 'first n-symbol accuracy': 0.9774951702464202, 'overlap rate': 0.9897039744977244}
#
# Current epoch: 470,
# training performance: {'loss': 0.0005346444406313822, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1046348787844181, 'full sequence accuracy': 0.9311, 'first n-symbol accuracy': 0.9778449046786548, 'overlap rate': 0.9898033197358197}
#
# Current epoch: 480,
# training performance: {'loss': 0.0005347198166418821, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.10451807933859528, 'full sequence accuracy': 0.9314, 'first n-symbol accuracy': 0.9780001473526475, 'overlap rate': 0.9898040798090799}
#
# Current epoch: 490,
# training performance: {'loss': 0.0005372846295358613, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.10359965809620916, 'full sequence accuracy': 0.9317, 'first n-symbol accuracy': 0.9782407317682319, 'overlap rate': 0.9898039932289932}
#
# Current epoch: 500,
# training performance: {'loss': 0.0005407953896792606, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.1043234677053988, 'full sequence accuracy': 0.9312999999999999, 'first n-symbol accuracy': 0.9781377006327008, 'overlap rate': 0.9897375371850371}
#
# experiments/rev/LSTM/attn-less/3/model.pt saved!
#
# experiments/rev/LSTM/attn-less/3/training_log.json saved!
# experiments/rev/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/rev/LSTM/attn-less/3/training_plot.png saved!
# experiments/rev/LSTM/attn-less/3/perfs_train.json saved!
# experiments/rev/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/rev/LSTM/attn-less/3/perfs_test.json saved!
# experiments/rev/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/rev/LSTM/attn-less/3/perfs_train.png saved!
# experiments/rev/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/rev/LSTM/attn-less/3/perfs_test.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
