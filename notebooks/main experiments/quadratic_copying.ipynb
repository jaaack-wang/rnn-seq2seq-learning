# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-05-30 01:25:39

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/quad_copy")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder,
                                            out_seq_encoder,
                                            padding_idx=1,
                                            batch_size=1000,
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "quadratic_copying"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss",
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):

            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")

            embd_dim = 128
            hidden_size = 512
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500

            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols
                           "reduction_method": "sum"}

            model = get_model(ModelConfig)

            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)

            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl,
                                     criterion, optimizer,
                                     saved_model_fp=saved_model_fp,
                                     acc_threshold=-0.1,
                                     print_eval_freq=10,
                                     max_epoch_num=max_epoch_num,
                                     train_exit_acc=0.9999,
                                     eval_exit_acc=0.995,
                                     teacher_forcing_ratio=1.0)

            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))

            train_res, dev_res = get_results(log, train_log=True)

            _, perfs_train = evaluate(model, train_dl, criterion,
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion,
                                      per_seq_len_performance=True)

            test_aggr, perfs_test = evaluate(model, test_dl, criterion,
                                             per_seq_len_performance=True)

            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion,
                                             per_seq_len_performance=True)

            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)

            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)


            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))

            clear_output(wait=True)

        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,176,476 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.4682986974716186, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0005033026478856396, 'overlap rate': 0.04013887532645792}
# evaluation performance: {'loss': 3.468750739097595, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.000481419636041418, 'overlap rate': 0.04044837529868868}
#
# Current epoch: 20,
# training performance: {'loss': 3.7386952877044677, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0024425364812736975, 'overlap rate': 0.11728174937251701}
# evaluation performance: {'loss': 3.763172459602356, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0022681662116209784, 'overlap rate': 0.11571209854456843}
#
# Current epoch: 30,
# training performance: {'loss': 3.6901175737380982, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0039906480092911974, 'overlap rate': 0.1145148873995873}
# evaluation performance: {'loss': 3.708730697631836, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0038465083763182415, 'overlap rate': 0.11285857540974878}
#
# Current epoch: 40,
# training performance: {'loss': 4.133606338500977, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.007879137537724696, 'overlap rate': 0.11784918194122715}
# evaluation performance: {'loss': 4.1489269733428955, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.007744574918078187, 'overlap rate': 0.1154176661113702}
#
# Current epoch: 50,
# training performance: {'loss': 4.711594295501709, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.008813876942401613, 'overlap rate': 0.10301443904463155}
# evaluation performance: {'loss': 4.726950454711914, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.008530216633746219, 'overlap rate': 0.10156204973368115}
#
# Current epoch: 60,
# training performance: {'loss': 5.071607446670532, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0106226652675516, 'overlap rate': 0.11480950558278953}
# evaluation performance: {'loss': 5.097089529037476, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.010388114451753663, 'overlap rate': 0.11232937717578095}
#
# Current epoch: 70,
# training performance: {'loss': 5.529933118820191, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.016409453085067093, 'overlap rate': 0.12335158419394254}
# evaluation performance: {'loss': 5.552707004547119, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.016321701806231353, 'overlap rate': 0.12203667913170446}
#
# Current epoch: 80,
# training performance: {'loss': 5.840088844299316, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.03094798134612418, 'overlap rate': 0.14596991222409}
# evaluation performance: {'loss': 5.868152379989624, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.029315642504377994, 'overlap rate': 0.14236490281504147}
#
# Current epoch: 90,
# training performance: {'loss': 6.050106620788574, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.0437806849413772, 'overlap rate': 0.16535075205069638}
# evaluation performance: {'loss': 6.0994065284729, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.040364178845917656, 'overlap rate': 0.15968241973930056}
#
# Current epoch: 100,
# training performance: {'loss': 5.730718183517456, 'full sequence accuracy': 0.0002, 'first n-symbol accuracy': 0.06956413345919006, 'overlap rate': 0.20558450755680627}
# evaluation performance: {'loss': 5.810948038101197, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.06189795493485696, 'overlap rate': 0.1947465625258433}
#
# Current epoch: 110,
# training performance: {'loss': 5.704674744606018, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.11050768982632994, 'overlap rate': 0.2628820599552276}
# evaluation performance: {'loss': 5.866096496582031, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.09975049705423689, 'overlap rate': 0.24694225374374956}
#
# Current epoch: 120,
# training performance: {'loss': 5.316077041625976, 'full sequence accuracy': 0.00030000000000000003, 'first n-symbol accuracy': 0.18439797481016365, 'overlap rate': 0.34780360828417345}
# evaluation performance: {'loss': 5.541961073875427, 'full sequence accuracy': 0.0005, 'first n-symbol accuracy': 0.16225489661009754, 'overlap rate': 0.32370091938412093}
#
# Current epoch: 130,
# training performance: {'loss': 5.542674875259399, 'full sequence accuracy': 0.0021000000000000003, 'first n-symbol accuracy': 0.16859279947863795, 'overlap rate': 0.3472093305692279}
# evaluation performance: {'loss': 5.809506750106811, 'full sequence accuracy': 0.0015000000000000002, 'first n-symbol accuracy': 0.14838081349834498, 'overlap rate': 0.3215718939451566}
#
# Current epoch: 140,
# training performance: {'loss': 5.0052014827728275, 'full sequence accuracy': 0.009400000000000002, 'first n-symbol accuracy': 0.23475161740993994, 'overlap rate': 0.4127232177618203}
# evaluation performance: {'loss': 5.323368930816651, 'full sequence accuracy': 0.006200000000000001, 'first n-symbol accuracy': 0.2061829826441485, 'overlap rate': 0.38001441257983537}
#
# Current epoch: 150,
# training performance: {'loss': 4.756580650806427, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.27915261351540765, 'overlap rate': 0.45845478328484746}
# evaluation performance: {'loss': 5.16263622045517, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.24435698771230657, 'overlap rate': 0.41878705337964617}
#
# Current epoch: 160,
# training performance: {'loss': 4.744344246387482, 'full sequence accuracy': 0.0091, 'first n-symbol accuracy': 0.2853673926028277, 'overlap rate': 0.4645138606642023}
# evaluation performance: {'loss': 5.206725692749023, 'full sequence accuracy': 0.0051, 'first n-symbol accuracy': 0.2466273036191488, 'overlap rate': 0.4192772244039114}
#
# Current epoch: 170,
# training performance: {'loss': 3.7059534013271334, 'full sequence accuracy': 0.005699999999999999, 'first n-symbol accuracy': 0.4225794567787471, 'overlap rate': 0.58175588447087}
# evaluation performance: {'loss': 4.412045061588287, 'full sequence accuracy': 0.0037000000000000006, 'first n-symbol accuracy': 0.34731514699419264, 'overlap rate': 0.511145771349409}
#
# Current epoch: 180,
# training performance: {'loss': 4.018331211805344, 'full sequence accuracy': 0.044000000000000004, 'first n-symbol accuracy': 0.384200300292319, 'overlap rate': 0.5639062219785713}
# evaluation performance: {'loss': 4.745234787464142, 'full sequence accuracy': 0.0228, 'first n-symbol accuracy': 0.3157769882575216, 'overlap rate': 0.49352414420130436}
#
# Current epoch: 190,
# training performance: {'loss': 3.0739747643470765, 'full sequence accuracy': 0.014400000000000001, 'first n-symbol accuracy': 0.5217933554156557, 'overlap rate': 0.6650917660790834}
# evaluation performance: {'loss': 4.023396223783493, 'full sequence accuracy': 0.0076, 'first n-symbol accuracy': 0.42002440553846015, 'overlap rate': 0.5724523004261788}
#
# Current epoch: 200,
# training performance: {'loss': 3.7447282910346984, 'full sequence accuracy': 0.06200000000000001, 'first n-symbol accuracy': 0.41370862578617834, 'overlap rate': 0.6010270315853413}
# evaluation performance: {'loss': 4.627604520320892, 'full sequence accuracy': 0.0357, 'first n-symbol accuracy': 0.32837972379980557, 'overlap rate': 0.517338136562775}
#
# Current epoch: 210,
# training performance: {'loss': 4.439657664299011, 'full sequence accuracy': 0.0888, 'first n-symbol accuracy': 0.39372971368549825, 'overlap rate': 0.5496149081505681}
# evaluation performance: {'loss': 5.2290283203125, 'full sequence accuracy': 0.0533, 'first n-symbol accuracy': 0.32145912876926713, 'overlap rate': 0.474395617621315}
#
# Current epoch: 220,
# training performance: {'loss': 3.0888417661190033, 'full sequence accuracy': 0.091, 'first n-symbol accuracy': 0.5278227436843126, 'overlap rate': 0.6764942709747863}
# evaluation performance: {'loss': 4.3639160871505736, 'full sequence accuracy': 0.054000000000000006, 'first n-symbol accuracy': 0.3959952195683237, 'overlap rate': 0.557434390611762}
#
# Current epoch: 230,
# training performance: {'loss': 1.830053873360157, 'full sequence accuracy': 0.15019999999999997, 'first n-symbol accuracy': 0.6944951771489803, 'overlap rate': 0.807877455091664}
# evaluation performance: {'loss': 3.4296335950493813, 'full sequence accuracy': 0.0826, 'first n-symbol accuracy': 0.5012977969347135, 'overlap rate': 0.6552932284150333}
#
# Current epoch: 240,
# training performance: {'loss': 2.543667281419039, 'full sequence accuracy': 0.10959999999999999, 'first n-symbol accuracy': 0.6018254338509088, 'overlap rate': 0.743176269703415}
# evaluation performance: {'loss': 3.9281944274902343, 'full sequence accuracy': 0.0551, 'first n-symbol accuracy': 0.4536294561056226, 'overlap rate': 0.6150646912333955}
#
# Current epoch: 250,
# training performance: {'loss': 2.5696991950273516, 'full sequence accuracy': 0.095, 'first n-symbol accuracy': 0.6089550243468795, 'overlap rate': 0.7419211821010084}
# evaluation performance: {'loss': 4.014561992883682, 'full sequence accuracy': 0.0465, 'first n-symbol accuracy': 0.4638948476979069, 'overlap rate': 0.6097745466573056}
#
# Current epoch: 260,
# training performance: {'loss': 2.2419626712799072, 'full sequence accuracy': 0.23769999999999997, 'first n-symbol accuracy': 0.6426727002368983, 'overlap rate': 0.7757170240334351}
# evaluation performance: {'loss': 3.8259960770606996, 'full sequence accuracy': 0.14139999999999997, 'first n-symbol accuracy': 0.47240100068712987, 'overlap rate': 0.6297699722083007}
#
# Current epoch: 270,
# training performance: {'loss': 2.156940884888172, 'full sequence accuracy': 0.023, 'first n-symbol accuracy': 0.6547187383911816, 'overlap rate': 0.78555164588949}
# evaluation performance: {'loss': 3.8059122025966645, 'full sequence accuracy': 0.0105, 'first n-symbol accuracy': 0.47488756123875664, 'overlap rate': 0.6390423980712554}
#
# Current epoch: 280,
# training performance: {'loss': 1.8664382576942444, 'full sequence accuracy': 0.14819999999999997, 'first n-symbol accuracy': 0.706681395896393, 'overlap rate': 0.8031928357091067}
# evaluation performance: {'loss': 3.737905877828598, 'full sequence accuracy': 0.096, 'first n-symbol accuracy': 0.4817127935427953, 'overlap rate': 0.6385629093614711}
#
# Current epoch: 290,
# training performance: {'loss': 1.571041052788496, 'full sequence accuracy': 0.39069999999999994, 'first n-symbol accuracy': 0.7442591238582648, 'overlap rate': 0.8460487916652457}
# evaluation performance: {'loss': 3.518326696753502, 'full sequence accuracy': 0.2326, 'first n-symbol accuracy': 0.5137479003364518, 'overlap rate': 0.6719918990578808}
#
# Current epoch: 300,
# training performance: {'loss': 3.0169434189796447, 'full sequence accuracy': 0.164, 'first n-symbol accuracy': 0.5977833427916639, 'overlap rate': 0.7224436520635449}
# evaluation performance: {'loss': 4.875627899169922, 'full sequence accuracy': 0.10799999999999998, 'first n-symbol accuracy': 0.4183456756468056, 'overlap rate': 0.565306588145953}
#
# Current epoch: 310,
# training performance: {'loss': 1.1700305009260774, 'full sequence accuracy': 0.5399999999999999, 'first n-symbol accuracy': 0.8095864970791714, 'overlap rate': 0.8849791552549926}
# evaluation performance: {'loss': 3.284669964015484, 'full sequence accuracy': 0.305, 'first n-symbol accuracy': 0.5544471567822974, 'overlap rate': 0.6989482023247172}
#
# Current epoch: 320,
# training performance: {'loss': 1.8286749556660653, 'full sequence accuracy': 0.4655, 'first n-symbol accuracy': 0.6963069402451335, 'overlap rate': 0.8286982682232459}
# evaluation performance: {'loss': 3.7990300387144087, 'full sequence accuracy': 0.28109999999999996, 'first n-symbol accuracy': 0.4833933559253928, 'overlap rate': 0.6600704388448746}
#
# Current epoch: 330,
# training performance: {'loss': 2.154863618314266, 'full sequence accuracy': 0.2742, 'first n-symbol accuracy': 0.6635123078068984, 'overlap rate': 0.7997061390852555}
# evaluation performance: {'loss': 3.9846026480197905, 'full sequence accuracy': 0.17149999999999996, 'first n-symbol accuracy': 0.4751993273207068, 'overlap rate': 0.6433297318246028}
#
# Current epoch: 340,
# training performance: {'loss': 1.539649450033903, 'full sequence accuracy': 0.27849999999999997, 'first n-symbol accuracy': 0.7456389773373736, 'overlap rate': 0.8562021505629515}
# evaluation performance: {'loss': 3.518530622124672, 'full sequence accuracy': 0.1807, 'first n-symbol accuracy': 0.5256076641610357, 'overlap rate': 0.6888959551344016}
#
# Current epoch: 350,
# training performance: {'loss': 1.3126361325383187, 'full sequence accuracy': 0.1511, 'first n-symbol accuracy': 0.7705991488913818, 'overlap rate': 0.8741912302941545}
# evaluation performance: {'loss': 3.3338095113635062, 'full sequence accuracy': 0.09950000000000002, 'first n-symbol accuracy': 0.5307547145313298, 'overlap rate': 0.6992905618979944}
#
# Current epoch: 360,
# training performance: {'loss': 1.360418063029647, 'full sequence accuracy': 0.41900000000000004, 'first n-symbol accuracy': 0.764655541183924, 'overlap rate': 0.8675345532963652}
# evaluation performance: {'loss': 3.4310475885868073, 'full sequence accuracy': 0.2136, 'first n-symbol accuracy': 0.5159768347882502, 'overlap rate': 0.6890513402798932}
#
# Current epoch: 370,
# training performance: {'loss': 0.8221885088831187, 'full sequence accuracy': 0.0649, 'first n-symbol accuracy': 0.8586559482314573, 'overlap rate': 0.9188852390973266}
# evaluation performance: {'loss': 3.149652545154095, 'full sequence accuracy': 0.029700000000000004, 'first n-symbol accuracy': 0.5648563766988263, 'overlap rate': 0.719785521425013}
#
# Current epoch: 380,
# training performance: {'loss': 1.141134750843048, 'full sequence accuracy': 0.4144, 'first n-symbol accuracy': 0.8158807272961708, 'overlap rate': 0.885731430107431}
# evaluation performance: {'loss': 3.4343487352132795, 'full sequence accuracy': 0.24519999999999995, 'first n-symbol accuracy': 0.5466649670904535, 'overlap rate': 0.6966217656421494}
#
# Current epoch: 390,
# training performance: {'loss': 0.9981791220605374, 'full sequence accuracy': 0.3386, 'first n-symbol accuracy': 0.8283414040255617, 'overlap rate': 0.9069165801507472}
# evaluation performance: {'loss': 3.3666519314050674, 'full sequence accuracy': 0.1941, 'first n-symbol accuracy': 0.5420945156396416, 'overlap rate': 0.7085278331209038}
#
# Current epoch: 400,
# training performance: {'loss': 1.023467722721398, 'full sequence accuracy': 0.5065999999999999, 'first n-symbol accuracy': 0.8281168605649686, 'overlap rate': 0.9036210982958709}
# evaluation performance: {'loss': 3.526828020811081, 'full sequence accuracy': 0.23689999999999997, 'first n-symbol accuracy': 0.5265919746367829, 'overlap rate': 0.6953506811108673}
#
# Current epoch: 410,
# training performance: {'loss': 0.8201062311418355, 'full sequence accuracy': 0.5568000000000001, 'first n-symbol accuracy': 0.8634093688481771, 'overlap rate': 0.9208962615523933}
# evaluation performance: {'loss': 3.264244744181633, 'full sequence accuracy': 0.2725, 'first n-symbol accuracy': 0.5641338292262892, 'overlap rate': 0.7182739084862175}
#
# Current epoch: 420,
# training performance: {'loss': 0.9320870950818062, 'full sequence accuracy': 0.24389999999999995, 'first n-symbol accuracy': 0.8345144934425328, 'overlap rate': 0.9131579919517885}
# evaluation performance: {'loss': 3.516650158166885, 'full sequence accuracy': 0.15829999999999997, 'first n-symbol accuracy': 0.5220564033618256, 'overlap rate': 0.7000112324780394}
#
# Current epoch: 430,
# training performance: {'loss': 1.1080556124448777, 'full sequence accuracy': 0.362, 'first n-symbol accuracy': 0.8239600115086917, 'overlap rate': 0.8890925974228946}
# evaluation performance: {'loss': 3.483303129673004, 'full sequence accuracy': 0.24420000000000003, 'first n-symbol accuracy': 0.5404587322847318, 'overlap rate': 0.7004249113487914}
#
# Current epoch: 440,
# training performance: {'loss': 0.9357987472787499, 'full sequence accuracy': 0.10729999999999998, 'first n-symbol accuracy': 0.8396527718189765, 'overlap rate': 0.9123523748019136}
# evaluation performance: {'loss': 3.1677017390727995, 'full sequence accuracy': 0.0518, 'first n-symbol accuracy': 0.5653634410722808, 'overlap rate': 0.7285642530893769}
#
# Current epoch: 450,
# training performance: {'loss': 1.4502926081418992, 'full sequence accuracy': 0.1806, 'first n-symbol accuracy': 0.7782780060564334, 'overlap rate': 0.8730495480469582}
# evaluation performance: {'loss': 3.9784205853939056, 'full sequence accuracy': 0.10449999999999997, 'first n-symbol accuracy': 0.5082234465495884, 'overlap rate': 0.6742233561286364}
#
# Current epoch: 460,
# training performance: {'loss': 1.1480160176753997, 'full sequence accuracy': 0.41159999999999997, 'first n-symbol accuracy': 0.8065821149130263, 'overlap rate': 0.8891736846709823}
# evaluation performance: {'loss': 3.3280757129192353, 'full sequence accuracy': 0.25339999999999996, 'first n-symbol accuracy': 0.5461142546541398, 'overlap rate': 0.7140837550575247}
#
# Current epoch: 470,
# training performance: {'loss': 0.7448389382101596, 'full sequence accuracy': 0.23829999999999996, 'first n-symbol accuracy': 0.8646544520303756, 'overlap rate': 0.9302652610145359}
# evaluation performance: {'loss': 3.0816330701112746, 'full sequence accuracy': 0.13149999999999998, 'first n-symbol accuracy': 0.5797768207338796, 'overlap rate': 0.7393920104025592}
#
# Current epoch: 480,
# training performance: {'loss': 1.1026404440402984, 'full sequence accuracy': 0.42869999999999997, 'first n-symbol accuracy': 0.8276201624565832, 'overlap rate': 0.8964244494934276}
# evaluation performance: {'loss': 3.517321228981018, 'full sequence accuracy': 0.21719999999999998, 'first n-symbol accuracy': 0.5409849780694844, 'overlap rate': 0.7037034897626472}
#
# Current epoch: 490,
# training performance: {'loss': 0.8657985366880894, 'full sequence accuracy': 0.32510000000000006, 'first n-symbol accuracy': 0.8386783680965184, 'overlap rate': 0.9186160722358567}
# evaluation performance: {'loss': 3.3218469589948656, 'full sequence accuracy': 0.1177, 'first n-symbol accuracy': 0.5495219601493646, 'overlap rate': 0.7222661196482763}
#
# Current epoch: 500,
# training performance: {'loss': 0.5198596368543804, 'full sequence accuracy': 0.2969, 'first n-symbol accuracy': 0.8984968620427445, 'overlap rate': 0.9512278391724658}
# evaluation performance: {'loss': 2.986682902276516, 'full sequence accuracy': 0.17399999999999996, 'first n-symbol accuracy': 0.5876036279733355, 'overlap rate': 0.7540608691544208}
#
# experiments/quadratic_copying/LSTM/attn-less/3/model.pt saved!
#
# experiments/quadratic_copying/LSTM/attn-less/3/training_log.json saved!
# experiments/quadratic_copying/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/quadratic_copying/LSTM/attn-less/3/training_plot.png saved!
# experiments/quadratic_copying/LSTM/attn-less/3/perfs_train.json saved!
# experiments/quadratic_copying/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/quadratic_copying/LSTM/attn-less/3/perfs_test.json saved!
# experiments/quadratic_copying/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/quadratic_copying/LSTM/attn-less/3/perfs_train.png saved!
# experiments/quadratic_copying/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/quadratic_copying/LSTM/attn-less/3/perfs_test.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
