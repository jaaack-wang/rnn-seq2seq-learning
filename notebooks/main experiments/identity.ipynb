# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-01-22 15:57:46

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/identity")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "identity"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 512
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,176,476 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.235386276245117, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.004893053474303475, 'overlap rate': 0.11254611874236872}
# evaluation performance: {'loss': 3.2357147216796873, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00445189060939061, 'overlap rate': 0.11230248501498503}
#
# Current epoch: 20,
# training performance: {'loss': 3.1543392896652223, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.0057805207292707305, 'overlap rate': 0.1271943346930847}
# evaluation performance: {'loss': 3.1556463956832888, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.00560437173937174, 'overlap rate': 0.12496955072705074}
#
# Current epoch: 30,
# training performance: {'loss': 3.0015143871307375, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.015523555611055609, 'overlap rate': 0.14865846944721944}
# evaluation performance: {'loss': 3.004912185668945, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.014678369130869132, 'overlap rate': 0.14656665084915083}
#
# Current epoch: 40,
# training performance: {'loss': 2.8578408479690554, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.031197250943500947, 'overlap rate': 0.1788942381229881}
# evaluation performance: {'loss': 2.864025616645813, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03100686840936841, 'overlap rate': 0.17669583805083802}
#
# Current epoch: 50,
# training performance: {'loss': 2.692250299453735, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.05518262459762459, 'overlap rate': 0.20441099886224884}
# evaluation performance: {'loss': 2.7037760734558107, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.054003682567432564, 'overlap rate': 0.20228032786657785}
#
# Current epoch: 60,
# training performance: {'loss': 2.380433750152588, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.10782146450771453, 'overlap rate': 0.2732953984903985}
# evaluation performance: {'loss': 2.403949248790741, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.10376800019425021, 'overlap rate': 0.26647648976023974}
#
# Current epoch: 70,
# training performance: {'loss': 2.151831316947937, 'full sequence accuracy': 0.0013, 'first n-symbol accuracy': 0.1617360173160173, 'overlap rate': 0.34664349983349985}
# evaluation performance: {'loss': 2.1862655520439147, 'full sequence accuracy': 0.0008, 'first n-symbol accuracy': 0.15681147061272063, 'overlap rate': 0.3375403273115773}
#
# Current epoch: 80,
# training performance: {'loss': 2.0482097983360292, 'full sequence accuracy': 0.017400000000000002, 'first n-symbol accuracy': 0.21208666791541794, 'overlap rate': 0.4068915082140082}
# evaluation performance: {'loss': 2.0942251682281494, 'full sequence accuracy': 0.011800000000000001, 'first n-symbol accuracy': 0.20126737623487628, 'overlap rate': 0.3953665660728161}
#
# Current epoch: 90,
# training performance: {'loss': 2.0009524703025816, 'full sequence accuracy': 0.0097, 'first n-symbol accuracy': 0.22753075965700967, 'overlap rate': 0.42961887667887666}
# evaluation performance: {'loss': 2.044796550273895, 'full sequence accuracy': 0.009700000000000002, 'first n-symbol accuracy': 0.21829683108558107, 'overlap rate': 0.4179556222943723}
#
# Current epoch: 100,
# training performance: {'loss': 1.9664526462554932, 'full sequence accuracy': 0.0029000000000000002, 'first n-symbol accuracy': 0.33091285908535906, 'overlap rate': 0.48705406371406373}
# evaluation performance: {'loss': 2.0374516606330872, 'full sequence accuracy': 0.0033, 'first n-symbol accuracy': 0.3081472867410367, 'overlap rate': 0.4669636514874015}
#
# Current epoch: 110,
# training performance: {'loss': 1.8782004594802857, 'full sequence accuracy': 0.0403, 'first n-symbol accuracy': 0.3077562672050172, 'overlap rate': 0.5136029237429237}
# evaluation performance: {'loss': 1.9423433065414428, 'full sequence accuracy': 0.032600000000000004, 'first n-symbol accuracy': 0.2905816085303585, 'overlap rate': 0.49786053238428235}
#
# Current epoch: 120,
# training performance: {'loss': 1.6958285570144653, 'full sequence accuracy': 0.11349999999999996, 'first n-symbol accuracy': 0.4022644746919746, 'overlap rate': 0.5930620546120547}
# evaluation performance: {'loss': 1.7812662541866302, 'full sequence accuracy': 0.09740000000000001, 'first n-symbol accuracy': 0.37982354714729716, 'overlap rate': 0.5720999492174492}
#
# Current epoch: 130,
# training performance: {'loss': 1.6314768195152283, 'full sequence accuracy': 0.1276, 'first n-symbol accuracy': 0.42030397311022305, 'overlap rate': 0.6168404692529693}
# evaluation performance: {'loss': 1.739661568403244, 'full sequence accuracy': 0.10559999999999996, 'first n-symbol accuracy': 0.3884514062326562, 'overlap rate': 0.5906438227050728}
#
# Current epoch: 140,
# training performance: {'loss': 1.5203043222427368, 'full sequence accuracy': 0.1919, 'first n-symbol accuracy': 0.4751513388000889, 'overlap rate': 0.6637450793650793}
# evaluation performance: {'loss': 1.6454307854175567, 'full sequence accuracy': 0.1606, 'first n-symbol accuracy': 0.43758511349761353, 'overlap rate': 0.6349056457431458}
#
# Current epoch: 150,
# training performance: {'loss': 1.4133883148431778, 'full sequence accuracy': 0.23769999999999997, 'first n-symbol accuracy': 0.5444062827450328, 'overlap rate': 0.7022665823065822}
# evaluation performance: {'loss': 1.553187358379364, 'full sequence accuracy': 0.2002, 'first n-symbol accuracy': 0.5041275235875237, 'overlap rate': 0.6733174485236985}
#
# Current epoch: 160,
# training performance: {'loss': 1.3598331958055496, 'full sequence accuracy': 0.25680000000000003, 'first n-symbol accuracy': 0.559704203019203, 'overlap rate': 0.7289741329503829}
# evaluation performance: {'loss': 1.541890126466751, 'full sequence accuracy': 0.20389999999999997, 'first n-symbol accuracy': 0.51192068986569, 'overlap rate': 0.6909611899211899}
#
# Current epoch: 170,
# training performance: {'loss': 1.2843459367752075, 'full sequence accuracy': 0.2851, 'first n-symbol accuracy': 0.6007494008769009, 'overlap rate': 0.7489514407814408}
# evaluation performance: {'loss': 1.4531428575515748, 'full sequence accuracy': 0.2383, 'first n-symbol accuracy': 0.5563729005716506, 'overlap rate': 0.7154640917415919}
#
# Current epoch: 180,
# training performance: {'loss': 1.0032396838068962, 'full sequence accuracy': 0.4144, 'first n-symbol accuracy': 0.6789997342934844, 'overlap rate': 0.8106923115773116}
# evaluation performance: {'loss': 1.2533297806978225, 'full sequence accuracy': 0.32009999999999994, 'first n-symbol accuracy': 0.606637521922522, 'overlap rate': 0.7631109317071816}
#
# Current epoch: 190,
# training performance: {'loss': 1.0494714990258216, 'full sequence accuracy': 0.426, 'first n-symbol accuracy': 0.6585099277111778, 'overlap rate': 0.80841141011766}
# evaluation performance: {'loss': 1.3281620681285857, 'full sequence accuracy': 0.3218, 'first n-symbol accuracy': 0.5851276406926408, 'overlap rate': 0.7574521063658565}
#
# Current epoch: 200,
# training performance: {'loss': 1.1422232538461685, 'full sequence accuracy': 0.4154000000000001, 'first n-symbol accuracy': 0.6358278830891331, 'overlap rate': 0.7962533032245533}
# evaluation performance: {'loss': 1.3957897931337357, 'full sequence accuracy': 0.32660000000000006, 'first n-symbol accuracy': 0.5714381303418803, 'overlap rate': 0.7505557564657566}
#
# Current epoch: 210,
# training performance: {'loss': 0.8578637212514877, 'full sequence accuracy': 0.5114000000000001, 'first n-symbol accuracy': 0.7359375931013431, 'overlap rate': 0.8511464496614497}
# evaluation performance: {'loss': 1.1603754594922067, 'full sequence accuracy': 0.3913000000000001, 'first n-symbol accuracy': 0.6552903588078587, 'overlap rate': 0.798890072982573}
#
# Current epoch: 220,
# training performance: {'loss': 0.8151322737336159, 'full sequence accuracy': 0.5137, 'first n-symbol accuracy': 0.7649074023199023, 'overlap rate': 0.8641697333222333}
# evaluation performance: {'loss': 1.1468182906508446, 'full sequence accuracy': 0.39609999999999995, 'first n-symbol accuracy': 0.6828518602231102, 'overlap rate': 0.8089665902153401}
#
# Current epoch: 230,
# training performance: {'loss': 1.0421019956469535, 'full sequence accuracy': 0.4535, 'first n-symbol accuracy': 0.6869497161172161, 'overlap rate': 0.8346500846375846}
# evaluation performance: {'loss': 1.334886646270752, 'full sequence accuracy': 0.35960000000000003, 'first n-symbol accuracy': 0.6209101756576756, 'overlap rate': 0.783996045066045}
#
# Current epoch: 240,
# training performance: {'loss': 0.803205618262291, 'full sequence accuracy': 0.564, 'first n-symbol accuracy': 0.7695666163003663, 'overlap rate': 0.8771139343989344}
# evaluation performance: {'loss': 1.1453634701669215, 'full sequence accuracy': 0.42990000000000006, 'first n-symbol accuracy': 0.6903738057775558, 'overlap rate': 0.8218545826395827}
#
# Current epoch: 250,
# training performance: {'loss': 0.818685756623745, 'full sequence accuracy': 0.5502, 'first n-symbol accuracy': 0.7542976078088579, 'overlap rate': 0.8702266570929071}
# evaluation performance: {'loss': 1.1806804150342942, 'full sequence accuracy': 0.4192, 'first n-symbol accuracy': 0.6642840166777667, 'overlap rate': 0.8118857940670441}
#
# Current epoch: 260,
# training performance: {'loss': 0.5218484289944172, 'full sequence accuracy': 0.6974, 'first n-symbol accuracy': 0.8443723880286381, 'overlap rate': 0.9224186659174161}
# evaluation performance: {'loss': 0.9815074786543846, 'full sequence accuracy': 0.5012, 'first n-symbol accuracy': 0.7301667904317906, 'overlap rate': 0.8525001266788769}
#
# Current epoch: 270,
# training performance: {'loss': 0.8420088890939951, 'full sequence accuracy': 0.5462, 'first n-symbol accuracy': 0.7645173816461316, 'overlap rate': 0.8776457647907648}
# evaluation performance: {'loss': 1.233410220593214, 'full sequence accuracy': 0.4203, 'first n-symbol accuracy': 0.6789715248640248, 'overlap rate': 0.8191611242923743}
#
# Current epoch: 280,
# training performance: {'loss': 0.7968185603618622, 'full sequence accuracy': 0.5776, 'first n-symbol accuracy': 0.7571711877011877, 'overlap rate': 0.8829879865967365}
# evaluation performance: {'loss': 1.2413373842835427, 'full sequence accuracy': 0.41240000000000004, 'first n-symbol accuracy': 0.6474832821345322, 'overlap rate': 0.8144848852536353}
#
# Current epoch: 290,
# training performance: {'loss': 0.6741474617272616, 'full sequence accuracy': 0.6235000000000002, 'first n-symbol accuracy': 0.8057626781551782, 'overlap rate': 0.904106323953824}
# evaluation performance: {'loss': 1.1108812153339387, 'full sequence accuracy': 0.45450000000000007, 'first n-symbol accuracy': 0.7033006894494395, 'overlap rate': 0.8389223802586303}
#
# Current epoch: 300,
# training performance: {'loss': 0.4691102795302868, 'full sequence accuracy': 0.7248000000000001, 'first n-symbol accuracy': 0.8679754195804197, 'overlap rate': 0.935798091075591}
# evaluation performance: {'loss': 0.9588443592190743, 'full sequence accuracy': 0.5246, 'first n-symbol accuracy': 0.7567201799589298, 'overlap rate': 0.866397814962815}
#
# Current epoch: 310,
# training performance: {'loss': 0.4189206914976239, 'full sequence accuracy': 0.7461, 'first n-symbol accuracy': 0.8715857639582639, 'overlap rate': 0.9425684071484071}
# evaluation performance: {'loss': 0.9478720471262931, 'full sequence accuracy': 0.5192, 'first n-symbol accuracy': 0.740641341020091, 'overlap rate': 0.8673140151515151}
#
# Current epoch: 320,
# training performance: {'loss': 0.6443446496501565, 'full sequence accuracy': 0.6462000000000001, 'first n-symbol accuracy': 0.8085140398490399, 'overlap rate': 0.9152548221223222}
# evaluation performance: {'loss': 1.1551262050867082, 'full sequence accuracy': 0.4616999999999999, 'first n-symbol accuracy': 0.6951660206460206, 'overlap rate': 0.8425379539904541}
#
# Current epoch: 330,
# training performance: {'loss': 0.3925170416012406, 'full sequence accuracy': 0.7744000000000001, 'first n-symbol accuracy': 0.884405148878899, 'overlap rate': 0.9503597166722167}
# evaluation performance: {'loss': 0.930638724565506, 'full sequence accuracy': 0.5426, 'first n-symbol accuracy': 0.7544813822288823, 'overlap rate': 0.8755400356587858}
#
# Current epoch: 340,
# training performance: {'loss': 0.2118150407448411, 'full sequence accuracy': 0.8703, 'first n-symbol accuracy': 0.9321228911366412, 'overlap rate': 0.9730814907314906}
# evaluation performance: {'loss': 0.7695644333958626, 'full sequence accuracy': 0.5941000000000001, 'first n-symbol accuracy': 0.7828892622655121, 'overlap rate': 0.8953782045732046}
#
# Current epoch: 350,
# training performance: {'loss': 0.3812375506386161, 'full sequence accuracy': 0.7817999999999999, 'first n-symbol accuracy': 0.8779313542013542, 'overlap rate': 0.9511258172383172}
# evaluation performance: {'loss': 0.9571892626583576, 'full sequence accuracy': 0.5346999999999998, 'first n-symbol accuracy': 0.734344421966922, 'overlap rate': 0.8721795899933401}
#
# Current epoch: 360,
# training performance: {'loss': 0.28415405955165624, 'full sequence accuracy': 0.8282, 'first n-symbol accuracy': 0.9117936093073592, 'overlap rate': 0.9645489989177488}
# evaluation performance: {'loss': 0.8577899411320686, 'full sequence accuracy': 0.5759000000000001, 'first n-symbol accuracy': 0.7725155022755023, 'overlap rate': 0.8884026480463982}
#
# Current epoch: 370,
# training performance: {'loss': 0.24185667969286442, 'full sequence accuracy': 0.8603, 'first n-symbol accuracy': 0.9317925019425018, 'overlap rate': 0.9717181895881897}
# evaluation performance: {'loss': 0.8278173137456178, 'full sequence accuracy': 0.5935, 'first n-symbol accuracy': 0.7927812458374959, 'overlap rate': 0.8963583258408259}
#
# Current epoch: 380,
# training performance: {'loss': 0.33687195954844357, 'full sequence accuracy': 0.8041, 'first n-symbol accuracy': 0.8964137172549673, 'overlap rate': 0.9597469759407259}
# evaluation performance: {'loss': 0.8926717150956393, 'full sequence accuracy': 0.5727, 'first n-symbol accuracy': 0.7704563690476192, 'overlap rate': 0.8862408911921411}
#
# Current epoch: 390,
# training performance: {'loss': 0.28236410142853857, 'full sequence accuracy': 0.8378, 'first n-symbol accuracy': 0.9122492754467755, 'overlap rate': 0.9666608483183484}
# evaluation performance: {'loss': 0.8750873349606991, 'full sequence accuracy': 0.5772, 'first n-symbol accuracy': 0.7672462896825396, 'overlap rate': 0.8889204476079475}
#
# Current epoch: 400,
# training performance: {'loss': 0.21366071300581096, 'full sequence accuracy': 0.8784000000000001, 'first n-symbol accuracy': 0.9289251023976023, 'overlap rate': 0.9750490279165278}
# evaluation performance: {'loss': 0.8236113935709, 'full sequence accuracy': 0.5958000000000001, 'first n-symbol accuracy': 0.7740139355089356, 'overlap rate': 0.8952752670940172}
#
# Current epoch: 410,
# training performance: {'loss': 0.1947867783717811, 'full sequence accuracy': 0.8928, 'first n-symbol accuracy': 0.9359995904095904, 'overlap rate': 0.9776059407259409}
# evaluation performance: {'loss': 0.7935728956013918, 'full sequence accuracy': 0.6059000000000001, 'first n-symbol accuracy': 0.7761864585414585, 'overlap rate': 0.8995335311910312}
#
# Current epoch: 420,
# training performance: {'loss': 0.11321450467221439, 'full sequence accuracy': 0.933, 'first n-symbol accuracy': 0.9679790275002776, 'overlap rate': 0.9879371864246863}
# evaluation performance: {'loss': 0.6970988934859633, 'full sequence accuracy': 0.643, 'first n-symbol accuracy': 0.8171090456765457, 'overlap rate': 0.9143755833055833}
#
# Current epoch: 430,
# training performance: {'loss': 0.12903313413262368, 'full sequence accuracy': 0.9284000000000001, 'first n-symbol accuracy': 0.9551626705239205, 'overlap rate': 0.9861368319180819}
# evaluation performance: {'loss': 0.6951135233044624, 'full sequence accuracy': 0.6427, 'first n-symbol accuracy': 0.8085572219447219, 'overlap rate': 0.9136855397380398}
#
# Current epoch: 440,
# training performance: {'loss': 0.16330674914643167, 'full sequence accuracy': 0.9089, 'first n-symbol accuracy': 0.9443639880952382, 'overlap rate': 0.9819387889887891}
# evaluation performance: {'loss': 0.727416312135756, 'full sequence accuracy': 0.6283000000000001, 'first n-symbol accuracy': 0.7931539596514596, 'overlap rate': 0.9093929360916861}
#
# Current epoch: 450,
# training performance: {'loss': 0.023014735453762113, 'full sequence accuracy': 0.9906000000000003, 'first n-symbol accuracy': 0.9953177755577757, 'overlap rate': 0.9984175283050284}
# evaluation performance: {'loss': 0.5731093846261501, 'full sequence accuracy': 0.6925000000000001, 'first n-symbol accuracy': 0.8471198677711179, 'overlap rate': 0.9303396493783994}
#
# Current epoch: 460,
# training performance: {'loss': 0.02085687757935375, 'full sequence accuracy': 0.9887, 'first n-symbol accuracy': 0.9962150686813187, 'overlap rate': 0.9984076282051282}
# evaluation performance: {'loss': 0.5545193335041404, 'full sequence accuracy': 0.7047, 'first n-symbol accuracy': 0.8545835875235873, 'overlap rate': 0.9338340473415474}
#
# Current epoch: 470,
# training performance: {'loss': 0.04730602337513119, 'full sequence accuracy': 0.9790000000000001, 'first n-symbol accuracy': 0.9872051406926408, 'overlap rate': 0.996035871905872}
# evaluation performance: {'loss': 0.5987340629100799, 'full sequence accuracy': 0.6856, 'first n-symbol accuracy': 0.8389593534243535, 'overlap rate': 0.9284496825396827}
#
# Current epoch: 480,
# training performance: {'loss': 0.0040507025667466225, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.44847135664895177, 'full sequence accuracy': 0.7556999999999999, 'first n-symbol accuracy': 0.8985604408091907, 'overlap rate': 0.9495763636363638}
#
# Current epoch: 490,
# training performance: {'loss': 0.002685799280880019, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.4330106426728889, 'full sequence accuracy': 0.7567999999999999, 'first n-symbol accuracy': 0.9028500836663337, 'overlap rate': 0.9515759473859475}
#
# Current epoch: 500,
# training performance: {'loss': 0.0023196332331281155, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.43684495356865227, 'full sequence accuracy': 0.7569999999999999, 'first n-symbol accuracy': 0.9049653567266066, 'overlap rate': 0.9517347585747586}
#
# experiments/identity/LSTM/attn-less/3/model.pt saved!
#
# experiments/identity/LSTM/attn-less/3/training_log.json saved!
# experiments/identity/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/identity/LSTM/attn-less/3/training_plot.png saved!
# experiments/identity/LSTM/attn-less/3/perfs_train.json saved!
# experiments/identity/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/identity/LSTM/attn-less/3/perfs_test.json saved!
# experiments/identity/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/identity/LSTM/attn-less/3/perfs_train.png saved!
# experiments/identity/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/identity/LSTM/attn-less/3/perfs_test.png saved!
# experiments/identity/LSTM/attn-less/3/perfs_gen.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
