# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-01-22 19:10:09

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/total_red")

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (10000, 10000, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "total_red"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 512
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,176,476 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 3.2739485263824464, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.002412917373197154, 'overlap rate': 0.08107688453096577}
# evaluation performance: {'loss': 3.275124263763428, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.002180175759411368, 'overlap rate': 0.07989070390917544}
#
# Current epoch: 20,
# training performance: {'loss': 3.023799180984497, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.009015560424122793, 'overlap rate': 0.14998817591158958}
# evaluation performance: {'loss': 3.031423473358154, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.009014932419571908, 'overlap rate': 0.14825768499738465}
#
# Current epoch: 30,
# training performance: {'loss': 2.865128254890442, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.011141996319803182, 'overlap rate': 0.1735681573628802}
# evaluation performance: {'loss': 2.8801276683807373, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.010751118001806921, 'overlap rate': 0.17072202081442345}
#
# Current epoch: 40,
# training performance: {'loss': 2.7508991956710815, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.015699167003267192, 'overlap rate': 0.17003261158740618}
# evaluation performance: {'loss': 2.768739914894104, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.015477754366433536, 'overlap rate': 0.1675334313080419}
#
# Current epoch: 50,
# training performance: {'loss': 2.659501624107361, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.024053225071627642, 'overlap rate': 0.1905344574480099}
# evaluation performance: {'loss': 2.6780466794967652, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.024459658981117925, 'overlap rate': 0.1898022530697089}
#
# Current epoch: 60,
# training performance: {'loss': 2.6649447679519653, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.03971088501422783, 'overlap rate': 0.19786553898887121}
# evaluation performance: {'loss': 2.683646821975708, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.039279016056756696, 'overlap rate': 0.1949220340478779}
#
# Current epoch: 70,
# training performance: {'loss': 2.696408748626709, 'full sequence accuracy': 0.0001, 'first n-symbol accuracy': 0.05106144578880254, 'overlap rate': 0.2236330145250199}
# evaluation performance: {'loss': 2.712348198890686, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.05085990664884197, 'overlap rate': 0.2204297982762767}
#
# Current epoch: 80,
# training performance: {'loss': 2.7941436529159547, 'full sequence accuracy': 0.0007, 'first n-symbol accuracy': 0.07272371092048391, 'overlap rate': 0.25061732390042585}
# evaluation performance: {'loss': 2.812215209007263, 'full sequence accuracy': 0.0005, 'first n-symbol accuracy': 0.07016525459809743, 'overlap rate': 0.24855964537869682}
#
# Current epoch: 90,
# training performance: {'loss': 2.6916842699050902, 'full sequence accuracy': 0.0017000000000000001, 'first n-symbol accuracy': 0.1305672465295568, 'overlap rate': 0.30411064680604044}
# evaluation performance: {'loss': 2.733068585395813, 'full sequence accuracy': 0.0012000000000000001, 'first n-symbol accuracy': 0.1236758990475629, 'overlap rate': 0.2951061657982545}
#
# Current epoch: 100,
# training performance: {'loss': 2.6188341856002806, 'full sequence accuracy': 0.030500000000000006, 'first n-symbol accuracy': 0.1607581044563996, 'overlap rate': 0.3596993294002049}
# evaluation performance: {'loss': 2.6763367533683775, 'full sequence accuracy': 0.0237, 'first n-symbol accuracy': 0.15040125272109559, 'overlap rate': 0.34749553197341604}
#
# Current epoch: 110,
# training performance: {'loss': 2.4323716282844545, 'full sequence accuracy': 0.0428, 'first n-symbol accuracy': 0.21804929850059684, 'overlap rate': 0.4158260089763385}
# evaluation performance: {'loss': 2.505970025062561, 'full sequence accuracy': 0.03660000000000001, 'first n-symbol accuracy': 0.20378335412470278, 'overlap rate': 0.3982649870525847}
#
# Current epoch: 120,
# training performance: {'loss': 2.564384162425995, 'full sequence accuracy': 0.0751, 'first n-symbol accuracy': 0.22515360633043682, 'overlap rate': 0.4347980569346858}
# evaluation performance: {'loss': 2.6590436458587647, 'full sequence accuracy': 0.060300000000000006, 'first n-symbol accuracy': 0.2048229179941456, 'overlap rate': 0.4146253571099332}
#
# Current epoch: 130,
# training performance: {'loss': 2.6298584580421447, 'full sequence accuracy': 0.0686, 'first n-symbol accuracy': 0.2283101341834762, 'overlap rate': 0.44733190112271826}
# evaluation performance: {'loss': 2.7147482872009276, 'full sequence accuracy': 0.059300000000000005, 'first n-symbol accuracy': 0.21482615434031285, 'overlap rate': 0.4329225798766282}
#
# Current epoch: 140,
# training performance: {'loss': 2.324183988571167, 'full sequence accuracy': 0.09359999999999999, 'first n-symbol accuracy': 0.3045193376730474, 'overlap rate': 0.5102782919181508}
# evaluation performance: {'loss': 2.4420420050621034, 'full sequence accuracy': 0.07890000000000001, 'first n-symbol accuracy': 0.28305463728535407, 'overlap rate': 0.4863577837109663}
#
# Current epoch: 150,
# training performance: {'loss': 2.1242615640163423, 'full sequence accuracy': 0.1891, 'first n-symbol accuracy': 0.3586562993075103, 'overlap rate': 0.5735944631145405}
# evaluation performance: {'loss': 2.2803800284862517, 'full sequence accuracy': 0.1568, 'first n-symbol accuracy': 0.3287511353257135, 'overlap rate': 0.5449581212715754}
#
# Current epoch: 160,
# training performance: {'loss': 2.0288594514131546, 'full sequence accuracy': 0.2354, 'first n-symbol accuracy': 0.41686229068261893, 'overlap rate': 0.6214439154020597}
# evaluation performance: {'loss': 2.214365470409393, 'full sequence accuracy': 0.1918, 'first n-symbol accuracy': 0.37737269044346755, 'overlap rate': 0.5886833239889567}
#
# Current epoch: 170,
# training performance: {'loss': 1.9782059788703918, 'full sequence accuracy': 0.22230000000000003, 'first n-symbol accuracy': 0.42833853063239574, 'overlap rate': 0.6343834485328046}
# evaluation performance: {'loss': 2.196055346727371, 'full sequence accuracy': 0.1872, 'first n-symbol accuracy': 0.3925784396571105, 'overlap rate': 0.5980620487957506}
#
# Current epoch: 180,
# training performance: {'loss': 2.0083538711071016, 'full sequence accuracy': 0.15189999999999998, 'first n-symbol accuracy': 0.43709038808076695, 'overlap rate': 0.6476333756783581}
# evaluation performance: {'loss': 2.2849356532096863, 'full sequence accuracy': 0.10959999999999996, 'first n-symbol accuracy': 0.3892384630761613, 'overlap rate': 0.6030446372850558}
#
# Current epoch: 190,
# training performance: {'loss': 1.562941959500313, 'full sequence accuracy': 0.36749999999999994, 'first n-symbol accuracy': 0.539447940136193, 'overlap rate': 0.7290465730449489}
# evaluation performance: {'loss': 1.8724341571331025, 'full sequence accuracy': 0.2914, 'first n-symbol accuracy': 0.47658931727738996, 'overlap rate': 0.6778125593918731}
#
# Current epoch: 200,
# training performance: {'loss': 1.8081018954515458, 'full sequence accuracy': 0.30919999999999986, 'first n-symbol accuracy': 0.4889539361705322, 'overlap rate': 0.6991336558098556}
# evaluation performance: {'loss': 2.0758426278829574, 'full sequence accuracy': 0.24960000000000004, 'first n-symbol accuracy': 0.44199626630708905, 'overlap rate': 0.6558166023533791}
#
# Current epoch: 210,
# training performance: {'loss': 1.4953905843198299, 'full sequence accuracy': 0.41570000000000007, 'first n-symbol accuracy': 0.5940376687415536, 'overlap rate': 0.7537555262872907}
# evaluation performance: {'loss': 1.8168900266289711, 'full sequence accuracy': 0.3281, 'first n-symbol accuracy': 0.5268868884615199, 'overlap rate': 0.703292386891667}
#
# Current epoch: 220,
# training performance: {'loss': 1.628999462723732, 'full sequence accuracy': 0.3198, 'first n-symbol accuracy': 0.5331242115844929, 'overlap rate': 0.7392780526559644}
# evaluation performance: {'loss': 2.037515479326248, 'full sequence accuracy': 0.2384, 'first n-symbol accuracy': 0.46073126538626213, 'overlap rate': 0.678794136962542}
#
# Current epoch: 230,
# training performance: {'loss': 1.4135436072945595, 'full sequence accuracy': 0.4166, 'first n-symbol accuracy': 0.5988826101641325, 'overlap rate': 0.7837218986597756}
# evaluation performance: {'loss': 1.8537883758544922, 'full sequence accuracy': 0.3143, 'first n-symbol accuracy': 0.5191717571148586, 'overlap rate': 0.7194799707577058}
#
# Current epoch: 240,
# training performance: {'loss': 1.2081987321376801, 'full sequence accuracy': 0.4366999999999999, 'first n-symbol accuracy': 0.6452144934324558, 'overlap rate': 0.8098504461247179}
# evaluation performance: {'loss': 1.6849212616682052, 'full sequence accuracy': 0.31120000000000003, 'first n-symbol accuracy': 0.5487102711224744, 'overlap rate': 0.7383460618811811}
#
# Current epoch: 250,
# training performance: {'loss': 1.2787892937660217, 'full sequence accuracy': 0.3883, 'first n-symbol accuracy': 0.6227344086744088, 'overlap rate': 0.8064084231024818}
# evaluation performance: {'loss': 1.7294785887002946, 'full sequence accuracy': 0.29850000000000004, 'first n-symbol accuracy': 0.5405938652537863, 'overlap rate': 0.7392751814808953}
#
# Current epoch: 260,
# training performance: {'loss': 1.397710257768631, 'full sequence accuracy': 0.3931, 'first n-symbol accuracy': 0.5998165315992666, 'overlap rate': 0.7926692420986848}
# evaluation performance: {'loss': 1.8667870461940765, 'full sequence accuracy': 0.2981999999999999, 'first n-symbol accuracy': 0.5185757140505495, 'overlap rate': 0.724205743949225}
#
# Current epoch: 270,
# training performance: {'loss': 1.0972790095955134, 'full sequence accuracy': 0.524, 'first n-symbol accuracy': 0.6807536378325152, 'overlap rate': 0.84410398340675}
# evaluation performance: {'loss': 1.6726644799113273, 'full sequence accuracy': 0.37590000000000007, 'first n-symbol accuracy': 0.564874517143801, 'overlap rate': 0.7634888825205108}
#
# Current epoch: 280,
# training performance: {'loss': 1.3371654257178307, 'full sequence accuracy': 0.4607, 'first n-symbol accuracy': 0.6382386187656692, 'overlap rate': 0.814201572360189}
# evaluation performance: {'loss': 1.9359851986169816, 'full sequence accuracy': 0.33309999999999995, 'first n-symbol accuracy': 0.5360684009104167, 'overlap rate': 0.7364414876074851}
#
# Current epoch: 290,
# training performance: {'loss': 1.1833992257714272, 'full sequence accuracy': 0.5194000000000001, 'first n-symbol accuracy': 0.6692723241657937, 'overlap rate': 0.8373585892492793}
# evaluation performance: {'loss': 1.804527962207794, 'full sequence accuracy': 0.37479999999999997, 'first n-symbol accuracy': 0.5559156903017108, 'overlap rate': 0.7546126521637041}
#
# Current epoch: 300,
# training performance: {'loss': 0.9254711391404271, 'full sequence accuracy': 0.6028, 'first n-symbol accuracy': 0.7338480786984589, 'overlap rate': 0.8723099285256068}
# evaluation performance: {'loss': 1.5630409352481365, 'full sequence accuracy': 0.43550000000000005, 'first n-symbol accuracy': 0.6079363925991815, 'overlap rate': 0.7860155127422894}
#
# Current epoch: 310,
# training performance: {'loss': 0.8124004395678639, 'full sequence accuracy': 0.6149, 'first n-symbol accuracy': 0.7479804069110851, 'overlap rate': 0.8895610700571168}
# evaluation performance: {'loss': 1.594942931830883, 'full sequence accuracy': 0.4050000000000001, 'first n-symbol accuracy': 0.5885573951999207, 'overlap rate': 0.7856359000735262}
#
# Current epoch: 320,
# training performance: {'loss': 0.7807407952845097, 'full sequence accuracy': 0.6087999999999999, 'first n-symbol accuracy': 0.759340372986557, 'overlap rate': 0.8974815605024602}
# evaluation performance: {'loss': 1.5796710938215255, 'full sequence accuracy': 0.4032, 'first n-symbol accuracy': 0.6048397430512528, 'overlap rate': 0.7954664747548656}
#
# Current epoch: 330,
# training performance: {'loss': 0.8032910384237766, 'full sequence accuracy': 0.6283, 'first n-symbol accuracy': 0.7568105768881217, 'overlap rate': 0.8945615748403736}
# evaluation performance: {'loss': 1.5814255803823472, 'full sequence accuracy': 0.4206, 'first n-symbol accuracy': 0.6022292350213496, 'overlap rate': 0.7931239139435652}
#
# Current epoch: 340,
# training performance: {'loss': 0.8023282714188099, 'full sequence accuracy': 0.6124, 'first n-symbol accuracy': 0.764474192151203, 'overlap rate': 0.8951213850136357}
# evaluation performance: {'loss': 1.5579375803470612, 'full sequence accuracy': 0.41159999999999997, 'first n-symbol accuracy': 0.6214707459655318, 'overlap rate': 0.795151832424823}
#
# Current epoch: 350,
# training performance: {'loss': 0.6582102417945862, 'full sequence accuracy': 0.6775, 'first n-symbol accuracy': 0.7934060606804808, 'overlap rate': 0.9158952011566373}
# evaluation performance: {'loss': 1.4548041023314, 'full sequence accuracy': 0.45299999999999996, 'first n-symbol accuracy': 0.629597480713286, 'overlap rate': 0.8126963503766357}
#
# Current epoch: 360,
# training performance: {'loss': 0.43727451865561306, 'full sequence accuracy': 0.7638999999999999, 'first n-symbol accuracy': 0.8627486381212346, 'overlap rate': 0.9443501974816885}
# evaluation performance: {'loss': 1.323296881839633, 'full sequence accuracy': 0.48690000000000005, 'first n-symbol accuracy': 0.6644162807619007, 'overlap rate': 0.8306809895023998}
#
# Current epoch: 370,
# training performance: {'loss': 0.7494032256305218, 'full sequence accuracy': 0.6401, 'first n-symbol accuracy': 0.7697436178676534, 'overlap rate': 0.9084693696057051}
# evaluation performance: {'loss': 1.6636721774935723, 'full sequence accuracy': 0.40359999999999996, 'first n-symbol accuracy': 0.5940662987771873, 'overlap rate': 0.7951661303275751}
#
# Current epoch: 380,
# training performance: {'loss': 0.42740196976810696, 'full sequence accuracy': 0.7811999999999999, 'first n-symbol accuracy': 0.8636005461592221, 'overlap rate': 0.9475006529261935}
# evaluation performance: {'loss': 1.3141413025557995, 'full sequence accuracy': 0.5086, 'first n-symbol accuracy': 0.6728292194162234, 'overlap rate': 0.838590091659357}
#
# Current epoch: 390,
# training performance: {'loss': 0.8626839354634285, 'full sequence accuracy': 0.6339999999999999, 'first n-symbol accuracy': 0.7694674062413307, 'overlap rate': 0.9017121449576827}
# evaluation performance: {'loss': 1.8982449740171432, 'full sequence accuracy': 0.3731000000000001, 'first n-symbol accuracy': 0.5810701882088234, 'overlap rate': 0.7823738245049071}
#
# Current epoch: 400,
# training performance: {'loss': 0.9128554619848728, 'full sequence accuracy': 0.6056, 'first n-symbol accuracy': 0.7534308309772472, 'overlap rate': 0.8937962493215228}
# evaluation performance: {'loss': 1.9745011940598487, 'full sequence accuracy': 0.36510000000000004, 'first n-symbol accuracy': 0.5693420653353705, 'overlap rate': 0.7737359428426669}
#
# Current epoch: 410,
# training performance: {'loss': 0.5154501743614673, 'full sequence accuracy': 0.7598, 'first n-symbol accuracy': 0.8463208715633874, 'overlap rate': 0.9389383664029222}
# evaluation performance: {'loss': 1.4133138552308082, 'full sequence accuracy': 0.49079999999999996, 'first n-symbol accuracy': 0.6655911189394056, 'overlap rate': 0.8316725559499876}
#
# Current epoch: 420,
# training performance: {'loss': 0.36358295325189827, 'full sequence accuracy': 0.8015000000000001, 'first n-symbol accuracy': 0.8800222610811435, 'overlap rate': 0.9567962005625779}
# evaluation performance: {'loss': 1.3354624971747397, 'full sequence accuracy': 0.5063, 'first n-symbol accuracy': 0.6745681797965433, 'overlap rate': 0.8408485153612035}
#
# Current epoch: 430,
# training performance: {'loss': 0.4334012678358704, 'full sequence accuracy': 0.776, 'first n-symbol accuracy': 0.8632422325701551, 'overlap rate': 0.9486438738508898}
# evaluation performance: {'loss': 1.4967977114021778, 'full sequence accuracy': 0.47939999999999994, 'first n-symbol accuracy': 0.6524254565819827, 'overlap rate': 0.8275976667549377}
#
# Current epoch: 440,
# training performance: {'loss': 0.2703807767946273, 'full sequence accuracy': 0.8533, 'first n-symbol accuracy': 0.9105004890432464, 'overlap rate': 0.9684438574927828}
# evaluation performance: {'loss': 1.320488317683339, 'full sequence accuracy': 0.5267999999999999, 'first n-symbol accuracy': 0.6878731760032937, 'overlap rate': 0.8448164124945577}
#
# Current epoch: 450,
# training performance: {'loss': 0.20654600381385535, 'full sequence accuracy': 0.8814, 'first n-symbol accuracy': 0.9309250918759897, 'overlap rate': 0.9764606796773485}
# evaluation performance: {'loss': 1.3442710250616074, 'full sequence accuracy': 0.5166999999999999, 'first n-symbol accuracy': 0.6849340208390953, 'overlap rate': 0.8467926073920765}
#
# Current epoch: 460,
# training performance: {'loss': 0.20830506626516582, 'full sequence accuracy': 0.8948, 'first n-symbol accuracy': 0.9355244007820485, 'overlap rate': 0.9776356806245466}
# evaluation performance: {'loss': 1.2527175195515157, 'full sequence accuracy': 0.5274, 'first n-symbol accuracy': 0.7033058779057371, 'overlap rate': 0.8564500010985967}
#
# Current epoch: 470,
# training performance: {'loss': 0.1328711659880355, 'full sequence accuracy': 0.9208999999999999, 'first n-symbol accuracy': 0.9561145122477812, 'overlap rate': 0.9859720660149713}
# evaluation performance: {'loss': 1.2266803562641144, 'full sequence accuracy': 0.5430999999999999, 'first n-symbol accuracy': 0.7076053969831003, 'overlap rate': 0.8608272970943032}
#
# Current epoch: 480,
# training performance: {'loss': 0.16054912735708057, 'full sequence accuracy': 0.9133000000000001, 'first n-symbol accuracy': 0.9491327862576254, 'overlap rate': 0.9828298165138583}
# evaluation performance: {'loss': 1.2256513029336928, 'full sequence accuracy': 0.5515000000000001, 'first n-symbol accuracy': 0.7135713051940623, 'overlap rate': 0.8600055439169738}
#
# Current epoch: 490,
# training performance: {'loss': 0.2048551777843386, 'full sequence accuracy': 0.8927999999999999, 'first n-symbol accuracy': 0.936380233672101, 'overlap rate': 0.9780379079315686}
# evaluation performance: {'loss': 1.3681472308933735, 'full sequence accuracy': 0.5233000000000001, 'first n-symbol accuracy': 0.687788906105427, 'overlap rate': 0.848371821415569}
#
# Current epoch: 500,
# training performance: {'loss': 0.11837218629661947, 'full sequence accuracy': 0.9351, 'first n-symbol accuracy': 0.9608926949371946, 'overlap rate': 0.9873741245707219}
# evaluation performance: {'loss': 1.2216611333191394, 'full sequence accuracy': 0.5548, 'first n-symbol accuracy': 0.7110626315519346, 'overlap rate': 0.8627284077561995}
#
# experiments/total_red/LSTM/attn-less/3/model.pt saved!
#
# experiments/total_red/LSTM/attn-less/3/training_log.json saved!
# experiments/total_red/LSTM/attn-less/3/ModelConfig.json saved!
# experiments/total_red/LSTM/attn-less/3/training_plot.png saved!
# experiments/total_red/LSTM/attn-less/3/perfs_train.json saved!
# experiments/total_red/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/total_red/LSTM/attn-less/3/perfs_test.json saved!
# experiments/total_red/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/total_red/LSTM/attn-less/3/perfs_train.png saved!
# experiments/total_red/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/total_red/LSTM/attn-less/3/perfs_test.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
