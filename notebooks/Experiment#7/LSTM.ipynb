# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = False
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 7
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#7 created!
# ./Experiments_Logs/Experiment#7/LSTM created!
# ./Experiments_Logs/Experiment#7/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#7/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#7/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#7 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.6316819563508034, 'abosulate accuracy': 0.0015000000479631127, 'consecutive overlap rate': 0.1519185989163816, 'overlap rate': 0.46770661398768426}
# evaluation performance: {'loss': 2.3773410111665725, 'abosulate accuracy': 0.00020000000367872416, 'consecutive overlap rate': 0.176656074821949, 'overlap rate': 0.29629629887640474}
#
# Current epoch: 10,
# training performance: {'loss': 1.1364337995648384, 'abosulate accuracy': 0.006600000313483179, 'consecutive overlap rate': 0.22099085468798876, 'overlap rate': 0.6029526121914387}
# evaluation performance: {'loss': 2.5790444552898406, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.2181120241060853, 'overlap rate': 0.33841859735548496}
#
# Current epoch: 15,
# training performance: {'loss': 0.8935455307364464, 'abosulate accuracy': 0.03680000158492476, 'consecutive overlap rate': 0.2809121388942003, 'overlap rate': 0.6793664552271366}
# evaluation performance: {'loss': 2.6402846217155456, 'abosulate accuracy': 0.0008500000170897692, 'consecutive overlap rate': 0.23179136384278537, 'overlap rate': 0.37464148327708247}
#
# Current epoch: 20,
# training performance: {'loss': 0.7677960883826017, 'abosulate accuracy': 0.06910000342177228, 'consecutive overlap rate': 0.314028493873775, 'overlap rate': 0.7221013829112053}
# evaluation performance: {'loss': 2.650768393278122, 'abosulate accuracy': 0.00910000057774596, 'consecutive overlap rate': 0.2197252394631505, 'overlap rate': 0.38696040138602256}
#
# Current epoch: 25,
# training performance: {'loss': 0.6637308232486248, 'abosulate accuracy': 0.11140000708401203, 'consecutive overlap rate': 0.35819911751896144, 'overlap rate': 0.758702565729618}
# evaluation performance: {'loss': 2.880908450484276, 'abosulate accuracy': 0.011100000340957195, 'consecutive overlap rate': 0.22323889266699554, 'overlap rate': 0.392357486858964}
#
# Current epoch: 30,
# training performance: {'loss': 0.6006704546511173, 'abosulate accuracy': 0.14580000700661913, 'consecutive overlap rate': 0.3810508197173476, 'overlap rate': 0.7816563367843627}
# evaluation performance: {'loss': 2.8756225764751435, 'abosulate accuracy': 0.014900000597117468, 'consecutive overlap rate': 0.22666233405470848, 'overlap rate': 0.40799394324421884}
#
# Current epoch: 35,
# training performance: {'loss': 0.5505560334771872, 'abosulate accuracy': 0.14850000845035538, 'consecutive overlap rate': 0.38047602102160455, 'overlap rate': 0.7995296135544777}
# evaluation performance: {'loss': 3.1565017968416216, 'abosulate accuracy': 0.010250000294763594, 'consecutive overlap rate': 0.2249540427699685, 'overlap rate': 0.40106686353683474}
#
# Current epoch: 40,
# training performance: {'loss': 0.5401166653260588, 'abosulate accuracy': 0.13520000813296065, 'consecutive overlap rate': 0.38709141984581946, 'overlap rate': 0.8014684364199638}
# evaluation performance: {'loss': 3.4520366549491883, 'abosulate accuracy': 0.008600000280421228, 'consecutive overlap rate': 0.21595677584409714, 'overlap rate': 0.3902471013367176}
#
# Current epoch: 45,
# training performance: {'loss': 0.5067650258541108, 'abosulate accuracy': 0.1661000079824589, 'consecutive overlap rate': 0.40601225234568117, 'overlap rate': 0.8158892005681991}
# evaluation performance: {'loss': 3.3964628368616103, 'abosulate accuracy': 0.013150000356836245, 'consecutive overlap rate': 0.21604839134961368, 'overlap rate': 0.39903929457068443}
#
# Current epoch: 50,
# training performance: {'loss': 0.4482572954148054, 'abosulate accuracy': 0.19450000738725065, 'consecutive overlap rate': 0.43272597789764405, 'overlap rate': 0.8369213178753853}
# evaluation performance: {'loss': 3.396944525837898, 'abosulate accuracy': 0.011350000352831558, 'consecutive overlap rate': 0.2237558813765645, 'overlap rate': 0.4116994421929121}
#
# Current epoch: 55,
# training performance: {'loss': 0.38028567070141434, 'abosulate accuracy': 0.2127000111155212, 'consecutive overlap rate': 0.4512330245226622, 'overlap rate': 0.8611114025115967}
# evaluation performance: {'loss': 3.374053382873535, 'abosulate accuracy': 0.015550000773509964, 'consecutive overlap rate': 0.2183916000649333, 'overlap rate': 0.42754256203770635}
#
# Current epoch: 60,
# training performance: {'loss': 0.32388544287532567, 'abosulate accuracy': 0.26030001379549506, 'consecutive overlap rate': 0.4929247569292784, 'overlap rate': 0.8821129977703095}
# evaluation performance: {'loss': 3.5862211495637895, 'abosulate accuracy': 0.020700001163640992, 'consecutive overlap rate': 0.22406071443110703, 'overlap rate': 0.4325101975351572}
#
# Current epoch: 65,
# training performance: {'loss': 0.27234097486361863, 'abosulate accuracy': 0.2751000147080049, 'consecutive overlap rate': 0.50311667509377, 'overlap rate': 0.9013556346297265}
# evaluation performance: {'loss': 3.7980573177337646, 'abosulate accuracy': 0.01790000078617595, 'consecutive overlap rate': 0.21699395775794983, 'overlap rate': 0.4210455700755119}
#
# Current epoch: 70,
# training performance: {'loss': 0.26822862764820454, 'abosulate accuracy': 0.2592000102275051, 'consecutive overlap rate': 0.4924658589065075, 'overlap rate': 0.9019454330205917}
# evaluation performance: {'loss': 3.769634747505188, 'abosulate accuracy': 0.024300000967923552, 'consecutive overlap rate': 0.22982974126935005, 'overlap rate': 0.4412063732743263}
#
# Current epoch: 75,
# training performance: {'loss': 0.22652107742615044, 'abosulate accuracy': 0.29240001521538944, 'consecutive overlap rate': 0.5202154580503702, 'overlap rate': 0.917904780805111}
# evaluation performance: {'loss': 3.9867823004722593, 'abosulate accuracy': 0.021350000804523005, 'consecutive overlap rate': 0.21937238052487373, 'overlap rate': 0.4389162201434374}
#
# Current epoch: 80,
# training performance: {'loss': 0.20005890345200897, 'abosulate accuracy': 0.3052000122726895, 'consecutive overlap rate': 0.5385588750243187, 'overlap rate': 0.9287695571780205}
# evaluation performance: {'loss': 4.238130152225494, 'abosulate accuracy': 0.017650000855792315, 'consecutive overlap rate': 0.22016740385442973, 'overlap rate': 0.4240179847925901}
#
# Current epoch: 85,
# training performance: {'loss': 0.19824497709050776, 'abosulate accuracy': 0.31960001518018544, 'consecutive overlap rate': 0.5408669367432595, 'overlap rate': 0.9287791341543198}
# evaluation performance: {'loss': 4.343353426456451, 'abosulate accuracy': 0.019250000675674526, 'consecutive overlap rate': 0.22029779087752105, 'overlap rate': 0.4296181544661522}
#
# Current epoch: 90,
# training performance: {'loss': 0.1693781037349254, 'abosulate accuracy': 0.34040001888060945, 'consecutive overlap rate': 0.5738390181213617, 'overlap rate': 0.9402493849396706}
# evaluation performance: {'loss': 4.595200306177139, 'abosulate accuracy': 0.013000000693136827, 'consecutive overlap rate': 0.21949568893760443, 'overlap rate': 0.42275527156889436}
#
# Current epoch: 95,
# training performance: {'loss': 0.15748379440046847, 'abosulate accuracy': 0.33210001677507534, 'consecutive overlap rate': 0.5832158751785755, 'overlap rate': 0.9447441890835762}
# evaluation performance: {'loss': 4.69875003695488, 'abosulate accuracy': 0.014300001034280285, 'consecutive overlap rate': 0.21899655032902957, 'overlap rate': 0.42368369065225125}
#
# Current epoch: 100,
# training performance: {'loss': 0.16603271951898932, 'abosulate accuracy': 0.3230000141542405, 'consecutive overlap rate': 0.5664938997477293, 'overlap rate': 0.9403612345457077}
# evaluation performance: {'loss': 4.692496961355209, 'abosulate accuracy': 0.018600000883452594, 'consecutive overlap rate': 0.22283936608582736, 'overlap rate': 0.4346621140837669}
#
# Current epoch: 105,
# training performance: {'loss': 0.15587170859798788, 'abosulate accuracy': 0.3293000133126043, 'consecutive overlap rate': 0.5681254718452692, 'overlap rate': 0.9446039527654648}
# evaluation performance: {'loss': 4.816571265459061, 'abosulate accuracy': 0.01875000089639798, 'consecutive overlap rate': 0.22015014085918666, 'overlap rate': 0.4273557960987091}
#
# Current epoch: 110,
# training performance: {'loss': 0.11209130943752825, 'abosulate accuracy': 0.40720001962035896, 'consecutive overlap rate': 0.6532622516155243, 'overlap rate': 0.9623871445655823}
# evaluation performance: {'loss': 4.993983292579651, 'abosulate accuracy': 0.016950000601354986, 'consecutive overlap rate': 0.22224758733063937, 'overlap rate': 0.43122774697840216}
#
# Current epoch: 115,
# training performance: {'loss': 0.1274888501036912, 'abosulate accuracy': 0.3770000180578791, 'consecutive overlap rate': 0.6089247778058052, 'overlap rate': 0.9552908673882484}
# evaluation performance: {'loss': 5.285674446821213, 'abosulate accuracy': 0.015700000739889218, 'consecutive overlap rate': 0.2183093920350075, 'overlap rate': 0.42084985934197905}
#
# Current epoch: 120,
# training performance: {'loss': 0.11778716584667563, 'abosulate accuracy': 0.3742000206839293, 'consecutive overlap rate': 0.6167593017220497, 'overlap rate': 0.9593166947364807}
# evaluation performance: {'loss': 5.416403591632843, 'abosulate accuracy': 0.011450000532204286, 'consecutive overlap rate': 0.21895006019622087, 'overlap rate': 0.41461935453116894}
#
# Current epoch: 125,
# training performance: {'loss': 0.16289375578053295, 'abosulate accuracy': 0.30190001499140634, 'consecutive overlap rate': 0.5470523223280906, 'overlap rate': 0.9411505088210106}
# evaluation performance: {'loss': 5.301718556880951, 'abosulate accuracy': 0.014850000763544813, 'consecutive overlap rate': 0.2158460196107626, 'overlap rate': 0.419235048443079}
#
# Current epoch: 130,
# training performance: {'loss': 0.12675780782010407, 'abosulate accuracy': 0.3686000183224678, 'consecutive overlap rate': 0.6128805667161942, 'overlap rate': 0.9551837533712387}
# evaluation performance: {'loss': 5.385234636068344, 'abosulate accuracy': 0.014450000826036558, 'consecutive overlap rate': 0.21434206739068032, 'overlap rate': 0.4196578487753868}
#
# Current epoch: 135,
# training performance: {'loss': 0.09987720006611198, 'abosulate accuracy': 0.40680001652799547, 'consecutive overlap rate': 0.6534524388611317, 'overlap rate': 0.9660413295030594}
# evaluation performance: {'loss': 5.3823386311531065, 'abosulate accuracy': 0.01525000050314702, 'consecutive overlap rate': 0.22131169438362122, 'overlap rate': 0.42884221486747265}
#
# Current epoch: 140,
# training performance: {'loss': 0.10308262340258807, 'abosulate accuracy': 0.4066000216174871, 'consecutive overlap rate': 0.6465417668223381, 'overlap rate': 0.9640774011611939}
# evaluation performance: {'loss': 5.593834507465362, 'abosulate accuracy': 0.01735000092885457, 'consecutive overlap rate': 0.21802378334105016, 'overlap rate': 0.42626182548701763}
#
# Current epoch: 145,
# training performance: {'loss': 0.11896954104304314, 'abosulate accuracy': 0.3656000191927887, 'consecutive overlap rate': 0.6089872382581234, 'overlap rate': 0.9575762435793876}
# evaluation performance: {'loss': 5.670587736368179, 'abosulate accuracy': 0.016150000458583235, 'consecutive overlap rate': 0.2156110879033804, 'overlap rate': 0.4240682408213615}
#
# Current epoch: 150,
# training performance: {'loss': 0.10512563409283757, 'abosulate accuracy': 0.389000017568469, 'consecutive overlap rate': 0.6302278757095336, 'overlap rate': 0.9633131712675095}
# evaluation performance: {'loss': 5.72318856716156, 'abosulate accuracy': 0.018300000962335618, 'consecutive overlap rate': 0.2195480702444911, 'overlap rate': 0.42681760229170324}
#
# Current epoch: 155,
# training performance: {'loss': 0.07637267935788258, 'abosulate accuracy': 0.46620002165436747, 'consecutive overlap rate': 0.7008540488779544, 'overlap rate': 0.9746548131108284}
# evaluation performance: {'loss': 5.808824497461319, 'abosulate accuracy': 0.021900000603636727, 'consecutive overlap rate': 0.22221923545002936, 'overlap rate': 0.431601981446147}
#
# Current epoch: 160,
# training performance: {'loss': 0.08571756093297153, 'abosulate accuracy': 0.43220001668669283, 'consecutive overlap rate': 0.6687010392546654, 'overlap rate': 0.9706827029585838}
# evaluation performance: {'loss': 5.830256664752961, 'abosulate accuracy': 0.024300001241499558, 'consecutive overlap rate': 0.22609127759933473, 'overlap rate': 0.43725980445742607}
#
# Current epoch: 165,
# training performance: {'loss': 0.07321021752431989, 'abosulate accuracy': 0.47040002113208174, 'consecutive overlap rate': 0.704386056214571, 'overlap rate': 0.9752744302153588}
# evaluation performance: {'loss': 5.898230719566345, 'abosulate accuracy': 0.022300001175608486, 'consecutive overlap rate': 0.22472880333662032, 'overlap rate': 0.4401794750243425}
#
# Current epoch: 170,
# training performance: {'loss': 0.07450837309006601, 'abosulate accuracy': 0.4641000213101506, 'consecutive overlap rate': 0.695853541046381, 'overlap rate': 0.9745158746838569}
# evaluation performance: {'loss': 5.989364749193191, 'abosulate accuracy': 0.024700001708697527, 'consecutive overlap rate': 0.22501429915428162, 'overlap rate': 0.4407428473234177}
#
# Current epoch: 175,
# training performance: {'loss': 0.0608075701398775, 'abosulate accuracy': 0.5027000196278095, 'consecutive overlap rate': 0.7296661972999573, 'overlap rate': 0.9798615723848343}
# evaluation performance: {'loss': 6.127983808517456, 'abosulate accuracy': 0.023600000876467676, 'consecutive overlap rate': 0.2245828401297331, 'overlap rate': 0.4403595358133316}
#
# Current epoch: 180,
# training performance: {'loss': 0.057201449142303316, 'abosulate accuracy': 0.5253000222146511, 'consecutive overlap rate': 0.7485717229545117, 'overlap rate': 0.9809477433562279}
# evaluation performance: {'loss': 6.067597687244415, 'abosulate accuracy': 0.029650001181289555, 'consecutive overlap rate': 0.22852507885545492, 'overlap rate': 0.4504126224666834}
#
# Current epoch: 185,
# training performance: {'loss': 0.058538357575889675, 'abosulate accuracy': 0.5207000276073813, 'consecutive overlap rate': 0.7337109230458736, 'overlap rate': 0.9801878362894059}
# evaluation performance: {'loss': 6.249207466840744, 'abosulate accuracy': 0.023600001278100535, 'consecutive overlap rate': 0.2237889813259244, 'overlap rate': 0.4428551115095615}
#
# Current epoch: 190,
# training performance: {'loss': 0.06947115375660359, 'abosulate accuracy': 0.46990002039819956, 'consecutive overlap rate': 0.7063968434929848, 'overlap rate': 0.9761376082897186}
# evaluation performance: {'loss': 6.353798890113831, 'abosulate accuracy': 0.024150000879308207, 'consecutive overlap rate': 0.2255977915599942, 'overlap rate': 0.44321445375680923}
#
# Current epoch: 195,
# training performance: {'loss': 0.07484494433738291, 'abosulate accuracy': 0.455500022135675, 'consecutive overlap rate': 0.6849010422825813, 'overlap rate': 0.9741752088069916}
# evaluation performance: {'loss': 6.331297159194946, 'abosulate accuracy': 0.023850000504171475, 'consecutive overlap rate': 0.22530266214162112, 'overlap rate': 0.4416372083127499}
#
# Current epoch: 200,
# training performance: {'loss': 0.06353923412971199, 'abosulate accuracy': 0.49840002581477166, 'consecutive overlap rate': 0.7221665672957898, 'overlap rate': 0.978167262673378}
# evaluation performance: {'loss': 6.413499015569687, 'abosulate accuracy': 0.024450001231161877, 'consecutive overlap rate': 0.22745082192122937, 'overlap rate': 0.4436369761824608}
#
# Experiments_Logs/Experiment#7/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 12.466584825515747, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006594166738796048, 'overlap rate': 0.09074917561374604}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.086229127645493, 'abosulate accuracy': 0.025900000880938023, 'consecutive overlap rate': 0.22600829210132362, 'overlap rate': 0.44826488196849823}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 11.505737563102477, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004770970831234609, 'overlap rate': 0.11150723239106516}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.874296922432749, 'abosulate accuracy': 0.07300000363274624, 'consecutive overlap rate': 0.21420917297272304, 'overlap rate': 0.36273993826226186}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.736375331878662, 'abosulate accuracy': 0.0008000000147148967, 'consecutive overlap rate': 0.14113038908690215, 'overlap rate': 0.44208708480000497}
# evaluation performance: {'loss': 2.3931262880563735, 'abosulate accuracy': 0.0009500000509433448, 'consecutive overlap rate': 0.16948377238586546, 'overlap rate': 0.2978981349617243}
#
# Current epoch: 10,
# training performance: {'loss': 1.0593755908310414, 'abosulate accuracy': 0.023200001218356192, 'consecutive overlap rate': 0.24041818361729383, 'overlap rate': 0.6274582073092461}
# evaluation performance: {'loss': 2.5108339458703997, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.21996167805045844, 'overlap rate': 0.3569751910865307}
#
# Current epoch: 15,
# training performance: {'loss': 0.8861215256154538, 'abosulate accuracy': 0.040200002328492704, 'consecutive overlap rate': 0.28011003211140634, 'overlap rate': 0.6820040754973888}
# evaluation performance: {'loss': 2.641959938406944, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.22420068345963956, 'overlap rate': 0.3767817925661802}
#
# Current epoch: 20,
# training performance: {'loss': 0.7550405647605658, 'abosulate accuracy': 0.06700000358978286, 'consecutive overlap rate': 0.3172061339020729, 'overlap rate': 0.7256381630897522}
# evaluation performance: {'loss': 2.5575421333312987, 'abosulate accuracy': 0.0059000002453103665, 'consecutive overlap rate': 0.2437498139217496, 'overlap rate': 0.41002584882080556}
#
# Current epoch: 25,
# training performance: {'loss': 0.6685874093323946, 'abosulate accuracy': 0.10560000417754054, 'consecutive overlap rate': 0.3516513954848051, 'overlap rate': 0.7568241044878959}
# evaluation performance: {'loss': 2.6914416521787645, 'abosulate accuracy': 0.014400000573368743, 'consecutive overlap rate': 0.2373488150537014, 'overlap rate': 0.41669300980865953}
#
# Current epoch: 30,
# training performance: {'loss': 0.5672828003764152, 'abosulate accuracy': 0.14150000716326758, 'consecutive overlap rate': 0.39432781245559456, 'overlap rate': 0.7930314511060714}
# evaluation performance: {'loss': 3.0160117745399475, 'abosulate accuracy': 0.011350000649690628, 'consecutive overlap rate': 0.24662630669772626, 'overlap rate': 0.41668662801384926}
#
# Current epoch: 35,
# training performance: {'loss': 0.5357619794085622, 'abosulate accuracy': 0.14320000666193664, 'consecutive overlap rate': 0.38801430016756056, 'overlap rate': 0.8043841809034348}
# evaluation performance: {'loss': 3.093755504488945, 'abosulate accuracy': 0.010650000476744026, 'consecutive overlap rate': 0.23585021011531354, 'overlap rate': 0.41712190248072145}
#
# Current epoch: 40,
# training performance: {'loss': 0.5161655303090811, 'abosulate accuracy': 0.15930000722873955, 'consecutive overlap rate': 0.3998083099722862, 'overlap rate': 0.8105896040797234}
# evaluation performance: {'loss': 3.3938005566596985, 'abosulate accuracy': 0.0130500006955117, 'consecutive overlap rate': 0.22705113962292672, 'overlap rate': 0.40579352229833604}
#
# Current epoch: 45,
# training performance: {'loss': 0.5160188995301723, 'abosulate accuracy': 0.13670000652782618, 'consecutive overlap rate': 0.3855393759906292, 'overlap rate': 0.8112590029835701}
# evaluation performance: {'loss': 3.4631618946790694, 'abosulate accuracy': 0.010900000797118992, 'consecutive overlap rate': 0.2287830190733075, 'overlap rate': 0.4091602396219969}
#
# Current epoch: 50,
# training performance: {'loss': 0.447810017876327, 'abosulate accuracy': 0.1825000054668635, 'consecutive overlap rate': 0.42486307993531225, 'overlap rate': 0.8360657557845116}
# evaluation performance: {'loss': 3.4359286397695543, 'abosulate accuracy': 0.018950000684708358, 'consecutive overlap rate': 0.22482256758958102, 'overlap rate': 0.4203939627856016}
#
# Current epoch: 55,
# training performance: {'loss': 0.40121599128469826, 'abosulate accuracy': 0.22060000943019986, 'consecutive overlap rate': 0.45407551936805246, 'overlap rate': 0.8541674718260766}
# evaluation performance: {'loss': 3.4370622277259826, 'abosulate accuracy': 0.014000000472879037, 'consecutive overlap rate': 0.2168399991467595, 'overlap rate': 0.4281090579926968}
#
# Current epoch: 60,
# training performance: {'loss': 0.33743962589651344, 'abosulate accuracy': 0.24920001104474068, 'consecutive overlap rate': 0.47644314393401144, 'overlap rate': 0.8770369365811348}
# evaluation performance: {'loss': 3.6116925299167635, 'abosulate accuracy': 0.019500000542029737, 'consecutive overlap rate': 0.2266550101339817, 'overlap rate': 0.42924399562180043}
#
# Current epoch: 65,
# training performance: {'loss': 0.27430480760522186, 'abosulate accuracy': 0.28220001215813684, 'consecutive overlap rate': 0.5090696092694997, 'overlap rate': 0.9012154474854469}
# evaluation performance: {'loss': 3.6093250066041946, 'abosulate accuracy': 0.027850001183105634, 'consecutive overlap rate': 0.22969339098781347, 'overlap rate': 0.4512861408293247}
#
# Current epoch: 70,
# training performance: {'loss': 0.23779853428713976, 'abosulate accuracy': 0.3044000155176036, 'consecutive overlap rate': 0.5273747645318508, 'overlap rate': 0.9147946745157242}
# evaluation performance: {'loss': 3.8469057381153107, 'abosulate accuracy': 0.024700000992743297, 'consecutive overlap rate': 0.23646561075001954, 'overlap rate': 0.44953754395246504}
#
# Current epoch: 75,
# training performance: {'loss': 0.22072682320140302, 'abosulate accuracy': 0.30440001259557903, 'consecutive overlap rate': 0.5226006805896759, 'overlap rate': 0.920145682990551}
# evaluation performance: {'loss': 4.146713274717331, 'abosulate accuracy': 0.023050000850344077, 'consecutive overlap rate': 0.2229178024455905, 'overlap rate': 0.4376088254153728}
#
# Current epoch: 80,
# training performance: {'loss': 0.19534675972536206, 'abosulate accuracy': 0.29520001183263955, 'consecutive overlap rate': 0.540286035463214, 'overlap rate': 0.9301132962107659}
# evaluation performance: {'loss': 4.251693385839462, 'abosulate accuracy': 0.020150000852299853, 'consecutive overlap rate': 0.22540848068892955, 'overlap rate': 0.43788105100393293}
#
# Current epoch: 85,
# training performance: {'loss': 0.17511525629088281, 'abosulate accuracy': 0.3183000186225399, 'consecutive overlap rate': 0.5580863073468209, 'overlap rate': 0.938005006313324}
# evaluation performance: {'loss': 4.405381125211716, 'abosulate accuracy': 0.019500000606058165, 'consecutive overlap rate': 0.22482189442962408, 'overlap rate': 0.43768875300884247}
#
# Current epoch: 90,
# training performance: {'loss': 0.18028981760144233, 'abosulate accuracy': 0.3008000108762644, 'consecutive overlap rate': 0.5391119752079249, 'overlap rate': 0.9351888060569763}
# evaluation performance: {'loss': 4.53270868062973, 'abosulate accuracy': 0.02155000140774064, 'consecutive overlap rate': 0.22302236258983613, 'overlap rate': 0.4408059358596802}
#
# Current epoch: 95,
# training performance: {'loss': 0.15524103727657348, 'abosulate accuracy': 0.32940001513343303, 'consecutive overlap rate': 0.5688004918396473, 'overlap rate': 0.9445897370576859}
# evaluation performance: {'loss': 4.555184608697891, 'abosulate accuracy': 0.021900001337053256, 'consecutive overlap rate': 0.22729228548705577, 'overlap rate': 0.4426462586969137}
#
# Current epoch: 100,
# training performance: {'loss': 0.15322444937191904, 'abosulate accuracy': 0.3320000167819671, 'consecutive overlap rate': 0.571540979295969, 'overlap rate': 0.9451284319162369}
# evaluation performance: {'loss': 4.676597762107849, 'abosulate accuracy': 0.019550001050811262, 'consecutive overlap rate': 0.2261350503191352, 'overlap rate': 0.44173354282975197}
#
# Current epoch: 105,
# training performance: {'loss': 0.17360563380643726, 'abosulate accuracy': 0.29570001454558226, 'consecutive overlap rate': 0.5391557689756155, 'overlap rate': 0.9368082448840142}
# evaluation performance: {'loss': 4.782326233386994, 'abosulate accuracy': 0.020700001151999457, 'consecutive overlap rate': 0.22293229606002568, 'overlap rate': 0.4379038166254759}
#
# Current epoch: 110,
# training performance: {'loss': 0.11972605644259601, 'abosulate accuracy': 0.3806000174372457, 'consecutive overlap rate': 0.6208915449678898, 'overlap rate': 0.9584850803017616}
# evaluation performance: {'loss': 5.010502058267593, 'abosulate accuracy': 0.02180000110529363, 'consecutive overlap rate': 0.22195029705762864, 'overlap rate': 0.440445888414979}
#
# Current epoch: 115,
# training performance: {'loss': 0.1189879692858085, 'abosulate accuracy': 0.3895000187098049, 'consecutive overlap rate': 0.6212722353637219, 'overlap rate': 0.9584329068660736}
# evaluation performance: {'loss': 5.200929206609726, 'abosulate accuracy': 0.019450000760843977, 'consecutive overlap rate': 0.22423753924667836, 'overlap rate': 0.4358862582594156}
#
# Current epoch: 120,
# training performance: {'loss': 0.09991915598511696, 'abosulate accuracy': 0.41310002071550117, 'consecutive overlap rate': 0.6563048750162125, 'overlap rate': 0.9660658553242684}
# evaluation performance: {'loss': 5.187619948387146, 'abosulate accuracy': 0.018550000712275506, 'consecutive overlap rate': 0.22551827169954777, 'overlap rate': 0.43935110196471217}
#
# Current epoch: 125,
# training performance: {'loss': 0.13143531498499214, 'abosulate accuracy': 0.35470001834910364, 'consecutive overlap rate': 0.600827094912529, 'overlap rate': 0.952915795147419}
# evaluation performance: {'loss': 5.37464257478714, 'abosulate accuracy': 0.018700000998796894, 'consecutive overlap rate': 0.22293199859559537, 'overlap rate': 0.4346854783594608}
#
# Current epoch: 130,
# training performance: {'loss': 0.10389386937022209, 'abosulate accuracy': 0.3878000210504979, 'consecutive overlap rate': 0.6356435030698776, 'overlap rate': 0.9638143330812454}
# evaluation performance: {'loss': 5.430369544029236, 'abosulate accuracy': 0.018300000781891868, 'consecutive overlap rate': 0.22643541041761636, 'overlap rate': 0.4345120433717966}
#
# Current epoch: 135,
# training performance: {'loss': 0.13841691110283136, 'abosulate accuracy': 0.3473000129102729, 'consecutive overlap rate': 0.5850144345313311, 'overlap rate': 0.9501968398690224}
# evaluation performance: {'loss': 5.553474652767181, 'abosulate accuracy': 0.01820000118459575, 'consecutive overlap rate': 0.21948871184140445, 'overlap rate': 0.42555099315941336}
#
# Current epoch: 140,
# training performance: {'loss': 0.12653626622632147, 'abosulate accuracy': 0.34340001713717355, 'consecutive overlap rate': 0.595813500136137, 'overlap rate': 0.9543802753090859}
# evaluation performance: {'loss': 5.639155900478363, 'abosulate accuracy': 0.015500000352039934, 'consecutive overlap rate': 0.22045626025646925, 'overlap rate': 0.4217760723084211}
#
# Current epoch: 145,
# training performance: {'loss': 0.13829588051885366, 'abosulate accuracy': 0.3224000159767456, 'consecutive overlap rate': 0.564654441177845, 'overlap rate': 0.9503231152892113}
# evaluation performance: {'loss': 5.713971138000488, 'abosulate accuracy': 0.01340000024647452, 'consecutive overlap rate': 0.2134593127295375, 'overlap rate': 0.4145586997270584}
#
# Current epoch: 150,
# training performance: {'loss': 0.09607072711223737, 'abosulate accuracy': 0.42440001777140424, 'consecutive overlap rate': 0.6633466474711895, 'overlap rate': 0.9668531760573387}
# evaluation performance: {'loss': 5.850612318515777, 'abosulate accuracy': 0.013700000487733632, 'consecutive overlap rate': 0.2186008021235466, 'overlap rate': 0.41657200567424296}
#
# Current epoch: 155,
# training performance: {'loss': 0.11451597162522376, 'abosulate accuracy': 0.36840001770760866, 'consecutive overlap rate': 0.616512505710125, 'overlap rate': 0.9590103849768639}
# evaluation performance: {'loss': 5.706787014007569, 'abosulate accuracy': 0.01915000075241551, 'consecutive overlap rate': 0.22221148386597633, 'overlap rate': 0.42998372204601765}
#
# Current epoch: 160,
# training performance: {'loss': 0.11497591915540398, 'abosulate accuracy': 0.37570001957938076, 'consecutive overlap rate': 0.613530620187521, 'overlap rate': 0.9591849416494369}
# evaluation performance: {'loss': 5.839820528030396, 'abosulate accuracy': 0.021850001421989874, 'consecutive overlap rate': 0.22129940893501043, 'overlap rate': 0.4304291971027851}
#
# Current epoch: 165,
# training performance: {'loss': 0.09881702242419124, 'abosulate accuracy': 0.40390001703053713, 'consecutive overlap rate': 0.6412938997149468, 'overlap rate': 0.9651327833533287}
# evaluation performance: {'loss': 5.863044857978821, 'abosulate accuracy': 0.02155000064522028, 'consecutive overlap rate': 0.22283199168741702, 'overlap rate': 0.43640426732599735}
#
# Current epoch: 170,
# training performance: {'loss': 0.08673485673498363, 'abosulate accuracy': 0.43620001785457135, 'consecutive overlap rate': 0.6705340869724751, 'overlap rate': 0.9694462195038795}
# evaluation performance: {'loss': 5.823550379276275, 'abosulate accuracy': 0.025400001101661473, 'consecutive overlap rate': 0.22527815084904432, 'overlap rate': 0.44295906759798526}
#
# Current epoch: 175,
# training performance: {'loss': 0.06011000603903085, 'abosulate accuracy': 0.5212000258266926, 'consecutive overlap rate': 0.747842050343752, 'overlap rate': 0.9806185126304626}
# evaluation performance: {'loss': 5.980686581134796, 'abosulate accuracy': 0.024300000950461254, 'consecutive overlap rate': 0.22562118265777825, 'overlap rate': 0.44197934307157993}
#
# Current epoch: 180,
# training performance: {'loss': 0.049764393694931644, 'abosulate accuracy': 0.566100025549531, 'consecutive overlap rate': 0.7805509701371193, 'overlap rate': 0.9840737223625183}
# evaluation performance: {'loss': 6.065509188175201, 'abosulate accuracy': 0.02740000150515698, 'consecutive overlap rate': 0.22973926607519388, 'overlap rate': 0.44999988935887814}
#
# Current epoch: 185,
# training performance: {'loss': 0.04388245763257146, 'abosulate accuracy': 0.591900021955371, 'consecutive overlap rate': 0.7940123692154885, 'overlap rate': 0.9862548515200615}
# evaluation performance: {'loss': 6.120703482627869, 'abosulate accuracy': 0.029800001136027276, 'consecutive overlap rate': 0.23016354367136954, 'overlap rate': 0.4547200210392475}
#
# Current epoch: 190,
# training performance: {'loss': 0.033757670363411305, 'abosulate accuracy': 0.6602000243961811, 'consecutive overlap rate': 0.8416126847267151, 'overlap rate': 0.990275202691555}
# evaluation performance: {'loss': 6.313108295202255, 'abosulate accuracy': 0.030800001078750937, 'consecutive overlap rate': 0.23053119461983443, 'overlap rate': 0.4526156853884459}
#
# Current epoch: 195,
# training performance: {'loss': 0.04410618550027721, 'abosulate accuracy': 0.5854000240564347, 'consecutive overlap rate': 0.7888154193758965, 'overlap rate': 0.9856527522206306}
# evaluation performance: {'loss': 6.475744038820267, 'abosulate accuracy': 0.027650001173606144, 'consecutive overlap rate': 0.22721713408827782, 'overlap rate': 0.44766671285033227}
#
# Current epoch: 200,
# training performance: {'loss': 0.05036723621888086, 'abosulate accuracy': 0.5497000254690647, 'consecutive overlap rate': 0.7622417211532593, 'overlap rate': 0.9830990806221962}
# evaluation performance: {'loss': 6.48568349480629, 'abosulate accuracy': 0.024800000677350907, 'consecutive overlap rate': 0.22546416483819484, 'overlap rate': 0.4476332861930132}
#
# Experiments_Logs/Experiment#7/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 8.21357017159462, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00417250003592926, 'overlap rate': 0.11047251080162823}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.8525907158851624, 'abosulate accuracy': 0.03205000119633041, 'consecutive overlap rate': 0.23523802645504474, 'overlap rate': 0.45605827793478965}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.897206549490652, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003025400751240311, 'overlap rate': 0.12170286620816877}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.317000125583849, 'abosulate accuracy': 0.07273684598897633, 'consecutive overlap rate': 0.22053967249628745, 'overlap rate': 0.3682168051600456}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9481547266244887, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.11563483821228146, 'overlap rate': 0.3965396970510483}
# evaluation performance: {'loss': 2.5035641878843307, 'abosulate accuracy': 0.0008500000287313015, 'consecutive overlap rate': 0.14288138300180436, 'overlap rate': 0.27109975516796114}
#
# Current epoch: 10,
# training performance: {'loss': 1.2490477457642555, 'abosulate accuracy': 0.005500000307802111, 'consecutive overlap rate': 0.19986209645867348, 'overlap rate': 0.5699151702225208}
# evaluation performance: {'loss': 2.382777285575867, 'abosulate accuracy': 0.0010500000324100256, 'consecutive overlap rate': 0.21795796528458594, 'overlap rate': 0.35015296898782255}
#
# Current epoch: 15,
# training performance: {'loss': 0.9547321647405624, 'abosulate accuracy': 0.04610000199172646, 'consecutive overlap rate': 0.2770112814381719, 'overlap rate': 0.6622488982975483}
# evaluation performance: {'loss': 2.3411630898714066, 'abosulate accuracy': 0.011200000625103712, 'consecutive overlap rate': 0.2335649650543928, 'overlap rate': 0.3997782416641712}
#
# Current epoch: 20,
# training performance: {'loss': 0.8274195052683353, 'abosulate accuracy': 0.053200002817902714, 'consecutive overlap rate': 0.2969048464670777, 'overlap rate': 0.7008066728711129}
# evaluation performance: {'loss': 2.6340665757656097, 'abosulate accuracy': 0.0018500000354833902, 'consecutive overlap rate': 0.23780430816113948, 'overlap rate': 0.39167258851230147}
#
# Current epoch: 25,
# training performance: {'loss': 0.7261793335899711, 'abosulate accuracy': 0.0919000031077303, 'consecutive overlap rate': 0.34096338842064144, 'overlap rate': 0.7370350778102874}
# evaluation performance: {'loss': 2.7379124641418455, 'abosulate accuracy': 0.0050500001932960005, 'consecutive overlap rate': 0.22484429255127908, 'overlap rate': 0.3904127486050129}
#
# Current epoch: 30,
# training performance: {'loss': 0.6483233580365777, 'abosulate accuracy': 0.12110000455286354, 'consecutive overlap rate': 0.35992500446736814, 'overlap rate': 0.7634117946028709}
# evaluation performance: {'loss': 2.8330701887607574, 'abosulate accuracy': 0.009700000594602898, 'consecutive overlap rate': 0.23395584151148796, 'overlap rate': 0.41257146559655666}
#
# Current epoch: 35,
# training performance: {'loss': 0.5767519883811474, 'abosulate accuracy': 0.15690000749891625, 'consecutive overlap rate': 0.3867838367819786, 'overlap rate': 0.7876941099762916}
# evaluation performance: {'loss': 2.807414796948433, 'abosulate accuracy': 0.018600000953301787, 'consecutive overlap rate': 0.24110892452299595, 'overlap rate': 0.4266012515872717}
#
# Current epoch: 40,
# training performance: {'loss': 0.5697255704551936, 'abosulate accuracy': 0.14120000756811352, 'consecutive overlap rate': 0.3798257954418659, 'overlap rate': 0.7907719433307647}
# evaluation performance: {'loss': 3.030671736598015, 'abosulate accuracy': 0.01020000054850243, 'consecutive overlap rate': 0.23656288366764783, 'overlap rate': 0.40812915563583374}
#
# Current epoch: 45,
# training performance: {'loss': 0.5239718340337276, 'abosulate accuracy': 0.14730000761337578, 'consecutive overlap rate': 0.3958016984164715, 'overlap rate': 0.8073594465851783}
# evaluation performance: {'loss': 3.4606682151556014, 'abosulate accuracy': 0.01025000048102811, 'consecutive overlap rate': 0.2262633854523301, 'overlap rate': 0.39305512681603433}
#
# Current epoch: 50,
# training performance: {'loss': 0.5046148480847478, 'abosulate accuracy': 0.16180000640451908, 'consecutive overlap rate': 0.3994189381599426, 'overlap rate': 0.8144796252250671}
# evaluation performance: {'loss': 3.555995100736618, 'abosulate accuracy': 0.013950000534532592, 'consecutive overlap rate': 0.23335616141557694, 'overlap rate': 0.399030989408493}
#
# Current epoch: 55,
# training performance: {'loss': 0.4812255403958261, 'abosulate accuracy': 0.18620000910013915, 'consecutive overlap rate': 0.4189893977716565, 'overlap rate': 0.8236342132091522}
# evaluation performance: {'loss': 3.306973883509636, 'abosulate accuracy': 0.02300000095856376, 'consecutive overlap rate': 0.2308970645070076, 'overlap rate': 0.42130100503563883}
#
# Current epoch: 60,
# training performance: {'loss': 0.4333775009494275, 'abosulate accuracy': 0.20910001136362552, 'consecutive overlap rate': 0.43251598328351976, 'overlap rate': 0.8411053851246834}
# evaluation performance: {'loss': 3.6326763212680815, 'abosulate accuracy': 0.016650000715162604, 'consecutive overlap rate': 0.22870968151837587, 'overlap rate': 0.40973332822322844}
#
# Current epoch: 65,
# training performance: {'loss': 0.3918104921467602, 'abosulate accuracy': 0.20780001003295184, 'consecutive overlap rate': 0.4408205535262823, 'overlap rate': 0.8559613868594169}
# evaluation performance: {'loss': 3.7819415986537934, 'abosulate accuracy': 0.014300000725779683, 'consecutive overlap rate': 0.2235355082899332, 'overlap rate': 0.4091524086892605}
#
# Current epoch: 70,
# training performance: {'loss': 0.3515954067930579, 'abosulate accuracy': 0.21110000908374787, 'consecutive overlap rate': 0.45322390682995317, 'overlap rate': 0.8706996873021126}
# evaluation performance: {'loss': 3.7978399604558946, 'abosulate accuracy': 0.017400000581983478, 'consecutive overlap rate': 0.22061877865344287, 'overlap rate': 0.41137939095497134}
#
# Current epoch: 75,
# training performance: {'loss': 0.33775668144226073, 'abosulate accuracy': 0.22260000760434195, 'consecutive overlap rate': 0.45589852407574655, 'overlap rate': 0.8754264324903488}
# evaluation performance: {'loss': 3.8540343940258026, 'abosulate accuracy': 0.015050000580959021, 'consecutive overlap rate': 0.21280828546732664, 'overlap rate': 0.4137079633772373}
#
# Current epoch: 80,
# training performance: {'loss': 0.28171290112659336, 'abosulate accuracy': 0.2528000125545077, 'consecutive overlap rate': 0.4850728467106819, 'overlap rate': 0.8975118428468705}
# evaluation performance: {'loss': 4.0000528454780575, 'abosulate accuracy': 0.01815000089700334, 'consecutive overlap rate': 0.21889468412846327, 'overlap rate': 0.4212892036885023}
#
# Current epoch: 85,
# training performance: {'loss': 0.2697612812742591, 'abosulate accuracy': 0.24410000999923795, 'consecutive overlap rate': 0.4846277546137571, 'overlap rate': 0.9016865640878677}
# evaluation performance: {'loss': 4.249834895133972, 'abosulate accuracy': 0.014550000743474812, 'consecutive overlap rate': 0.21230370867997408, 'overlap rate': 0.40460663810372355}
#
# Current epoch: 90,
# training performance: {'loss': 0.2232613400556147, 'abosulate accuracy': 0.29170001345919444, 'consecutive overlap rate': 0.5176568474620581, 'overlap rate': 0.9191632866859436}
# evaluation performance: {'loss': 4.324400091171265, 'abosulate accuracy': 0.01980000093462877, 'consecutive overlap rate': 0.22307297084480524, 'overlap rate': 0.4220698095858097}
#
# Current epoch: 95,
# training performance: {'loss': 0.21286275871098043, 'abosulate accuracy': 0.2749000087846071, 'consecutive overlap rate': 0.519911115989089, 'overlap rate': 0.9233573734760284}
# evaluation performance: {'loss': 4.544808328151703, 'abosulate accuracy': 0.013850000681122765, 'consecutive overlap rate': 0.22225613556802273, 'overlap rate': 0.4137525446712971}
#
# Current epoch: 100,
# training performance: {'loss': 0.21818427196703852, 'abosulate accuracy': 0.26800001473166046, 'consecutive overlap rate': 0.5155392941087484, 'overlap rate': 0.9208263993263245}
# evaluation performance: {'loss': 4.7880019545555115, 'abosulate accuracy': 0.010100000526290388, 'consecutive overlap rate': 0.21358451042324306, 'overlap rate': 0.3984689489006996}
#
# Current epoch: 105,
# training performance: {'loss': 0.18446711576543748, 'abosulate accuracy': 0.2980000146431848, 'consecutive overlap rate': 0.5499965786933899, 'overlap rate': 0.9341687738895417}
# evaluation performance: {'loss': 4.943016922473907, 'abosulate accuracy': 0.011350000742822886, 'consecutive overlap rate': 0.21974103506654502, 'overlap rate': 0.4039354421198368}
#
# Current epoch: 110,
# training performance: {'loss': 0.1911616263911128, 'abosulate accuracy': 0.2917000128538348, 'consecutive overlap rate': 0.5406620960682631, 'overlap rate': 0.9305671334266663}
# evaluation performance: {'loss': 4.9728646099567415, 'abosulate accuracy': 0.010700000263750554, 'consecutive overlap rate': 0.21376919019967316, 'overlap rate': 0.4004063606262207}
#
# Current epoch: 115,
# training performance: {'loss': 0.19862232962623239, 'abosulate accuracy': 0.2771000141859986, 'consecutive overlap rate': 0.52520114146173, 'overlap rate': 0.9277766540646553}
# evaluation performance: {'loss': 5.240198022127151, 'abosulate accuracy': 0.009200000448618083, 'consecutive overlap rate': 0.20945584680885077, 'overlap rate': 0.3909198619425297}
#
# Current epoch: 120,
# training performance: {'loss': 0.14206043884623795, 'abosulate accuracy': 0.35260001781862227, 'consecutive overlap rate': 0.5979448109865189, 'overlap rate': 0.9503227949142456}
# evaluation performance: {'loss': 5.284630221128464, 'abosulate accuracy': 0.013050000654766336, 'consecutive overlap rate': 0.22107192054390906, 'overlap rate': 0.406283874809742}
#
# Current epoch: 125,
# training performance: {'loss': 0.16437769657932222, 'abosulate accuracy': 0.3187000122270547, 'consecutive overlap rate': 0.5636215094476938, 'overlap rate': 0.9408730357885361}
# evaluation performance: {'loss': 5.446986693143844, 'abosulate accuracy': 0.014550000691087916, 'consecutive overlap rate': 0.2189629388973117, 'overlap rate': 0.40237449780106543}
#
# Current epoch: 130,
# training performance: {'loss': 0.14564281455241143, 'abosulate accuracy': 0.33180001538712534, 'consecutive overlap rate': 0.583090627938509, 'overlap rate': 0.9485770657658577}
# evaluation performance: {'loss': 5.3500517964363095, 'abosulate accuracy': 0.016550000390270724, 'consecutive overlap rate': 0.2216781698167324, 'overlap rate': 0.411372197419405}
#
# Current epoch: 135,
# training performance: {'loss': 0.13824097509495914, 'abosulate accuracy': 0.34240002020960675, 'consecutive overlap rate': 0.5873765148222446, 'overlap rate': 0.9507705718278885}
# evaluation performance: {'loss': 5.48879114985466, 'abosulate accuracy': 0.01735000079497695, 'consecutive overlap rate': 0.21924715619534255, 'overlap rate': 0.4085452284663916}
#
# Current epoch: 140,
# training performance: {'loss': 0.15112504600547255, 'abosulate accuracy': 0.34460001547122376, 'consecutive overlap rate': 0.5833434127271175, 'overlap rate': 0.9455210521817208}
# evaluation performance: {'loss': 5.492861074209213, 'abosulate accuracy': 0.018350000760983677, 'consecutive overlap rate': 0.21910710260272026, 'overlap rate': 0.4130615033209324}
#
# Current epoch: 145,
# training performance: {'loss': 0.11639403037261217, 'abosulate accuracy': 0.3804000162053853, 'consecutive overlap rate': 0.6290724851191044, 'overlap rate': 0.9598077654838562}
# evaluation performance: {'loss': 5.642215371131897, 'abosulate accuracy': 0.017650000710273162, 'consecutive overlap rate': 0.22053291518241167, 'overlap rate': 0.41216009967029094}
#
# Current epoch: 150,
# training performance: {'loss': 0.11355737168341876, 'abosulate accuracy': 0.38360002235276625, 'consecutive overlap rate': 0.6287513040006161, 'overlap rate': 0.9602108806371689}
# evaluation performance: {'loss': 5.768976098299026, 'abosulate accuracy': 0.016400000464636834, 'consecutive overlap rate': 0.21832959149032832, 'overlap rate': 0.4100917086005211}
#
# Current epoch: 155,
# training performance: {'loss': 0.09341557547450066, 'abosulate accuracy': 0.4268000215757638, 'consecutive overlap rate': 0.6722106777131558, 'overlap rate': 0.9681302472949028}
# evaluation performance: {'loss': 5.832017976045608, 'abosulate accuracy': 0.01950000097276643, 'consecutive overlap rate': 0.22170348428189754, 'overlap rate': 0.4162894655019045}
#
# Current epoch: 160,
# training performance: {'loss': 0.10808850100729614, 'abosulate accuracy': 0.38370001626899464, 'consecutive overlap rate': 0.6327181205153465, 'overlap rate': 0.9623640850186348}
# evaluation performance: {'loss': 6.042963302135467, 'abosulate accuracy': 0.018250000779516995, 'consecutive overlap rate': 0.21531739737838507, 'overlap rate': 0.4124619510024786}
#
# Current epoch: 165,
# training performance: {'loss': 0.11489274008199572, 'abosulate accuracy': 0.3768000192474574, 'consecutive overlap rate': 0.6206380382180214, 'overlap rate': 0.9591934368014335}
# evaluation performance: {'loss': 6.022294795513153, 'abosulate accuracy': 0.01840000074589625, 'consecutive overlap rate': 0.2191766496747732, 'overlap rate': 0.41469048261642455}
#
# Current epoch: 170,
# training performance: {'loss': 0.0878999155946076, 'abosulate accuracy': 0.4291000166907907, 'consecutive overlap rate': 0.6728399999439716, 'overlap rate': 0.9700038835406304}
# evaluation performance: {'loss': 6.16751748919487, 'abosulate accuracy': 0.017700000636978075, 'consecutive overlap rate': 0.21926071476191283, 'overlap rate': 0.4170802548527718}
#
# Current epoch: 175,
# training performance: {'loss': 0.09000015368219465, 'abosulate accuracy': 0.42130001801997424, 'consecutive overlap rate': 0.6622499965131283, 'overlap rate': 0.9684851676225662}
# evaluation performance: {'loss': 6.368008190393448, 'abosulate accuracy': 0.017000000464031474, 'consecutive overlap rate': 0.21667352858930827, 'overlap rate': 0.41030933149158955}
#
# Current epoch: 180,
# training performance: {'loss': 0.07624410953139886, 'abosulate accuracy': 0.45700002238154414, 'consecutive overlap rate': 0.6972449265420437, 'overlap rate': 0.9740954548120498}
# evaluation performance: {'loss': 6.180649799108505, 'abosulate accuracy': 0.023150000907480716, 'consecutive overlap rate': 0.22278257869184018, 'overlap rate': 0.4258769616484642}
#
# Current epoch: 185,
# training performance: {'loss': 0.07189017415512353, 'abosulate accuracy': 0.47900002412498, 'consecutive overlap rate': 0.7172438941895962, 'overlap rate': 0.9756654188036918}
# ...
#
# Current epoch: 180,
# training performance: {'loss': 0.8548835721332579, 'abosulate accuracy': 0.2709000114351511, 'consecutive overlap rate': 0.43969854321330787, 'overlap rate': 0.735204417258501}
# evaluation performance: {'loss': 5.646231782436371, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.11700846077874302, 'overlap rate': 0.21852797344326974}
#
# Current epoch: 185,
# training performance: {'loss': 0.8834191067144275, 'abosulate accuracy': 0.21270000897347927, 'consecutive overlap rate': 0.4003290643915534, 'overlap rate': 0.7224453628063202}
# evaluation performance: {'loss': 5.438898432254791, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.12145180618390441, 'overlap rate': 0.2254374258220196}
#
# Current epoch: 190,
# training performance: {'loss': 0.8600365315563977, 'abosulate accuracy': 0.23580000987276434, 'consecutive overlap rate': 0.40556415617465974, 'overlap rate': 0.731117495149374}
# evaluation performance: {'loss': 5.677982878684998, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.11248225225135684, 'overlap rate': 0.21325094848871232}
#
# Current epoch: 195,
# training performance: {'loss': 0.8995673696510493, 'abosulate accuracy': 0.17390001013409345, 'consecutive overlap rate': 0.36843057814985514, 'overlap rate': 0.7156045608222484}
# evaluation performance: {'loss': 5.516359543800354, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11672181086614727, 'overlap rate': 0.218485339358449}
#
# Current epoch: 200,
# training performance: {'loss': 0.8127320875879377, 'abosulate accuracy': 0.27100001350045205, 'consecutive overlap rate': 0.43178004343062637, 'overlap rate': 0.7476615719497204}
# evaluation performance: {'loss': 5.761201632022858, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.12354161674156786, 'overlap rate': 0.22080193422734737}
#
# Experiments_Logs/Experiment#7/LSTM/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/LSTM/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 10.206974923610687, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03451125044375658, 'overlap rate': 0.08388417614623904}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.159539294242859, 'abosulate accuracy': 0.000175000011222437, 'consecutive overlap rate': 0.11097821397706867, 'overlap rate': 0.2184953387826681}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 10.601858015983336, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024384809249351103, 'overlap rate': 0.0661365863776976}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.058640116139462, 'abosulate accuracy': 0.004289473799106322, 'consecutive overlap rate': 0.10603392918251063, 'overlap rate': 0.19452886440252004}
# Experiments_Logs/Experiment#7/LSTM/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.153000736236572, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016213814298680518, 'overlap rate': 0.03891153642907739}
# evaluation performance: {'loss': 3.1522637486457823, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015249718780978583, 'overlap rate': 0.03835177971050143}
#
# Current epoch: 10,
# training performance: {'loss': 3.1454040706157684, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013652589230332523, 'overlap rate': 0.04129910245537758}
# evaluation performance: {'loss': 3.1471521258354187, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018545819271821528, 'overlap rate': 0.03885759115219116}
#
# Current epoch: 15,
# training performance: {'loss': 3.1440068960189818, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012813809102226515, 'overlap rate': 0.04266152111813426}
# evaluation performance: {'loss': 3.148314172029495, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013489491993823322, 'overlap rate': 0.038280889857560396}
#
# Current epoch: 20,
# training performance: {'loss': 3.1025505006313323, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00525418360484764, 'overlap rate': 0.05361900255084038}
# evaluation performance: {'loss': 3.094419264793396, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006143497780431062, 'overlap rate': 0.0513710412196815}
#
# Current epoch: 25,
# training performance: {'loss': 2.8865914344787598, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007175678081694059, 'overlap rate': 0.09439711030572653}
# evaluation performance: {'loss': 3.142489093542099, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006441139517119154, 'overlap rate': 0.05391152249649167}
#
# Current epoch: 30,
# training performance: {'loss': 2.7114513158798217, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011446143861394375, 'overlap rate': 0.13285752460360528}
# evaluation performance: {'loss': 3.1337468683719636, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01115811119088903, 'overlap rate': 0.07037113802507519}
#
# Current epoch: 35,
# training performance: {'loss': 2.4398354649543763, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.019669479876756667, 'overlap rate': 0.20145820062607528}
# evaluation performance: {'loss': 3.1621129155158996, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.019221491552889346, 'overlap rate': 0.09816640857607126}
#
# Current epoch: 40,
# training performance: {'loss': 2.201050689816475, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02712047102395445, 'overlap rate': 0.27285291217267515}
# evaluation performance: {'loss': 3.1546955049037932, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02472727275453508, 'overlap rate': 0.12194947153329849}
#
# Current epoch: 45,
# training performance: {'loss': 1.9918521016836166, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.03318670263979584, 'overlap rate': 0.3364381458610296}
# evaluation performance: {'loss': 3.1373492002487184, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028967345878481866, 'overlap rate': 0.14434158075600861}
#
# Current epoch: 50,
# training performance: {'loss': 1.827358140051365, 'abosulate accuracy': 0.0021000001346692444, 'consecutive overlap rate': 0.051555147673934695, 'overlap rate': 0.39951365292072294}
# evaluation performance: {'loss': 3.279358631372452, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.04218201832845807, 'overlap rate': 0.15904871392995118}
#
# Current epoch: 55,
# training performance: {'loss': 1.6544166468083858, 'abosulate accuracy': 0.01200000048847869, 'consecutive overlap rate': 0.07744189887307584, 'overlap rate': 0.46534477919340134}
# evaluation performance: {'loss': 3.3226602256298063, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05695217298343778, 'overlap rate': 0.18016463201493024}
#
# Current epoch: 60,
# training performance: {'loss': 1.5162531428039074, 'abosulate accuracy': 0.04180000126361847, 'consecutive overlap rate': 0.13194125490263103, 'overlap rate': 0.519275414198637}
# evaluation performance: {'loss': 3.3612501978874207, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0752421042881906, 'overlap rate': 0.19951813109219074}
#
# Current epoch: 65,
# training performance: {'loss': 1.4039150401949883, 'abosulate accuracy': 0.07720000279368833, 'consecutive overlap rate': 0.19247927824035288, 'overlap rate': 0.5622434191405773}
# evaluation performance: {'loss': 3.572890520095825, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.09192427806556225, 'overlap rate': 0.20784827508032322}
#
# Current epoch: 70,
# training performance: {'loss': 1.3389367807656527, 'abosulate accuracy': 0.08650000473717227, 'consecutive overlap rate': 0.22074519991874694, 'overlap rate': 0.5826655924320221}
# evaluation performance: {'loss': 3.7229189336299897, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1039285771548748, 'overlap rate': 0.21348814107477665}
#
# Current epoch: 75,
# training performance: {'loss': 1.2386601453647017, 'abosulate accuracy': 0.1549000070663169, 'consecutive overlap rate': 0.28563715890049934, 'overlap rate': 0.6198971666395664}
# evaluation performance: {'loss': 3.873276209831238, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.10961918458342552, 'overlap rate': 0.2179517935961485}
#
# Current epoch: 80,
# training performance: {'loss': 1.3018793113529683, 'abosulate accuracy': 0.09030000295024365, 'consecutive overlap rate': 0.2557709351181984, 'overlap rate': 0.5948573023080825}
# evaluation performance: {'loss': 3.9607117056846617, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.11307631228119135, 'overlap rate': 0.21973814815282822}
#
# Current epoch: 85,
# training performance: {'loss': 1.164998140372336, 'abosulate accuracy': 0.18060000747209415, 'consecutive overlap rate': 0.32120234705507755, 'overlap rate': 0.6429286539554596}
# evaluation performance: {'loss': 3.9409149408340456, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11523223221302033, 'overlap rate': 0.2249856784939766}
#
# Current epoch: 90,
# training performance: {'loss': 1.1237905830144883, 'abosulate accuracy': 0.20570001052692533, 'consecutive overlap rate': 0.3593838945031166, 'overlap rate': 0.6573444314301014}
# evaluation performance: {'loss': 4.178059750795365, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.12060012239962817, 'overlap rate': 0.22597386725246907}
#
# Current epoch: 95,
# training performance: {'loss': 1.089697269257158, 'abosulate accuracy': 0.21630001025041565, 'consecutive overlap rate': 0.37925822716206314, 'overlap rate': 0.6679561480879783}
# evaluation performance: {'loss': 4.194423443078994, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.12121067978441716, 'overlap rate': 0.22813235148787497}
#
# Current epoch: 100,
# training performance: {'loss': 1.1134198622778058, 'abosulate accuracy': 0.13270000487100334, 'consecutive overlap rate': 0.31704535204917195, 'overlap rate': 0.6549109734594822}
# evaluation performance: {'loss': 4.465654706954956, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.11659597689285875, 'overlap rate': 0.2224727388471365}
#
# Current epoch: 105,
# training performance: {'loss': 1.1067367047071457, 'abosulate accuracy': 0.14660000674193724, 'consecutive overlap rate': 0.3254054805263877, 'overlap rate': 0.6573181495070457}
# evaluation performance: {'loss': 4.355892091989517, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.11616120720282197, 'overlap rate': 0.22439458556473255}
#
# Current epoch: 110,
# training performance: {'loss': 1.062793499045074, 'abosulate accuracy': 0.21490001070778816, 'consecutive overlap rate': 0.3902066446840763, 'overlap rate': 0.6746216922998428}
# evaluation performance: {'loss': 4.3169827401638035, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.12249920228496194, 'overlap rate': 0.23033003509044647}
#
# Current epoch: 115,
# training performance: {'loss': 1.022336971014738, 'abosulate accuracy': 0.20520001067779958, 'consecutive overlap rate': 0.3849856201559305, 'overlap rate': 0.6865239724516868}
# evaluation performance: {'loss': 4.515728449821472, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.12037294544279575, 'overlap rate': 0.22823508270084858}
#
# Current epoch: 120,
# training performance: {'loss': 0.9881729471962899, 'abosulate accuracy': 0.25840001180768013, 'consecutive overlap rate': 0.42924864776432514, 'overlap rate': 0.7003145024180413}
# evaluation performance: {'loss': 4.62679705619812, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.12276084935292601, 'overlap rate': 0.22833982594311236}
#
# Current epoch: 125,
# training performance: {'loss': 0.9924688686616718, 'abosulate accuracy': 0.21350000915117562, 'consecutive overlap rate': 0.39968693163245916, 'overlap rate': 0.6961152777075768}
# evaluation performance: {'loss': 4.816630613803864, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.12014958476647734, 'overlap rate': 0.22513198032975196}
#
# Current epoch: 130,
# training performance: {'loss': 0.9929634897969664, 'abosulate accuracy': 0.20110000933054833, 'consecutive overlap rate': 0.39329523518681525, 'overlap rate': 0.6941985800862313}
# evaluation performance: {'loss': 4.795525145530701, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.1247092300094664, 'overlap rate': 0.23090434968471527}
#
# Current epoch: 135,
# training performance: {'loss': 0.9765984568744898, 'abosulate accuracy': 0.22180000874213873, 'consecutive overlap rate': 0.4108053335919976, 'overlap rate': 0.7006361111998558}
# evaluation performance: {'loss': 4.816361761093139, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11946256859228015, 'overlap rate': 0.22761536985635758}
#
# Current epoch: 140,
# training performance: {'loss': 0.9504688411951066, 'abosulate accuracy': 0.23760001184418797, 'consecutive overlap rate': 0.42949045952409504, 'overlap rate': 0.709063769876957}
# evaluation performance: {'loss': 4.969272637367249, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.11903324266895651, 'overlap rate': 0.22501224651932716}
#
# Current epoch: 145,
# training performance: {'loss': 0.9732765354216099, 'abosulate accuracy': 0.20260000941343606, 'consecutive overlap rate': 0.39588870871812104, 'overlap rate': 0.7002111189067364}
# evaluation performance: {'loss': 4.961230707168579, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.1182307374663651, 'overlap rate': 0.22363582327961923}
#
# Current epoch: 150,
# training performance: {'loss': 0.9595602138899266, 'abosulate accuracy': 0.20970000908710063, 'consecutive overlap rate': 0.4050162848085165, 'overlap rate': 0.7038731396198272}
# evaluation performance: {'loss': 5.165026652812958, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11901994924992323, 'overlap rate': 0.22303347438573837}
#
# Current epoch: 155,
# training performance: {'loss': 0.9583262473344802, 'abosulate accuracy': 0.19300000872462988, 'consecutive overlap rate': 0.3866381665691733, 'overlap rate': 0.7037797495722771}
# evaluation performance: {'loss': 5.124507880210876, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.12356386557221413, 'overlap rate': 0.2289065107703209}
#
# Current epoch: 160,
# training performance: {'loss': 0.9966976827010512, 'abosulate accuracy': 0.14500000509433447, 'consecutive overlap rate': 0.34429496675729754, 'overlap rate': 0.6896579056978226}
# evaluation performance: {'loss': 5.478816103935242, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11952844019979239, 'overlap rate': 0.22174228802323342}
#
# Current epoch: 165,
# training performance: {'loss': 0.9634722332470119, 'abosulate accuracy': 0.200100008957088, 'consecutive overlap rate': 0.39263357538729904, 'overlap rate': 0.702469751983881}
# evaluation performance: {'loss': 5.446172523498535, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.11562956925481557, 'overlap rate': 0.21892475746572018}

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
