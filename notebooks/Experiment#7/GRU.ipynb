# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = False
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 7
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#7/GRU created!
# ./Experiments_Logs/Experiment#7/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#7/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#7/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#7 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
# training performance: {'loss': 0.5713348854333162, 'abosulate accuracy': 0.12330000670626759, 'consecutive overlap rate': 0.3618790900334716, 'overlap rate': 0.7904381841421128}
# evaluation performance: {'loss': 2.823853167891502, 'abosulate accuracy': 0.027100000833161175, 'consecutive overlap rate': 0.24546243343502283, 'overlap rate': 0.42674607820808885}
#
# Current epoch: 185,
# training performance: {'loss': 0.5164407681673765, 'abosulate accuracy': 0.18880000868812202, 'consecutive overlap rate': 0.39898206796497104, 'overlap rate': 0.8106276869773865}
# evaluation performance: {'loss': 2.9339031279087067, 'abosulate accuracy': 0.020300000987481324, 'consecutive overlap rate': 0.21035553254187106, 'overlap rate': 0.40669121146202086}
#
# Current epoch: 190,
# training performance: {'loss': 0.45803439486771824, 'abosulate accuracy': 0.2177000090479851, 'consecutive overlap rate': 0.4322444325312972, 'overlap rate': 0.8330326735973358}
# evaluation performance: {'loss': 2.888805603981018, 'abosulate accuracy': 0.02835000105551444, 'consecutive overlap rate': 0.2522068193182349, 'overlap rate': 0.43091768994927404}
#
# Current epoch: 195,
# training performance: {'loss': 0.45914822705090047, 'abosulate accuracy': 0.22010001055896283, 'consecutive overlap rate': 0.42910599801689386, 'overlap rate': 0.8307232454419136}
# evaluation performance: {'loss': 2.912079870700836, 'abosulate accuracy': 0.03715000196243636, 'consecutive overlap rate': 0.24768163552507758, 'overlap rate': 0.4408170454204082}
#
# Current epoch: 200,
# training performance: {'loss': 0.4319172203540802, 'abosulate accuracy': 0.23380001038312911, 'consecutive overlap rate': 0.427660340256989, 'overlap rate': 0.840640039741993}
# evaluation performance: {'loss': 3.0207178235054015, 'abosulate accuracy': 0.026150001329369843, 'consecutive overlap rate': 0.24779727766290308, 'overlap rate': 0.4360682774335146}
#
# Experiments_Logs/Experiment#7/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.632449595630169, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004100000056496356, 'overlap rate': 0.3284137830138206}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.826112973690033, 'abosulate accuracy': 0.040625002668821256, 'consecutive overlap rate': 0.24841783298179507, 'overlap rate': 0.43238102160394193}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.2732209544028006, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002919393085363892, 'overlap rate': 0.33130721392170076}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 2.9383885460464576, 'abosulate accuracy': 0.1853157972034655, 'consecutive overlap rate': 0.2611895139868322, 'overlap rate': 0.37524830863664027}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.122669571638107, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015015777130611242, 'overlap rate': 0.08456580694764852}
# evaluation performance: {'loss': 3.113975703716278, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012997180502861739, 'overlap rate': 0.10660104602575302}
#
# Current epoch: 10,
# training performance: {'loss': 2.7336838006973267, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# Current epoch: 185,
# training performance: {'loss': 0.45622388925403357, 'abosulate accuracy': 0.23650001138448715, 'consecutive overlap rate': 0.43796163965016605, 'overlap rate': 0.8326461270451546}
# evaluation performance: {'loss': 2.906685557961464, 'abosulate accuracy': 0.02980000209645368, 'consecutive overlap rate': 0.24632140332832933, 'overlap rate': 0.4393104054033756}
#
# Current epoch: 190,
# training performance: {'loss': 0.47324503529816864, 'abosulate accuracy': 0.17910000886768102, 'consecutive overlap rate': 0.3992997730150819, 'overlap rate': 0.8241572409868241}
# evaluation performance: {'loss': 3.0612945735454558, 'abosulate accuracy': 0.026650001219240948, 'consecutive overlap rate': 0.2295260707847774, 'overlap rate': 0.4153889581561089}
#
# Current epoch: 195,
# training performance: {'loss': 0.46306198090314865, 'abosulate accuracy': 0.1945000072941184, 'consecutive overlap rate': 0.41645050775259734, 'overlap rate': 0.8285508275032043}
# evaluation performance: {'loss': 3.0673944622278215, 'abosulate accuracy': 0.020750000950647517, 'consecutive overlap rate': 0.23388965828344227, 'overlap rate': 0.4284166757017374}
#
# Current epoch: 200,
# training performance: {'loss': 0.4627884138375521, 'abosulate accuracy': 0.19140000883489847, 'consecutive overlap rate': 0.40774959288537505, 'overlap rate': 0.8267909154295922}
# evaluation performance: {'loss': 3.0228404104709625, 'abosulate accuracy': 0.03160000117495656, 'consecutive overlap rate': 0.22694221688434482, 'overlap rate': 0.43113542906939983}
#
# Experiments_Logs/Experiment#7/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.562236748635769, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003571666718198685, 'overlap rate': 0.34890253413468597}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.132086658477783, 'abosulate accuracy': 0.040600001678103584, 'consecutive overlap rate': 0.24814232159405947, 'overlap rate': 0.4158990040421486}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.3284132111457088, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025190417782493656, 'overlap rate': 0.35657976365858507}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.294228773368032, 'abosulate accuracy': 0.16513158616266752, 'consecutive overlap rate': 0.2532949780947284, 'overlap rate': 0.35920995140546247}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.9301784515380858, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013539710757322609, 'overlap rate': 0.13142750784754753}
# evaluation performance: {'loss': 2.9200282394886017, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013049965747632087, 'overlap rate': 0.12470238637179136}
#
# Current epoch: 10,
# training performance: {'loss': 2.492238348722458, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.023239362961612643, 'overlap rate': 0.23955039121210575}
# evaluation performance: {'loss': 2.871824824810028, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.023601108067668974, 'overlap rate': 0.11441696304827928}
#
# Current epoch: 15,
# training performance: {'loss': 1.8429908990859984, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001673667491559172, 'overlap rate': 0.0200124608585611}
# evaluation performance: {'loss': 3.296229273080826, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001503876689093886, 'overlap rate': 0.03956910353153944}
#
# Current epoch: 15,
# training performance: {'loss': 3.2819560110569, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019216015803976915, 'overlap rate': 0.027202675747685135}
# evaluation performance: {'loss': 3.3031953871250153, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002191295502416324, 'overlap rate': 0.038391921948641536}
#
# Current epoch: 20,
# training performance: {'loss': 3.2263527691364287, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004687441454734653, 'overlap rate': 0.04734570868313313}
# evaluation performance: {'loss': 3.2743181705474855, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004122247872874141, 'overlap rate': 0.0571743642911315}
#
# Current epoch: 25,
# training performance: {'loss': 2.925022542476654, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01136490794015117, 'overlap rate': 0.1302891505882144}
# evaluation performance: {'loss': 2.9951583445072174, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008817835670197383, 'overlap rate': 0.10202873088419437}
#
# Current epoch: 30,
# training performance: {'loss': 2.2297193944454192, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.034596903901547196, 'overlap rate': 0.2925898842513561}
# evaluation performance: {'loss': 2.8154654920101168, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02311275361571461, 'overlap rate': 0.11808067373931408}
#
# Current epoch: 35,
# training performance: {'loss': 1.73675497174263, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.06900475271977484, 'overlap rate': 0.4231281094253063}
# evaluation performance: {'loss': 2.7684098303318025, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.04615381457842886, 'overlap rate': 0.15780318528413773}
#
# Current epoch: 40,
# training performance: {'loss': 1.5315934389829635, 'abosulate accuracy': 0.002300000109244138, 'consecutive overlap rate': 0.09766671084798872, 'overlap rate': 0.48520985841751096}
# evaluation performance: {'loss': 2.782044696807861, 'abosulate accuracy': 0.0008500000287313015, 'consecutive overlap rate': 0.062223263643682004, 'overlap rate': 0.18809756059199573}
#
# Current epoch: 45,
# training performance: {'loss': 1.3522317253053189, 'abosulate accuracy': 0.012200000660959632, 'consecutive overlap rate': 0.12473727222532034, 'overlap rate': 0.5387520477175712}
# evaluation performance: {'loss': 2.730297350883484, 'abosulate accuracy': 0.0008500000520143657, 'consecutive overlap rate': 0.07782933609560132, 'overlap rate': 0.21726058684289457}
#
# Current epoch: 50,
# training performance: {'loss': 1.2914223797619342, 'abosulate accuracy': 0.017900000466033815, 'consecutive overlap rate': 0.14137480529025198, 'overlap rate': 0.5576000332832336}
# evaluation performance: {'loss': 2.8103592097759247, 'abosulate accuracy': 0.0020000000717118383, 'consecutive overlap rate': 0.08293899782001972, 'overlap rate': 0.22549582347273828}
#
# Current epoch: 55,
# training performance: {'loss': 1.2747265741229057, 'abosulate accuracy': 0.015700000280048698, 'consecutive overlap rate': 0.1487305643968284, 'overlap rate': 0.5637701623141765}
# evaluation performance: {'loss': 2.9510200142860414, 'abosulate accuracy': 0.01685000109137036, 'consecutive overlap rate': 0.1671011483296752, 'overlap rate': 0.3709187887609005}
#
# Current epoch: 190,
# training performance: {'loss': 0.6165921650826931, 'abosulate accuracy': 0.1678000072715804, 'consecutive overlap rate': 0.3858812738209963, 'overlap rate': 0.7771113887429237}
# evaluation performance: {'loss': 3.2943532556295394, 'abosulate accuracy': 0.012050000537419692, 'consecutive overlap rate': 0.15216954611241817, 'overlap rate': 0.35196977853775024}
#
# Current epoch: 195,
# training performance: {'loss': 0.6357268905267119, 'abosulate accuracy': 0.13050000676885248, 'consecutive overlap rate': 0.35312298517674207, 'overlap rate': 0.7700793728232384}
# evaluation performance: {'loss': 3.2792063146829604, 'abosulate accuracy': 0.00960000028135255, 'consecutive overlap rate': 0.15429376307874917, 'overlap rate': 0.345086669921875}
#
# Current epoch: 200,
# training performance: {'loss': 0.5703795742243528, 'abosulate accuracy': 0.18810000871308147, 'consecutive overlap rate': 0.40430484917014836, 'overlap rate': 0.7942840978503227}
# evaluation performance: {'loss': 3.5725454449653626, 'abosulate accuracy': 0.01420000065700151, 'consecutive overlap rate': 0.15307276453822852, 'overlap rate': 0.3370536834001541}
#
# Experiments_Logs/Experiment#7/GRU/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/GRU/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.3734958112239837, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05746666728518903, 'overlap rate': 0.3500746196135879}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.835681509971619, 'abosulate accuracy': 0.017625000892439856, 'consecutive overlap rate': 0.16923560071736574, 'overlap rate': 0.3745196498930454}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.000223767372869, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04107074641412304, 'overlap rate': 0.3009136746006627}
# Experiments_Logs/Experiment#7/GRU/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
