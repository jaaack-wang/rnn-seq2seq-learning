# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 512
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = False 
use_attention = False
reduction_method = torch.sum

learning_rate = 1e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 7
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#7/RNN created!
# ./Experiments_Logs/Experiment#7/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#7/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#7/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#7 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.716548943519592, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014997262146789581, 'overlap rate': 0.2345668338239193}
# evaluation performance: {'loss': 2.996807563304901, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016532207769341768, 'overlap rate': 0.16261860094964503}
#
# Current epoch: 10,
# training performance: {'loss': 2.090635946393013, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.05870052883401513, 'overlap rate': 0.4360148750245571}
# evaluation performance: {'loss': 3.033639353513718, 'abosulate accuracy': 0.0005000000295694917, 'consecutive overlap rate': 0.05374886100180447, 'overlap rate': 0.2090453775599599}
#
# Current epoch: 15,
# training performance: {'loss': 1.757280448079109, 'abosulate accuracy': 0.004900000256020576, 'consecutive overlap rate': 0.10252734292298556, 'overlap rate': 0.5326841682195663}
# evaluation performance: {'loss': 3.067442947626114, 'abosulate accuracy': 0.005900000146357343, 'consecutive overlap rate': 0.09338061613962054, 'overlap rate': 0.2456092657521367}
#
# Current epoch: 20,
# training performance: {'loss': 1.5465438097715378, 'abosulate accuracy': 0.020700000540819018, 'consecutive overlap rate': 0.1492799791507423, 'overlap rate': 0.5933775700628757}
# evaluation performance: {'loss': 3.074844977259636, 'abosulate accuracy': 0.018650000548223033, 'consecutive overlap rate': 0.13754642577841877, 'overlap rate': 0.2852733306586742}
#
# Current epoch: 25,
# training performance: {'loss': 1.4303457677364348, 'abosulate accuracy': 0.03240000053774565, 'consecutive overlap rate': 0.1765528742223978, 'overlap rate': 0.6233964249491691}
# evaluation performance: {'loss': 3.0436369657516478, 'abosulate accuracy': 0.03235000201384537, 'consecutive overlap rate': 0.16627410044893623, 'overlap rate': 0.3116242665797472}
#
# Current epoch: 30,
# training performance: {'loss': 1.28714267462492, 'abosulate accuracy': 0.0643000038457103, 'consecutive overlap rate': 0.2167321987450123, 'overlap rate': 0.6632867738604545}
# evaluation performance: {'loss': 2.9867395594716073, 'abosulate accuracy': 0.06480000196024775, 'consecutive overlap rate': 0.21111040655523539, 'overlap rate': 0.348826153203845}
#
# Current epoch: 35,
# training performance: {'loss': 1.2442945785820485, 'abosulate accuracy': 0.0764000020455569, 'consecutive overlap rate': 0.23627763725817202, 'overlap rate': 0.6726611569523812}
# evaluation performance: {'loss': 3.012717105448246, 'abosulate accuracy': 0.0842500026221387, 'consecutive overlap rate': 0.23383546844124795, 'overlap rate': 0.36885502822697164}
#
# Current epoch: 40,
# training performance: {'loss': 1.1733817175030707, 'abosulate accuracy': 0.08890000432729721, 'consecutive overlap rate': 0.2521507252007723, 'overlap rate': 0.6910153396427632}
# evaluation performance: {'loss': 2.984181159734726, 'abosulate accuracy': 0.08005000326083973, 'consecutive overlap rate': 0.24420925099402666, 'overlap rate': 0.37471913993358613}
#
# Current epoch: 45,
# training performance: {'loss': 1.1506774812936782, 'abosulate accuracy': 0.09840000512776896, 'consecutive overlap rate': 0.2635682478547096, 'overlap rate': 0.7001239597797394}
# evaluation performance: {'loss': 3.002028988301754, 'abosulate accuracy': 0.0786500048416201, 'consecutive overlap rate': 0.23472844790667297, 'overlap rate': 0.36920337975025175}
#
# Current epoch: 50,
# training performance: {'loss': 1.0743919990956783, 'abosulate accuracy': 0.10480000518728047, 'consecutive overlap rate': 0.2808565780520439, 'overlap rate': 0.7162382043898106}
# evaluation performance: {'loss': 2.9785419404506683, 'abosulate accuracy': 0.12110000520478933, 'consecutive overlap rate': 0.27998964227735995, 'overlap rate': 0.40608166828751563}
#
# Current epoch: 55,
# training performance: {'loss': 1.0364196941256523, 'abosulate accuracy': 0.12310000599827617, 'consecutive overlap rate': 0.29758370667696, 'overlap rate': 0.725913918018341}
# evaluation performance: {'loss': 2.987790997326374, 'abosulate accuracy': 0.10625000495929271, 'consecutive overlap rate': 0.279925636574626, 'overlap rate': 0.4062592636793852}
#
# Current epoch: 60,
# training performance: {'loss': 1.0340486958622932, 'abosulate accuracy': 0.12630000544013456, 'consecutive overlap rate': 0.30750622432678937, 'overlap rate': 0.7290912300348282}
# evaluation performance: {'loss': 3.0504505835473537, 'abosulate accuracy': 0.12380000549601392, 'consecutive overlap rate': 0.2904983164742589, 'overlap rate': 0.4170252654701471}
#
# Current epoch: 65,
# training performance: {'loss': 0.986673828214407, 'abosulate accuracy': 0.14010000580456108, 'consecutive overlap rate': 0.3199144721031189, 'overlap rate': 0.74232592061162}
# evaluation performance: {'loss': 3.075287774205208, 'abosulate accuracy': 0.11675000439863652, 'consecutive overlap rate': 0.29934704042971133, 'overlap rate': 0.42728226631879807}
#
# Current epoch: 70,
# training performance: {'loss': 1.020846562832594, 'abosulate accuracy': 0.10940000659320503, 'consecutive overlap rate': 0.27249410226941106, 'overlap rate': 0.7220008417963981}
# evaluation performance: {'loss': 3.016798648238182, 'abosulate accuracy': 0.14135000885580667, 'consecutive overlap rate': 0.30452705938369035, 'overlap rate': 0.4307263448834419}
#
# Current epoch: 75,
# training performance: {'loss': 0.9002662640064955, 'abosulate accuracy': 0.15960000730119644, 'consecutive overlap rate': 0.3375005446374416, 'overlap rate': 0.763330540060997}
# evaluation performance: {'loss': 2.9291976243257523, 'abosulate accuracy': 0.16825000701937826, 'consecutive overlap rate': 0.3344322910532355, 'overlap rate': 0.45221675038337705}
#
# Current epoch: 80,
# training performance: {'loss': 0.907509646192193, 'abosulate accuracy': 0.1588000062503852, 'consecutive overlap rate': 0.33907892890274527, 'overlap rate': 0.7594588860869408}
# evaluation performance: {'loss': 2.9562048844993116, 'abosulate accuracy': 0.16945000732666812, 'consecutive overlap rate': 0.33265102151781323, 'overlap rate': 0.4534084625542164}
#
# Current epoch: 85,
# training performance: {'loss': 0.919951717928052, 'abosulate accuracy': 0.144300006411504, 'consecutive overlap rate': 0.32035646960139275, 'overlap rate': 0.7564892053604126}
# evaluation performance: {'loss': 2.926154924929142, 'abosulate accuracy': 0.1610500068636611, 'consecutive overlap rate': 0.3236814081668854, 'overlap rate': 0.4499234020709991}
#
# Current epoch: 90,
# training performance: {'loss': 0.9280657630413771, 'abosulate accuracy': 0.15010000698966905, 'consecutive overlap rate': 0.32351754792034626, 'overlap rate': 0.7627425268292427}
# evaluation performance: {'loss': 3.172738716006279, 'abosulate accuracy': 0.15215000854223035, 'consecutive overlap rate': 0.30837038811296225, 'overlap rate': 0.44083333425223825}
#
# Current epoch: 95,
# training performance: {'loss': 0.8256835922598839, 'abosulate accuracy': 0.16360000749118625, 'consecutive overlap rate': 0.34232608173042534, 'overlap rate': 0.7785132959485054}
# evaluation performance: {'loss': 2.8349173828959464, 'abosulate accuracy': 0.18440000790287742, 'consecutive overlap rate': 0.3488590497523546, 'overlap rate': 0.473147701099515}
#
# Current epoch: 100,
# training performance: {'loss': 0.7845167376101017, 'abosulate accuracy': 0.1855000085197389, 'consecutive overlap rate': 0.36075328979641197, 'overlap rate': 0.7899716481566429}
# evaluation performance: {'loss': 2.8450635239481925, 'abosulate accuracy': 0.20010000846814363, 'consecutive overlap rate': 0.3609097173437476, 'overlap rate': 0.4854238461703062}
#
# Current epoch: 105,
# training performance: {'loss': 0.7633605547249317, 'abosulate accuracy': 0.18250001057749615, 'consecutive overlap rate': 0.353675177693367, 'overlap rate': 0.7971901148557663}
# evaluation performance: {'loss': 2.97959393337369, 'abosulate accuracy': 0.18180001006112434, 'consecutive overlap rate': 0.34189064186066387, 'overlap rate': 0.4742749955505133}
#
# Current epoch: 110,
# training performance: {'loss': 0.7178810678422451, 'abosulate accuracy': 0.17960001095198094, 'consecutive overlap rate': 0.3503196043893695, 'overlap rate': 0.8059345483779907}
# evaluation performance: {'loss': 2.9525691993534564, 'abosulate accuracy': 0.21785001028329135, 'consecutive overlap rate': 0.36942073777318, 'overlap rate': 0.4990926258265972}
#
# Current epoch: 115,
# training performance: {'loss': 0.677169994264841, 'abosulate accuracy': 0.19800000976538285, 'consecutive overlap rate': 0.3690993992611766, 'overlap rate': 0.8166510462760925}
# evaluation performance: {'loss': 2.968974022194743, 'abosulate accuracy': 0.23325001313351096, 'consecutive overlap rate': 0.384111999720335, 'overlap rate': 0.5105608820915222}
#
# Current epoch: 120,
# training performance: {'loss': 0.647736893966794, 'abosulate accuracy': 0.2182000114582479, 'consecutive overlap rate': 0.3888807695358992, 'overlap rate': 0.8238668963313103}
# evaluation performance: {'loss': 3.0129276596009733, 'abosulate accuracy': 0.23835001208353787, 'consecutive overlap rate': 0.39124876763671634, 'overlap rate': 0.5168509133160114}
#
# Current epoch: 125,
# training performance: {'loss': 0.6696846853941679, 'abosulate accuracy': 0.197600010689348, 'consecutive overlap rate': 0.3775655744597316, 'overlap rate': 0.8154693946242333}
# evaluation performance: {'loss': 2.9736843567341564, 'abosulate accuracy': 0.23005000957637095, 'consecutive overlap rate': 0.38435198571532964, 'overlap rate': 0.5121438547968864}
#
# Current epoch: 130,
# training performance: {'loss': 0.6238037245348096, 'abosulate accuracy': 0.22700001033954323, 'consecutive overlap rate': 0.3990800499916077, 'overlap rate': 0.8287303254008294}
# evaluation performance: {'loss': 2.9384977661073206, 'abosulate accuracy': 0.2518500143662095, 'consecutive overlap rate': 0.4033776927739382, 'overlap rate': 0.5277558546513319}
#
# Current epoch: 135,
# training performance: {'loss': 0.6053020721301436, 'abosulate accuracy': 0.2230000106152147, 'consecutive overlap rate': 0.4039034448564053, 'overlap rate': 0.8331666320562363}
# evaluation performance: {'loss': 2.9639064140617846, 'abosulate accuracy': 0.21180000922759062, 'consecutive overlap rate': 0.39172862023115157, 'overlap rate': 0.5203214481472969}
#
# Current epoch: 140,
# training performance: {'loss': 0.5973835898563266, 'abosulate accuracy': 0.232600010978058, 'consecutive overlap rate': 0.4094074063003063, 'overlap rate': 0.8359103903174401}
# evaluation performance: {'loss': 2.9712198875844478, 'abosulate accuracy': 0.2705000126734376, 'consecutive overlap rate': 0.42322062626481055, 'overlap rate': 0.5447208836674691}
#
# Current epoch: 145,
# training performance: {'loss': 0.582862775027752, 'abosulate accuracy': 0.23600001027807593, 'consecutive overlap rate': 0.41325783617794515, 'overlap rate': 0.8386993065476418}
# evaluation performance: {'loss': 3.005529020540416, 'abosulate accuracy': 0.26290001105517147, 'consecutive overlap rate': 0.416648480668664, 'overlap rate': 0.5404337268322706}
#
# Current epoch: 150,
# training performance: {'loss': 0.569241045974195, 'abosulate accuracy': 0.2369000126607716, 'consecutive overlap rate': 0.41683069467544553, 'overlap rate': 0.8412391260266304}
# evaluation performance: {'loss': 2.940208422206342, 'abosulate accuracy': 0.2634500112384558, 'consecutive overlap rate': 0.42073335833847525, 'overlap rate': 0.5442294672131538}
#
# Current epoch: 155,
# training performance: {'loss': 0.5594438372179866, 'abosulate accuracy': 0.23340001199394464, 'consecutive overlap rate': 0.414320757240057, 'overlap rate': 0.8431537240743637}
# evaluation performance: {'loss': 2.9002083906903864, 'abosulate accuracy': 0.26020001331344245, 'consecutive overlap rate': 0.4232469268143177, 'overlap rate': 0.5465205848217011}
#
# Current epoch: 160,
# training performance: {'loss': 0.5418933963403105, 'abosulate accuracy': 0.23840001244097947, 'consecutive overlap rate': 0.42264312095940115, 'overlap rate': 0.8477347835898399}
# evaluation performance: {'loss': 2.8952894203364847, 'abosulate accuracy': 0.2746500128880143, 'consecutive overlap rate': 0.4293250899761915, 'overlap rate': 0.5522933632135392}
#
# Current epoch: 165,
# training performance: {'loss': 0.5571339575573802, 'abosulate accuracy': 0.2520000101067126, 'consecutive overlap rate': 0.42561274617910383, 'overlap rate': 0.8461830109357834}
# evaluation performance: {'loss': 3.022162048332393, 'abosulate accuracy': 0.2639500146731734, 'consecutive overlap rate': 0.412120121344924, 'overlap rate': 0.5419952347874641}
#
# Current epoch: 170,
# training performance: {'loss': 0.5606993546709418, 'abosulate accuracy': 0.23690001303330063, 'consecutive overlap rate': 0.41497812718153, 'overlap rate': 0.8425649330019951}
# evaluation performance: {'loss': 2.955603492818773, 'abosulate accuracy': 0.25845001437701287, 'consecutive overlap rate': 0.41321278251707555, 'overlap rate': 0.5438399784266948}
#
# Current epoch: 175,
# training performance: {'loss': 0.5309606608003378, 'abosulate accuracy': 0.2537000120617449, 'consecutive overlap rate': 0.4332053057849407, 'overlap rate': 0.851282712817192}
# evaluation performance: {'loss': 3.012302862852812, 'abosulate accuracy': 0.28835001606494187, 'consecutive overlap rate': 0.4381217811256647, 'overlap rate': 0.5621567085385323}
#
# Current epoch: 180,
# training performance: {'loss': 0.5127871066331864, 'abosulate accuracy': 0.2512000098824501, 'consecutive overlap rate': 0.43282336443662645, 'overlap rate': 0.8552086040377617}
# evaluation performance: {'loss': 2.959468907676637, 'abosulate accuracy': 0.29355001226067545, 'consecutive overlap rate': 0.4448266040533781, 'overlap rate': 0.5676947757601738}
#
# Current epoch: 185,
# training performance: {'loss': 0.5193056622520089, 'abosulate accuracy': 0.25320001058280467, 'consecutive overlap rate': 0.43208004906773567, 'overlap rate': 0.853117062151432}
# evaluation performance: {'loss': 3.0196397162973883, 'abosulate accuracy': 0.2751000135205686, 'consecutive overlap rate': 0.4233578208833933, 'overlap rate': 0.5539845339953899}
#
# Current epoch: 190,
# training performance: {'loss': 0.49213604917749765, 'abosulate accuracy': 0.2583000114187598, 'consecutive overlap rate': 0.4341330986469984, 'overlap rate': 0.8604027777910233}
# evaluation performance: {'loss': 2.9691426867619155, 'abosulate accuracy': 0.2986000144854188, 'consecutive overlap rate': 0.44446972347795966, 'overlap rate': 0.5713957749307156}
#
# Current epoch: 195,
# training performance: {'loss': 0.4700616030022502, 'abosulate accuracy': 0.2684000089764595, 'consecutive overlap rate': 0.4450289588421583, 'overlap rate': 0.8665646374225616}
# evaluation performance: {'loss': 3.004293206892908, 'abosulate accuracy': 0.2882500134408474, 'consecutive overlap rate': 0.43684420436620713, 'overlap rate': 0.5662743426859379}
#
# Current epoch: 200,
# training performance: {'loss': 0.47301331972703337, 'abosulate accuracy': 0.26720001418143513, 'consecutive overlap rate': 0.4417809747159481, 'overlap rate': 0.8646980613470078}
# evaluation performance: {'loss': 2.9741849527694284, 'abosulate accuracy': 0.29895001333206894, 'consecutive overlap rate': 0.44561521522700787, 'overlap rate': 0.5738415271043777}
#
# Experiments_Logs/Experiment#7/RNN/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 8.093739998340606, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0041937500463973265, 'overlap rate': 0.041474587935954335}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.9510947784408925, 'abosulate accuracy': 0.30312501508742573, 'consecutive overlap rate': 0.44906408414244653, 'overlap rate': 0.5747612066566944}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.013005924224854, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003252267564511708, 'overlap rate': 0.1108738717532927}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.967387662710328, 'abosulate accuracy': 0.19205264114211068, 'consecutive overlap rate': 0.33416208977762024, 'overlap rate': 0.4459905071478141}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.660061943531036, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.017889576428569854, 'overlap rate': 0.25570259243249893}
# evaluation performance: {'loss': 3.02361136674881, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01842582770623267, 'overlap rate': 0.1587490115314722}
#
# Current epoch: 10,
# training performance: {'loss': 2.1471575140953063, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05762239615432918, 'overlap rate': 0.4211279757320881}
# evaluation performance: {'loss': 3.1168641567230226, 'abosulate accuracy': 0.00035000000498257576, 'consecutive overlap rate': 0.05130505049601197, 'overlap rate': 0.19257975053042173}
#
# Current epoch: 15,
# training performance: {'loss': 1.869127744436264, 'abosulate accuracy': 0.003400000196415931, 'consecutive overlap rate': 0.09282815987244249, 'overlap rate': 0.5012358240783215}
# evaluation performance: {'loss': 3.095960220694542, 'abosulate accuracy': 0.003850000270176679, 'consecutive overlap rate': 0.07970356061123311, 'overlap rate': 0.2271500241011381}
#
# Current epoch: 20,
# training performance: {'loss': 1.6730793133378028, 'abosulate accuracy': 0.014500000653788448, 'consecutive overlap rate': 0.13290497446432709, 'overlap rate': 0.5592511132359504}
# evaluation performance: {'loss': 3.0651013225317003, 'abosulate accuracy': 0.012250000750645995, 'consecutive overlap rate': 0.12111645825207233, 'overlap rate': 0.26789250746369364}
#
# Current epoch: 25,
# training performance: {'loss': 1.508528147637844, 'abosulate accuracy': 0.026000001362990587, 'consecutive overlap rate': 0.16558132451027632, 'overlap rate': 0.6040134944021702}
# evaluation performance: {'loss': 3.0276920974254606, 'abosulate accuracy': 0.027650001185247675, 'consecutive overlap rate': 0.15774649111554026, 'overlap rate': 0.3031221505254507}
#
# Current epoch: 30,
# training performance: {'loss': 1.3871765196323396, 'abosulate accuracy': 0.04160000201081857, 'consecutive overlap rate': 0.19161872789263726, 'overlap rate': 0.6355423532426357}
# evaluation performance: {'loss': 3.0284057766199113, 'abosulate accuracy': 0.041700002207653596, 'consecutive overlap rate': 0.18660493064671754, 'overlap rate': 0.32949431240558624}
#
# Current epoch: 35,
# training performance: {'loss': 1.2599480107426644, 'abosulate accuracy': 0.06410000168252736, 'consecutive overlap rate': 0.22045829519629478, 'overlap rate': 0.6700033485889435}
# evaluation performance: {'loss': 3.005767601728439, 'abosulate accuracy': 0.07095000363187864, 'consecutive overlap rate': 0.21934995502233506, 'overlap rate': 0.3590331319719553}
#
# Current epoch: 40,
# training performance: {'loss': 1.197149620950222, 'abosulate accuracy': 0.0784000020707026, 'consecutive overlap rate': 0.24298637825995684, 'overlap rate': 0.68499571159482}
# evaluation performance: {'loss': 3.037196050584316, 'abosulate accuracy': 0.08500000382191501, 'consecutive overlap rate': 0.24484084378927945, 'overlap rate': 0.37960519827902317}
#
# Current epoch: 45,
# training performance: {'loss': 1.1325327299535275, 'abosulate accuracy': 0.09250000428874046, 'consecutive overlap rate': 0.26354864072054623, 'overlap rate': 0.7024390533566475}
# evaluation performance: {'loss': 3.024717579782009, 'abosulate accuracy': 0.0992500045336783, 'consecutive overlap rate': 0.2639853501692414, 'overlap rate': 0.3944106478244066}
#
# Current epoch: 50,
# training performance: {'loss': 1.1004434540867805, 'abosulate accuracy': 0.09150000620866194, 'consecutive overlap rate': 0.2704220566898584, 'overlap rate': 0.7075216218829155}
# evaluation performance: {'loss': 3.07410229742527, 'abosulate accuracy': 0.10470000351779163, 'consecutive overlap rate': 0.2758761851117015, 'overlap rate': 0.4049183461815119}
#
# Current epoch: 55,
# training performance: {'loss': 1.0799343965947628, 'abosulate accuracy': 0.11040000462671742, 'consecutive overlap rate': 0.2861825285479426, 'overlap rate': 0.7137978293001652}
# evaluation performance: {'loss': 3.0211327724158763, 'abosulate accuracy': 0.12175000482238829, 'consecutive overlap rate': 0.29229952301830053, 'overlap rate': 0.4159868612885475}
#
# Current epoch: 60,
# training performance: {'loss': 1.0472430504858494, 'abosulate accuracy': 0.12500000422587618, 'consecutive overlap rate': 0.3047004327178001, 'overlap rate': 0.7252728313207626}
# evaluation performance: {'loss': 2.9910360015928745, 'abosulate accuracy': 0.13465000597061588, 'consecutive overlap rate': 0.3046445332467556, 'overlap rate': 0.42588082142174244}
#
# Current epoch: 65,
# training performance: {'loss': 1.056057345867157, 'abosulate accuracy': 0.12440000434871763, 'consecutive overlap rate': 0.30489735715091226, 'overlap rate': 0.7244089126586915}
# evaluation performance: {'loss': 3.028200303763151, 'abosulate accuracy': 0.12620000535389408, 'consecutive overlap rate': 0.296897673420608, 'overlap rate': 0.4220701761543751}
#
# Current epoch: 70,
# training performance: {'loss': 0.9971236951649189, 'abosulate accuracy': 0.1336000054841861, 'consecutive overlap rate': 0.3139834240078926, 'overlap rate': 0.7354677721858025}
# evaluation performance: {'loss': 2.9643832676112654, 'abosulate accuracy': 0.14540000836132094, 'consecutive overlap rate': 0.312075274810195, 'overlap rate': 0.4349418982863426}
#
# Current epoch: 75,
# training performance: {'loss': 0.9379949681460857, 'abosulate accuracy': 0.142900007404387, 'consecutive overlap rate': 0.3228998173028231, 'overlap rate': 0.7497946202754975}
# evaluation performance: {'loss': 2.973191127181053, 'abosulate accuracy': 0.15345000764355063, 'consecutive overlap rate': 0.32206082325428725, 'overlap rate': 0.4452994499355555}
#
# Current epoch: 80,
# training performance: {'loss': 0.9092118740081787, 'abosulate accuracy': 0.1524000079720281, 'consecutive overlap rate': 0.33155248071998356, 'overlap rate': 0.7573656678199768}
# evaluation performance: {'loss': 2.9868821404874324, 'abosulate accuracy': 0.15400000687805004, 'consecutive overlap rate': 0.32617104332894087, 'overlap rate': 0.449579655751586}
#
# Current epoch: 85,
# training performance: {'loss': 0.872147761285305, 'abosulate accuracy': 0.16370000769384205, 'consecutive overlap rate': 0.34357839096337556, 'overlap rate': 0.7650117367506027}
# evaluation performance: {'loss': 2.992298085987568, 'abosulate accuracy': 0.17195000640349462, 'consecutive overlap rate': 0.339788350649178, 'overlap rate': 0.461483159288764}
#
# Current epoch: 90,
# training performance: {'loss': 0.8577209457755088, 'abosulate accuracy': 0.17190000653499737, 'consecutive overlap rate': 0.3529855044558644, 'overlap rate': 0.7722884386777877}
# evaluation performance: {'loss': 2.9761445172131062, 'abosulate accuracy': 0.1729000095569063, 'consecutive overlap rate': 0.3419026728719473, 'overlap rate': 0.46332328729331496}
#
# Current epoch: 95,
# training performance: {'loss': 0.8223238293081522, 'abosulate accuracy': 0.17460000768769532, 'consecutive overlap rate': 0.3592796580865979, 'overlap rate': 0.7785463482141495}
# evaluation performance: {'loss': 2.935872360691428, 'abosulate accuracy': 0.18925000872695819, 'consecutive overlap rate': 0.35890703089535236, 'overlap rate': 0.4771114069968462}
#
# Current epoch: 100,
# training performance: {'loss': 0.8074156437069178, 'abosulate accuracy': 0.18070000703446568, 'consecutive overlap rate': 0.36490647662431, 'overlap rate': 0.7833800733089447}
# evaluation performance: {'loss': 2.947315988689661, 'abosulate accuracy': 0.19405001147533768, 'consecutive overlap rate': 0.36036636848002673, 'overlap rate': 0.48049909286201}
#
# Current epoch: 105,
# training performance: {'loss': 0.8026365391910076, 'abosulate accuracy': 0.18280000784434378, 'consecutive overlap rate': 0.36599135119467974, 'overlap rate': 0.783293004333973}
# evaluation performance: {'loss': 2.9134960982948543, 'abosulate accuracy': 0.20025001005851664, 'consecutive overlap rate': 0.36959835700690746, 'overlap rate': 0.4882009644061327}
#
# Current epoch: 110,
# training performance: {'loss': 0.784353194385767, 'abosulate accuracy': 0.1908000104711391, 'consecutive overlap rate': 0.3766999565064907, 'overlap rate': 0.7880206257104874}
# evaluation performance: {'loss': 2.9529625322669744, 'abosulate accuracy': 0.20900000983383507, 'consecutive overlap rate': 0.3783632591366768, 'overlap rate': 0.4971550151705742}
#
# Current epoch: 115,
# training performance: {'loss': 0.7549221608787775, 'abosulate accuracy': 0.19090000896248965, 'consecutive overlap rate': 0.37839564103633166, 'overlap rate': 0.7945505976676941}
# evaluation performance: {'loss': 2.913311865180731, 'abosulate accuracy': 0.2150500101153739, 'consecutive overlap rate': 0.37903014589101075, 'overlap rate': 0.4982363324612379}
#
# Current epoch: 120,
# training performance: {'loss': 0.7306427747011185, 'abosulate accuracy': 0.19160001061391085, 'consecutive overlap rate': 0.3720683794468641, 'overlap rate': 0.7988972619175911}
# evaluation performance: {'loss': 2.969711435958743, 'abosulate accuracy': 0.21035001028794795, 'consecutive overlap rate': 0.37203488536179063, 'overlap rate': 0.4963247962296009}
#
# Current epoch: 125,
# training performance: {'loss': 0.7078393552452326, 'abosulate accuracy': 0.1921000081812963, 'consecutive overlap rate': 0.3768770793452859, 'overlap rate': 0.807471764087677}
# evaluation performance: {'loss': 3.0015396498143674, 'abosulate accuracy': 0.22405001193983481, 'consecutive overlap rate': 0.38028787821531296, 'overlap rate': 0.504117314517498}
#
# Current epoch: 130,
# training performance: {'loss': 0.6696872770786285, 'abosulate accuracy': 0.209900009422563, 'consecutive overlap rate': 0.3921863973140717, 'overlap rate': 0.8149379372596741}
# evaluation performance: {'loss': 2.937806823477149, 'abosulate accuracy': 0.22750001125968994, 'consecutive overlap rate': 0.39046476017683746, 'overlap rate': 0.5136323750019074}
#
# Current epoch: 135,
# training performance: {'loss': 0.7170150931924582, 'abosulate accuracy': 0.19010000921553, 'consecutive overlap rate': 0.3756871746852994, 'overlap rate': 0.806386747956276}
# evaluation performance: {'loss': 3.0003093078732492, 'abosulate accuracy': 0.2168500111438334, 'consecutive overlap rate': 0.38394594080746175, 'overlap rate': 0.5118011813610792}
#
# Current epoch: 140,
# training performance: {'loss': 0.7022247437387705, 'abosulate accuracy': 0.20260001020506024, 'consecutive overlap rate': 0.38771408405154945, 'overlap rate': 0.8130616709589958}
# evaluation performance: {'loss': 3.1904995746910574, 'abosulate accuracy': 0.1309500049217604, 'consecutive overlap rate': 0.3324608730152249, 'overlap rate': 0.47833478152751924}
#
# Current epoch: 145,
# training performance: {'loss': 0.7235096309334039, 'abosulate accuracy': 0.19330000840127468, 'consecutive overlap rate': 0.3747412420809269, 'overlap rate': 0.8073042139410973}
# evaluation performance: {'loss': 3.122758749872446, 'abosulate accuracy': 0.18985000926768408, 'consecutive overlap rate': 0.34881199710071087, 'overlap rate': 0.48819283582270145}
#
# Current epoch: 150,
# training performance: {'loss': 0.6533621421083808, 'abosulate accuracy': 0.2286000109743327, 'consecutive overlap rate': 0.39963604845106604, 'overlap rate': 0.8243330895900727}
# evaluation performance: {'loss': 3.044750116020441, 'abosulate accuracy': 0.20540000891778618, 'consecutive overlap rate': 0.3678293900564313, 'overlap rate': 0.5033080641180276}
#
# Current epoch: 155,
# training performance: {'loss': 0.6073286946862936, 'abosulate accuracy': 0.22970000933855772, 'consecutive overlap rate': 0.408541302382946, 'overlap rate': 0.8326998710632324}
# evaluation performance: {'loss': 2.9292164236307143, 'abosulate accuracy': 0.2293500101659447, 'consecutive overlap rate': 0.39620292745530605, 'overlap rate': 0.5245598234236241}
#
# Current epoch: 160,
# training performance: {'loss': 0.5956968488171697, 'abosulate accuracy': 0.22720000906847418, 'consecutive overlap rate': 0.4051257960498333, 'overlap rate': 0.8339927852153778}
# evaluation performance: {'loss': 3.0309476163238287, 'abosulate accuracy': 0.19400000907480716, 'consecutive overlap rate': 0.384852634370327, 'overlap rate': 0.5208494227379561}
#
# Current epoch: 165,
# training performance: {'loss': 0.5943749578669667, 'abosulate accuracy': 0.22380001014098524, 'consecutive overlap rate': 0.4023368012160063, 'overlap rate': 0.8343250066041946}
# evaluation performance: {'loss': 2.969970040395856, 'abosulate accuracy': 0.2487000142224133, 'consecutive overlap rate': 0.402630658634007, 'overlap rate': 0.5345843218266964}
#
# Current epoch: 170,
# training performance: {'loss': 0.5689168322831393, 'abosulate accuracy': 0.23860001405701042, 'consecutive overlap rate': 0.4155289106070995, 'overlap rate': 0.8406501904129982}
# evaluation performance: {'loss': 2.9462934356182813, 'abosulate accuracy': 0.24355000890791417, 'consecutive overlap rate': 0.40215920265764, 'overlap rate': 0.5372978471219539}
#
# Current epoch: 175,
# training performance: {'loss': 0.5746029764413834, 'abosulate accuracy': 0.24980001193471252, 'consecutive overlap rate': 0.41990127563476565, 'overlap rate': 0.8407502636313439}
# evaluation performance: {'loss': 2.984560663253069, 'abosulate accuracy': 0.26575001180171964, 'consecutive overlap rate': 0.4134001167491078, 'overlap rate': 0.5449915509670973}
#
# Current epoch: 180,
# training performance: {'loss': 0.5418726658448577, 'abosulate accuracy': 0.24660001397132875, 'consecutive overlap rate': 0.4236903298646212, 'overlap rate': 0.8487159490585328}
# evaluation performance: {'loss': 2.9118848755955695, 'abosulate accuracy': 0.27500001322478057, 'consecutive overlap rate': 0.4243361234664917, 'overlap rate': 0.5529908977448941}
#
# Current epoch: 185,
# training performance: {'loss': 0.538937184214592, 'abosulate accuracy': 0.2498000120744109, 'consecutive overlap rate': 0.4239072546362877, 'overlap rate': 0.8487129390239716}
# evaluation performance: {'loss': 2.957521244324744, 'abosulate accuracy': 0.2792500102892518, 'consecutive overlap rate': 0.4276977241039276, 'overlap rate': 0.5566133432090282}
#
# Current epoch: 190,
# training performance: {'loss': 0.5125199289992451, 'abosulate accuracy': 0.25920001287013295, 'consecutive overlap rate': 0.4349064201116562, 'overlap rate': 0.8563034027814865}
# evaluation performance: {'loss': 2.9731823045760395, 'abosulate accuracy': 0.28245001267641784, 'consecutive overlap rate': 0.42996219620108606, 'overlap rate': 0.5599426239728927}
#
# Current epoch: 195,
# training performance: {'loss': 0.4914045941084623, 'abosulate accuracy': 0.2567000132985413, 'consecutive overlap rate': 0.4337775561958551, 'overlap rate': 0.8600388169288635}
# evaluation performance: {'loss': 2.941821286827326, 'abosulate accuracy': 0.2944500122219324, 'consecutive overlap rate': 0.43980025202035905, 'overlap rate': 0.5682764403522015}
#
# Current epoch: 200,
# training performance: {'loss': 0.49456233307719233, 'abosulate accuracy': 0.2700000121258199, 'consecutive overlap rate': 0.44302439466118815, 'overlap rate': 0.8603692516684532}
# evaluation performance: {'loss': 2.986026079207659, 'abosulate accuracy': 0.2723500127904117, 'consecutive overlap rate': 0.4279157008975744, 'overlap rate': 0.559877947717905}
#
# Experiments_Logs/Experiment#7/RNN/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 8.232037627696991, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004018750049726805, 'overlap rate': 0.03812750412616879}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.9513348780572413, 'abosulate accuracy': 0.2950500139966607, 'consecutive overlap rate': 0.439879435300827, 'overlap rate': 0.568964409083128}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.948852296029368, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003015525320229391, 'overlap rate': 0.05095877719502295}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.950847084977125, 'abosulate accuracy': 0.20707895705709234, 'consecutive overlap rate': 0.3344193336210753, 'overlap rate': 0.44544755706661626}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.70424302816391, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014013391523621976, 'overlap rate': 0.24432295188307762}
# evaluation performance: {'loss': 3.0546847224235534, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016470580047462137, 'overlap rate': 0.1495005626231432}
#
# Current epoch: 10,
# training performance: {'loss': 2.175106179714203, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05835577310062945, 'overlap rate': 0.4095420971512794}
# evaluation performance: {'loss': 3.1398181200027464, 'abosulate accuracy': 0.0004500000097323209, 'consecutive overlap rate': 0.05534465834498405, 'overlap rate': 0.1887317467480898}
#
# Current epoch: 15,
# training performance: {'loss': 1.9058342903852463, 'abosulate accuracy': 0.0028000001097097994, 'consecutive overlap rate': 0.09864048417657614, 'overlap rate': 0.4941925212740898}
# evaluation performance: {'loss': 3.1131579905748366, 'abosulate accuracy': 0.0037500002537854014, 'consecutive overlap rate': 0.08733974732458591, 'overlap rate': 0.22507680766284466}
#
# Current epoch: 20,
# training performance: {'loss': 1.6999356657266618, 'abosulate accuracy': 0.012600000435486435, 'consecutive overlap rate': 0.1386713532730937, 'overlap rate': 0.5527473278343678}
# evaluation performance: {'loss': 3.0965886384248735, 'abosulate accuracy': 0.011800000234507025, 'consecutive overlap rate': 0.12690106527879835, 'overlap rate': 0.2664061293005943}
#
# Current epoch: 25,
# training performance: {'loss': 1.5278080388903619, 'abosulate accuracy': 0.027900001034140587, 'consecutive overlap rate': 0.17732361983507872, 'overlap rate': 0.6005300670862198}
# evaluation performance: {'loss': 3.0456395953893662, 'abosulate accuracy': 0.030200001242337748, 'consecutive overlap rate': 0.16903499532490968, 'overlap rate': 0.30614420026540756}
#
# Current epoch: 30,
# training performance: {'loss': 1.406700710952282, 'abosulate accuracy': 0.0487000014516525, 'consecutive overlap rate': 0.212520394846797, 'overlap rate': 0.6335069887340069}
# evaluation performance: {'loss': 2.978780047595501, 'abosulate accuracy': 0.050650001742178576, 'consecutive overlap rate': 0.20362706016749144, 'overlap rate': 0.33764549605548383}
#
# Current epoch: 35,
# training performance: {'loss': 1.3148275718092919, 'abosulate accuracy': 0.06500000290106982, 'consecutive overlap rate': 0.23732595331966877, 'overlap rate': 0.6558537773787976}
# evaluation performance: {'loss': 2.9437860578298567, 'abosulate accuracy': 0.0699500031536445, 'consecutive overlap rate': 0.2330944910645485, 'overlap rate': 0.36454758122563363}
#
# Current epoch: 40,
# training performance: {'loss': 1.235254043340683, 'abosulate accuracy': 0.08510000449605286, 'consecutive overlap rate': 0.25999046247452495, 'overlap rate': 0.6771044552326202}
# evaluation performance: {'loss': 2.9514719650149344, 'abosulate accuracy': 0.09065000546397642, 'consecutive overlap rate': 0.2584281377494335, 'overlap rate': 0.3893590223044157}
#
# Current epoch: 45,
# training performance: {'loss': 1.1615161180496216, 'abosulate accuracy': 0.09490000538062304, 'consecutive overlap rate': 0.27476101778447626, 'overlap rate': 0.6955920130014419}
# evaluation performance: {'loss': 2.9043719112873077, 'abosulate accuracy': 0.10885000443086028, 'consecutive overlap rate': 0.2776917291805148, 'overlap rate': 0.40812602154910566}
#
# Current epoch: 50,
# training performance: {'loss': 1.1042124301195144, 'abosulate accuracy': 0.11570000554202124, 'consecutive overlap rate': 0.29503217674791815, 'overlap rate': 0.7122849367558957}
# evaluation performance: {'loss': 2.937158170342445, 'abosulate accuracy': 0.11185000505647621, 'consecutive overlap rate': 0.28383666798472407, 'overlap rate': 0.41548151075839995}
#
# Current epoch: 55,
# training performance: {'loss': 1.024599315226078, 'abosulate accuracy': 0.1359000051394105, 'consecutive overlap rate': 0.3151719203218818, 'overlap rate': 0.7315414689481259}
# evaluation performance: {'loss': 2.8671749107539655, 'abosulate accuracy': 0.13795000643003733, 'consecutive overlap rate': 0.3121790198609233, 'overlap rate': 0.4400944359600544}
#
# Current epoch: 60,
# training performance: {'loss': 0.982941846549511, 'abosulate accuracy': 0.14540000715060158, 'consecutive overlap rate': 0.3273847123607993, 'overlap rate': 0.7423765562474728}
# evaluation performance: {'loss': 2.904451607167721, 'abosulate accuracy': 0.1493500081880484, 'consecutive overlap rate': 0.32460292261093854, 'overlap rate': 0.4519030783325434}
#
# Current epoch: 65,
# training performance: {'loss': 0.9563294626772404, 'abosulate accuracy': 0.15680000816937537, 'consecutive overlap rate': 0.3355523904785514, 'overlap rate': 0.7500870607793331}
# evaluation performance: {'loss': 2.8614629447460174, 'abosulate accuracy': 0.1549000094179064, 'consecutive overlap rate': 0.3278716094791889, 'overlap rate': 0.4551286093890667}
#
# Current epoch: 70,
# training performance: {'loss': 0.8904045470058918, 'abosulate accuracy': 0.16990000841906294, 'consecutive overlap rate': 0.3503956923261285, 'overlap rate': 0.766596582531929}
# evaluation performance: {'loss': 2.829667540639639, 'abosulate accuracy': 0.18130000866949558, 'consecutive overlap rate': 0.35234079547226427, 'overlap rate': 0.47687074169516563}
#
# Current epoch: 75,
# training performance: {'loss': 0.8521523650735616, 'abosulate accuracy': 0.179400010232348, 'consecutive overlap rate': 0.3578975511714816, 'overlap rate': 0.7752971649169922}
# evaluation performance: {'loss': 2.8700255163013937, 'abosulate accuracy': 0.1941000087419525, 'consecutive overlap rate': 0.3616790181025863, 'overlap rate': 0.4849720988422632}
#
# Current epoch: 80,
# training performance: {'loss': 0.8277981668710709, 'abosulate accuracy': 0.18690000919159502, 'consecutive overlap rate': 0.3678006449714303, 'overlap rate': 0.7810301899909973}
# evaluation performance: {'loss': 2.873634399473667, 'abosulate accuracy': 0.2028000082122162, 'consecutive overlap rate': 0.3709602616727352, 'overlap rate': 0.4931984569877386}
#
# Current epoch: 85,
# training performance: {'loss': 0.7917078275233507, 'abosulate accuracy': 0.1986000093864277, 'consecutive overlap rate': 0.38078770264983175, 'overlap rate': 0.7899286299943924}
# evaluation performance: {'loss': 2.8734377928078176, 'abosulate accuracy': 0.21505000984179787, 'consecutive overlap rate': 0.3846065945923328, 'overlap rate': 0.5048536688089371}
#
# Current epoch: 90,
# training performance: {'loss': 0.7773771613836289, 'abosulate accuracy': 0.2042000105022453, 'consecutive overlap rate': 0.38772795870900156, 'overlap rate': 0.7939397424459458}
# evaluation performance: {'loss': 2.9007309384644033, 'abosulate accuracy': 0.2142000086256303, 'consecutive overlap rate': 0.3862423712387681, 'overlap rate': 0.5072058357298375}
#
# Current epoch: 95,
# training performance: {'loss': 0.7393076550215483, 'abosulate accuracy': 0.20890001023653895, 'consecutive overlap rate': 0.39484206959605217, 'overlap rate': 0.8025508195161819}
# evaluation performance: {'loss': 2.8621699918061494, 'abosulate accuracy': 0.22630000912467949, 'consecutive overlap rate': 0.3963416486978531, 'overlap rate': 0.5154134672135114}
#
# Current epoch: 100,
# training performance: {'loss': 0.7148860357701778, 'abosulate accuracy': 0.2137000117218122, 'consecutive overlap rate': 0.4004810657352209, 'overlap rate': 0.8081681683659554}
# evaluation performance: {'loss': 2.8450489841401576, 'abosulate accuracy': 0.24150001177331432, 'consecutive overlap rate': 0.40771763026714325, 'overlap rate': 0.5248116832226515}
#
# Current epoch: 105,
# training performance: {'loss': 0.7092350963503122, 'abosulate accuracy': 0.2019000075641088, 'consecutive overlap rate': 0.392370992526412, 'overlap rate': 0.8077230840921402}
# evaluation performance: {'loss': 2.8712408863008023, 'abosulate accuracy': 0.23955001144204288, 'consecutive overlap rate': 0.40482934303581714, 'overlap rate': 0.5245070990175009}
#
# Current epoch: 110,
# training performance: {'loss': 0.683028357103467, 'abosulate accuracy': 0.21500000902451574, 'consecutive overlap rate': 0.4030991356819868, 'overlap rate': 0.815328349173069}
# evaluation performance: {'loss': 2.8704528279602526, 'abosulate accuracy': 0.24830001234076918, 'consecutive overlap rate': 0.4124447714537382, 'overlap rate': 0.5322333067655564}
#
# Current epoch: 115,
# training performance: {'loss': 0.6539070673286915, 'abosulate accuracy': 0.2202000118792057, 'consecutive overlap rate': 0.4090154379606247, 'overlap rate': 0.8221480414271355}
# evaluation performance: {'loss': 2.8768200773745773, 'abosulate accuracy': 0.2561000150628388, 'consecutive overlap rate': 0.4196388140320778, 'overlap rate': 0.5389691326767206}
#
# Current epoch: 120,
# training performance: {'loss': 0.6437261164188385, 'abosulate accuracy': 0.22590001022908837, 'consecutive overlap rate': 0.41123655065894127, 'overlap rate': 0.8231515049934387}
# evaluation performance: {'loss': 2.9002135924994947, 'abosulate accuracy': 0.261050012242049, 'consecutive overlap rate': 0.4209473397582769, 'overlap rate': 0.5421509396284818}
#
# Current epoch: 125,
# training performance: {'loss': 0.6231071332469582, 'abosulate accuracy': 0.2262000106740743, 'consecutive overlap rate': 0.41024273373186587, 'overlap rate': 0.8285540699958801}
# evaluation performance: {'loss': 2.8989776756614445, 'abosulate accuracy': 0.2641500117257237, 'consecutive overlap rate': 0.422047583386302, 'overlap rate': 0.5444099918007851}
#
# Current epoch: 130,
# training performance: {'loss': 0.6072316793724895, 'abosulate accuracy': 0.23370001062285156, 'consecutive overlap rate': 0.4178731881082058, 'overlap rate': 0.8331836313009262}
# evaluation performance: {'loss': 2.9116458777338265, 'abosulate accuracy': 0.2659500132314861, 'consecutive overlap rate': 0.4223117046058178, 'overlap rate': 0.5455446489155292}
#
# Current epoch: 135,
# training performance: {'loss': 0.5833753639832139, 'abosulate accuracy': 0.24340001130476593, 'consecutive overlap rate': 0.42635237984359264, 'overlap rate': 0.8395169034600258}
# evaluation performance: {'loss': 2.914193006232381, 'abosulate accuracy': 0.2709000138565898, 'consecutive overlap rate': 0.4303040735423565, 'overlap rate': 0.5522559963166713}
#
# Current epoch: 140,
# training performance: {'loss': 0.5783885717391968, 'abosulate accuracy': 0.24390001259744168, 'consecutive overlap rate': 0.4277199096977711, 'overlap rate': 0.8394200667738915}
# evaluation performance: {'loss': 2.9178073087707164, 'abosulate accuracy': 0.27630001017823813, 'consecutive overlap rate': 0.4343664016574621, 'overlap rate': 0.55679317638278}
#
# Current epoch: 145,
# training performance: {'loss': 0.5509194120764732, 'abosulate accuracy': 0.2549000110477209, 'consecutive overlap rate': 0.43152521178126335, 'overlap rate': 0.8474898904561996}
# evaluation performance: {'loss': 2.926048733107746, 'abosulate accuracy': 0.27715001367032527, 'consecutive overlap rate': 0.43343369513750074, 'overlap rate': 0.5580147251486778}
#
# Current epoch: 150,
# training performance: {'loss': 0.5555435018613935, 'abosulate accuracy': 0.24700001133605837, 'consecutive overlap rate': 0.4261991549283266, 'overlap rate': 0.8453790038824082}
# evaluation performance: {'loss': 2.917170681990683, 'abosulate accuracy': 0.2747500132769346, 'consecutive overlap rate': 0.4324048563838005, 'overlap rate': 0.5590553179383277}
#
# Current epoch: 155,
# training performance: {'loss': 0.5216781591996551, 'abosulate accuracy': 0.263700011279434, 'consecutive overlap rate': 0.44213684312999246, 'overlap rate': 0.8545976504683495}
# evaluation performance: {'loss': 2.929451544582844, 'abosulate accuracy': 0.2926000127568841, 'consecutive overlap rate': 0.4483063627034426, 'overlap rate': 0.5702837884426117}
#
# Current epoch: 160,
# training performance: {'loss': 0.5383693594485521, 'abosulate accuracy': 0.25240001259371636, 'consecutive overlap rate': 0.4335349202156067, 'overlap rate': 0.8484052643179893}
# evaluation performance: {'loss': 2.937143712490797, 'abosulate accuracy': 0.28740001320838926, 'consecutive overlap rate': 0.4389956220984459, 'overlap rate': 0.5659575223922729}
#
# Current epoch: 165,
# training performance: {'loss': 0.4869827913120389, 'abosulate accuracy': 0.27310001142323015, 'consecutive overlap rate': 0.4474639121443033, 'overlap rate': 0.8637798324227333}
# evaluation performance: {'loss': 2.9287506213411687, 'abosulate accuracy': 0.3020500148588326, 'consecutive overlap rate': 0.44891744926571847, 'overlap rate': 0.5748073264956475}
#
# Current epoch: 170,
# training performance: {'loss': 0.4647280307486653, 'abosulate accuracy': 0.2837000135332346, 'consecutive overlap rate': 0.4543593067675829, 'overlap rate': 0.8703537568449974}
# evaluation performance: {'loss': 2.9119047105312346, 'abosulate accuracy': 0.3077500144019723, 'consecutive overlap rate': 0.455745829641819, 'overlap rate': 0.5807996928691864}
#
# Current epoch: 175,
# training performance: {'loss': 0.4590522011741996, 'abosulate accuracy': 0.2824000157415867, 'consecutive overlap rate': 0.4561119329184294, 'overlap rate': 0.870505402982235}
# evaluation performance: {'loss': 2.9080597681924703, 'abosulate accuracy': 0.31120001682429577, 'consecutive overlap rate': 0.46075935252010825, 'overlap rate': 0.5864723049104213}
#
# Current epoch: 180,
# training performance: {'loss': 0.4506231934763491, 'abosulate accuracy': 0.2826000157743692, 'consecutive overlap rate': 0.46142597422003745, 'overlap rate': 0.8727347135543824}
# evaluation performance: {'loss': 2.930565516464412, 'abosulate accuracy': 0.31080001424998044, 'consecutive overlap rate': 0.46158756911754606, 'overlap rate': 0.5887359395623207}
#
# Current epoch: 185,
# training performance: {'loss': 0.4496378322131932, 'abosulate accuracy': 0.27170000970363617, 'consecutive overlap rate': 0.44923729076981544, 'overlap rate': 0.8721231311559677}
# evaluation performance: {'loss': 2.882391677238047, 'abosulate accuracy': 0.31945001557469366, 'consecutive overlap rate': 0.46482629217207433, 'overlap rate': 0.5905956402420998}
#
# Current epoch: 190,
# training performance: {'loss': 0.4395440538413823, 'abosulate accuracy': 0.2826000114902854, 'consecutive overlap rate': 0.46017191745340824, 'overlap rate': 0.8745819583535195}
# ...
# evaluation performance: {'loss': 3.14997638463974, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0028890112589579076, 'overlap rate': 0.0425815743394196}
#
# Current epoch: 135,
# training performance: {'loss': 3.060582822561264, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004671771571156569, 'overlap rate': 0.07678377814590931}
# evaluation performance: {'loss': 3.148883932828903, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0032345686544431374, 'overlap rate': 0.04325502458959818}
#
# Current epoch: 140,
# training performance: {'loss': 3.0522129774093627, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004848197512910701, 'overlap rate': 0.0788842293433845}
# evaluation performance: {'loss': 3.1472189128398895, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0035357048938749356, 'overlap rate': 0.04402080811560154}
#
# Current epoch: 145,
# training performance: {'loss': 3.0382321655750273, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005196790065383539, 'overlap rate': 0.08266507992520929}
# evaluation performance: {'loss': 3.147333598136902, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0035206493805162607, 'overlap rate': 0.04401048347353935}
#
# Current epoch: 150,
# training performance: {'loss': 3.048244482278824, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0050931832025526095, 'overlap rate': 0.0796611936762929}
# evaluation performance: {'loss': 3.1441806852817535, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003535548847867176, 'overlap rate': 0.044645218458026645}
#
# Current epoch: 155,
# training performance: {'loss': 3.033015584945679, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0053930843860143796, 'overlap rate': 0.0831263866275549}
# evaluation performance: {'loss': 3.144161653518677, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003492332581663504, 'overlap rate': 0.044990080688148734}
#
# Current epoch: 160,
# training performance: {'loss': 3.02280712723732, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005617822307976894, 'overlap rate': 0.08745714761316777}
# evaluation performance: {'loss': 3.1409453630447386, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00364693877636455, 'overlap rate': 0.04656934849917889}
#
# Current epoch: 165,
# training performance: {'loss': 3.0141887843608854, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005779559395159594, 'overlap rate': 0.08908073203638196}
# evaluation performance: {'loss': 3.1459474742412565, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003628963194205426, 'overlap rate': 0.04562263432890177}
#
# Current epoch: 170,
# training performance: {'loss': 3.026559978723526, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005739410495152697, 'overlap rate': 0.08552267123013735}
# evaluation performance: {'loss': 3.141026312112808, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0036596964055206627, 'overlap rate': 0.046386624686419964}
#
# Current epoch: 175,
# training performance: {'loss': 3.012535059452057, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005942108354065567, 'overlap rate': 0.08955688811838627}
# evaluation performance: {'loss': 3.1410557329654694, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038243474235059695, 'overlap rate': 0.047452579252421856}
#
# Current epoch: 180,
# training performance: {'loss': 3.00278217792511, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005959218935458921, 'overlap rate': 0.09303582096472382}
# evaluation performance: {'loss': 3.139135003089905, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003830366802867502, 'overlap rate': 0.04762609023600817}
#
# Current epoch: 185,
# training performance: {'loss': 2.9913207232952117, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0058628426515497266, 'overlap rate': 0.09389434987679124}
# evaluation performance: {'loss': 3.144742822647095, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038911198294954374, 'overlap rate': 0.0469908450730145}
#
# Current epoch: 190,
# training performance: {'loss': 2.989841842651367, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005932762651355006, 'overlap rate': 0.09506672946736217}
# evaluation performance: {'loss': 3.141961228847504, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003961345585412346, 'overlap rate': 0.048332682345062494}
#
# Current epoch: 195,
# training performance: {'loss': 2.970426046848297, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0061020269728032876, 'overlap rate': 0.10096820034086704}
# evaluation performance: {'loss': 3.1423880457878113, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004209525883197784, 'overlap rate': 0.04882135596126318}
#
# Current epoch: 200,
# training performance: {'loss': 2.973666900396347, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006057571468409151, 'overlap rate': 0.098495071567595}
# evaluation performance: {'loss': 3.1402666687965395, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0042950833943905305, 'overlap rate': 0.048529840912669896}
#
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#7/RNN/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 5.390604734420776, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013920833625888918, 'overlap rate': 0.02767875281861052}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.13947474360466, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004319015803048387, 'overlap rate': 0.048644542880356315}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.418483318821076, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009716624022281218, 'overlap rate': 0.038398100195392484}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.297609749593233, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003044932572122075, 'overlap rate': 0.041772981027239246}
# Experiments_Logs/Experiment#7/RNN/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.2807277858257295, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001710522992652841, 'overlap rate': 0.03762741973623633}
# evaluation performance: {'loss': 3.312228614091873, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015957771654939279, 'overlap rate': 0.038949529826641086}
#
# Current epoch: 10,
# training performance: {'loss': 3.2583446145057677, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002379060402745381, 'overlap rate': 0.038492672331631186}
# evaluation performance: {'loss': 3.289793407917023, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018801214428094681, 'overlap rate': 0.0393133501522243}
#
# Current epoch: 15,
# training performance: {'loss': 3.2512437760829926, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002497787124593742, 'overlap rate': 0.041395517392084004}
# evaluation performance: {'loss': 3.2707929372787476, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020799963793251665, 'overlap rate': 0.04223918141797185}
#
# Current epoch: 20,
# training performance: {'loss': 3.277925783395767, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025360113810165784, 'overlap rate': 0.041537678753957155}
# evaluation performance: {'loss': 3.292348062992096, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002317962145025376, 'overlap rate': 0.040994465723633765}
#
# Current epoch: 25,
# training performance: {'loss': 3.2470342099666594, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002945914184965659, 'overlap rate': 0.04416636219248175}
# evaluation performance: {'loss': 3.2864543318748476, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025407210967387074, 'overlap rate': 0.04190836464986205}
#
# Current epoch: 30,
# training performance: {'loss': 3.2527191281318664, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0033357197156874464, 'overlap rate': 0.042712597316130994}
# evaluation performance: {'loss': 3.276604676246643, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025535449429298753, 'overlap rate': 0.04010054245591164}
#
# Current epoch: 35,
# training performance: {'loss': 3.2918336987495422, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014934705672203564, 'overlap rate': 0.03124950542114675}
# evaluation performance: {'loss': 3.30791015625, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015255416059517302, 'overlap rate': 0.03845499763265252}
#
# Current epoch: 40,
# training performance: {'loss': 3.2971853017807007, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0017159872324555181, 'overlap rate': 0.031544465955812485}
# evaluation performance: {'loss': 3.3074037373065948, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001432397699682042, 'overlap rate': 0.03828846663236618}
#
# Current epoch: 45,
# training performance: {'loss': 3.267841476202011, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0017371291032759473, 'overlap rate': 0.03611676516011357}
# evaluation performance: {'loss': 3.2863932073116304, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00147491588286357, 'overlap rate': 0.03877124907448888}
#
# Current epoch: 50,
# training performance: {'loss': 3.2655252397060393, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001843588908377569, 'overlap rate': 0.035831792885437606}
# evaluation performance: {'loss': 3.2762094497680665, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014621034330048132, 'overlap rate': 0.038037289213389155}
#
# Current epoch: 55,
# training performance: {'loss': 3.262462329864502, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019663041428430008, 'overlap rate': 0.035874793166294695}
# evaluation performance: {'loss': 3.2729322254657744, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014303984375146684, 'overlap rate': 0.03302936688996851}
#
# Current epoch: 60,
# training performance: {'loss': 3.240591770410538, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00197575778583996, 'overlap rate': 0.04186243093572557}
# evaluation performance: {'loss': 3.278254598379135, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015956976902089081, 'overlap rate': 0.03436790886335075}
#
# Current epoch: 65,
# training performance: {'loss': 3.246946406364441, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003119756428350229, 'overlap rate': 0.042871727142482996}
# evaluation performance: {'loss': 3.273971849679947, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0027580974972806873, 'overlap rate': 0.04283747272565961}
#
# Current epoch: 70,
# training performance: {'loss': 3.241632753610611, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0046140194230247285, 'overlap rate': 0.04288099841214717}
# evaluation performance: {'loss': 3.252361959218979, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004576607292983681, 'overlap rate': 0.043864162359386685}
#
# Current epoch: 75,
# training performance: {'loss': 3.2098863244056703, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005379779590293765, 'overlap rate': 0.05035979887470603}
# evaluation performance: {'loss': 3.239059853553772, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005200426810188219, 'overlap rate': 0.042579675931483506}
#
# Current epoch: 80,
# training performance: {'loss': 3.2294128119945524, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005607245364808477, 'overlap rate': 0.047994840703904626}
# evaluation performance: {'loss': 3.2602341890335085, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005113306723069399, 'overlap rate': 0.04668679237365723}
#
# Current epoch: 85,
# training performance: {'loss': 3.189751935005188, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005646076524863019, 'overlap rate': 0.052811537962406875}
# evaluation performance: {'loss': 3.2289908707141874, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004778608708875254, 'overlap rate': 0.04102141177281737}
#
# Current epoch: 90,
# training performance: {'loss': 3.1562480032444, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005598114302847535, 'overlap rate': 0.05960551928728819}
# evaluation performance: {'loss': 3.2782489240169523, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0028333684924291445, 'overlap rate': 0.04118087943643332}
#
# Current epoch: 95,
# training performance: {'loss': 3.135769486427307, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005918234205455519, 'overlap rate': 0.06143955569714308}
# evaluation performance: {'loss': 3.156202232837677, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004489205777645111, 'overlap rate': 0.044558489322662355}
#
# Current epoch: 100,
# training performance: {'loss': 3.09321511387825, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006086156584206037, 'overlap rate': 0.07078199787065387}
# evaluation performance: {'loss': 3.1614945113658903, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004982143655070104, 'overlap rate': 0.04642017427831888}
#
# Current epoch: 105,
# training performance: {'loss': 3.2012485802173614, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005381611225311644, 'overlap rate': 0.058412691485136746}
# evaluation performance: {'loss': 3.240368491411209, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004739930899813771, 'overlap rate': 0.0423598007299006}
#
# Current epoch: 110,
# training performance: {'loss': 3.097847604751587, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00578935443481896, 'overlap rate': 0.07442985819652677}
# evaluation performance: {'loss': 3.2005545020103456, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004247089574346319, 'overlap rate': 0.04222191581502557}
#
# Current epoch: 115,
# training performance: {'loss': 3.0743059694766997, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005478249269071966, 'overlap rate': 0.08004537345841527}
# evaluation performance: {'loss': 3.1653428614139556, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0043605759652564306, 'overlap rate': 0.04520127521827817}
#
# Current epoch: 120,
# training performance: {'loss': 3.057026559114456, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005455311527475715, 'overlap rate': 0.08512881295755506}
# evaluation performance: {'loss': 3.1831825613975524, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00411423628393095, 'overlap rate': 0.04281126223504543}
#
# Current epoch: 125,
# training performance: {'loss': 3.1003739178180694, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005489527745521627, 'overlap rate': 0.08071166016161442}
# evaluation performance: {'loss': 3.1910083472728727, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004414570052176714, 'overlap rate': 0.0432556658051908}
#
# Current epoch: 130,
# training performance: {'loss': 3.0505235731601714, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005272911416250281, 'overlap rate': 0.0860049401409924}
# evaluation performance: {'loss': 3.181316393613815, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004725214766222052, 'overlap rate': 0.04409904312342405}

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
