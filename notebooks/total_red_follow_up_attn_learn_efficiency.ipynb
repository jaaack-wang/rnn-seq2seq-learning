# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import random
import pandas as pd 
from string import ascii_lowercase
from IPython.display import clear_output

from os import makedirs
from os.path import join

import torch.nn as nn
import torch.optim as optim

from scripts.utils import read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.visualization import plot_training_log, plot_performances_per_seq_len
from scripts.pytorch_utils import get_model, count_parameters, train_and_evaluate, evaluate, get_results

# %% [markdown]
# ## Log time and random seeds

# %%
from datetime import datetime
import random 
import numpy as np
import torch

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))

seed = 3266473
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# Out:
# Time stamp: 2023-02-08 03:58:49

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/total_red")
train_new, dev_new = [], []

# reduce the train and dev set size to 1/4 of the original size
# 1000 --> 250
for i in range(0, len(train), 1000):
    train_new.extend(train[i: i+250])
    dev_new.extend(dev[i: i+250])

train = train_new
dev = dev_new

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (2500, 2500, 50000, 100000)

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=250, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Experiments

# %%
task_name = "total_red_attn_learn_efficiency"

metadata = []
main_results = []
task_folder = join("experiments", task_name)
meta_col = ["RNN", "Attention", "lr", "Hidden size", "Embedding size", "Param #", "Max Epoch #"]
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]


for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True]: # --> only test attentional models
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            embd_dim = 128
            hidden_size = 128 # 512 --> 128
            learning_rate = 5e-4
            weight_decay = 1e-5
            max_epoch_num = 500
            
            ModelConfig = {"rnn_type": rnn_type,
                           "embd_dim": embd_dim,
                           "hidden_size": hidden_size,
                           "device": "cuda",
                           "num_layers": 1,
                           "dropout_rate": 0.0,
                           "use_attention": use_attn,
                           "bidirectional": False,
                           "in_vocab_size": len(in_vocab) + 2, # for the two boundary symbols 
                           "out_vocab_size": len(out_vocab) + 2, # for the two boundary symbols 
                           "reduction_method": "sum"}
            
            model = get_model(ModelConfig)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)
            
            saved_model_fp = join(folder, "model.pt")
            log = train_and_evaluate(model, train_dl, dev_dl, 
                                     criterion, optimizer, 
                                     saved_model_fp=saved_model_fp, 
                                     acc_threshold=-0.1, 
                                     print_eval_freq=10, 
                                     max_epoch_num=max_epoch_num, 
                                     train_exit_acc=0.9999, 
                                     eval_exit_acc=0.995, 
                                     teacher_forcing_ratio=1.0)
            
            save_dict_as_json(log, join(folder, "training_log.json"))
            save_dict_as_json(ModelConfig, join(folder, "ModelConfig.json"))
            plot_training_log(log, show_plot=False, saved_plot_fp=join(folder, "training_plot.png"))
            
            train_res, dev_res = get_results(log, train_log=True)
            
            _, perfs_train = evaluate(model, train_dl, criterion, 
                                      per_seq_len_performance=True)
            _, perfs_dev = evaluate(model, dev_dl, criterion, 
                                      per_seq_len_performance=True)
            
            test_aggr, perfs_test = evaluate(model, test_dl, criterion, 
                                             per_seq_len_performance=True)
            
            gen_aggr, perfs_gen = evaluate(model, gen_dl, criterion, 
                                             per_seq_len_performance=True)
            
            test_res = get_results(test_aggr, train_log=False)
            gen_res = get_results(gen_aggr, train_log=False)
            
            for res, ds in zip([train_res, dev_res, test_res, gen_res], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + res)
                       
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))
            
            clear_output(wait=True)
        
        param_num = count_parameters(model)
        metadata.append([rnn_type, use_attn, learning_rate, hidden_size, embd_dim, param_num, max_epoch_num])

pd.DataFrame(metadata, columns=meta_col).to_csv(join(task_folder, "metadata.csv"), index=False)
pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: LSTM; use attention: True; run num: 3
#
# The model has 373,532 trainable parameters
# Current epoch: 10,
# training performance: {'loss': 2.8562182664871214, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005573921192228413, 'overlap rate': 0.17062698782824937}
# evaluation performance: {'loss': 2.8701900959014894, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.005187315871582064, 'overlap rate': 0.1666924921562967}
#
# Current epoch: 20,
# training performance: {'loss': 2.6574044227600098, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.008793997334175185, 'overlap rate': 0.1856728561434544}
# evaluation performance: {'loss': 2.6747080802917482, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.008046132627577193, 'overlap rate': 0.18487598308237946}
#
# Current epoch: 30,
# training performance: {'loss': 2.6148274660110475, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.016894469110720324, 'overlap rate': 0.18465522600826406}
# evaluation performance: {'loss': 2.6370132207870483, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.01518354701188697, 'overlap rate': 0.18478517251255505}
#
# Current epoch: 40,
# training performance: {'loss': 2.6366586208343508, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.025995669439563336, 'overlap rate': 0.21414127816886303}
# evaluation performance: {'loss': 2.6593157052993774, 'full sequence accuracy': 0.0, 'first n-symbol accuracy': 0.024101218078586933, 'overlap rate': 0.20814057524321514}
#
# Current epoch: 50,
# training performance: {'loss': 2.666171669960022, 'full sequence accuracy': 0.0012000000000000001, 'first n-symbol accuracy': 0.038021500431704304, 'overlap rate': 0.237785470286433}
# evaluation performance: {'loss': 2.706869959831238, 'full sequence accuracy': 0.0004, 'first n-symbol accuracy': 0.0334871125475395, 'overlap rate': 0.23148544427320555}
#
# Current epoch: 60,
# training performance: {'loss': 2.4642768144607543, 'full sequence accuracy': 0.0124, 'first n-symbol accuracy': 0.07795679579879704, 'overlap rate': 0.3314572969700019}
# evaluation performance: {'loss': 2.5121140360832213, 'full sequence accuracy': 0.005200000000000001, 'first n-symbol accuracy': 0.06780698730641074, 'overlap rate': 0.3158284580657493}
#
# Current epoch: 70,
# training performance: {'loss': 2.3658668637275695, 'full sequence accuracy': 0.0184, 'first n-symbol accuracy': 0.11870634960390128, 'overlap rate': 0.3852464775604597}
# evaluation performance: {'loss': 2.4300179719924926, 'full sequence accuracy': 0.01, 'first n-symbol accuracy': 0.10050569240492224, 'overlap rate': 0.36411686260861365}
#
# Current epoch: 80,
# training performance: {'loss': 2.0028672337532045, 'full sequence accuracy': 0.036800000000000006, 'first n-symbol accuracy': 0.20439287424442476, 'overlap rate': 0.5003362628439995}
# evaluation performance: {'loss': 2.091667950153351, 'full sequence accuracy': 0.0268, 'first n-symbol accuracy': 0.18033368853725626, 'overlap rate': 0.4754194320286104}
#
# Current epoch: 90,
# training performance: {'loss': 1.9398716509342193, 'full sequence accuracy': 0.08600000000000001, 'first n-symbol accuracy': 0.25628923072616694, 'overlap rate': 0.5457652592682527}
# evaluation performance: {'loss': 2.0473249673843386, 'full sequence accuracy': 0.05920000000000001, 'first n-symbol accuracy': 0.22004796414823122, 'overlap rate': 0.5146589774693178}
#
# Current epoch: 100,
# training performance: {'loss': 2.169189339876175, 'full sequence accuracy': 0.088, 'first n-symbol accuracy': 0.27125592686597594, 'overlap rate': 0.5203781126049932}
# evaluation performance: {'loss': 2.20989990234375, 'full sequence accuracy': 0.0784, 'first n-symbol accuracy': 0.2551904129036858, 'overlap rate': 0.5067308243931649}
#
# Current epoch: 110,
# training performance: {'loss': 1.24612095952034, 'full sequence accuracy': 0.23960000000000004, 'first n-symbol accuracy': 0.4798816036141952, 'overlap rate': 0.7300513940688937}
# evaluation performance: {'loss': 1.3972337067127227, 'full sequence accuracy': 0.17560000000000003, 'first n-symbol accuracy': 0.4309951973329865, 'overlap rate': 0.6907697067307637}
#
# Current epoch: 120,
# training performance: {'loss': 1.2244710564613341, 'full sequence accuracy': 0.14040000000000002, 'first n-symbol accuracy': 0.45246526048379165, 'overlap rate': 0.7468515116390977}
# evaluation performance: {'loss': 1.4149872541427613, 'full sequence accuracy': 0.1044, 'first n-symbol accuracy': 0.4043915786442131, 'overlap rate': 0.7012290968426316}
#
# Current epoch: 130,
# training performance: {'loss': 1.315183937549591, 'full sequence accuracy': 0.16, 'first n-symbol accuracy': 0.5088863003083344, 'overlap rate': 0.7092749919420906}
# evaluation performance: {'loss': 1.484068500995636, 'full sequence accuracy': 0.11200000000000002, 'first n-symbol accuracy': 0.4569043856681943, 'overlap rate': 0.6708401891165812}
#
# Current epoch: 140,
# training performance: {'loss': 0.816825982928276, 'full sequence accuracy': 0.37200000000000005, 'first n-symbol accuracy': 0.6247033175324086, 'overlap rate': 0.8271908337116974}
# evaluation performance: {'loss': 0.9946972608566285, 'full sequence accuracy': 0.2856, 'first n-symbol accuracy': 0.5600686019742297, 'overlap rate': 0.7836139942236124}
#
# Current epoch: 150,
# training performance: {'loss': 0.8666240870952606, 'full sequence accuracy': 0.40279999999999994, 'first n-symbol accuracy': 0.6921489202332476, 'overlap rate': 0.8249862277080295}
# evaluation performance: {'loss': 1.0431854486465455, 'full sequence accuracy': 0.334, 'first n-symbol accuracy': 0.6386845126218323, 'overlap rate': 0.7879679718627892}
#
# Current epoch: 160,
# training performance: {'loss': 1.337996421009302, 'full sequence accuracy': 0.36560000000000004, 'first n-symbol accuracy': 0.6383955071408799, 'overlap rate': 0.7897509277114059}
# evaluation performance: {'loss': 1.419955924153328, 'full sequence accuracy': 0.3148000000000001, 'first n-symbol accuracy': 0.6002391043720834, 'overlap rate': 0.7713796024166286}
#
# Current epoch: 170,
# training performance: {'loss': 0.37649267464876174, 'full sequence accuracy': 0.6624000000000001, 'first n-symbol accuracy': 0.8176577432706067, 'overlap rate': 0.9353682574110506}
# evaluation performance: {'loss': 0.5623692005872727, 'full sequence accuracy': 0.5191999999999999, 'first n-symbol accuracy': 0.7244855899466444, 'overlap rate': 0.8971546081544906}
#
# Current epoch: 180,
# training performance: {'loss': 0.19077567085623742, 'full sequence accuracy': 0.8440000000000001, 'first n-symbol accuracy': 0.923612410939598, 'overlap rate': 0.97502513160016}
# evaluation performance: {'loss': 0.3645679473876953, 'full sequence accuracy': 0.6876000000000001, 'first n-symbol accuracy': 0.8313751576988834, 'overlap rate': 0.9428293335093324}
#
# Current epoch: 190,
# training performance: {'loss': 0.27034439891576767, 'full sequence accuracy': 0.8128, 'first n-symbol accuracy': 0.9315507485352864, 'overlap rate': 0.9599191167165622}
# evaluation performance: {'loss': 0.3821806453168392, 'full sequence accuracy': 0.7268000000000001, 'first n-symbol accuracy': 0.8854709641645716, 'overlap rate': 0.9387849744289246}
#
# Current epoch: 200,
# training performance: {'loss': 0.09168652445077896, 'full sequence accuracy': 0.9352, 'first n-symbol accuracy': 0.9654839992213813, 'overlap rate': 0.9901411528988711}
# evaluation performance: {'loss': 0.17878029495477676, 'full sequence accuracy': 0.8368, 'first n-symbol accuracy': 0.9097884948632032, 'overlap rate': 0.9733250569059051}
#
# Current epoch: 210,
# training performance: {'loss': 0.7840007994323969, 'full sequence accuracy': 0.728, 'first n-symbol accuracy': 0.8573603175314155, 'overlap rate': 0.8728480986319564}
# evaluation performance: {'loss': 0.9304781138896943, 'full sequence accuracy': 0.64, 'first n-symbol accuracy': 0.81130038868929, 'overlap rate': 0.8470031292829929}
#
# Current epoch: 220,
# training performance: {'loss': 0.2955216489732265, 'full sequence accuracy': 0.8288, 'first n-symbol accuracy': 0.9077654343401218, 'overlap rate': 0.946515465961322}
# evaluation performance: {'loss': 0.4524479299783707, 'full sequence accuracy': 0.7212, 'first n-symbol accuracy': 0.8402133497838437, 'overlap rate': 0.918085025578994}
#
# Current epoch: 230,
# training performance: {'loss': 1.06462831646204, 'full sequence accuracy': 0.6612, 'first n-symbol accuracy': 0.8314716506442315, 'overlap rate': 0.8483221398498536}
# evaluation performance: {'loss': 1.3309835344552994, 'full sequence accuracy': 0.5624, 'first n-symbol accuracy': 0.7789693080934261, 'overlap rate': 0.805897729415902}
#
# Current epoch: 240,
# training performance: {'loss': 0.5154439441859722, 'full sequence accuracy': 0.8216000000000001, 'first n-symbol accuracy': 0.9183709399027252, 'overlap rate': 0.9264294328480972}
# evaluation performance: {'loss': 0.7672442629933357, 'full sequence accuracy': 0.7323999999999999, 'first n-symbol accuracy': 0.8696517002410127, 'overlap rate': 0.8885485908045441}
#
# Current epoch: 250,
# training performance: {'loss': 0.008465286809951067, 'full sequence accuracy': 0.9996, 'first n-symbol accuracy': 0.9998064516129033, 'overlap rate': 0.9999741935483872}
# evaluation performance: {'loss': 0.057913809828460214, 'full sequence accuracy': 0.9596, 'first n-symbol accuracy': 0.980460002158323, 'overlap rate': 0.993612602671017}
#
# Current epoch: 260,
# training performance: {'loss': 0.00657357550226152, 'full sequence accuracy': 0.9996, 'first n-symbol accuracy': 0.9996387096774194, 'overlap rate': 0.9999354838709678}
# evaluation performance: {'loss': 0.037445205124095084, 'full sequence accuracy': 0.9728, 'first n-symbol accuracy': 0.9878704551671266, 'overlap rate': 0.9959224960046384}
#
# Current epoch: 270,
# training performance: {'loss': 0.0032295399345457555, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.011031164997257292, 'full sequence accuracy': 0.9928000000000001, 'first n-symbol accuracy': 0.9967779809936695, 'overlap rate': 0.9991632846988219}
#
# Current epoch: 280,
# training performance: {'loss': 0.0026232780655846, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.010931748431175947, 'full sequence accuracy': 0.994, 'first n-symbol accuracy': 0.9973357662812612, 'overlap rate': 0.9991897683991121}
#
# Current epoch: 290,
# training performance: {'loss': 0.002279534749686718, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.010369260958395899, 'full sequence accuracy': 0.9944, 'first n-symbol accuracy': 0.997528869729537, 'overlap rate': 0.9992173546060086}
#
# Current epoch: 300,
# training performance: {'loss': 0.0020234917756170034, 'full sequence accuracy': 1.0, 'first n-symbol accuracy': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.009599755564704538, 'full sequence accuracy': 0.9952, 'first n-symbol accuracy': 0.9980766529807685, 'overlap rate': 0.9992830360510003}
#
# experiments/total_red_attn_learn_efficiency/LSTM/attn/3/model.pt saved!
#
# experiments/total_red_attn_learn_efficiency/LSTM/attn/3/training_log.json saved!
# experiments/total_red_attn_learn_efficiency/LSTM/attn/3/ModelConfig.json saved!
# experiments/total_red_attn_learn_efficiency/LSTM/attn/3/training_plot.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
