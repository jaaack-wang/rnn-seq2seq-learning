# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 512
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = False 
use_attention = False
reduction_method = torch.sum

learning_rate = 1e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 8
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#8/RNN created!
# ./Experiments_Logs/Experiment#8/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#8/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#8/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#8 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9328129559755325, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333432395011, 'overlap rate': 0.4299767084419727}
# evaluation performance: {'loss': 1.9567126348614692, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006508333488454809, 'overlap rate': 0.42988920845091344}
#
# Current epoch: 10,
# training performance: {'loss': 1.9143877506256104, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007183333473221865, 'overlap rate': 0.43100837990641594}
# evaluation performance: {'loss': 1.913915976881981, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006766666820112732, 'overlap rate': 0.4303775455802679}
#
# Current epoch: 15,
# training performance: {'loss': 1.9052434772253037, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007316666815313511, 'overlap rate': 0.4316617101430893}
# evaluation performance: {'loss': 1.9049289986491202, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006677118783045444, 'overlap rate': 0.43024610094726085}
#
# Current epoch: 20,
# training performance: {'loss': 1.9597720205783844, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007924293931864668, 'overlap rate': 0.4272143870592117}
# evaluation performance: {'loss': 2.309599596261978, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006725000152073335, 'overlap rate': 0.42699504382908343}
#
# Current epoch: 25,
# training performance: {'loss': 1.9002665668725967, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007600000186357647, 'overlap rate': 0.432673379778862}
# evaluation performance: {'loss': 1.9025654718279839, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006508333481178852, 'overlap rate': 0.43042504526674746}
#
# Current epoch: 30,
# training performance: {'loss': 1.9007025986909867, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007750000135274604, 'overlap rate': 0.4329283766448498}
# evaluation performance: {'loss': 1.901393061876297, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006483333456344554, 'overlap rate': 0.43021754138171675}
#
# Current epoch: 35,
# training performance: {'loss': 1.8973385214805603, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007850000190956052, 'overlap rate': 0.43360671401023865}
# evaluation performance: {'loss': 1.9000640287995338, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006608333482290618, 'overlap rate': 0.43074504621326926}
#
# Current epoch: 40,
# training performance: {'loss': 1.8962761759757996, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008016666848561727, 'overlap rate': 0.43444337844848635}
# evaluation performance: {'loss': 1.9002039536833764, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333448765916, 'overlap rate': 0.4305375427007675}
#
# Current epoch: 45,
# training performance: {'loss': 1.8955726623535156, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008783333483734168, 'overlap rate': 0.43475171029567716}
# evaluation performance: {'loss': 1.8995498433709144, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006858333479613065, 'overlap rate': 0.431071712821722}
#
# Current epoch: 50,
# training performance: {'loss': 1.9703781008720398, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00064000001475506, 'overlap rate': 0.4170417092740536}
# evaluation performance: {'loss': 4.5117795944213865, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006458333511545789, 'overlap rate': 0.40730254389345644}
#
# Current epoch: 55,
# training performance: {'loss': 1.9654931664466857, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007916666836536024, 'overlap rate': 0.41846837624907496}
# evaluation performance: {'loss': 4.69066492319107, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007050000160234049, 'overlap rate': 0.4050125446170568}
#
# Current epoch: 60,
# training performance: {'loss': 1.9638220012187957, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000748813574318774, 'overlap rate': 0.41945289745926856}
# evaluation performance: {'loss': 3.6592858523130416, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006766666820112732, 'overlap rate': 0.022544169053435325}
#
# Current epoch: 65,
# training performance: {'loss': 1.9640179485082627, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007233333490148652, 'overlap rate': 0.41919337809085844}
# evaluation performance: {'loss': 4.365973433852195, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006908333485625917, 'overlap rate': 0.3951350416988134}
#
# Current epoch: 70,
# training performance: {'loss': 1.963579699397087, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007433333485096227, 'overlap rate': 0.41957337632775304}
# evaluation performance: {'loss': 4.370230951905251, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006858333479613065, 'overlap rate': 0.3947742093354464}
#
# Current epoch: 75,
# training performance: {'loss': 1.9576048463582993, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007316666808037553, 'overlap rate': 0.4233267143368721}
# evaluation performance: {'loss': 2.6171365678310394, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006784745914046652, 'overlap rate': 0.3493384785950184}
#
# Current epoch: 80,
# training performance: {'loss': 2.0047951340675354, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0005516666766197887, 'overlap rate': 0.41317504122853277}
# evaluation performance: {'loss': 4.770016664266587, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006766666811017785, 'overlap rate': 0.4048317104578018}
#
# Current epoch: 85,
# training performance: {'loss': 1.9642464488744735, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007566666827187873, 'overlap rate': 0.4190933734178543}
# evaluation performance: {'loss': 4.949373346567154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006591666795429773, 'overlap rate': 0.40273004360497}
#
# Current epoch: 90,
# training performance: {'loss': 1.9482360363006592, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006566666808794253, 'overlap rate': 0.42660171166062355}
# evaluation performance: {'loss': 2.850857636332512, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007150000139517943, 'overlap rate': 0.4239858776330948}
#
# Current epoch: 95,
# training performance: {'loss': 1.9372994661331178, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007700000140175689, 'overlap rate': 0.430241709202528}
# evaluation performance: {'loss': 2.6701812863349916, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006575000130396802, 'overlap rate': 0.42780170887708663}
#
# Current epoch: 100,
# training performance: {'loss': 1.940174463391304, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008016666753974278, 'overlap rate': 0.42974337488412856}
# evaluation performance: {'loss': 2.7070365875959395, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006918644230609061, 'overlap rate': 0.42760498747229575}
#
# Current epoch: 105,
# training performance: {'loss': 1.9343896090984345, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006950000162760262, 'overlap rate': 0.4308333724737167}
# evaluation performance: {'loss': 2.0750760689377783, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006575706342118792, 'overlap rate': 0.4297616247087717}
#
# Current epoch: 110,
# training performance: {'loss': 1.9313235640525819, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000780000018858118, 'overlap rate': 0.4315983787178993}
# evaluation performance: {'loss': 2.450964352488518, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006318220505818317, 'overlap rate': 0.38786928690969946}
#
# Current epoch: 115,
# training performance: {'loss': 1.9183489501476287, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008183333498891443, 'overlap rate': 0.4335583783686161}
# evaluation performance: {'loss': 1.924921803176403, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007041666831355542, 'overlap rate': 0.4305467110127211}
#
# Current epoch: 120,
# training performance: {'loss': 1.9407985985279084, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008050000134971925, 'overlap rate': 0.43038171231746675}
# evaluation performance: {'loss': 2.2776820957660675, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333480800502, 'overlap rate': 0.4278192050755024}
#
# Current epoch: 125,
# training performance: {'loss': 1.9226110756397248, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008066666821832768, 'overlap rate': 0.43292004615068436}
# evaluation performance: {'loss': 2.142455059289932, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333491714439, 'overlap rate': 0.4295358758419752}
#
# Current epoch: 130,
# training performance: {'loss': 1.9144292026758194, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008700000165845267, 'overlap rate': 0.43416504710912707}
# evaluation performance: {'loss': 1.9336740687489509, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006775000121706399, 'overlap rate': 0.4306292090564966}
#
# Current epoch: 135,
# training performance: {'loss': 1.929209116101265, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008000000110769179, 'overlap rate': 0.4323117159307003}
# evaluation performance: {'loss': 2.0674117743968963, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006716666839565733, 'overlap rate': 0.42956754341721537}
#
# Current epoch: 140,
# training performance: {'loss': 1.9114839553833007, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000850000017817365, 'overlap rate': 0.43450837284326554}
# evaluation performance: {'loss': 2.090131637454033, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006825988843047526, 'overlap rate': 0.4295561037957668}
#
# Current epoch: 145,
# training performance: {'loss': 1.9106658846139908, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007933333501568996, 'overlap rate': 0.4342967107892036}
# evaluation performance: {'loss': 1.9141055688261985, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006575000170414569, 'overlap rate': 0.43036087565124037}
#
# Current epoch: 150,
# training performance: {'loss': 1.9089971691370011, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008066666858212556, 'overlap rate': 0.4351150430738926}
# evaluation performance: {'loss': 1.9711994871497154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006800000148359687, 'overlap rate': 0.43025170676410196}
#
# Current epoch: 155,
# training performance: {'loss': 1.909447479248047, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008550000253308099, 'overlap rate': 0.4353700429201126}
# evaluation performance: {'loss': 1.918819673359394, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000666666682172945, 'overlap rate': 0.43054920993745327}
#
# Current epoch: 160,
# training performance: {'loss': 1.9100073128938675, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008566666845581494, 'overlap rate': 0.43530171141028406}
# evaluation performance: {'loss': 1.9848412990570068, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006775000176276081, 'overlap rate': 0.43013170883059504}
#
# Current epoch: 165,
# training performance: {'loss': 1.9052450031042099, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008516666835930664, 'overlap rate': 0.43544004037976264}
# evaluation performance: {'loss': 1.9460471913218498, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006458333467890043, 'overlap rate': 0.42305420748889444}
#
# Current epoch: 170,
# training performance: {'loss': 1.8994821190834046, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008766666855080984, 'overlap rate': 0.43549171164631845}
# evaluation performance: {'loss': 1.9030309960246086, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006566666819708189, 'overlap rate': 0.43054171055555346}
#
# Current epoch: 175,
# training performance: {'loss': 1.9004675567150116, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008400000209803693, 'overlap rate': 0.43589337840676307}
# evaluation performance: {'loss': 1.9032594844698907, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006858333490527002, 'overlap rate': 0.43064337596297264}
#
# Current epoch: 180,
# training performance: {'loss': 1.9285309106111526, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007983333540323656, 'overlap rate': 0.43338671177625654}
# evaluation performance: {'loss': 1.9639569446444511, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006975000142119825, 'overlap rate': 0.4303575441241264}
#
# Current epoch: 185,
# training performance: {'loss': 1.8971782803535462, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008950000199547503, 'overlap rate': 0.43615170791745184}
# evaluation performance: {'loss': 1.9014732614159584, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006650000133959111, 'overlap rate': 0.4303717140108347}
#
# Current epoch: 190,
# training performance: {'loss': 1.901237067580223, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000838333345745923, 'overlap rate': 0.43599504679441453}
# evaluation performance: {'loss': 1.9050764963030815, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007052966269839089, 'overlap rate': 0.43061935231089593}
#
# Current epoch: 195,
# training performance: {'loss': 1.8969555795192719, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009033333517436404, 'overlap rate': 0.4364017084240913}
# evaluation performance: {'loss': 1.905311106145382, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006766666821931722, 'overlap rate': 0.43050087951123717}
#
# Current epoch: 200,
# training performance: {'loss': 1.967320090532303, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007316666829865426, 'overlap rate': 0.4280100427567959}
# evaluation performance: {'loss': 2.4449029147624968, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006300000140981865, 'overlap rate': 0.4286800421774387}
#
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.4445077896118166, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006826059466220613, 'overlap rate': 0.4286181218922138}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 8.37173683643341, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016955974977463483, 'overlap rate': 0.025372978346422315}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.77094050376646, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0004968029230029412, 'overlap rate': 0.4108295584878614}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 8.736306353619224, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019680686328731674, 'overlap rate': 0.024135263519144103}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9393310010433198, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006650000163062941, 'overlap rate': 0.4289133816957474}
# evaluation performance: {'loss': 2.01468952447176, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006925000130650006, 'overlap rate': 0.42862254455685617}
#
# Current epoch: 10,
# training performance: {'loss': 1.9337501019239425, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007433333492372185, 'overlap rate': 0.42973670959472654}
# evaluation performance: {'loss': 1.9578879117965697, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333469886565, 'overlap rate': 0.4294358741492033}
#
# Current epoch: 15,
# training performance: {'loss': 1.919905361533165, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000813333346741274, 'overlap rate': 0.4310417078435421}
# evaluation performance: {'loss': 1.9167904704809189, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006708333454298554, 'overlap rate': 0.43008671030402185}
#
# Current epoch: 20,
# training performance: {'loss': 1.9138731122016908, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008550000209652353, 'overlap rate': 0.4314233735203743}
# evaluation performance: {'loss': 1.9360233888030052, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006575000134034781, 'overlap rate': 0.4304775446653366}
#
# Current epoch: 25,
# training performance: {'loss': 1.9136255979537964, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008616666906164028, 'overlap rate': 0.4323967106640339}
# evaluation performance: {'loss': 1.9874585345387459, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006866666823043488, 'overlap rate': 0.41951337531208993}
#
# Current epoch: 30,
# training performance: {'loss': 1.9086448073387146, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008466666782624088, 'overlap rate': 0.43265838027000425}
# evaluation performance: {'loss': 1.9044648125767707, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00068416667963902, 'overlap rate': 0.4301100429147482}
#
# Current epoch: 35,
# training performance: {'loss': 1.9102088779211044, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008400000173423905, 'overlap rate': 0.4328583799302578}
# evaluation performance: {'loss': 1.9149329036474227, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006666666796263599, 'overlap rate': 0.43032587990164756}
#
# Current epoch: 40,
# training performance: {'loss': 1.9095871597528458, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008366666850633919, 'overlap rate': 0.43328838124871255}
# evaluation performance: {'loss': 1.926373766362667, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333446946926, 'overlap rate': 0.4302167106419802}
#
# Current epoch: 45,
# training performance: {'loss': 1.906484231352806, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000830000016867416, 'overlap rate': 0.43385337814688685}
# evaluation performance: {'loss': 1.9365164577960967, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006851553796877851, 'overlap rate': 0.43003716692328453}
#
# Current epoch: 50,
# training performance: {'loss': 1.9107359200716019, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000825000018812716, 'overlap rate': 0.43373504355549813}
# evaluation performance: {'loss': 1.916501948237419, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006850000154372538, 'overlap rate': 0.43029088005423544}
#
# Current epoch: 55,
# training performance: {'loss': 1.907994693517685, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008450000226730481, 'overlap rate': 0.43428671136498453}
# evaluation performance: {'loss': 1.904375357925892, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000690000015674741, 'overlap rate': 0.4307633779942989}
#
# Current epoch: 60,
# training performance: {'loss': 1.8997701078653335, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008316666928294581, 'overlap rate': 0.43446837142109873}
# evaluation performance: {'loss': 1.9077118888497353, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006450000153563451, 'overlap rate': 0.4306758802384138}
#
# Current epoch: 65,
# training performance: {'loss': 1.9022418290376664, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008200000229408033, 'overlap rate': 0.43442004546523094}
# evaluation performance: {'loss': 1.9008936807513237, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006533333478728309, 'overlap rate': 0.43040671199560165}
#
# Current epoch: 70,
# training performance: {'loss': 1.9019554078578949, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008266666853160131, 'overlap rate': 0.43461004719138147}
# evaluation performance: {'loss': 1.901426962018013, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006775000136258313, 'overlap rate': 0.43026670776307585}
#
# Current epoch: 75,
# training performance: {'loss': 1.9010076582431794, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008483333498588763, 'overlap rate': 0.4345900483429432}
# evaluation performance: {'loss': 1.9025390908122062, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006833333492977545, 'overlap rate': 0.43049504309892656}
#
# Current epoch: 80,
# training performance: {'loss': 1.896123507618904, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008400000093388371, 'overlap rate': 0.43489004895091055}
# evaluation performance: {'loss': 1.9003005862236022, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006633333505305927, 'overlap rate': 0.4308325435966253}
#
# Current epoch: 85,
# training performance: {'loss': 1.8979979395866393, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008266666824056301, 'overlap rate': 0.43492670729756355}
# evaluation performance: {'loss': 1.9022032499313355, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006617937997361878, 'overlap rate': 0.4302797481417656}
#
# Current epoch: 90,
# training performance: {'loss': 1.8955739080905913, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000846666686993558, 'overlap rate': 0.4353517085313797}
# evaluation performance: {'loss': 1.9010004177689552, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006791666808567242, 'overlap rate': 0.4305783711373806}
#
# Current epoch: 95,
# training performance: {'loss': 1.8996854901313782, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008500000090862159, 'overlap rate': 0.4351650446653366}
# evaluation performance: {'loss': 1.9014835715293885, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007175000155257294, 'overlap rate': 0.4304742131382227}
#
# Current epoch: 100,
# training performance: {'loss': 1.8952117353677749, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000865000020712614, 'overlap rate': 0.43549338057637216}
# evaluation performance: {'loss': 1.9006089448928833, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000690833347471198, 'overlap rate': 0.4305808782577515}
#
# Current epoch: 105,
# training performance: {'loss': 1.8943135470151902, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009066666818398517, 'overlap rate': 0.43594170808792115}
# evaluation performance: {'loss': 1.90033168643713, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007283333477971609, 'overlap rate': 0.4310867119580507}
#
# Current epoch: 110,
# training performance: {'loss': 1.9129607111215592, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008621186680102255, 'overlap rate': 0.43418261110782624}
# evaluation performance: {'loss': 1.9302952378988265, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006775000169000122, 'overlap rate': 0.430259208381176}
#
# Current epoch: 115,
# training performance: {'loss': 1.8949915021657944, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000886666685983073, 'overlap rate': 0.4361217111349106}
# evaluation performance: {'loss': 1.9006353422999382, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006800000141083728, 'overlap rate': 0.43063587360084055}
#
# Current epoch: 120,
# training performance: {'loss': 1.9230749756097794, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008066666814556811, 'overlap rate': 0.4332867100834846}
# evaluation performance: {'loss': 2.0018575116991997, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006575000148586696, 'overlap rate': 0.4295483808964491}
#
# Current epoch: 125,
# training performance: {'loss': 1.895608052611351, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008433333459834103, 'overlap rate': 0.43610004633665084}
# evaluation performance: {'loss': 1.901979273557663, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006633333461650182, 'overlap rate': 0.43037254326045515}
#
# Current epoch: 130,
# training performance: {'loss': 1.895272210240364, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008250000166299288, 'overlap rate': 0.435936713963747}
# evaluation performance: {'loss': 1.9009275928139686, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000675000012415694, 'overlap rate': 0.43059420548379423}
#
# Current epoch: 135,
# training performance: {'loss': 1.8936160326004028, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009133333522186148, 'overlap rate': 0.43663338050246236}
# evaluation performance: {'loss': 1.9004358857870103, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007033333477011183, 'overlap rate': 0.43077837824821474}
#
# Current epoch: 140,
# training performance: {'loss': 1.8928706496953964, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008616666775196791, 'overlap rate': 0.43698337897658346}
# evaluation performance: {'loss': 1.9004175812005997, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007000000154221197, 'overlap rate': 0.43089587390422823}
#
# Current epoch: 145,
# training performance: {'loss': 1.9362752556800842, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000818446341145318, 'overlap rate': 0.4329416789114475}
# evaluation performance: {'loss': 2.0706822380423544, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006433333482164016, 'overlap rate': 0.4298025440424681}
#
# Current epoch: 150,
# training performance: {'loss': 1.8966923862695695, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008916666847653687, 'overlap rate': 0.43650171235203744}
# evaluation performance: {'loss': 1.901623012125492, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000700000017968705, 'overlap rate': 0.4306167121976614}
#
# Current epoch: 155,
# training performance: {'loss': 1.892791935801506, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008866666910762433, 'overlap rate': 0.4373250402510166}
# evaluation performance: {'loss': 1.9016564413905144, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007134604689781554, 'overlap rate': 0.4305371630936861}
#
# Current epoch: 160,
# training performance: {'loss': 1.8920423924922942, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000915000015811529, 'overlap rate': 0.4376617155969143}
# evaluation performance: {'loss': 1.9005528122186661, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007333333498536377, 'overlap rate': 0.4308933764696121}
#
# Current epoch: 165,
# training performance: {'loss': 1.9378385335206985, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008633333520265297, 'overlap rate': 0.4282767094671726}
# evaluation performance: {'loss': 2.835077151656151, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007625000181178621, 'overlap rate': 0.3212675340473652}
#
# Current epoch: 170,
# training performance: {'loss': 1.9335953682661056, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009816666854021606, 'overlap rate': 0.4271417073905468}
# evaluation performance: {'loss': 2.206406870484352, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007887005805969239, 'overlap rate': 0.3514177329838276}
#
# Current epoch: 175,
# training performance: {'loss': 1.9354025095701217, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008966666799096856, 'overlap rate': 0.4269783809781075}
# evaluation performance: {'loss': 2.2313174664974214, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000701666678833135, 'overlap rate': 0.3518867030739784}
#
# Current epoch: 180,
# training performance: {'loss': 1.9388628095388412, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009388700738782064, 'overlap rate': 0.4271338053047657}
# evaluation performance: {'loss': 2.2308087170124056, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007125000127416569, 'overlap rate': 0.3520942013710737}
#
# Current epoch: 185,
# training performance: {'loss': 1.949382796883583, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008500000243657268, 'overlap rate': 0.4249600447714329}
# evaluation performance: {'loss': 2.239652681350708, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007050000176604954, 'overlap rate': 0.35162170343101024}
#
# Current epoch: 190,
# training performance: {'loss': 1.9315569579601288, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009500000247498974, 'overlap rate': 0.42784337475895884}
# evaluation performance: {'loss': 2.2058246344327928, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007183333484135801, 'overlap rate': 0.3518758699297905}
#
# Current epoch: 195,
# training performance: {'loss': 1.9332963585853578, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001040000026114285, 'overlap rate': 0.42750670984387396}
# evaluation performance: {'loss': 2.223106327652931, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008234322212956613, 'overlap rate': 0.3518639478832483}
#
# Current epoch: 200,
# training performance: {'loss': 1.9347796529531478, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009816666875849477, 'overlap rate': 0.4282100394368172}
# evaluation performance: {'loss': 2.229820567369461, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007650000163266669, 'overlap rate': 0.3518992029130459}
#
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.2297133922576906, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007720833495113766, 'overlap rate': 0.3521292025223374}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.2953356921672823, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005445124622201547, 'overlap rate': 0.042594494950026277}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.3450392707701653, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000589452983601199, 'overlap rate': 0.35555776030786573}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.349317236950523, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007365051632452952, 'overlap rate': 0.044540602223653546}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9462640136480331, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007166666830016766, 'overlap rate': 0.42841837704181673}
# evaluation performance: {'loss': 1.9508134812116622, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006583333466551267, 'overlap rate': 0.42969421073794367}
#
# Current epoch: 10,
# training performance: {'loss': 1.9276021420955658, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007216666832391639, 'overlap rate': 0.43008004054427146}
# evaluation performance: {'loss': 1.9253730714321136, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006775000161724165, 'overlap rate': 0.4300708778202534}
#
# Current epoch: 15,
# training performance: {'loss': 1.926493653655052, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007916666800156236, 'overlap rate': 0.43058170899748804}
# evaluation performance: {'loss': 1.9608625575900078, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006975000131205888, 'overlap rate': 0.42990921139717103}
#
# Current epoch: 20,
# training performance: {'loss': 1.918514832854271, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008333333484188188, 'overlap rate': 0.4319467142224312}
# evaluation performance: {'loss': 1.9301523506641387, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006641666812356561, 'overlap rate': 0.4299192078411579}
#
# Current epoch: 25,
# training performance: {'loss': 1.9108419626951219, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008333333527843934, 'overlap rate': 0.43246004208922384}
# evaluation performance: {'loss': 1.906645268201828, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006901836296492547, 'overlap rate': 0.4301250845193863}
#
# Current epoch: 30,
# training performance: {'loss': 1.9121225297451019, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008250000151747372, 'overlap rate': 0.4328550428152084}
# evaluation performance: {'loss': 1.916397973895073, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006808333477238193, 'overlap rate': 0.4300042103976011}
#
# Current epoch: 35,
# training performance: {'loss': 1.924390944838524, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008350000221980736, 'overlap rate': 0.43171504735946653}
# evaluation performance: {'loss': 2.002144545316696, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000681666683885851, 'overlap rate': 0.4297308769077063}
#
# Current epoch: 40,
# training performance: {'loss': 1.922357624769211, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008403389983868692, 'overlap rate': 0.4321812279522419}
# evaluation performance: {'loss': 1.944212220609188, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000641016964436858, 'overlap rate': 0.42981624566018584}
#
# Current epoch: 45,
# training performance: {'loss': 1.903876382112503, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008633333527541254, 'overlap rate': 0.4338733807206154}
# evaluation performance: {'loss': 1.9060018852353096, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006891666831506882, 'overlap rate': 0.43045337609946727}
#
# Current epoch: 50,
# training performance: {'loss': 1.9209721565246582, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000805480237613665, 'overlap rate': 0.4326761454343796}
# evaluation performance: {'loss': 1.9726507529616355, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007625000147527316, 'overlap rate': 0.4298067107796669}
#
# Current epoch: 55,
# training performance: {'loss': 1.9062051504850388, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008250000159023329, 'overlap rate': 0.4341150499880314}
# evaluation performance: {'loss': 1.9349355474114418, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006766666807379807, 'overlap rate': 0.43024587854743}
#
# Current epoch: 60,
# training performance: {'loss': 1.9185093700885774, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007933333523396868, 'overlap rate': 0.43257670998573305}
# evaluation performance: {'loss': 2.3889654159545897, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006850000143458601, 'overlap rate': 0.4197308745235205}
#
# Current epoch: 65,
# training performance: {'loss': 1.9020729809999466, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007866666863264981, 'overlap rate': 0.4346017114818096}
# evaluation performance: {'loss': 1.9190646708011627, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006733333484589821, 'overlap rate': 0.43045587576925753}
#
# Current epoch: 70,
# training performance: {'loss': 1.8997918844223023, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007983333518495784, 'overlap rate': 0.4343833826482296}
# evaluation performance: {'loss': 1.9010284483432769, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000686666681940551, 'overlap rate': 0.43026754520833493}
#
# Current epoch: 75,
# training performance: {'loss': 1.8984974175691605, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008350000200152863, 'overlap rate': 0.4346633806824684}
# evaluation performance: {'loss': 1.9011348590254784, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007083333455739193, 'overlap rate': 0.43042754493653773}
#
# Current epoch: 80,
# training performance: {'loss': 1.9007535189390183, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009133333529462107, 'overlap rate': 0.43474671319127084}
# evaluation performance: {'loss': 1.9017707362771035, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006541666822158732, 'overlap rate': 0.4303683765232563}
#
# Current epoch: 85,
# training performance: {'loss': 1.9023318320512772, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008366666887013707, 'overlap rate': 0.4348317101597786}
# evaluation performance: {'loss': 1.9025153130292893, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006858333494164981, 'overlap rate': 0.4303250405937433}
#
# Current epoch: 90,
# training performance: {'loss': 1.8962736546993255, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008900000233552418, 'overlap rate': 0.4353633806109428}
# evaluation performance: {'loss': 1.900537657737732, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006800000166549581, 'overlap rate': 0.4302117072045803}
#
# Current epoch: 95,
# training performance: {'loss': 1.8977705508470535, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009066666811122559, 'overlap rate': 0.435345046967268}
# evaluation performance: {'loss': 1.9006861343979835, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00067333334709474, 'overlap rate': 0.43060754276812074}
#
# Current epoch: 100,
# training performance: {'loss': 1.8966982334852218, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009000000194646418, 'overlap rate': 0.43557671308517454}
# evaluation performance: {'loss': 1.9011481747031211, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000693333346498548, 'overlap rate': 0.43030671365559103}
#
# Current epoch: 105,
# training performance: {'loss': 1.8949895650148392, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008800000185146927, 'overlap rate': 0.43555004671216013}
# evaluation performance: {'loss': 1.9007023587822913, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006733333499141736, 'overlap rate': 0.43050420954823493}
#
# Current epoch: 110,
# training performance: {'loss': 1.8963000744581222, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009033333481056616, 'overlap rate': 0.43608504086732863}
# evaluation performance: {'loss': 1.9012022390961647, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006750000151441782, 'overlap rate': 0.430535876005888}
#
# Current epoch: 115,
# training performance: {'loss': 1.9082656651735306, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000875000016822014, 'overlap rate': 0.4348583810031414}
# evaluation performance: {'loss': 1.9020720988512039, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000673333351733163, 'overlap rate': 0.4305617120116949}
#
# Current epoch: 120,
# training performance: {'loss': 1.8945994555950165, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008783333461906296, 'overlap rate': 0.436091710627079}
# evaluation performance: {'loss': 1.9006372556090354, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006458333460614085, 'overlap rate': 0.4306767102330923}
#
# Current epoch: 125,
# training performance: {'loss': 1.8962674140930176, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008766666811425239, 'overlap rate': 0.43641837909817693}
# evaluation performance: {'loss': 2.429505342245102, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000657500016677659, 'overlap rate': 0.37677670270204544}
#
# Current epoch: 130,
# training performance: {'loss': 1.894465908408165, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008783333454630337, 'overlap rate': 0.43660171180963514}
# evaluation performance: {'loss': 1.9020160734653473, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006559463428857271, 'overlap rate': 0.430365589633584}
#
# Current epoch: 135,
# training performance: {'loss': 1.89325510263443, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008816666842903942, 'overlap rate': 0.4369317159056664}
# evaluation performance: {'loss': 1.9008111342787744, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006625000143685611, 'overlap rate': 0.4308225452899933}
#
# Current epoch: 140,
# training performance: {'loss': 1.8926247239112854, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008750000190048013, 'overlap rate': 0.4373567126691341}
# evaluation performance: {'loss': 1.9006951361894608, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006600000160688069, 'overlap rate': 0.4309933751821518}
#
# Current epoch: 145,
# training performance: {'loss': 1.8921541839838028, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009100000221224036, 'overlap rate': 0.4375717110931873}
# evaluation performance: {'loss': 1.900225004553795, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006566666819708189, 'overlap rate': 0.4311075426638126}
#
# Current epoch: 150,
# training performance: {'loss': 1.8917519479990006, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008983333485957701, 'overlap rate': 0.4379583761096001}
# evaluation performance: {'loss': 1.9014226496219635, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000645932215047651, 'overlap rate': 0.4310052402317524}
#
# Current epoch: 155,
# training performance: {'loss': 1.949992722272873, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007950000173877925, 'overlap rate': 0.4271167114377022}
# evaluation performance: {'loss': 5.221631002426148, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006841666803666157, 'overlap rate': 0.40895337574183943}
#
# Current epoch: 160,
# training performance: {'loss': 1.9328205168247223, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007654237444512546, 'overlap rate': 0.4306895323097706}
# evaluation performance: {'loss': 5.043602627515793, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006660028382611926, 'overlap rate': 0.40936867222189904}
#
# Current epoch: 165,
# training performance: {'loss': 1.903483808040619, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007800000166753307, 'overlap rate': 0.43420004323124883}
# evaluation performance: {'loss': 1.9086074590682984, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00068166668061167, 'overlap rate': 0.43043754398822787}
#
# Current epoch: 170,
# training performance: {'loss': 1.9147809416055679, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007833333518647123, 'overlap rate': 0.4335233762860298}
# evaluation performance: {'loss': 4.240874075889588, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000696666680596536, 'overlap rate': 0.13483584886416794}
#
# Current epoch: 175,
# training performance: {'loss': 1.95340636074543, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007600000179081689, 'overlap rate': 0.42369004487991335}
# evaluation performance: {'loss': 5.833106601238251, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006908333485625917, 'overlap rate': 0.4008042089641094}
#
# Current epoch: 180,
# training performance: {'loss': 1.9575673788785934, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007300000150280539, 'overlap rate': 0.42404837533831596}
# evaluation performance: {'loss': 4.807906365394592, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000669166682746436, 'overlap rate': 0.422872544080019}
#
# Current epoch: 185,
# training performance: {'loss': 1.9468743920326232, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007600000149977859, 'overlap rate': 0.4286383740603924}
# evaluation performance: {'loss': 2.828516972064972, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006900000160385388, 'overlap rate': 0.42793421223759653}
#
# Current epoch: 190,
# training performance: {'loss': 1.9636053770780564, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007983333518495784, 'overlap rate': 0.41969004049897196}
# evaluation performance: {'loss': 5.58543798327446, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007758333507808856, 'overlap rate': 0.38591170199215413}
#
# Current epoch: 195,
# training performance: {'loss': 1.96194069981575, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000778333348716842, 'overlap rate': 0.42044504433870317}
# evaluation performance: {'loss': 4.614663821458817, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007209322164271725, 'overlap rate': 0.32442597709596155}
#
# Current epoch: 200,
# training performance: {'loss': 1.9448235750198364, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006800000192015432, 'overlap rate': 0.428611708432436}
# evaluation performance: {'loss': 2.3065101712942124, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007116666802176042, 'overlap rate': 0.42853587456047537}
#
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.3066990196704866, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007083333478476561, 'overlap rate': 0.42848629504442215}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.888766121864319, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018325606317375787, 'overlap rate': 0.02941436490509659}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.614480052455779, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000478048533137377, 'overlap rate': 0.40594368634685396}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 7.7515543322814136, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004201482873452876, 'overlap rate': 0.03066875459626317}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9413016706705093, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006150000132038258, 'overlap rate': 0.42906337454915044}
# evaluation performance: {'loss': 1.9406725510954856, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006233333464479074, 'overlap rate': 0.42896670922636987}
#
# Current epoch: 10,
# training performance: {'loss': 1.932637158036232, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333483326714, 'overlap rate': 0.4296800449490547}
# evaluation performance: {'loss': 1.9829704493284226, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006459604654082795, 'overlap rate': 0.4296413861215115}
#
# Current epoch: 15,
# ...
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.936786377429962, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006633333476202096, 'overlap rate': 0.4294433780014515}
# evaluation performance: {'loss': 1.9240508824586868, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006916666832694318, 'overlap rate': 0.4300792071968317}
#
# Current epoch: 10,
# training performance: {'loss': 1.923943567276001, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010100000166858082, 'overlap rate': 0.43094504848122595}
# evaluation performance: {'loss': 1.9404403910040855, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010250000254018233, 'overlap rate': 0.42988421097397805}
#
# Current epoch: 15,
# training performance: {'loss': 1.9259494334459304, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001165423751808703, 'overlap rate': 0.4313833206892014}
# evaluation performance: {'loss': 2.1401990368962287, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011200000215467298, 'overlap rate': 0.42906837724149227}
#
# Current epoch: 20,
# training performance: {'loss': 1.9074121177196504, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019333333562826737, 'overlap rate': 0.4349883787333965}
# evaluation performance: {'loss': 1.9055820181965828, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00201166669576196, 'overlap rate': 0.4345158778131008}
#
# Current epoch: 25,
# training performance: {'loss': 1.9238619923591613, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006885875853186007, 'overlap rate': 0.4306922733783722}
# evaluation performance: {'loss': 1.9571535483002662, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007066666792525211, 'overlap rate': 0.42989504225552083}
#
# Current epoch: 30,
# training performance: {'loss': 1.9044582664966583, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0022166666924022136, 'overlap rate': 0.43641837909817693}
# evaluation performance: {'loss': 1.9168039098381997, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002225833358534146, 'overlap rate': 0.43451837822794914}
#
# Current epoch: 35,
# training performance: {'loss': 1.9155332714319229, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024866666964953764, 'overlap rate': 0.43623170629143715}
# evaluation performance: {'loss': 2.0099105343222616, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024391666927840562, 'overlap rate': 0.4338742133229971}
#
# Current epoch: 40,
# training performance: {'loss': 1.8934335947036742, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024700000300072133, 'overlap rate': 0.4383133754134178}
# evaluation performance: {'loss': 1.9235772103071214, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024708333541639147, 'overlap rate': 0.4347050454467535}
#
# Current epoch: 45,
# training performance: {'loss': 1.8900905936956405, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002433333350927569, 'overlap rate': 0.43858171328902246}
# evaluation performance: {'loss': 1.9349747493863105, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025141667007119394, 'overlap rate': 0.43461504243314264}
#
# Current epoch: 50,
# training performance: {'loss': 1.886799094080925, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024100000213366003, 'overlap rate': 0.43949504718184473}
# evaluation performance: {'loss': 1.8992164984345437, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002440000034403056, 'overlap rate': 0.43451671339571474}
#
# Current epoch: 55,
# training performance: {'loss': 1.8853164523839951, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0023400000121910126, 'overlap rate': 0.4405867144465446}
# evaluation performance: {'loss': 1.9053068161010742, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002285833364294376, 'overlap rate': 0.4342508759349585}
#
# Current epoch: 60,
# training performance: {'loss': 1.8813478291034698, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018850000225938857, 'overlap rate': 0.44305170476436617}
# evaluation performance: {'loss': 1.9708277568221093, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001798333358601667, 'overlap rate': 0.43308337591588497}
#
# Current epoch: 65,
# training performance: {'loss': 1.8573192059993744, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018350000231293962, 'overlap rate': 0.45052005127072337}
# evaluation performance: {'loss': 1.927555112540722, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0017975000271690078, 'overlap rate': 0.4322975441813469}
#
# Current epoch: 70,
# training performance: {'loss': 1.8661658138036727, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019000000262167304, 'overlap rate': 0.4475850470364094}
# evaluation performance: {'loss': 1.9000053092837335, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016391666904382873, 'overlap rate': 0.4323983769863844}
#
# Current epoch: 75,
# training performance: {'loss': 1.8961938321590424, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001698870089603588, 'overlap rate': 0.4439889922738075}
# evaluation performance: {'loss': 1.9519428670406342, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001258601717563579, 'overlap rate': 0.43105470314621924}
#
# Current epoch: 80,
# training performance: {'loss': 1.8460566997528076, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001918333349749446, 'overlap rate': 0.4527417071163654}
# evaluation performance: {'loss': 1.899574713408947, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019075000265729614, 'overlap rate': 0.4325392071157694}
#
# Current epoch: 85,
# training performance: {'loss': 1.8499754816293716, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019450000225333496, 'overlap rate': 0.4529033824801445}
# evaluation performance: {'loss': 1.9564749106764794, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019483333584503272, 'overlap rate': 0.42513254545629026}
#
# Current epoch: 90,
# training performance: {'loss': 1.8407510608434676, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019750000181375073, 'overlap rate': 0.45399670898914335}
# evaluation performance: {'loss': 1.9015933945775032, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018601977651997003, 'overlap rate': 0.43226358741521836}
#
# Current epoch: 95,
# training performance: {'loss': 1.8353894472122192, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002050000027520582, 'overlap rate': 0.45471671149134635}
# evaluation performance: {'loss': 1.9005066469311713, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019433333465713077, 'overlap rate': 0.4329617079347372}
#
# Current epoch: 100,
# training performance: {'loss': 1.8407123118638993, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002053333350340836, 'overlap rate': 0.45397670939564705}
# evaluation performance: {'loss': 1.9060577288269998, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019050988936214707, 'overlap rate': 0.43247210830450056}
#
# Current epoch: 105,
# training performance: {'loss': 1.833114206790924, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021050000112154523, 'overlap rate': 0.45542004629969596}
# evaluation performance: {'loss': 1.8985261276364327, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019983333520940507, 'overlap rate': 0.4328425470739603}
#
# Current epoch: 110,
# training performance: {'loss': 1.883319115638733, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020833333459449933, 'overlap rate': 0.44310337901115415}
# evaluation performance: {'loss': 1.912455366551876, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020375000312924385, 'overlap rate': 0.43310254327952863}
#
# Current epoch: 115,
# training performance: {'loss': 1.8335220992565155, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021316666912753134, 'overlap rate': 0.4553633786737919}
# evaluation performance: {'loss': 1.9014102980494498, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001965833360736724, 'overlap rate': 0.4328542113304138}
#
# Current epoch: 120,
# training performance: {'loss': 1.8734923779964447, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002055367249704432, 'overlap rate': 0.4505029872059822}
# evaluation performance: {'loss': 1.9128307297825813, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018725706457189517, 'overlap rate': 0.432266129553318}
#
# Current epoch: 125,
# training performance: {'loss': 1.8258072435855865, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002161666698521003, 'overlap rate': 0.4565983787178993}
# evaluation performance: {'loss': 1.9117456406354905, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002020974587503588, 'overlap rate': 0.4326962999999523}
#
# Current epoch: 130,
# training performance: {'loss': 1.8305961042642593, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021066666871774943, 'overlap rate': 0.456503377109766}
# evaluation performance: {'loss': 1.8985944613814354, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020533333605271763, 'overlap rate': 0.43275921009480955}
#
# Current epoch: 135,
# training performance: {'loss': 1.9294198602437973, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001942259921634104, 'overlap rate': 0.4417589694261551}
# evaluation performance: {'loss': 1.9693607911467552, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020566666935337707, 'overlap rate': 0.4330642089247704}
#
# Current epoch: 140,
# training performance: {'loss': 1.823915421962738, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002213333357940428, 'overlap rate': 0.45684671550989153}
# evaluation performance: {'loss': 1.9005496740341186, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00201833336323034, 'overlap rate': 0.43315254263579844}
#
# Current epoch: 145,
# training performance: {'loss': 1.8635075628757476, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021516666893148795, 'overlap rate': 0.4511950433254242}
# evaluation performance: {'loss': 1.9015070527791977, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002052500023273751, 'overlap rate': 0.43262171037495134}
#
# Current epoch: 150,
# training performance: {'loss': 1.8253771215677261, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021683333645341916, 'overlap rate': 0.45637504681944846}
# evaluation performance: {'loss': 1.898004437983036, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020900000308756717, 'overlap rate': 0.4329192079603672}
#
# Current epoch: 155,
# training performance: {'loss': 1.867506557703018, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021652260053087956, 'overlap rate': 0.4515103556215763}
# evaluation performance: {'loss': 1.906962661445141, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020175000274321063, 'overlap rate': 0.4329550459980965}
#
# Current epoch: 160,
# training performance: {'loss': 1.8174595534801483, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002256666685570963, 'overlap rate': 0.4581783749163151}
# evaluation performance: {'loss': 1.9001388162374497, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020675000385381283, 'overlap rate': 0.43275421150028703}
#
# Current epoch: 165,
# training performance: {'loss': 1.8339227586984634, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0022216666955500843, 'overlap rate': 0.45619671419262886}
# evaluation performance: {'loss': 1.9038632825016975, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002081666688900441, 'overlap rate': 0.4327050469815731}
#
# Current epoch: 170,
# training performance: {'loss': 1.8142741978168488, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0022466666938271373, 'overlap rate': 0.4587000459432602}
# evaluation performance: {'loss': 1.8989505052566529, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00212916669115657, 'overlap rate': 0.43308004550635815}
#
# Current epoch: 175,
# training performance: {'loss': 1.8771071583032608, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00211364408605732, 'overlap rate': 0.4494636580348015}
# evaluation performance: {'loss': 1.8976756438612938, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020141666929703204, 'overlap rate': 0.4329500414431095}
#
# Current epoch: 180,
# training performance: {'loss': 1.8219383090734482, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0023116666881833224, 'overlap rate': 0.45784504935145376}
# evaluation performance: {'loss': 1.8991108492016793, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00216500002425164, 'overlap rate': 0.4326883777976036}
#
# Current epoch: 185,
# training performance: {'loss': 1.8138392180204392, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002320000043255277, 'overlap rate': 0.4586650513112545}
# evaluation performance: {'loss': 1.8984986752271653, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021758333445177414, 'overlap rate': 0.43342004120349886}
#
# Current epoch: 190,
# training performance: {'loss': 1.817755177617073, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0023150000255554915, 'overlap rate': 0.4586017124354839}
# evaluation performance: {'loss': 1.898386301100254, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002158333361148834, 'overlap rate': 0.4331200454384089}
#
# Current epoch: 195,
# training performance: {'loss': 1.9091911554336547, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002067005669232458, 'overlap rate': 0.4432062305510044}
# evaluation performance: {'loss': 1.9032523095607758, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021416666844743305, 'overlap rate': 0.4332950431853533}
#
# Current epoch: 200,
# training performance: {'loss': 1.813300570845604, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002356666690320708, 'overlap rate': 0.4590033784508705}
# evaluation performance: {'loss': 1.8989391654729844, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021275000341120175, 'overlap rate': 0.43305421210825445}
#
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/RNN/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.8991097554564476, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020108333497773855, 'overlap rate': 0.4331650445237756}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 5.354332363605499, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001803341154300142, 'overlap rate': 0.033537639584392306}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.28640604019165, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007687224338071481, 'overlap rate': 0.38058737516403196}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.897077227893629, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020512791831462985, 'overlap rate': 0.03550805259299906}
# Experiments_Logs/Experiment#8/RNN/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#8 with RNN seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#8/RNN/hyperparameters.json saved!

# %%
from google.colab import runtime
runtime.unassign()
