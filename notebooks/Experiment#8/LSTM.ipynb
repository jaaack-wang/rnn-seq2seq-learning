# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = False
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 8
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#8/LSTM created!
# ./Experiments_Logs/Experiment#8/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#8/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#8/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#8 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9627960681915284, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006316666811471805, 'overlap rate': 0.41966171115636824}
# evaluation performance: {'loss': 3.363228937983513, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006558333472639788, 'overlap rate': 0.2613158605992794}
#
# Current epoch: 10,
# training performance: {'loss': 1.939992517232895, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006550000151037238, 'overlap rate': 0.42743504568934443}
# evaluation performance: {'loss': 2.5463053941726685, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006550000132847344, 'overlap rate': 0.4280808798968792}
#
# Current epoch: 15,
# training performance: {'loss': 1.93025763630867, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007033333444269374, 'overlap rate': 0.42938670963048936}
# evaluation performance: {'loss': 2.401409959793091, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333506266353, 'overlap rate': 0.4287500444799662}
#
# Current epoch: 20,
# training performance: {'loss': 1.9286217749118806, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007900000186054967, 'overlap rate': 0.4293700434267521}
# evaluation performance: {'loss': 2.5691055327653887, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007141666839743266, 'overlap rate': 0.4282217096537352}
#
# Current epoch: 25,
# training performance: {'loss': 1.9159407645463944, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007516666810261086, 'overlap rate': 0.4315067149698734}
# evaluation performance: {'loss': 2.0771284639835357, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006475000116552109, 'overlap rate': 0.4298608753830194}
#
# Current epoch: 30,
# training performance: {'loss': 1.9335685580968858, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007566666870843619, 'overlap rate': 0.42915504053235054}
# evaluation performance: {'loss': 2.8567085057497024, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006967514287680388, 'overlap rate': 0.4281874880194664}
#
# Current epoch: 35,
# training performance: {'loss': 1.9123202204704284, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007468926753062988, 'overlap rate': 0.4317330658435822}
# evaluation performance: {'loss': 1.9135520100593566, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000645000015720143, 'overlap rate': 0.4304292075335979}
#
# Current epoch: 40,
# training performance: {'loss': 1.8992640733718873, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007933333512482932, 'overlap rate': 0.43292504400014875}
# evaluation performance: {'loss': 1.8992607697844506, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000687500013737008, 'overlap rate': 0.4307558752596378}
#
# Current epoch: 45,
# training performance: {'loss': 2.095779624581337, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008337853287230246, 'overlap rate': 0.4134932652115822}
# evaluation performance: {'loss': 6.234477436542511, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006893220486745121, 'overlap rate': 0.09002955676987767}
#
# Current epoch: 50,
# training performance: {'loss': 1.8954115360975266, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008866666852554772, 'overlap rate': 0.4367150478065014}
# evaluation performance: {'loss': 1.8971707761287688, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008466666844469728, 'overlap rate': 0.43258754573762415}
#
# Current epoch: 55,
# training performance: {'loss': 1.8844511955976486, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014716666992171668, 'overlap rate': 0.44074837639927866}
# evaluation performance: {'loss': 1.8925579443573952, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016683333604305516, 'overlap rate': 0.43525254391133783}
#
# Current epoch: 60,
# training performance: {'loss': 1.8680822640657424, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002241666681948118, 'overlap rate': 0.4453800432384014}
# evaluation performance: {'loss': 1.8848545029759407, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0022191666867001913, 'overlap rate': 0.4374408762902021}
#
# Current epoch: 65,
# training performance: {'loss': 1.853938066959381, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0031033333856612445, 'overlap rate': 0.4502250462770462}
# evaluation performance: {'loss': 1.8754119113087655, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029797457973472774, 'overlap rate': 0.44076123349368573}
#
# Current epoch: 70,
# training performance: {'loss': 1.8162520051002502, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004478333366569132, 'overlap rate': 0.458031714707613}
# evaluation performance: {'loss': 1.8509476691484452, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0041566667176084595, 'overlap rate': 0.44919170886278154}
#
# Current epoch: 75,
# training performance: {'loss': 1.7625378489494323, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006451666785869748, 'overlap rate': 0.47465504705905914}
# evaluation performance: {'loss': 1.8206501096487044, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006387500104028732, 'overlap rate': 0.4584658816456795}
#
# Current epoch: 80,
# training performance: {'loss': 1.6889530003070832, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008423333428800106, 'overlap rate': 0.4979567125439644}
# evaluation performance: {'loss': 1.7907200083136559, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008574166748439893, 'overlap rate': 0.4651150479912758}
#
# Current epoch: 85,
# training performance: {'loss': 1.6253815591335297, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010123333428055048, 'overlap rate': 0.5144350476562977}
# evaluation performance: {'loss': 1.7578086465597154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01012833344284445, 'overlap rate': 0.4708775464445353}
#
# Current epoch: 90,
# training performance: {'loss': 1.56908560693264, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012131666811183096, 'overlap rate': 0.5303533896803856}
# evaluation performance: {'loss': 1.7420756652951241, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012133375881239772, 'overlap rate': 0.4742617718875408}
#
# Current epoch: 95,
# training performance: {'loss': 1.5155150920152665, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0139983335044235, 'overlap rate': 0.5454300582408905}
# evaluation performance: {'loss': 1.7144934609532356, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014555000129621475, 'overlap rate': 0.4822692170739174}
#
# Current epoch: 100,
# training performance: {'loss': 1.4782549411058425, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016306554060429336, 'overlap rate': 0.5559453651309013}
# evaluation performance: {'loss': 1.6978163480758668, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016106864623725414, 'overlap rate': 0.4866162080317736}
#
# Current epoch: 105,
# training performance: {'loss': 1.4347764611244203, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01842833342961967, 'overlap rate': 0.5680917158722878}
# evaluation performance: {'loss': 1.6848482221364975, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018026709265541285, 'overlap rate': 0.4913571681827307}
#
# Current epoch: 110,
# training performance: {'loss': 1.3933316677808762, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02036166675388813, 'overlap rate': 0.5785317257046699}
# evaluation performance: {'loss': 1.6710553258657455, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020344166876748206, 'overlap rate': 0.4966408874839544}
#
# Current epoch: 115,
# training performance: {'loss': 1.3704939574003219, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02275833343155682, 'overlap rate': 0.5844117224216461}
# evaluation performance: {'loss': 1.6650222316384315, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.022271666885353626, 'overlap rate': 0.49931588023900986}
#
# Current epoch: 120,
# training performance: {'loss': 1.3307917624711991, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.02542000012472272, 'overlap rate': 0.5942200571298599}
# evaluation performance: {'loss': 1.6543895676732063, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.02455916693434119, 'overlap rate': 0.5036242172122002}
#
# Current epoch: 125,
# training performance: {'loss': 1.3044284462928772, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.028010000521317125, 'overlap rate': 0.6018433943390846}
# evaluation performance: {'loss': 1.644544030725956, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02751583370845765, 'overlap rate': 0.508680048212409}
#
# Current epoch: 130,
# training performance: {'loss': 1.2854851126670837, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.02959449184127152, 'overlap rate': 0.6064711600542069}
# evaluation performance: {'loss': 1.6344378054142, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.02919750039000064, 'overlap rate': 0.5114642150700093}
#
# Current epoch: 135,
# training performance: {'loss': 1.250684529542923, 'abosulate accuracy': 0.0006000000284984708, 'consecutive overlap rate': 0.03214000007137656, 'overlap rate': 0.6159467279911042}
# evaluation performance: {'loss': 1.6355160921812057, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.03171000045258552, 'overlap rate': 0.5148350562900305}
#
# Current epoch: 140,
# training performance: {'loss': 1.219256728887558, 'abosulate accuracy': 0.0011000000522471964, 'consecutive overlap rate': 0.035393333481624725, 'overlap rate': 0.6241900712251663}
# evaluation performance: {'loss': 1.6300997257232666, 'abosulate accuracy': 0.0009500000451225787, 'consecutive overlap rate': 0.03494005692191422, 'overlap rate': 0.5180465802550316}
#
# Current epoch: 145,
# training performance: {'loss': 1.2167935729026795, 'abosulate accuracy': 0.0013000000617466867, 'consecutive overlap rate': 0.03776833387091756, 'overlap rate': 0.6252717345952987}
# evaluation performance: {'loss': 1.6090160593390466, 'abosulate accuracy': 0.0009500000451225787, 'consecutive overlap rate': 0.037396667245775464, 'overlap rate': 0.5216733921319247}
#
# Current epoch: 150,
# training performance: {'loss': 1.1690986573696136, 'abosulate accuracy': 0.002400000113993883, 'consecutive overlap rate': 0.04220675174146891, 'overlap rate': 0.6371562749147415}
# evaluation performance: {'loss': 1.6128023117780685, 'abosulate accuracy': 0.0013000000501051546, 'consecutive overlap rate': 0.03971569240093231, 'overlap rate': 0.5262558035552501}
#
# Current epoch: 155,
# training performance: {'loss': 1.1522380977869033, 'abosulate accuracy': 0.0020000000833533703, 'consecutive overlap rate': 0.04387833373621106, 'overlap rate': 0.6422383889555932}
# evaluation performance: {'loss': 1.6049483656883239, 'abosulate accuracy': 0.0026500001200474798, 'consecutive overlap rate': 0.04302666722796857, 'overlap rate': 0.5304767180234193}
#
# Current epoch: 160,
# training performance: {'loss': 1.1234577596187592, 'abosulate accuracy': 0.004900000209454447, 'consecutive overlap rate': 0.04902500035241246, 'overlap rate': 0.6501233965158463}
# evaluation performance: {'loss': 1.6036641910672187, 'abosulate accuracy': 0.002950000116834417, 'consecutive overlap rate': 0.04671250027604401, 'overlap rate': 0.5347100544720889}
#
# Current epoch: 165,
# training performance: {'loss': 1.0967129185795783, 'abosulate accuracy': 0.006800000299699604, 'consecutive overlap rate': 0.05273000057786703, 'overlap rate': 0.6574700683355331}
# evaluation performance: {'loss': 1.6020208567380905, 'abosulate accuracy': 0.004500000190455466, 'consecutive overlap rate': 0.049597317026928066, 'overlap rate': 0.5365685939788818}
#
# Current epoch: 170,
# training performance: {'loss': 1.0773280665278435, 'abosulate accuracy': 0.0095000003115274, 'consecutive overlap rate': 0.05807500118389726, 'overlap rate': 0.6628433972597122}
# evaluation performance: {'loss': 1.59279595464468, 'abosulate accuracy': 0.00460000018356368, 'consecutive overlap rate': 0.051915000565350054, 'overlap rate': 0.5393008895218372}
#
# Current epoch: 175,
# training performance: {'loss': 1.0562557816505431, 'abosulate accuracy': 0.010300000361166895, 'consecutive overlap rate': 0.060478334315121174, 'overlap rate': 0.6690417319536209}
# evaluation performance: {'loss': 1.594811463356018, 'abosulate accuracy': 0.006900000263703987, 'consecutive overlap rate': 0.05662333406507969, 'overlap rate': 0.5444200560450554}
#
# Current epoch: 180,
# training performance: {'loss': 1.0290591910481452, 'abosulate accuracy': 0.014100000564940273, 'consecutive overlap rate': 0.06666000057011842, 'overlap rate': 0.6758950799703598}
# evaluation performance: {'loss': 1.5937413647770882, 'abosulate accuracy': 0.007250000262865796, 'consecutive overlap rate': 0.05856583421118557, 'overlap rate': 0.5459133885800839}
#
# Current epoch: 185,
# training performance: {'loss': 1.0118301779031753, 'abosulate accuracy': 0.014800000574905426, 'consecutive overlap rate': 0.06946833431720734, 'overlap rate': 0.6815767258405685}
# evaluation performance: {'loss': 1.5825885519385339, 'abosulate accuracy': 0.009300000400980935, 'consecutive overlap rate': 0.06292333379387856, 'overlap rate': 0.5501008912920952}
#
# Current epoch: 190,
# training performance: {'loss': 0.9877882465720177, 'abosulate accuracy': 0.0174000006983988, 'consecutive overlap rate': 0.07433166764676571, 'overlap rate': 0.6878900721669197}
# evaluation performance: {'loss': 1.5905926018953322, 'abosulate accuracy': 0.009500000398838892, 'consecutive overlap rate': 0.06559583400376141, 'overlap rate': 0.5519742242991924}
#
# Current epoch: 195,
# training performance: {'loss': 0.9795101761817933, 'abosulate accuracy': 0.019600000698119402, 'consecutive overlap rate': 0.07767101777717471, 'overlap rate': 0.690089975297451}
# evaluation performance: {'loss': 1.5858486652374268, 'abosulate accuracy': 0.010850000398932025, 'consecutive overlap rate': 0.06887500071898103, 'overlap rate': 0.5551650524139404}
#
# Current epoch: 200,
# training performance: {'loss': 0.9499047920107841, 'abosulate accuracy': 0.023300000955350696, 'consecutive overlap rate': 0.08303500097244979, 'overlap rate': 0.698160070180893}
# evaluation performance: {'loss': 1.5868447154760361, 'abosulate accuracy': 0.014050000463612378, 'consecutive overlap rate': 0.07337235952727497, 'overlap rate': 0.55801190584898}
#
# Experiments_Logs/Experiment#8/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.5868358984589577, 'abosulate accuracy': 0.013550000506802462, 'consecutive overlap rate': 0.07326875096186995, 'overlap rate': 0.5580933868885041}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.729133611917496, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.10488402675837279, 'overlap rate': 0.269233500957489}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.9214335772298998, 'abosulate accuracy': 0.01578613921038566, 'consecutive overlap rate': 0.051264546931751316, 'overlap rate': 0.5109251776049214}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 2.7809751159266423, 'abosulate accuracy': 0.016342106088383223, 'consecutive overlap rate': 0.13555835746228695, 'overlap rate': 0.2584396588959192}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.96229607462883, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007050000123854261, 'overlap rate': 0.4199183747172356}
# evaluation performance: {'loss': 7.918425422906876, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006708333507049246, 'overlap rate': 0.41732420921325686}
#
# Current epoch: 10,
# training performance: {'loss': 1.9640435129404068, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007350000123551581, 'overlap rate': 0.41826837584376336}
# evaluation performance: {'loss': 3.9394949644804003, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333504447364, 'overlap rate': 0.3707667089998722}
#
# Current epoch: 15,
# training performance: {'loss': 1.9589153110980988, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007300000164832454, 'overlap rate': 0.4234933748841286}
# evaluation performance: {'loss': 3.6412107348442078, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006833333496615524, 'overlap rate': 0.4254600409418344}
#
# Current epoch: 20,
# training performance: {'loss': 1.933405977487564, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007433333492372185, 'overlap rate': 0.42904171496629717}
# evaluation performance: {'loss': 2.948415791988373, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006826271346653812, 'overlap rate': 0.42787829488515855}
#
# Current epoch: 25,
# training performance: {'loss': 1.9517792731523513, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007383333504549228, 'overlap rate': 0.42492837756872176}
# evaluation performance: {'loss': 3.126060050725937, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00066250001455046, 'overlap rate': 0.4269142124801874}
#
# Current epoch: 30,
# training performance: {'loss': 1.897518053650856, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010983333515468985, 'overlap rate': 0.4365333802998066}
# evaluation performance: {'loss': 1.9136339753866196, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009108333553740522, 'overlap rate': 0.43267837576568124}
#
# Current epoch: 35,
# training performance: {'loss': 1.8841787070035934, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012550000217743218, 'overlap rate': 0.4400133788585663}
# evaluation performance: {'loss': 1.8976225346326827, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009991666876885575, 'overlap rate': 0.43148337826132777}
#
# Current epoch: 40,
# training performance: {'loss': 1.8764604717493056, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020900000381516293, 'overlap rate': 0.4432400457561016}
# evaluation performance: {'loss': 1.892898166179657, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019441666998318396, 'overlap rate': 0.4351858776062727}
#
# Current epoch: 45,
# training performance: {'loss': 1.8518175184726715, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003356666717445478, 'overlap rate': 0.4543417118489742}
# evaluation performance: {'loss': 1.8710233941674232, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003247358780936338, 'overlap rate': 0.444892106577754}
#
# Current epoch: 50,
# training performance: {'loss': 1.784343272447586, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004761666670674458, 'overlap rate': 0.4736750528216362}
# evaluation performance: {'loss': 1.8621634393930435, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004935833375202492, 'overlap rate': 0.44655671566724775}
#
# Current epoch: 55,
# training performance: {'loss': 1.7051469683647156, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006718333414755762, 'overlap rate': 0.4945950448513031}
# evaluation performance: {'loss': 1.8536331251263618, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006948333431500942, 'overlap rate': 0.45052671283483503}
#
# Current epoch: 60,
# training performance: {'loss': 1.6400475203990936, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008710000046994537, 'overlap rate': 0.5117067135870457}
# evaluation performance: {'loss': 1.8342021092772485, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008935833390569314, 'overlap rate': 0.45530254431068895}
#
# Current epoch: 65,
# training performance: {'loss': 1.5856327950954436, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011286666826345026, 'overlap rate': 0.5258717238903046}
# evaluation performance: {'loss': 1.8003085091710092, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011486666835844516, 'overlap rate': 0.46400088295340536}
#
# Current epoch: 70,
# training performance: {'loss': 1.55182486474514, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014043333544395863, 'overlap rate': 0.534980059415102}
# evaluation performance: {'loss': 1.78527020663023, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014389166876208037, 'overlap rate': 0.4687525488436222}
#
# Current epoch: 75,
# training performance: {'loss': 1.489002960920334, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.017725000204518438, 'overlap rate': 0.5506683886051178}
# evaluation performance: {'loss': 1.7611273482441903, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018094166950322687, 'overlap rate': 0.4774417124688625}
#
# Current epoch: 80,
# training performance: {'loss': 1.4368074595928193, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.021781666949391366, 'overlap rate': 0.5645350560545921}
# evaluation performance: {'loss': 1.7323507994413376, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02165250019170344, 'overlap rate': 0.4833242155611515}
#
# Current epoch: 85,
# training performance: {'loss': 1.400814425945282, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024441666901111603, 'overlap rate': 0.5745100617408753}
# evaluation performance: {'loss': 1.7205890744924546, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024407500284723938, 'overlap rate': 0.48854088075459}
#
# Current epoch: 90,
# training performance: {'loss': 1.359102290868759, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028998333821073176, 'overlap rate': 0.5853617206215859}
# evaluation performance: {'loss': 1.7051193967461586, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.028810000349767505, 'overlap rate': 0.49577504955232143}
#
# Current epoch: 95,
# training performance: {'loss': 1.3133894324302673, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.033475000457838175, 'overlap rate': 0.5979117199778556}
# evaluation performance: {'loss': 1.683897277712822, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.033946666936390105, 'overlap rate': 0.5048933915793896}
#
# Current epoch: 100,
# training performance: {'loss': 1.2809621095657349, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.03705000029876828, 'overlap rate': 0.607148391008377}
# evaluation performance: {'loss': 1.665886551141739, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.03615583376958966, 'overlap rate': 0.5097225524485112}
#
# Current epoch: 105,
# training performance: {'loss': 1.2456431835889816, 'abosulate accuracy': 0.0013000000617466867, 'consecutive overlap rate': 0.041060960944741966, 'overlap rate': 0.6181811928749085}
# evaluation performance: {'loss': 1.6474918380379677, 'abosulate accuracy': 0.0007000000332482159, 'consecutive overlap rate': 0.0409475005697459, 'overlap rate': 0.5186575550585986}
#
# Current epoch: 110,
# training performance: {'loss': 1.1874567806720733, 'abosulate accuracy': 0.0014000000548548997, 'consecutive overlap rate': 0.045241667050868274, 'overlap rate': 0.6341383993625641}
# evaluation performance: {'loss': 1.6499816805124283, 'abosulate accuracy': 0.0014000000664964318, 'consecutive overlap rate': 0.04489416740834713, 'overlap rate': 0.5240717191249132}
#
# Current epoch: 115,
# training performance: {'loss': 1.1650962769985198, 'abosulate accuracy': 0.001600000075995922, 'consecutive overlap rate': 0.04848333382979035, 'overlap rate': 0.6416100665926934}
# evaluation performance: {'loss': 1.636419315636158, 'abosulate accuracy': 0.002050000097369775, 'consecutive overlap rate': 0.048237500619143246, 'overlap rate': 0.5291000563651324}
#
# Current epoch: 120,
# training performance: {'loss': 1.1382787644863128, 'abosulate accuracy': 0.0031000001588836314, 'consecutive overlap rate': 0.05374110229313374, 'overlap rate': 0.6476838663220406}
# evaluation performance: {'loss': 1.6332147881388663, 'abosulate accuracy': 0.0032500001427251844, 'consecutive overlap rate': 0.053562599606812, 'overlap rate': 0.5343206211924553}
#
# Current epoch: 125,
# training performance: {'loss': 1.1034550458192824, 'abosulate accuracy': 0.004000000155065209, 'consecutive overlap rate': 0.0577250006608665, 'overlap rate': 0.6571517258882522}
# evaluation performance: {'loss': 1.6325345382094383, 'abosulate accuracy': 0.003650000167544931, 'consecutive overlap rate': 0.05619166730903089, 'overlap rate': 0.5383300609886646}
#
# Current epoch: 130,
# training performance: {'loss': 1.075333046913147, 'abosulate accuracy': 0.006900000246241688, 'consecutive overlap rate': 0.06368000088259577, 'overlap rate': 0.666130068898201}
# evaluation performance: {'loss': 1.6275032877922058, 'abosulate accuracy': 0.005200000212062151, 'consecutive overlap rate': 0.061195000726729634, 'overlap rate': 0.5432542257010937}
#
# Current epoch: 135,
# training performance: {'loss': 1.06146779358387, 'abosulate accuracy': 0.008200000238139183, 'consecutive overlap rate': 0.06754666734486818, 'overlap rate': 0.6694317385554314}
# evaluation performance: {'loss': 1.612984336912632, 'abosulate accuracy': 0.005600000236881897, 'consecutive overlap rate': 0.0645007211714983, 'overlap rate': 0.5480340115725995}
#
# Current epoch: 140,
# training performance: {'loss': 1.0403728887438775, 'abosulate accuracy': 0.010100000316742807, 'consecutive overlap rate': 0.07244166806340217, 'overlap rate': 0.6751934006810189}
# evaluation performance: {'loss': 1.618411485850811, 'abosulate accuracy': 0.005350000213366002, 'consecutive overlap rate': 0.0664691673591733, 'overlap rate': 0.5497375577688217}
#
# Current epoch: 145,
# training performance: {'loss': 1.0119305655360222, 'abosulate accuracy': 0.012300000514369459, 'consecutive overlap rate': 0.07732500052079558, 'overlap rate': 0.6832050696015358}
# evaluation performance: {'loss': 1.6106606259942056, 'abosulate accuracy': 0.008550000330433249, 'consecutive overlap rate': 0.07280750060454011, 'overlap rate': 0.553995893150568}
#
# Current epoch: 150,
# training performance: {'loss': 0.990429975092411, 'abosulate accuracy': 0.016800000495277346, 'consecutive overlap rate': 0.08438833449035883, 'overlap rate': 0.6900534063577652}
# evaluation performance: {'loss': 1.617308397591114, 'abosulate accuracy': 0.011450000444892795, 'consecutive overlap rate': 0.07867083409801126, 'overlap rate': 0.558533389866352}
#
# Current epoch: 155,
# training performance: {'loss': 0.9706699848175049, 'abosulate accuracy': 0.019900000910274683, 'consecutive overlap rate': 0.0901516679674387, 'overlap rate': 0.694963401556015}
# evaluation performance: {'loss': 1.6217416018247603, 'abosulate accuracy': 0.01025000040535815, 'consecutive overlap rate': 0.08019583392888308, 'overlap rate': 0.5623742148280144}
#
# Current epoch: 160,
# training performance: {'loss': 0.938751895725727, 'abosulate accuracy': 0.026200001314282417, 'consecutive overlap rate': 0.0989560179412365, 'overlap rate': 0.7041832268238067}
# evaluation performance: {'loss': 1.6262516036629677, 'abosulate accuracy': 0.013300000416347758, 'consecutive overlap rate': 0.08556666756048799, 'overlap rate': 0.5644667252898217}
#
# Current epoch: 165,
# training performance: {'loss': 0.9357500702142716, 'abosulate accuracy': 0.025400001159869134, 'consecutive overlap rate': 0.10050500128418208, 'overlap rate': 0.7059984132647514}
# evaluation performance: {'loss': 1.5982836395502091, 'abosulate accuracy': 0.013850000407546758, 'consecutive overlap rate': 0.08840750129893422, 'overlap rate': 0.569477555155754}
#
# Current epoch: 170,
# training performance: {'loss': 0.9155815079808235, 'abosulate accuracy': 0.02930000112392008, 'consecutive overlap rate': 0.10698500107973814, 'overlap rate': 0.7110384076833725}
# evaluation performance: {'loss': 1.6010683193802833, 'abosulate accuracy': 0.017400000657653437, 'consecutive overlap rate': 0.09242000104859471, 'overlap rate': 0.5704967208206654}
#
# Current epoch: 175,
# training performance: {'loss': 0.9024225100874901, 'abosulate accuracy': 0.035200001765042545, 'consecutive overlap rate': 0.11474500130861998, 'overlap rate': 0.7150417268276215}
# evaluation performance: {'loss': 1.6099935919046402, 'abosulate accuracy': 0.018100000696722417, 'consecutive overlap rate': 0.09649500139057636, 'overlap rate': 0.5743192255496978}
#
# Current epoch: 180,
# training performance: {'loss': 0.8825718462467194, 'abosulate accuracy': 0.036200001882389185, 'consecutive overlap rate': 0.11742833498865365, 'overlap rate': 0.7210434064269066}
# evaluation performance: {'loss': 1.6101741641759872, 'abosulate accuracy': 0.018600000732112675, 'consecutive overlap rate': 0.09983750088140368, 'overlap rate': 0.5781500592827797}
#
# Current epoch: 185,
# training performance: {'loss': 0.862847974896431, 'abosulate accuracy': 0.04440000206232071, 'consecutive overlap rate': 0.12731000129133463, 'overlap rate': 0.7265350818634033}
# evaluation performance: {'loss': 1.6248653754591942, 'abosulate accuracy': 0.015550000529037789, 'consecutive overlap rate': 0.09809666788205504, 'overlap rate': 0.5804217211902142}
#
# Current epoch: 190,
# training performance: {'loss': 0.864262017607689, 'abosulate accuracy': 0.04090000167489052, 'consecutive overlap rate': 0.1253883346915245, 'overlap rate': 0.7265417516231537}
# evaluation performance: {'loss': 1.5991232320666313, 'abosulate accuracy': 0.019250000815372915, 'consecutive overlap rate': 0.10165833430364728, 'overlap rate': 0.5806092284619808}
#
# Current epoch: 195,
# training performance: {'loss': 0.8364414125680923, 'abosulate accuracy': 0.047700001811608675, 'consecutive overlap rate': 0.13343562241643667, 'overlap rate': 0.733728775382042}
# evaluation performance: {'loss': 1.615753947198391, 'abosulate accuracy': 0.02105000089504756, 'consecutive overlap rate': 0.10715000070631504, 'overlap rate': 0.5866958908736706}
#
# Current epoch: 200,
# training performance: {'loss': 0.8269801050424576, 'abosulate accuracy': 0.05380000243894756, 'consecutive overlap rate': 0.13998500145971776, 'overlap rate': 0.7369883999228477}
# evaluation performance: {'loss': 1.6041554048657418, 'abosulate accuracy': 0.023700001003453507, 'consecutive overlap rate': 0.1102008349262178, 'overlap rate': 0.5882850617170334}
#
# Experiments_Logs/Experiment#8/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.6192647486925125, 'abosulate accuracy': 0.021975000901147724, 'consecutive overlap rate': 0.10882673826999963, 'overlap rate': 0.5854019239544869}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.831738179922104, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.17778514996170997, 'overlap rate': 0.3391851749271154}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.0944560866202075, 'abosulate accuracy': 0.009940338936904746, 'consecutive overlap rate': 0.06360688764722117, 'overlap rate': 0.5288580761801812}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.0564339851078235, 'abosulate accuracy': 0.003815789703941463, 'consecutive overlap rate': 0.15668137538197793, 'overlap rate': 0.2755499984088697}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9628678739070893, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007100000118953175, 'overlap rate': 0.4195967100560665}
# evaluation performance: {'loss': 7.892361098527909, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006510310879093595, 'overlap rate': 0.41463279761373995}
#
# Current epoch: 10,
# training performance: {'loss': 1.9517052948474884, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006966666849621106, 'overlap rate': 0.42579670920968055}
# evaluation performance: {'loss': 5.109578347206115, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006508333477540873, 'overlap rate': 0.4237167101353407}
#
# Current epoch: 15,
# training performance: {'loss': 1.9408227235078812, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007300000164832454, 'overlap rate': 0.427190038561821}
# evaluation performance: {'loss': 1.9827466696500777, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006916666803590488, 'overlap rate': 0.4302233763039112}
#
# Current epoch: 20,
# training performance: {'loss': 1.8980303794145583, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000708333346847212, 'overlap rate': 0.4317500501871109}
# evaluation performance: {'loss': 1.8988368019461632, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006900000131281559, 'overlap rate': 0.43086254559457304}
#
# Current epoch: 25,
# training performance: {'loss': 1.895897176861763, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000738333349727327, 'overlap rate': 0.43322171568870543}
# evaluation performance: {'loss': 1.9003686100244521, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007258333493155078, 'overlap rate': 0.43148504570126534}
#
# Current epoch: 30,
# training performance: {'loss': 1.961855399608612, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007516666839364917, 'overlap rate': 0.4275983773171902}
# evaluation performance: {'loss': 1.9194887652993202, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000724166681902716, 'overlap rate': 0.4305242095142603}
#
# Current epoch: 35,
# training performance: {'loss': 1.8929324179887772, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000990000015735859, 'overlap rate': 0.4355850502848625}
# evaluation performance: {'loss': 1.8939314052462577, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007908333551313263, 'overlap rate': 0.43408837616443635}
#
# Current epoch: 40,
# training performance: {'loss': 1.868974894285202, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002158333361148834, 'overlap rate': 0.4474217116832733}
# evaluation performance: {'loss': 1.881613564491272, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019658333447296174, 'overlap rate': 0.4391450431197882}
#
# Current epoch: 45,
# training performance: {'loss': 1.8190677136182785, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003415000037057325, 'overlap rate': 0.461703385412693}
# evaluation performance: {'loss': 1.8727173790335656, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003523333347402513, 'overlap rate': 0.44288337863981725}
#
# Current epoch: 50,
# training performance: {'loss': 1.7704863220453262, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00518500006874092, 'overlap rate': 0.4751650482416153}
# evaluation performance: {'loss': 1.8558309495449066, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005684166721766815, 'overlap rate': 0.45205921567976476}
#
# Current epoch: 55,
# training performance: {'loss': 1.7091545909643173, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00654166677268222, 'overlap rate': 0.485228381305933}
# evaluation performance: {'loss': 1.839894424378872, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006554166728165001, 'overlap rate': 0.4565458744764328}
#
# Current epoch: 60,
# training performance: {'loss': 1.6535168915987015, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008325000084005297, 'overlap rate': 0.5012850485742092}
# evaluation performance: {'loss': 1.800775085389614, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008686186518752947, 'overlap rate': 0.4642132826149464}
#
# Current epoch: 65,
# training performance: {'loss': 1.581440418958664, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011160000064410269, 'overlap rate': 0.52208838686347}
# evaluation performance: {'loss': 1.762202760577202, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011365833471063524, 'overlap rate': 0.476803382486105}
#
# Current epoch: 70,
# training performance: {'loss': 1.4839402854442596, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015280000166967511, 'overlap rate': 0.5493633970618248}
# evaluation performance: {'loss': 1.7375592738389969, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015285833494272084, 'overlap rate': 0.48558671921491625}
#
# Current epoch: 75,
# training performance: {'loss': 1.4100855588912964, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018831666838377715, 'overlap rate': 0.5705933913588523}
# evaluation performance: {'loss': 1.7056834727525712, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018590000411495566, 'overlap rate': 0.4976817175745964}
#
# Current epoch: 80,
# training performance: {'loss': 1.3342837035655974, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024775000382214786, 'overlap rate': 0.5927133888006211}
# evaluation performance: {'loss': 1.6808987155556678, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024246666952967642, 'overlap rate': 0.5086017239838838}
#
# Current epoch: 85,
# training performance: {'loss': 1.2735511243343354, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.030035000294446945, 'overlap rate': 0.6096450686454773}
# evaluation performance: {'loss': 1.652072075009346, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.029755000304430724, 'overlap rate': 0.5191750526428223}
#
# Current epoch: 90,
# training performance: {'loss': 1.2335064947605132, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.034956667199730874, 'overlap rate': 0.6222233980894089}
# evaluation performance: {'loss': 1.6491058513522148, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03443666703533381, 'overlap rate': 0.525075887516141}
#
# Current epoch: 95,
# training performance: {'loss': 1.189158621430397, 'abosulate accuracy': 0.0006000000284984708, 'consecutive overlap rate': 0.0388266671448946, 'overlap rate': 0.635778397321701}
# evaluation performance: {'loss': 1.6197686359286307, 'abosulate accuracy': 0.0006000000284984708, 'consecutive overlap rate': 0.03867333373054862, 'overlap rate': 0.533537556603551}
#
# Current epoch: 100,
# training performance: {'loss': 1.1547187447547913, 'abosulate accuracy': 0.0022000000928528605, 'consecutive overlap rate': 0.043875000439584255, 'overlap rate': 0.6457850694656372}
# evaluation performance: {'loss': 1.6137165948748589, 'abosulate accuracy': 0.000800000037997961, 'consecutive overlap rate': 0.04132833373732865, 'overlap rate': 0.5382442206144333}
#
# Current epoch: 105,
# training performance: {'loss': 1.1266748309135437, 'abosulate accuracy': 0.0022000000928528605, 'consecutive overlap rate': 0.0467933339998126, 'overlap rate': 0.6523983895778656}
# evaluation performance: {'loss': 1.6214768141508102, 'abosulate accuracy': 0.0009000000427477062, 'consecutive overlap rate': 0.044768334040418266, 'overlap rate': 0.5412092238664628}
#
# Current epoch: 110,
# training performance: {'loss': 1.0980266705155373, 'abosulate accuracy': 0.002700000116601586, 'consecutive overlap rate': 0.04997833389788866, 'overlap rate': 0.6610434129834175}
# evaluation performance: {'loss': 1.6191116020083427, 'abosulate accuracy': 0.0014500000630505382, 'consecutive overlap rate': 0.0465858337469399, 'overlap rate': 0.5450375571846962}
#
# Current epoch: 115,
# training performance: {'loss': 1.0713524281978608, 'abosulate accuracy': 0.0054000002099201085, 'consecutive overlap rate': 0.055651667434722184, 'overlap rate': 0.6681550726294517}
# evaluation performance: {'loss': 1.610953225195408, 'abosulate accuracy': 0.0028000001213513313, 'consecutive overlap rate': 0.051420833775773646, 'overlap rate': 0.5514333859086037}
#
# Current epoch: 120,
# training performance: {'loss': 1.0383793413639069, 'abosulate accuracy': 0.007000000297557563, 'consecutive overlap rate': 0.06066166730597615, 'overlap rate': 0.6781584039330483}
# evaluation performance: {'loss': 1.6230202227830888, 'abosulate accuracy': 0.0027000001224223523, 'consecutive overlap rate': 0.05337583385407925, 'overlap rate': 0.5523475557565689}
#
# Current epoch: 125,
# training performance: {'loss': 1.0247918874025346, 'abosulate accuracy': 0.00850000026402995, 'consecutive overlap rate': 0.06383000100031495, 'overlap rate': 0.6810200721025467}
# evaluation performance: {'loss': 1.619068305194378, 'abosulate accuracy': 0.0048000001872424035, 'consecutive overlap rate': 0.058667500503361225, 'overlap rate': 0.5550833858549595}
#
# Current epoch: 130,
# training performance: {'loss': 1.0005840256810188, 'abosulate accuracy': 0.010200000472832472, 'consecutive overlap rate': 0.06843669563531876, 'overlap rate': 0.6881010875105857}
# evaluation performance: {'loss': 1.6149528205394745, 'abosulate accuracy': 0.005600000219419599, 'consecutive overlap rate': 0.06217000056058168, 'overlap rate': 0.5613600589334965}
#
# Current epoch: 135,
# training performance: {'loss': 0.9924897983670234, 'abosulate accuracy': 0.011300000385381282, 'consecutive overlap rate': 0.07090666769072414, 'overlap rate': 0.6899750739336014}
# evaluation performance: {'loss': 1.6284665539860725, 'abosulate accuracy': 0.00660000026691705, 'consecutive overlap rate': 0.06510250065475702, 'overlap rate': 0.5621967241168022}
#
# Current epoch: 140,
# training performance: {'loss': 0.9716044574975967, 'abosulate accuracy': 0.015200000640470534, 'consecutive overlap rate': 0.07660333421081304, 'overlap rate': 0.6954017356038094}
# evaluation performance: {'loss': 1.6254163071513177, 'abosulate accuracy': 0.007300000241957605, 'consecutive overlap rate': 0.06787333404645324, 'overlap rate': 0.5662608921527863}
#
# Current epoch: 145,
# training performance: {'loss': 0.9457605823874473, 'abosulate accuracy': 0.019200000702403484, 'consecutive overlap rate': 0.08338333461433649, 'overlap rate': 0.7022934004664421}
# evaluation performance: {'loss': 1.6335976645350456, 'abosulate accuracy': 0.009350000385893509, 'consecutive overlap rate': 0.07195916743949056, 'overlap rate': 0.5685033857822418}
#
# Current epoch: 150,
# training performance: {'loss': 0.9354639708995819, 'abosulate accuracy': 0.019900000817142428, 'consecutive overlap rate': 0.08607500065118075, 'overlap rate': 0.7054567441344262}
# evaluation performance: {'loss': 1.6284283801913262, 'abosulate accuracy': 0.009050000255228952, 'consecutive overlap rate': 0.07297416781075299, 'overlap rate': 0.5705517262220383}
#
# Current epoch: 155,
# training performance: {'loss': 0.9116267904639244, 'abosulate accuracy': 0.02170000079786405, 'consecutive overlap rate': 0.08928570747375489, 'overlap rate': 0.7114820495247841}
# evaluation performance: {'loss': 1.6271896675229072, 'abosulate accuracy': 0.011500000423984602, 'consecutive overlap rate': 0.07854166775941848, 'overlap rate': 0.573710898309946}
#
# Current epoch: 160,
# training performance: {'loss': 0.8898608922958374, 'abosulate accuracy': 0.026300001027993857, 'consecutive overlap rate': 0.09647666793316603, 'overlap rate': 0.7179900750517845}
# evaluation performance: {'loss': 1.65550404638052, 'abosulate accuracy': 0.012650000449502841, 'consecutive overlap rate': 0.0801583344116807, 'overlap rate': 0.5744983933866024}
#
# Current epoch: 165,
# training performance: {'loss': 0.8831145763397217, 'abosulate accuracy': 0.030700001353397965, 'consecutive overlap rate': 0.10201833434402943, 'overlap rate': 0.7199867352843284}
# evaluation performance: {'loss': 1.644688206911087, 'abosulate accuracy': 0.01335000055260025, 'consecutive overlap rate': 0.08349583428353072, 'overlap rate': 0.5776467233896255}
#
# Current epoch: 170,
# training performance: {'loss': 0.8624136716127395, 'abosulate accuracy': 0.03150000157766044, 'consecutive overlap rate': 0.10477841868996621, 'overlap rate': 0.725521120429039}
# evaluation performance: {'loss': 1.6651986479759215, 'abosulate accuracy': 0.014950000552926213, 'consecutive overlap rate': 0.08715166747570038, 'overlap rate': 0.5799042247235775}
#
# Current epoch: 175,
# training performance: {'loss': 0.8467726841568947, 'abosulate accuracy': 0.035400001471862196, 'consecutive overlap rate': 0.11104333493858576, 'overlap rate': 0.7302650660276413}
# evaluation performance: {'loss': 1.6625230938196183, 'abosulate accuracy': 0.017900000733789057, 'consecutive overlap rate': 0.09118833448737859, 'overlap rate': 0.5818025507032871}
#
# Current epoch: 180,
# training performance: {'loss': 0.8369349539279938, 'abosulate accuracy': 0.03900000175926834, 'consecutive overlap rate': 0.1158583341166377, 'overlap rate': 0.7326717406511307}
# evaluation performance: {'loss': 1.677535316348076, 'abosulate accuracy': 0.014050000550923869, 'consecutive overlap rate': 0.08817666750401258, 'overlap rate': 0.5819483943283558}
#
# Current epoch: 185,
# training performance: {'loss': 0.8221216678619385, 'abosulate accuracy': 0.04220000174827874, 'consecutive overlap rate': 0.1212733343243599, 'overlap rate': 0.7374817356467247}
# evaluation performance: {'loss': 1.6725050806999207, 'abosulate accuracy': 0.01955000082962215, 'consecutive overlap rate': 0.09687500102445483, 'overlap rate': 0.5861617259681224}
#
# Current epoch: 190,
# training performance: {'loss': 0.8082573905587196, 'abosulate accuracy': 0.04570000236853957, 'consecutive overlap rate': 0.1264000006020069, 'overlap rate': 0.7410534113645554}
# evaluation performance: {'loss': 1.684575766324997, 'abosulate accuracy': 0.02215000091237016, 'consecutive overlap rate': 0.1002433338202536, 'overlap rate': 0.5879342280328274}
#
# Current epoch: 195,
# training performance: {'loss': 0.792396855354309, 'abosulate accuracy': 0.04920000219717622, 'consecutive overlap rate': 0.13078166786581277, 'overlap rate': 0.7457017362117767}
# evaluation performance: {'loss': 1.6966509476304055, 'abosulate accuracy': 0.021800000901566818, 'consecutive overlap rate': 0.10047166785225273, 'overlap rate': 0.5881783969700336}
#
# Current epoch: 200,
# training performance: {'loss': 0.7965058729052543, 'abosulate accuracy': 0.050200002081692216, 'consecutive overlap rate': 0.13290500100702046, 'overlap rate': 0.7444517359137535}
# evaluation performance: {'loss': 1.6824304476380347, 'abosulate accuracy': 0.02460000093560666, 'consecutive overlap rate': 0.10572583433240652, 'overlap rate': 0.5916758887469769}
#
# Experiments_Logs/Experiment#8/LSTM/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# ...
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9637997657060624, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006633333478021086, 'overlap rate': 0.418935040384531}
# evaluation performance: {'loss': 8.352302771806716, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006558333472639788, 'overlap rate': 0.41474587097764015}
#
# Current epoch: 10,
# training performance: {'loss': 1.9613496482372283, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006850000172562432, 'overlap rate': 0.4219517134130001}
# evaluation performance: {'loss': 3.03716057240963, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000621666680672206, 'overlap rate': 0.4254367098212242}
#
# Current epoch: 15,
# training performance: {'loss': 1.9326333820819854, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006700000158161856, 'overlap rate': 0.42884504422545433}
# evaluation performance: {'loss': 2.400371307134628, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006617938004637835, 'overlap rate': 0.4288728844374418}
#
# Current epoch: 20,
# training performance: {'loss': 1.958675816655159, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007650000101421028, 'overlap rate': 0.4251950405538082}
# evaluation performance: {'loss': 3.4069929480552674, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006500000150481356, 'overlap rate': 0.4264467090368271}
#
# Current epoch: 25,
# training performance: {'loss': 1.9562844574451446, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006920056635863148, 'overlap rate': 0.4228604108095169}
# evaluation performance: {'loss': 3.9540149360895156, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006341666794469347, 'overlap rate': 0.4249292090535164}
#
# Current epoch: 30,
# training performance: {'loss': 1.9234586119651795, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007683333482418675, 'overlap rate': 0.4305900394916534}
# evaluation performance: {'loss': 2.2233029127120973, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006950000151846325, 'overlap rate': 0.42927254140377047}
#
# Current epoch: 35,
# training performance: {'loss': 1.9016569972038269, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007366666788584553, 'overlap rate': 0.432846712321043}
# evaluation performance: {'loss': 1.901041530072689, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006675000136965537, 'overlap rate': 0.4303667090833187}
#
# Current epoch: 40,
# training performance: {'loss': 1.9143358260393142, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006966666769585572, 'overlap rate': 0.43093171119689944}
# evaluation performance: {'loss': 2.0599623680114747, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006583333488379139, 'overlap rate': 0.43004587665200233}
#
# Current epoch: 45,
# training performance: {'loss': 1.896802970767021, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000753333349712193, 'overlap rate': 0.4331850431859493}
# evaluation performance: {'loss': 1.8983995392918587, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333461498842, 'overlap rate': 0.43046337403357027}
#
# Current epoch: 50,
# training performance: {'loss': 1.8957466423511504, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006650000148511026, 'overlap rate': 0.43332337886095046}
# evaluation performance: {'loss': 1.8991238698363304, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000665098887111526, 'overlap rate': 0.43100696466863153}
#
# Current epoch: 55,
# training performance: {'loss': 2.018219256401062, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000682203404721804, 'overlap rate': 0.4178360290825367}
# evaluation performance: {'loss': 9.84200577735901, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006875000144646037, 'overlap rate': 0.4152592055499554}
#
# Current epoch: 60,
# training performance: {'loss': 1.9585243791341782, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007583333455841057, 'overlap rate': 0.42327337637543677}
# evaluation performance: {'loss': 3.171552512049675, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006350000148813706, 'overlap rate': 0.42775087505578996}
#
# Current epoch: 65,
# training performance: {'loss': 1.900795006752014, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000676666679646587, 'overlap rate': 0.43212671130895614}
# evaluation performance: {'loss': 1.8993730902671815, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006091666793508921, 'overlap rate': 0.4304292116314173}
#
# Current epoch: 70,
# training performance: {'loss': 1.8962381541728974, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007366666839516256, 'overlap rate': 0.4333433732390404}
# evaluation performance: {'loss': 1.8985156297683716, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000655000014739926, 'overlap rate': 0.4309008810669184}
#
# Current epoch: 75,
# training performance: {'loss': 1.8935004085302354, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000953333357028896, 'overlap rate': 0.43531837686896324}
# evaluation performance: {'loss': 1.8938694506883622, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009158333559753373, 'overlap rate': 0.43387837931513784}
#
# Current epoch: 80,
# training performance: {'loss': 1.8840198755264281, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009000000180094502, 'overlap rate': 0.4390600502490997}
# evaluation performance: {'loss': 1.8965937912464141, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000835833349992754, 'overlap rate': 0.43191754296422}
#
# Current epoch: 85,
# training performance: {'loss': 1.8739460706710815, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010450000176206232, 'overlap rate': 0.4411400444805622}
# evaluation performance: {'loss': 1.8960989356040954, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009208333540300373, 'overlap rate': 0.43210337683558464}
#
# Current epoch: 90,
# training performance: {'loss': 1.863799262046814, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011133333551697432, 'overlap rate': 0.4435100436210632}
# evaluation performance: {'loss': 1.8966975778341293, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009816666850383626, 'overlap rate': 0.4317742124199867}
#
# Current epoch: 95,
# training performance: {'loss': 1.8531759440898896, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010600000183330848, 'overlap rate': 0.44411338344216345}
# evaluation performance: {'loss': 1.89787008613348, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001015000020561274, 'overlap rate': 0.43163254372775556}
#
# Current epoch: 100,
# training performance: {'loss': 1.8479824125766755, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012983333581360057, 'overlap rate': 0.44516504257917405}
# evaluation performance: {'loss': 1.896307970583439, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012883333554782439, 'overlap rate': 0.4325317073613405}
#
# Current epoch: 105,
# training performance: {'loss': 1.8359895139932632, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0017333333496935665, 'overlap rate': 0.4492383785545826}
# evaluation performance: {'loss': 1.894971916079521, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012950000207638368, 'overlap rate': 0.43477754592895507}
#
# Current epoch: 110,
# training performance: {'loss': 1.8210092663764954, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001548333365644794, 'overlap rate': 0.45328504741191866}
# evaluation performance: {'loss': 1.8941946297883987, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001495833359513199, 'overlap rate': 0.43540087901055813}
#
# Current epoch: 115,
# training performance: {'loss': 1.79127439558506, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018016666843323037, 'overlap rate': 0.46165338307619097}
# evaluation performance: {'loss': 1.899029089510441, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016900000293389895, 'overlap rate': 0.43507337644696237}
#
# Current epoch: 120,
# training performance: {'loss': 1.7620876252651214, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001978333372971974, 'overlap rate': 0.4698033817112446}
# evaluation performance: {'loss': 1.9034927010536193, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0017966666971915401, 'overlap rate': 0.43499254435300827}
#
# Current epoch: 125,
# training performance: {'loss': 1.736055937409401, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002086666683317162, 'overlap rate': 0.4761733815073967}
# evaluation performance: {'loss': 1.90760195851326, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001951666701643262, 'overlap rate': 0.43530337773263456}
#
# Current epoch: 130,
# training performance: {'loss': 1.7113774806261062, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002266666694777086, 'overlap rate': 0.4811033792793751}
# evaluation performance: {'loss': 1.915117047727108, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002099166692642029, 'overlap rate': 0.43576754443347454}
#
# Current epoch: 135,
# training performance: {'loss': 1.7022842735052108, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002398333355085924, 'overlap rate': 0.48332504779100416}
# evaluation performance: {'loss': 1.9174624621868133, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002226666691421997, 'overlap rate': 0.4360333777964115}
#
# Current epoch: 140,
# training performance: {'loss': 1.6849764436483383, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024616666982183234, 'overlap rate': 0.48601172044873236}
# evaluation performance: {'loss': 1.9234021574258804, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0022850000255857593, 'overlap rate': 0.436379212141037}
#
# Current epoch: 145,
# training performance: {'loss': 1.6533039778470993, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002588333361200057, 'overlap rate': 0.4919817179441452}
# evaluation performance: {'loss': 1.9362168222665788, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024875000352039935, 'overlap rate': 0.4370150454342365}
#
# Current epoch: 150,
# training performance: {'loss': 1.6359938591718675, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002808333357097581, 'overlap rate': 0.49589838087558746}
# evaluation performance: {'loss': 1.9462038204073906, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002571666697622277, 'overlap rate': 0.4371542077511549}
#
# Current epoch: 155,
# training performance: {'loss': 1.613799411058426, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029666666989214717, 'overlap rate': 0.4997750476002693}
# evaluation performance: {'loss': 1.962051732838154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0026883333615842276, 'overlap rate': 0.43762421049177647}
#
# Current epoch: 160,
# training performance: {'loss': 1.6012942373752594, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003050000040093437, 'overlap rate': 0.5031167186796666}
# evaluation performance: {'loss': 1.9747679710388184, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0028125000433647076, 'overlap rate': 0.4376225434243679}
#
# Current epoch: 165,
# training performance: {'loss': 1.5953778266906737, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0031900000583846124, 'overlap rate': 0.5047350570559501}
# evaluation performance: {'loss': 1.9826107442378997, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0028766667048330417, 'overlap rate': 0.4375700432807207}
#
# Current epoch: 170,
# training performance: {'loss': 1.5816903799772262, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003293333388864994, 'overlap rate': 0.5072250582277775}
# evaluation performance: {'loss': 1.9938310250639915, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0030250000330852345, 'overlap rate': 0.4380400475114584}
#
# Current epoch: 175,
# training performance: {'loss': 1.5893926799297333, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0034916667093057184, 'overlap rate': 0.5068883895874023}
# evaluation performance: {'loss': 1.9979300409555436, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0030783333655563182, 'overlap rate': 0.4383433800190687}
#
# Current epoch: 180,
# training performance: {'loss': 1.5606845289468765, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0036000000371132048, 'overlap rate': 0.5124333925545216}
# evaluation performance: {'loss': 2.0175790935754776, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003179166722111404, 'overlap rate': 0.43861171044409275}
#
# Current epoch: 185,
# training performance: {'loss': 1.5667593359947205, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003668333380483091, 'overlap rate': 0.5122733809053898}
# evaluation performance: {'loss': 2.021430753171444, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003273333361721598, 'overlap rate': 0.4386433746665716}
#
# Current epoch: 190,
# training performance: {'loss': 1.5430159896612168, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0037498305551707744, 'overlap rate': 0.5174085803329944}
# evaluation performance: {'loss': 2.0394607961177824, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0033658333879429845, 'overlap rate': 0.4389675449579954}
#
# Current epoch: 195,
# training performance: {'loss': 1.5372900187969207, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003925000037997961, 'overlap rate': 0.5197967298328876}
# evaluation performance: {'loss': 2.042496529221535, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003475819242885336, 'overlap rate': 0.43874476477503777}
#
# Current epoch: 200,
# training performance: {'loss': 1.5364129811525344, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004050000035203993, 'overlap rate': 0.5202867217361927}
# evaluation performance: {'loss': 2.0535120561718943, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003624166696681641, 'overlap rate': 0.4393750440329313}
#
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/LSTM/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.0524421401321886, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003794992988696322, 'overlap rate': 0.43958741798996925}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.740244287252426, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007834846951300278, 'overlap rate': 0.056691162288188934}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.079646058236399, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0026621302379475488, 'overlap rate': 0.4376591832407059}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.484769300410622, 'abosulate accuracy': 0.00015789473821458064, 'consecutive overlap rate': 0.009477503150456437, 'overlap rate': 0.057581664798291105}
# Experiments_Logs/Experiment#8/LSTM/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#8 with LSTM seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#8/LSTM/hyperparameters.json saved!

# %%
from google.colab import runtime
runtime.unassign()
