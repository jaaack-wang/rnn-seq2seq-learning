# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = False
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 8
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#8 created!
# ./Experiments_Logs/Experiment#8/GRU created!
# ./Experiments_Logs/Experiment#8/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#8/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#8/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#8 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
# training performance: {'loss': 0.10691258814185858, 'abosulate accuracy': 0.3248000152409077, 'consecutive overlap rate': 0.4839533381164074, 'overlap rate': 0.9629634112119675}
# evaluation performance: {'loss': 3.9443956673145295, 'abosulate accuracy': 0.01725000069127418, 'consecutive overlap rate': 0.08930000085383653, 'overlap rate': 0.5759025558829307}
#
# Current epoch: 185,
# training performance: {'loss': 0.09311439413577319, 'abosulate accuracy': 0.35420001596212386, 'consecutive overlap rate': 0.5274016730487346, 'overlap rate': 0.9685734152793884}
# evaluation performance: {'loss': 4.153831854462624, 'abosulate accuracy': 0.015700000675860793, 'consecutive overlap rate': 0.0872041673399508, 'overlap rate': 0.5738908886909485}
#
# Current epoch: 190,
# training performance: {'loss': 0.18320039361715318, 'abosulate accuracy': 0.18740000799298287, 'consecutive overlap rate': 0.3321150027215481, 'overlap rate': 0.9338850945234298}
# evaluation performance: {'loss': 3.8081107288599014, 'abosulate accuracy': 0.014400000573368743, 'consecutive overlap rate': 0.08466500118374824, 'overlap rate': 0.5711700610816479}
#
# Current epoch: 195,
# training performance: {'loss': 0.07237279089167714, 'abosulate accuracy': 0.4333000175654888, 'consecutive overlap rate': 0.5975916728377342, 'overlap rate': 0.9774150684475899}
# evaluation performance: {'loss': 4.000155594944954, 'abosulate accuracy': 0.017900000722147525, 'consecutive overlap rate': 0.08976000091060996, 'overlap rate': 0.5762908890843391}
#
# Current epoch: 200,
# training performance: {'loss': 0.023878529854118823, 'abosulate accuracy': 0.8293000400066376, 'consecutive overlap rate': 0.9014800086617469, 'overlap rate': 0.996245077252388}
# evaluation performance: {'loss': 4.329685714840889, 'abosulate accuracy': 0.01860000078449957, 'consecutive overlap rate': 0.09138166811317205, 'overlap rate': 0.5774208962917328}
#
# Experiments_Logs/Experiment#8/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.919685347378254, 'abosulate accuracy': 0.05095000246074051, 'consecutive overlap rate': 0.1312041677068919, 'overlap rate': 0.6018075529485941}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.930078685283661, 'abosulate accuracy': 0.003325000204495154, 'consecutive overlap rate': 0.16956275692209602, 'overlap rate': 0.3658507697284222}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.128858378625686, 'abosulate accuracy': 0.022508081421256064, 'consecutive overlap rate': 0.06304561954832846, 'overlap rate': 0.5005808553388041}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.569156828679536, 'abosulate accuracy': 0.02192105362681966, 'consecutive overlap rate': 0.15955455998252882, 'overlap rate': 0.275556727851692}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9532141923904418, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009366666839923709, 'overlap rate': 0.4278583750128746}
# evaluation performance: {'loss': 2.7157762914896013, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0
# evaluation performance: {'loss': 1.931201086938381, 'abosulate accuracy': 0.026750001061009242, 'consecutive overlap rate': 0.11777666807174683, 'overlap rate': 0.6044008955359459}
#
# Current epoch: 190,
# training performance: {'loss': 0.4073749251663685, 'abosulate accuracy': 0.12550000492483376, 'consecutive overlap rate': 0.2388100016862154, 'overlap rate': 0.8515217393636704}
# evaluation performance: {'loss': 2.16255641579628, 'abosulate accuracy': 0.02590000121272169, 'consecutive overlap rate': 0.11817083461210132, 'overlap rate': 0.6015383914113045}
#
# Current epoch: 195,
# training performance: {'loss': 0.3702515736222267, 'abosulate accuracy': 0.1530000062659383, 'consecutive overlap rate': 0.2681033365428448, 'overlap rate': 0.8656900718808174}
# evaluation performance: {'loss': 2.1743468537926676, 'abosulate accuracy': 0.026400001160800456, 'consecutive overlap rate': 0.11887549506500364, 'overlap rate': 0.6019179828464984}
#
# Current epoch: 200,
# training performance: {'loss': 0.3640412397682667, 'abosulate accuracy': 0.14730000570416452, 'consecutive overlap rate': 0.2620250031352043, 'overlap rate': 0.8674584060907364}
# evaluation performance: {'loss': 2.169235886633396, 'abosulate accuracy': 0.026900001236936078, 'consecutive overlap rate': 0.12029463462531567, 'overlap rate': 0.6032155670225621}
#
# Experiments_Logs/Experiment#8/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.6923445083200932, 'abosulate accuracy': 0.04180000181077048, 'consecutive overlap rate': 0.1311325012240559, 'overlap rate': 0.6032142288982868}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.975203663110733, 'abosulate accuracy': 0.00015000001003500073, 'consecutive overlap rate': 0.1830775935202837, 'overlap rate': 0.31057317927479744}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.538628258243683, 'abosulate accuracy': 0.027262601034054833, 'consecutive overlap rate': 0.07356028826005998, 'overlap rate': 0.4972117366329316}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.078327247970982, 'abosulate accuracy': 0.013868421965621804, 'consecutive overlap rate': 0.17021269527705093, 'overlap rate': 0.2626075819134712}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9424574732780457, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015650000161258504, 'overlap rate': 0.43360337913036345}
# evaluation performance: {'loss': 2.8333034068346024, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021933333468041384, 'overlap rate': 0.43529004268348215}
#
# Current epoch: 10,
# training performance: {'loss': 1.6981767028570176, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010730000108014792, 'overlap rate': 0.503916721791029}
# evaluation performance: {'loss': 2.4771242409944536, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# evaluation performance: {'loss': 3.4521839737892153, 'abosulate accuracy': 0.0634000034071505, 'consecutive overlap rate': 0.1853016685694456, 'overlap rate': 0.6221175603568554}
#
# Current epoch: 195,
# training performance: {'loss': 0.12965619377791882, 'abosulate accuracy': 0.33370001465082166, 'consecutive overlap rate': 0.5304816715419293, 'overlap rate': 0.9548250794410705}
# evaluation performance: {'loss': 3.4366701662540438, 'abosulate accuracy': 0.0714500040281564, 'consecutive overlap rate': 0.19694712087512017, 'overlap rate': 0.6250430814921856}
#
# Current epoch: 200,
# training performance: {'loss': 0.11720905415713787, 'abosulate accuracy': 0.3487000174820423, 'consecutive overlap rate': 0.545001669973135, 'overlap rate': 0.959353406727314}
# evaluation performance: {'loss': 3.496925961971283, 'abosulate accuracy': 0.06335000367835164, 'consecutive overlap rate': 0.18636083528399466, 'overlap rate': 0.6227867260575295}
#
# Experiments_Logs/Experiment#8/GRU/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#8/GRU/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.7251585200428963, 'abosulate accuracy': 0.07857500414829702, 'consecutive overlap rate': 0.2102101999334991, 'overlap rate': 0.6322718039155006}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 33.356639528274535, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01663920177379623, 'overlap rate': 0.04265499437460676}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.781251012125323, 'abosulate accuracy': 0.02018677818799211, 'consecutive overlap rate': 0.11517549262892815, 'overlap rate': 0.5542953679638524}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 20.779670062818024, 'abosulate accuracy': 5.263158144723428e-05, 'consecutive overlap rate': 0.06458538852779097, 'overlap rate': 0.12519407125287935}
# Experiments_Logs/Experiment#8/GRU/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#8 with GRU seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
