# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Helper function to help visualize

# %%
def plot_log(log):
    len_range = len(log) -1 if "Best eval accu" in log else len(log)
    epoch_nums, train_loss, dev_loss = [], [], []
    train_acc, dev_acc = [], []

    for epoch in range(1, len_range+1):
        epoch_nums.append(epoch)
        train = log[f"Epoch#{epoch}"]["Train"]
        dev = log[f"Epoch#{epoch}"]["Eval"]
        train_loss.append(train['loss'])
        train_acc.append(train['abosulate accuracy'])

        dev_loss.append(dev['loss'])
        dev_acc.append(dev['abosulate accuracy'])

    ax1 = plt.subplot(211)
    ax1.plot(epoch_nums, train_loss, label="train loss")
    ax1.plot(epoch_nums, dev_loss, label="dev loss")
    ax1.legend()

    ax2 = plt.subplot(212)
    ax2.plot(epoch_nums, train_acc, label="train acc")
    ax2.plot(epoch_nums, dev_acc, label="dev acc")
    ax2.legend()
    plt.show()

# %%
folder = "tuning_data/"
experiment_num = 6
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250 
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 150 # max num of epoches 
train_acc_exit=0.92 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.92 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

# %% [markdown]
# # RevStr

# %%
train = read_data(join(folder, "RevStr/train.txt"))
dev = read_data(join(folder, "RevStr/dev.txt"))
saved_model_fp = join(project_dir, "notebooks/Hyperparatemers Tuning/RevStr_lstm_model.pt")

train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)

# %% [markdown]
# ## Hyperparameter set 1

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = True
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9610295355319978, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000718333351687761, 'overlap rate': 0.42039671167731285}
# evaluation performance: {'loss': 3.7706141501665114, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006416666794393678, 'overlap rate': 0.2826591946184635}
#
# Current epoch: 10,
# training performance: {'loss': 1.9244585275650024, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013233333651442082, 'overlap rate': 0.4365433774888515}
# evaluation performance: {'loss': 3.1461852490901947, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012466666885302402, 'overlap rate': 0.43257921151816847}
#
# Current epoch: 15,
# training performance: {'loss': 1.8691504895687103, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015633333576261065, 'overlap rate': 0.445408371090889}
# evaluation performance: {'loss': 2.0653246700763703, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020091666883672588, 'overlap rate': 0.4065550442785025}
#
# Current epoch: 20,
# training performance: {'loss': 1.6270475029945373, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008538333361502736, 'overlap rate': 0.5008383899927139}
# evaluation performance: {'loss': 1.6902924314141274, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008794166723964736, 'overlap rate': 0.49306171499192714}
#
# Current epoch: 25,
# training performance: {'loss': 1.522849014401436, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011558333481661975, 'overlap rate': 0.5291783876717091}
# evaluation performance: {'loss': 1.5857057213783263, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01191583345644176, 'overlap rate': 0.51524588316679}
#
# Current epoch: 30,
# training performance: {'loss': 1.3041621655225755, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.022446666890755296, 'overlap rate': 0.5963867396116257}
# evaluation performance: {'loss': 1.4280394718050957, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.022527500218711794, 'overlap rate': 0.5607508935034275}
#
# Current epoch: 35,
# training performance: {'loss': 1.1172114998102187, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.03647666666656733, 'overlap rate': 0.6526217415928841}
# evaluation performance: {'loss': 1.3166011229157448, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.035875000548548995, 'overlap rate': 0.5973917283117771}
#
# Current epoch: 40,
# training performance: {'loss': 0.8658359125256538, 'abosulate accuracy': 0.01130000049015507, 'consecutive overlap rate': 0.07510500019416214, 'overlap rate': 0.7233034133911133}
# evaluation performance: {'loss': 1.2198653772473336, 'abosulate accuracy': 0.0018000000854954123, 'consecutive overlap rate': 0.06038416717201471, 'overlap rate': 0.6379867278039455}
#
# Current epoch: 45,
# training performance: {'loss': 0.7073716849088669, 'abosulate accuracy': 0.03570000152103603, 'consecutive overlap rate': 0.11170500181615353, 'overlap rate': 0.7713217437267303}
# evaluation performance: {'loss': 1.3038480535149575, 'abosulate accuracy': 0.003450000158045441, 'consecutive overlap rate': 0.06693077771924436, 'overlap rate': 0.6468484684824943}
#
# Current epoch: 50,
# training performance: {'loss': 0.5993037715554237, 'abosulate accuracy': 0.05990000292658806, 'consecutive overlap rate': 0.1540133349597454, 'overlap rate': 0.8059067413210869}
# evaluation performance: {'loss': 1.3997059985995293, 'abosulate accuracy': 0.004600000195205211, 'consecutive overlap rate': 0.08252750094980002, 'overlap rate': 0.6529617317020893}
#
# Current epoch: 55,
# training performance: {'loss': 0.5152767300605774, 'abosulate accuracy': 0.08320000395178795, 'consecutive overlap rate': 0.1830666683614254, 'overlap rate': 0.8327750787138939}
# evaluation performance: {'loss': 1.513449417054653, 'abosulate accuracy': 0.004550000192830339, 'consecutive overlap rate': 0.08350583389401436, 'overlap rate': 0.6521325632929802}
# evaluation performance: {'loss': 2.263197918236256, 'abosulate accuracy': 0.005750000273110345, 'consecutive overlap rate': 0.08470621560700238, 'overlap rate': 0.651720967888832}
#
# Current epoch: 105,
# training performance: {'loss': 0.2513265937566757, 'abosulate accuracy': 0.18440000899136066, 'consecutive overlap rate': 0.31718500331044197, 'overlap rate': 0.9156767502427101}
# evaluation performance: {'loss': 2.3223496824502945, 'abosulate accuracy': 0.0049500002060085535, 'consecutive overlap rate': 0.08437666771933436, 'overlap rate': 0.6510125584900379}
#
# Current epoch: 110,
# training performance: {'loss': 0.2479134000837803, 'abosulate accuracy': 0.17760000769048928, 'consecutive overlap rate': 0.3119916718453169, 'overlap rate': 0.9162000820040703}
# evaluation performance: {'loss': 2.3586962550878523, 'abosulate accuracy': 0.004800000175600871, 'consecutive overlap rate': 0.08384000128135086, 'overlap rate': 0.651724225282669}
#
# Current epoch: 115,
# training performance: {'loss': 0.2268148824572563, 'abosulate accuracy': 0.20240000896155835, 'consecutive overlap rate': 0.33985000252723696, 'overlap rate': 0.9235534116625785}
# evaluation performance: {'loss': 2.429279586672783, 'abosulate accuracy': 0.005000000167638063, 'consecutive overlap rate': 0.0850283338688314, 'overlap rate': 0.651118403673172}
#
# Current epoch: 120,
# training performance: {'loss': 0.23611793629825115, 'abosulate accuracy': 0.17670000679790973, 'consecutive overlap rate': 0.3192333370447159, 'overlap rate': 0.9194617465138435}
# evaluation performance: {'loss': 2.5177866876125337, 'abosulate accuracy': 0.0051500001805834476, 'consecutive overlap rate': 0.08479583384469151, 'overlap rate': 0.6501400671899319}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#     156
# --> 157         eval_perf = evaluate(model, eval_dl, criterion)
#     158         eval_acc = eval_perf['abosulate accuracy']
#     159
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in evaluate(model, dataloader, criterion, per_seq_len_performance)
#     106             X = X.to(model.device)
#     107             Y = Y.to(model.device)
# --> 108             logits, _ = model(X, Y,
#     109                               teacher_forcing_ratio=0.0)
#     110
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /drive/My Drive/RNNSeq2Seq/scripts/model.py in forward(self, X, Y, teacher_forcing_ratio)
#     183         for t in range(1, Y.shape[0]):
#     184             output, hidden, cell, attn_w = \
# --> 185             self.decoder(y, hidden, cell, encoder_outputs)
#     186
#     187             outputs.append(output); attn_weights.append(attn_w)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /drive/My Drive/RNNSeq2Seq/scripts/model.py in forward(self, y, hidden, cell, encoder_outputs)
#     157         # output: (1, batch size, hidden size)
#     158         if self.rnn_type == "LSTM":
# --> 159             output, (hidden, cell) = self.rnn(rnn_input, (hidden, cell))
#     160         else:
#     161             output, hidden = self.rnn(rnn_input, hidden)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     767         self.check_forward_args(input, hx, batch_sizes)
#     768         if batch_sizes is None:
# --> 769             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     770                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     771         else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 2

# %%
hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9111924797296524, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006133333467005286, 'overlap rate': 0.43138837814331055}
# evaluation performance: {'loss': 1.9050104081630708, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006635310834099073, 'overlap rate': 0.43052393905818465}
#
# Current epoch: 10,
# training performance: {'loss': 1.8986809074878692, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006633333490754012, 'overlap rate': 0.4322350464761257}
# evaluation performance: {'loss': 1.8990997105836869, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006575000181328506, 'overlap rate': 0.4310650438070297}
#
# Current epoch: 15,
# training performance: {'loss': 1.897565519809723, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006866666772111785, 'overlap rate': 0.43212337642908094}
# evaluation performance: {'loss': 1.8993864625692367, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006716666830470785, 'overlap rate': 0.4309975434094667}
#
# Current epoch: 20,
# training performance: {'loss': 1.8976662874221801, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007100000140781049, 'overlap rate': 0.4325000442564487}
# evaluation performance: {'loss': 1.8989591673016548, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006900000171299325, 'overlap rate': 0.43107337802648543}
#
# Current epoch: 25,
# training performance: {'loss': 1.8919981211423873, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002293333350098692, 'overlap rate': 0.43593504577875136}
# evaluation performance: {'loss': 1.8908324047923089, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002801666689629201, 'overlap rate': 0.43760004788637163}
#
# Current epoch: 30,
# training performance: {'loss': 1.865231254696846, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006943333416711539, 'overlap rate': 0.4455017104744911}
# evaluation performance: {'loss': 1.869836723804474, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007450748642440885, 'overlap rate': 0.4388243079185486}
#
# Current epoch: 35,
# training performance: {'loss': 1.8291070610284805, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01271333354525268, 'overlap rate': 0.45713171139359476}
# evaluation performance: {'loss': 1.8384293004870416, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013077500229701399, 'overlap rate': 0.4498542115092278}
#
# Current epoch: 40,
# training performance: {'loss': 1.7629773557186126, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016280000167898833, 'overlap rate': 0.4715400457382202}
# evaluation performance: {'loss': 1.7937352180480957, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01659833355806768, 'overlap rate': 0.4592925444245338}
#
# Current epoch: 45,
# training performance: {'loss': 1.745968943834305, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.019125000154599548, 'overlap rate': 0.4747650496661663}
# evaluation performance: {'loss': 1.7730721920728683, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01924000014550984, 'overlap rate': 0.46236337833106517}
#
# Current epoch: 50,
# training performance: {'loss': 1.7239569008350373, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020268474705517292, 'overlap rate': 0.4784010946750641}
# evaluation performance: {'loss': 1.7635509237647056, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01989255682565272, 'overlap rate': 0.46374804265797137}
#
# Current epoch: 55,
# training performance: {'loss': 1.7035050988197327, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02076833350583911, 'overlap rate': 0.48256838098168375}
# evaluation performance: {'loss': 1.7545198634266854, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02031916701234877, 'overlap rate': 0.4650983795523643}
#
# Current epoch: 60,
# training performance: {'loss': 1.6930686831474304, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02121500005014241, 'overlap rate': 0.4853717155754566}
# evaluation performance: {'loss': 1.7685318395495415, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02050750032067299, 'overlap rate': 0.4654017124325037}
#
# Current epoch: 65,
# training performance: {'loss': 1.6801557153463365, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.021290000388398768, 'overlap rate': 0.4905967183411121}
# evaluation performance: {'loss': 1.7718943700194358, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02110416693612933, 'overlap rate': 0.46663088239729406}
#
# Current epoch: 70,
# training performance: {'loss': 1.6465601116418838, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02352833338081837, 'overlap rate': 0.5005750529468059}
# evaluation performance: {'loss': 1.7853740721940994, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02100916679482907, 'overlap rate': 0.466605881601572}
#
# Current epoch: 75,
# training performance: {'loss': 1.5994818031787872, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.026535000279545785, 'overlap rate': 0.515628381818533}
# evaluation performance: {'loss': 1.7978262066841126, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02483666690532118, 'overlap rate': 0.47129588313400744}
#
# Current epoch: 80,
# training performance: {'loss': 1.526617619395256, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.027753333654254676, 'overlap rate': 0.5380517244338989}
# evaluation performance: {'loss': 1.8616297930479049, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025659166974946856, 'overlap rate': 0.47175171710550784}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#     156
# --> 157         eval_perf = evaluate(model, eval_dl, criterion)
#     158         eval_acc = eval_perf['abosulate accuracy']
#     159
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in evaluate(model, dataloader, criterion, per_seq_len_performance)
#     110
#     111             Ypred = logits.view(seq_len, batch_size, -1).argmax(2)
# --> 112             accu, covr, ovr = metrics(Y[1:-1], Ypred[:-1])
#     113             loss = criterion(logits, Y[1:].view(-1))
#     114
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in metrics(Y, Ypred)
#      30
#      31     # overlap_rate and abosulate accuracy
# ---> 32     overlap_rate = batch_overlap_rate.mean().item()
#      33     abs_correct = (batch_overlap_rate == 1.0)
#      34     abs_accu = abs_correct.float().mean().item()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 3

# %%
hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 1e-2
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9252118825912476, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009800000203540548, 'overlap rate': 0.4322133757174015}
# evaluation performance: {'loss': 1.9584557130932807, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010593079343379941, 'overlap rate': 0.43358810655772684}
#
# Current epoch: 10,
# training performance: {'loss': 1.8526558339595796, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0032883333798963575, 'overlap rate': 0.4449133761227131}
# evaluation performance: {'loss': 1.8744195833802224, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038691667228704318, 'overlap rate': 0.43538004383444784}
#
# Current epoch: 15,
# training performance: {'loss': 1.7191067188978195, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014901666902005672, 'overlap rate': 0.4793933808803558}
# evaluation performance: {'loss': 1.7767226949334145, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016289166826754808, 'overlap rate': 0.4637833803892136}
#
# Current epoch: 20,
# training performance: {'loss': 1.561902979016304, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
#
# Current epoch: 70,
# training performance: {'loss': 1.0307866171002389, 'abosulate accuracy': 0.011100000445730984, 'consecutive overlap rate': 0.09041666751727462, 'overlap rate': 0.6800650656223297}
# evaluation performance: {'loss': 1.6852089062333107, 'abosulate accuracy': 0.0013000000617466867, 'consecutive overlap rate': 0.06621000058948993, 'overlap rate': 0.5734658971428871}
#
# Current epoch: 75,
# training performance: {'loss': 0.8463296219706535, 'abosulate accuracy': 0.03850000184029341, 'consecutive overlap rate': 0.15198833718895913, 'overlap rate': 0.7351700767874718}
# evaluation performance: {'loss': 1.787047803401947, 'abosulate accuracy': 0.0014000000664964318, 'consecutive overlap rate': 0.07077500070445239, 'overlap rate': 0.5776375599205494}
#
# Current epoch: 80,
# training performance: {'loss': 0.8021611914038658, 'abosulate accuracy': 0.042100001918151976, 'consecutive overlap rate': 0.15357000194489956, 'overlap rate': 0.7481200769543648}
# evaluation performance: {'loss': 1.8902395695447922, 'abosulate accuracy': 0.0007500000356230885, 'consecutive overlap rate': 0.06919666714966297, 'overlap rate': 0.5749000616371631}
#
# Current epoch: 85,
# training performance: {'loss': 0.749464850127697, 'abosulate accuracy': 0.053500002808868886, 'consecutive overlap rate': 0.1740483358502388, 'overlap rate': 0.7645184084773063}
# evaluation performance: {'loss': 1.9910633265972137, 'abosulate accuracy': 0.0010000000474974513, 'consecutive overlap rate': 0.06842250092886389, 'overlap rate': 0.5740067265927792}
#
# Current epoch: 90,
# training performance: {'loss': 0.7166190028190613, 'abosulate accuracy': 0.05430000266060233, 'consecutive overlap rate': 0.17625483274459838, 'overlap rate': 0.7741302207112313}
# evaluation performance: {'loss': 2.0924704909324645, 'abosulate accuracy': 0.000800000037997961, 'consecutive overlap rate': 0.06810833406634628, 'overlap rate': 0.5733033947646617}
#
# Current epoch: 95,
# training performance: {'loss': 0.6956581905484199, 'abosulate accuracy': 0.051700002234429124, 'consecutive overlap rate': 0.17055333517491816, 'overlap rate': 0.7801550701260567}
# evaluation performance: {'loss': 2.1545908346772196, 'abosulate accuracy': 0.0010000000474974513, 'consecutive overlap rate': 0.06678166738711297, 'overlap rate': 0.5721642307937145}

# %% [markdown]
# ## Hyperparameter set 4

# %%
hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9026744425296784, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006566666819708189, 'overlap rate': 0.43093337342143057}
# evaluation performance: {'loss': 1.9013691633939742, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006675000153336441, 'overlap rate': 0.43060754165053367}
#
# Current epoch: 10,
# training performance: {'loss': 1.8968867063522339, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007166666764533147, 'overlap rate': 0.43261504620313646}
# evaluation performance: {'loss': 1.8985399201512336, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006959039688808844, 'overlap rate': 0.43096624240279197}
#
# Current epoch: 15,
# training performance: {'loss': 1.895988357067108, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007033333458821289, 'overlap rate': 0.4333900444209576}
# evaluation performance: {'loss': 1.8980976849794389, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000705000020479929, 'overlap rate': 0.4312650434672832}
#
# Current epoch: 20,
# training performance: {'loss': 1.9041444450616836, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000661920918355463, 'overlap rate': 0.4314955502748489}
# evaluation performance: {'loss': 1.9018737733364106, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006625000158237526, 'overlap rate': 0.43074837774038316}
#
# Current epoch: 25,
# training performance: {'loss': 1.8963696986436844, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006850000143458601, 'overlap rate': 0.43318004831671714}
# evaluation performance: {'loss': 1.8979949370026588, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006758333486686751, 'overlap rate': 0.4311483770608902}
#
# Current epoch: 30,
# training performance: {'loss': 1.8970808863639832, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007050000167510007, 'overlap rate': 0.43299504593014715}
# evaluation performance: {'loss': 1.8989304810762406, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006950000180950156, 'overlap rate': 0.43118754476308824}
#
# Current epoch: 35,
# training performance: {'loss': 1.895742166042328, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007166666793636978, 'overlap rate': 0.43357671052217484}
# evaluation performance: {'loss': 1.8979559004306794, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008416666816629004, 'overlap rate': 0.431531710550189}
#
# Current epoch: 40,
# training performance: {'loss': 1.8891670525074005, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012973164004506544, 'overlap rate': 0.4410265125334263}
# evaluation performance: {'loss': 1.8914201945066451, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012900000241643284, 'overlap rate': 0.4391867104917765}
#
# Current epoch: 45,
# training performance: {'loss': 1.844335201382637, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002026666692108847, 'overlap rate': 0.45373504385352137}
# evaluation performance: {'loss': 1.8756121844053268, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020183333690511063, 'overlap rate': 0.44365587942302226}
#
# Current epoch: 50,
# training performance: {'loss': 1.779556792974472, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0034083333623129873, 'overlap rate': 0.4738133825361729}
# evaluation performance: {'loss': 1.8611758932471276, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003610000043408945, 'overlap rate': 0.44749504663050177}
#
# Current epoch: 55,
# training performance: {'loss': 1.6715483665466309, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004553333373041824, 'overlap rate': 0.5035533927381038}
# evaluation performance: {'loss': 1.8639487966895103, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004715833402588032, 'overlap rate': 0.44825004898011683}
#
# Current epoch: 60,
# training performance: {'loss': 1.6075032979249955, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006411666760686785, 'overlap rate': 0.5174467138946056}
# evaluation performance: {'loss': 1.800670510530472, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00666916673653759, 'overlap rate': 0.4651692111045122}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     151         epoch += 1
#     152
# --> 153         train_perf = train_loop(model, train_dl, optimizer,
#     154                                 criterion, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_loop(model, dataloader, optimizer, criterion, teacher_forcing_ratio)
#      58                  "overlap rate": 0.0}
#      59
# ---> 60     for X, Y in dataloader:
#      61         seq_len, batch_size = Y.shape
#      62         seq_len -= 1 # logits does not have <s>
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /drive/My Drive/RNNSeq2Seq/scripts/dataloader.py in __getitem__(self, index)
#      31     def __getitem__(self, index):
#      32         in_seq, out_seq = self.data[index]
# ---> 33         x = [self.iv2idx.get(
#      34             i_s, len(self.iv2idx)) for i_s in in_seq]
#      35         y = [self.ov2idx.get(
#
# /drive/My Drive/RNNSeq2Seq/scripts/dataloader.py in <listcomp>(.0)
#      31     def __getitem__(self, index):
#      32         in_seq, out_seq = self.data[index]
# ---> 33         x = [self.iv2idx.get(
#      34             i_s, len(self.iv2idx)) for i_s in in_seq]
#      35         y = [self.ov2idx.get(
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 5

# %%
hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-2
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9961162239313126, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006666666813543998, 'overlap rate': 0.41714170947670937}
# evaluation performance: {'loss': 5.211909478902816, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006591666799067753, 'overlap rate': 0.037454170919954774}
#
# Current epoch: 10,
# training performance: {'loss': 2.6407080829143523, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007266666754730978, 'overlap rate': 0.4171900376677513}
# evaluation performance: {'loss': 5.435972255468369, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006458333497903368, 'overlap rate': 0.030111670424230397}
#
# Current epoch: 15,
# training performance: {'loss': 1.9742255955934525, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007033333509752993, 'overlap rate': 0.42179338037967684}
# evaluation performance: {'loss': 4.1781165361404415, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006483333472715458, 'overlap rate': 0.24905669298022987}
#
# Current epoch: 20,
# training performance: {'loss': 1.966076523065567, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007635875859705266, 'overlap rate': 0.42374975979328156}
# evaluation performance: {'loss': 3.3224799394607545, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006350000137899769, 'overlap rate': 0.14631501566618682}
#
# Current epoch: 25,
# training performance: {'loss': 1.9574639230966568, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007800000166753307, 'overlap rate': 0.42590004578232765}
# evaluation performance: {'loss': 3.1332602351903915, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006708333484311879, 'overlap rate': 0.24665419124066829}
#
# Current epoch: 30,
# training performance: {'loss': 1.9604328334331513, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008333333498740103, 'overlap rate': 0.4258417122066021}
# evaluation performance: {'loss': 3.0703107088804247, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006858333472337108, 'overlap rate': 0.2732108587399125}
#
# Current epoch: 35,
# training performance: {'loss': 1.9506855010986328, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008366666843357962, 'overlap rate': 0.42847504541277887}
# evaluation performance: {'loss': 2.7867493331432343, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007608333518874133, 'overlap rate': 0.36258420124650004}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     151         epoch += 1
#     152
# --> 153         train_perf = train_loop(model, train_dl, optimizer,
#     154                                 criterion, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_loop(model, dataloader, optimizer, criterion, teacher_forcing_ratio)
#      76         aggr_perf["overlap rate"] += ovr
#      77
# ---> 78         loss.backward(); optimizer.step()
#      79
#      80     aggr_perf = {k:v/len(dataloader) for k,v in aggr_perf.items()}
#
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     171     # some Python versions print out the first line of a multi-line function
#     172     # calls in the traceback and some print out the last line
# --> 173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 6

# %%
hidden_size = 256
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9123721271753311, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006683333485852927, 'overlap rate': 0.4307867087423801}
# evaluation performance: {'loss': 1.9386005595326423, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007141666823372361, 'overlap rate': 0.4299425456672907}
#
# Current epoch: 10,
# training performance: {'loss': 1.8980722695589065, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006785028366721235, 'overlap rate': 0.431949283182621}
# evaluation performance: {'loss': 1.8983167365193367, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006958333482543821, 'overlap rate': 0.4309733796864748}
#
# Current epoch: 15,
# training performance: {'loss': 1.8961813658475877, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008066666865488515, 'overlap rate': 0.43309338092803956}
# evaluation performance: {'loss': 1.8975609421730042, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007633333483681781, 'overlap rate': 0.43185921274125577}
#
# Current epoch: 20,
# training performance: {'loss': 1.9001049190759658, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006916666818142403, 'overlap rate': 0.43184670731425284}
# evaluation performance: {'loss': 1.8990399271249772, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007108333502401365, 'overlap rate': 0.4307517118752003}
#
# Current epoch: 25,
# training performance: {'loss': 1.8961795300245285, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008866666816174984, 'overlap rate': 0.43330337554216386}
# evaluation performance: {'loss': 1.897249710559845, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009350000207632547, 'overlap rate': 0.4317175459116697}
#
# Current epoch: 30,
# training performance: {'loss': 1.8805091321468352, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012183333572465926, 'overlap rate': 0.44178337827324865}
# evaluation performance: {'loss': 1.8807687237858772, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001237500031857053, 'overlap rate': 0.44088504575192927}
#
# Current epoch: 35,
# training performance: {'loss': 1.8397547006607056, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0022550000256160276, 'overlap rate': 0.45618838593363764}
# evaluation performance: {'loss': 1.8728371128439902, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002195833355654031, 'overlap rate': 0.4420375432819128}
#
# Current epoch: 40,
# training performance: {'loss': 1.77257359623909, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0035000000381842254, 'overlap rate': 0.47553505152463915}
# evaluation performance: {'loss': 1.8629193887114526, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0034916667093057184, 'overlap rate': 0.4459267143160105}
#
# Current epoch: 45,
# training performance: {'loss': 1.69398173391819, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004966666776454076, 'overlap rate': 0.4963100515305996}
# evaluation performance: {'loss': 1.8613834843039512, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004891666720504872, 'overlap rate': 0.44634170904755593}
#
# Current epoch: 50,
# training performance: {'loss': 1.6079212099313736, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006970000092405826, 'overlap rate': 0.5188200533390045}
# evaluation performance: {'loss': 1.8621622517704963, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006941666750935838, 'overlap rate': 0.4482075393199921}
#
# Current epoch: 55,
# training performance: {'loss': 1.5276516765356063, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008825000049546361, 'overlap rate': 0.5390000678598881}
# evaluation performance: {'loss': 1.8740102991461753, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008525833411840721, 'overlap rate': 0.44971337392926214}
#
# Current epoch: 60,
# training performance: {'loss': 1.4600312560796738, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010696666780859232, 'overlap rate': 0.5573283970355988}
# evaluation performance: {'loss': 1.8883340790867806, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010540621605468915, 'overlap rate': 0.4525278422981501}
#
# Current epoch: 65,
# training performance: {'loss': 1.379678174853325, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012686666892841458, 'overlap rate': 0.5786700665950775}
# evaluation performance: {'loss': 1.9155805587768555, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.012605748744681478, 'overlap rate': 0.45466054007411005}
#
# Current epoch: 70,
# training performance: {'loss': 1.3273697465658187, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.014293333515524864, 'overlap rate': 0.5926267251372337}
# evaluation performance: {'loss': 1.9400827974081039, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.01436916678212583, 'overlap rate': 0.45822171308100224}
#
# Current epoch: 75,
# training performance: {'loss': 1.2758728235960006, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.01696166698820889, 'overlap rate': 0.6068850591778755}
# evaluation performance: {'loss': 1.958720824122429, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.01616833349689841, 'overlap rate': 0.46038921512663367}
#
# Current epoch: 80,
# training performance: {'loss': 1.2287232726812363, 'abosulate accuracy': 0.000800000037997961, 'consecutive overlap rate': 0.020438333484344186, 'overlap rate': 0.6207400649785996}
# evaluation performance: {'loss': 1.9928527846932411, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.018442500208038837, 'overlap rate': 0.4627033781260252}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#     156
# --> 157         eval_perf = evaluate(model, eval_dl, criterion)
#     158         eval_acc = eval_perf['abosulate accuracy']
#     159
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in evaluate(model, dataloader, criterion, per_seq_len_performance)
#     106             X = X.to(model.device)
#     107             Y = Y.to(model.device)
# --> 108             logits, _ = model(X, Y,
#     109                               teacher_forcing_ratio=0.0)
#     110
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /drive/My Drive/RNNSeq2Seq/scripts/model.py in forward(self, X, Y, teacher_forcing_ratio)
#     183         for t in range(1, Y.shape[0]):
#     184             output, hidden, cell, attn_w = \
# --> 185             self.decoder(y, hidden, cell, encoder_outputs)
#     186
#     187             outputs.append(output); attn_weights.append(attn_w)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /drive/My Drive/RNNSeq2Seq/scripts/model.py in forward(self, y, hidden, cell, encoder_outputs)
#     133
#     134         # embd: (num layers, batch size, embd dim)
# --> 135         embd = self.dropout(self.embedding(y))
#     136
#     137         if self.use_attention and self.attention:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     156
#     157     def forward(self, input: Tensor) -> Tensor:
# --> 158         return F.embedding(
#     159             input, self.weight, self.padding_idx, self.max_norm,
#     160             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2197         # remove once script supports set_grad_enabled
#    2198         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2199     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2200
#    2201
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 7

# %%
hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.908746635913849, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006683333464025054, 'overlap rate': 0.4306583806872368}
# evaluation performance: {'loss': 1.8993145197629928, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006491666790680028, 'overlap rate': 0.43054004311561583}
#
# Current epoch: 10,
# training performance: {'loss': 1.8965239077806473, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006900000131281559, 'overlap rate': 0.43254504203796384}
# evaluation performance: {'loss': 1.8978860899806023, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006600000142498175, 'overlap rate': 0.4311258740723133}
#
# Current epoch: 15,
# training performance: {'loss': 1.8960694134235383, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006316666782367975, 'overlap rate': 0.43304004669189455}
# evaluation performance: {'loss': 1.8986768454313279, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007333333498536377, 'overlap rate': 0.4312108766287565}
#
# Current epoch: 20,
# training performance: {'loss': 1.897960603237152, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006819209185778164, 'overlap rate': 0.4322310619056225}
# evaluation performance: {'loss': 1.8981594249606133, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006491666823421838, 'overlap rate': 0.43111254535615445}
#
# Current epoch: 25,
# training performance: {'loss': 1.8958585441112519, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006950000126380474, 'overlap rate': 0.433453381806612}
# evaluation performance: {'loss': 1.8981864348053932, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007208333467133343, 'overlap rate': 0.43128504529595374}
#
# Current epoch: 30,
# training performance: {'loss': 1.8541298687458039, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016366666881367565, 'overlap rate': 0.4477717153728008}
# evaluation performance: {'loss': 1.8906115099787713, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015425000230607111, 'overlap rate': 0.43668004386126996}
#
# Current epoch: 35,
# training performance: {'loss': 1.801780131459236, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029966667119879276, 'overlap rate': 0.46901671066880224}
# evaluation performance: {'loss': 1.8437807872891425, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002969166709226556, 'overlap rate': 0.4521250486373901}
#
# Current epoch: 40,
# training performance: {'loss': 1.7027117997407912, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004761666723061353, 'overlap rate': 0.4902350537478924}
# evaluation performance: {'loss': 1.7861407294869422, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005006666708504781, 'overlap rate': 0.46497421376407144}
#
# Current epoch: 45,
# training performance: {'loss': 1.6092108517885209, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007905000098980963, 'overlap rate': 0.5128100559115409}
# evaluation performance: {'loss': 1.7170627161860466, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008570833381963894, 'overlap rate': 0.4800308827310801}
#
# Current epoch: 50,
# training performance: {'loss': 1.5173727452754975, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013565000193193556, 'overlap rate': 0.5348050564527511}
# evaluation performance: {'loss': 1.6643561229109765, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014837500150315463, 'overlap rate': 0.4951592184603214}
#
# Current epoch: 55,
# training performance: {'loss': 1.4119529962539672, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020285000232979654, 'overlap rate': 0.5670933917164802}
# evaluation performance: {'loss': 1.6824792057275773, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# evaluation performance: {'loss': 1.6093159586191177, 'abosulate accuracy': 0.02830000122776255, 'consecutive overlap rate': 0.11849333494901657, 'overlap rate': 0.6103067241609097}
#
# Current epoch: 105,
# training performance: {'loss': 0.7039985939860344, 'abosulate accuracy': 0.07470000376924872, 'consecutive overlap rate': 0.17931500375270842, 'overlap rate': 0.771720078587532}
# evaluation performance: {'loss': 1.617361019551754, 'abosulate accuracy': 0.03335000152001157, 'consecutive overlap rate': 0.127907501347363, 'overlap rate': 0.6153659000992775}
#
# Current epoch: 110,
# training performance: {'loss': 0.670550586283207, 'abosulate accuracy': 0.08650000412017107, 'consecutive overlap rate': 0.19641833528876304, 'overlap rate': 0.7820367410778999}
# evaluation performance: {'loss': 1.6171394541859627, 'abosulate accuracy': 0.03510000163223594, 'consecutive overlap rate': 0.13332000132650138, 'overlap rate': 0.6189642287790775}
#
# Current epoch: 115,
# training performance: {'loss': 0.6500280901789666, 'abosulate accuracy': 0.09660000344738365, 'consecutive overlap rate': 0.2070783358067274, 'overlap rate': 0.7877450808882713}
# evaluation performance: {'loss': 1.6451255351305007, 'abosulate accuracy': 0.03800000186311081, 'consecutive overlap rate': 0.1393533348105848, 'overlap rate': 0.6222025603055954}
#
# Current epoch: 120,
# training performance: {'loss': 0.6224240064620972, 'abosulate accuracy': 0.11230000387877226, 'consecutive overlap rate': 0.22670333571732043, 'overlap rate': 0.7958067417144775}
# evaluation performance: {'loss': 1.673292163014412, 'abosulate accuracy': 0.04050000186543912, 'consecutive overlap rate': 0.1431433348916471, 'overlap rate': 0.6246200554072857}
#
# Current epoch: 125,
# training performance: {'loss': 0.598382256925106, 'abosulate accuracy': 0.12360000461339951, 'consecutive overlap rate': 0.24021500311791896, 'overlap rate': 0.8029984071850776}
# evaluation performance: {'loss': 1.7041420504450797, 'abosulate accuracy': 0.04315000181086361, 'consecutive overlap rate': 0.14787783967331053, 'overlap rate': 0.6267801016569138}
#
# Current epoch: 130,
# training performance: {'loss': 0.5756843730807304, 'abosulate accuracy': 0.13610000535845757, 'consecutive overlap rate': 0.25595500506460667, 'overlap rate': 0.8105517387390136}
# evaluation performance: {'loss': 1.7325245797634126, 'abosulate accuracy': 0.04410000201314688, 'consecutive overlap rate': 0.15116274142637848, 'overlap rate': 0.6288180455565453}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#     156
# --> 157         eval_perf = evaluate(model, eval_dl, criterion)
#     158         eval_acc = eval_perf['abosulate accuracy']
#     159
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in evaluate(model, dataloader, criterion, per_seq_len_performance)
#     110
#     111             Ypred = logits.view(seq_len, batch_size, -1).argmax(2)
# --> 112             accu, covr, ovr = metrics(Y[1:-1], Ypred[:-1])
#     113             loss = criterion(logits, Y[1:].view(-1))
#     114
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in metrics(Y, Ypred)
#      41     else:
#      42         for col_idx, min_idx in enumerate(pw_cmp.argmin(0)):
# ---> 43             if pw_cmp[min_idx, col_idx] == 0:
#      44                 pw_cmp[min_idx:, col_idx] = 0
#      45
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 8

# %%
hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.96162751019001, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006416666787117719, 'overlap rate': 0.4197617068886757}
# evaluation performance: {'loss': 3.280040580034256, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006808333448134363, 'overlap rate': 0.22388252150267363}
#
# Current epoch: 10,
# training performance: {'loss': 1.941453191637993, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006050000127288512, 'overlap rate': 0.4278133764863014}
# evaluation performance: {'loss': 2.541892331838608, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006650000155786984, 'overlap rate': 0.4284667085856199}
#
# Current epoch: 15,
# training performance: {'loss': 1.8987116992473603, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007016666779236403, 'overlap rate': 0.43186170905828475}
# evaluation performance: {'loss': 1.9000818610191346, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006791666823119158, 'overlap rate': 0.43059754334390166}
#
# Current epoch: 20,
# training performance: {'loss': 2.0846840858459474, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006583333495655097, 'overlap rate': 0.4106283761560917}
# evaluation performance: {'loss': 2.2930549710988997, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006975000147576793, 'overlap rate': 0.3587008662521839}
#
# Current epoch: 25,
# training performance: {'loss': 1.9046701610088348, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006850000121630728, 'overlap rate': 0.4316700428724289}
# evaluation performance: {'loss': 1.900126013159752, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007100000148057006, 'overlap rate': 0.4315958768129349}
#
# Current epoch: 30,
# training performance: {'loss': 1.8933073043823243, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007200000174634625, 'overlap rate': 0.434646712988615}
# evaluation performance: {'loss': 1.8936169788241386, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006983333500102162, 'overlap rate': 0.4340333789587021}
#
# Current epoch: 35,
# training performance: {'loss': 1.8701053440570832, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001510480247088708, 'overlap rate': 0.44337272718548776}
# evaluation performance: {'loss': 1.8717660799622535, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016225000261329114, 'overlap rate': 0.4410742111504078}
#
# Current epoch: 40,
# training performance: {'loss': 1.8043338179588317, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004310000024270266, 'overlap rate': 0.46078171730041506}
# evaluation performance: {'loss': 1.8382444351911544, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00493750004679896, 'overlap rate': 0.44988754838705064}
#
# Current epoch: 45,
# training performance: {'loss': 1.7040300101041794, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010011666733771563, 'overlap rate': 0.48708505034446714}
# evaluation performance: {'loss': 1.7965548247098924, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.009883333439938724, 'overlap rate': 0.4634925462305546}
#
# Current epoch: 50,
# training performance: {'loss': 1.5777427524328231, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014685000129975378, 'overlap rate': 0.5207400567829609}
# evaluation performance: {'loss': 1.7662379130721093, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014974166871979833, 'overlap rate': 0.47512255050241947}
#
# Current epoch: 55,
# training performance: {'loss': 1.4146158277988434, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02183333346620202, 'overlap rate': 0.5665017247200013}
# evaluation performance: {'loss': 1.7250660374760627, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.021456666849553586, 'overlap rate': 0.4900133848190308}
#
# Current epoch: 60,
# training performance: {'loss': 1.2673784375190735, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
#
# Current epoch: 105,
# training performance: {'loss': 0.6880593448877335, 'abosulate accuracy': 0.13380000554025173, 'consecutive overlap rate': 0.26252167001366616, 'overlap rate': 0.7828500673174859}
# evaluation performance: {'loss': 1.9242002978920936, 'abosulate accuracy': 0.061650002980604766, 'consecutive overlap rate': 0.15116922548040748, 'overlap rate': 0.5938406623899937}
#
# Current epoch: 110,
# training performance: {'loss': 0.6601315096020699, 'abosulate accuracy': 0.1511000070720911, 'consecutive overlap rate': 0.2836050037294626, 'overlap rate': 0.791010069847107}
# evaluation performance: {'loss': 2.0071128606796265, 'abosulate accuracy': 0.0541500024497509, 'consecutive overlap rate': 0.14181186612695457, 'overlap rate': 0.590918393433094}
#
# Current epoch: 115,
# training performance: {'loss': 0.6312382817268372, 'abosulate accuracy': 0.16890000831335783, 'consecutive overlap rate': 0.31029833778738974, 'overlap rate': 0.8004533961415291}
# evaluation performance: {'loss': 2.0285292834043505, 'abosulate accuracy': 0.07205000380054116, 'consecutive overlap rate': 0.16541666872799396, 'overlap rate': 0.5991092249751091}
#
# Current epoch: 120,
# training performance: {'loss': 0.6088667325675488, 'abosulate accuracy': 0.1816000085324049, 'consecutive overlap rate': 0.32671166844666005, 'overlap rate': 0.8068634122610092}
# evaluation performance: {'loss': 2.058721494674683, 'abosulate accuracy': 0.0736000039614737, 'consecutive overlap rate': 0.1678841684013605, 'overlap rate': 0.6025967255234719}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     151         epoch += 1
#     152
# --> 153         train_perf = train_loop(model, train_dl, optimizer,
#     154                                 criterion, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_loop(model, dataloader, optimizer, criterion, teacher_forcing_ratio)
#      58                  "overlap rate": 0.0}
#      59
# ---> 60     for X, Y in dataloader:
#      61         seq_len, batch_size = Y.shape
#      62         seq_len -= 1 # logits does not have <s>
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
# ---> 52         return self.collate_fn(data)
#
# /drive/My Drive/RNNSeq2Seq/scripts/dataloader.py in collate_fn(batch, max_seq_len)
#      57     for idx, (x, y) in enumerate(batch):
#      58         inputs[:len(x), idx] = torch.Tensor(x).long()
# ---> 59         outputs[:len(y), idx] = torch.Tensor(y).long()
#      60
#      61     return inputs, outputs
#
# KeyboardInterrupt:

# %% [markdown]
# # RedStr

# %%
train = read_data(join(folder, "RedStr/train.txt"))
dev = read_data(join(folder, "RedStr/dev.txt"))
saved_model_fp = join(project_dir, "notebooks/Hyperparatemers Tuning/RevStr_model.pt")

train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)

# %% [markdown]
# ## Hyperparameter set 1

# %%
hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.2221718728542328, 'abosulate accuracy': 0.0019000000902451575, 'consecutive overlap rate': 0.0665450006723404, 'overlap rate': 0.6225267291069031}
# evaluation performance: {'loss': 1.4914841458201409, 'abosulate accuracy': 0.003200000140350312, 'consecutive overlap rate': 0.07476583467796445, 'overlap rate': 0.5522575534880161}
#
# Current epoch: 10,
# training performance: {'loss': 0.6765504240989685, 'abosulate accuracy': 0.0831000043079257, 'consecutive overlap rate': 0.2025883361697197, 'overlap rate': 0.7745067432522774}
# evaluation performance: {'loss': 1.268258836865425, 'abosulate accuracy': 0.07190000372938812, 'consecutive overlap rate': 0.18455083575099707, 'overlap rate': 0.6531759008765221}
#
# Current epoch: 15,
# training performance: {'loss': 0.44640626609325407, 'abosulate accuracy': 0.19590000957250595, 'consecutive overlap rate': 0.3198866702616215, 'overlap rate': 0.8430600747466087}
# evaluation performance: {'loss': 1.2108197957277298, 'abosulate accuracy': 0.13470000438392163, 'consecutive overlap rate': 0.2511575009673834, 'overlap rate': 0.702493391185999}
#
# Current epoch: 20,
# training performance: {'loss': 0.3036181591451168, 'abosulate accuracy': 0.290700014680624, 'consecutive overlap rate': 0.41763167157769204, 'overlap rate': 0.8907267406582833}
# evaluation performance: {'loss': 1.2686732098460198, 'abosulate accuracy': 0.17250000787898898, 'consecutive overlap rate': 0.289683336392045, 'overlap rate': 0.7254308991134166}
#
# Current epoch: 25,
# training performance: {'loss': 0.22080033421516418, 'abosulate accuracy': 0.3581000156700611, 'consecutive overlap rate': 0.48969000577926636, 'overlap rate': 0.9206017389893532}
# evaluation performance: {'loss': 1.4011209979653358, 'abosulate accuracy': 0.18795000854879618, 'consecutive overlap rate': 0.3052833367139101, 'overlap rate': 0.7318909011781216}
#
# Current epoch: 30,
# training performance: {'loss': 0.16856013797223568, 'abosulate accuracy': 0.38810001537203787, 'consecutive overlap rate': 0.5315149992704391, 'overlap rate': 0.9395850777626038}
# evaluation performance: {'loss': 1.54709852039814, 'abosulate accuracy': 0.19070000955834984, 'consecutive overlap rate': 0.3048402855172753, 'overlap rate': 0.7334254734218121}
#
# Current epoch: 35,
# training performance: {'loss': 0.12618378400802613, 'abosulate accuracy': 0.43270001783967016, 'consecutive overlap rate': 0.5889733389019967, 'overlap rate': 0.9564917430281639}
# evaluation performance: {'loss': 1.720757532119751, 'abosulate accuracy': 0.18925000801682473, 'consecutive overlap rate': 0.3026425026357174, 'overlap rate': 0.7309717379510403}
#
# Current epoch: 40,
# training performance: {'loss': 0.0878123166039586, 'abosulate accuracy': 0.4860000215470791, 'consecutive overlap rate': 0.6533316746354103, 'overlap rate': 0.9715067282319069}
# evaluation performance: {'loss': 1.9311962559819222, 'abosulate accuracy': 0.18260000804439186, 'consecutive overlap rate': 0.3003225041553378, 'overlap rate': 0.7306459002196789}
 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.1656624376773834, 'abosulate accuracy': 0.18455000780522823, 'consecutive overlap rate': 0.2984100043773651, 'overlap rate': 0.7246000610291958}
#
# Current epoch: 95,
# training performance: {'loss': 0.000551455681124935, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.2365526080131533, 'abosulate accuracy': 0.1842000089585781, 'consecutive overlap rate': 0.2980191703885794, 'overlap rate': 0.7239083983004093}
#
# Current epoch: 100,
# training performance: {'loss': 0.0004569993725453969, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.3012485414743424, 'abosulate accuracy': 0.1834000077098608, 'consecutive overlap rate': 0.29738583583384753, 'overlap rate': 0.7234275639057159}
#
# Current epoch: 105,
# training performance: {'loss': 0.00038928241483517925, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.360186058282852, 'abosulate accuracy': 0.18265000805258752, 'consecutive overlap rate': 0.29691833816468716, 'overlap rate': 0.7231425642967224}
#
# Current epoch: 110,
# training performance: {'loss': 0.00033459099649917333, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.4120419323444366, 'abosulate accuracy': 0.18230000799521803, 'consecutive overlap rate': 0.2966191701591015, 'overlap rate': 0.7227017380297184}
#
# Current epoch: 115,
# training performance: {'loss': 0.0002896628298913129, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.4678290337324142, 'abosulate accuracy': 0.18070000782608986, 'consecutive overlap rate': 0.29526083655655383, 'overlap rate': 0.722350899130106}
#
# Current epoch: 120,
# training performance: {'loss': 0.0002561806351877749, 'abosulate accuracy': 0.9999000012874604, 'consecutive overlap rate': 0.9999783337116241, 'overlap rate': 0.9999983355402946}
# evaluation performance: {'loss': 3.5163421452045442, 'abosulate accuracy': 0.18105000872164964, 'consecutive overlap rate': 0.2953466702252626, 'overlap rate': 0.7221300594508648}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     151         epoch += 1
#     152
# --> 153         train_perf = train_loop(model, train_dl, optimizer,
#     154                                 criterion, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_loop(model, dataloader, optimizer, criterion, teacher_forcing_ratio)
#      76         aggr_perf["overlap rate"] += ovr
#      77
# ---> 78         loss.backward(); optimizer.step()
#      79
#      80     aggr_perf = {k:v/len(dataloader) for k,v in aggr_perf.items()}
#
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     171     # some Python versions print out the first line of a multi-line function
#     172     # calls in the traceback and some print out the last line
# --> 173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 2

# %%
hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.608892983198166, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007940000121016056, 'overlap rate': 0.512643388658762}
# evaluation performance: {'loss': 1.6680292353034019, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# evaluation performance: {'loss': 2.2648010298609735, 'abosulate accuracy': 0.2770500125363469, 'consecutive overlap rate': 0.3724275030195713, 'overlap rate': 0.7021675527095794}
#
# Current epoch: 140,
# training performance: {'loss': 0.11925672981888055, 'abosulate accuracy': 0.4796000212430954, 'consecutive overlap rate': 0.6092050075531006, 'overlap rate': 0.9571800783276558}
# evaluation performance: {'loss': 2.27552325129509, 'abosulate accuracy': 0.27025001123547554, 'consecutive overlap rate': 0.3684428997337818, 'overlap rate': 0.7044384710490703}
#
# Current epoch: 145,
# training performance: {'loss': 0.11408754773437976, 'abosulate accuracy': 0.48960001915693285, 'consecutive overlap rate': 0.6197150066494942, 'overlap rate': 0.9589934021234512}
# evaluation performance: {'loss': 2.3303976535797117, 'abosulate accuracy': 0.27150001358240844, 'consecutive overlap rate': 0.36948131769895554, 'overlap rate': 0.7051358081400394}
#
# Current epoch: 150,
# training performance: {'loss': 0.11611134577542544, 'abosulate accuracy': 0.4809000208973885, 'consecutive overlap rate': 0.607898335158825, 'overlap rate': 0.9578600704669953}
# evaluation performance: {'loss': 2.3647225379943846, 'abosulate accuracy': 0.27345001250505446, 'consecutive overlap rate': 0.3685091700404882, 'overlap rate': 0.7031175546348095}

# %% [markdown]
# ## Hyperparameter set 3

# %%
hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.632438600063324, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006960000086110085, 'overlap rate': 0.5064483851194381}
# evaluation performance: {'loss': 1.6582319915294648, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007836666773073375, 'overlap rate': 0.49147755093872547}
#
# Current epoch: 10,
# training performance: {'loss': 1.1512112230062486, 'abosulate accuracy': 0.002300000109244138, 'consecutive overlap rate': 0.0329650002066046, 'overlap rate': 0.6424467265605927}
# evaluation performance: {'loss': 1.5906814634799957, 'abosulate accuracy': 0.00520000018295832, 'consecutive overlap rate': 0.03942750052083284, 'overlap rate': 0.5298267185688019}
#
# Current epoch: 15,
# training performance: {'loss': 0.8675558537244796, 'abosulate accuracy': 0.04420000184327364, 'consecutive overlap rate': 0.10043000150471926, 'overlap rate': 0.7210617393255234}
# evaluation performance: {'loss': 1.5656942322850227, 'abosulate accuracy': 0.04040000191889703, 'consecutive overlap rate': 0.09497666768729687, 'overlap rate': 0.5745033912360669}
#
# Current epoch: 20,
# training performance: {'loss': 0.6955479681491852, 'abosulate accuracy': 0.10290000345557929, 'consecutive overlap rate': 0.17366333566606046, 'overlap rate': 0.7694067344069481}
# evaluation performance: {'loss': 1.5299565851688386, 'abosulate accuracy': 0.09595000357367098, 'consecutive overlap rate': 0.1663799741305411, 'overlap rate': 0.6092736676335335}
#
# Current epoch: 25,
#
# Current epoch: 70,
# training performance: {'loss': 0.19805700778961183, 'abosulate accuracy': 0.42620002031326293, 'consecutive overlap rate': 0.5376200072467328, 'overlap rate': 0.9275817349553108}
# evaluation performance: {'loss': 1.8252532094717027, 'abosulate accuracy': 0.2631500132381916, 'consecutive overlap rate': 0.3608941715210676, 'overlap rate': 0.7017042264342308}
#
# Current epoch: 75,
# training performance: {'loss': 0.18379791118204594, 'abosulate accuracy': 0.4368000216782093, 'consecutive overlap rate': 0.5509566709399223, 'overlap rate': 0.9328867420554161}
# evaluation performance: {'loss': 1.8718147158622742, 'abosulate accuracy': 0.27500001173466443, 'consecutive overlap rate': 0.37163360565900805, 'overlap rate': 0.7045499883592129}
#
# Current epoch: 80,
# training performance: {'loss': 0.17263953760266304, 'abosulate accuracy': 0.44190001860260963, 'consecutive overlap rate': 0.5619866773486137, 'overlap rate': 0.936801740527153}
# evaluation performance: {'loss': 1.9121564358472825, 'abosulate accuracy': 0.2798500131815672, 'consecutive overlap rate': 0.3755861632525921, 'overlap rate': 0.7055185437202454}
#
# Current epoch: 85,
# training performance: {'loss': 0.15924291238188742, 'abosulate accuracy': 0.45270001962780954, 'consecutive overlap rate': 0.5741900078952312, 'overlap rate': 0.9419250801205635}
# evaluation performance: {'loss': 1.9486774295568465, 'abosulate accuracy': 0.28220001347362994, 'consecutive overlap rate': 0.3795762337744236, 'overlap rate': 0.7090518370270729}
#
# Current epoch: 90,
# training performance: {'loss': 0.1442140370607376, 'abosulate accuracy': 0.467700020223856, 'consecutive overlap rate': 0.5953233376145363, 'overlap rate': 0.9476484030485153}
# evaluation performance: {'loss': 1.9988212451338767, 'abosulate accuracy': 0.28570001404732465, 'consecutive overlap rate': 0.38298583664000035, 'overlap rate': 0.709920059144497}
#
# Current epoch: 95,
# training performance: {'loss': 0.13510578721761704, 'abosulate accuracy': 0.4723000206053257, 'consecutive overlap rate': 0.6041316732764244, 'overlap rate': 0.9512334063649177}
# evaluation performance: {'loss': 2.098905098438263, 'abosulate accuracy': 0.27970001231878994, 'consecutive overlap rate': 0.3773725055158138, 'overlap rate': 0.7043742224574089}
#
# Current epoch: 100,
# training performance: {'loss': 0.13023539185523986, 'abosulate accuracy': 0.476200021058321, 'consecutive overlap rate': 0.6093783408403397, 'overlap rate': 0.9531234040856361}
# evaluation performance: {'loss': 2.0976847007870676, 'abosulate accuracy': 0.28885001242160796, 'consecutive overlap rate': 0.38605583757162093, 'overlap rate': 0.7097542203962803}
#
# Current epoch: 105,
# training performance: {'loss': 0.12654518857598304, 'abosulate accuracy': 0.4788000211119652, 'consecutive overlap rate': 0.6140600070357323, 'overlap rate': 0.9544117286801338}
# evaluation performance: {'loss': 2.162281523644924, 'abosulate accuracy': 0.2842000126838684, 'consecutive overlap rate': 0.3817393403500319, 'overlap rate': 0.7081198252737522}
#
# Current epoch: 110,
# training performance: {'loss': 0.11776398234069348, 'abosulate accuracy': 0.4862000234425068, 'consecutive overlap rate': 0.6256583392620086, 'overlap rate': 0.9576400816440582}
