# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Helper function to help visualize

# %%
def plot_log(log):
    len_range = len(log) -1 if "Best eval accu" in log else len(log)
    epoch_nums, train_loss, dev_loss = [], [], []
    train_acc, dev_acc = [], []

    for epoch in range(1, len_range+1):
        epoch_nums.append(epoch)
        train = log[f"Epoch#{epoch}"]["Train"]
        dev = log[f"Epoch#{epoch}"]["Eval"]
        train_loss.append(train['loss'])
        train_acc.append(train['abosulate accuracy'])

        dev_loss.append(dev['loss'])
        dev_acc.append(dev['abosulate accuracy'])

    ax1 = plt.subplot(211)
    ax1.plot(epoch_nums, train_loss, label="train loss")
    ax1.plot(epoch_nums, dev_loss, label="dev loss")
    ax1.legend()

    ax2 = plt.subplot(212)
    ax2.plot(epoch_nums, train_acc, label="train acc")
    ax2.plot(epoch_nums, dev_acc, label="dev acc")
    ax2.legend()
    plt.show()

# %%
folder = "tuning_data/"
experiment_num = 5
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250 
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 150 # max num of epoches 
train_acc_exit=0.92 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.92 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

# %% [markdown]
# # RevStr

# %%
train = read_data(join(folder, "RevStr/train.txt"))
dev = read_data(join(folder, "RevStr/dev.txt"))
saved_model_fp = join(project_dir, "notebooks/Hyperparatemers Tuning/RevStr_lstm_model.pt")

train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)

# %% [markdown]
# ## Hyperparameter set 1

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 256
embd_dim = 128
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = True
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 3.156470203399658, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010700952785555273, 'overlap rate': 0.08123138044029474}
# evaluation performance: {'loss': 3.124418765306473, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013804840645752848, 'overlap rate': 0.09062504991889}
#
# Current epoch: 10,
# training performance: {'loss': 2.5327584981918334, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.019364073278848083, 'overlap rate': 0.22426162362098695}
# evaluation performance: {'loss': 2.868162214756012, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.019482497801072897, 'overlap rate': 0.12558982335031033}
#
# Current epoch: 15,
# training performance: {'loss': 2.0444620966911318, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03903427100740373, 'overlap rate': 0.3582210224121809}
# evaluation performance: {'loss': 2.768571138381958, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0372551650274545, 'overlap rate': 0.15017738472670317}
#
# Current epoch: 20,
# training performance: {'loss': 1.7646062150597572, 'abosulate accuracy': 0.0003000000026077032, 'consecutive overlap rate': 0.06027075662277639, 'overlap rate': 0.43545676693320273}
# evaluation performance: {'loss': 2.7981664538383484, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.059631668496876955, 'overlap rate': 0.18858497459441423}
#
# Current epoch: 25,
# training performance: {'loss': 1.5495408549904823, 'abosulate accuracy': 0.0032000001636333765, 'consecutive overlap rate': 0.08763965177349746, 'overlap rate': 0.5044859580695629}
# evaluation performance: {'loss': 2.705732759833336, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.0867302720900625, 'overlap rate': 0.2297724299132824}
#
# Current epoch: 30,
# training performance: {'loss': 1.43737071454525, 'abosulate accuracy': 0.004300000274088234, 'consecutive overlap rate': 0.10977811207994818, 'overlap rate': 0.5355637066066266}
# evaluation performance: {'loss': 2.728174951672554, 'abosulate accuracy': 0.005300000187708065, 'consecutive overlap rate': 0.10445176549255848, 'overlap rate': 0.2609554398804903}
#
# Current epoch: 35,
# training performance: {'loss': 1.2838705785572528, 'abosulate accuracy': 0.017700001038610934, 'consecutive overlap rate': 0.13961488483473658, 'overlap rate': 0.5848186999559403}
# evaluation performance: {'loss': 2.7139941424131395, 'abosulate accuracy': 0.012250000610947609, 'consecutive overlap rate': 0.12675410695374012, 'overlap rate': 0.29039595238864424}
#
# Current epoch: 40,
# training performance: {'loss': 1.2062496431171894, 'abosulate accuracy': 0.027400001266505568, 'consecutive overlap rate': 0.15929907048121095, 'overlap rate': 0.6078252777457237}
# evaluation performance: {'loss': 2.769619160890579, 'abosulate accuracy': 0.0031000001181382686, 'consecutive overlap rate': 0.14339589243754744, 'overlap rate': 0.296608879044652}
#
# Current epoch: 45,
# training performance: {'loss': 1.1410040020942689, 'abosulate accuracy': 0.03950000201584771, 'consecutive overlap rate': 0.17949731331318616, 'overlap rate': 0.6287921234965325}
# evaluation performance: {'loss': 2.7258961111307145, 'abosulate accuracy': 0.005000000091968104, 'consecutive overlap rate': 0.1577301912009716, 'overlap rate': 0.310660232976079}
#
# Current epoch: 50,
# training performance: {'loss': 1.105884225666523, 'abosulate accuracy': 0.04230000254465267, 'consecutive overlap rate': 0.1882193334400654, 'overlap rate': 0.6372133076190949}
# training performance: {'loss': 0.7851876474916935, 'abosulate accuracy': 0.08760000432375818, 'consecutive overlap rate': 0.26919673290103674, 'overlap rate': 0.7295247331261635}
# evaluation performance: {'loss': 2.9525195002555846, 'abosulate accuracy': 0.01615000090096146, 'consecutive overlap rate': 0.20114999813959003, 'overlap rate': 0.3642708957195282}
#
# Current epoch: 100,
# training performance: {'loss': 0.7593609809875488, 'abosulate accuracy': 0.10220000449335202, 'consecutive overlap rate': 0.28352428805083035, 'overlap rate': 0.7392171725630761}
# evaluation performance: {'loss': 2.829434986412525, 'abosulate accuracy': 0.02980000096722506, 'consecutive overlap rate': 0.23152288869023324, 'overlap rate': 0.3962023753672838}
#
# Current epoch: 105,
# training performance: {'loss': 0.7444577161222696, 'abosulate accuracy': 0.140600005001761, 'consecutive overlap rate': 0.30891771875321866, 'overlap rate': 0.7470894888043403}
# evaluation performance: {'loss': 2.856988067924976, 'abosulate accuracy': 0.03715000129886903, 'consecutive overlap rate': 0.22665167106315492, 'overlap rate': 0.3975985884666443}
#
# Current epoch: 110,
# training performance: {'loss': 0.7105051942169667, 'abosulate accuracy': 0.12670000604121015, 'consecutive overlap rate': 0.30587268304079773, 'overlap rate': 0.7549253910779953}
# evaluation performance: {'loss': 2.78861173838377, 'abosulate accuracy': 0.06010000325622968, 'consecutive overlap rate': 0.2578869519755244, 'overlap rate': 0.4175287865102291}
#
# Current epoch: 115,
# training performance: {'loss': 0.7392985256388783, 'abosulate accuracy': 0.1227000071434304, 'consecutive overlap rate': 0.30493421480059624, 'overlap rate': 0.7478127926588058}
# evaluation performance: {'loss': 2.835032510757446, 'abosulate accuracy': 0.040250002132961524, 'consecutive overlap rate': 0.24524539932608605, 'overlap rate': 0.4063233159482479}
#
# Current epoch: 120,
# training performance: {'loss': 0.6898506445810199, 'abosulate accuracy': 0.14370000913040712, 'consecutive overlap rate': 0.3179580820724368, 'overlap rate': 0.7613457545638085}
# evaluation performance: {'loss': 3.0187786340713503, 'abosulate accuracy': 0.03970000162371434, 'consecutive overlap rate': 0.22528406092897058, 'overlap rate': 0.3885911799967289}
#
# Current epoch: 125,
# training performance: {'loss': 0.6930311473086477, 'abosulate accuracy': 0.10010000272886828, 'consecutive overlap rate': 0.29241081438958644, 'overlap rate': 0.7567914485931396}
# evaluation performance: {'loss': 2.9338140442967413, 'abosulate accuracy': 0.040500000928295775, 'consecutive overlap rate': 0.24642747221514583, 'overlap rate': 0.4169463623315096}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#     156
# --> 157         eval_perf = evaluate(model, eval_dl, criterion)
#     158         eval_acc = eval_perf['abosulate accuracy']
#     159
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in evaluate(model, dataloader, criterion, per_seq_len_performance)
#     100
#     101     with torch.no_grad():
# --> 102         for X, Y in dataloader:
#     103             seq_len, batch_size = Y.shape
#     104             seq_len -= 1 # logits does not have <s>
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /drive/My Drive/RNNSeq2Seq/scripts/dataloader.py in __getitem__(self, index)
#      31     def __getitem__(self, index):
#      32         in_seq, out_seq = self.data[index]
# ---> 33         x = [self.iv2idx.get(
#      34             i_s, len(self.iv2idx)) for i_s in in_seq]
#      35         y = [self.ov2idx.get(
#
# /drive/My Drive/RNNSeq2Seq/scripts/dataloader.py in <listcomp>(.0)
#      32         in_seq, out_seq = self.data[index]
#      33         x = [self.iv2idx.get(
# ---> 34             i_s, len(self.iv2idx)) for i_s in in_seq]
#      35         y = [self.ov2idx.get(
#      36             o_s, len(self.ov2idx)) for o_s in out_seq]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 2

# %%
hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 3.0998071312904356, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015165035880636423, 'overlap rate': 0.09512267261743546}
# evaluation performance: {'loss': 3.0808730483055116, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015795153030194343, 'overlap rate': 0.0990808418020606}
#
# Current epoch: 10,
# training performance: {'loss': 2.4021985054016115, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025761540955863894, 'overlap rate': 0.25648026503622534}
# evaluation performance: {'loss': 2.7952981114387514, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025953369843773545, 'overlap rate': 0.13833190836012363}
#
# Current epoch: 15,
# training performance: {'loss': 1.7518838316202163, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.06396952425129712, 'overlap rate': 0.43575517311692236}
# evaluation performance: {'loss': 2.6352903217077257, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.061138207605108616, 'overlap rate': 0.20578935407102109}
#
# Current epoch: 20,
# evaluation performance: {'loss': 2.6912076473236084, 'abosulate accuracy': 0.05890000173822045, 'consecutive overlap rate': 0.2684562706388533, 'overlap rate': 0.46353155598044393}
#
# Current epoch: 110,
# training performance: {'loss': 0.554269321449101, 'abosulate accuracy': 0.18280000891536474, 'consecutive overlap rate': 0.3733945585787296, 'overlap rate': 0.8018482968211174}
# evaluation performance: {'loss': 2.721147730946541, 'abosulate accuracy': 0.07150000332039781, 'consecutive overlap rate': 0.27444712445139885, 'overlap rate': 0.4651621520519257}
#
# Current epoch: 115,
# training performance: {'loss': 0.5435605073347688, 'abosulate accuracy': 0.16520000693853945, 'consecutive overlap rate': 0.3601162726059556, 'overlap rate': 0.8042111724615097}
# evaluation performance: {'loss': 3.0248790219426156, 'abosulate accuracy': 0.033000001375330615, 'consecutive overlap rate': 0.2402480874210596, 'overlap rate': 0.41626766286790373}
#
# Current epoch: 120,
# training performance: {'loss': 0.4935243148356676, 'abosulate accuracy': 0.2048000077251345, 'consecutive overlap rate': 0.39643277525901793, 'overlap rate': 0.8218119621276856}
# evaluation performance: {'loss': 2.8889493569731712, 'abosulate accuracy': 0.04790000157663599, 'consecutive overlap rate': 0.2595152273774147, 'overlap rate': 0.451167181879282}
#
# Current epoch: 125,
# training performance: {'loss': 0.48475669845938685, 'abosulate accuracy': 0.21090001054108143, 'consecutive overlap rate': 0.40590968132019045, 'overlap rate': 0.8249113529920578}
# evaluation performance: {'loss': 2.9189069882035255, 'abosulate accuracy': 0.06160000269301236, 'consecutive overlap rate': 0.2779370879754424, 'overlap rate': 0.47049537524580953}
#
# Current epoch: 130,
# training performance: {'loss': 0.4664770380593836, 'abosulate accuracy': 0.22390001090243458, 'consecutive overlap rate': 0.420406355895102, 'overlap rate': 0.8315701559185982}
# evaluation performance: {'loss': 2.84877996891737, 'abosulate accuracy': 0.07765000314684585, 'consecutive overlap rate': 0.2708562705665827, 'overlap rate': 0.4780275944620371}
#
# Current epoch: 135,
# training performance: {'loss': 0.44117166511714456, 'abosulate accuracy': 0.2356000119820237, 'consecutive overlap rate': 0.42140122205019, 'overlap rate': 0.840322633087635}
# evaluation performance: {'loss': 2.9172545269131662, 'abosulate accuracy': 0.0516000012808945, 'consecutive overlap rate': 0.2910318860784173, 'overlap rate': 0.47807184271514414}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#     156
# --> 157         eval_perf = evaluate(model, eval_dl, criterion)
#     158         eval_acc = eval_perf['abosulate accuracy']
#     159
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in evaluate(model, dataloader, criterion, per_seq_len_performance)
#     110
#     111             Ypred = logits.view(seq_len, batch_size, -1).argmax(2)
# --> 112             accu, covr, ovr = metrics(Y[1:-1], Ypred[:-1])
#     113             loss = criterion(logits, Y[1:].view(-1))
#     114
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in metrics(Y, Ypred)
#      42         for col_idx, min_idx in enumerate(pw_cmp.argmin(0)):
#      43             if pw_cmp[min_idx, col_idx] == 0:
# ---> 44                 pw_cmp[min_idx:, col_idx] = 0
#      45
#      46     # consecutive overlap rate
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hyperparameter set 3

# %%
hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9917359977960587, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.09928605342283844, 'overlap rate': 0.36638888344168663}
# evaluation performance: {'loss': 2.4620127826929092, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.12910344367846846, 'overlap rate': 0.23979217186570168}
#
# Current epoch: 10,
# training performance: {'loss': 1.1593837656080723, 'abosulate accuracy': 0.011600000644102692, 'consecutive overlap rate': 0.22039294634014367, 'overlap rate': 0.603282880783081}
# evaluation performance: {'loss': 2.315541833639145, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.2194042459130287, 'overlap rate': 0.35284348502755164}
#
# Current epoch: 15,
# training performance: {'loss': 0.8628774482756854, 'abosulate accuracy': 0.04420000233221799, 'consecutive overlap rate': 0.29633779525756837, 'overlap rate': 0.7007954493165016}
# evaluation performance: {'loss': 2.322176057100296, 'abosulate accuracy': 0.0005500000261235982, 'consecutive overlap rate': 0.24044713526964187, 'overlap rate': 0.4096985593438148}
#
# Current epoch: 20,
# training performance: {'loss': 0.7128556426614523, 'abosulate accuracy': 0.08990000408375635, 'consecutive overlap rate': 0.35125971436500547, 'overlap rate': 0.7509072035551071}
# evaluation performance: {'loss': 2.234586262702942, 'abosulate accuracy': 0.010000000410946086, 'consecutive overlap rate': 0.26788862869143487, 'overlap rate': 0.45276542752981186}
#
# Current epoch: 25,
# training performance: {'loss': 0.6158489249646664, 'abosulate accuracy': 0.12250000678468495, 'consecutive overlap rate': 0.38638507537543776, 'overlap rate': 0.782574737071991}
# evaluation performance: {'loss': 2.2796278655529023, 'abosulate accuracy': 0.014900000888155773, 'consecutive overlap rate': 0.2780875040218234, 'overlap rate': 0.47710084691643717}
#
# Current epoch: 30,
# training performance: {'loss': 0.5193640132434666, 'abosulate accuracy': 0.18080000693444162, 'consecutive overlap rate': 0.4289222192019224, 'overlap rate': 0.8165096312761306}
#
# Current epoch: 120,
# training performance: {'loss': 0.1265976492781192, 'abosulate accuracy': 0.3759000194608234, 'consecutive overlap rate': 0.6200071081519127, 'overlap rate': 0.9557645484805107}
# evaluation performance: {'loss': 3.854823812842369, 'abosulate accuracy': 0.0449000017833896, 'consecutive overlap rate': 0.28522822819650173, 'overlap rate': 0.5281533233821392}
#
# Current epoch: 125,
# training performance: {'loss': 0.10874899721238762, 'abosulate accuracy': 0.3991000181878917, 'consecutive overlap rate': 0.6522359021008015, 'overlap rate': 0.9621983453631401}
# evaluation performance: {'loss': 3.8638803958892822, 'abosulate accuracy': 0.04875000201864168, 'consecutive overlap rate': 0.28392902929335834, 'overlap rate': 0.5285181865096092}
#
# Current epoch: 130,
# training performance: {'loss': 0.06300589723978192, 'abosulate accuracy': 0.5237000226974488, 'consecutive overlap rate': 0.7591858081519604, 'overlap rate': 0.9808917969465256}
# evaluation performance: {'loss': 3.834194076061249, 'abosulate accuracy': 0.061550002201693134, 'consecutive overlap rate': 0.29689055532217024, 'overlap rate': 0.5486731506884098}
#
# Current epoch: 135,
# training performance: {'loss': 0.03740651281550526, 'abosulate accuracy': 0.6654000289738178, 'consecutive overlap rate': 0.8570252552628517, 'overlap rate': 0.9905242800712586}
# evaluation performance: {'loss': 4.0945828467607495, 'abosulate accuracy': 0.05455000242218375, 'consecutive overlap rate': 0.29179479982703926, 'overlap rate': 0.5424234323203564}
#
# Current epoch: 140,
# training performance: {'loss': 0.031148058880353345, 'abosulate accuracy': 0.7052000321447849, 'consecutive overlap rate': 0.8756412267684937, 'overlap rate': 0.9926225692033768}
# evaluation performance: {'loss': 4.215794524550438, 'abosulate accuracy': 0.06340000208001584, 'consecutive overlap rate': 0.296980294957757, 'overlap rate': 0.5465130493044853}
#
# Current epoch: 145,
# training performance: {'loss': 0.0332732463197317, 'abosulate accuracy': 0.677400029450655, 'consecutive overlap rate': 0.8599480107426644, 'overlap rate': 0.9910854071378707}
# evaluation performance: {'loss': 4.2732610493898395, 'abosulate accuracy': 0.0615500032028649, 'consecutive overlap rate': 0.29590739365667107, 'overlap rate': 0.5451341174542904}
#
# Current epoch: 150,
# training performance: {'loss': 0.020728973181394394, 'abosulate accuracy': 0.7819000348448754, 'consecutive overlap rate': 0.9203806281089782, 'overlap rate': 0.9956666305661201}
# evaluation performance: {'loss': 4.341715914011002, 'abosulate accuracy': 0.06345000277506188, 'consecutive overlap rate': 0.30113839767873285, 'overlap rate': 0.550643365085125}

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 0.022206133205327206, 'abosulate accuracy': 0.7573000296950341, 'consecutive overlap rate': 0.9142616584897041, 'overlap rate': 0.9946980372071266}
# evaluation performance: {'loss': 4.530015012621879, 'abosulate accuracy': 0.05600000281119719, 'consecutive overlap rate': 0.2923725279048085, 'overlap rate': 0.5398232460021972}
#
# Current epoch: 10,
#
# Current epoch: 55,
# training performance: {'loss': 0.034971045699785465, 'abosulate accuracy': 0.6349000290036202, 'consecutive overlap rate': 0.8302157700061799, 'overlap rate': 0.9889129638671875}
# evaluation performance: {'loss': 4.810482344031334, 'abosulate accuracy': 0.06280000322731212, 'consecutive overlap rate': 0.2994205242022872, 'overlap rate': 0.5495966441929341}
#
# Current epoch: 60,
# training performance: {'loss': 0.1382694065454416, 'abosulate accuracy': 0.36330001674359663, 'consecutive overlap rate': 0.5895144812762737, 'overlap rate': 0.9515090733766556}
# evaluation performance: {'loss': 4.701290729641914, 'abosulate accuracy': 0.05465000192634761, 'consecutive overlap rate': 0.2928760450333357, 'overlap rate': 0.5403551302850247}
#
# Current epoch: 65,
# training performance: {'loss': 0.18779112631455064, 'abosulate accuracy': 0.2853000139934011, 'consecutive overlap rate': 0.528298382461071, 'overlap rate': 0.9337523713707924}
# evaluation performance: {'loss': 4.536001652479172, 'abosulate accuracy': 0.04025000223191455, 'consecutive overlap rate': 0.28201674446463587, 'overlap rate': 0.5283147417008877}
#
# Current epoch: 70,
# training performance: {'loss': 0.08625140611547977, 'abosulate accuracy': 0.4274000228382647, 'consecutive overlap rate': 0.6666222147643566, 'overlap rate': 0.9692093834280968}
# evaluation performance: {'loss': 4.24039401113987, 'abosulate accuracy': 0.06275000243913383, 'consecutive overlap rate': 0.30589599125087263, 'overlap rate': 0.5563286721706391}
#
# Current epoch: 75,
# training performance: {'loss': 0.025275511192739943, 'abosulate accuracy': 0.735900029540062, 'consecutive overlap rate': 0.8925372391939164, 'overlap rate': 0.9937734916806221}
# evaluation performance: {'loss': 4.390679821372032, 'abosulate accuracy': 0.06675000268733129, 'consecutive overlap rate': 0.30821014624089005, 'overlap rate': 0.5621797882020474}
#
# Current epoch: 80,
# training performance: {'loss': 0.02119539684645133, 'abosulate accuracy': 0.7620000272989274, 'consecutive overlap rate': 0.9114012062549591, 'overlap rate': 0.9949780985713005}
# evaluation performance: {'loss': 4.669262093305588, 'abosulate accuracy': 0.06350000323727727, 'consecutive overlap rate': 0.3032550001516938, 'overlap rate': 0.5510949328541755}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c28d81945550> in <module>
# ----> 1 log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer,
#       2                          saved_model_fp, acc_threshold, print_freq, max_epoch_num,
#       3                          train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in train_and_evaluate(model, train_dl, eval_dl, criterion, optimizer, saved_model_fp, acc_threshold, print_freq, max_epoch_num, train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
#     155         train_acc = train_perf['abosulate accuracy']
#     156
# --> 157         eval_perf = evaluate(model, eval_dl, criterion)
#     158         eval_acc = eval_perf['abosulate accuracy']
#     159
#
# /drive/My Drive/RNNSeq2Seq/scripts/pytorch_utils.py in evaluate(model, dataloader, criterion, per_seq_len_performance)
#     100
#     101     with torch.no_grad():
# --> 102         for X, Y in dataloader:
#     103             seq_len, batch_size = Y.shape
#     104             seq_len -= 1 # logits does not have <s>
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
# ---> 52         return self.collate_fn(data)
#
# /drive/My Drive/RNNSeq2Seq/scripts/dataloader.py in collate_fn(batch, max_seq_len)
#      56
#      57     for idx, (x, y) in enumerate(batch):
# ---> 58         inputs[:len(x), idx] = torch.Tensor(x).long()
#      59         outputs[:len(y), idx] = torch.Tensor(y).long()
#      60
#
# KeyboardInterrupt:

# %% [markdown]
# # RedStr

# %%
train = read_data(join(folder, "RedStr/train.txt"))
dev = read_data(join(folder, "RedStr/dev.txt"))
saved_model_fp = join(project_dir, "notebooks/Hyperparatemers Tuning/RevStr_model.pt")

train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)

# %% [markdown]
# ## Hyperparameter set 1

# %%
hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
encoder = Encoder(in_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type, 
                  dropout_rate, bidirectional, 
                  reduction_method)
attention = Attention(hidden_size)
decoder = Decoder(out_vocab_size, hidden_size, 
                  embd_dim, num_layers, rnn_type,
                  attention, use_attention, 
                  dropout_rate)

model = Seq2Seq(encoder, decoder, device).to(device)
model.apply(init_weights)

learning_rate = 5e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                         saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                         train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
# Out:
# Current epoch: 5,
# training performance: {'loss': 1.9082737118005753, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1081216687336564, 'overlap rate': 0.3857444874942303}
# evaluation performance: {'loss': 2.4091228723526, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1430215218104422, 'overlap rate': 0.25363508686423303}
#
# Current epoch: 10,
# training performance: {'loss': 1.1443809315562248, 'abosulate accuracy': 0.008400000364053995, 'consecutive overlap rate': 0.21873919554054738, 'overlap rate': 0.6102190256118775}
# evaluation performance: {'loss': 2.231535592675209, 'abosulate accuracy': 0.0009500000218395144, 'consecutive overlap rate': 0.2236722782254219, 'overlap rate': 0.3659326836466789}
#
# Current epoch: 15,
# training performance: {'loss': 0.8297893077135086, 'abosulate accuracy': 0.05440000231610611, 'consecutive overlap rate': 0.3123174518346786, 'overlap rate': 0.7143769800662995}
# evaluation performance: {'loss': 2.18544145822525, 'abosulate accuracy': 0.005750000284751877, 'consecutive overlap rate': 0.2604998638853431, 'overlap rate': 0.43958172053098676}
#
# Current epoch: 20,
# training performance: {'loss': 0.6626474654302001, 'abosulate accuracy': 0.10970000539673493, 'consecutive overlap rate': 0.37631621286273004, 'overlap rate': 0.76945970505476}
# evaluation performance: {'loss': 2.0682329818606378, 'abosulate accuracy': 0.017500000790460036, 'consecutive overlap rate': 0.29452559277415274, 'overlap rate': 0.496630872040987}
#
# Current epoch: 25,
# training performance: {'loss': 0.5780486898496747, 'abosulate accuracy': 0.12400000775232911, 'consecutive overlap rate': 0.399974213168025, 'overlap rate': 0.7958036571741104}
# evaluation performance: {'loss': 2.149196243286133, 'abosulate accuracy': 0.01660000067204237, 'consecutive overlap rate': 0.28742593452334403, 'overlap rate': 0.5016682639718055}
#
# Current epoch: 30,
# training performance: {'loss': 0.4885768324136734, 'abosulate accuracy': 0.19250000780448318, 'consecutive overlap rate': 0.4448046650737524, 'overlap rate': 0.8269822269678115}
# evaluation performance: {'loss': 2.0656529784202577, 'abosulate accuracy': 0.041950002562953156, 'consecutive overlap rate': 0.3081563148647547, 'overlap rate': 0.5316138006746769}
#
# Current epoch: 35,
# training performance: {'loss': 0.44422836042940617, 'abosulate accuracy': 0.19470000844448804, 'consecutive overlap rate': 0.442343694716692, 'overlap rate': 0.8403250500559807}
# evaluation performance: {'loss': 2.4596665501594543, 'abosulate accuracy': 0.020600000926060603, 'consecutive overlap rate': 0.293491405248642, 'overlap rate': 0.4999456711113453}
#
# Current epoch: 40,
# training performance: {'loss': 0.4346598207950592, 'abosulate accuracy': 0.20600000936537982, 'consecutive overlap rate': 0.4560001078993082, 'overlap rate': 0.8451426953077317}
# evaluation performance: {'loss': 2.39911188185215, 'abosulate accuracy': 0.028600001434097067, 'consecutive overlap rate': 0.3087860396131873, 'overlap rate': 0.527048560231924}
#
# Current epoch: 45,
# training performance: {'loss': 0.42203832529485225, 'abosulate accuracy': 0.20380000891163946, 'consecutive overlap rate': 0.47024528235197066, 'overlap rate': 0.8493914008140564}
# evaluation performance: {'loss': 2.474428880214691, 'abosulate accuracy': 0.02015000112587586, 'consecutive overlap rate': 0.2909957991912961, 'overlap rate': 0.5242594003677368}
#
# Current epoch: 50,
# training performance: {'loss': 0.35548532335087657, 'abosulate accuracy': 0.2651000116020441, 'consecutive overlap rate': 0.5090501915663481, 'overlap rate': 0.8740197166800499}
# evaluation performance: {'loss': 2.2628914266824722, 'abosulate accuracy': 0.06095000217901543, 'consecutive overlap rate': 0.31015363037586213, 'overlap rate': 0.5633161999285221}
#
# Current epoch: 55,
# training performance: {'loss': 0.28662038282491265, 'abosulate accuracy': 0.3264000158756971, 'consecutive overlap rate': 0.544202073290944, 'overlap rate': 0.8981706082820893}
# evaluation performance: {'loss': 2.279345816373825, 'abosulate accuracy': 0.0661000027495902, 'consecutive overlap rate': 0.31498364415019753, 'overlap rate': 0.5693542927503585}
#
# Current epoch: 60,
# training performance: {'loss': 0.23715424588881434, 'abosulate accuracy': 0.33080001692287625, 'consecutive overlap rate': 0.5520333871245384, 'overlap rate': 0.9162257999181748}
# evaluation performance: {'loss': 2.387450225651264, 'abosulate accuracy': 0.0643000038806349, 'consecutive overlap rate': 0.3252894951030612, 'overlap rate': 0.5827815361320973}
#
# Current epoch: 65,
# training performance: {'loss': 0.20831147145945578, 'abosulate accuracy': 0.3603000187431462, 'consecutive overlap rate': 0.5798398151993751, 'overlap rate': 0.9267011851072311}
# evaluation performance: {'loss': 2.670718589425087, 'abosulate accuracy': 0.05165000315173529, 'consecutive overlap rate': 0.30999483950436113, 'overlap rate': 0.5588942170143127}
#
# Current epoch: 70,
# training performance: {'loss': 0.20427410798147322, 'abosulate accuracy': 0.3299000146565959, 'consecutive overlap rate': 0.5643698994070292, 'overlap rate': 0.9274026036262513}
# evaluation performance: {'loss': 2.7406987503170965, 'abosulate accuracy': 0.04660000109579414, 'consecutive overlap rate': 0.3076289609074593, 'overlap rate': 0.5556764356791973}
#
# Current epoch: 75,
# training performance: {'loss': 0.19468424282968044, 'abosulate accuracy': 0.3596000164397992, 'consecutive overlap rate': 0.5811837155371904, 'overlap rate': 0.9313036605715752}
# evaluation performance: {'loss': 3.032578682899475, 'abosulate accuracy': 0.03625000121537596, 'consecutive overlap rate': 0.2985195366665721, 'overlap rate': 0.5359878428280354}
#
# Current epoch: 80,
# training performance: {'loss': 0.1712142238393426, 'abosulate accuracy': 0.3406000153976493, 'consecutive overlap rate': 0.5901419416069984, 'overlap rate': 0.9395765274763107}
# evaluation performance: {'loss': 3.0252954989671705, 'abosulate accuracy': 0.04350000189151615, 'consecutive overlap rate': 0.3069774528965354, 'overlap rate': 0.5461951076984406}
#
# Current epoch: 85,
# training performance: {'loss': 0.20115582700818777, 'abosulate accuracy': 0.3033000150229782, 'consecutive overlap rate': 0.5543693143874406, 'overlap rate': 0.9279235199093818}
# evaluation performance: {'loss': 3.071240597963333, 'abosulate accuracy': 0.04755000116419979, 'consecutive overlap rate': 0.30274385325610637, 'overlap rate': 0.5435309134423733}
#
# Current epoch: 90,
# training performance: {'loss': 0.19963094610720872, 'abosulate accuracy': 0.3105000133626163, 'consecutive overlap rate': 0.558561023697257, 'overlap rate': 0.9280007153749465}
# evaluation performance: {'loss': 3.007931911945343, 'abosulate accuracy': 0.04955000250483863, 'consecutive overlap rate': 0.3024241426959634, 'overlap rate': 0.5524361193180084}
#
# Current epoch: 95,
# training performance: {'loss': 0.16037682136520742, 'abosulate accuracy': 0.34560001554200426, 'consecutive overlap rate': 0.5929284788668155, 'overlap rate': 0.9430800467729569}
# evaluation performance: {'loss': 3.022918958961964, 'abosulate accuracy': 0.06750000327010638, 'consecutive overlap rate': 0.3161238880828023, 'overlap rate': 0.5681385897099972}
#
# Current epoch: 100,
# training performance: {'loss': 0.08511817158432677, 'abosulate accuracy': 0.46960002053529026, 'consecutive overlap rate': 0.719969841837883, 'overlap rate': 0.9741731598973274}
# evaluation performance: {'loss': 3.057520776987076, 'abosulate accuracy': 0.07635000317823142, 'consecutive overlap rate': 0.3235669741407037, 'overlap rate': 0.5805922962725163}
#
# Current epoch: 105,
# training performance: {'loss': 0.06552663363399916, 'abosulate accuracy': 0.5365000227466226, 'consecutive overlap rate': 0.7672083020210266, 'overlap rate': 0.9811478897929191}
# evaluation performance: {'loss': 3.3830609142780306, 'abosulate accuracy': 0.05740000249934383, 'consecutive overlap rate': 0.3124450197443366, 'overlap rate': 0.5650568343698978}
#
# Current epoch: 110,
# training performance: {'loss': 0.06407137931091711, 'abosulate accuracy': 0.5315000273287296, 'consecutive overlap rate': 0.7520311534404754, 'overlap rate': 0.9810350984334946}
# evaluation performance: {'loss': 3.460239741206169, 'abosulate accuracy': 0.06260000196052715, 'consecutive overlap rate': 0.31648157592862847, 'overlap rate': 0.5678997196257114}
#
# Current epoch: 115,
# training performance: {'loss': 0.06757162865251302, 'abosulate accuracy': 0.5142000237479806, 'consecutive overlap rate': 0.7468748897314071, 'overlap rate': 0.9784816607832909}
# evaluation performance: {'loss': 3.5659588396549227, 'abosulate accuracy': 0.06505000368342735, 'consecutive overlap rate': 0.31200316790491345, 'overlap rate': 0.5643201246857643}
#
# Current epoch: 120,
# training performance: {'loss': 0.09822005892638117, 'abosulate accuracy': 0.42040001773275437, 'consecutive overlap rate': 0.658165268599987, 'overlap rate': 0.9658936440944672}
# evaluation performance: {'loss': 3.6279222846031187, 'abosulate accuracy': 0.059400003077462314, 'consecutive overlap rate': 0.31401007901877165, 'overlap rate': 0.5634161308407784}
#
# Current epoch: 125,
# training performance: {'loss': 0.08980431559029967, 'abosulate accuracy': 0.43400002100970597, 'consecutive overlap rate': 0.6686010003089905, 'overlap rate': 0.9688656404614449}
# evaluation performance: {'loss': 3.6357966661453247, 'abosulate accuracy': 0.06450000241748058, 'consecutive overlap rate': 0.3116756549105048, 'overlap rate': 0.5653583273291588}
#
# Current epoch: 130,
# training performance: {'loss': 0.07428381842328236, 'abosulate accuracy': 0.4769000232219696, 'consecutive overlap rate': 0.7157538384199142, 'overlap rate': 0.9753125518560409}
# evaluation performance: {'loss': 3.64202498793602, 'abosulate accuracy': 0.07015000264509581, 'consecutive overlap rate': 0.32286158557981254, 'overlap rate': 0.5715760320425034}
#
# Current epoch: 135,
# training performance: {'loss': 0.0751550529326778, 'abosulate accuracy': 0.4692000221461058, 'consecutive overlap rate': 0.7116547375917435, 'overlap rate': 0.9747596934437752}
# evaluation performance: {'loss': 3.6684825152158735, 'abosulate accuracy': 0.06575000306474976, 'consecutive overlap rate': 0.316642414778471, 'overlap rate': 0.5714914113283157}
#
# Current epoch: 140,
# training performance: {'loss': 0.06677912482991814, 'abosulate accuracy': 0.491800020262599, 'consecutive overlap rate': 0.7233514383435249, 'overlap rate': 0.9779427260160446}
# evaluation performance: {'loss': 3.766204869747162, 'abosulate accuracy': 0.06680000306223519, 'consecutive overlap rate': 0.314619024656713, 'overlap rate': 0.5680636085569859}
#
# Current epoch: 145,
# training performance: {'loss': 0.0629008912597783, 'abosulate accuracy': 0.5117000220343471, 'consecutive overlap rate': 0.7433370888233185, 'overlap rate': 0.9792057260870933}
# evaluation performance: {'loss': 3.9037434279918672, 'abosulate accuracy': 0.061250003083841875, 'consecutive overlap rate': 0.3171928172931075, 'overlap rate': 0.5686366632580757}
#
# Current epoch: 150,
# training performance: {'loss': 0.0353822838049382, 'abosulate accuracy': 0.6593000322580338, 'consecutive overlap rate': 0.8528750091791153, 'overlap rate': 0.9902079269289971}
# evaluation performance: {'loss': 3.9090502351522445, 'abosulate accuracy': 0.07245000245166011, 'consecutive overlap rate': 0.32400631438940763, 'overlap rate': 0.5756413377821445}

# %%
plot_log(log)
