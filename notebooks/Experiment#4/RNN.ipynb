# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 256
embd_dim = 128
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = False
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 4
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#4/RNN created!
# ./Experiments_Logs/Experiment#4/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#4/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#4/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#4 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9027850478887558, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009383333563164342, 'overlap rate': 0.4454017162322998}
# evaluation performance: {'loss': 2.8809755444526672, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000936666681081988, 'overlap rate': 0.4429450433701277}
#
# Current epoch: 10,
# training performance: {'loss': 1.807151585817337, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0032850000454345716, 'overlap rate': 0.47135004699230193}
# evaluation performance: {'loss': 2.4756985396146773, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004151666694087908, 'overlap rate': 0.421057540923357}
#
# Current epoch: 15,
# training performance: {'loss': 1.5960863202810287, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007923333439975977, 'overlap rate': 0.5229817166924476}
# evaluation performance: {'loss': 1.9532244250178337, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008070889906957746, 'overlap rate': 0.42307123988866807}
#
# Current epoch: 20,
# training performance: {'loss': 0.47779093831777575, 'abosulate accuracy': 0.02270000099670142, 'consecutive overlap rate': 0.08017000108957291, 'overlap rate': 0.8755334243178368}
# evaluation performance: {'loss': 0.7902041219174862, 'abosulate accuracy': 0.058300002943724394, 'consecutive overlap rate': 0.15102416770532728, 'overlap rate': 0.7774850711226463}
#
# Current epoch: 25,
# training performance: {'loss': 0.06436533704400063, 'abosulate accuracy': 0.7884000405669213, 'consecutive overlap rate': 0.8372433423995972, 'overlap rate': 0.9956733927130699}
# evaluation performance: {'loss': 0.14202918903902173, 'abosulate accuracy': 0.8313500382006168, 'consecutive overlap rate': 0.8697791829705238, 'overlap rate': 0.9793483898043632}
#
# Current epoch: 30,
# training performance: {'loss': 0.019598080590367318, 'abosulate accuracy': 0.9609000474214554, 'consecutive overlap rate': 0.9650200068950653, 'overlap rate': 0.999301728606224}
# evaluation performance: {'loss': 0.06509259918238967, 'abosulate accuracy': 0.9586500450968742, 'consecutive overlap rate': 0.9637316785752773, 'overlap rate': 0.9921775557100773}
#
# Current epoch: 35,
# training performance: {'loss': 0.009828972374089062, 'abosulate accuracy': 0.9771000444889069, 'consecutive overlap rate': 0.9778600111603737, 'overlap rate': 0.9996067374944687}
# evaluation performance: {'loss': 0.05347642502747476, 'abosulate accuracy': 0.9732500456273556, 'consecutive overlap rate': 0.9744950115680695, 'overlap rate': 0.9936250522732735}
#
# Current epoch: 40,
# training performance: {'loss': 0.006127635738812387, 'abosulate accuracy': 0.9808000385761261, 'consecutive overlap rate': 0.9808450177311897, 'overlap rate': 0.9996767461299896}
# evaluation performance: {'loss': 0.049315745488274845, 'abosulate accuracy': 0.9765500426292419, 'consecutive overlap rate': 0.9771525122225284, 'overlap rate': 0.9941050536930561}
#
# Current epoch: 45,
# training performance: {'loss': 0.004299946926767007, 'abosulate accuracy': 0.981300039589405, 'consecutive overlap rate': 0.9813033550977707, 'overlap rate': 0.9996867403388023}
# evaluation performance: {'loss': 0.04723283417406492, 'abosulate accuracy': 0.9777000427246094, 'consecutive overlap rate': 0.9781673580408097, 'overlap rate': 0.9944964684545994}
#
# Current epoch: 50,
# training performance: {'loss': 0.00324219178291969, 'abosulate accuracy': 0.9816000416874886, 'consecutive overlap rate': 0.9816033482551575, 'overlap rate': 0.9996917322278023}
# evaluation performance: {'loss': 0.04587381697492674, 'abosulate accuracy': 0.9783000439405442, 'consecutive overlap rate': 0.9787616774439811, 'overlap rate': 0.9946825549006462}
#
# Current epoch: 55,
# training performance: {'loss': 0.002560343997902237, 'abosulate accuracy': 0.9830000385642051, 'consecutive overlap rate': 0.9830000162124634, 'overlap rate': 0.9997150778770447}
# evaluation performance: {'loss': 0.044976834033150226, 'abosulate accuracy': 0.9789500430226326, 'consecutive overlap rate': 0.9793641798198223, 'overlap rate': 0.9949067242443561}
#
# Current epoch: 60,
# training performance: {'loss': 0.0020849711261689665, 'abosulate accuracy': 0.9838000386953354, 'consecutive overlap rate': 0.983800008893013, 'overlap rate': 0.9997300654649734}
# evaluation performance: {'loss': 0.04599747654428939, 'abosulate accuracy': 0.9795000433921814, 'consecutive overlap rate': 0.9798833444714546, 'overlap rate': 0.9949425481259823}
#
# Current epoch: 65,
# training performance: {'loss': 0.0017329322727164254, 'abosulate accuracy': 0.9850000411272049, 'consecutive overlap rate': 0.9850000098347664, 'overlap rate': 0.99975006878376}
# evaluation performance: {'loss': 0.0426874699187465, 'abosulate accuracy': 0.9798500426113605, 'consecutive overlap rate': 0.9802116803824902, 'overlap rate': 0.9953817218542099}
#
# Current epoch: 70,
# training performance: {'loss': 0.001456934459565673, 'abosulate accuracy': 0.9864000409841538, 'consecutive overlap rate': 0.9864000096917153, 'overlap rate': 0.9997734069824219}
# evaluation performance: {'loss': 0.04286554340505973, 'abosulate accuracy': 0.980600043386221, 'consecutive overlap rate': 0.9809625126421452, 'overlap rate': 0.9954375550150871}
#
# Current epoch: 75,
# training performance: {'loss': 0.0012347425654297695, 'abosulate accuracy': 0.9876000374555588, 'consecutive overlap rate': 0.9876000091433526, 'overlap rate': 0.999793416261673}
# evaluation performance: {'loss': 0.037764340540161354, 'abosulate accuracy': 0.9810500428080559, 'consecutive overlap rate': 0.9814108468592166, 'overlap rate': 0.995989229530096}
#
# Current epoch: 80,
# training performance: {'loss': 0.0010496750750462525, 'abosulate accuracy': 0.9894000366330147, 'consecutive overlap rate': 0.9894000083208084, 'overlap rate': 0.999823409318924}
# evaluation performance: {'loss': 0.036271466920152304, 'abosulate accuracy': 0.9818000368773937, 'consecutive overlap rate': 0.9821033470332623, 'overlap rate': 0.9962008997797966}
#
# Current epoch: 85,
# training performance: {'loss': 0.0008963017535279505, 'abosulate accuracy': 0.991200040280819, 'consecutive overlap rate': 0.9911999985575676, 'overlap rate': 0.9998533681035042}
# evaluation performance: {'loss': 0.03612466201375355, 'abosulate accuracy': 0.9823500387370586, 'consecutive overlap rate': 0.9826483473181724, 'overlap rate': 0.9962842218577862}
#
# Current epoch: 90,
# training performance: {'loss': 0.0007753114827210083, 'abosulate accuracy': 0.9922000348567963, 'consecutive overlap rate': 0.99220000654459, 'overlap rate': 0.9998699456453324}
# evaluation performance: {'loss': 0.034304040147253544, 'abosulate accuracy': 0.9831000357866287, 'consecutive overlap rate': 0.9833966813981533, 'overlap rate': 0.996530893445015}
#
# Current epoch: 95,
# training performance: {'loss': 0.0006451534864027053, 'abosulate accuracy': 0.994700038433075, 'consecutive overlap rate': 0.9946999937295914, 'overlap rate': 0.9999117285013199}
# evaluation performance: {'loss': 0.03442431849980494, 'abosulate accuracy': 0.9835500374436379, 'consecutive overlap rate': 0.9838616788387299, 'overlap rate': 0.9965667188167572}
#
# Current epoch: 100,
# training performance: {'loss': 0.00054672558180755, 'abosulate accuracy': 0.9963000312447547, 'consecutive overlap rate': 0.9962999939918518, 'overlap rate': 0.9999383836984634}
# evaluation performance: {'loss': 0.03399594510046881, 'abosulate accuracy': 0.9842000387609005, 'consecutive overlap rate': 0.9844950161874294, 'overlap rate': 0.9966733865439892}
#
# Experiments_Logs/Experiment#4/RNN/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.03049679037721944, 'abosulate accuracy': 0.9849250391125679, 'consecutive overlap rate': 0.9851095952093601, 'overlap rate': 0.9969496369361878}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.206669420003891, 'abosulate accuracy': 0.2239000104367733, 'consecutive overlap rate': 0.24885019473731518, 'overlap rate': 0.6887494824826718}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.0886138173841662, 'abosulate accuracy': 0.8488728596318152, 'consecutive overlap rate': 0.8780520285329511, 'overlap rate': 0.9146974605898703}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.692028444064291, 'abosulate accuracy': 0.19350000823798932, 'consecutive overlap rate': 0.21639965788314217, 'overlap rate': 0.5462780857556745}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.8788221567869186, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008266666845884174, 'overlap rate': 0.4521783798933029}
# evaluation performance: {'loss': 2.1645628079771995, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008776271341048413, 'overlap rate': 0.4482990723103285}
#
# Current epoch: 10,
# training performance: {'loss': 1.6858712702989578, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002313333351048641, 'overlap rate': 0.4980150513350964}
# evaluation performance: {'loss': 1.9919995993375779, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003133333372534253, 'overlap rate': 0.4832842152565718}
#
# Current epoch: 15,
# training performance: {'loss': 1.1878221735358239, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01374500012025237, 'overlap rate': 0.6323117271065712}
# evaluation performance: {'loss': 1.875245824456215, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0161541668465361, 'overlap rate': 0.45874838121235373}
#
# Current epoch: 20,
# training performance: {'loss': 0.5201525643467904, 'abosulate accuracy': 0.016100000601727515, 'consecutive overlap rate': 0.07656000088900328, 'overlap rate': 0.855933427810669}
# evaluation performance: {'loss': 0.9487820982933044, 'abosulate accuracy': 0.047350002196617426, 'consecutive overlap rate': 0.12478583483025432, 'overlap rate': 0.7442834056913853}
#
# Current epoch: 25,
# training performance: {'loss': 1.3384401500225067, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.053713334165513514, 'overlap rate': 0.6349250748753548}
# evaluation performance: {'loss': 2.0414445281028746, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05522916750051081, 'overlap rate': 0.5362650580704212}
#
# Current epoch: 30,
# training performance: {'loss': 0.17831800654530525, 'abosulate accuracy': 0.33510001450777055, 'consecutive overlap rate': 0.4638683371245861, 'overlap rate': 0.975786742568016}
# evaluation performance: {'loss': 0.41526492200791837, 'abosulate accuracy': 0.41825001910328863, 'consecutive overlap rate': 0.5321658387780189, 'overlap rate': 0.9197950698435307}
#
# Current epoch: 35,
# training performance: {'loss': 0.05609335619956255, 'abosulate accuracy': 0.8387000411748886, 'consecutive overlap rate': 0.8770050123333931, 'overlap rate': 0.9966867431998253}
# evaluation performance: {'loss': 0.1367071785032749, 'abosulate accuracy': 0.8199000418186188, 'consecutive overlap rate': 0.8662016779184342, 'overlap rate': 0.9807200565934181}
#
# Current epoch: 40,
# training performance: {'loss': 0.028010199824348093, 'abosulate accuracy': 0.9429000452160835, 'consecutive overlap rate': 0.9553350150585175, 'overlap rate': 0.9989433884620667}
# evaluation performance: {'loss': 0.08359214728698135, 'abosulate accuracy': 0.9209000408649445, 'consecutive overlap rate': 0.9392875112593174, 'overlap rate': 0.9897900685667992}
#
# Current epoch: 45,
# training performance: {'loss': 0.016805721633136272, 'abosulate accuracy': 0.9738000467419624, 'consecutive overlap rate': 0.9785116747021675, 'overlap rate': 0.9995383903384208}
# evaluation performance: {'loss': 0.05712562107946724, 'abosulate accuracy': 0.9530000433325767, 'consecutive overlap rate': 0.9633016794919967, 'overlap rate': 0.9933608904480934}
#
# Current epoch: 50,
# training performance: {'loss': 0.01123339666519314, 'abosulate accuracy': 0.9851000338792801, 'consecutive overlap rate': 0.9872883453965187, 'overlap rate': 0.9997400686144828}
# evaluation performance: {'loss': 0.04158715168014169, 'abosulate accuracy': 0.9695500455796718, 'consecutive overlap rate': 0.9760133437812328, 'overlap rate': 0.9952383898198605}
#
# Current epoch: 55,
# training performance: {'loss': 0.008025355532299727, 'abosulate accuracy': 0.9911000385880471, 'consecutive overlap rate': 0.9918900042772293, 'overlap rate': 0.9998450666666031}
# evaluation performance: {'loss': 0.032463125314097854, 'abosulate accuracy': 0.9755500458180905, 'consecutive overlap rate': 0.980692508071661, 'overlap rate': 0.9964350618422031}
#
# Current epoch: 60,
# training performance: {'loss': 0.0060053370078094305, 'abosulate accuracy': 0.9944000363349914, 'consecutive overlap rate': 0.9945187255740165, 'overlap rate': 0.9999000266194343}
# evaluation performance: {'loss': 0.027447068982291968, 'abosulate accuracy': 0.9790500424802303, 'consecutive overlap rate': 0.9834416747093201, 'overlap rate': 0.9970475614070893}
#
# Current epoch: 65,
# training performance: {'loss': 0.004599472798872739, 'abosulate accuracy': 0.9959000289440155, 'consecutive overlap rate': 0.995924998819828, 'overlap rate': 0.9999300479888916}
# evaluation performance: {'loss': 0.024828877358231694, 'abosulate accuracy': 0.9835500404238701, 'consecutive overlap rate': 0.9866000093519688, 'overlap rate': 0.997335896641016}
#
# Current epoch: 70,
# training performance: {'loss': 0.0036212302453350275, 'abosulate accuracy': 0.9970000252127648, 'consecutive overlap rate': 0.9969999954104424, 'overlap rate': 0.9999500408768653}
# evaluation performance: {'loss': 0.024248311581322922, 'abosulate accuracy': 0.9853000394999981, 'consecutive overlap rate': 0.9880458414554596, 'overlap rate': 0.9974183946847915}
#
# Current epoch: 75,
# training performance: {'loss': 0.0029072482662741094, 'abosulate accuracy': 0.997700022161007, 'consecutive overlap rate': 0.9976999953389167, 'overlap rate': 0.9999617025256157}
# evaluation performance: {'loss': 0.020725599862635134, 'abosulate accuracy': 0.9868000365793705, 'consecutive overlap rate': 0.9894458435475826, 'overlap rate': 0.9977567322552204}
#
# Current epoch: 80,
# training performance: {'loss': 0.00237191432970576, 'abosulate accuracy': 0.9983000159263611, 'consecutive overlap rate': 0.9982999965548516, 'overlap rate': 0.99997169226408}
# evaluation performance: {'loss': 0.0205077860126039, 'abosulate accuracy': 0.9882500357925892, 'consecutive overlap rate': 0.9906583398580551, 'overlap rate': 0.9978308863937855}
#
# Current epoch: 85,
# training performance: {'loss': 0.0019574006466427816, 'abosulate accuracy': 0.9990000128746033, 'consecutive overlap rate': 0.9989999979734421, 'overlap rate': 0.9999833554029465}
# evaluation performance: {'loss': 0.019874035500106402, 'abosulate accuracy': 0.9897000342607498, 'consecutive overlap rate': 0.99173583984375, 'overlap rate': 0.9979450568556786}
#
# Current epoch: 90,
# training performance: {'loss': 0.0016306734993122517, 'abosulate accuracy': 0.9992000102996826, 'consecutive overlap rate': 0.9991999983787536, 'overlap rate': 0.9999866843223572}
# evaluation performance: {'loss': 0.016674437443725765, 'abosulate accuracy': 0.9906500376760959, 'consecutive overlap rate': 0.9924841754138469, 'overlap rate': 0.9982150584459305}
#
# Current epoch: 95,
# training performance: {'loss': 0.0013718270958634094, 'abosulate accuracy': 0.9993000075221061, 'consecutive overlap rate': 0.9992999985814095, 'overlap rate': 0.9999883458018303}
# evaluation performance: {'loss': 0.016980343175237066, 'abosulate accuracy': 0.9911000363528728, 'consecutive overlap rate': 0.9929133422672749, 'overlap rate': 0.998250050097704}
#
# Current epoch: 100,
# training performance: {'loss': 0.0011608902364969253, 'abosulate accuracy': 0.9995000049471855, 'consecutive overlap rate': 0.999499998986721, 'overlap rate': 0.999991674721241}
# evaluation performance: {'loss': 0.016139961159205997, 'abosulate accuracy': 0.992000038176775, 'consecutive overlap rate': 0.9936537377536296, 'overlap rate': 0.9982914470136166}
#
# Experiments_Logs/Experiment#4/RNN/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.01651340746902861, 'abosulate accuracy': 0.9920750342309475, 'consecutive overlap rate': 0.9937395926564931, 'overlap rate': 0.998262134194374}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 9.981961101293564, 'abosulate accuracy': 0.06252500393020455, 'consecutive overlap rate': 0.0980742507847026, 'overlap rate': 0.15083720395341516}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.5352226995652725, 'abosulate accuracy': 0.29908861133360093, 'consecutive overlap rate': 0.3125920774475221, 'overlap rate': 0.5464709328066918}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 10.894872232487327, 'abosulate accuracy': 0.031315790676193216, 'consecutive overlap rate': 0.10311731833912506, 'overlap rate': 0.15730118653491923}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.900822749733925, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009204519919876475, 'overlap rate': 0.4468178980052471}
# evaluation performance: {'loss': 2.3738548308610916, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008816666839265963, 'overlap rate': 0.4457942094653845}
#
# Current epoch: 10,
# training performance: {'loss': 1.7262134104967117, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002250000047206413, 'overlap rate': 0.48814838007092476}
# evaluation performance: {'loss': 2.1958424657583238, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002460833369696047, 'overlap rate': 0.46752671264111995}
#
# Current epoch: 15,
# training performance: {'loss': 1.4030589163303375, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010785000084433704, 'overlap rate': 0.5748950555920601}
# evaluation performance: {'loss': 2.2718411833047867, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01178083346458152, 'overlap rate': 0.4746133804321289}
#
# Current epoch: 20,
# training performance: {'loss': 1.1993003115057945, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.029315000399947166, 'overlap rate': 0.6604134008288384}
# evaluation performance: {'loss': 2.0184518665075304, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.029555833572521804, 'overlap rate': 0.46060921549797057}
#
# Current epoch: 25,
# training performance: {'loss': 1.6243471041321755, 'abosulate accuracy': 0.05320000243373215, 'consecutive overlap rate': 0.11645666882395744, 'overlap rate': 0.6515567265450954}
# evaluation performance: {'loss': 2.941438984870911, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.034159166971221566, 'overlap rate': 0.40509670600295067}
#
# Current epoch: 30,
# training performance: {'loss': 1.5888984858989716, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.041758672520518306, 'overlap rate': 0.5329275473952293}
# evaluation performance: {'loss': 2.506979766488075, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04053666712716222, 'overlap rate': 0.3558333687484264}
#
# Current epoch: 35,
# training performance: {'loss': 1.4809463798999787, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04115000036545098, 'overlap rate': 0.6010617271065712}
# evaluation performance: {'loss': 2.6619730263948442, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.036664167139679196, 'overlap rate': 0.4556958802044392}
#
# Current epoch: 40,
# training performance: {'loss': 0.10191782135516406, 'abosulate accuracy': 0.5796000249683857, 'consecutive overlap rate': 0.6804833397269249, 'overlap rate': 0.988680063188076}
# evaluation performance: {'loss': 0.32010511998087166, 'abosulate accuracy': 0.6345500335097313, 'consecutive overlap rate': 0.7255733452737332, 'overlap rate': 0.9506142273545265}
#
# Current epoch: 45,
# training performance: {'loss': 0.027463569305837154, 'abosulate accuracy': 0.9322000458836556, 'consecutive overlap rate': 0.9448116779327392, 'overlap rate': 0.9987050697207451}
# evaluation performance: {'loss': 0.10525022791698575, 'abosulate accuracy': 0.9324000425636768, 'consecutive overlap rate': 0.9447808407247067, 'overlap rate': 0.987347561120987}
#
# Current epoch: 50,
# training performance: {'loss': 0.013301890389993788, 'abosulate accuracy': 0.9684000506997108, 'consecutive overlap rate': 0.9715300068259239, 'overlap rate': 0.9994483828544617}
# evaluation performance: {'loss': 0.08120441692881286, 'abosulate accuracy': 0.9616000480949879, 'consecutive overlap rate': 0.9659908406436444, 'overlap rate': 0.990580053627491}
#
# Current epoch: 55,
# training performance: {'loss': 0.008223794947843999, 'abosulate accuracy': 0.9765000477433204, 'consecutive overlap rate': 0.9773783460259438, 'overlap rate': 0.9995984047651291}
# evaluation performance: {'loss': 0.06758613326819614, 'abosulate accuracy': 0.9698500439524651, 'consecutive overlap rate': 0.9722325138747692, 'overlap rate': 0.9922017239034175}
#
# Current epoch: 60,
# training performance: {'loss': 0.005741171375848353, 'abosulate accuracy': 0.9796000406146049, 'consecutive overlap rate': 0.9796950146555901, 'overlap rate': 0.9996567368507385}
# evaluation performance: {'loss': 0.060643794224597515, 'abosulate accuracy': 0.9731000460684299, 'consecutive overlap rate': 0.974698343873024, 'overlap rate': 0.9929892241954803}
#
# Current epoch: 65,
# training performance: {'loss': 0.004320804763119667, 'abosulate accuracy': 0.9803000435233116, 'consecutive overlap rate': 0.9803100153803825, 'overlap rate': 0.9996717482805252}
# evaluation performance: {'loss': 0.05582032802049071, 'abosulate accuracy': 0.9745000474154949, 'consecutive overlap rate': 0.9758550070226193, 'overlap rate': 0.9935867220163346}
#
# Current epoch: 70,
# training performance: {'loss': 0.0034112366614863277, 'abosulate accuracy': 0.9812000334262848, 'consecutive overlap rate': 0.9812000185251236, 'overlap rate': 0.9996867403388023}
# evaluation performance: {'loss': 0.051565039763227107, 'abosulate accuracy': 0.9759500421583652, 'consecutive overlap rate': 0.9770283445715904, 'overlap rate': 0.9941275589168072}
#
# Current epoch: 75,
# training performance: {'loss': 0.0028108365251682697, 'abosulate accuracy': 0.9811000406742096, 'consecutive overlap rate': 0.9811000168323517, 'overlap rate': 0.9996849060058594}
# evaluation performance: {'loss': 0.05039889248728287, 'abosulate accuracy': 0.9764500454068183, 'consecutive overlap rate': 0.9774927519261837, 'overlap rate': 0.9944481208920479}
#
# Current epoch: 80,
# training performance: {'loss': 0.0023447926359949633, 'abosulate accuracy': 0.9815000414848327, 'consecutive overlap rate': 0.9815000131726265, 'overlap rate': 0.9996915385127068}
# evaluation performance: {'loss': 0.04813020128058269, 'abosulate accuracy': 0.9773500435054302, 'consecutive overlap rate': 0.9783225148916245, 'overlap rate': 0.9946933872997761}
#
# Current epoch: 85,
# training performance: {'loss': 0.00195426435675472, 'abosulate accuracy': 0.9829000428318977, 'consecutive overlap rate': 0.9829000145196914, 'overlap rate': 0.9997150793671608}
# evaluation performance: {'loss': 0.048727134708315134, 'abosulate accuracy': 0.9775500446557999, 'consecutive overlap rate': 0.9785042233765125, 'overlap rate': 0.9946691751480102}
#
# Current epoch: 90,
# training performance: {'loss': 0.001666562055470422, 'abosulate accuracy': 0.9834000378847122, 'consecutive overlap rate': 0.9834000125527382, 'overlap rate': 0.9997234061360359}
# evaluation performance: {'loss': 0.04699567829811713, 'abosulate accuracy': 0.9787000440061092, 'consecutive overlap rate': 0.9794750116765499, 'overlap rate': 0.994949222356081}
#
# Current epoch: 95,
# training performance: {'loss': 0.0014276760542998091, 'abosulate accuracy': 0.9847000360488891, 'consecutive overlap rate': 0.9847000166773796, 'overlap rate': 0.9997450768947601}
# evaluation performance: {'loss': 0.0425147624235251, 'abosulate accuracy': 0.9795500405132771, 'consecutive overlap rate': 0.9802366808056832, 'overlap rate': 0.9954392284154892}
#
# Current epoch: 100,
# training performance: {'loss': 0.0012290010010474362, 'abosulate accuracy': 0.9863000407814979, 'consecutive overlap rate': 0.9863000094890595, 'overlap rate': 0.9997717350721359}
# evaluation performance: {'loss': 0.04272375573928002, 'abosulate accuracy': 0.9802500426769256, 'consecutive overlap rate': 0.9808575145900249, 'overlap rate': 0.9955292202532291}
#
# Experiments_Logs/Experiment#4/RNN/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.0462360155001079, 'abosulate accuracy': 0.9798000406473875, 'consecutive overlap rate': 0.9804041791707278, 'overlap rate': 0.995207141712308}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.8328611463308335, 'abosulate accuracy': 0.18830000925809146, 'consecutive overlap rate': 0.21248716507107018, 'overlap rate': 0.6843859322369099}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.0830058536221903, 'abosulate accuracy': 0.7706057183204159, 'consecutive overlap rate': 0.7843878057695204, 'overlap rate': 0.8510078833949182}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.699073804052253, 'abosulate accuracy': 0.11336842597168136, 'consecutive overlap rate': 0.12730533899249216, 'overlap rate': 0.4449073738957706}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9000163555145264, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013200000175856985, 'overlap rate': 0.4475733771920204}
# evaluation performance: {'loss': 2.033743566274643, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013750000282016118, 'overlap rate': 0.4403458785265684}
#
# Current epoch: 10,
# training performance: {'loss': 1.5292276084423064, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005563333397731185, 'overlap rate': 0.5423333927989006}
# evaluation performance: {'loss': 1.6982788309454917, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006373333401279524, 'overlap rate': 0.4903750505298376}
#
# Current epoch: 15,
# training performance: {'loss': 0.8882419019937515, 'abosulate accuracy': 0.0069000002811662854, 'consecutive overlap rate': 0.06354833347722888, 'overlap rate': 0.7505917325615883}
# evaluation performance: {'loss': 1.0049527369439601, 'abosulate accuracy': 0.02210000088089146, 'consecutive overlap rate': 0.09835176700726152, 'overlap rate': 0.7157847866415977}
#
# Current epoch: 20,
# training performance: {'loss': 0.9675461396574974, 'abosulate accuracy': 0.007600000326056034, 'consecutive overlap rate': 0.09535000082105398, 'overlap rate': 0.7318300798535347}
# evaluation performance: {'loss': 1.1947616651654243, 'abosulate accuracy': 0.019200000818818806, 'consecutive overlap rate': 0.13202166808769106, 'overlap rate': 0.6570400707423687}
#
# Current epoch: 25,
# training performance: {'loss': 0.11387635823339223, 'abosulate accuracy': 0.5785000242292881, 'consecutive overlap rate': 0.7265816703438759, 'overlap rate': 0.9881550550460816}
# evaluation performance: {'loss': 0.16924666222184898, 'abosulate accuracy': 0.6740000315010548, 'consecutive overlap rate': 0.7948191732168197, 'overlap rate': 0.9726658962666989}
#
# Current epoch: 30,
# training performance: {'loss': 0.030537646869197486, 'abosulate accuracy': 0.9485000476241112, 'consecutive overlap rate': 0.9742216721177102, 'overlap rate': 0.9990467295050621}
# evaluation performance: {'loss': 0.06623535882681608, 'abosulate accuracy': 0.9201000437140465, 'consecutive overlap rate': 0.9609925076365471, 'overlap rate': 0.9920150600373745}
#
# Current epoch: 35,
# training performance: {'loss': 0.015721877687610686, 'abosulate accuracy': 0.9828000366687775, 'consecutive overlap rate': 0.9920750126242638, 'overlap rate': 0.999656717479229}
# evaluation performance: {'loss': 0.04639959132764489, 'abosulate accuracy': 0.9415000438690185, 'consecutive overlap rate': 0.9782208420336247, 'overlap rate': 0.9946050614118576}
#
# Current epoch: 40,
# training performance: {'loss': 0.007934945216402412, 'abosulate accuracy': 0.998100021481514, 'consecutive overlap rate': 0.9989800021052361, 'overlap rate': 0.9999683707952499}
# evaluation performance: {'loss': 0.015934114123228937, 'abosulate accuracy': 0.9889000378549099, 'consecutive overlap rate': 0.9947816796600819, 'overlap rate': 0.9986417248845101}
#
# Current epoch: 45,
# training performance: {'loss': 0.005103393003810197, 'abosulate accuracy': 0.9993000090122223, 'consecutive overlap rate': 0.9995416685938835, 'overlap rate': 0.9999883487820626}
# evaluation performance: {'loss': 0.012478271598229184, 'abosulate accuracy': 0.9911500364542007, 'consecutive overlap rate': 0.9960791766643524, 'overlap rate': 0.9988708890974521}
#
# Current epoch: 50,
# training performance: {'loss': 0.0035562122939154506, 'abosulate accuracy': 0.9999000012874604, 'consecutive overlap rate': 0.9999083340167999, 'overlap rate': 0.9999983355402946}
# evaluation performance: {'loss': 0.010168081324081868, 'abosulate accuracy': 0.9935000404715538, 'consecutive overlap rate': 0.9971741780638694, 'overlap rate': 0.999058385938406}
#
# Experiments_Logs/Experiment#4/RNN/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.0060571411668206565, 'abosulate accuracy': 0.9965500254184008, 'consecutive overlap rate': 0.9988241732120514, 'overlap rate': 0.9995950300246477}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.6156890716869384, 'abosulate accuracy': 0.6655500296503305, 'consecutive overlap rate': 0.7434879511594772, 'overlap rate': 0.9019017204642296}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.9830002173300713, 'abosulate accuracy': 0.5410542570775555, 'consecutive overlap rate': 0.830121902496584, 'overlap rate': 0.8870838153746821}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.1262895243340416, 'abosulate accuracy': 0.434552653055442, 'consecutive overlap rate': 0.7269841283559799, 'overlap rate': 0.8273345043784693}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9025245279073715, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015375141520053148, 'overlap rate': 0.44815575182437895}
# evaluation performance: {'loss': 2.0108302041888235, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015700000250944868, 'overlap rate': 0.432890048250556}
#
# Current epoch: 10,
# training performance: {'loss': 1.5931469678878785, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004371666721999646, 'overlap rate': 0.5238817170262337}
# evaluation performance: {'loss': 2.1261294543743134, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004832500053453259, 'overlap rate': 0.48847754634916785}
#
# Current epoch: 15,
# training performance: {'loss': 0.9101232558488845, 'abosulate accuracy': 0.002900000102818012, 'consecutive overlap rate': 0.04922833419404924, 'overlap rate': 0.738411745429039}
# evaluation performance: {'loss': 1.7677786931395532, 'abosulate accuracy': 0.003950000158511102, 'consecutive overlap rate': 0.051340000703930855, 'overlap rate': 0.5890658892691135}
#
# Current epoch: 20,
# training performance: {'loss': 0.10070052929222584, 'abosulate accuracy': 0.6689000338315964, 'consecutive overlap rate': 0.8013233438134193, 'overlap rate': 0.9919133812189103}
# evaluation performance: {'loss': 0.14342390904203056, 'abosulate accuracy': 0.7131000310182571, 'consecutive overlap rate': 0.8391666755080223, 'overlap rate': 0.9802792191505432}
#
# Current epoch: 25,
# training performance: {'loss': 0.029853079514577986, 'abosulate accuracy': 0.957100048661232, 'consecutive overlap rate': 0.9788200095295906, 'overlap rate': 0.9992217287421227}
# evaluation performance: {'loss': 0.037415637215599415, 'abosulate accuracy': 0.9548000454902649, 'consecutive overlap rate': 0.9789058469235897, 'overlap rate': 0.9974029451608658}
#
# Current epoch: 30,
# training performance: {'loss': 0.014037322555668651, 'abosulate accuracy': 0.9907000347971916, 'consecutive overlap rate': 0.9957833394408226, 'overlap rate': 0.9998450621962547}
# evaluation performance: {'loss': 0.018980432185344398, 'abosulate accuracy': 0.9803500398993492, 'consecutive overlap rate': 0.9917771995067597, 'overlap rate': 0.998884166777134}
#
# Current epoch: 35,
# training performance: {'loss': 0.00805191237013787, 'abosulate accuracy': 0.9981000199913979, 'consecutive overlap rate': 0.9992500007152557, 'overlap rate': 0.9999683663249016}
# evaluation performance: {'loss': 0.010829833126626909, 'abosulate accuracy': 0.992000038176775, 'consecutive overlap rate': 0.9972333438694477, 'overlap rate': 0.999498387426138}
#
# Current epoch: 40,
# training performance: {'loss': 0.005187822366133332, 'abosulate accuracy': 0.9996000051498413, 'consecutive overlap rate': 0.9998633325099945, 'overlap rate': 0.9999933421611786}
# evaluation performance: {'loss': 0.006948265311075374, 'abosulate accuracy': 0.9948000341653824, 'consecutive overlap rate': 0.9981025069952011, 'overlap rate': 0.9996925465762615}
#
# Current epoch: 45,
# training performance: {'loss': 0.0035920253430958837, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.9998933330178261, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.00528942875971552, 'abosulate accuracy': 0.996200031042099, 'consecutive overlap rate': 0.9986858412623405, 'overlap rate': 0.9997425355017185}
#
# Experiments_Logs/Experiment#4/RNN/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.005908684391761199, 'abosulate accuracy': 0.9960500307381153, 'consecutive overlap rate': 0.9984902799129486, 'overlap rate': 0.9996403776109218}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 1.7259225298184901, 'abosulate accuracy': 0.6225000300677493, 'consecutive overlap rate': 0.6732256721472367, 'overlap rate': 0.7897587632760406}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.3003319317294704, 'abosulate accuracy': 0.409354474659889, 'consecutive overlap rate': 0.6068770185593636, 'overlap rate': 0.8027462859307566}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.074634223980339, 'abosulate accuracy': 0.09289474093575815, 'consecutive overlap rate': 0.19087387256226257, 'overlap rate': 0.3927602150330418}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.93070208132267, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014583333482732995, 'overlap rate': 0.4377950467169285}
# evaluation performance: {'loss': 2.9133635431528093, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016100000284495763, 'overlap rate': 0.42800754196941854}
#
# Current epoch: 10,
# training performance: {'loss': 1.6403401762247085, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003428333386546001, 'overlap rate': 0.5104300506412983}
# evaluation performance: {'loss': 2.1297329723834992, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004461666729184799, 'overlap rate': 0.47888005040585996}
#
# Current epoch: 15,
# training performance: {'loss': 0.9576827317476273, 'abosulate accuracy': 0.0037000001640990375, 'consecutive overlap rate': 0.042128333915025, 'overlap rate': 0.7190250769257546}
# evaluation performance: {'loss': 1.3771043673157692, 'abosulate accuracy': 0.003800000163028017, 'consecutive overlap rate': 0.051666667219251394, 'overlap rate': 0.5807683914899826}
#
# Current epoch: 20,
# training performance: {'loss': 0.1753396350890398, 'abosulate accuracy': 0.41470001712441446, 'consecutive overlap rate': 0.6035316720604896, 'overlap rate': 0.9761600658297539}
# evaluation performance: {'loss': 0.3203162007033825, 'abosulate accuracy': 0.4639000196009874, 'consecutive overlap rate': 0.6595616713166237, 'overlap rate': 0.9381367325782776}
#
# Current epoch: 25,
# training performance: {'loss': 0.03697788352146745, 'abosulate accuracy': 0.9273000374436379, 'consecutive overlap rate': 0.9652233466506004, 'overlap rate': 0.9986317306756973}
# evaluation performance: {'loss': 0.05890746302902698, 'abosulate accuracy': 0.9161500401794911, 'consecutive overlap rate': 0.9579075120389462, 'overlap rate': 0.993845059722662}
#
# Current epoch: 30,
# training performance: {'loss': 0.015375430206768214, 'abosulate accuracy': 0.9845000386238099, 'consecutive overlap rate': 0.9932416826486588, 'overlap rate': 0.9997317314147949}
# evaluation performance: {'loss': 0.025696607981808485, 'abosulate accuracy': 0.9721500471234321, 'consecutive overlap rate': 0.9888658449053764, 'overlap rate': 0.9978308960795402}
#
# Current epoch: 35,
# training performance: {'loss': 0.008267035521566869, 'abosulate accuracy': 0.9966000214219093, 'consecutive overlap rate': 0.998743337392807, 'overlap rate': 0.9999433681368828}
# evaluation performance: {'loss': 0.01383901724475436, 'abosulate accuracy': 0.9881500363349914, 'consecutive overlap rate': 0.9953425116837025, 'overlap rate': 0.9990400604903698}
#
# Current epoch: 40,
# training performance: {'loss': 0.005087374651338905, 'abosulate accuracy': 0.9989000141620636, 'consecutive overlap rate': 0.9994916677474975, 'overlap rate': 0.9999816909432411}
# evaluation performance: {'loss': 0.009289127076044679, 'abosulate accuracy': 0.9932000368833542, 'consecutive overlap rate': 0.997702506929636, 'overlap rate': 0.9993875563144684}
#
# Current epoch: 45,
# training performance: {'loss': 0.0034191675833426414, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.007231646648142487, 'abosulate accuracy': 0.9949500322341919, 'consecutive overlap rate': 0.9984141744673252, 'overlap rate': 0.9994850412011147}
#
# Experiments_Logs/Experiment#4/RNN/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/RNN/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.008263161637296434, 'abosulate accuracy': 0.9939750351011754, 'consecutive overlap rate': 0.9976116735488176, 'overlap rate': 0.9992862969636918}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.5386802745517343, 'abosulate accuracy': 0.7990000426769257, 'consecutive overlap rate': 0.8755608767271041, 'overlap rate': 0.9347337499260903}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.6955658297384937, 'abosulate accuracy': 0.4500770563079465, 'consecutive overlap rate': 0.6319038379576898, 'overlap rate': 0.769756995477984}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.7539865568672355, 'abosulate accuracy': 0.4107631786518093, 'consecutive overlap rate': 0.60874710271233, 'overlap rate': 0.7784323417826703}
# Experiments_Logs/Experiment#4/RNN/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#4 with RNN seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#4/RNN/hyperparameters.json saved!

# %%
from google.colab import runtime
runtime.unassign()
