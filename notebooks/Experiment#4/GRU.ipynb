# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 256
embd_dim = 128
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = False
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 4
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#4 created!
# ./Experiments_Logs/Experiment#4/GRU created!
# ./Experiments_Logs/Experiment#4/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#4/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#4/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#4 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014333333447575569, 'overlap rate': 0.564665062725544}
# evaluation performance: {'loss': 2.511867281794548, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01876916689798236, 'overlap rate': 0.48784255124628545}
#
# Current epoch: 60,
# training performance: {'loss': 0.14327998217195273, 'abosulate accuracy': 0.3316000115126371, 'consecutive overlap rate': 0.43189594000577924, 'overlap rate': 0.969129367172718}
# evaluation performance: {'loss': 0.8335167698562145, 'abosulate accuracy': 0.3694500159472227, 'consecutive overlap rate': 0.47200584001839163, 'overlap rate': 0.8467800691723824}
#
# Current epoch: 65,
# training performance: {'loss': 0.051600796077400445, 'abosulate accuracy': 0.7447000324726105, 'consecutive overlap rate': 0.7999616727232933, 'overlap rate': 0.9939517319202423}
# evaluation performance: {'loss': 0.2947640558704734, 'abosulate accuracy': 0.7335000284016132, 'consecutive overlap rate': 0.7916175112128258, 'overlap rate': 0.9520758830010891}
#
# Current epoch: 70,
# training performance: {'loss': 0.03001728281378746, 'abosulate accuracy': 0.8818000480532646, 'consecutive overlap rate': 0.9073616772890091, 'overlap rate': 0.9976450711488724}
# evaluation performance: {'loss': 0.1520211160182953, 'abosulate accuracy': 0.8641000419855118, 'consecutive overlap rate': 0.894297506660223, 'overlap rate': 0.9772183857858181}
#
# Current epoch: 75,
# training performance: {'loss': 1.25710405735299, 'abosulate accuracy': 0.4881000218796544, 'consecutive overlap rate': 0.49923834021028596, 'overlap rate': 0.7509683974087238}
# evaluation performance: {'loss': 4.386682188510894, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016291666899633129, 'overlap rate': 0.03813917059451342}
#
# Current epoch: 80,
# training performance: {'loss': 1.5632910788059236, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005235000076936558, 'overlap rate': 0.5340250551700592}
# evaluation performance: {'loss': 2.5702444940805433, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005571666746982373, 'overlap rate': 0.2593141933903098}
#
# Current epoch: 85,
# training performance: {'loss': 0.6227753147482872, 'abosulate accuracy': 0.0018000000738538802, 'consecutive overlap rate': 0.0214383335551247, 'overlap rate': 0.7904934182763099}
# evaluation performance: {'loss': 1.8068784713745116, 'abosulate accuracy': 0.002850000117905438, 'consecutive overlap rate': 0.026794167119078338, 'overlap rate': 0.5796933896839619}
#
# Current epoch: 90,
# training performance: {'loss': 1.702857208251953, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.009556666703429074, 'overlap rate': 0.5011317141354084}
# evaluation performance: {'loss': 2.4921399474143984, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.009392500133253634, 'overlap rate': 0.39840420745313165}
#
# Current epoch: 95,
# training performance: {'loss': 1.2358400613069533, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015240000118501485, 'overlap rate': 0.6054450541734695}
# evaluation performance: {'loss': 1.8243223160505295, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01615416689310223, 'overlap rate': 0.47558838203549386}
#
# Current epoch: 100,
# training performance: {'loss': 0.6329183384776116, 'abosulate accuracy': 0.005300000193528831, 'consecutive overlap rate': 0.03801166722550988, 'overlap rate': 0.7883667469024658}
# evaluation performance: {'loss': 1.6385766506195067, 'abosulate accuracy': 0.007700000266777351, 'consecutive overlap rate': 0.04312000072095543, 'overlap rate': 0.5837092280387879}
#
# Experiments_Logs/Experiment#4/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.04794931744690985, 'abosulate accuracy': 0.9308750446885824, 'consecutive overlap rate': 0.9414927858859301, 'overlap rate': 0.9938471913337708}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.314872455596924, 'abosulate accuracy': 0.05275000310502946, 'consecutive overlap rate': 0.08174662629608065, 'overlap rate': 0.2856991533190012}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.961246376652872, 'abosulate accuracy': 0.02823711386130702, 'consecutive overlap rate': 0.0313924936998275, 'overlap rate': 0.4331459927943445}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.949270731524417, 'abosulate accuracy': 0.004263158118670904, 'consecutive overlap rate': 0.0247548403843355, 'overlap rate': 0.11923717785822718}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.958451372385025, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007866666834161151, 'overlap rate': 0.4302133768796921}
# evaluation performance: {'loss': 4.16865571141243, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000709166681554052, 'overlap rate': 0.42962503992021084}
#
# Current epoch: 10,
# training performance: {'loss': 1.9049116373062134, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009416666929610073, 'overlap rate': 0.44606504291296006}
# evaluation performance: {'loss': 3.3418580144643784, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009825000182900113, 'overlap rate': 0.054664172464981675}
#
# Current epoch: 15,
# training performance: {'loss': 1.6772308051586151, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025816667184699327, 'overlap rate': 0.49246337711811067}
# evaluation performance: {'loss': 2.792856702208519, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002779166682739742, 'overlap rate': 0.45731421299278735}
#
# Current epoch: 20,
# training performance: {'loss': 0.6783735454082489, 'abosulate accuracy': 0.006300000217743218, 'consecutive overlap rate': 0.04690833380445838, 'overlap rate': 0.7731934055685997}
# evaluation performance: {'loss': 1.1488851830363274, 'abosulate accuracy': 0.011200000415556133, 'consecutive overlap rate': 0.06262000082060695, 'overlap rate': 0.6426900647580623}
#
# Current epoch: 25,
# training performance: {'loss': 0.26345000639557836, 'abosulate accuracy': 0.21230001114308833, 'consecutive overlap rate': 0.2910500030964613, 'overlap rate': 0.9370267480611801}
# evaluation performance: {'loss': 0.6486923448741436, 'abosulate accuracy': 0.25655001066625116, 'consecutive overlap rate': 0.34051750376820566, 'overlap rate': 0.8384783998131752}
#
# Current epoch: 30,
# training performance: {'loss': 0.0680699878372252, 'abosulate accuracy': 0.719900032877922, 'consecutive overlap rate': 0.7761183470487595, 'overlap rate': 0.9925083935260772}
# evaluation performance: {'loss': 0.15108677884563804, 'abosulate accuracy': 0.7399000354111195, 'consecutive overlap rate': 0.792859174311161, 'overlap rate': 0.9756158880889416}
#
# Current epoch: 35,
# training performance: {'loss': 0.027136583346873522, 'abosulate accuracy': 0.9358000427484512, 'consecutive overlap rate': 0.9471300095319748, 'overlap rate': 0.9986900627613068}
 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003281666722614318, 'overlap rate': 0.43563337847590444}
# evaluation performance: {'loss': 3.6775626212358477, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003084166721964721, 'overlap rate': 0.41890920884907246}
#
# Current epoch: 95,
# training performance: {'loss': 1.9474035203456879, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003383333358215168, 'overlap rate': 0.43837504684925077}
# evaluation performance: {'loss': 3.261954614520073, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003256666708330158, 'overlap rate': 0.4137817081063986}
#
# Current epoch: 100,
# training performance: {'loss': 1.9416626751422883, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0034816666739061475, 'overlap rate': 0.4407417096197605}
# evaluation performance: {'loss': 3.6385674685239793, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0034025000350084156, 'overlap rate': 0.42403837814927103}
#
# Experiments_Logs/Experiment#4/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.010739639980602077, 'abosulate accuracy': 0.9934500362724066, 'consecutive overlap rate': 0.9947220914065837, 'overlap rate': 0.9991783816367388}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 8.433895266242326, 'abosulate accuracy': 0.0451750027568778, 'consecutive overlap rate': 0.10091326711699367, 'overlap rate': 0.14147561602294445}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.94315220309842, 'abosulate accuracy': 0.15682785746551328, 'consecutive overlap rate': 0.16547169800727599, 'overlap rate': 0.48802349029048797}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 9.08238937352833, 'abosulate accuracy': 0.0006052632019609997, 'consecutive overlap rate': 0.060158331094211655, 'overlap rate': 0.11084217735027012}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.963685691356659, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008500000127241947, 'overlap rate': 0.4268267072737217}
# evaluation performance: {'loss': 3.242850598692894, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006891666838782839, 'overlap rate': 0.35975587032735346}
#
# Current epoch: 10,
# training performance: {'loss': 1.9292281180620194, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009000000136438757, 'overlap rate': 0.4432100422680378}
# evaluation performance: {'loss': 3.3499033361673356, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008850000212987652, 'overlap rate': 0.05022750529460609}
#
# Current epoch: 15,
# training performance: {'loss': 1.8010810792446137, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010033333543105981, 'overlap rate': 0.4651517137885094}
# evaluation performance: {'loss': 3.6375156819820402, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012327260104939342, 'overlap rate': 0.4034696012735367}
#
# Current epoch: 20,
# training performance: {'loss': 0.9977007538080216, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.009599999990314245, 'overlap rate': 0.6629550784826279}
# evaluation performance: {'loss': 1.7813281640410423, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013137500116135925, 'overlap rate': 0.5148817218840123}
#
# Current epoch: 25,
# training performance: {'loss': 0.7872544415295124, 'abosulate accuracy': 0.11250000478466973, 'consecutive overlap rate': 0.17894333628937603, 'overlap rate': 0.8181534081697464}
# evaluation performance: {'loss': 3.1300177782773972, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# evaluation performance: {'loss': 0.04888488283613697, 'abosulate accuracy': 0.9692500457167625, 'consecutive overlap rate': 0.9765200078487396, 'overlap rate': 0.9942367285490036}
#
# Current epoch: 80,
# training performance: {'loss': 0.008692659693770111, 'abosulate accuracy': 0.9913000360131263, 'consecutive overlap rate': 0.9934083461761475, 'overlap rate': 0.9998517364263535}
# evaluation performance: {'loss': 0.037750876811333, 'abosulate accuracy': 0.9797500416636467, 'consecutive overlap rate': 0.9845650114119053, 'overlap rate': 0.9956708885729313}
#
# Current epoch: 85,
# training performance: {'loss': 0.006427802913822234, 'abosulate accuracy': 0.9960000306367874, 'consecutive overlap rate': 0.9971366748213768, 'overlap rate': 0.9999317184090615}
# evaluation performance: {'loss': 0.03116308822063729, 'abosulate accuracy': 0.9838500410318375, 'consecutive overlap rate': 0.9878450103104115, 'overlap rate': 0.9964825555682182}
#
# Current epoch: 90,
# training performance: {'loss': 0.004939919710159302, 'abosulate accuracy': 0.9977000206708908, 'consecutive overlap rate': 0.998311671614647, 'overlap rate': 0.9999600321054458}
# evaluation performance: {'loss': 0.02667740307515487, 'abosulate accuracy': 0.9874000370502471, 'consecutive overlap rate': 0.9906108424067497, 'overlap rate': 0.9970300517976284}
#
# Current epoch: 95,
# training performance: {'loss': 0.00391889518359676, 'abosulate accuracy': 0.9990000128746033, 'consecutive overlap rate': 0.9992750018835068, 'overlap rate': 0.9999833554029465}
# evaluation performance: {'loss': 0.020753910182975233, 'abosulate accuracy': 0.9897000350058078, 'consecutive overlap rate': 0.9927216753363609, 'overlap rate': 0.99777921885252}
#
# Current epoch: 100,
# training performance: {'loss': 0.0031618620560038835, 'abosulate accuracy': 0.9995000064373016, 'consecutive overlap rate': 0.9996866673231125, 'overlap rate': 0.9999916777014732}
# evaluation performance: {'loss': 0.01840909729653504, 'abosulate accuracy': 0.9912500388920307, 'consecutive overlap rate': 0.9936141788959503, 'overlap rate': 0.9980483889579773}
#
# Experiments_Logs/Experiment#4/GRU/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.01857797611010028, 'abosulate accuracy': 0.9912000339478254, 'consecutive overlap rate': 0.9932783413678408, 'overlap rate': 0.9980533871799707}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.596764446049929, 'abosulate accuracy': 0.15007500745996366, 'consecutive overlap rate': 0.17915479158982633, 'overlap rate': 0.2979514027014375}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.150681511048348, 'abosulate accuracy': 0.2508453635438796, 'consecutive overlap rate': 0.25253061604115273, 'overlap rate': 0.5237259209156037}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 9.049089196481203, 'abosulate accuracy': 0.04160526506970391, 'consecutive overlap rate': 0.09634136388960637, 'overlap rate': 0.15354127838815512}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9721347212791442, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008000000161700882, 'overlap rate': 0.4270867079496384}
# evaluation performance: {'loss': 3.453089636564255, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010458333523274631, 'overlap rate': 0.33512336760759354}
#
# Current epoch: 10,
# training performance: {'loss': 1.9253470867872238, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001466666688793339, 'overlap rate': 0.4413817092776299}
# evaluation performance: {'loss': 3.659634867310524, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014358333559357562, 'overlap rate': 0.1728375183418393}
#
# Current epoch: 15,
# training performance: {'loss': 1.7904152363538741, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025816666893661022, 'overlap rate': 0.4708283819258213}
# evaluation performance: {'loss': 3.095842656493187, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003275833364750724, 'overlap rate': 0.1624466858804226}
#
# Current epoch: 20,
# training performance: {'loss': 0.5632946461439132, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.23034333530813456, 'overlap rate': 0.843135091662407}
# evaluation performance: {'loss': 1.0720767609775066, 'abosulate accuracy': 0.0018500000820495187, 'consecutive overlap rate': 0.2988975040614605, 'overlap rate': 0.7640325777232647}
#
# Current epoch: 25,
# training performance: {'loss': 1.3494671016931534, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06339000072330236, 'overlap rate': 0.6048134014010429}
# evaluation performance: {'loss': 3.270434620976448, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08260000087320804, 'overlap rate': 0.41540587805211543}
#
# Current epoch: 30,
# training performance: {'loss': 1.1633405029773711, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1182733342051506, 'overlap rate': 0.666326729953289}
# evaluation performance: {'loss': 3.2625944316387177, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07740741614252329, 'overlap rate': 0.3905249673873186}
#
# Current epoch: 35,
# training performance: {'loss': 1.1712131202220917, 'abosulate accuracy': 0.0024000001489184798, 'consecutive overlap rate': 0.13470000121742487, 'overlap rate': 0.663990068435669}
# evaluation performance: {'loss': 2.0193804442882537, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.1376408351585269, 'overlap rate': 0.5269400514662266}
#
# Current epoch: 40,
# training performance: {'loss': 1.099922390282154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.13706333544105292, 'overlap rate': 0.6758584097027779}
# evaluation performance: {'loss': 1.6968396663665772, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.20424583535641433, 'overlap rate': 0.6043800629675389}
#
# Current epoch: 45,
# training performance: {'loss': 0.08639209549874068, 'abosulate accuracy': 0.6440000355243682, 'consecutive overlap rate': 0.8502850130200386, 'overlap rate': 0.9881567224860192}
# evaluation performance: {'loss': 0.13178494973108174, 'abosulate accuracy': 0.711000033468008, 'consecutive overlap rate': 0.8921991780400276, 'overlap rate': 0.979046729952097}
#
# Current epoch: 50,
# training performance: {'loss': 0.02856650883331895, 'abosulate accuracy': 0.9168000429868698, 'consecutive overlap rate': 0.9747600063681603, 'overlap rate': 0.9982934132218361}
# evaluation performance: {'loss': 0.04352551333140582, 'abosulate accuracy': 0.9252500452101231, 'consecutive overlap rate': 0.9775833450257778, 'overlap rate': 0.9953742265701294}
#
# Current epoch: 55,
# training performance: {'loss': 0.014668514393270016, 'abosulate accuracy': 0.9789000391960144, 'consecutive overlap rate': 0.9942050129175186, 'overlap rate': 0.9996150627732276}
# evaluation performance: {'loss': 0.020739672193303704, 'abosulate accuracy': 0.9732500448822975, 'consecutive overlap rate': 0.9928850121796131, 'overlap rate': 0.9984558932483196}
#
# Current epoch: 60,
# training performance: {'loss': 0.009102911280933768, 'abosulate accuracy': 0.9928000375628472, 'consecutive overlap rate': 0.9979850128293037, 'overlap rate': 0.9998717293143272}
# evaluation performance: {'loss': 0.0144477152149193, 'abosulate accuracy': 0.9878000371158123, 'consecutive overlap rate': 0.9961683422327041, 'overlap rate': 0.9989600621163846}
#
# Current epoch: 65,
# training performance: {'loss': 0.006201666395645589, 'abosulate accuracy': 0.9970000237226486, 'consecutive overlap rate': 0.9990000039339065, 'overlap rate': 0.9999483734369278}
# evaluation performance: {'loss': 0.010475819045677782, 'abosulate accuracy': 0.9927000343799591, 'consecutive overlap rate': 0.9972666740417481, 'overlap rate': 0.9992633856832981}
#
# Current epoch: 70,
# training performance: {'loss': 0.004476298927329481, 'abosulate accuracy': 0.9993000075221061, 'consecutive overlap rate': 0.9997100010514259, 'overlap rate': 0.9999866783618927}
# evaluation performance: {'loss': 0.00745808583451435, 'abosulate accuracy': 0.9959000281989574, 'consecutive overlap rate': 0.9983525075018406, 'overlap rate': 0.9995267041027546}
#
# Current epoch: 75,
# training performance: {'loss': 0.003356928180437535, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.999975000321865, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.007058933534426615, 'abosulate accuracy': 0.9962500281631946, 'consecutive overlap rate': 0.9981025047600269, 'overlap rate': 0.999454203248024}
#
# Experiments_Logs/Experiment#4/GRU/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.004685405000054743, 'abosulate accuracy': 0.9976250227540732, 'consecutive overlap rate': 0.9990701109170914, 'overlap rate': 0.9997724581509828}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 9.722214133432136, 'abosulate accuracy': 0.14315000686328858, 'consecutive overlap rate': 0.2063256403311243, 'overlap rate': 0.231550030714061}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.5775031222451118, 'abosulate accuracy': 0.42465872245450176, 'consecutive overlap rate': 0.8079440847519905, 'overlap rate': 0.9430558954515765}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.298390427310216, 'abosulate accuracy': 0.056421055685189604, 'consecutive overlap rate': 0.4682783187959821, 'overlap rate': 0.48361222635599244}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.965333741903305, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000711666680581402, 'overlap rate': 0.42526171281933783}
# evaluation performance: {'loss': 3.0631000101566315, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006575000126758824, 'overlap rate': 0.35142086781561377}
#
# Current epoch: 10,
# training performance: {'loss': 1.9286253184080124, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001425734492659103, 'overlap rate': 0.4454647034406662}
# evaluation performance: {'loss': 2.935187950730324, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013587147172074766, 'overlap rate': 0.44196514301002027}
#
# Current epoch: 15,
# training performance: {'loss': 1.7911221027374267, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016450000315671788, 'overlap rate': 0.46954505145549774}
# evaluation performance: {'loss': 2.4137479931116106, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015300000297429506, 'overlap rate': 0.4584417134523392}
#
# Current epoch: 20,
# training performance: {'loss': 0.9999634847044945, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.013270000088959932, 'overlap rate': 0.6780667468905449}
# evaluation performance: {'loss': 1.2893219530582427, 'abosulate accuracy': 0.0014500000688713044, 'consecutive overlap rate': 0.026725000189617275, 'overlap rate': 0.6142167292535305}
#
# Current epoch: 25,
# training performance: {'loss': 0.21999926604330539, 'abosulate accuracy': 0.29520001374185084, 'consecutive overlap rate': 0.5093283392488956, 'overlap rate': 0.9534167528152466}
# evaluation performance: {'loss': 0.3271891061216593, 'abosulate accuracy': 0.38625001832842826, 'consecutive overlap rate': 0.6041416734457016, 'overlap rate': 0.9315142467617988}
#
# Current epoch: 30,
# training performance: {'loss': 0.03507657521404326, 'abosulate accuracy': 0.9279000431299209, 'consecutive overlap rate': 0.969473347067833, 'overlap rate': 0.9986017256975174}
# evaluation performance: {'loss': 0.04215422431007028, 'abosulate accuracy': 0.9291000425815582, 'consecutive overlap rate': 0.9733666770160199, 'overlap rate': 0.9968042314052582}
#
# Current epoch: 35,
# training performance: {'loss': 0.013751534558832646, 'abosulate accuracy': 0.9887000396847725, 'consecutive overlap rate': 0.9960633456707001, 'overlap rate': 0.999796737730503}
# evaluation performance: {'loss': 0.015821459400467575, 'abosulate accuracy': 0.9856500379741192, 'consecutive overlap rate': 0.9946525104343891, 'overlap rate': 0.9993500635027885}
#
# Current epoch: 40,
# training performance: {'loss': 0.007352555927354842, 'abosulate accuracy': 0.9975000232458114, 'consecutive overlap rate': 0.9991900026798248, 'overlap rate': 0.9999567046761513}
# evaluation performance: {'loss': 0.008850662829354405, 'abosulate accuracy': 0.9949000366032124, 'consecutive overlap rate': 0.9984441787004471, 'overlap rate': 0.9996967189013958}
#
# Current epoch: 45,
# training performance: {'loss': 0.004561745491810143, 'abosulate accuracy': 0.9993000090122223, 'consecutive overlap rate': 0.9998533353209496, 'overlap rate': 0.9999883487820626}
# evaluation performance: {'loss': 0.005474264107760973, 'abosulate accuracy': 0.996950026601553, 'consecutive overlap rate': 0.9990583389997483, 'overlap rate': 0.9998342044651508}
#
# Experiments_Logs/Experiment#4/GRU/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.004356989650113973, 'abosulate accuracy': 0.9979000210762023, 'consecutive overlap rate': 0.9991995882242918, 'overlap rate': 0.9998487774282694}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 7.384403835237026, 'abosulate accuracy': 0.10552500439516735, 'consecutive overlap rate': 0.12053997599286959, 'overlap rate': 0.17037338763475418}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.4017822819371377, 'abosulate accuracy': 0.0835119814642014, 'consecutive overlap rate': 0.5556682348251343, 'overlap rate': 0.9016587899577233}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.762274269504767, 'abosulate accuracy': 0.02355263291208662, 'consecutive overlap rate': 0.45409631518046617, 'overlap rate': 0.4774627033621073}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9638499081134797, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007683333482418675, 'overlap rate': 0.4252467110753059}
# evaluation performance: {'loss': 3.4192660212516786, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007383333475445397, 'overlap rate': 0.38627253845334053}
#
# Current epoch: 10,
# training performance: {'loss': 1.9267407655715942, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013733333587879315, 'overlap rate': 0.4465267151594162}
# evaluation performance: {'loss': 3.0819437474012377, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011825000248791185, 'overlap rate': 0.4464267138391733}
#
# Current epoch: 15,
# training performance: {'loss': 1.7655826091766358, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003006666703731753, 'overlap rate': 0.47756504714488984}
# evaluation performance: {'loss': 2.319901004433632, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038233333791140465, 'overlap rate': 0.45283171236515046}
#
# Current epoch: 20,
# training performance: {'loss': 0.8909836404025555, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.054782628058455886, 'overlap rate': 0.7527856066823005}
# evaluation performance: {'loss': 1.9156998738646507, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.09958508573472499, 'overlap rate': 0.5517271623015404}
#
# Current epoch: 25,
# training performance: {'loss': 0.119668223336339, 'abosulate accuracy': 0.08590000364929437, 'consecutive overlap rate': 0.5136416748166084, 'overlap rate': 0.9815167665481568}
# evaluation performance: {'loss': 0.7950584083795548, 'abosulate accuracy': 0.12000000374391676, 'consecutive overlap rate': 0.5296391725540162, 'overlap rate': 0.7771384082734585}
#
# Current epoch: 30,
# training performance: {'loss': 0.04907436762005091, 'abosulate accuracy': 0.44640002176165583, 'consecutive overlap rate': 0.69961167126894, 'overlap rate': 0.9904317319393158}
# evaluation performance: {'loss': 0.22732971012592315, 'abosulate accuracy': 0.46120001971721647, 'consecutive overlap rate': 0.7064212113618851, 'overlap rate': 0.937677787989378}
#
# Current epoch: 35,
# training performance: {'loss': 0.02913614073768258, 'abosulate accuracy': 0.759600031375885, 'consecutive overlap rate': 0.8552883431315422, 'overlap rate': 0.9958617210388183}
# evaluation performance: {'loss': 0.10665262639522552, 'abosulate accuracy': 0.7787500344216823, 'consecutive overlap rate': 0.8676358461380005, 'overlap rate': 0.9811283931136131}
#
# Current epoch: 40,
# training performance: {'loss': 0.01939206328243017, 'abosulate accuracy': 0.894000044465065, 'consecutive overlap rate': 0.9291033476591111, 'overlap rate': 0.9981700763106346}
# evaluation performance: {'loss': 0.07630648447666318, 'abosulate accuracy': 0.8560000456869602, 'consecutive overlap rate': 0.9061425097286702, 'overlap rate': 0.9895208843052388}
#
# Current epoch: 45,
# training performance: {'loss': 0.013875473104417325, 'abosulate accuracy': 0.941400046646595, 'consecutive overlap rate': 0.9573833480477333, 'overlap rate': 0.9989683941006661}
# evaluation performance: {'loss': 0.06675653851125389, 'abosulate accuracy': 0.9220000423491002, 'consecutive overlap rate': 0.9474816776812076, 'overlap rate': 0.993530061095953}
#
# Current epoch: 50,
# training performance: {'loss': 0.01021282181609422, 'abosulate accuracy': 0.961600050330162, 'consecutive overlap rate': 0.9689633458852768, 'overlap rate': 0.999325056374073}
# evaluation performance: {'loss': 0.05622772219358012, 'abosulate accuracy': 0.9433000467717647, 'consecutive overlap rate': 0.9597500130534172, 'overlap rate': 0.9952525608241558}
#
# Current epoch: 55,
# training performance: {'loss': 0.007857114530634136, 'abosulate accuracy': 0.970500048995018, 'consecutive overlap rate': 0.9740966796875, 'overlap rate': 0.9994933888316154}
# evaluation performance: {'loss': 0.05296075324295089, 'abosulate accuracy': 0.9549000464379788, 'consecutive overlap rate': 0.9661093197762967, 'overlap rate': 0.9953358814120292}
#
# Current epoch: 60,
# training performance: {'loss': 0.006144411966670304, 'abosulate accuracy': 0.974100048840046, 'consecutive overlap rate': 0.9759983390569686, 'overlap rate': 0.9995567247271537}
# evaluation performance: {'loss': 0.038473160145804285, 'abosulate accuracy': 0.9622500486671924, 'consecutive overlap rate': 0.9704941779375076, 'overlap rate': 0.9967208921909332}
#
# Current epoch: 65,
# training performance: {'loss': 0.004886829387396574, 'abosulate accuracy': 0.9755000472068787, 'consecutive overlap rate': 0.9764666795730591, 'overlap rate': 0.9995850652456284}
# evaluation performance: {'loss': 0.033389780484139917, 'abosulate accuracy': 0.9649000458419323, 'consecutive overlap rate': 0.9714776635169983, 'overlap rate': 0.997363344579935}
#
# Current epoch: 70,
# training performance: {'loss': 0.0038750964449718595, 'abosulate accuracy': 0.977000042796135, 'consecutive overlap rate': 0.977571678161621, 'overlap rate': 0.9996117323637008}
# evaluation performance: {'loss': 0.030431654024869203, 'abosulate accuracy': 0.9675000466406345, 'consecutive overlap rate': 0.9727783977985383, 'overlap rate': 0.9968323789536953}
#
# Current epoch: 75,
# training performance: {'loss': 0.003161250537959859, 'abosulate accuracy': 0.9773000434041024, 'consecutive overlap rate': 0.9775050133466721, 'overlap rate': 0.9996200710535049}
# evaluation performance: {'loss': 0.02631519893184304, 'abosulate accuracy': 0.9679500460624695, 'consecutive overlap rate': 0.9731741778552532, 'overlap rate': 0.997175894677639}
#
# Current epoch: 80,
# training performance: {'loss': 0.0026584578881738707, 'abosulate accuracy': 0.9775000408291816, 'consecutive overlap rate': 0.9777800142765045, 'overlap rate': 0.9996234148740768}
# evaluation performance: {'loss': 0.023067369213094935, 'abosulate accuracy': 0.970400047302246, 'consecutive overlap rate': 0.9741900086402893, 'overlap rate': 0.997671726346016}
#
# Current epoch: 85,
# training performance: {'loss': 0.002307167154503986, 'abosulate accuracy': 0.9780000403523446, 'consecutive overlap rate': 0.9780000135302543, 'overlap rate': 0.9996334031224251}
# evaluation performance: {'loss': 0.02016034695261624, 'abosulate accuracy': 0.9709000520408153, 'consecutive overlap rate': 0.9744741789996624, 'overlap rate': 0.9979567259550095}
#
# Current epoch: 90,
# training performance: {'loss': 2.094685637950897, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 1.6666666851961053e-06, 'overlap rate': 0.4087783724069595}
# evaluation performance: {'loss': 3.2373234063386915, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 1.0000000111176633e-05, 'overlap rate': 0.40848921053111553}
#
# Current epoch: 95,
# training performance: {'loss': 1.9658026218414306, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007833333474991377, 'overlap rate': 0.42961171120405195}
# evaluation performance: {'loss': 3.030233323574066, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007593785463541281, 'overlap rate': 0.42613175250589846}
#
# Current epoch: 100,
# training performance: {'loss': 1.9552092254161835, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008783333549217786, 'overlap rate': 0.4340133771300316}
# evaluation performance: {'loss': 2.7814648926258085, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008108333520794985, 'overlap rate': 0.42879837453365327}
#
# Experiments_Logs/Experiment#4/GRU/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/GRU/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.01912714291465818, 'abosulate accuracy': 0.9710750460624695, 'consecutive overlap rate': 0.9744787625968456, 'overlap rate': 0.9979729726910591}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 15.52242856770754, 'abosulate accuracy': 0.0027500001015141606, 'consecutive overlap rate': 0.004283917444990948, 'overlap rate': 0.08687455158215016}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.5660911675422422, 'abosulate accuracy': 0.3869360756489538, 'consecutive overlap rate': 0.7175047970587207, 'overlap rate': 0.8965778346984618}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 8.725488592135278, 'abosulate accuracy': 0.002657894884530259, 'consecutive overlap rate': 0.019326565333789115, 'overlap rate': 0.36963448976166546}
# Experiments_Logs/Experiment#4/GRU/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#4 with GRU seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
