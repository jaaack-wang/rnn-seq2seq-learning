# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 256
embd_dim = 128
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = False
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 4
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#4/LSTM created!
# ./Experiments_Logs/Experiment#4/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#4/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#4/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#4 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9894322127103805, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006983333492826205, 'overlap rate': 0.4188417077064514}
# evaluation performance: {'loss': 4.248453223705292, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006383898438798496, 'overlap rate': 0.3544693153351545}
#
# Current epoch: 10,
# training performance: {'loss': 1.9732223570346832, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000720282500697067, 'overlap rate': 0.4198817923665047}
# evaluation performance: {'loss': 3.4765762835741043, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006843079234386095, 'overlap rate': 0.023878265148960055}
#
# Current epoch: 15,
# training performance: {'loss': 1.966426634788513, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007283333485247568, 'overlap rate': 0.4264650456607342}
# evaluation performance: {'loss': 3.576758047938347, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007016666837444063, 'overlap rate': 0.030910003278404475}
#
# Current epoch: 20,
# training performance: {'loss': 1.9372890293598175, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008837570836476516, 'overlap rate': 0.4362360045313835}
# evaluation performance: {'loss': 3.0280461490154265, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008550000209652353, 'overlap rate': 0.3583325374871492}
#
# Current epoch: 25,
# training performance: {'loss': 1.8158665776252747, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001253333360364195, 'overlap rate': 0.46667504832148554}
# evaluation performance: {'loss': 2.635233986377716, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012741666894726222, 'overlap rate': 0.44735004641115667}
#
# Current epoch: 30,
# training performance: {'loss': 1.356289966404438, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012678333546500654, 'overlap rate': 0.6068434037268162}
# evaluation performance: {'loss': 4.083093419671059, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006789519853191451, 'overlap rate': 0.4419388588517904}
#
# Current epoch: 35,
# training performance: {'loss': 1.6456166744232177, 'abosulate accuracy': 0.0013000000733882188, 'consecutive overlap rate': 0.03035833383910358, 'overlap rate': 0.5861783877015114}
# evaluation performance: {'loss': 3.07040736079216, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02209750029724091, 'overlap rate': 0.47845087572932243}
#
# Current epoch: 40,
# training performance: {'loss': 0.2687166895717382, 'abosulate accuracy': 0.19020000901073217, 'consecutive overlap rate': 0.2789016716182232, 'overlap rate': 0.9468267470598221}
# evaluation performance: {'loss': 0.7029275976121425, 'abosulate accuracy': 0.25905001200735567, 'consecutive overlap rate': 0.34955583661794665, 'overlap rate': 0.8428192406892776}
#
# Current epoch: 45,
# training performance: {'loss': 1.8880637854337692, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.027100000251084565, 'overlap rate': 0.4750933863222599}
# evaluation performance: {'loss': 5.26747385263443, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.033515000552870336, 'overlap rate': 0.3851242050528526}
#
# Current epoch: 50,
# training performance: {'loss': 1.402899894118309, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03237000028602779, 'overlap rate': 0.5957417219877243}
# evaluation performance: {'loss': 2.0109317556023596, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03232187896501273, 'overlap rate': 0.4891845118254423}
#
# Current epoch: 55,
# training performance: {'loss': 1.028222906589508, 'abosulate accuracy': 0.002100000064820051, 'consecutive overlap rate': 0.041748334048315884, 'overlap rate': 0.713401734828949}
# evaluation performance: {'loss': 2.3464809745550155, 'abosulate accuracy': 0.004950000171083957, 'consecutive overlap rate': 0.05729583380743861, 'overlap rate': 0.537789223343134}
#
# Current epoch: 60,
# training performance: {'loss': 1.5004139229655267, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.024751666840165852, 'overlap rate': 0.6247000604867935}
# evaluation performance: {'loss': 3.8521885573863983, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0331241671461612, 'overlap rate': 0.4740292128175497}
#
# Current epoch: 65,
# training performance: {'loss': 1.0007986158132554, 'abosulate accuracy': 0.001500000071246177, 'consecutive overlap rate': 0.049455000553280115, 'overlap rate': 0.7362767457962036}
# evaluation performance: {'loss': 2.37220359146595, 'abosulate accuracy': 0.006150000251363963, 'consecutive overlap rate': 0.0700608337763697, 'overlap rate': 0.544226722419262}
#
# Current epoch: 70,
# training performance: {'loss': 0.44086150750517844, 'abosulate accuracy': 0.06370000317692756, 'consecutive overlap rate': 0.13190666791051625, 'overlap rate': 0.8917034283280373}
# evaluation performance: {'loss': 1.317110227048397, 'abosulate accuracy': 0.09720000438392162, 'consecutive overlap rate': 0.17051750235259533, 'overlap rate': 0.6759375654160976}
#
# Current epoch: 75,
# training performance: {'loss': 0.1514123674482107, 'abosulate accuracy': 0.41560002118349076, 'consecutive overlap rate': 0.5025883376598358, 'overlap rate': 0.9767384082078934}
# evaluation performance: {'loss': 0.6031816307455301, 'abosulate accuracy': 0.43260001949965954, 'consecutive overlap rate': 0.5189308356493711, 'overlap rate': 0.8799942344427109}
#
# Current epoch: 80,
# training performance: {'loss': 0.07605326883494853, 'abosulate accuracy': 0.6840000331401825, 'consecutive overlap rate': 0.7447716817259789, 'overlap rate': 0.9920583844184876}
# evaluation performance: {'loss': 0.25945733916014435, 'abosulate accuracy': 0.6932000294327736, 'consecutive overlap rate': 0.7513741753995419, 'overlap rate': 0.9564967274665832}
#
# Current epoch: 85,
# training performance: {'loss': 0.04508359860628843, 'abosulate accuracy': 0.8437000378966332, 'consecutive overlap rate': 0.876788341999054, 'overlap rate': 0.9968100741505623}
# evaluation performance: {'loss': 0.14758908431977033, 'abosulate accuracy': 0.8210500426590442, 'consecutive overlap rate': 0.8592566758394241, 'overlap rate': 0.9786675594747066}
#
# Current epoch: 90,
# training performance: {'loss': 0.029371386906132103, 'abosulate accuracy': 0.9193000420928001, 'consecutive overlap rate': 0.9361300110816956, 'overlap rate': 0.9984717339277267}
# evaluation performance: {'loss': 0.09318433082662522, 'abosulate accuracy': 0.8975500449538231, 'consecutive overlap rate': 0.9194658413529396, 'overlap rate': 0.987769217044115}
#
# Current epoch: 95,
# training performance: {'loss': 0.020449860161170362, 'abosulate accuracy': 0.9558000504970551, 'consecutive overlap rate': 0.965113340318203, 'overlap rate': 0.999206717312336}
# evaluation performance: {'loss': 0.06425998082850129, 'abosulate accuracy': 0.9367000445723533, 'consecutive overlap rate': 0.9510608419775963, 'overlap rate': 0.9920450575649739}
#
# Current epoch: 100,
# training performance: {'loss': 0.014895132486708462, 'abosulate accuracy': 0.9762000441551208, 'consecutive overlap rate': 0.9809433415532112, 'overlap rate': 0.9995900705456734}
# evaluation performance: {'loss': 0.05082294219173491, 'abosulate accuracy': 0.9572500467300415, 'consecutive overlap rate': 0.9675791770219803, 'overlap rate': 0.993873393535614}
#
# Experiments_Logs/Experiment#4/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.047541745100170375, 'abosulate accuracy': 0.9590750470757484, 'consecutive overlap rate': 0.9690187633037567, 'overlap rate': 0.9945425599813461}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.066772198677063, 'abosulate accuracy': 0.06800000362563878, 'consecutive overlap rate': 0.11728512090048752, 'overlap rate': 0.23406626638025047}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.279462909698486, 'abosulate accuracy': 0.2175798245976048, 'consecutive overlap rate': 0.22698554810016386, 'overlap rate': 0.5284852562412139}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 7.752920189970418, 'abosulate accuracy': 0.021263158662661322, 'consecutive overlap rate': 0.09119864901233661, 'overlap rate': 0.18066850304603577}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9833207696676254, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006133333488833159, 'overlap rate': 0.42170670703053476}
# evaluation performance: {'loss': 3.263038086891174, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006685028396532289, 'overlap rate': 0.08884503804147244}
#
# Current epoch: 10,
# training performance: {'loss': 1.9892215996980667, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007516666897572577, 'overlap rate': 0.41870337575674055}
# evaluation performance: {'loss': 3.6618193715810774, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007083333475748077, 'overlap rate': 0.025565836136229335}
#
# Current epoch: 15,
# training performance: {'loss': 1.9445294320583344, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007250000118801836, 'overlap rate': 0.43166838139295577}
# evaluation performance: {'loss': 3.7865078926086424, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006541666778502985, 'overlap rate': 0.08139584185555578}
#
# Current epoch: 20,
# training performance: {'loss': 1.9302129715681076, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008416666845732834, 'overlap rate': 0.4358400471508503}
# evaluation performance: {'loss': 3.536975401639938, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007350000149017432, 'overlap rate': 0.26808336153626444}
#
# Current epoch: 25,
# training performance: {'loss': 1.4741455167531967, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0027333333564456552, 'overlap rate': 0.5504800572991371}
# evaluation performance: {'loss': 2.1197340220212935, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0030758333785342986, 'overlap rate': 0.49523754604160786}
#
# Current epoch: 30,
# training performance: {'loss': 1.0201421514153481, 'abosulate accuracy': 0.0005000000121071935, 'consecutive overlap rate': 0.015986666770186276, 'overlap rate': 0.7039150804281235}
# evaluation performance: {'loss': 1.4777062833309174, 'abosulate accuracy': 0.0004500000213738531, 'consecutive overlap rate': 0.02150250026024878, 'overlap rate': 0.5860592275857925}
#
# Current epoch: 35,
# training performance: {'loss': 0.2158668886870146, 'abosulate accuracy': 0.2324000108987093, 'consecutive overlap rate': 0.3574016701430082, 'overlap rate': 0.9674067303538323}
# evaluation performance: {'loss': 0.432038876414299, 'abosulate accuracy': 0.3262000162154436, 'consecutive overlap rate': 0.4575916726142168, 'overlap rate': 0.9103159137070179}
#
# Current epoch: 40,
# training performance: {'loss': 0.48589969277381895, 'abosulate accuracy': 0.03390000166837126, 'consecutive overlap rate': 0.09683333449065686, 'overlap rate': 0.8708084225654602}
# evaluation performance: {'loss': 0.9892578326165676, 'abosulate accuracy': 0.09460000377148389, 'consecutive overlap rate': 0.17960500195622445, 'overlap rate': 0.7629217423498631}
#
# Current epoch: 45,
# training performance: {'loss': 0.09903763495385647, 'abosulate accuracy': 0.6721000328660012, 'consecutive overlap rate': 0.7473750114440918, 'overlap rate': 0.9918167144060135}
# evaluation performance: {'loss': 0.21823062989860773, 'abosulate accuracy': 0.7054500296711922, 'consecutive overlap rate': 0.7734408430755139, 'overlap rate': 0.965663394331932}
#
# Current epoch: 50,
# training performance: {'loss': 0.037406299542635676, 'abosulate accuracy': 0.927000044286251, 'consecutive overlap rate': 0.9450133472681046, 'overlap rate': 0.9986434057354927}
# evaluation performance: {'loss': 0.07602895190939307, 'abosulate accuracy': 0.915300040692091, 'consecutive overlap rate': 0.9351620554924012, 'overlap rate': 0.9914434380829334}
#
# Current epoch: 55,
# training performance: {'loss': 0.02045817202888429, 'abosulate accuracy': 0.9746000424027443, 'consecutive overlap rate': 0.9810850113630295, 'overlap rate': 0.9995533987879753}
# evaluation performance: {'loss': 0.03986462361644953, 'abosulate accuracy': 0.9620500452816486, 'consecutive overlap rate': 0.9714350081980229, 'overlap rate': 0.9964100703597069}
#
# Current epoch: 60,
# training performance: {'loss': 0.013003206555731594, 'abosulate accuracy': 0.9895000368356704, 'consecutive overlap rate': 0.9919900059700012, 'overlap rate': 0.999816732108593}
# evaluation performance: {'loss': 0.02574281960260123, 'abosulate accuracy': 0.979250044375658, 'consecutive overlap rate': 0.9846358440816403, 'overlap rate': 0.9978492230176925}
#
# Current epoch: 65,
# training performance: {'loss': 0.008941359841264785, 'abosulate accuracy': 0.9957000374794006, 'consecutive overlap rate': 0.9965383410453796, 'overlap rate': 0.9999267265200615}
# evaluation performance: {'loss': 0.02174702255288139, 'abosulate accuracy': 0.9855000391602516, 'consecutive overlap rate': 0.9890925139188766, 'overlap rate': 0.9980917252600193}
#
# Current epoch: 70,
# training performance: {'loss': 0.006507338723167777, 'abosulate accuracy': 0.9985000163316726, 'consecutive overlap rate': 0.9987950041890145, 'overlap rate': 0.9999733611941337}
# evaluation performance: {'loss': 0.016654339322121813, 'abosulate accuracy': 0.9890000365674496, 'consecutive overlap rate': 0.9914916753768921, 'overlap rate': 0.9985808901488781}
#
# Current epoch: 75,
# training performance: {'loss': 0.004916832817252725, 'abosulate accuracy': 0.9995000064373016, 'consecutive overlap rate': 0.9995550006628037, 'overlap rate': 0.9999916777014732}
# evaluation performance: {'loss': 0.013444359571440145, 'abosulate accuracy': 0.9920000344514847, 'consecutive overlap rate': 0.9940125100314617, 'overlap rate': 0.9988592185080052}
#
# Current epoch: 80,
# training performance: {'loss': 0.0038194112828932704, 'abosulate accuracy': 0.9999000012874604, 'consecutive overlap rate': 0.9999433338642121, 'overlap rate': 0.9999983355402946}
# evaluation performance: {'loss': 0.011991966381901874, 'abosulate accuracy': 0.992850037664175, 'consecutive overlap rate': 0.994589177519083, 'overlap rate': 0.9989642165601254}
#
# Current epoch: 85,
# training performance: {'loss': 0.0030302752216812222, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.01062404935946688, 'abosulate accuracy': 0.9936000354588032, 'consecutive overlap rate': 0.9951575085520744, 'overlap rate': 0.9990608811378479}
#
# Current epoch: 90,
# training performance: {'loss': 0.0024455756996758283, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.008858200564282015, 'abosulate accuracy': 0.9941500350832939, 'consecutive overlap rate': 0.9956850066781044, 'overlap rate': 0.9992008805274963}
#
# Current epoch: 95,
# training performance: {'loss': 0.0020132676407229157, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 0.009071842845878563, 'abosulate accuracy': 0.9947500295937062, 'consecutive overlap rate': 0.9960883416235446, 'overlap rate': 0.9991608746349812}
#
# Experiments_Logs/Experiment#4/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.008185189775394975, 'abosulate accuracy': 0.9950000334531068, 'consecutive overlap rate': 0.9963158443570137, 'overlap rate': 0.9992321271449327}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 7.4902469089254735, 'abosulate accuracy': 0.1299750061618397, 'consecutive overlap rate': 0.16906133152078837, 'overlap rate': 0.276385354436934}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.364197850996448, 'abosulate accuracy': 0.23021885387359126, 'consecutive overlap rate': 0.23308265439925654, 'overlap rate': 0.4944667389315944}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 7.607757257787805, 'abosulate accuracy': 0.13300000571057594, 'consecutive overlap rate': 0.217569846120712, 'overlap rate': 0.2722039509956774}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.986068531870842, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006533333453262458, 'overlap rate': 0.41838004291057584}
# evaluation performance: {'loss': 4.654919505119324, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006408333509170915, 'overlap rate': 0.3739275369793177}
#
# Current epoch: 10,
# training performance: {'loss': 1.9410213261842728, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333546284121, 'overlap rate': 0.4286500416696072}
# evaluation performance: {'loss': 3.099689093232155, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006916666832694318, 'overlap rate': 0.428906711563468}
#
# Current epoch: 15,
# training performance: {'loss': 1.9807970136404038, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007566666798084043, 'overlap rate': 0.42198837697505953}
# evaluation performance: {'loss': 3.4075368463993074, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006791666808567242, 'overlap rate': 0.39318587370216845}
#
# Current epoch: 20,
# training performance: {'loss': 1.9549819201231002, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008166666841134429, 'overlap rate': 0.4305983766913414}
# evaluation performance: {'loss': 2.6765744417905806, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007168361706135328, 'overlap rate': 0.35204749256372453}
#
# Current epoch: 25,
# training performance: {'loss': 1.941687536239624, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008000000190804713, 'overlap rate': 0.4339033767580986}
# evaluation performance: {'loss': 2.820063331723213, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007308333504624897, 'overlap rate': 0.4313042122870684}
#
# Current epoch: 30,
# training performance: {'loss': 1.8458607375621796, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010205932456301525, 'overlap rate': 0.4599323093891144}
# evaluation performance: {'loss': 2.170104031264782, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010041666912002257, 'overlap rate': 0.39729337505996226}
#
# Current epoch: 35,
# training performance: {'loss': 1.69234718978405, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001733333372976631, 'overlap rate': 0.49807005003094673}
# evaluation performance: {'loss': 2.6276386827230453, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021216666893451473, 'overlap rate': 0.44938087910413743}
#
# Current epoch: 40,
# training performance: {'loss': 1.2205098092556, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0160700001521036, 'overlap rate': 0.6276633992791176}
# evaluation performance: {'loss': 3.2876631766557693, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025195833668112753, 'overlap rate': 0.48587338142097}
#
# Current epoch: 45,
# training performance: {'loss': 0.6882733121514321, 'abosulate accuracy': 0.004300000134389847, 'consecutive overlap rate': 0.05252666771411896, 'overlap rate': 0.7886434018611908}
# evaluation performance: {'loss': 1.6979901686310768, 'abosulate accuracy': 0.008350000315112993, 'consecutive overlap rate': 0.07085833437740803, 'overlap rate': 0.5676892161369324}
#
# Current epoch: 50,
# training performance: {'loss': 1.577939236164093, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.040408333763480186, 'overlap rate': 0.585760061442852}
# evaluation performance: {'loss': 1.9838573932647705, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04995833393186331, 'overlap rate': 0.52497255243361}
#
# Current epoch: 55,
# training performance: {'loss': 0.24655597805976867, 'abosulate accuracy': 0.2806000135838985, 'consecutive overlap rate': 0.3730650044977665, 'overlap rate': 0.9569167420268059}
# evaluation performance: {'loss': 0.5493304520845413, 'abosulate accuracy': 0.35775001719594, 'consecutive overlap rate': 0.45449833795428274, 'overlap rate': 0.8851725772023201}
#
# Current epoch: 60,
# training performance: {'loss': 0.06789691783487797, 'abosulate accuracy': 0.7970000326633453, 'consecutive overlap rate': 0.8364066779613495, 'overlap rate': 0.9954134106636048}
# evaluation performance: {'loss': 0.12960301460698248, 'abosulate accuracy': 0.7891500391066074, 'consecutive overlap rate': 0.8304800085723401, 'overlap rate': 0.9830583974719047}
#
# Current epoch: 65,
# training performance: {'loss': 0.033454678719863296, 'abosulate accuracy': 0.9330000504851341, 'consecutive overlap rate': 0.9453033462166787, 'overlap rate': 0.9987500667572021}
# evaluation performance: {'loss': 0.05614586235024035, 'abosulate accuracy': 0.9232500456273556, 'consecutive overlap rate': 0.9383622854948044, 'overlap rate': 0.994725764542818}
#
# Current epoch: 70,
# training performance: {'loss': 0.019924540538340807, 'abosulate accuracy': 0.9769000440835953, 'consecutive overlap rate': 0.9802016749978065, 'overlap rate': 0.9995917350053787}
# evaluation performance: {'loss': 0.032316715572960675, 'abosulate accuracy': 0.9641500465571881, 'consecutive overlap rate': 0.9717633463442326, 'overlap rate': 0.9974875703454018}
#
# Current epoch: 75,
# training performance: {'loss': 0.013096876651979983, 'abosulate accuracy': 0.9913000345230103, 'consecutive overlap rate': 0.9923933401703835, 'overlap rate': 0.9998550608754158}
# evaluation performance: {'loss': 0.02070960986893624, 'abosulate accuracy': 0.981350039690733, 'consecutive overlap rate': 0.984977513551712, 'overlap rate': 0.9986467286944389}
#
# Current epoch: 80,
# training performance: {'loss': 0.009197623748332263, 'abosulate accuracy': 0.9971000298857688, 'consecutive overlap rate': 0.9974100053310394, 'overlap rate': 0.9999517172574997}
# evaluation performance: {'loss': 0.015553151874337345, 'abosulate accuracy': 0.9872000344097615, 'consecutive overlap rate': 0.9902776218950748, 'overlap rate': 0.9990116909146309}
#
# Current epoch: 85,
# training performance: {'loss': 0.006752893421798944, 'abosulate accuracy': 0.998700013756752, 'consecutive overlap rate': 0.9988500013947487, 'overlap rate': 0.9999783560633659}
# evaluation performance: {'loss': 0.01095798786263913, 'abosulate accuracy': 0.9921000368893147, 'consecutive overlap rate': 0.9940066814422608, 'overlap rate': 0.9993767231702805}
#
# Current epoch: 90,
# training performance: {'loss': 0.00512350257486105, 'abosulate accuracy': 0.9995000064373016, 'consecutive overlap rate': 0.9995683342218399, 'overlap rate': 0.9999916777014732}
# evaluation performance: {'loss': 0.008693729451624676, 'abosulate accuracy': 0.9946500286459923, 'consecutive overlap rate': 0.9960358388721943, 'overlap rate': 0.9995008774101735}
#
# Current epoch: 95,
# training performance: {'loss': 0.00398725041304715, 'abosulate accuracy': 0.999700003862381, 'consecutive overlap rate': 0.9997116670012474, 'overlap rate': 0.9999950066208839}
# evaluation performance: {'loss': 0.006869573361473158, 'abosulate accuracy': 0.9958000347018242, 'consecutive overlap rate': 0.9970400094985962, 'overlap rate': 0.9996242120862007}
#
# Experiments_Logs/Experiment#4/LSTM/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.007025954473647289, 'abosulate accuracy': 0.9956250332295895, 'consecutive overlap rate': 0.9968420911580325, 'overlap rate': 0.9995387922972441}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 5.108000640291721, 'abosulate accuracy': 0.2853000115894247, 'consecutive overlap rate': 0.37859248016029595, 'overlap rate': 0.46513331644237044}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.3406203946759625, 'abosulate accuracy': 0.3209982898927504, 'consecutive overlap rate': 0.3234098732471466, 'overlap rate': 0.5491297077748083}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 7.146920935495904, 'abosulate accuracy': 0.13044737492638983, 'consecutive overlap rate': 0.21254317986925966, 'overlap rate': 0.3082256608299519}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9998878061771392, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006933333483175374, 'overlap rate': 0.4174367092549801}
# evaluation performance: {'loss': 7.245730799436569, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006550000145580271, 'overlap rate': 0.4127217117697001}
#
# Current epoch: 10,
# training performance: {'loss': 1.9769854366779327, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007700000212935265, 'overlap rate': 0.42106171399354936}
# evaluation performance: {'loss': 3.541627037525177, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333486964693, 'overlap rate': 0.02514583608135581}
#
# Current epoch: 15,
# training performance: {'loss': 1.954395368695259, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000771666687069228, 'overlap rate': 0.4275317095220089}
# evaluation performance: {'loss': 2.637487843632698, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000646751426938863, 'overlap rate': 0.3939186416566372}
#
# Current epoch: 20,
# training performance: {'loss': 1.9354304552078248, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008700000173121226, 'overlap rate': 0.43519004061818123}
# evaluation performance: {'loss': 3.444127556681633, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008550000165996607, 'overlap rate': 0.2724866934120655}
#
# Current epoch: 25,
# training performance: {'loss': 1.4149171859025955, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003281666699331254, 'overlap rate': 0.580151729285717}
# evaluation performance: {'loss': 2.810121589899063, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038291667238809167, 'overlap rate': 0.49364338368177413}
#
# Current epoch: 30,
# training performance: {'loss': 1.0838796123862267, 'abosulate accuracy': 0.0007000000332482159, 'consecutive overlap rate': 0.02783333375118673, 'overlap rate': 0.7005500748753548}
# evaluation performance: {'loss': 2.4336996376514435, 'abosulate accuracy': 0.012450000422541052, 'consecutive overlap rate': 0.05517250066623092, 'overlap rate': 0.626133394241333}
#
# Current epoch: 35,
# training performance: {'loss': 0.07960795089602471, 'abosulate accuracy': 0.8637000441551208, 'consecutive overlap rate': 0.9466207146644592, 'overlap rate': 0.9970410123467446}
# evaluation performance: {'loss': 0.08245097920298576, 'abosulate accuracy': 0.8934000454843044, 'consecutive overlap rate': 0.9620433419942855, 'overlap rate': 0.9942292273044586}
#
# Current epoch: 40,
# training performance: {'loss': 0.020491795754060148, 'abosulate accuracy': 0.9920000359416008, 'consecutive overlap rate': 0.9978516742587089, 'overlap rate': 0.9998633980751037}
# evaluation performance: {'loss': 0.021300733438692987, 'abosulate accuracy': 0.9865000382065773, 'consecutive overlap rate': 0.9966373138129712, 'overlap rate': 0.9993391387164593}
#
# Current epoch: 45,
# training performance: {'loss': 0.009150492842309177, 'abosulate accuracy': 0.9991000100970269, 'consecutive overlap rate': 0.999880000948906, 'overlap rate': 0.9999850168824196}
# evaluation performance: {'loss': 0.00996388893108815, 'abosulate accuracy': 0.9952500306069851, 'consecutive overlap rate': 0.9989566713571548, 'overlap rate': 0.9997792139649391}
#
# Current epoch: 50,
# training performance: {'loss': 0.00515589821152389, 'abosulate accuracy': 0.9997000023722649, 'consecutive overlap rate': 0.9998517796397209, 'overlap rate': 0.9999949738383294}
# evaluation performance: {'loss': 0.005880072683794424, 'abosulate accuracy': 0.9980500183999539, 'consecutive overlap rate': 0.999377503246069, 'overlap rate': 0.9998891890048981}
#
# Experiments_Logs/Experiment#4/LSTM/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.006227271314128302, 'abosulate accuracy': 0.998325015604496, 'consecutive overlap rate': 0.999608751758933, 'overlap rate': 0.9998883526772261}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 7.884678648342378, 'abosulate accuracy': 0.2081250104587525, 'consecutive overlap rate': 0.24652199004813155, 'overlap rate': 0.3050941020203027}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.6552737993578757, 'abosulate accuracy': 0.4556867664860141, 'consecutive overlap rate': 0.7935021292778753, 'overlap rate': 0.932416812450655}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.315765105383961, 'abosulate accuracy': 0.05057895046009339, 'consecutive overlap rate': 0.45680689853064615, 'overlap rate': 0.48864703870525483}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9709156602621078, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007283333558007144, 'overlap rate': 0.4219233736395836}
# evaluation performance: {'loss': 3.7178015768527986, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006941666830243776, 'overlap rate': 0.39273920729756356}
#
# Current epoch: 10,
# training performance: {'loss': 1.966360977292061, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006816666791564785, 'overlap rate': 0.4219750389456749}
# evaluation performance: {'loss': 3.3286687403917314, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333480800502, 'overlap rate': 0.3506017025560141}
#
# Current epoch: 15,
# training performance: {'loss': 1.9707278788089753, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00074333335069241, 'overlap rate': 0.42307170778512954}
# evaluation performance: {'loss': 3.4399383902549743, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007575000152428401, 'overlap rate': 0.02706166945863515}
#
# Current epoch: 20,
# training performance: {'loss': 1.9304321616888047, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009850000227743295, 'overlap rate': 0.43658171147108077}
# evaluation performance: {'loss': 2.5185375928878786, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008783333494648104, 'overlap rate': 0.42118920795619486}
#
# Current epoch: 25,
# training performance: {'loss': 1.883406114578247, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001261666689242702, 'overlap rate': 0.4502917148172855}
# evaluation performance: {'loss': 2.8987026125192643, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012008333556877914, 'overlap rate': 0.26522169578820465}
#
# Current epoch: 30,
# training performance: {'loss': 1.7845515310764313, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001576666698383633, 'overlap rate': 0.47451171800494196}
# evaluation performance: {'loss': 2.1163305595517157, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015233333651849534, 'overlap rate': 0.449410879611969}
#
# Current epoch: 35,
# training performance: {'loss': 1.4888928830623627, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029616667132359, 'overlap rate': 0.5465450540184975}
# evaluation performance: {'loss': 2.5030244529247283, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003217500032042153, 'overlap rate': 0.46074921675026415}
#
# Current epoch: 40,
# training performance: {'loss': 1.0408841654658318, 'abosulate accuracy': 0.0009000000427477062, 'consecutive overlap rate': 0.0170400001690723, 'overlap rate': 0.697805079817772}
# evaluation performance: {'loss': 1.5122682467103004, 'abosulate accuracy': 0.0026000001060310753, 'consecutive overlap rate': 0.02335250029573217, 'overlap rate': 0.5836658932268619}
#
# Current epoch: 45,
# training performance: {'loss': 1.0412403061985969, 'abosulate accuracy': 0.004900000244379044, 'consecutive overlap rate': 0.04235666710883379, 'overlap rate': 0.7094834133982658}
# evaluation performance: {'loss': 2.2634838983416556, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.04352750023826957, 'overlap rate': 0.6075742311775685}
#
# Current epoch: 50,
# training performance: {'loss': 0.216462716832757, 'abosulate accuracy': 0.32270001247525215, 'consecutive overlap rate': 0.4256800010800362, 'overlap rate': 0.9646167472004891}
# evaluation performance: {'loss': 2.4418951839208605, 'abosulate accuracy': 0.23505000974982976, 'consecutive overlap rate': 0.39066917076706886, 'overlap rate': 0.7096700571477413}
#
# Current epoch: 55,
# training performance: {'loss': 0.9060715675354004, 'abosulate accuracy': 0.06880000295350328, 'consecutive overlap rate': 0.18592333691194654, 'overlap rate': 0.7576000675559044}
# evaluation performance: {'loss': 1.7860697299242019, 'abosulate accuracy': 0.05035000261850655, 'consecutive overlap rate': 0.22025166936218737, 'overlap rate': 0.6261533923447132}
#
# Current epoch: 60,
# training performance: {'loss': 0.09791618455201387, 'abosulate accuracy': 0.7300000369548798, 'consecutive overlap rate': 0.8805300086736679, 'overlap rate': 0.9923533901572228}
# evaluation performance: {'loss': 0.12531344061717392, 'abosulate accuracy': 0.797350037097931, 'consecutive overlap rate': 0.9190995752811432, 'overlap rate': 0.9867482997477055}
#
# Current epoch: 65,
# training performance: {'loss': 0.034804545296356085, 'abosulate accuracy': 0.9560000464320183, 'consecutive overlap rate': 0.9880700126290322, 'overlap rate': 0.9991650596261025}
# evaluation performance: {'loss': 0.03934918916784227, 'abosulate accuracy': 0.9557000458240509, 'consecutive overlap rate': 0.9887100107967853, 'overlap rate': 0.9980209030210971}
#
# Current epoch: 70,
# training performance: {'loss': 0.018667125469073655, 'abosulate accuracy': 0.9874000385403633, 'consecutive overlap rate': 0.9975700050592422, 'overlap rate': 0.9997817441821099}
# evaluation performance: {'loss': 0.020511346263810994, 'abosulate accuracy': 0.9853000335395337, 'consecutive overlap rate': 0.9972050122916698, 'overlap rate': 0.9993883959949017}
#
# Current epoch: 75,
# training performance: {'loss': 0.011631758185103536, 'abosulate accuracy': 0.9964000269770622, 'consecutive overlap rate': 0.9995283409953117, 'overlap rate': 0.999938377737999}
# evaluation performance: {'loss': 0.013918046618346124, 'abosulate accuracy': 0.9872500382363796, 'consecutive overlap rate': 0.9979475073516368, 'overlap rate': 0.9994550600647927}
#
# Current epoch: 80,
# training performance: {'loss': 0.007897080131806433, 'abosulate accuracy': 0.9986000165343285, 'consecutive overlap rate': 0.9999131679534912, 'overlap rate': 0.9999766647815704}
# evaluation performance: {'loss': 0.008711104473331944, 'abosulate accuracy': 0.9950500316917896, 'consecutive overlap rate': 0.9992308408021927, 'overlap rate': 0.9998150438070297}
#
# Current epoch: 85,
# training performance: {'loss': 0.005648935807403177, 'abosulate accuracy': 0.9996000051498413, 'consecutive overlap rate': 0.9999783352017403, 'overlap rate': 0.9999933421611786}
# evaluation performance: {'loss': 0.006205300911096856, 'abosulate accuracy': 0.9970000244677066, 'consecutive overlap rate': 0.9994941718876362, 'overlap rate': 0.9998883664608001}
#
# Experiments_Logs/Experiment#4/LSTM/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.005107118745218031, 'abosulate accuracy': 0.9981500174850225, 'consecutive overlap rate': 0.9997245866805315, 'overlap rate': 0.9999350216239691}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 8.263567984895781, 'abosulate accuracy': 0.11315000489121303, 'consecutive overlap rate': 0.1402702470222721, 'overlap rate': 0.18673725086264312}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.0323975439994566, 'abosulate accuracy': 0.5246035348984504, 'consecutive overlap rate': 0.6318492616376569, 'overlap rate': 0.6922820002801957}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.834033070622306, 'abosulate accuracy': 0.03918421219139801, 'consecutive overlap rate': 0.2545739389177853, 'overlap rate': 0.289242514016989}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9739062905311584, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007050000160234049, 'overlap rate': 0.4198217146098614}
# evaluation performance: {'loss': 3.429128512740135, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006383333483427122, 'overlap rate': 0.42182421050965785}
#
# Current epoch: 10,
# training performance: {'loss': 1.9715529352426528, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007650000203284435, 'overlap rate': 0.41840004473924636}
# evaluation performance: {'loss': 5.937404268980027, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333508792566, 'overlap rate': 0.4079900402575731}
#
# Current epoch: 15,
# training performance: {'loss': 1.9409054696559906, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007533333504397888, 'overlap rate': 0.43190004080533984}
# evaluation performance: {'loss': 4.0833265542984005, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006483333490905352, 'overlap rate': 0.034160003811120984}
#
# Current epoch: 20,
# training performance: {'loss': 1.9460944473743438, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007850000183680095, 'overlap rate': 0.43127171248197554}
# evaluation performance: {'loss': 2.491098481416702, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007375000197498594, 'overlap rate': 0.35968920327723025}
#
# Current epoch: 25,
# training performance: {'loss': 1.9493681997060777, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010333333593735006, 'overlap rate': 0.4322800412774086}
# evaluation performance: {'loss': 3.628583177924156, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009441666883503785, 'overlap rate': 0.31365836337208747}
#
# Current epoch: 30,
# training performance: {'loss': 1.7129939764738082, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015983333592885173, 'overlap rate': 0.49617171958088874}
# evaluation performance: {'loss': 2.6925843119621278, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016358333581592889, 'overlap rate': 0.46911087818443775}
#
# Current epoch: 35,
# training performance: {'loss': 1.0527981400489808, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.00951000009663403, 'overlap rate': 0.6902150765061379}
# evaluation performance: {'loss': 1.6455740600824356, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.012323573604226113, 'overlap rate': 0.5018073253333568}
#
# Current epoch: 40,
# training performance: {'loss': 1.0517239838838577, 'abosulate accuracy': 0.009300000441726297, 'consecutive overlap rate': 0.1088250020518899, 'overlap rate': 0.6987600713968277}
# evaluation performance: {'loss': 1.458478170633316, 'abosulate accuracy': 0.030300001474097372, 'consecutive overlap rate': 0.14355750186368824, 'overlap rate': 0.6705600671470165}
#
# Current epoch: 45,
# training performance: {'loss': 0.26774045936763285, 'abosulate accuracy': 0.3216000162065029, 'consecutive overlap rate': 0.5456900060176849, 'overlap rate': 0.9508800745010376}
# evaluation performance: {'loss': 0.38103984445333483, 'abosulate accuracy': 0.39420001953840256, 'consecutive overlap rate': 0.6209526345133781, 'overlap rate': 0.9258807815611363}
#
# Current epoch: 50,
# training performance: {'loss': 0.043556802440434694, 'abosulate accuracy': 0.9408000499010086, 'consecutive overlap rate': 0.982461678981781, 'overlap rate': 0.9988483846187591}
# evaluation performance: {'loss': 0.050141205871477725, 'abosulate accuracy': 0.9365000478923321, 'consecutive overlap rate': 0.9795691795647145, 'overlap rate': 0.9968684040009975}
#
# Current epoch: 55,
# training performance: {'loss': 0.018773337313905358, 'abosulate accuracy': 0.9895000398159027, 'consecutive overlap rate': 0.9977687388658524, 'overlap rate': 0.999814985692501}
# evaluation performance: {'loss': 0.020509507646784185, 'abosulate accuracy': 0.9864500381052494, 'consecutive overlap rate': 0.9966866753995418, 'overlap rate': 0.999349232763052}
#
# Current epoch: 60,
# training performance: {'loss': 0.010527193592861295, 'abosulate accuracy': 0.9972000241279602, 'consecutive overlap rate': 0.9997450068593026, 'overlap rate': 0.9999533727765083}
# evaluation performance: {'loss': 0.012212482304312289, 'abosulate accuracy': 0.9926000349223614, 'consecutive overlap rate': 0.9981366753578186, 'overlap rate': 0.9996225543320179}
#
# Current epoch: 65,
# training performance: {'loss': 0.006769801280461252, 'abosulate accuracy': 0.9995000064373016, 'consecutive overlap rate': 0.9999716684222222, 'overlap rate': 0.9999916777014732}
# evaluation performance: {'loss': 0.0076042483793571595, 'abosulate accuracy': 0.9966500267386437, 'consecutive overlap rate': 0.9993075057864189, 'overlap rate': 0.9998367048799992}
#
# Current epoch: 70,
# training performance: {'loss': 0.004695361363701522, 'abosulate accuracy': 0.9998000025749206, 'consecutive overlap rate': 0.9999899998307228, 'overlap rate': 0.9999966710805893}
# evaluation performance: {'loss': 0.005500258388929069, 'abosulate accuracy': 0.9970500260591507, 'consecutive overlap rate': 0.9994550056755542, 'overlap rate': 0.9998533703386784}
#
# Experiments_Logs/Experiment#4/LSTM/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#4/LSTM/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.005038713071553502, 'abosulate accuracy': 0.9974500201642513, 'consecutive overlap rate': 0.9993145871907473, 'overlap rate': 0.9998550280928612}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 10.705952104087919, 'abosulate accuracy': 0.0907750039594248, 'consecutive overlap rate': 0.10734731570701114, 'overlap rate': 0.1507331994915148}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.221899393297011, 'abosulate accuracy': 0.4829887144027218, 'consecutive overlap rate': 0.6439427271966012, 'overlap rate': 0.7240249549188922}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.450807331522045, 'abosulate accuracy': 0.02850000047749889, 'consecutive overlap rate': 0.3332439499714191, 'overlap rate': 0.3562060180365255}
# Experiments_Logs/Experiment#4/LSTM/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#4 with LSTM seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#4/LSTM/hyperparameters.json saved!

# %%
from google.colab import runtime
runtime.unassign()
