# %% [markdown]
# ## Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
# Out:
# Mounted at /drive

# %%
project_dir = "/drive/My Drive/RNN_seq2seq"

# change working directory to project_dir
os.chdir(project_dir)

# %% [markdown]
# ## Dependencies

# %%
import torch
import torch.nn as nn

from os import makedirs
from os.path import join

import pandas as pd 
import matplotlib.pyplot as plt
from string import ascii_lowercase

from scripts.data import get_input_spec_red_pair
from scripts.utils import read_data, read_json, read_datasets, save_dict_as_json
from scripts.dataloader import get_text_encoder_decoder, customize_dataloader_func
from scripts.pytorch_utils import get_model, customize_predictor, metrics, get_results

# %% [markdown]
# ## Log time

# %%
from datetime import datetime

now = datetime.now()
print("Time stamp:", now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Time stamp: 2023-02-03 06:08:56

# %% [markdown]
# ## Data loading and processing

# %%
train, dev, test, gen = read_datasets("data/input_spec_red")

# add new data containing unseen number of instruction symbols to the gen set
gen_X = [x for (x, _) in read_data("data/identity/gen.txt")]
test_X = [x for (x, _) in read_data("data/identity/test.txt")]

for n in range(4, 7):
    for x in gen_X[:5000*5] + test_X + gen_X[5000*5:]:
        gen.append(get_input_spec_red_pair(x, n))

# %%
len(train), len(dev), len(test), len(gen)
# Out:
# (30000, 30000, 150000, 750000)

# %%
in_vocab = ascii_lowercase + "@"
out_vocab = ascii_lowercase + "@"
in_seq_encoder, in_seq_decoder = get_text_encoder_decoder(in_vocab)
out_seq_encoder, out_seq_decoder = get_text_encoder_decoder(out_vocab)

# %%
dataloader_func = customize_dataloader_func(in_seq_encoder, 
                                            out_seq_encoder, 
                                            padding_idx=1, 
                                            batch_size=1000, 
                                            shuffle=False)

train_dl = dataloader_func(train)
dev_dl = dataloader_func(dev)
test_dl = dataloader_func(test, batch_size=5000)
gen_dl = dataloader_func(gen, batch_size=5000)

# %% [markdown]
# ## Re-evaluation
#
# We redefine the evaluation and visualization functions so that they work for results obtained in the experiments for the input specified reduplication.

# %%
def get_trained_model(task_name, rnn_type, attention, run_num):
    attention = "attn" if attention else "attn-less"
    saved_model_fp = f'experiments/{task_name}/{rnn_type}/{attention}/{run_num}/model.pt'
    ModelConfig = read_json(f'experiments/{task_name}/{rnn_type}/{attention}/{run_num}/ModelConfig.json')
    model = get_model(ModelConfig)
    model.load_state_dict(torch.load(saved_model_fp))
    return model

# %%
def evaluate_input_spec_red(model, dataloader, criterion):
    model.eval()    
    perf_log = dict()
        
    # aggragate performance
    aggr_perf = {"loss": 0.0, 
                 "full sequence accuracy": 0.0, 
                 "first n-symbol accuracy": 0.0, 
                 "overlap rate": 0.0}
    
    with torch.no_grad():
        for X, Y in dataloader:
            num_red = (X[:, 0] == 28).sum().item()
            x_seq_len = X.shape[0] - 2 - num_red # not counting <s>, </s>, and @
            seq_len, batch_size = Y.shape
            seq_len -= 1 # logits does not have <s>

            X = X.to(model.device)
            Y = Y.to(model.device)
            logits, _ = model(X, Y, teacher_forcing_ratio=0.0)
            
            Ypred = logits.view(seq_len, batch_size, -1).argmax(2)
            full_seq_accu, first_n_accu, overlap_rate = metrics(Y[1:], Ypred)
            loss = criterion(logits, Y[1:].view(-1))
            
            aggr_perf["loss"] += loss.item()
            aggr_perf["full sequence accuracy"] += full_seq_accu
            aggr_perf["first n-symbol accuracy"] += first_n_accu
            aggr_perf["overlap rate"] += overlap_rate
            
            batch_perf = {"loss": loss.item(), "full sequence accuracy": full_seq_accu, 
                          "first n-symbol accuracy": first_n_accu, "overlap rate": overlap_rate}

            key = f"Red-{num_red}"
            if key not in perf_log:
                perf_log[f"Red-{num_red}"] = {f"Len-{x_seq_len}": batch_perf}
            else:
                perf_log[f"Red-{num_red}"][f"Len-{x_seq_len}"] = batch_perf
    
    aggr_perf = {k:v/len(dataloader) for k,v in aggr_perf.items()}
    perf_log[f"Aggregated"] = aggr_perf
        
    return aggr_perf, perf_log

# %%
def plot_performances_per_seq_len(perfs, show_plot=True, saved_plot_fp=None, 
                                  metric="full sequence accuracy"):
    
    red_nums = [rn for rn in perfs if "Red" in rn]
    
    for red_num in red_nums:
        rn_dict = perfs[red_num]
        lengths = [int(l.split("-")[-1]) for l in perfs[red_num]]
        res = [rn_dict[f"Len-{l}"][metric] for l in lengths]
        plt.plot(lengths, res, ".-", label=red_num)
    
    plt.xlabel("Length")
    plt.ylabel(metric.title())
    plt.xticks(lengths, fontsize=6, rotation=-25)
    plt.grid(True, alpha=0.1)
    plt.legend()
        
    if saved_plot_fp != None:
        plt.savefig(saved_plot_fp, dpi=600, bbox_inches='tight')
        print(f"{saved_plot_fp} saved!")

    if show_plot:
        plt.show()
    else:
        plt.close()

    plt.show()

# %%
task_name = "input_spec_red"

main_results = []
task_folder = join("experiments", task_name + "_RE_EVAL")
main_res_col = ["Run #", "RNN", "Attention", "Dataset", "Loss", 
                "Full Sequence Accuracy", "First N-symbol Accuracy", "Overlap Rate"]

for rnn_type in ["SRNN", "GRU", "LSTM"]:
    for use_attn in [True, False]:
        for run_num in range(1, 4):
            
            print(f"RNN type: {rnn_type}; use attention: {use_attn}; run num: {run_num}\n")
            
            model = get_trained_model(task_name, rnn_type, use_attn, run_num)
            criterion = nn.CrossEntropyLoss()

            attn = "attn" if use_attn else "attn-less"
            folder = join(task_folder, rnn_type, attn, str(run_num))
            makedirs(folder, exist_ok=True)

            train_aggr, perfs_train = evaluate_input_spec_red(model, train_dl, criterion)
            dev_aggr, perfs_dev = evaluate_input_spec_red(model, dev_dl, criterion)
            test_aggr, perfs_test = evaluate_input_spec_red(model, test_dl, criterion)
            gen_aggr, perfs_gen = evaluate_input_spec_red(model, gen_dl, criterion)

            for aggr, ds in zip([train_aggr, dev_aggr, test_aggr, gen_aggr], ["Train", "Dev", "Test", "Gen"]):
                main_results.append([run_num, rnn_type, use_attn, ds] + get_results(aggr, train_log=False))
            
            save_dict_as_json(perfs_train, join(folder, "perfs_train.json"))
            save_dict_as_json(perfs_dev, join(folder, "perfs_dev.json"))
            save_dict_as_json(perfs_test, join(folder, "perfs_test.json"))
            save_dict_as_json(perfs_gen, join(folder, "perfs_gen.json"))
            plot_performances_per_seq_len(perfs_train, False, join(folder, "perfs_train.png"))
            plot_performances_per_seq_len(perfs_dev, False, join(folder, "perfs_dev.png"))
            plot_performances_per_seq_len(perfs_test, False, join(folder, "perfs_test.png"))
            plot_performances_per_seq_len(perfs_gen, False, join(folder, "perfs_gen.png"))

pd.DataFrame(main_results, columns=main_res_col).to_csv(join(task_folder, "main_results.csv"), index=False)
# Out:
# RNN type: SRNN; use attention: True; run num: 1
#
# The model has 1,467,165 trainable parameters
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/1/perfs_gen.png saved!
# RNN type: SRNN; use attention: True; run num: 2
#
# The model has 1,467,165 trainable parameters
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/2/perfs_gen.png saved!
# RNN type: SRNN; use attention: True; run num: 3
#
# The model has 1,467,165 trainable parameters
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn/3/perfs_gen.png saved!
# RNN type: SRNN; use attention: False; run num: 1
#
# The model has 1,205,021 trainable parameters
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/1/perfs_gen.png saved!
# RNN type: SRNN; use attention: False; run num: 2
#
# The model has 1,205,021 trainable parameters
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/2/perfs_gen.png saved!
# RNN type: SRNN; use attention: False; run num: 3
#
# The model has 1,205,021 trainable parameters
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/SRNN/attn-less/3/perfs_gen.png saved!
# RNN type: GRU; use attention: True; run num: 1
#
# The model has 3,306,269 trainable parameters
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/1/perfs_gen.png saved!
# RNN type: GRU; use attention: True; run num: 2
#
# The model has 3,306,269 trainable parameters
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/2/perfs_gen.png saved!
# RNN type: GRU; use attention: True; run num: 3
#
# The model has 3,306,269 trainable parameters
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn/3/perfs_gen.png saved!
# RNN type: GRU; use attention: False; run num: 1
#
# The model has 2,519,837 trainable parameters
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/1/perfs_gen.png saved!
# RNN type: GRU; use attention: False; run num: 2
#
# The model has 2,519,837 trainable parameters
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/2/perfs_gen.png saved!
# RNN type: GRU; use attention: False; run num: 3
#
# The model has 2,519,837 trainable parameters
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/GRU/attn-less/3/perfs_gen.png saved!
# RNN type: LSTM; use attention: True; run num: 1
#
# The model has 4,225,821 trainable parameters
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/1/perfs_gen.png saved!
# RNN type: LSTM; use attention: True; run num: 2
#
# The model has 4,225,821 trainable parameters
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/2/perfs_gen.png saved!
# RNN type: LSTM; use attention: True; run num: 3
#
# The model has 4,225,821 trainable parameters
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn/3/perfs_gen.png saved!
# RNN type: LSTM; use attention: False; run num: 1
#
# The model has 3,177,245 trainable parameters
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/1/perfs_gen.png saved!
# RNN type: LSTM; use attention: False; run num: 2
#
# The model has 3,177,245 trainable parameters
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/2/perfs_gen.png saved!
# RNN type: LSTM; use attention: False; run num: 3
#
# The model has 3,177,245 trainable parameters
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_train.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_dev.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_test.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_gen.json saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_train.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_dev.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_test.png saved!
# experiments/input_spec_red_RE_EVAL/LSTM/attn-less/3/perfs_gen.png saved!

# %% [markdown]
# ## Automatically disconnect and delete the runtime

# %%
from google.colab import runtime
runtime.unassign()
