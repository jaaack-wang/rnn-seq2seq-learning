# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 384
embd_dim = 256
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = True
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 6
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#6/LSTM created!
# ./Experiments_Logs/Experiment#6/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#6/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#6/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#6 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.8986435264348984, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006700000109049143, 'overlap rate': 0.43163004219532014}
# evaluation performance: {'loss': 1.8995005324482919, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006483333479991415, 'overlap rate': 0.43135671131312847}
#
# Current epoch: 10,
# training performance: {'loss': 1.8545134574174882, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0041750000789761545, 'overlap rate': 0.4467233784496784}
# evaluation performance: {'loss': 1.903073352575302, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004335000042920001, 'overlap rate': 0.43972754627466204}
#
# Current epoch: 15,
# training performance: {'loss': 1.723394799232483, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011226666742004454, 'overlap rate': 0.47480504438281057}
# evaluation performance: {'loss': 1.8490957453846932, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010844745894428343, 'overlap rate': 0.4513147480785847}
#
# Current epoch: 20,
# training performance: {'loss': 1.559814515709877, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014136666781269014, 'overlap rate': 0.5089267194271088}
# evaluation performance: {'loss': 1.862956164777279, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0131491667823866, 'overlap rate': 0.46526338048279287}
#
# Current epoch: 25,
# training performance: {'loss': 1.4376257598400115, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02055166675709188, 'overlap rate': 0.5398283876478672}
# evaluation performance: {'loss': 1.7747872576117516, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01912083344068378, 'overlap rate': 0.4866375461220741}
#
# Current epoch: 30,
# training performance: {'loss': 1.3239802539348602, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025491667026653887, 'overlap rate': 0.5715850561857223}
# evaluation performance: {'loss': 1.864730454981327, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02240333359222859, 'overlap rate': 0.4943517167121172}
#
# Current epoch: 35,
# training performance: {'loss': 1.2359901905059814, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03019333383999765, 'overlap rate': 0.5976500630378723}
# evaluation performance: {'loss': 1.884225568175316, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.026166666951030492, 'overlap rate': 0.5033025551587343}
#
# Current epoch: 40,
# training performance: {'loss': 1.1420843929052353, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.03717500027269125, 'overlap rate': 0.6262900680303574}
# evaluation performance: {'loss': 1.831909492611885, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03166666713077575, 'overlap rate': 0.5239150546491146}
#
# Current epoch: 45,
# training performance: {'loss': 1.065162369608879, 'abosulate accuracy': 0.0011000000522471964, 'consecutive overlap rate': 0.047351667284965517, 'overlap rate': 0.6526367366313934}
# evaluation performance: {'loss': 1.960804532468319, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03833333388902247, 'overlap rate': 0.5234917249530554}
#
# Current epoch: 50,
# training performance: {'loss': 0.9849310949444771, 'abosulate accuracy': 0.00320000012870878, 'consecutive overlap rate': 0.0612766676582396, 'overlap rate': 0.6808117374777793}
# evaluation performance: {'loss': 2.04100244641304, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.045886667305603625, 'overlap rate': 0.528062554448843}
#
# Current epoch: 55,
# training performance: {'loss': 0.9161070495843887, 'abosulate accuracy': 0.0070000002509914335, 'consecutive overlap rate': 0.07212666757404804, 'overlap rate': 0.7039584010839463}
# evaluation performance: {'loss': 2.1518620565533637, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.04856750057078898, 'overlap rate': 0.5296850554645062}
#
# Current epoch: 60,
# training performance: {'loss': 0.8275142997503281, 'abosulate accuracy': 0.015200000628829003, 'consecutive overlap rate': 0.08705666810274124, 'overlap rate': 0.7327250748872757}
# evaluation performance: {'loss': 2.2864573329687117, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.05126333413645625, 'overlap rate': 0.5322000615298748}
#
# Current epoch: 65,
# training performance: {'loss': 0.7560426712036132, 'abosulate accuracy': 0.02210000087507069, 'consecutive overlap rate': 0.09959000051021576, 'overlap rate': 0.7562134057283402}
# evaluation performance: {'loss': 2.4748364061117174, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05208185091614723, 'overlap rate': 0.5302901431918144}
#
# Current epoch: 70,
# training performance: {'loss': 0.7013384565711022, 'abosulate accuracy': 0.02730000134324655, 'consecutive overlap rate': 0.1078716678544879, 'overlap rate': 0.7735717415809631}
# evaluation performance: {'loss': 2.655948266386986, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.05274487338028848, 'overlap rate': 0.5284197133034467}
#
# Current epoch: 75,
# training performance: {'loss': 0.6541281387209892, 'abosulate accuracy': 0.03290000180713833, 'consecutive overlap rate': 0.11771166771650314, 'overlap rate': 0.7880450770258903}
# evaluation performance: {'loss': 2.7685847997665407, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05365916732698679, 'overlap rate': 0.5299967225641012}
#
# Current epoch: 80,
# training performance: {'loss': 0.623097549378872, 'abosulate accuracy': 0.03950000163167715, 'consecutive overlap rate': 0.12773666810244322, 'overlap rate': 0.7974450767040253}
# evaluation performance: {'loss': 2.844797757267952, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.054257500590756534, 'overlap rate': 0.5305375527590513}
#
# Current epoch: 85,
# training performance: {'loss': 0.5854469433426857, 'abosulate accuracy': 0.05080000227317214, 'consecutive overlap rate': 0.14209864437580108, 'overlap rate': 0.8096506386995316}
# evaluation performance: {'loss': 2.9546061605215073, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.05422416739165783, 'overlap rate': 0.5304367192089557}
#
# Current epoch: 90,
# training performance: {'loss': 0.5678319208323955, 'abosulate accuracy': 0.04700000230222941, 'consecutive overlap rate': 0.13993067871779202, 'overlap rate': 0.8143142387270927}
# evaluation performance: {'loss': 3.0738206267356873, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.05323333400301635, 'overlap rate': 0.5292033828794956}
#
# Current epoch: 95,
# training performance: {'loss': 0.5391748413443566, 'abosulate accuracy': 0.050500002410262826, 'consecutive overlap rate': 0.14427000265568496, 'overlap rate': 0.8232567459344864}
# evaluation performance: {'loss': 3.160029536485672, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.0540416672360152, 'overlap rate': 0.5295733861625195}
#
# Current epoch: 100,
# training performance: {'loss': 0.5247265189886093, 'abosulate accuracy': 0.05310000274330377, 'consecutive overlap rate': 0.1485766675323248, 'overlap rate': 0.8272267565131187}
# evaluation performance: {'loss': 3.2691098868846895, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05419666729867458, 'overlap rate': 0.5296225544065237}
#
# Current epoch: 105,
# training performance: {'loss': 0.49702844098210336, 'abosulate accuracy': 0.06600000318139791, 'consecutive overlap rate': 0.16773500181734563, 'overlap rate': 0.8363200783729553}
# evaluation performance: {'loss': 3.3586993366479874, 'abosulate accuracy': 0.0002500000118743628, 'consecutive overlap rate': 0.05414583384990692, 'overlap rate': 0.5290158916264772}
#
# Current epoch: 110,
# training performance: {'loss': 0.47150352522730826, 'abosulate accuracy': 0.07190000358968973, 'consecutive overlap rate': 0.17610166892409324, 'overlap rate': 0.8443900749087334}
# evaluation performance: {'loss': 3.4256644368171694, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.05396500071510672, 'overlap rate': 0.5297333799302578}
#
# Current epoch: 115,
# training performance: {'loss': 0.4744812034070492, 'abosulate accuracy': 0.06640000334009528, 'consecutive overlap rate': 0.16942833550274372, 'overlap rate': 0.8425384178757668}
# evaluation performance: {'loss': 3.5254390090703964, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.053494167421013115, 'overlap rate': 0.5281342189759016}
#
# Current epoch: 120,
# training performance: {'loss': 0.4433616168797016, 'abosulate accuracy': 0.08310000346973538, 'consecutive overlap rate': 0.19129000157117843, 'overlap rate': 0.8530717402696609}
# evaluation performance: {'loss': 3.604054570198059, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.05462000072002411, 'overlap rate': 0.5289825513958931}
#
# Current epoch: 125,
# training performance: {'loss': 0.4323042206466198, 'abosulate accuracy': 0.08150000423192978, 'consecutive overlap rate': 0.19369166977703572, 'overlap rate': 0.8567567363381385}
# evaluation performance: {'loss': 3.629475462436676, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05419666729867458, 'overlap rate': 0.5295275535434485}
#
# Current epoch: 130,
# training performance: {'loss': 0.4284705527126789, 'abosulate accuracy': 0.0817000038921833, 'consecutive overlap rate': 0.19255166910588742, 'overlap rate': 0.8572084099054337}
# evaluation performance: {'loss': 3.7474353700876235, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05384083390235901, 'overlap rate': 0.5289850499480963}
#
# Current epoch: 135,
# training performance: {'loss': 0.42668466493487356, 'abosulate accuracy': 0.08300000419840217, 'consecutive overlap rate': 0.19523000195622445, 'overlap rate': 0.857713408768177}
# evaluation performance: {'loss': 3.8226744711399077, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.05382416737265885, 'overlap rate': 0.5284583825618029}
#
# Current epoch: 140,
# training performance: {'loss': 0.4130518980324268, 'abosulate accuracy': 0.08980000410228968, 'consecutive overlap rate': 0.2036400016397238, 'overlap rate': 0.8620450824499131}
# evaluation performance: {'loss': 3.8476414144039155, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.05437000058591366, 'overlap rate': 0.5293567236512899}
#
# Current epoch: 145,
# training performance: {'loss': 0.4000020407140255, 'abosulate accuracy': 0.09490000363439322, 'consecutive overlap rate': 0.21083500161767005, 'overlap rate': 0.8666900873184205}
# evaluation performance: {'loss': 3.909593951702118, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.054194167349487544, 'overlap rate': 0.5291233841329813}
#
# Current epoch: 150,
# training performance: {'loss': 0.3891424126923084, 'abosulate accuracy': 0.08750000419095158, 'consecutive overlap rate': 0.20590000301599504, 'overlap rate': 0.869611744582653}
# evaluation performance: {'loss': 3.998426803946495, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.053621667297557, 'overlap rate': 0.5289000578224659}
#
# Current epoch: 155,
# training performance: {'loss': 0.38582400903105735, 'abosulate accuracy': 0.09480000426992774, 'consecutive overlap rate': 0.21687000133097173, 'overlap rate': 0.8706284165382385}
# evaluation performance: {'loss': 4.076388585567474, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.05394500051625073, 'overlap rate': 0.5278325542807579}
#
# Current epoch: 160,
# training performance: {'loss': 0.38942136988043785, 'abosulate accuracy': 0.0871000038459897, 'consecutive overlap rate': 0.2042600020766258, 'overlap rate': 0.8696784138679504}
# evaluation performance: {'loss': 4.196712702512741, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.052228334033861755, 'overlap rate': 0.5243158865720033}
#
# Current epoch: 165,
# training performance: {'loss': 0.3585001781582832, 'abosulate accuracy': 0.10450000371783971, 'consecutive overlap rate': 0.2279133353382349, 'overlap rate': 0.8797934144735337}
# evaluation performance: {'loss': 4.130395033955574, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.053962500765919685, 'overlap rate': 0.5293417207896709}
#
# Current epoch: 170,
# training performance: {'loss': 0.3507902197539806, 'abosulate accuracy': 0.10940000414848328, 'consecutive overlap rate': 0.23526333682239056, 'overlap rate': 0.8822867453098298}
# evaluation performance: {'loss': 4.222282993793487, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05333916707895696, 'overlap rate': 0.5281325530260801}
#
# Current epoch: 175,
# training performance: {'loss': 0.3397854045033455, 'abosulate accuracy': 0.11870000436902046, 'consecutive overlap rate': 0.24767833538353443, 'overlap rate': 0.8861767515540123}
# evaluation performance: {'loss': 4.329038059711456, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.05357583397999406, 'overlap rate': 0.5284508857876062}
#
# Current epoch: 180,
# training performance: {'loss': 0.3698542095720768, 'abosulate accuracy': 0.09980000369250774, 'consecutive overlap rate': 0.21939833611249923, 'overlap rate': 0.8751517444849014}
# evaluation performance: {'loss': 4.338746726512909, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05325666717253626, 'overlap rate': 0.5280167199671268}
#
# Current epoch: 185,
# training performance: {'loss': 0.326674123108387, 'abosulate accuracy': 0.12560000475496053, 'consecutive overlap rate': 0.25843000411987305, 'overlap rate': 0.8901717439293861}
# evaluation performance: {'loss': 4.38054791688919, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.0537533339112997, 'overlap rate': 0.5283250533044338}
#
# Current epoch: 190,
# training performance: {'loss': 0.32468806207180023, 'abosulate accuracy': 0.12440000437200069, 'consecutive overlap rate': 0.2593866724520922, 'overlap rate': 0.8908517435193062}
# evaluation performance: {'loss': 4.4265014171600345, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05368166747502982, 'overlap rate': 0.5284800495952368}
#
# Current epoch: 195,
# training performance: {'loss': 0.34248441234231, 'abosulate accuracy': 0.10570000428706408, 'consecutive overlap rate': 0.23363686837255954, 'overlap rate': 0.8840545222163201}
# evaluation performance: {'loss': 4.481066662073135, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.05400916719809175, 'overlap rate': 0.5277858879417181}
#
# Current epoch: 200,
# training performance: {'loss': 0.34724382013082505, 'abosulate accuracy': 0.10120000392198562, 'consecutive overlap rate': 0.22647333592176438, 'overlap rate': 0.8819734171032906}
# evaluation performance: {'loss': 4.402488660812378, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05359000060707331, 'overlap rate': 0.5287800550460815}
#
# Experiments_Logs/Experiment#6/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 4.0139222458004955, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05400656829588115, 'overlap rate': 0.528816843777895}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 8.897703814506531, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05057326047681272, 'overlap rate': 0.14289369154721498}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.786090866211922, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03491815304563892, 'overlap rate': 0.48172169231599377}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 9.120861806367573, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.042025047697519004, 'overlap rate': 0.11424475800442069}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.960840418934822, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007366666839516256, 'overlap rate': 0.42076670974493025}
# evaluation performance: {'loss': 3.2414908170700074, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006616666789341253, 'overlap rate': 0.2398416928946972}
#
# Current epoch: 10,
# training performance: {'loss': 1.8979372173547744, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007016666815616191, 'overlap rate': 0.43183338195085524}
# evaluation performance: {'loss': 1.8990189909934998, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006450000146287493, 'overlap rate': 0.431247540935874}
#
# Current epoch: 15,
# training performance: {'loss': 1.8768219083547593, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001441666689061094, 'overlap rate': 0.4434000439941883}
# evaluation performance: {'loss': 1.8781411603093148, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014975000158301555, 'overlap rate': 0.43777671046555044}
#
# Current epoch: 20,
# training performance: {'loss': 1.7650198251008988, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003790000022854656, 'overlap rate': 0.47646005302667616}
# evaluation performance: {'loss': 1.8666288256645203, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0039475000696256755, 'overlap rate': 0.4456150453537703}
#
# Current epoch: 25,
# training performance: {'loss': 1.574678760766983, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008371666783932596, 'overlap rate': 0.5246967226266861}
# evaluation performance: {'loss': 1.746778005361557, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.008810000109951944, 'overlap rate': 0.4765492152422667}
#
# Current epoch: 30,
# training performance: {'loss': 1.3676918238401412, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018013333599083126, 'overlap rate': 0.5806917250156403}
# evaluation performance: {'loss': 1.5123098626732827, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020432500285096467, 'overlap rate': 0.5428242146968841}
#
# Current epoch: 35,
# training performance: {'loss': 1.159835097193718, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.031260000681504606, 'overlap rate': 0.6357884049415589}
# evaluation performance: {'loss': 1.4932762950658798, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.028760000318288802, 'overlap rate': 0.5571933887898922}
#
# Current epoch: 40,
# training performance: {'loss': 1.0888076782226563, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.03493000031448901, 'overlap rate': 0.6566283971071243}
# evaluation performance: {'loss': 1.4087043896317482, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.030999166984111072, 'overlap rate': 0.5892642274498939}
#
# Current epoch: 45,
# training performance: {'loss': 1.0922359183430672, 'abosulate accuracy': 0.0010000000358559192, 'consecutive overlap rate': 0.033002288360148666, 'overlap rate': 0.6638085708022118}
# evaluation performance: {'loss': 1.5024460583925248, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03038250026293099, 'overlap rate': 0.5793583944439888}
#
# Current epoch: 50,
# training performance: {'loss': 0.8961821779608726, 'abosulate accuracy': 0.004200000176206231, 'consecutive overlap rate': 0.04563333373516798, 'overlap rate': 0.7181150779128075}
# evaluation performance: {'loss': 1.5247078448534013, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03213416698854417, 'overlap rate': 0.5996942229568958}
#
# Current epoch: 55,
# training performance: {'loss': 1.0367278695106505, 'abosulate accuracy': 0.002200000104494393, 'consecutive overlap rate': 0.03506000027991831, 'overlap rate': 0.692748399078846}
# evaluation performance: {'loss': 1.6873571261763574, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.029817500454373657, 'overlap rate': 0.5779942281544208}
#
# Current epoch: 60,
# training performance: {'loss': 0.8630427196621895, 'abosulate accuracy': 0.004300000192597508, 'consecutive overlap rate': 0.04250500062480569, 'overlap rate': 0.7298067346215248}
# evaluation performance: {'loss': 1.7887479439377785, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.031019166973419488, 'overlap rate': 0.5844133913516998}
#
# Current epoch: 65,
# training performance: {'loss': 0.7145458593964576, 'abosulate accuracy': 0.012900000531226396, 'consecutive overlap rate': 0.05979000087827444, 'overlap rate': 0.772005082666874}
# evaluation performance: {'loss': 1.8167844146490097, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03134666692931205, 'overlap rate': 0.59429172873497}
#
# Current epoch: 70,
# training performance: {'loss': 0.6919909164309501, 'abosulate accuracy': 0.010400000342633576, 'consecutive overlap rate': 0.05819833427667618, 'overlap rate': 0.778021739423275}
# evaluation performance: {'loss': 1.9546577602624893, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.030630000517703593, 'overlap rate': 0.5849858969449997}
#
# Current epoch: 75,
# training performance: {'loss': 0.6692546471953392, 'abosulate accuracy': 0.012500000465661288, 'consecutive overlap rate': 0.06123833414167166, 'overlap rate': 0.7850567504763604}
# evaluation performance: {'loss': 1.9897790014743806, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03140083365142345, 'overlap rate': 0.5896217279136181}
#
# Current epoch: 80,
# training performance: {'loss': 0.6505627244710922, 'abosulate accuracy': 0.013300000550225377, 'consecutive overlap rate': 0.06161000095307827, 'overlap rate': 0.7903917416930198}
# evaluation performance: {'loss': 2.0482779696583746, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.03133000044617802, 'overlap rate': 0.5908475466072559}
#
# Current epoch: 85,
# training performance: {'loss': 0.6161040052771568, 'abosulate accuracy': 0.016100000613369046, 'consecutive overlap rate': 0.06622166717424989, 'overlap rate': 0.7999134242534638}
# evaluation performance: {'loss': 2.1057173743844033, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.031872500432655215, 'overlap rate': 0.5925583891570568}
#
# Current epoch: 90,
# training performance: {'loss': 0.6802211657166481, 'abosulate accuracy': 0.013100000564008951, 'consecutive overlap rate': 0.057566667813807725, 'overlap rate': 0.7846234157681465}
# evaluation performance: {'loss': 2.2075603723526003, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.030560833821073174, 'overlap rate': 0.5827142246067524}
#
# Current epoch: 95,
# training performance: {'loss': 0.5842951461672783, 'abosulate accuracy': 0.0181000008713454, 'consecutive overlap rate': 0.07039833413437009, 'overlap rate': 0.8110317587852478}
# evaluation performance: {'loss': 2.316662085056305, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.030347500322386624, 'overlap rate': 0.5784708894789219}
#
# Current epoch: 100,
# training performance: {'loss': 0.5477625243365765, 'abosulate accuracy': 0.021200000937096775, 'consecutive overlap rate': 0.07653166763484479, 'overlap rate': 0.8207850828766823}
# evaluation performance: {'loss': 2.2545627802610397, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03156583365052938, 'overlap rate': 0.5900858916342259}
#
# Current epoch: 105,
# training performance: {'loss': 0.5573244646191597, 'abosulate accuracy': 0.020400000875815748, 'consecutive overlap rate': 0.07366333361715079, 'overlap rate': 0.8179050981998444}
# evaluation performance: {'loss': 2.289188838005066, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.03162083374336362, 'overlap rate': 0.591680896282196}
#
# Current epoch: 110,
# training performance: {'loss': 0.5273604221642018, 'abosulate accuracy': 0.023700000904500484, 'consecutive overlap rate': 0.08098000083118677, 'overlap rate': 0.8264767482876778}
# evaluation performance: {'loss': 2.3436977326869965, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.032122500520199535, 'overlap rate': 0.5936942249536514}
#
# Current epoch: 115,
# training performance: {'loss': 0.530290050059557, 'abosulate accuracy': 0.023400000983383507, 'consecutive overlap rate': 0.07877166718244552, 'overlap rate': 0.8261617496609688}
# evaluation performance: {'loss': 2.40624994635582, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.031100833765231074, 'overlap rate': 0.5886333905160427}
#
# Current epoch: 120,
# training performance: {'loss': 0.48826994150877, 'abosulate accuracy': 0.03110000123269856, 'consecutive overlap rate': 0.09033333398401737, 'overlap rate': 0.838815076649189}
# evaluation performance: {'loss': 2.4013919830322266, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.031678333738818766, 'overlap rate': 0.5931667290627957}
#
# Current epoch: 125,
# training performance: {'loss': 0.4772092945873737, 'abosulate accuracy': 0.030100001418031753, 'consecutive overlap rate': 0.09039000123739242, 'overlap rate': 0.8417484164237976}
# evaluation performance: {'loss': 2.451830115914345, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.03200250030495226, 'overlap rate': 0.5941992312669754}
#
# Current epoch: 130,
# training performance: {'loss': 0.48171413540840147, 'abosulate accuracy': 0.026500001072417945, 'consecutive overlap rate': 0.08594166794791817, 'overlap rate': 0.8393334120512008}
# evaluation performance: {'loss': 2.515592336654663, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.03181833373382688, 'overlap rate': 0.5924833945930004}
#
# Current epoch: 135,
# training performance: {'loss': 0.4966669872403145, 'abosulate accuracy': 0.027000001072883605, 'consecutive overlap rate': 0.08398666772991419, 'overlap rate': 0.8353850856423378}
# evaluation performance: {'loss': 2.5530389964580538, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03178416709415614, 'overlap rate': 0.5921633973717689}
#
# Current epoch: 140,
# training performance: {'loss': 0.46826503351330756, 'abosulate accuracy': 0.030700001399964094, 'consecutive overlap rate': 0.09057500101625919, 'overlap rate': 0.8433834165334702}
# evaluation performance: {'loss': 2.54131196141243, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.03235916716512292, 'overlap rate': 0.5947233945131302}
#
# Current epoch: 145,
# training performance: {'loss': 1.1486689835786819, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.032848333846777676, 'overlap rate': 0.6632817342877388}
# evaluation performance: {'loss': 1.8757187560200692, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.031156723643653093, 'overlap rate': 0.5931323774158954}
#
# Current epoch: 150,
# training performance: {'loss': 0.5631865173578262, 'abosulate accuracy': 0.011500000522937625, 'consecutive overlap rate': 0.06504500070586801, 'overlap rate': 0.8140784204006195}
# evaluation performance: {'loss': 2.2159811913967133, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03151833384763449, 'overlap rate': 0.5927833907306195}
#
# Current epoch: 155,
# training performance: {'loss': 0.46659514531493185, 'abosulate accuracy': 0.02690000116126612, 'consecutive overlap rate': 0.0887783351354301, 'overlap rate': 0.8457834213972092}
# evaluation performance: {'loss': 2.3574318051338197, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03212000031489879, 'overlap rate': 0.595950897783041}
#
# Current epoch: 160,
# training performance: {'loss': 0.4648576132953167, 'abosulate accuracy': 0.029700001538731157, 'consecutive overlap rate': 0.09026500098407268, 'overlap rate': 0.8453684091567993}
# evaluation performance: {'loss': 2.470616939663887, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.032296667178161445, 'overlap rate': 0.5945308990776539}
#
# Current epoch: 165,
# training performance: {'loss': 0.4431982345879078, 'abosulate accuracy': 0.034200001740828156, 'consecutive overlap rate': 0.09579666778445244, 'overlap rate': 0.8520950838923455}
# evaluation performance: {'loss': 2.6261773675680162, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.031805833661928774, 'overlap rate': 0.589465893059969}
#
# Current epoch: 170,
# training performance: {'loss': 0.4613441459834576, 'abosulate accuracy': 0.030900001409463584, 'consecutive overlap rate': 0.09196833418682218, 'overlap rate': 0.8463267520070076}
# evaluation performance: {'loss': 2.5974475502967835, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.03277416678611189, 'overlap rate': 0.5950383923947811}
#
# Current epoch: 175,
# training performance: {'loss': 0.43464356288313866, 'abosulate accuracy': 0.03470000140368938, 'consecutive overlap rate': 0.09800000172108411, 'overlap rate': 0.8546400874853134}
# evaluation performance: {'loss': 2.721273401379585, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.03147500003688038, 'overlap rate': 0.5890100583434105}
#
# Current epoch: 180,
# training performance: {'loss': 0.4449638232588768, 'abosulate accuracy': 0.030300001380965114, 'consecutive overlap rate': 0.0924716679379344, 'overlap rate': 0.8506500765681266}
# evaluation performance: {'loss': 2.6305290162563324, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03258416696917266, 'overlap rate': 0.5960025623440742}
#
# Current epoch: 185,
# training performance: {'loss': 0.3895361326634884, 'abosulate accuracy': 0.05060000233352184, 'consecutive overlap rate': 0.12045666724443435, 'overlap rate': 0.8696767643094063}
# evaluation performance: {'loss': 2.7020842850208284, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.03319992967881262, 'overlap rate': 0.5974111646413803}
#
# Current epoch: 190,
# training performance: {'loss': 0.41771875470876696, 'abosulate accuracy': 0.04250000193715096, 'consecutive overlap rate': 0.10945666767656803, 'overlap rate': 0.8600284144282341}
# evaluation performance: {'loss': 2.84516718685627, 'abosulate accuracy': 0.0001500000071246177, 'consecutive overlap rate': 0.03247166706714779, 'overlap rate': 0.5874792262911797}
#
# Current epoch: 195,
# training performance: {'loss': 0.3927588939666748, 'abosulate accuracy': 0.043800002057105304, 'consecutive overlap rate': 0.1127766678109765, 'overlap rate': 0.8677050739526748}
# evaluation performance: {'loss': 2.7498567014932633, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03332666689530015, 'overlap rate': 0.5973233915865421}
#
# Current epoch: 200,
# training performance: {'loss': 0.39910087659955024, 'abosulate accuracy': 0.04610000206157565, 'consecutive overlap rate': 0.11334000136703253, 'overlap rate': 0.8649884134531021}
# evaluation performance: {'loss': 2.7914355635643004, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03309916704893112, 'overlap rate': 0.5963383942842484}
#
# Experiments_Logs/Experiment#6/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.6481212370097638, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03089541709050536, 'overlap rate': 0.5917813055217266}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.4333634078502655, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.050410543428733946, 'overlap rate': 0.2772742334753275}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.2004944924385317, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007332149283179352, 'overlap rate': 0.46907695974073105}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.648867632213392, 'abosulate accuracy': 0.00031578949481052786, 'consecutive overlap rate': 0.04975643391279798, 'overlap rate': 0.23807540222218163}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.8904981523752213, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008000000103493221, 'overlap rate': 0.43882837891578674}
# evaluation performance: {'loss': 1.8913267239928246, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008866666852554772, 'overlap rate': 0.43437087498605254}
#
# Current epoch: 10,
# training performance: {'loss': 1.8378885477781295, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003886666690232232, 'overlap rate': 0.4582350455224514}
# evaluation performance: {'loss': 1.8521406546235084, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00695083339815028, 'overlap rate': 0.44692588187754156}
#
# Current epoch: 15,
# training performance: {'loss': 1.5422895848751068, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020726666785776615, 'overlap rate': 0.536853389441967}
# evaluation performance: {'loss': 1.6338000565767288, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.020337500143796206, 'overlap rate': 0.4948908850550652}
#
# Current epoch: 20,
# training performance: {'loss': 1.3270223140716553, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.031621666997671126, 'overlap rate': 0.5928184002637863}
# evaluation performance: {'loss': 1.5300025016069412, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.031138333724811673, 'overlap rate': 0.5258275583386421}
#
# Current epoch: 25,
# training performance: {'loss': 1.1486609905958176, 'abosulate accuracy': 0.0011000000522471964, 'consecutive overlap rate': 0.043141666986048224, 'overlap rate': 0.6399700611829757}
# evaluation performance: {'loss': 1.6106466889381408, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03311583371832967, 'overlap rate': 0.521706722676754}
#
# Current epoch: 30,
# training performance: {'loss': 1.028961393237114, 'abosulate accuracy': 0.005400000186637044, 'consecutive overlap rate': 0.05577833410352469, 'overlap rate': 0.6734800770878792}
# evaluation performance: {'loss': 1.5158484384417534, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.04300250038504601, 'overlap rate': 0.5538575604557991}
#
# Current epoch: 35,
# training performance: {'loss': 0.9295565962791443, 'abosulate accuracy': 0.010600000480189919, 'consecutive overlap rate': 0.06624500062316656, 'overlap rate': 0.7016284063458442}
# evaluation performance: {'loss': 1.6088414922356606, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.045316667295992374, 'overlap rate': 0.5493875563144683}
#
# Current epoch: 40,
# training performance: {'loss': 0.8276717200875282, 'abosulate accuracy': 0.021200000832322985, 'consecutive overlap rate': 0.08338666763156652, 'overlap rate': 0.7332900688052177}
# evaluation performance: {'loss': 1.6909579619765283, 'abosulate accuracy': 0.0005500000261235982, 'consecutive overlap rate': 0.046510000620037316, 'overlap rate': 0.5563800618052482}
#
# Current epoch: 45,
# training performance: {'loss': 0.7646290242671967, 'abosulate accuracy': 0.02300000103423372, 'consecutive overlap rate': 0.08816500091925264, 'overlap rate': 0.7524334102869034}
# evaluation performance: {'loss': 1.7763440534472466, 'abosulate accuracy': 0.0005500000203028321, 'consecutive overlap rate': 0.04825666695833206, 'overlap rate': 0.5604325599968434}
#
# Current epoch: 50,
# training performance: {'loss': 0.6619856357574463, 'abosulate accuracy': 0.045900002354756, 'consecutive overlap rate': 0.12434833534061909, 'overlap rate': 0.7852417409420014}
# evaluation performance: {'loss': 1.8867948427796364, 'abosulate accuracy': 0.0008500000403728336, 'consecutive overlap rate': 0.05242500058375299, 'overlap rate': 0.5609117239713669}
#
# Current epoch: 55,
# training performance: {'loss': 0.6080845803022384, 'abosulate accuracy': 0.052300002332776784, 'consecutive overlap rate': 0.13431666810065507, 'overlap rate': 0.8024550810456276}
# evaluation performance: {'loss': 1.9772046327590942, 'abosulate accuracy': 0.0009000000427477062, 'consecutive overlap rate': 0.05382333397865295, 'overlap rate': 0.5640058912336826}
#
# Current epoch: 60,
# training performance: {'loss': 0.5787207707762718, 'abosulate accuracy': 0.05550000257790089, 'consecutive overlap rate': 0.13951666764914988, 'overlap rate': 0.8100184142589569}
# evaluation performance: {'loss': 2.0729600161314012, 'abosulate accuracy': 0.0006500000308733433, 'consecutive overlap rate': 0.05259583373554051, 'overlap rate': 0.5607758931815624}
#
# Current epoch: 65,
# training performance: {'loss': 0.5524506650865078, 'abosulate accuracy': 0.05800000317394734, 'consecutive overlap rate': 0.1421016687527299, 'overlap rate': 0.8187734127044678}
# evaluation performance: {'loss': 2.199184903502464, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.04990666736848652, 'overlap rate': 0.5560183949768543}
#
# Current epoch: 70,
# training performance: {'loss': 0.49754723981022836, 'abosulate accuracy': 0.0723000037483871, 'consecutive overlap rate': 0.16478166859596968, 'overlap rate': 0.8355934128165246}
# evaluation performance: {'loss': 2.2685092240571976, 'abosulate accuracy': 0.0009000000427477062, 'consecutive overlap rate': 0.0536725006531924, 'overlap rate': 0.5603567294776439}
#
# Current epoch: 75,
# training performance: {'loss': 0.9546519190073013, 'abosulate accuracy': 0.0022000000928528605, 'consecutive overlap rate': 0.06439500078558921, 'overlap rate': 0.6926350772380829}
# evaluation performance: {'loss': 1.7519771754741669, 'abosulate accuracy': 0.0010500000498723239, 'consecutive overlap rate': 0.05517750065773726, 'overlap rate': 0.5657358862459659}
#
# Current epoch: 80,
# training performance: {'loss': 0.5389274127781392, 'abosulate accuracy': 0.04070000210776925, 'consecutive overlap rate': 0.13579500187188387, 'overlap rate': 0.8225367471575737}
# evaluation performance: {'loss': 2.116770198941231, 'abosulate accuracy': 0.0010500000498723239, 'consecutive overlap rate': 0.05356542435474694, 'overlap rate': 0.5607126422226429}
#
# Current epoch: 85,
# training performance: {'loss': 0.495559074729681, 'abosulate accuracy': 0.05650000283494592, 'consecutive overlap rate': 0.15018000155687333, 'overlap rate': 0.835505086183548}
# evaluation performance: {'loss': 2.228224590420723, 'abosulate accuracy': 0.0010500000498723239, 'consecutive overlap rate': 0.05652583409100771, 'overlap rate': 0.5655892252922058}
#
# Current epoch: 90,
# training performance: {'loss': 0.45030979067087173, 'abosulate accuracy': 0.0679000036790967, 'consecutive overlap rate': 0.16622166931629181, 'overlap rate': 0.849955078959465}
# evaluation performance: {'loss': 2.3476515293121336, 'abosulate accuracy': 0.0008500000403728336, 'consecutive overlap rate': 0.05639500063844025, 'overlap rate': 0.5653350599110126}
#
# Current epoch: 95,
# training performance: {'loss': 0.45961499884724616, 'abosulate accuracy': 0.06560000330209732, 'consecutive overlap rate': 0.15639833509922027, 'overlap rate': 0.8461384192109108}
# evaluation performance: {'loss': 2.429312214255333, 'abosulate accuracy': 0.0007500000356230885, 'consecutive overlap rate': 0.05615857401862741, 'overlap rate': 0.564823853969574}
#
# Current epoch: 100,
# training performance: {'loss': 0.4353194944560528, 'abosulate accuracy': 0.07340000323019921, 'consecutive overlap rate': 0.17011000253260136, 'overlap rate': 0.8543734073638916}
# evaluation performance: {'loss': 2.540518641471863, 'abosulate accuracy': 0.0007500000356230885, 'consecutive overlap rate': 0.05464166719466448, 'overlap rate': 0.5583900585770607}
#
# Current epoch: 105,
# training performance: {'loss': 0.3952613689005375, 'abosulate accuracy': 0.09400000367313624, 'consecutive overlap rate': 0.2000250019133091, 'overlap rate': 0.868003411591053}
# evaluation performance: {'loss': 2.604298231005669, 'abosulate accuracy': 0.0004500000213738531, 'consecutive overlap rate': 0.05507500055246055, 'overlap rate': 0.5630575560033322}
#
# Current epoch: 110,
# training performance: {'loss': 0.39568996205925944, 'abosulate accuracy': 0.08760000374168157, 'consecutive overlap rate': 0.1913866687566042, 'overlap rate': 0.8662284135818481}
# evaluation performance: {'loss': 2.633980080485344, 'abosulate accuracy': 0.0008500000345520675, 'consecutive overlap rate': 0.056468334048986435, 'overlap rate': 0.5635492265224457}
#
# Current epoch: 115,
# training performance: {'loss': 0.3673472717404366, 'abosulate accuracy': 0.09640000397339463, 'consecutive overlap rate': 0.20649500228464604, 'overlap rate': 0.8759384095668793}
# evaluation performance: {'loss': 2.71775279045105, 'abosulate accuracy': 0.0008500000403728336, 'consecutive overlap rate': 0.05782666755840182, 'overlap rate': 0.5653058886528015}
#
# Current epoch: 120,
# training performance: {'loss': 0.36022515296936036, 'abosulate accuracy': 0.1036000045016408, 'consecutive overlap rate': 0.21541666910052298, 'overlap rate': 0.877946749329567}
# evaluation performance: {'loss': 2.7472739607095717, 'abosulate accuracy': 0.0009500000451225787, 'consecutive overlap rate': 0.058465000707656145, 'overlap rate': 0.5642167247831822}
#
# Current epoch: 125,
# training performance: {'loss': 0.3820556074380875, 'abosulate accuracy': 0.08440000424161553, 'consecutive overlap rate': 0.18942500166594983, 'overlap rate': 0.8695184171199799}
# evaluation performance: {'loss': 2.776176244020462, 'abosulate accuracy': 0.0008500000403728336, 'consecutive overlap rate': 0.0573341675568372, 'overlap rate': 0.5643283911049366}
#
# Current epoch: 130,
# training performance: {'loss': 0.34027230739593506, 'abosulate accuracy': 0.11120000500231982, 'consecutive overlap rate': 0.22392333522439004, 'overlap rate': 0.884593415260315}
# evaluation performance: {'loss': 2.8354947924613954, 'abosulate accuracy': 0.0007000000332482159, 'consecutive overlap rate': 0.05723500070162117, 'overlap rate': 0.564935053139925}
#
# Current epoch: 135,
# training performance: {'loss': 0.340155753493309, 'abosulate accuracy': 0.09730000458657742, 'consecutive overlap rate': 0.21085333414375781, 'overlap rate': 0.8839217573404312}
# evaluation performance: {'loss': 2.8789049983024597, 'abosulate accuracy': 0.0010000000474974513, 'consecutive overlap rate': 0.05703083397820592, 'overlap rate': 0.5653208866715431}
#
# Current epoch: 140,
# training performance: {'loss': 0.32883079051971437, 'abosulate accuracy': 0.11250000409781932, 'consecutive overlap rate': 0.22885167002677917, 'overlap rate': 0.8876917481422424}
# evaluation performance: {'loss': 2.897015357017517, 'abosulate accuracy': 0.0009000000427477062, 'consecutive overlap rate': 0.058286667428910734, 'overlap rate': 0.565506724268198}
#
# Current epoch: 145,
# training performance: {'loss': 0.32179159224033355, 'abosulate accuracy': 0.10930000450462103, 'consecutive overlap rate': 0.22531166784465312, 'overlap rate': 0.8905350759625434}
# evaluation performance: {'loss': 2.9680304139852525, 'abosulate accuracy': 0.0010500000498723239, 'consecutive overlap rate': 0.05844666729681194, 'overlap rate': 0.5662400603294373}
#
# Current epoch: 150,
# training performance: {'loss': 0.32244163677096366, 'abosulate accuracy': 0.10660000462085009, 'consecutive overlap rate': 0.2229416687041521, 'overlap rate': 0.8894100859761238}
# evaluation performance: {'loss': 3.033910745382309, 'abosulate accuracy': 0.0009500000451225787, 'consecutive overlap rate': 0.056971667287871244, 'overlap rate': 0.5646508947014809}
#
# Current epoch: 155,
# training performance: {'loss': 0.3046999178826809, 'abosulate accuracy': 0.11770000420510769, 'consecutive overlap rate': 0.2361466683447361, 'overlap rate': 0.895450085401535}
# evaluation performance: {'loss': 3.091394770145416, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.05467750085517764, 'overlap rate': 0.5610333882272244}
#
# Current epoch: 160,
# training performance: {'loss': 0.3078841730952263, 'abosulate accuracy': 0.11800000481307507, 'consecutive overlap rate': 0.23618841990828515, 'overlap rate': 0.8945880547165871}
# evaluation performance: {'loss': 3.0973325222730637, 'abosulate accuracy': 0.0006500000250525773, 'consecutive overlap rate': 0.057543969620019196, 'overlap rate': 0.5641954928636551}
#
# Current epoch: 165,
# training performance: {'loss': 0.29942687749862673, 'abosulate accuracy': 0.11830000448971986, 'consecutive overlap rate': 0.2423450019210577, 'overlap rate': 0.8972200810909271}
# evaluation performance: {'loss': 3.1023146748542785, 'abosulate accuracy': 0.0010500000498723239, 'consecutive overlap rate': 0.058919167472049595, 'overlap rate': 0.5667975559830666}
#
# Current epoch: 170,
# training performance: {'loss': 0.3233755335211754, 'abosulate accuracy': 0.10280000492930412, 'consecutive overlap rate': 0.21706000231206418, 'overlap rate': 0.8895534068346024}
# evaluation performance: {'loss': 3.2558001220226287, 'abosulate accuracy': 0.0007500000356230885, 'consecutive overlap rate': 0.054778334032744166, 'overlap rate': 0.5581267237663269}
#
# Current epoch: 175,
# training performance: {'loss': 0.27391547337174416, 'abosulate accuracy': 0.14210000596940517, 'consecutive overlap rate': 0.26649167016148567, 'overlap rate': 0.9064417526125907}
# evaluation performance: {'loss': 3.1571076452732085, 'abosulate accuracy': 0.0009000000427477062, 'consecutive overlap rate': 0.0592466673348099, 'overlap rate': 0.5675808899104595}
#
# Current epoch: 180,
# training performance: {'loss': 0.2904897160828114, 'abosulate accuracy': 0.11990000382065773, 'consecutive overlap rate': 0.24309667125344275, 'overlap rate': 0.8996000811457634}
# evaluation performance: {'loss': 3.2381498336791994, 'abosulate accuracy': 0.0010500000498723239, 'consecutive overlap rate': 0.057822500634938476, 'overlap rate': 0.5651800654828548}
#
# Current epoch: 185,
# training performance: {'loss': 0.26680534668266775, 'abosulate accuracy': 0.1372000051662326, 'consecutive overlap rate': 0.2652100034058094, 'overlap rate': 0.9085900813341141}
# evaluation performance: {'loss': 3.2650934606790543, 'abosulate accuracy': 0.0006000000284984708, 'consecutive overlap rate': 0.055801667273044586, 'overlap rate': 0.563864229619503}
#
# Current epoch: 190,
# training performance: {'loss': 0.30607002377510073, 'abosulate accuracy': 0.10920000337064266, 'consecutive overlap rate': 0.2254033364355564, 'overlap rate': 0.8941250875592232}
# ...
# evaluation performance: {'loss': 2.5038252413272857, 'abosulate accuracy': 0.21320000886917115, 'consecutive overlap rate': 0.3225216712802649, 'overlap rate': 0.7446133986115455}
#
# Current epoch: 155,
# training performance: {'loss': 0.003594711673213169, 'abosulate accuracy': 0.9936000391840935, 'consecutive overlap rate': 0.9976833418011666, 'overlap rate': 0.9998900696635247}
# evaluation performance: {'loss': 2.6892829656600954, 'abosulate accuracy': 0.2306000104174018, 'consecutive overlap rate': 0.33810479156672957, 'overlap rate': 0.7507948391139507}
#
# Current epoch: 160,
# training performance: {'loss': 0.0011236901715165003, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 2.860666036605835, 'abosulate accuracy': 0.23050001002848147, 'consecutive overlap rate': 0.3380025040358305, 'overlap rate': 0.7495100609958172}
#
# Current epoch: 165,
# training performance: {'loss': 0.0008058314575464465, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 2.9655933737754823, 'abosulate accuracy': 0.23050001114606858, 'consecutive overlap rate': 0.3380766697227955, 'overlap rate': 0.7486042253673076}
#
# Current epoch: 170,
# training performance: {'loss': 0.000628295999194961, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.0501314967870714, 'abosulate accuracy': 0.22980001010000706, 'consecutive overlap rate': 0.3372450016438961, 'overlap rate': 0.7475633956491947}
#
# Current epoch: 175,
# training performance: {'loss': 0.000509024111670442, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.1236851096153258, 'abosulate accuracy': 0.22760000992566348, 'consecutive overlap rate': 0.3357491701841354, 'overlap rate': 0.7470208995044232}
#
# Current epoch: 180,
# training performance: {'loss': 0.00043234030381427145, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.1733671933412553, 'abosulate accuracy': 0.22665001060813667, 'consecutive overlap rate': 0.3330708369612694, 'overlap rate': 0.7473358973860741}
#
# Current epoch: 185,
# training performance: {'loss': 0.0009806771435250995, 'abosulate accuracy': 0.9968000262975693, 'consecutive overlap rate': 0.998563340306282, 'overlap rate': 0.9999317079782486}
# evaluation performance: {'loss': 3.211170795559883, 'abosulate accuracy': 0.22255000993609428, 'consecutive overlap rate': 0.3299341693520546, 'overlap rate': 0.7452958911657334}
#
# Current epoch: 190,
# training performance: {'loss': 0.07375307641923427, 'abosulate accuracy': 0.4694000244140625, 'consecutive overlap rate': 0.6252966731786728, 'overlap rate': 0.9741450697183609}
# evaluation performance: {'loss': 2.1173039853572844, 'abosulate accuracy': 0.2299500111490488, 'consecutive overlap rate': 0.33942583613097665, 'overlap rate': 0.7521225646138191}
#
# Current epoch: 195,
# training performance: {'loss': 0.009619796625338494, 'abosulate accuracy': 0.9435000449419022, 'consecutive overlap rate': 0.9732533425092698, 'overlap rate': 0.9989600628614426}
# evaluation performance: {'loss': 2.445143628120422, 'abosulate accuracy': 0.24215001054108143, 'consecutive overlap rate': 0.35032167211174964, 'overlap rate': 0.755552563071251}
#
# Current epoch: 200,
# training performance: {'loss': 0.001435736395069398, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 2.6801836460828783, 'abosulate accuracy': 0.24435001108795404, 'consecutive overlap rate': 0.3524925045669079, 'overlap rate': 0.7553983986377716}
#
# Experiments_Logs/Experiment#6/LSTM/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/LSTM/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.5547466591000556, 'abosulate accuracy': 0.24337501134723424, 'consecutive overlap rate': 0.35174458753317595, 'overlap rate': 0.7559608966112137}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.7712344288825985, 'abosulate accuracy': 2.5000001187436283e-05, 'consecutive overlap rate': 0.20235495809465648, 'overlap rate': 0.420422725379467}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.109291485817201, 'abosulate accuracy': 0.08936263551154444, 'consecutive overlap rate': 0.15072133454584305, 'overlap rate': 0.6188819508398733}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 7.480903725875051, 'abosulate accuracy': 0.00031578948868340567, 'consecutive overlap rate': 0.1427919129399877, 'overlap rate': 0.3393886446168548}
# Experiments_Logs/Experiment#6/LSTM/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.1400263234972954, 'abosulate accuracy': 0.006200000236276537, 'consecutive overlap rate': 0.07305000117048621, 'overlap rate': 0.6385550573468208}
# evaluation performance: {'loss': 1.4904217690229415, 'abosulate accuracy': 0.005850000202190131, 'consecutive overlap rate': 0.07769500073045492, 'overlap rate': 0.5519533835351467}
#
# Current epoch: 10,
# training performance: {'loss': 0.6204235136508942, 'abosulate accuracy': 0.10070000421255827, 'consecutive overlap rate': 0.21813333556056022, 'overlap rate': 0.7865984097123147}
# evaluation performance: {'loss': 1.2981366008520125, 'abosulate accuracy': 0.07800000379793345, 'consecutive overlap rate': 0.19023768603801727, 'overlap rate': 0.652639952301979}
#
# Current epoch: 15,
# training performance: {'loss': 0.39677667170763015, 'abosulate accuracy': 0.2252000093460083, 'consecutive overlap rate': 0.35332167223095895, 'overlap rate': 0.8581067323684692}
# evaluation performance: {'loss': 1.1858802154660224, 'abosulate accuracy': 0.1508000060915947, 'consecutive overlap rate': 0.2682933369651437, 'overlap rate': 0.7123242236673832}
#
# Current epoch: 20,
# training performance: {'loss': 0.2875464133918285, 'abosulate accuracy': 0.3062000147998333, 'consecutive overlap rate': 0.4360121235251427, 'overlap rate': 0.8958372727036477}
# evaluation performance: {'loss': 1.2163651272654534, 'abosulate accuracy': 0.18580000791698695, 'consecutive overlap rate': 0.30574333779513835, 'overlap rate': 0.7347125686705113}
#
# Current epoch: 25,
# training performance: {'loss': 0.21850799359381198, 'abosulate accuracy': 0.36120001673698426, 'consecutive overlap rate': 0.49730000346899034, 'overlap rate': 0.9202567428350449}
# evaluation performance: {'loss': 1.3123328298330308, 'abosulate accuracy': 0.1959000088274479, 'consecutive overlap rate': 0.31018250361084937, 'overlap rate': 0.7410542346537113}
#
# Current epoch: 30,
# training performance: {'loss': 0.16443231999874114, 'abosulate accuracy': 0.4095000192523003, 'consecutive overlap rate': 0.551086676120758, 'overlap rate': 0.9406750813126564}
# evaluation performance: {'loss': 1.4548373624682427, 'abosulate accuracy': 0.20425000861287118, 'consecutive overlap rate': 0.31874250508844854, 'overlap rate': 0.7452675692737103}
#
# Current epoch: 35,
# training performance: {'loss': 0.13177592158317566, 'abosulate accuracy': 0.42680002078413964, 'consecutive overlap rate': 0.5792983427643776, 'overlap rate': 0.953295074403286}
# evaluation performance: {'loss': 1.5826673969626426, 'abosulate accuracy': 0.195000009983778, 'consecutive overlap rate': 0.3051125034689903, 'overlap rate': 0.7426458932459354}
#
# Current epoch: 40,
# training performance: {'loss': 0.1034512136131525, 'abosulate accuracy': 0.4606000192463398, 'consecutive overlap rate': 0.6189700067043304, 'overlap rate': 0.9642684042453766}
# evaluation performance: {'loss': 1.7212877541780471, 'abosulate accuracy': 0.1970000084489584, 'consecutive overlap rate': 0.3093766704201698, 'overlap rate': 0.7422100692987442}
#
# Current epoch: 45,
# training performance: {'loss': 0.08494954463094473, 'abosulate accuracy': 0.47920001819729807, 'consecutive overlap rate': 0.6387033417820931, 'overlap rate': 0.971151739358902}
# evaluation performance: {'loss': 1.8784286767244338, 'abosulate accuracy': 0.1962500089779496, 'consecutive overlap rate': 0.30752250328660014, 'overlap rate': 0.7403975650668144}
#
# Current epoch: 50,
# training performance: {'loss': 0.068272471614182, 'abosulate accuracy': 0.5093000195920467, 'consecutive overlap rate': 0.6779683366417885, 'overlap rate': 0.9775000736117363}
# evaluation performance: {'loss': 2.020625638961792, 'abosulate accuracy': 0.18805000875145197, 'consecutive overlap rate': 0.298254169896245, 'overlap rate': 0.7367258988320827}
#
# Current epoch: 55,
# training performance: {'loss': 0.04784918650984764, 'abosulate accuracy': 0.590700027346611, 'consecutive overlap rate': 0.7453216716647149, 'overlap rate': 0.9855700492858886}
# evaluation performance: {'loss': 2.1496272876858713, 'abosulate accuracy': 0.19230000888928772, 'consecutive overlap rate': 0.3026108365505934, 'overlap rate': 0.7381717316806317}
#
# Current epoch: 60,
# training performance: {'loss': 0.04102766024880111, 'abosulate accuracy': 0.6148000255227088, 'consecutive overlap rate': 0.7683650076389312, 'overlap rate': 0.9877133890986443}
# evaluation performance: {'loss': 2.308746838569641, 'abosulate accuracy': 0.19060000833123922, 'consecutive overlap rate': 0.3022108364850283, 'overlap rate': 0.7367350690066814}
#
# Current epoch: 65,
# training performance: {'loss': 0.05214046407490969, 'abosulate accuracy': 0.5349000252783298, 'consecutive overlap rate': 0.6974033385515213, 'overlap rate': 0.9825517281889915}
# evaluation performance: {'loss': 2.3703834295272825, 'abosulate accuracy': 0.17855000905692578, 'consecutive overlap rate': 0.2891183357685804, 'overlap rate': 0.732208401709795}
#
# Current epoch: 70,
# training performance: {'loss': 0.046196226961910725, 'abosulate accuracy': 0.5551000274717808, 'consecutive overlap rate': 0.7114050075411796, 'overlap rate': 0.9847183957695961}
# evaluation performance: {'loss': 2.414153379201889, 'abosulate accuracy': 0.1789000080898404, 'consecutive overlap rate': 0.28914083670824764, 'overlap rate': 0.7332917369902134}
#
# Current epoch: 75,
# training performance: {'loss': 0.02419927204027772, 'abosulate accuracy': 0.7327000334858894, 'consecutive overlap rate': 0.8465783447027206, 'overlap rate': 0.9934183821082115}
# evaluation performance: {'loss': 2.5254769921302795, 'abosulate accuracy': 0.1842500077560544, 'consecutive overlap rate': 0.2979225037619472, 'overlap rate': 0.7359817333519458}
#
# Current epoch: 80,
# training performance: {'loss': 0.005293582938611508, 'abosulate accuracy': 0.9763000443577766, 'consecutive overlap rate': 0.9915357753634453, 'overlap rate': 0.9995646446943283}
# evaluation performance: {'loss': 2.6888753920793533, 'abosulate accuracy': 0.19185000844299793, 'consecutive overlap rate': 0.30436833649873735, 'overlap rate': 0.7393592335283756}
#
# Current epoch: 85,
# training performance: {'loss': 0.0013759084831690416, 'abosulate accuracy': 0.9982000142335892, 'consecutive overlap rate': 0.9995766714215278, 'overlap rate': 0.9999650254845619}
# evaluation performance: {'loss': 2.8411532551050187, 'abosulate accuracy': 0.19495000913739205, 'consecutive overlap rate': 0.30785333812236787, 'overlap rate': 0.7393450662493706}
#
# Current epoch: 90,
# training performance: {'loss': 0.000793163436173927, 'abosulate accuracy': 0.9998000010848045, 'consecutive overlap rate': 0.9998616665601731, 'overlap rate': 0.9999866679310798}
# evaluation performance: {'loss': 2.9379337191581727, 'abosulate accuracy': 0.1959500097669661, 'consecutive overlap rate': 0.309021669998765, 'overlap rate': 0.7391683958470822}
#
# Current epoch: 95,
# training performance: {'loss': 0.0005528596833755728, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.0238840609788893, 'abosulate accuracy': 0.19635000955313445, 'consecutive overlap rate': 0.3091325029730797, 'overlap rate': 0.7387200623750687}
#
# Current epoch: 100,
# training performance: {'loss': 0.0004496280365856364, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.0884479612112044, 'abosulate accuracy': 0.1970000086352229, 'consecutive overlap rate': 0.3099541708827019, 'overlap rate': 0.7385650642216206}
#
# Current epoch: 105,
# training performance: {'loss': 0.0003768746952118818, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.1470411509275436, 'abosulate accuracy': 0.19595000818371772, 'consecutive overlap rate': 0.3093308351933956, 'overlap rate': 0.7383833952248097}
#
# Current epoch: 110,
# training performance: {'loss': 0.00032110983302118256, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.2024350434541704, 'abosulate accuracy': 0.19550000894814729, 'consecutive overlap rate': 0.30908500254154203, 'overlap rate': 0.7379492312669754}
#
# Current epoch: 115,
# training performance: {'loss': 0.0002766805831925012, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.257639914751053, 'abosulate accuracy': 0.19510000869631766, 'consecutive overlap rate': 0.30863750390708444, 'overlap rate': 0.7374808989465237}
#
# Current epoch: 120,
# training performance: {'loss': 0.00024027433792070952, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.308469223976135, 'abosulate accuracy': 0.1952500089071691, 'consecutive overlap rate': 0.308780837059021, 'overlap rate': 0.7368909031152725}
#
# Current epoch: 125,
# training performance: {'loss': 0.00020975027982785832, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.3575963914394378, 'abosulate accuracy': 0.19490000922232867, 'consecutive overlap rate': 0.3084958355873823, 'overlap rate': 0.7366275668144227}
#
# Current epoch: 130,
# training performance: {'loss': 0.0001843751611886546, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.4027048379182814, 'abosulate accuracy': 0.1943000081926584, 'consecutive overlap rate': 0.30805417113006117, 'overlap rate': 0.7364775694906711}
#
# Current epoch: 135,
# training performance: {'loss': 0.00016188334593607577, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.4537683576345444, 'abosulate accuracy': 0.19365000836551188, 'consecutive overlap rate': 0.3073783375322819, 'overlap rate': 0.735969228297472}
#
# Current epoch: 140,
# training performance: {'loss': 0.00014282458905654494, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.5023915588855745, 'abosulate accuracy': 0.1933000085875392, 'consecutive overlap rate': 0.3071663029491901, 'overlap rate': 0.7354602292180061}
#
# Current epoch: 145,
# training performance: {'loss': 0.0001263233187273727, 'abosulate accuracy': 1.0, 'consecutive overlap rate': 1.0, 'overlap rate': 1.0}
# evaluation performance: {'loss': 3.552269461750984, 'abosulate accuracy': 0.19275000970810652, 'consecutive overlap rate': 0.30662272982299327, 'overlap rate': 0.7351116463541985}

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
