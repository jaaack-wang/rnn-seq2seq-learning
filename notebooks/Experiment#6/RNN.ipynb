# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 512
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = True 
use_attention = False
reduction_method = torch.sum

learning_rate = 1e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 6
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#6/RNN created!
# ./Experiments_Logs/Experiment#6/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#6/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#6/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#6 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9325275361537932, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007600000153615838, 'overlap rate': 0.430008377879858}
# evaluation performance: {'loss': 1.963646487891674, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006758333485777257, 'overlap rate': 0.4290475446730852}
#
# Current epoch: 10,
# training performance: {'loss': 1.9204555094242095, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007900000171503052, 'overlap rate': 0.43128671273589136}
# evaluation performance: {'loss': 1.9205702736973762, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00069583334861818, 'overlap rate': 0.4299633756279945}
#
# Current epoch: 15,
# training performance: {'loss': 1.927506646513939, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009150000201771036, 'overlap rate': 0.43083837926387786}
# evaluation performance: {'loss': 1.9370170652866363, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333458972629, 'overlap rate': 0.429816710203886}
#
# Current epoch: 20,
# training performance: {'loss': 1.910313880443573, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009433333543711342, 'overlap rate': 0.4327667146921158}
# evaluation performance: {'loss': 1.9161595731973649, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000721666682511568, 'overlap rate': 0.43081337958574295}
#
# Current epoch: 25,
# training performance: {'loss': 1.9234801292419434, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010133333555131685, 'overlap rate': 0.43195004388689995}
# evaluation performance: {'loss': 1.9821023359894752, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007825000171578722, 'overlap rate': 0.4304575428366661}
#
# Current epoch: 30,
# training performance: {'loss': 1.9037686884403229, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001010000020323787, 'overlap rate': 0.4334167130291462}
# evaluation performance: {'loss': 1.903256595134735, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007616666844114661, 'overlap rate': 0.4307325419038534}
#
# Current epoch: 35,
# training performance: {'loss': 1.9008144944906236, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010800000236486085, 'overlap rate': 0.43421171307563783}
# evaluation performance: {'loss': 1.9020636036992074, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007525000193709275, 'overlap rate': 0.4306475445628166}
#
# Current epoch: 40,
# training performance: {'loss': 1.8991243541240692, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011716666893335059, 'overlap rate': 0.43456837460398673}
# evaluation performance: {'loss': 1.9017462074756621, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008050000164075754, 'overlap rate': 0.4306458756327629}
#
# Current epoch: 45,
# training performance: {'loss': 1.9185960114002227, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011783333524363116, 'overlap rate': 0.433533376455307}
# evaluation performance: {'loss': 1.9084006503224373, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007583333492220846, 'overlap rate': 0.43079587668180463}
#
# Current epoch: 50,
# training performance: {'loss': 1.8974863141775131, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013383333673118614, 'overlap rate': 0.4354633778333664}
# evaluation performance: {'loss': 1.9015463054180146, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00088166668501799, 'overlap rate': 0.43105004243552686}
#
# Current epoch: 55,
# training performance: {'loss': 1.896852770447731, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001418333360925317, 'overlap rate': 0.4358017072081566}
# evaluation performance: {'loss': 1.9010595992207526, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000979166684919619, 'overlap rate': 0.4312358796596527}
#
# Current epoch: 60,
# training performance: {'loss': 1.9045067101716995, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016175706463400275, 'overlap rate': 0.4362207755446434}
# evaluation performance: {'loss': 1.983948740363121, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010485028418770526, 'overlap rate': 0.43088609986007215}
#
# Current epoch: 65,
# training performance: {'loss': 1.8885687828063964, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019383333623409272, 'overlap rate': 0.4381183758378029}
# evaluation performance: {'loss': 1.8950825363397599, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014225000209989957, 'overlap rate': 0.4331308797001839}
#
# Current epoch: 70,
# training performance: {'loss': 1.8862371295690536, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002066666691098362, 'overlap rate': 0.4390133790671825}
# evaluation performance: {'loss': 1.8956920847296714, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016116666927700862, 'overlap rate': 0.4340117108076811}
#
# Current epoch: 75,
# training performance: {'loss': 1.880791974067688, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0024033333524130286, 'overlap rate': 0.44107171669602396}
# evaluation performance: {'loss': 1.9023971080780029, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019475000182865188, 'overlap rate': 0.43509337641298773}
#
# Current epoch: 80,
# training performance: {'loss': 2.100939479470253, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008169491680746433, 'overlap rate': 0.4110282935202122}
# evaluation performance: {'loss': 4.64372119307518, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006700706373521826, 'overlap rate': 0.4186226114630699}
#
# Current epoch: 85,
# training performance: {'loss': 1.9219669431447983, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008933333498134744, 'overlap rate': 0.4319900445640087}
# evaluation performance: {'loss': 2.3031138271093368, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006966666813241317, 'overlap rate': 0.4287192091345787}
#
# Current epoch: 90,
# training performance: {'loss': 1.9160716891288758, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008566666772821918, 'overlap rate': 0.4328933790326118}
# evaluation performance: {'loss': 1.9808910623192788, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006566666819708189, 'overlap rate': 0.4302217110991478}
#
# Current epoch: 95,
# training performance: {'loss': 1.908490279316902, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000920000016776612, 'overlap rate': 0.4339000418782234}
# evaluation performance: {'loss': 1.9904691755771637, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006966666809603339, 'overlap rate': 0.4300942122936249}
#
# Current epoch: 100,
# training performance: {'loss': 1.9034523576498033, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009766666895302477, 'overlap rate': 0.43397504910826684}
# evaluation performance: {'loss': 1.9084313631057739, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007368079270236195, 'overlap rate': 0.4304973341524601}
#
# Current epoch: 105,
# training performance: {'loss': 1.9216492176055908, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008016666812181939, 'overlap rate': 0.43216838091611864}
# evaluation performance: {'loss': 1.929636113345623, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006725000130245462, 'overlap rate': 0.43009754568338393}
#
# Current epoch: 110,
# training performance: {'loss': 1.9048590630292892, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008766666906012688, 'overlap rate': 0.43445837646722796}
# evaluation performance: {'loss': 1.966771848499775, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333486964693, 'overlap rate': 0.42502004466950893}
#
# Current epoch: 115,
# training performance: {'loss': 1.9021420627832413, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009516666832496412, 'overlap rate': 0.4347567118704319}
# evaluation performance: {'loss': 1.908108578622341, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007016666808340233, 'overlap rate': 0.43052171021699903}
#
# Current epoch: 120,
# training performance: {'loss': 1.9073157459497452, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009350000160338823, 'overlap rate': 0.4342267096042633}
# evaluation performance: {'loss': 1.9809725239872933, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007091666842825361, 'overlap rate': 0.43038421124219894}
#
# Current epoch: 125,
# training performance: {'loss': 1.8961978942155837, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009600000194041058, 'overlap rate': 0.43521171137690545}
# evaluation performance: {'loss': 1.9024610549211503, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007083333494847466, 'overlap rate': 0.43047504499554634}
#
# Current epoch: 130,
# training performance: {'loss': 1.896228450536728, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009416666885954328, 'overlap rate': 0.4352217078208923}
# evaluation performance: {'loss': 1.9012596368789674, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007066666805258138, 'overlap rate': 0.43079087510704994}
#
# Current epoch: 135,
# training performance: {'loss': 1.8943739235401154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010316666870494374, 'overlap rate': 0.4357267126441002}
# evaluation performance: {'loss': 1.9008775308728219, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007383333504549228, 'overlap rate': 0.43069587722420694}
#
# Current epoch: 140,
# training performance: {'loss': 1.893550843000412, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011066666891565546, 'overlap rate': 0.4364350467920303}
# evaluation performance: {'loss': 1.9006214141845703, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007300000164832454, 'overlap rate': 0.43098254352807996}
#
# Current epoch: 145,
# training performance: {'loss': 1.8937501162290573, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010983333508193028, 'overlap rate': 0.4365300439298153}
# evaluation performance: {'loss': 1.9003225669264794, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007308333500986919, 'overlap rate': 0.43064338229596616}
#
# Current epoch: 150,
# training performance: {'loss': 1.8928036361932754, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011500000196974724, 'overlap rate': 0.4370883762836456}
# evaluation performance: {'loss': 1.899950134754181, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008116666816931683, 'overlap rate': 0.43085421025753023}
#
# Current epoch: 155,
# training performance: {'loss': 1.9072528153657913, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010016666841693223, 'overlap rate': 0.4352383777499199}
# evaluation performance: {'loss': 2.0112077727913857, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007509745915740496, 'overlap rate': 0.4304853841662407}
#
# Current epoch: 160,
# training performance: {'loss': 1.9195644229650497, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010883333583478817, 'overlap rate': 0.43455171287059785}
# evaluation performance: {'loss': 1.904575414955616, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007733333506621421, 'overlap rate': 0.43093837425112724}
#
# Current epoch: 165,
# training performance: {'loss': 1.9019845962524413, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012366666967864148, 'overlap rate': 0.43689837828278544}
# evaluation performance: {'loss': 1.9194712147116662, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008550000180548523, 'overlap rate': 0.4308108787983656}
#
# Current epoch: 170,
# training performance: {'loss': 1.886920118331909, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001620000031834934, 'overlap rate': 0.438913381844759}
# evaluation performance: {'loss': 1.895838712155819, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012225000245962292, 'overlap rate': 0.4324400406330824}
#
# Current epoch: 175,
# training performance: {'loss': 1.8832479000091553, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0017466666977270506, 'overlap rate': 0.4398533821105957}
# evaluation performance: {'loss': 1.893499355018139, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001390833353070775, 'overlap rate': 0.4332000471651554}
#
# Current epoch: 180,
# training performance: {'loss': 1.9203701049089432, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013883333595003933, 'overlap rate': 0.43559337630867956}
# evaluation performance: {'loss': 2.154718707501888, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011783333575294819, 'overlap rate': 0.4318758748471737}
#
# Current epoch: 185,
# training performance: {'loss': 1.882463338971138, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018500000238418578, 'overlap rate': 0.44063171222805975}
# evaluation performance: {'loss': 1.9376365825533868, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001450833362468984, 'overlap rate': 0.43343087621033194}
#
# Current epoch: 190,
# training performance: {'loss': 1.8982574671506882, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021495762921404094, 'overlap rate': 0.4409702718257904}
# evaluation performance: {'loss': 1.8996726453304291, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016216666903346778, 'overlap rate': 0.43389254771173}
#
# Current epoch: 195,
# training performance: {'loss': 1.8688477784395219, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0021266666939482094, 'overlap rate': 0.4446983769536018}
# evaluation performance: {'loss': 1.920594798028469, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00159500002337154, 'overlap rate': 0.43407504484057424}
#
# Current epoch: 200,
# training performance: {'loss': 1.8643325507640838, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019600000203354286, 'overlap rate': 0.44700337797403333}
# evaluation performance: {'loss': 1.8984482809901237, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014725000255566556, 'overlap rate': 0.4332700453698635}
#
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.8976495265960693, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014412500269827433, 'overlap rate': 0.433276710100472}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.289589446783066, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0037012352928286417, 'overlap rate': 0.0404937800951302}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.128896265645181, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010197668180485526, 'overlap rate': 0.4078677552361642}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.694999293277138, 'abosulate accuracy': 2.631579072361714e-05, 'consecutive overlap rate': 0.004949505076327018, 'overlap rate': 0.04118272814115411}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9481276988983154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007400000176858157, 'overlap rate': 0.42828837409615517}
# evaluation performance: {'loss': 1.9765354335308074, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006733333470037905, 'overlap rate': 0.4293675430119038}
#
# Current epoch: 10,
# training performance: {'loss': 1.9199606001377105, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007733333462965674, 'overlap rate': 0.43098504543304444}
# evaluation performance: {'loss': 1.9214688658714294, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006900000138557516, 'overlap rate': 0.43055837862193586}
#
# Current epoch: 15,
# training performance: {'loss': 1.9709504932165145, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007116666842193808, 'overlap rate': 0.4268250443041325}
# evaluation performance: {'loss': 2.1435109853744505, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006508333441161085, 'overlap rate': 0.4275533750653267}
#
# Current epoch: 20,
# training performance: {'loss': 1.9137791723012925, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007933333465189208, 'overlap rate': 0.43177837803959845}
# evaluation performance: {'loss': 1.9404906675219535, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006600000146136153, 'overlap rate': 0.429947542399168}
#
# Current epoch: 25,
# training performance: {'loss': 1.919629728794098, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008200000174838351, 'overlap rate': 0.4314450420439243}
# evaluation performance: {'loss': 1.9751182869076729, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006600000153412112, 'overlap rate': 0.4222433760762215}
#
# Current epoch: 30,
# training performance: {'loss': 1.9065563291311265, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008716666838154197, 'overlap rate': 0.43309338092803956}
# evaluation performance: {'loss': 1.9146307855844498, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006875000141917554, 'overlap rate': 0.43030087612569334}
#
# Current epoch: 35,
# training performance: {'loss': 1.9052045315504074, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000888333346665604, 'overlap rate': 0.433605045825243}
# evaluation performance: {'loss': 1.9303725615143776, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006941666792954493, 'overlap rate': 0.43038421086966994}
#
# Current epoch: 40,
# training performance: {'loss': 1.9061524778604508, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009020621648232919, 'overlap rate': 0.43314374312758447}
# evaluation performance: {'loss': 1.9269975543022155, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007135310861485777, 'overlap rate': 0.43084214590489867}
#
# Current epoch: 45,
# training performance: {'loss': 1.8982075542211532, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009550000206218102, 'overlap rate': 0.4339800447225571}
# evaluation performance: {'loss': 1.9007852971553802, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007150000157707837, 'overlap rate': 0.4306333750486374}
#
# Current epoch: 50,
# training performance: {'loss': 1.9054460734128953, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009937288348737638, 'overlap rate': 0.43418936654925344}
# evaluation performance: {'loss': 1.903208900988102, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007233333482872695, 'overlap rate': 0.43046921119093895}
#
# Current epoch: 55,
# training performance: {'loss': 1.896299159526825, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010416666882520076, 'overlap rate': 0.43453837782144544}
# evaluation performance: {'loss': 1.9004932388663291, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007516666806623107, 'overlap rate': 0.4308617077767849}
#
# Current epoch: 60,
# training performance: {'loss': 1.8950358599424362, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001128333355882205, 'overlap rate': 0.4350933775305748}
# evaluation performance: {'loss': 1.900339514017105, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007308333475521067, 'overlap rate': 0.4308608792722225}
#
# Current epoch: 65,
# training performance: {'loss': 1.8943154633045196, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011983333562966437, 'overlap rate': 0.4360183797776699}
# evaluation performance: {'loss': 1.8999841302633285, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007641666843483108, 'overlap rate': 0.4309183765202761}
#
# Current epoch: 70,
# training performance: {'loss': 1.896074777841568, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00101833335502306, 'overlap rate': 0.4349300429224968}
# evaluation performance: {'loss': 1.900985150039196, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007625000162079232, 'overlap rate': 0.43071421086788175}
#
# Current epoch: 75,
# training performance: {'loss': 1.89507414996624, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011566666828002781, 'overlap rate': 0.4357433758676052}
# evaluation performance: {'loss': 1.90071702003479, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007550000183982775, 'overlap rate': 0.4307108785957098}
#
# Current epoch: 80,
# training performance: {'loss': 1.893429046869278, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012583333504153416, 'overlap rate': 0.4365100458264351}
# evaluation performance: {'loss': 1.9000883042812347, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007625000169355189, 'overlap rate': 0.43088670931756495}
#
# Current epoch: 85,
# training performance: {'loss': 1.892666110396385, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013466666976455599, 'overlap rate': 0.4370050422847271}
# evaluation performance: {'loss': 1.900521159172058, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007659887196496129, 'overlap rate': 0.43110373094677923}
#
# Current epoch: 90,
# training performance: {'loss': 1.8919709891080856, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014200000136042946, 'overlap rate': 0.4374667100608349}
# evaluation performance: {'loss': 1.8999376863241195, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007950000164782978, 'overlap rate': 0.43137337565422057}
#
# Current epoch: 95,
# training performance: {'loss': 1.8911287546157838, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001558333361754194, 'overlap rate': 0.43796504139900205}
# evaluation performance: {'loss': 1.8995994955301285, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008791666867182357, 'overlap rate': 0.4315875455737114}
#
# Current epoch: 100,
# training performance: {'loss': 1.9039661228656768, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010200000207987614, 'overlap rate': 0.4352767124772072}
# evaluation performance: {'loss': 2.0421310901641845, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007759463434922509, 'overlap rate': 0.4300213292241096}
#
# Current epoch: 105,
# training performance: {'loss': 1.928503230214119, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012222599107190035, 'overlap rate': 0.43441674038767814}
# evaluation performance: {'loss': 1.9308059185743331, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333473524545, 'overlap rate': 0.4304317101836205}
#
# Current epoch: 110,
# training performance: {'loss': 1.8922050058841706, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00138000002480112, 'overlap rate': 0.43778504580259325}
# evaluation performance: {'loss': 1.901335883140564, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007910169646493159, 'overlap rate': 0.4310133773833513}
#
# Current epoch: 115,
# training performance: {'loss': 1.8910921514034271, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0015266666930983774, 'overlap rate': 0.43851337879896163}
# evaluation performance: {'loss': 1.9002193167805672, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008275000192952576, 'overlap rate': 0.4313767097890377}
#
# Current epoch: 120,
# training performance: {'loss': 1.8901224493980409, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016250000189756975, 'overlap rate': 0.4391367107629776}
# evaluation performance: {'loss': 1.9002412423491477, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008725000170670683, 'overlap rate': 0.43152088224887847}
#
# Current epoch: 125,
# training performance: {'loss': 1.8888231486082077, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018533333553932608, 'overlap rate': 0.43979171440005305}
# evaluation performance: {'loss': 1.901866587996483, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009125000160565833, 'overlap rate': 0.43137337639927864}
#
# Current epoch: 130,
# training performance: {'loss': 1.9118964314460754, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019516666914569214, 'overlap rate': 0.4386783741414547}
# evaluation performance: {'loss': 2.367342096567154, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008816666886559688, 'overlap rate': 0.4299283783882856}
#
# Current epoch: 135,
# training performance: {'loss': 1.8902034282684326, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001730000029783696, 'overlap rate': 0.4391367115080357}
# evaluation performance: {'loss': 1.9008725494146348, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009508333536359714, 'overlap rate': 0.4313592117279768}
#
# Current epoch: 140,
# training performance: {'loss': 1.888517466187477, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018550000357208773, 'overlap rate': 0.4398767098784447}
# evaluation performance: {'loss': 1.9008816540241242, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009708333524031332, 'overlap rate': 0.4316967111080885}
#
# Current epoch: 145,
# training performance: {'loss': 1.8836598873138428, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020916666864650322, 'overlap rate': 0.4411867119371891}
# evaluation performance: {'loss': 1.8985082432627678, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012450000169337728, 'overlap rate': 0.4330308768898249}
#
# Current epoch: 150,
# training performance: {'loss': 1.878821563720703, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0023983333579963074, 'overlap rate': 0.44243504405021666}
# evaluation performance: {'loss': 1.897616371512413, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013491666893969522, 'overlap rate': 0.43319087848067284}
#
# Current epoch: 155,
# training performance: {'loss': 1.8723540604114532, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025516666937619448, 'overlap rate': 0.4443583734333515}
# evaluation performance: {'loss': 1.8979873970150947, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001553333354240749, 'overlap rate': 0.43409837782382965}
#
# Current epoch: 160,
# training performance: {'loss': 1.875620386004448, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00225333335401956, 'overlap rate': 0.44363670945167544}
# evaluation performance: {'loss': 1.8980651870369911, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011550000206625554, 'overlap rate': 0.432810040935874}
#
# Current epoch: 165,
# training performance: {'loss': 1.869566595554352, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002501666694297455, 'overlap rate': 0.44598171189427377}
# evaluation performance: {'loss': 1.8996979951858521, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001403333366761217, 'overlap rate': 0.43339671231806276}
#
# Current epoch: 170,
# training performance: {'loss': 1.872044602036476, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.002568333366070874, 'overlap rate': 0.4456433720886707}
# evaluation performance: {'loss': 1.894799579679966, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016971045493846758, 'overlap rate': 0.43464548178017137}
#
# Current epoch: 175,
# training performance: {'loss': 1.8508536338806152, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0030916667165001854, 'overlap rate': 0.4504417136311531}
# evaluation performance: {'loss': 1.8992846578359603, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018458333579474129, 'overlap rate': 0.435309212654829}
#
# Current epoch: 180,
# training performance: {'loss': 1.8423541128635406, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00309166670194827, 'overlap rate': 0.45293171182274816}
# evaluation performance: {'loss': 1.9155035033822059, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018450000250595621, 'overlap rate': 0.4350133776664734}
#
# Current epoch: 185,
# training performance: {'loss': 1.8372243851423264, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0030683333752676845, 'overlap rate': 0.45476504415273666}
# evaluation performance: {'loss': 1.9447233542799949, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018158333637984469, 'overlap rate': 0.43503170758485793}
#
# Current epoch: 190,
# training performance: {'loss': 1.821097183227539, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003038333373842761, 'overlap rate': 0.4586767129600048}
# evaluation performance: {'loss': 2.0015809297561646, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0018208333596703597, 'overlap rate': 0.434190046787262}
#
# Current epoch: 195,
# training performance: {'loss': 1.8127968221902848, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0031766666914336385, 'overlap rate': 0.46060837879776956}
# evaluation performance: {'loss': 1.9384962603449822, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0019125000282656402, 'overlap rate': 0.4346917115151882}
#
# Current epoch: 200,
# training performance: {'loss': 1.8195051908493043, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003213333379244432, 'overlap rate': 0.4601067155599594}
# evaluation performance: {'loss': 1.9181924685835838, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001922500018554274, 'overlap rate': 0.43436420932412145}
#
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.9169999592006206, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0020083333569345997, 'overlap rate': 0.4343142107129097}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 6.07026526927948, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006036900327308104, 'overlap rate': 0.03964589843526482}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.838205974332748, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0013199808083534722, 'overlap rate': 0.40095965285455026}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.549533969477603, 'abosulate accuracy': 0.00010526316289446856, 'consecutive overlap rate': 0.00816591302128999, 'overlap rate': 0.044537016729775225}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9384166121482849, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007600000171805732, 'overlap rate': 0.42944837883114817}
# evaluation performance: {'loss': 1.9455810964107514, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006933333475899417, 'overlap rate': 0.4290892079472542}
#
# Current epoch: 10,
# training performance: {'loss': 1.9311084896326065, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008083333545073401, 'overlap rate': 0.43080171570181847}
# evaluation performance: {'loss': 1.9510364100337028, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006818502977694151, 'overlap rate': 0.429064704105258}
#
# Current epoch: 15,
# training performance: {'loss': 1.918988585472107, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008683333500812296, 'overlap rate': 0.4319750443100929}
# evaluation performance: {'loss': 1.9260941028594971, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007008333446719917, 'overlap rate': 0.42977920845150946}
#
# Current epoch: 20,
# training performance: {'loss': 1.9100408166646958, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008916666833101772, 'overlap rate': 0.43235004097223284}
# evaluation performance: {'loss': 1.9159274131059647, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007016666830168105, 'overlap rate': 0.43009670823812485}
#
# Current epoch: 25,
# training performance: {'loss': 1.910125121474266, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009450000208744314, 'overlap rate': 0.4330950453877449}
# evaluation performance: {'loss': 1.941451258957386, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006983333496464184, 'overlap rate': 0.4305158782750368}
#
# Current epoch: 30,
# training performance: {'loss': 1.905143576860428, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000978333347302396, 'overlap rate': 0.43346337601542473}
# evaluation performance: {'loss': 1.9082743316888808, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007143079243178363, 'overlap rate': 0.4301177956163883}
#
# Current epoch: 35,
# training performance: {'loss': 1.907161957025528, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009716666878375691, 'overlap rate': 0.4336517103016376}
# evaluation performance: {'loss': 1.917370893061161, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007166666804550914, 'overlap rate': 0.43084587566554544}
#
# Current epoch: 40,
# training performance: {'loss': 1.9016194552183152, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010133333576959557, 'overlap rate': 0.4344033792614937}
# evaluation performance: {'loss': 1.925274133682251, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007300000153918518, 'overlap rate': 0.42945087850093844}
#
# Current epoch: 45,
# training performance: {'loss': 1.898673978447914, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001038333353062626, 'overlap rate': 0.43447171077132224}
# evaluation performance: {'loss': 1.9014486804604531, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007358333485171897, 'overlap rate': 0.4305650442838669}
#
# Current epoch: 50,
# training performance: {'loss': 1.8985091716051101, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010200000200711657, 'overlap rate': 0.43466004356741905}
# evaluation performance: {'loss': 1.9038470014929771, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007152542530093342, 'overlap rate': 0.43023690916597845}
#
# Current epoch: 55,
# training performance: {'loss': 1.9016827136278152, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010050000273622572, 'overlap rate': 0.43482337668538096}
# evaluation performance: {'loss': 1.9030736908316612, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006983333485550247, 'overlap rate': 0.4304025433957577}
#
# Current epoch: 60,
# training performance: {'loss': 1.8960949808359147, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001168333351961337, 'overlap rate': 0.4354650467634201}
# evaluation performance: {'loss': 1.9005351692438126, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007358333492447855, 'overlap rate': 0.430550879240036}
#
# Current epoch: 65,
# training performance: {'loss': 1.8960361033678055, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011933333560591563, 'overlap rate': 0.43559504598379134}
# evaluation performance: {'loss': 1.9008135721087456, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007641666845302098, 'overlap rate': 0.4309567116200924}
#
# Current epoch: 70,
# training performance: {'loss': 1.894375041127205, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0012466666870750488, 'overlap rate': 0.43620671406388284}
# evaluation performance: {'loss': 1.9013653874397278, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008066666825470748, 'overlap rate': 0.4314042065292597}
#
# Current epoch: 75,
# training performance: {'loss': 1.9634168982505797, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007833333511371166, 'overlap rate': 0.42172171026468275}
# evaluation performance: {'loss': 4.789859861135483, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006875000142827048, 'overlap rate': 0.4068708747625351}
#
# Current epoch: 80,
# training performance: {'loss': 1.9496877074241639, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008766666840529069, 'overlap rate': 0.4273050412535667}
# evaluation performance: {'loss': 4.020909970998764, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006783333483326714, 'overlap rate': 0.42083004526793955}
#
# Current epoch: 85,
# training performance: {'loss': 1.9227619141340255, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008400000195251777, 'overlap rate': 0.43214171305298804}
# evaluation performance: {'loss': 1.9796165332198143, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000649166678522306, 'overlap rate': 0.42991421073675157}
#
# Current epoch: 90,
# training performance: {'loss': 1.907452592253685, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008866666794347111, 'overlap rate': 0.43429837971925733}
# evaluation performance: {'loss': 1.9257079526782035, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006533333456900436, 'overlap rate': 0.4303083769977093}
#
# Current epoch: 95,
# training performance: {'loss': 1.9336913079023361, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000905000013881363, 'overlap rate': 0.43158837854862214}
# evaluation performance: {'loss': 2.919753661751747, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006875000159197953, 'overlap rate': 0.42615004256367683}
#
# Current epoch: 100,
# training performance: {'loss': 1.8991884410381317, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009266666864277795, 'overlap rate': 0.43473837822675704}
# evaluation performance: {'loss': 1.9030025482177735, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006883333473524545, 'overlap rate': 0.4304267127066851}
#
# Current epoch: 105,
# training performance: {'loss': 1.897315150499344, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009083333512535319, 'overlap rate': 0.4350800454616547}
# evaluation performance: {'loss': 1.9010112211108208, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006950000155484304, 'overlap rate': 0.43089337833225727}
#
# Current epoch: 110,
# training performance: {'loss': 2.0002445846796038, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007633333530975506, 'overlap rate': 0.41611670702695847}
# evaluation performance: {'loss': 4.871782320737839, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006983333511016099, 'overlap rate': 0.3987542100250721}
#
# Current epoch: 115,
# training performance: {'loss': 1.9603463679552078, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008283333481813315, 'overlap rate': 0.4214917093515396}
# evaluation performance: {'loss': 5.645062899589538, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007058333463646705, 'overlap rate': 0.4090058747678995}
#
# Current epoch: 120,
# training performance: {'loss': 1.951110988855362, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008016666863113642, 'overlap rate': 0.42436004281044004}
# evaluation performance: {'loss': 4.216616702079773, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006891666784213157, 'overlap rate': 0.396940041705966}
#
# Current epoch: 125,
# training performance: {'loss': 1.9496692150831223, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007450000157405157, 'overlap rate': 0.42562004625797273}
# evaluation performance: {'loss': 5.091735428571701, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006841666836407967, 'overlap rate': 0.4188150431960821}
#
# Current epoch: 130,
# training performance: {'loss': 1.955891302227974, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000786892670294037, 'overlap rate': 0.4250781774520874}
# evaluation performance: {'loss': 2.9984293311834334, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007066666821629042, 'overlap rate': 0.41092754527926445}
#
# Current epoch: 135,
# training performance: {'loss': 1.9273000627756118, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008616666920715943, 'overlap rate': 0.43160837739706037}
# evaluation performance: {'loss': 2.116688071191311, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006695480375128682, 'overlap rate': 0.4259209752082825}
#
# Current epoch: 140,
# training performance: {'loss': 1.9135000258684158, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008333333535119891, 'overlap rate': 0.4341417096555233}
# evaluation performance: {'loss': 1.957520878314972, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007066666832542979, 'overlap rate': 0.4304883785545826}
#
# Current epoch: 145,
# training performance: {'loss': 1.8985575735569, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000910000017756829, 'overlap rate': 0.43481837660074235}
# evaluation performance: {'loss': 1.9025190055370331, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006691666792903561, 'overlap rate': 0.4307267103344202}
#
# Current epoch: 150,
# training performance: {'loss': 1.8956334948539735, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009366666803543921, 'overlap rate': 0.43553671017289164}
# evaluation performance: {'loss': 1.9010490968823432, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006708333479764405, 'overlap rate': 0.43085671216249466}
#
# Current epoch: 155,
# training performance: {'loss': 1.8956255853176116, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008900000182620715, 'overlap rate': 0.4356267139315605}
# evaluation performance: {'loss': 1.9016346737742424, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006510452113616339, 'overlap rate': 0.4305464293807745}
#
# Current epoch: 160,
# training performance: {'loss': 1.8940803050994872, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009383333512232639, 'overlap rate': 0.43622170835733415}
# evaluation performance: {'loss': 1.9003680795431137, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006800000162911601, 'overlap rate': 0.4309050414711237}
#
# Current epoch: 165,
# training performance: {'loss': 1.899001106619835, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0008600000182923395, 'overlap rate': 0.4352667070925236}
# evaluation performance: {'loss': 1.9032787710428238, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007283333496161503, 'overlap rate': 0.43069587610661986}
#
# Current epoch: 170,
# training performance: {'loss': 1.9313336044549942, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009936723356076982, 'overlap rate': 0.43325467556715014}
# evaluation performance: {'loss': 2.3334203124046327, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0007033333440631395, 'overlap rate': 0.38863503821194173}
#
# Current epoch: 175,
# training performance: {'loss': 1.8935450911521912, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000958333355083596, 'overlap rate': 0.43696338310837746}
# evaluation performance: {'loss': 1.9006865277886391, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006866666804853594, 'overlap rate': 0.4308625482022762}
#
# Current epoch: 180,
# training performance: {'loss': 1.8930128544569016, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009683333548309748, 'overlap rate': 0.4369017079472542}
# evaluation performance: {'loss': 1.9007142305374145, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006733333495503758, 'overlap rate': 0.4308025438338518}
#
# Current epoch: 185,
# training performance: {'loss': 1.8928810238838196, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009516666876152157, 'overlap rate': 0.43719337731599806}
# evaluation performance: {'loss': 1.900518923997879, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006891666824230924, 'overlap rate': 0.43087504580616953}
#
# Current epoch: 190,
# training performance: {'loss': 1.8919839918613435, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009950000196113252, 'overlap rate': 0.4377167157828808}
# evaluation performance: {'loss': 1.9002887904644012, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006791666808567242, 'overlap rate': 0.4312475424259901}
#
# Current epoch: 195,
# training performance: {'loss': 1.8915726214647293, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0009950000181561335, 'overlap rate': 0.43767837435007095}
# evaluation performance: {'loss': 1.90066901743412, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006816666826125583, 'overlap rate': 0.4310417104512453}
#
# Current epoch: 200,
# training performance: {'loss': 1.8910502940416336, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0010466666913998778, 'overlap rate': 0.4380067102611065}
# evaluation performance: {'loss': 1.9004189565777778, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.000684166682913201, 'overlap rate': 0.4310975454747677}
#
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.900449024885893, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0006654166804764827, 'overlap rate': 0.431165043823421}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.416701853275299, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001913417836476583, 'overlap rate': 0.03646808499470353}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.835807003513459, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0004949368567453817, 'overlap rate': 0.3905283599130569}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 7.676640880735297, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0038900341207504666, 'overlap rate': 0.030060862460614818}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.8960621535778046, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005586666753515601, 'overlap rate': 0.4436800450086594}
# evaluation performance: {'loss': 1.9151834920048714, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006672500091372058, 'overlap rate': 0.4455742139369249}
#
# Current epoch: 10,
# training performance: {'loss': 1.8372933387756347, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011515000043436885, 'overlap rate': 0.4637467198073864}
# evaluation performance: {'loss': 1.874695061147213, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011030833492986858, 'overlap rate': 0.4610117141157389}
#
# Current epoch: 15,
# ...
#
# Experiments_Logs/Experiment#6/RNN/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/RNN/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.7553260579705237, 'abosulate accuracy': 0.35637501552700995, 'consecutive overlap rate': 0.44618500508368014, 'overlap rate': 0.6430683810263872}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 3.6707451432943343, 'abosulate accuracy': 0.2562250132672489, 'consecutive overlap rate': 0.4077420350164175, 'overlap rate': 0.5298204839229583}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 6.1633957709035565, 'abosulate accuracy': 0.018946790956561602, 'consecutive overlap rate': 0.11623908536088082, 'overlap rate': 0.48103427021734174}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 6.217951774597168, 'abosulate accuracy': 0.21050000577968986, 'consecutive overlap rate': 0.3306874464216985, 'overlap rate': 0.4255553785907595}
# Experiments_Logs/Experiment#6/RNN/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9186101466417314, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004903333389665932, 'overlap rate': 0.4403617106378078}
# evaluation performance: {'loss': 2.004670736193657, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005511666741222143, 'overlap rate': 0.44114338159561156}
#
# Current epoch: 10,
# training performance: {'loss': 1.8638202995061874, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010650000162422657, 'overlap rate': 0.45732504650950434}
# evaluation performance: {'loss': 1.9256797328591346, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010661666782107204, 'overlap rate': 0.45623504631221296}
#
# Current epoch: 15,
# training performance: {'loss': 1.802305680513382, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011581666674464941, 'overlap rate': 0.4779517129063606}
# evaluation performance: {'loss': 1.8777952298521996, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01133166680810973, 'overlap rate': 0.47232754789292813}
#
# Current epoch: 20,
# training performance: {'loss': 1.6172117322683335, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01682000015862286, 'overlap rate': 0.5342217281460762}
# evaluation performance: {'loss': 1.8575048059225083, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01646333353128284, 'overlap rate': 0.4844067178666592}
#
# Current epoch: 25,
# training performance: {'loss': 1.4341424882411957, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.025071667041629553, 'overlap rate': 0.588801720738411}
# evaluation performance: {'loss': 1.9027422159910201, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.024599166866391898, 'overlap rate': 0.4977058868855238}
#
# Current epoch: 30,
# training performance: {'loss': 1.2793830454349517, 'abosulate accuracy': 0.0011000000522471964, 'consecutive overlap rate': 0.03427666728384793, 'overlap rate': 0.6352383986115455}
# evaluation performance: {'loss': 1.8180058419704437, 'abosulate accuracy': 0.0015500000736210495, 'consecutive overlap rate': 0.03329159640707076, 'overlap rate': 0.5040788255631924}
#
# Current epoch: 35,
# training performance: {'loss': 1.1450856000185012, 'abosulate accuracy': 0.007100000232458115, 'consecutive overlap rate': 0.04988500056788325, 'overlap rate': 0.6764433965086937}
# evaluation performance: {'loss': 1.8710669815540313, 'abosulate accuracy': 0.008550000307150186, 'consecutive overlap rate': 0.050556667149066925, 'overlap rate': 0.5192475523799658}
#
# Current epoch: 40,
# training performance: {'loss': 1.0652253553271294, 'abosulate accuracy': 0.0198000006377697, 'consecutive overlap rate': 0.06962833413854241, 'overlap rate': 0.7001717329025269}
# evaluation performance: {'loss': 1.8714946582913399, 'abosulate accuracy': 0.01815000071073882, 'consecutive overlap rate': 0.06697166753001511, 'overlap rate': 0.5236183855682611}
#
# Current epoch: 45,
# training performance: {'loss': 0.9984608843922615, 'abosulate accuracy': 0.03290000157430768, 'consecutive overlap rate': 0.08995000030845404, 'overlap rate': 0.7186484053730965}
# evaluation performance: {'loss': 1.9212037369608879, 'abosulate accuracy': 0.03530000164173543, 'consecutive overlap rate': 0.09088500114157796, 'overlap rate': 0.5310392189770937}
#
# Current epoch: 50,
# training performance: {'loss': 0.9461650535464287, 'abosulate accuracy': 0.046600002236664294, 'consecutive overlap rate': 0.10850333459675313, 'overlap rate': 0.7327467337250709}
# evaluation performance: {'loss': 1.917813678085804, 'abosulate accuracy': 0.043450002139434216, 'consecutive overlap rate': 0.1040336025878787, 'overlap rate': 0.5395991303026676}
#
# Current epoch: 55,
# training performance: {'loss': 0.9089396223425865, 'abosulate accuracy': 0.059000002965331075, 'consecutive overlap rate': 0.12521500159054993, 'overlap rate': 0.7429067313671112}
# evaluation performance: {'loss': 1.93568554520607, 'abosulate accuracy': 0.05075000247452408, 'consecutive overlap rate': 0.11611892757937312, 'overlap rate': 0.5478898156434298}
#
# Current epoch: 60,
# training performance: {'loss': 0.8774553775787354, 'abosulate accuracy': 0.06800000369548798, 'consecutive overlap rate': 0.1372200008481741, 'overlap rate': 0.7512250810861587}
# evaluation performance: {'loss': 1.9368361100554465, 'abosulate accuracy': 0.06530000339262187, 'consecutive overlap rate': 0.13403250155970453, 'overlap rate': 0.5545200549066067}
#
# Current epoch: 65,
# training performance: {'loss': 0.8392765089869499, 'abosulate accuracy': 0.07930000461637973, 'consecutive overlap rate': 0.15106500145047902, 'overlap rate': 0.7623950824141502}
# evaluation performance: {'loss': 1.9509587585926056, 'abosulate accuracy': 0.07815000424161553, 'consecutive overlap rate': 0.14848750187084078, 'overlap rate': 0.5569967225193977}
#
# Current epoch: 70,
# training performance: {'loss': 0.7991250604391098, 'abosulate accuracy': 0.08720000395551324, 'consecutive overlap rate': 0.15973333436995746, 'overlap rate': 0.7720900774002075}
# evaluation performance: {'loss': 2.0066398829221725, 'abosulate accuracy': 0.0869000043720007, 'consecutive overlap rate': 0.15741500183939933, 'overlap rate': 0.5630508854985237}
#
# Current epoch: 75,
# training performance: {'loss': 0.7602726697921753, 'abosulate accuracy': 0.10270000398159027, 'consecutive overlap rate': 0.17723500169813633, 'overlap rate': 0.783268404006958}
# evaluation performance: {'loss': 1.990846461057663, 'abosulate accuracy': 0.10120000429451466, 'consecutive overlap rate': 0.1748966682702303, 'overlap rate': 0.5678825512528419}
#
# Current epoch: 80,
# training performance: {'loss': 0.7272072896361351, 'abosulate accuracy': 0.11690000407397746, 'consecutive overlap rate': 0.1936683364212513, 'overlap rate': 0.7924484059214592}
# evaluation performance: {'loss': 2.0142643719911577, 'abosulate accuracy': 0.1105500040575862, 'consecutive overlap rate': 0.18620666824281215, 'overlap rate': 0.575065889954567}
#
# Current epoch: 85,
# training performance: {'loss': 0.6939814954996109, 'abosulate accuracy': 0.12900000493973493, 'consecutive overlap rate': 0.20689166933298112, 'overlap rate': 0.8014434009790421}
# evaluation performance: {'loss': 2.0313002571463583, 'abosulate accuracy': 0.1271000045351684, 'consecutive overlap rate': 0.20341666955500842, 'overlap rate': 0.5778908900916576}
#
# Current epoch: 90,
# training performance: {'loss': 0.6649962231516838, 'abosulate accuracy': 0.14290000554174184, 'consecutive overlap rate': 0.22222500257194042, 'overlap rate': 0.8099484100937844}
# evaluation performance: {'loss': 2.0585832819342613, 'abosulate accuracy': 0.1397500054910779, 'consecutive overlap rate': 0.21765500344336033, 'overlap rate': 0.5835133843123913}
#
# Current epoch: 95,
# training performance: {'loss': 0.6371927186846733, 'abosulate accuracy': 0.1543000066652894, 'consecutive overlap rate': 0.23421333581209183, 'overlap rate': 0.816608402132988}
# evaluation performance: {'loss': 2.1110138222575188, 'abosulate accuracy': 0.1505500060506165, 'consecutive overlap rate': 0.22864916883409023, 'overlap rate': 0.5895708784461021}
#
# Current epoch: 100,
# training performance: {'loss': 0.6104622349143028, 'abosulate accuracy': 0.16610000804066657, 'consecutive overlap rate': 0.2474083360284567, 'overlap rate': 0.8242867320775986}
# evaluation performance: {'loss': 2.116767446696758, 'abosulate accuracy': 0.1617000075057149, 'consecutive overlap rate': 0.24067917019128798, 'overlap rate': 0.5909150511026382}
#
# Current epoch: 105,
# training performance: {'loss': 0.5854548871517181, 'abosulate accuracy': 0.18030000887811184, 'consecutive overlap rate': 0.2626316696405411, 'overlap rate': 0.8312817379832268}
# evaluation performance: {'loss': 2.2881204038858414, 'abosulate accuracy': 0.17035000752657653, 'consecutive overlap rate': 0.2501158365979791, 'overlap rate': 0.595985060930252}
#
# Current epoch: 110,
# training performance: {'loss': 0.5618528388440609, 'abosulate accuracy': 0.19340000860393047, 'consecutive overlap rate': 0.2753233376890421, 'overlap rate': 0.8371434167027474}
# evaluation performance: {'loss': 2.163121758401394, 'abosulate accuracy': 0.18610000796616077, 'consecutive overlap rate': 0.265076670050621, 'overlap rate': 0.5969050519168377}
#
# Current epoch: 115,
# training performance: {'loss': 0.5753463268280029, 'abosulate accuracy': 0.19290000833570958, 'consecutive overlap rate': 0.2743686754256487, 'overlap rate': 0.832768265902996}
# evaluation performance: {'loss': 2.1970228984951974, 'abosulate accuracy': 0.1877000080421567, 'consecutive overlap rate': 0.2663166679441929, 'overlap rate': 0.5981308870017529}
#
# Current epoch: 120,
# training performance: {'loss': 0.5197582855820656, 'abosulate accuracy': 0.21670000962913036, 'consecutive overlap rate': 0.3004766710102558, 'overlap rate': 0.8491834074258804}
# evaluation performance: {'loss': 2.2510284766554833, 'abosulate accuracy': 0.20810000970959663, 'consecutive overlap rate': 0.2881458356976509, 'overlap rate': 0.6003608763217926}
#
# Current epoch: 125,
# training performance: {'loss': 0.49956206530332564, 'abosulate accuracy': 0.2347000103443861, 'consecutive overlap rate': 0.3186366707086563, 'overlap rate': 0.8543017372488976}
# evaluation performance: {'loss': 2.2393378168344498, 'abosulate accuracy': 0.21390000954270363, 'consecutive overlap rate': 0.29678333681076763, 'overlap rate': 0.6134850509464741}
#
# Current epoch: 130,
# training performance: {'loss': 0.4832974709570408, 'abosulate accuracy': 0.24560001119971275, 'consecutive overlap rate': 0.33032833635807035, 'overlap rate': 0.8584734082221985}
# evaluation performance: {'loss': 2.2436830908060075, 'abosulate accuracy': 0.2272500092163682, 'consecutive overlap rate': 0.3092783363536, 'overlap rate': 0.6082858845591546}
#
# Current epoch: 135,
# training performance: {'loss': 0.4683065488934517, 'abosulate accuracy': 0.2543000113219023, 'consecutive overlap rate': 0.3397800035774708, 'overlap rate': 0.8626334071159363}
# evaluation performance: {'loss': 2.299028119444847, 'abosulate accuracy': 0.23835001178085805, 'consecutive overlap rate': 0.3212933372706175, 'overlap rate': 0.6210467197000981}
#
# Current epoch: 140,
# training performance: {'loss': 0.45829266905784605, 'abosulate accuracy': 0.2607000108808279, 'consecutive overlap rate': 0.3474816709756851, 'overlap rate': 0.8656334072351456}
# evaluation performance: {'loss': 2.270441660284996, 'abosulate accuracy': 0.243300012126565, 'consecutive overlap rate': 0.32671917229890823, 'overlap rate': 0.6188642174005509}
#
# Current epoch: 145,
# training performance: {'loss': 0.4455461218953133, 'abosulate accuracy': 0.27140001207590103, 'consecutive overlap rate': 0.358175004273653, 'overlap rate': 0.8690734058618546}
# evaluation performance: {'loss': 2.3213741958141325, 'abosulate accuracy': 0.26050001122057437, 'consecutive overlap rate': 0.3441500052809715, 'overlap rate': 0.626037546992302}
#
# Current epoch: 150,
# training performance: {'loss': 0.43659944757819175, 'abosulate accuracy': 0.28040001094341277, 'consecutive overlap rate': 0.36798667162656784, 'overlap rate': 0.8711934119462967}
# evaluation performance: {'loss': 2.3456422209739687, 'abosulate accuracy': 0.2596000127494335, 'consecutive overlap rate': 0.3472800049930811, 'overlap rate': 0.6275758884847165}
#
# Current epoch: 155,
# training performance: {'loss': 0.4338038444519043, 'abosulate accuracy': 0.2851000152528286, 'consecutive overlap rate': 0.3732583366334438, 'overlap rate': 0.8717033967375756}
# evaluation performance: {'loss': 2.350775609910488, 'abosulate accuracy': 0.26365001033991575, 'consecutive overlap rate': 0.3519375044852495, 'overlap rate': 0.6342375479638577}
#
# Current epoch: 160,
# training performance: {'loss': 0.42739993408322335, 'abosulate accuracy': 0.2881000120192766, 'consecutive overlap rate': 0.37735833823680875, 'overlap rate': 0.8734034046530723}
# evaluation performance: {'loss': 2.3422513142228127, 'abosulate accuracy': 0.27885001320391894, 'consecutive overlap rate': 0.3647516708821058, 'overlap rate': 0.6295433856546879}
#
# Current epoch: 165,
# training performance: {'loss': 0.4440893016755581, 'abosulate accuracy': 0.29000001661479474, 'consecutive overlap rate': 0.3783004261553288, 'overlap rate': 0.8688291609287262}
# evaluation performance: {'loss': 2.395473974943161, 'abosulate accuracy': 0.2757000125944614, 'consecutive overlap rate': 0.36170917227864263, 'overlap rate': 0.6294883824884892}
#
# Current epoch: 170,
# training performance: {'loss': 0.39792813956737516, 'abosulate accuracy': 0.30830001309514043, 'consecutive overlap rate': 0.3976250052452087, 'overlap rate': 0.8819800719618798}
# evaluation performance: {'loss': 2.3843268364667893, 'abosulate accuracy': 0.2726000124588609, 'consecutive overlap rate': 0.36829083748161795, 'overlap rate': 0.6428500503301621}
#
# Current epoch: 175,
# training performance: {'loss': 0.390612705796957, 'abosulate accuracy': 0.31590001434087756, 'consecutive overlap rate': 0.4055750027298927, 'overlap rate': 0.8840434119105339}
# evaluation performance: {'loss': 2.376763728260994, 'abosulate accuracy': 0.29870001450181005, 'consecutive overlap rate': 0.3850200042128563, 'overlap rate': 0.6382750518620014}
#
# Current epoch: 180,
# training performance: {'loss': 0.3978004284203053, 'abosulate accuracy': 0.3169000118970871, 'consecutive overlap rate': 0.40722381621599196, 'overlap rate': 0.8814528703689575}
# evaluation performance: {'loss': 2.425778439640999, 'abosulate accuracy': 0.291150014474988, 'consecutive overlap rate': 0.3774958372116089, 'overlap rate': 0.6254858739674092}
#
# Current epoch: 185,
# training performance: {'loss': 0.3838367387652397, 'abosulate accuracy': 0.3227000132203102, 'consecutive overlap rate': 0.41230500489473343, 'overlap rate': 0.884765075147152}
# evaluation performance: {'loss': 2.4188849180936813, 'abosulate accuracy': 0.3070500137284398, 'consecutive overlap rate': 0.39448833726346494, 'overlap rate': 0.6425992101430893}
#
# Current epoch: 190,
# training performance: {'loss': 0.3699189141392708, 'abosulate accuracy': 0.3325000159442425, 'consecutive overlap rate': 0.42315500378608706, 'overlap rate': 0.8893384069204331}
# evaluation performance: {'loss': 2.439148762822151, 'abosulate accuracy': 0.3151500133797526, 'consecutive overlap rate': 0.4047675047069788, 'overlap rate': 0.6521600514650345}

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
