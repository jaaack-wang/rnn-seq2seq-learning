# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 512
embd_dim = 256
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = True
use_attention = False
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 6
shuffle_batch = True

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#6 created!
# ./Experiments_Logs/Experiment#6/GRU created!
# ./Experiments_Logs/Experiment#6/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#6/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#6/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.0 # for saving the best trained models 
max_epoch_num = 200 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#6 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
# evaluation performance: {'loss': 2.190905733406544, 'abosulate accuracy': 0.13380000507459044, 'consecutive overlap rate': 0.2256166685372591, 'overlap rate': 0.6443367213010788}
#
# Current epoch: 185,
# training performance: {'loss': 0.18618962951004506, 'abosulate accuracy': 0.44820002019405364, 'consecutive overlap rate': 0.5308166712522506, 'overlap rate': 0.9338734030723572}
# evaluation performance: {'loss': 2.222634442150593, 'abosulate accuracy': 0.1294500047340989, 'consecutive overlap rate': 0.22141250278800725, 'overlap rate': 0.6454075612127781}
#
# Current epoch: 190,
# training performance: {'loss': 0.18366743214428424, 'abosulate accuracy': 0.44890002012252805, 'consecutive overlap rate': 0.5322816729545593, 'overlap rate': 0.9360817387700081}
# evaluation performance: {'loss': 2.1483202293515204, 'abosulate accuracy': 0.13730000462383032, 'consecutive overlap rate': 0.22746166959404945, 'overlap rate': 0.6471625559031964}
#
# Current epoch: 195,
# training performance: {'loss': 0.17777226269245147, 'abosulate accuracy': 0.45310001969337466, 'consecutive overlap rate': 0.5375050060451031, 'overlap rate': 0.9364800751209259}
# evaluation performance: {'loss': 2.2747876971960066, 'abosulate accuracy': 0.1321500045247376, 'consecutive overlap rate': 0.22447000313550233, 'overlap rate': 0.6469492256641388}
#
# Current epoch: 200,
# training performance: {'loss': 0.15438385419547557, 'abosulate accuracy': 0.49310002103447914, 'consecutive overlap rate': 0.5783800035715103, 'overlap rate': 0.9527267321944237}
# evaluation performance: {'loss': 2.1495171397924424, 'abosulate accuracy': 0.13365000505000352, 'consecutive overlap rate': 0.22550916895270348, 'overlap rate': 0.6480592228472233}
#
# Experiments_Logs/Experiment#6/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.8674567185342312, 'abosulate accuracy': 0.13845000504516064, 'consecutive overlap rate': 0.22494916915893554, 'overlap rate': 0.6424217272549868}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.365830957889557, 'abosulate accuracy': 0.00010000000183936208, 'consecutive overlap rate': 0.07069690953940153, 'overlap rate': 0.22071063071489333}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.441473465581094, 'abosulate accuracy': 0.03615969502397122, 'consecutive overlap rate': 0.08221143462484883, 'overlap rate': 0.5067125495403043}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.2957353591918945, 'abosulate accuracy': 0.02657894853894648, 'consecutive overlap rate': 0.1127431447078523, 'overlap rate': 0.22573404523887133}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9169969618320466, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0025066666916245595, 'overlap rate': 0.43973504602909086}
# evaluation performance: {'loss': 2.139678767323494, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# training performance: {'loss': 0.19055907987058163, 'abosulate accuracy': 0.4534000210464001, 'consecutive overlap rate': 0.5304266691207886, 'overlap rate': 0.9329217404127121}
# evaluation performance: {'loss': 2.1146102428436278, 'abosulate accuracy': 0.13350000530481337, 'consecutive overlap rate': 0.22656000256538392, 'overlap rate': 0.6487375542521476}
#
# Current epoch: 190,
# training performance: {'loss': 0.19825312495231628, 'abosulate accuracy': 0.43570002242922784, 'consecutive overlap rate': 0.5171100072562694, 'overlap rate': 0.9282067254185676}
# evaluation performance: {'loss': 2.155276897549629, 'abosulate accuracy': 0.12700000433251263, 'consecutive overlap rate': 0.2202258352190256, 'overlap rate': 0.6481092318892478}
#
# Current epoch: 195,
# training performance: {'loss': 0.18161103911697865, 'abosulate accuracy': 0.45180002227425575, 'consecutive overlap rate': 0.5355600036680699, 'overlap rate': 0.935150071978569}
# evaluation performance: {'loss': 2.1963405668735505, 'abosulate accuracy': 0.13070000475272536, 'consecutive overlap rate': 0.22351916898041962, 'overlap rate': 0.650469221174717}
#
# Current epoch: 200,
# training performance: {'loss': 0.18812526315450667, 'abosulate accuracy': 0.4429000221192837, 'consecutive overlap rate': 0.5287300109863281, 'overlap rate': 0.9329800754785538}
# evaluation performance: {'loss': 2.116115188598633, 'abosulate accuracy': 0.1398000055924058, 'consecutive overlap rate': 0.23194416891783476, 'overlap rate': 0.6524392247200013}
#
# Experiments_Logs/Experiment#6/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.9528729707002639, 'abosulate accuracy': 0.13990000514313577, 'consecutive overlap rate': 0.23282958641648294, 'overlap rate': 0.6506908882409335}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 4.715992522239685, 'abosulate accuracy': 2.5000001187436283e-05, 'consecutive overlap rate': 0.07923993542790413, 'overlap rate': 0.23408386446535587}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.873152443670457, 'abosulate accuracy': 0.03948259527584718, 'consecutive overlap rate': 0.08929339601628242, 'overlap rate': 0.512808459612631}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.7039655760714885, 'abosulate accuracy': 0.04513158107262203, 'consecutive overlap rate': 0.127290140739397, 'overlap rate': 0.24628702257024615}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.9418973356485367, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0016166667002835311, 'overlap rate': 0.4322567142546177}
# evaluation performance: {'loss': 2.599509572982788, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001973333358182572, 'overlap rate': 0.40103587359189985}
#
# Current epoch: 10,
# training performance: {'loss': 1.7886998027563095, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0046316667285282165, 'overlap rate': 0.47008004784584045}
# evaluation performance: {'loss': 1.872543592751026, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004554166732123122, 'overlap rate': 0.46944914795458315}
#
# Current epoch: 15,
# training performance: {'loss': 1.4922105699777604, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0
# evaluation performance: {'loss': 2.146702529489994, 'abosulate accuracy': 0.18825000878423453, 'consecutive overlap rate': 0.28167166840285063, 'overlap rate': 0.6785800524055958}
#
# Current epoch: 200,
# training performance: {'loss': 0.13499565087258816, 'abosulate accuracy': 0.4839000225067139, 'consecutive overlap rate': 0.5766616716980935, 'overlap rate': 0.9524934113025665}
# evaluation performance: {'loss': 2.168764501810074, 'abosulate accuracy': 0.18660000823438166, 'consecutive overlap rate': 0.279672503657639, 'overlap rate': 0.6789783976972104}
#
# Experiments_Logs/Experiment#6/GRU/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#6/GRU/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 1.8746156886219978, 'abosulate accuracy': 0.19875000892207026, 'consecutive overlap rate': 0.2883662398904562, 'overlap rate': 0.6790355857461691}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 5.117496472597122, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.20564861139282584, 'overlap rate': 0.33180209435522556}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.698733692784463, 'abosulate accuracy': 0.03273229150462054, 'consecutive overlap rate': 0.08285409870647616, 'overlap rate': 0.5067240082448529}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 5.696152542766772, 'abosulate accuracy': 0.04239473897216253, 'consecutive overlap rate': 0.17711921781301498, 'overlap rate': 0.27083146728967367}
# Experiments_Logs/Experiment#6/GRU/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 1.7595266610383988, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00493666670517996, 'overlap rate': 0.47677171528339385}
# evaluation performance: {'loss': 2.606051045656204, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005148333369288593, 'overlap rate': 0.4723100449889898}
#
# Current epoch: 10,
# training performance: {'loss': 1.473548126220703, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.009095000033266843, 'overlap rate': 0.5352834030985832}
# evaluation performance: {'loss': 1.6311573565006257, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.009755833441158757, 'overlap rate': 0.48411588221788404}
#
# Current epoch: 15,
# training performance: {'loss': 1.1099795401096344, 'abosulate accuracy': 0.003700000140815973, 'consecutive overlap rate': 0.028790000174194575, 'overlap rate': 0.6322867333889007}
# evaluation performance: {'loss': 1.7041856586933135, 'abosulate accuracy': 0.002050000097369775, 'consecutive overlap rate': 0.028138333675451578, 'overlap rate': 0.5063725501298905}
#
# Current epoch: 20,
# training performance: {'loss': 0.8897745460271835, 'abosulate accuracy': 0.028300001146271826, 'consecutive overlap rate': 0.0716783344745636, 'overlap rate': 0.6946234107017517}
# evaluation performance: {'loss': 1.5459498450160027, 'abosulate accuracy': 0.02330000099609606, 'consecutive overlap rate': 0.06760031152516603, 'overlap rate': 0.5413363382220269}
#
# Current epoch: 25,
# training performance: {'loss': 0.7620808154344558, 'abosulate accuracy': 0.05730000277981162, 'consecutive overlap rate': 0.11142666805535555, 'overlap rate': 0.7326750680804253}
# evaluation performance: {'loss': 1.5545297116041183, 'abosulate accuracy': 0.03460000160848722, 'consecutive overlap rate': 0.09044083440676332, 'overlap rate': 0.5624858886003494}
#
# Current epoch: 30,
# training performance: {'loss': 0.6726408064365387, 'abosulate accuracy': 0.09440000411123037, 'consecutive overlap rate': 0.15340500250458716, 'overlap rate': 0.7604834139347076}
# evaluation performance: {'loss': 1.5646885469555856, 'abosulate accuracy': 0.05965000283904374, 'consecutive overlap rate': 0.11728833420202137, 'overlap rate': 0.5747525550425052}
#
# Current epoch: 35,
# training performance: {'loss': 0.6084078118205071, 'abosulate accuracy': 0.12340000458061695, 'consecutive overlap rate': 0.18607666864991187, 'overlap rate': 0.7814517363905906}
# evaluation performance: {'loss': 1.5562725126743318, 'abosulate accuracy': 0.07910000407136977, 'consecutive overlap rate': 0.1420484614558518, 'overlap rate': 0.5900419279932976}
#
# Current epoch: 40,
# training performance: {'loss': 0.5582817375659943, 'abosulate accuracy': 0.15020000599324704, 'consecutive overlap rate': 0.2150350008159876, 'overlap rate': 0.7974567368626595}
# evaluation performance: {'loss': 1.553161409497261, 'abosulate accuracy': 0.09400000413879753, 'consecutive overlap rate': 0.16048750150948762, 'overlap rate': 0.6028567232191563}
#
# Current epoch: 45,
# training performance: {'loss': 0.5217646852135658, 'abosulate accuracy': 0.16770000625401735, 'consecutive overlap rate': 0.2342333372682333, 'overlap rate': 0.8093667343258858}
# evaluation performance: {'loss': 1.5438787743449212, 'abosulate accuracy': 0.10375000387430192, 'consecutive overlap rate': 0.17447833567857743, 'overlap rate': 0.612942561507225}
#
# Current epoch: 50,
# training performance: {'loss': 0.4754628799855709, 'abosulate accuracy': 0.20260000973939896, 'consecutive overlap rate': 0.2689666707068682, 'overlap rate': 0.8255017429590226}
# evaluation performance: {'loss': 1.5528818547725678, 'abosulate accuracy': 0.12200000416487455, 'consecutive overlap rate': 0.19498712085187436, 'overlap rate': 0.6234567627310753}
#
# Current epoch: 55,
# training performance: {'loss': 0.4386937081813812, 'abosulate accuracy': 0.22880001030862332, 'consecutive overlap rate': 0.2960633382201195, 'overlap rate': 0.8393017381429673}
# evaluation performance: {'loss': 1.55248481631279, 'abosulate accuracy': 0.1319000044837594, 'consecutive overlap rate': 0.20636250134557485, 'overlap rate': 0.6321250572800636}
#
# Current epoch: 60,
# training performance: {'loss': 0.41608135402202606, 'abosulate accuracy': 0.24450001083314418, 'consecutive overlap rate': 0.3123466711491346, 'overlap rate': 0.8463000804185867}
# evaluation performance: {'loss': 1.5840776816010476, 'abosulate accuracy': 0.13530000457540153, 'consecutive overlap rate': 0.2106166696175933, 'overlap rate': 0.6323525585234165}
#
# Current epoch: 65,
# training performance: {'loss': 0.4590347893536091, 'abosulate accuracy': 0.21120000891387464, 'consecutive overlap rate': 0.28401333689689634, 'overlap rate': 0.83129673153162}
# evaluation performance: {'loss': 1.5613688200712204, 'abosulate accuracy': 0.1472500058822334, 'consecutive overlap rate': 0.2198108358308673, 'overlap rate': 0.6359283901751042}
#
# Current epoch: 70,
#
# Current epoch: 115,
# training performance: {'loss': 0.2235597711056471, 'abosulate accuracy': 0.41960001960396764, 'consecutive overlap rate': 0.4844800055027008, 'overlap rate': 0.9193383976817131}
# evaluation performance: {'loss': 1.7765332967042924, 'abosulate accuracy': 0.18355000894516707, 'consecutive overlap rate': 0.2701016698032618, 'overlap rate': 0.6691375598311424}
#
# Current epoch: 120,
# training performance: {'loss': 0.21394719555974007, 'abosulate accuracy': 0.4301000200212002, 'consecutive overlap rate': 0.4951083406805992, 'overlap rate': 0.9240417361259461}
# evaluation performance: {'loss': 1.7825646877288819, 'abosulate accuracy': 0.18965000845491886, 'consecutive overlap rate': 0.2761466694995761, 'overlap rate': 0.668855058401823}
#
# Current epoch: 125,
# training performance: {'loss': 0.212624678760767, 'abosulate accuracy': 0.432900021225214, 'consecutive overlap rate': 0.49863333627581596, 'overlap rate': 0.924493408203125}
# evaluation performance: {'loss': 1.7713521629571916, 'abosulate accuracy': 0.18990000877529384, 'consecutive overlap rate': 0.2745941698551178, 'overlap rate': 0.6704633809626103}
#
# Current epoch: 130,
# training performance: {'loss': 0.1964037526398897, 'abosulate accuracy': 0.44450002163648605, 'consecutive overlap rate': 0.5118666723370552, 'overlap rate': 0.9305384084582329}
# evaluation performance: {'loss': 1.8434855446219445, 'abosulate accuracy': 0.18765000784769653, 'consecutive overlap rate': 0.2744116675108671, 'overlap rate': 0.6705042250454426}
#
# Current epoch: 135,
# training performance: {'loss': 0.2282366666942835, 'abosulate accuracy': 0.4005000196397305, 'consecutive overlap rate': 0.4762416735291481, 'overlap rate': 0.9154217362403869}
# evaluation performance: {'loss': 1.8177835687994957, 'abosulate accuracy': 0.19655000772327186, 'consecutive overlap rate': 0.28122333586215975, 'overlap rate': 0.6736908860504627}
#
# Current epoch: 140,
# training performance: {'loss': 0.18738097622990607, 'abosulate accuracy': 0.44000001922249793, 'consecutive overlap rate': 0.5127850100398064, 'overlap rate': 0.932463413476944}
# evaluation performance: {'loss': 1.9151913121342659, 'abosulate accuracy': 0.19070000853389502, 'consecutive overlap rate': 0.27793513145297766, 'overlap rate': 0.6730941772460938}

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
