# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 256
embd_dim = 128
num_layers = 1
rnn_type = "LSTM"
dropout_rate = 0.0
bidirectional = False
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 3
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#3/LSTM created!
# ./Experiments_Logs/Experiment#3/LSTM/Training_Logs created!
# ./Experiments_Logs/Experiment#3/LSTM/Testing_Logs created!
# ./Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#3/LSTM/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#3 with LSTM seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.8251726806163786, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01176799915265292, 'overlap rate': 0.1787674056366086}
# evaluation performance: {'loss': 2.938365525007248, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01446457151323557, 'overlap rate': 0.13131843134760857}
#
# Current epoch: 10,
# training performance: {'loss': 2.2051827251911162, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0340983557747677, 'overlap rate': 0.3253418758511543}
# evaluation performance: {'loss': 2.7354042172431945, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.04344917666167021, 'overlap rate': 0.1643891429528594}
#
# Current epoch: 15,
# training performance: {'loss': 1.7083049327135087, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05557728740386665, 'overlap rate': 0.4660485960543156}
# evaluation performance: {'loss': 2.7612800180912016, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.07230956507846713, 'overlap rate': 0.1943970113992691}
#
# Current epoch: 20,
# training performance: {'loss': 1.5642813801765443, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07813513027504086, 'overlap rate': 0.520387963950634}
# evaluation performance: {'loss': 2.6249223709106446, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.09378325184807182, 'overlap rate': 0.24691260196268558}
#
# Current epoch: 25,
# training performance: {'loss': 0.7322366833686829, 'abosulate accuracy': 0.004300000157672912, 'consecutive overlap rate': 0.15350355608388783, 'overlap rate': 0.7918648153543473}
# evaluation performance: {'loss': 1.7725288897752762, 'abosulate accuracy': 0.03300000163726509, 'consecutive overlap rate': 0.23734039086848496, 'overlap rate': 0.5491097308695316}
#
# Current epoch: 30,
# training performance: {'loss': 0.4481998234987259, 'abosulate accuracy': 0.07920000322628766, 'consecutive overlap rate': 0.2891998656094074, 'overlap rate': 0.893092580139637}
# evaluation performance: {'loss': 1.2741916626691818, 'abosulate accuracy': 0.17335000762250274, 'consecutive overlap rate': 0.41863253712654114, 'overlap rate': 0.7456817358732224}
#
# Current epoch: 35,
# training performance: {'loss': 1.4488160081207753, 'abosulate accuracy': 0.18560000696452333, 'consecutive overlap rate': 0.3777940658153966, 'overlap rate': 0.76996137984097}
# evaluation performance: {'loss': 4.114146816730499, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.1185262045590207, 'overlap rate': 0.2057562367990613}
#
# Current epoch: 40,
# training performance: {'loss': 0.44251219630241395, 'abosulate accuracy': 0.16770000802353024, 'consecutive overlap rate': 0.37949416786432266, 'overlap rate': 0.9201767250895501}
# evaluation performance: {'loss': 1.3742978379130364, 'abosulate accuracy': 0.2130500093451701, 'consecutive overlap rate': 0.4487181190401316, 'overlap rate': 0.7071935921907425}
#
# Current epoch: 45,
# training performance: {'loss': 0.18696457725018262, 'abosulate accuracy': 0.48360002040863037, 'consecutive overlap rate': 0.6495428919792176, 'overlap rate': 0.9741326451301575}
# evaluation performance: {'loss': 0.6815703965723514, 'abosulate accuracy': 0.5394000243395567, 'consecutive overlap rate': 0.7229962058365345, 'overlap rate': 0.8785526782274247}
#
# Current epoch: 50,
# training performance: {'loss': 0.06605504415929317, 'abosulate accuracy': 0.8104000374674797, 'consecutive overlap rate': 0.9100576415657997, 'overlap rate': 0.9962739780545234}
# evaluation performance: {'loss': 0.23879521582275628, 'abosulate accuracy': 0.8001000359654427, 'consecutive overlap rate': 0.9070254817605019, 'overlap rate': 0.9667420402169228}
#
# Current epoch: 55,
# training performance: {'loss': 0.049939316743984816, 'abosulate accuracy': 0.8211000338196754, 'consecutive overlap rate': 0.9220334112644195, 'overlap rate': 0.9966678589582443}
# evaluation performance: {'loss': 0.17727479990571737, 'abosulate accuracy': 0.8268500357866287, 'consecutive overlap rate': 0.9222941353917122, 'overlap rate': 0.9756586492061615}
#
# Current epoch: 60,
# training performance: {'loss': 0.2724686272442341, 'abosulate accuracy': 0.3022000127355568, 'consecutive overlap rate': 0.451512810960412, 'overlap rate': 0.9422211527824402}
# evaluation performance: {'loss': 1.3382777400314807, 'abosulate accuracy': 0.4343500219285488, 'consecutive overlap rate': 0.6236483421176672, 'overlap rate': 0.7918909877538681}
#
# Current epoch: 65,
# training performance: {'loss': 0.2436012551188469, 'abosulate accuracy': 0.40720001691952346, 'consecutive overlap rate': 0.5690657902508974, 'overlap rate': 0.958863140642643}
# evaluation performance: {'loss': 1.509945274889469, 'abosulate accuracy': 0.3082500174641609, 'consecutive overlap rate': 0.5626134879887104, 'overlap rate': 0.7358639992773532}
#
# Current epoch: 70,
# training performance: {'loss': 0.06725850664079189, 'abosulate accuracy': 0.7563000351190567, 'consecutive overlap rate': 0.8605796560645104, 'overlap rate': 0.9941513538360596}
# evaluation performance: {'loss': 0.38182338029146196, 'abosulate accuracy': 0.7605000331997871, 'consecutive overlap rate': 0.8702754870057106, 'overlap rate': 0.9424137398600578}
#
# Current epoch: 75,
# training performance: {'loss': 0.05421921885572374, 'abosulate accuracy': 0.7863000392913818, 'consecutive overlap rate': 0.891333632171154, 'overlap rate': 0.9949816107749939}
# evaluation performance: {'loss': 0.35469756964594124, 'abosulate accuracy': 0.7822000354528427, 'consecutive overlap rate': 0.8869770511984825, 'overlap rate': 0.949024485051632}
#
# Current epoch: 80,
# training performance: {'loss': 0.032808252470567824, 'abosulate accuracy': 0.8536000356078148, 'consecutive overlap rate': 0.9409779474139214, 'overlap rate': 0.9978938475251198}
# evaluation performance: {'loss': 0.19473860114812852, 'abosulate accuracy': 0.8523000419139862, 'consecutive overlap rate': 0.9411033764481544, 'overlap rate': 0.9740898534655571}
#
# Current epoch: 85,
# training performance: {'loss': 0.020669187838211655, 'abosulate accuracy': 0.893900029361248, 'consecutive overlap rate': 0.9765220820903778, 'overlap rate': 0.9991115242242813}
# evaluation performance: {'loss': 0.12081872993148864, 'abosulate accuracy': 0.8817500382661819, 'consecutive overlap rate': 0.9698454111814498, 'overlap rate': 0.9852194279432297}
#
# Current epoch: 90,
# training performance: {'loss': 0.014556990563869476, 'abosulate accuracy': 0.9074000313878059, 'consecutive overlap rate': 0.9859339341521263, 'overlap rate': 0.9995230808854103}
# evaluation performance: {'loss': 0.08068022395018488, 'abosulate accuracy': 0.89870003759861, 'consecutive overlap rate': 0.9817898601293564, 'overlap rate': 0.9908974513411521}
#
# Current epoch: 95,
# training performance: {'loss': 0.058342185232322666, 'abosulate accuracy': 0.8226000264286994, 'consecutive overlap rate': 0.9437980860471725, 'overlap rate': 0.9941384047269821}
# evaluation performance: {'loss': 0.3599397033452988, 'abosulate accuracy': 0.7725500360131263, 'consecutive overlap rate': 0.9180763885378838, 'overlap rate': 0.953724493086338}
#
# Current epoch: 100,
# training performance: {'loss': 2.897375524044037, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.1200493337586522, 'overlap rate': 0.20615419521927833}
# evaluation performance: {'loss': 2.9397796750068665, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.12494285376742482, 'overlap rate': 0.1961651287972927}
#
# Experiments_Logs/Experiment#3/LSTM/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 9.520027208328248, 'abosulate accuracy': 0.03982500185957179, 'consecutive overlap rate': 0.04186500041978434, 'overlap rate': 0.08981458942871541}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.07335529867559672, 'abosulate accuracy': 0.9027500465512276, 'consecutive overlap rate': 0.9853997260332108, 'overlap rate': 0.9920508995652199}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 9.202348013847105, 'abosulate accuracy': 0.02810194956499242, 'consecutive overlap rate': 0.03261307159498815, 'overlap rate': 0.09001107518711397}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.6028638564442333, 'abosulate accuracy': 0.8301842487172076, 'consecutive overlap rate': 0.8880128531079543, 'overlap rate': 0.925744315511302}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.7705228328704834, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01292453519999981, 'overlap rate': 0.19140393789857627}
# evaluation performance: {'loss': 2.895603024959564, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015604346070904284, 'overlap rate': 0.13619239423424007}
#
# Current epoch: 10,
# training performance: {'loss': 2.678412216901779, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03996414435096085, 'overlap rate': 0.2332390308380127}
# evaluation performance: {'loss': 2.879566764831543, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.041832705633714794, 'overlap rate': 0.1325752967968583}
#
# Current epoch: 15,
# training performance: {'loss': 1.57957104742527, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06287057674489915, 'overlap rate': 0.4938959330320358}
# evaluation performance: {'loss': 2.5476290583610535, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06512719783931971, 'overlap rate': 0.22416107766330243}
#
# Current epoch: 20,
# training performance: {'loss': 1.1161783248186112, 'abosulate accuracy': 0.0018000000738538802, 'consecutive overlap rate': 0.11681005409918725, 'overlap rate': 0.6601915322244167}
# evaluation performance: {'loss': 2.557552510499954, 'abosulate accuracy': 0.00040000001317821445, 'consecutive overlap rate': 0.1127333315089345, 'overlap rate': 0.3009027265012264}
#
# Current epoch: 25,
# training performance: {'loss': 0.6175991803407669, 'abosulate accuracy': 0.07020000303164124, 'consecutive overlap rate': 0.26497730500996114, 'overlap rate': 0.8399346143007278}
# evaluation performance: {'loss': 2.1268202543258665, 'abosulate accuracy': 0.018200000654906033, 'consecutive overlap rate': 0.23038273137062787, 'overlap rate': 0.4645085446536541}
#
# Current epoch: 30,
# training performance: {'loss': 0.29406446516513823, 'abosulate accuracy': 0.19550000808667392, 'consecutive overlap rate': 0.4119450461119413, 'overlap rate': 0.9368610695004463}
# evaluation performance: {'loss': 1.1574433162808417, 'abosulate accuracy': 0.27225001305341723, 'consecutive overlap rate': 0.4968973856419325, 'overlap rate': 0.7616397559642791}
#
# Current epoch: 35,
# training performance: {'loss': 0.06607442824169993, 'abosulate accuracy': 0.8369000405073166, 'consecutive overlap rate': 0.9381669819355011, 'overlap rate': 0.9972170233726502}
# evaluation performance: {'loss': 0.16400785110890864, 'abosulate accuracy': 0.8295500382781029, 'consecutive overlap rate': 0.9353407755494118, 'overlap rate': 0.980463270843029}
#
# Current epoch: 40,
# training performance: {'loss': 0.035956710763275626, 'abosulate accuracy': 0.891900035738945, 'consecutive overlap rate': 0.9775432184338569, 'overlap rate': 0.9989580392837525}
# evaluation performance: {'loss': 0.10311495303176343, 'abosulate accuracy': 0.880250035226345, 'consecutive overlap rate': 0.9705253064632415, 'overlap rate': 0.9887718245387077}
#
# Current epoch: 45,
# training performance: {'loss': 0.02150267530232668, 'abosulate accuracy': 0.9117000281810761, 'consecutive overlap rate': 0.9910624593496322, 'overlap rate': 0.9996607303619385}
# evaluation performance: {'loss': 0.0698156957514584, 'abosulate accuracy': 0.8981000334024429, 'consecutive overlap rate': 0.9825372025370598, 'overlap rate': 0.992732422053814}
#
# Current epoch: 50,
# training performance: {'loss': 0.01467860045377165, 'abosulate accuracy': 0.917700020968914, 'consecutive overlap rate': 0.9953883856534957, 'overlap rate': 0.9998330727219582}
# evaluation performance: {'loss': 0.0594210016541183, 'abosulate accuracy': 0.9042500346899033, 'consecutive overlap rate': 0.9865068376064301, 'overlap rate': 0.9937858611345292}
#
# Current epoch: 55,
# training performance: {'loss': 0.010621219919994474, 'abosulate accuracy': 0.9211000174283981, 'consecutive overlap rate': 0.9976348742842674, 'overlap rate': 0.9999061405658722}
# evaluation performance: {'loss': 0.05172394861001521, 'abosulate accuracy': 0.9070000320672988, 'consecutive overlap rate': 0.9886704847216606, 'overlap rate': 0.9946725696325303}
#
# Current epoch: 60,
# training performance: {'loss': 0.007986334688030183, 'abosulate accuracy': 0.923300014436245, 'consecutive overlap rate': 0.999065899848938, 'overlap rate': 0.9999630376696587}
# evaluation performance: {'loss': 0.05160865263314918, 'abosulate accuracy': 0.9086000353097916, 'consecutive overlap rate': 0.9896138280630111, 'overlap rate': 0.9945650428533555}
#
# Current epoch: 65,
# training performance: {'loss': 0.006178166740573943, 'abosulate accuracy': 0.9246000036597252, 'consecutive overlap rate': 0.9997606307268143, 'overlap rate': 0.9999924644827842}
# evaluation performance: {'loss': 0.05324903334258124, 'abosulate accuracy': 0.9093500360846519, 'consecutive overlap rate': 0.9901392370462417, 'overlap rate': 0.9944115862250328}
#
# Current epoch: 70,
# training performance: {'loss': 0.004883453517686575, 'abosulate accuracy': 0.9247000038623809, 'consecutive overlap rate': 0.9998250380158424, 'overlap rate': 0.9999941602349282}
# evaluation performance: {'loss': 0.0525123177561909, 'abosulate accuracy': 0.9102500319480896, 'consecutive overlap rate': 0.9907384753227234, 'overlap rate': 0.9944595292210578}
#
# Current epoch: 75,
# training performance: {'loss': 0.0039257286349311474, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999777764081955, 'overlap rate': 0.9999977752566338}
# evaluation performance: {'loss': 0.05351888765580952, 'abosulate accuracy': 0.9106000363826752, 'consecutive overlap rate': 0.9909560114145279, 'overlap rate': 0.9944021672010421}
#
# Current epoch: 80,
# training performance: {'loss': 0.003199970681453124, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999777764081955, 'overlap rate': 0.9999977752566338}
# evaluation performance: {'loss': 0.050400396873010324, 'abosulate accuracy': 0.9114000380039216, 'consecutive overlap rate': 0.9914417311549186, 'overlap rate': 0.9948486328125}
#
# Current epoch: 85,
# training performance: {'loss': 0.002635990711860359, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9999777764081955, 'overlap rate': 0.9999977752566338}
# evaluation performance: {'loss': 0.05214197535533458, 'abosulate accuracy': 0.9115500375628471, 'consecutive overlap rate': 0.9915365040302276, 'overlap rate': 0.9946828618645668}
#
# Current epoch: 90,
# training performance: {'loss': 0.0021946233784547074, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.05400562274153344, 'abosulate accuracy': 0.911500035226345, 'consecutive overlap rate': 0.9915339455008507, 'overlap rate': 0.9945697680115699}
#
# Current epoch: 95,
# training performance: {'loss': 0.0018388448632322251, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.05810154557111673, 'abosulate accuracy': 0.9112500354647637, 'consecutive overlap rate': 0.9912647932767868, 'overlap rate': 0.9943087205290795}
#
# Current epoch: 100,
# training performance: {'loss': 0.0015526834729826077, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0603070635930635, 'abosulate accuracy': 0.9115000292658806, 'consecutive overlap rate': 0.9915008470416069, 'overlap rate': 0.9942114725708961}
#
# Experiments_Logs/Experiment#3/LSTM/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 10.158445411920548, 'abosulate accuracy': 0.04182500183815137, 'consecutive overlap rate': 0.04350166718941182, 'overlap rate': 0.07771250458899885}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.05508138088625856, 'abosulate accuracy': 0.9112500414252281, 'consecutive overlap rate': 0.9911816418170929, 'overlap rate': 0.9944661319255829}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 9.112481837118825, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0034587262190818304, 'overlap rate': 0.10756201335499363}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.309941243907241, 'abosulate accuracy': 0.5806579167164225, 'consecutive overlap rate': 0.6547403570852781, 'overlap rate': 0.6872705954470133}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.8456477344036104, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01401509486604482, 'overlap rate': 0.1699420902878046}
# evaluation performance: {'loss': 2.933348309993744, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01914570399094373, 'overlap rate': 0.13803861308842896}
#
# Current epoch: 10,
# training performance: {'loss': 2.1797668009996416, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04433072896208614, 'overlap rate': 0.34258957356214526}
# evaluation performance: {'loss': 2.813567441701889, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04006374343298376, 'overlap rate': 0.15140641275793315}
#
# Current epoch: 15,
# training performance: {'loss': 2.2595882594585417, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.055633373698219656, 'overlap rate': 0.32943448796868324}
# evaluation performance: {'loss': 2.935904198884964, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.054192159604281184, 'overlap rate': 0.14812763947993518}
#
# Current epoch: 20,
# training performance: {'loss': 0.955409400165081, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.1120356535539031, 'overlap rate': 0.70374094247818}
# evaluation performance: {'loss': 2.60017876625061, 'abosulate accuracy': 0.003650000150082633, 'consecutive overlap rate': 0.12146205510944127, 'overlap rate': 0.2982204306870699}
#
# Current epoch: 25,
# training performance: {'loss': 1.0457881778478622, 'abosulate accuracy': 0.0007000000216066838, 'consecutive overlap rate': 0.12017064336687326, 'overlap rate': 0.6879307687282562}
# evaluation performance: {'loss': 2.590549126267433, 'abosulate accuracy': 0.0025500000920146704, 'consecutive overlap rate': 0.15656224582344294, 'overlap rate': 0.3685200322419405}
#
# Current epoch: 30,
# training performance: {'loss': 0.5191526181995869, 'abosulate accuracy': 0.03450000154552981, 'consecutive overlap rate': 0.2372649809345603, 'overlap rate': 0.8614227548241615}
# evaluation performance: {'loss': 1.6192086398601533, 'abosulate accuracy': 0.12530000741244293, 'consecutive overlap rate': 0.3567544285207987, 'overlap rate': 0.6458543010056019}
#
# Current epoch: 35,
# training performance: {'loss': 0.2560803759843111, 'abosulate accuracy': 0.2670000129844993, 'consecutive overlap rate': 0.47024308405816556, 'overlap rate': 0.9516704276204109}
# evaluation performance: {'loss': 0.9817780405282974, 'abosulate accuracy': 0.35365001587197187, 'consecutive overlap rate': 0.5659729279577732, 'overlap rate': 0.8043562099337578}
#
# Current epoch: 40,
# training performance: {'loss': 0.08189961630851031, 'abosulate accuracy': 0.7452000349760055, 'consecutive overlap rate': 0.8610666394233704, 'overlap rate': 0.9941374838352204}
# evaluation performance: {'loss': 0.25214086566120386, 'abosulate accuracy': 0.7541000321507454, 'consecutive overlap rate': 0.8732498064637184, 'overlap rate': 0.9634770154953003}
#
# Current epoch: 45,
# training performance: {'loss': 0.04463799092918634, 'abosulate accuracy': 0.8576000347733498, 'consecutive overlap rate': 0.9489120930433274, 'overlap rate': 0.9981218218803406}
# evaluation performance: {'loss': 0.13268772000446916, 'abosulate accuracy': 0.8476500421762466, 'consecutive overlap rate': 0.9445544451475143, 'overlap rate': 0.9835689797997474}
#
# Current epoch: 50,
# training performance: {'loss': 0.02861696733161807, 'abosulate accuracy': 0.8923000305891037, 'consecutive overlap rate': 0.9757951408624649, 'overlap rate': 0.9991466507315636}
# evaluation performance: {'loss': 0.08892281111329794, 'abosulate accuracy': 0.8793500378727913, 'consecutive overlap rate': 0.9683871403336525, 'overlap rate': 0.9898875117301941}
#
# Current epoch: 55,
# training performance: {'loss': 0.019816124765202402, 'abosulate accuracy': 0.9065000295639039, 'consecutive overlap rate': 0.9865968927741051, 'overlap rate': 0.9995299369096756}
# evaluation performance: {'loss': 0.06938618971034885, 'abosulate accuracy': 0.8931500360369682, 'consecutive overlap rate': 0.9791795253753662, 'overlap rate': 0.9923902958631515}
#
# Current epoch: 60,
# training performance: {'loss': 0.01440404129680246, 'abosulate accuracy': 0.9142000257968903, 'consecutive overlap rate': 0.9924264594912529, 'overlap rate': 0.9997289225459098}
# evaluation performance: {'loss': 0.05671625593677163, 'abosulate accuracy': 0.9013500437140465, 'consecutive overlap rate': 0.9852089121937752, 'overlap rate': 0.9939594894647599}
#
# Current epoch: 65,
# training performance: {'loss': 0.010840739379636944, 'abosulate accuracy': 0.9187000229954719, 'consecutive overlap rate': 0.9953066006302833, 'overlap rate': 0.9998423427343368}
# evaluation performance: {'loss': 0.04754369086585939, 'abosulate accuracy': 0.9051500424742699, 'consecutive overlap rate': 0.9883367210626602, 'overlap rate': 0.9950705900788307}
#
# Current epoch: 70,
# training performance: {'loss': 0.008381631423253566, 'abosulate accuracy': 0.9218000203371048, 'consecutive overlap rate': 0.9974612548947335, 'overlap rate': 0.9999218299984932}
# evaluation performance: {'loss': 0.04480986820999533, 'abosulate accuracy': 0.9079000398516655, 'consecutive overlap rate': 0.990269860625267, 'overlap rate': 0.9953481510281563}
#
# Current epoch: 75,
# training performance: {'loss': 0.006618000811431557, 'abosulate accuracy': 0.9230000138282776, 'consecutive overlap rate': 0.9982582464814186, 'overlap rate': 0.9999523773789406}
# evaluation performance: {'loss': 0.04095631620148197, 'abosulate accuracy': 0.9095500394701957, 'consecutive overlap rate': 0.991448099911213, 'overlap rate': 0.9957798734307289}
#
# Current epoch: 80,
# training performance: {'loss': 0.005312246712855994, 'abosulate accuracy': 0.9238000109791755, 'consecutive overlap rate': 0.9989051163196564, 'overlap rate': 0.9999705895781517}
# evaluation performance: {'loss': 0.040960253041703254, 'abosulate accuracy': 0.9101000383496285, 'consecutive overlap rate': 0.9917724326252937, 'overlap rate': 0.9957029059529304}
#
# Current epoch: 85,
# training performance: {'loss': 0.004321219580015167, 'abosulate accuracy': 0.9245000049471855, 'consecutive overlap rate': 0.9993755429983139, 'overlap rate': 0.9999838218092918}
# evaluation performance: {'loss': 0.039291766262613236, 'abosulate accuracy': 0.9114500343799591, 'consecutive overlap rate': 0.9926132306456565, 'overlap rate': 0.9959699138998985}
#
# Current epoch: 90,
# training performance: {'loss': 0.0035540362761821596, 'abosulate accuracy': 0.9247000038623809, 'consecutive overlap rate': 0.9997270256280899, 'overlap rate': 0.9999909639358521}
# evaluation performance: {'loss': 0.037519897473976015, 'abosulate accuracy': 0.9122000366449357, 'consecutive overlap rate': 0.9931295081973076, 'overlap rate': 0.996123057603836}
#
# Current epoch: 95,
# training performance: {'loss': 0.0029503109282813965, 'abosulate accuracy': 0.9249000012874603, 'consecutive overlap rate': 0.9998526692390441, 'overlap rate': 0.9999951764941215}
# evaluation performance: {'loss': 0.038999689189950004, 'abosulate accuracy': 0.9125500380992889, 'consecutive overlap rate': 0.9933433949947357, 'overlap rate': 0.9960636332631111}
#
# Current epoch: 100,
# training performance: {'loss': 0.0024685459036845716, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.03977580771315843, 'abosulate accuracy': 0.9125500351190567, 'consecutive overlap rate': 0.9934889987111092, 'overlap rate': 0.9959577575325966}
#
# Experiments_Logs/Experiment#3/LSTM/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 10.012186956405639, 'abosulate accuracy': 0.04470000219298527, 'consecutive overlap rate': 0.046525198232848196, 'overlap rate': 0.09909372222609818}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.040291031007654965, 'abosulate accuracy': 0.9120750367641449, 'consecutive overlap rate': 0.9931260123848915, 'overlap rate': 0.9957852616906167}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 9.290051103407336, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003041293448768556, 'overlap rate': 0.11282981927356413}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 2.781167173807166, 'abosulate accuracy': 0.6280526619949868, 'consecutive overlap rate': 0.6864293459802866, 'overlap rate': 0.7348106723082694}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.962754321098328, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029124131775461136, 'overlap rate': 0.14428687151521444}
# evaluation performance: {'loss': 3.0414431273937224, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003097465119208209, 'overlap rate': 0.12198847457766533}
#
# Current epoch: 10,
# training performance: {'loss': 2.047069972753525, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013327581179328262, 'overlap rate': 0.38086145631968976}
# evaluation performance: {'loss': 2.835070312023163, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.009965012001339346, 'overlap rate': 0.14389451127499342}
#
# Current epoch: 15,
# training performance: {'loss': 1.2785633146762847, 'abosulate accuracy': 0.0006000000168569386, 'consecutive overlap rate': 0.041409956919960675, 'overlap rate': 0.6183766469359397}
# evaluation performance: {'loss': 3.0163299322128294, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01641147572081536, 'overlap rate': 0.17870189603418113}
#
# Current epoch: 20,
# training performance: {'loss': 0.663863705098629, 'abosulate accuracy': 0.010200000449549407, 'consecutive overlap rate': 0.2337748609483242, 'overlap rate': 0.8247083514928818}
# evaluation performance: {'loss': 2.447848179936409, 'abosulate accuracy': 0.00035000001662410796, 'consecutive overlap rate': 0.1283501200377941, 'overlap rate': 0.403172754496336}
#
# Current epoch: 25,
# training performance: {'loss': 0.34375616163015366, 'abosulate accuracy': 0.22860001267399638, 'consecutive overlap rate': 0.6378018144518137, 'overlap rate': 0.9323570251464843}
# evaluation performance: {'loss': 2.623740018904209, 'abosulate accuracy': 0.02640000117244199, 'consecutive overlap rate': 0.25707334131002424, 'overlap rate': 0.48280595541000365}
#
# Current epoch: 30,
# training performance: {'loss': 0.17029100582003592, 'abosulate accuracy': 0.5631000277586281, 'consecutive overlap rate': 0.8464616276323795, 'overlap rate': 0.976825401186943}
# evaluation performance: {'loss': 1.3891212478280068, 'abosulate accuracy': 0.2038500089198351, 'consecutive overlap rate': 0.510318185389042, 'overlap rate': 0.7415903761982918}
#
# Current epoch: 35,
# training performance: {'loss': 0.0646778435446322, 'abosulate accuracy': 0.7949000358581543, 'consecutive overlap rate': 0.9591715574264527, 'overlap rate': 0.995611846446991}
# evaluation performance: {'loss': 0.41139681441709397, 'abosulate accuracy': 0.6103000283241272, 'consecutive overlap rate': 0.8348091840744019, 'overlap rate': 0.9361687391996384}
#
# Current epoch: 40,
# training performance: {'loss': 0.2468449731823057, 'abosulate accuracy': 0.7279000231996179, 'consecutive overlap rate': 0.9360068030655384, 'overlap rate': 0.9686764471232892}
# evaluation performance: {'loss': 3.759937509894371, 'abosulate accuracy': 0.1019500048365444, 'consecutive overlap rate': 0.43385642804205415, 'overlap rate': 0.45647794380784035}
#
# Current epoch: 45,
# training performance: {'loss': 1.4256394155323506, 'abosulate accuracy': 0.043700002250261605, 'consecutive overlap rate': 0.3182366892695427, 'overlap rate': 0.6115581899881363}
# evaluation performance: {'loss': 2.452351889014244, 'abosulate accuracy': 0.03165000139269978, 'consecutive overlap rate': 0.2562440444715321, 'overlap rate': 0.43911471739411356}
#
# Current epoch: 50,
# training performance: {'loss': 0.23575465176254512, 'abosulate accuracy': 0.318600014958065, 'consecutive overlap rate': 0.6750142876058817, 'overlap rate': 0.9495791688561439}
# evaluation performance: {'loss': 1.8933999001979829, 'abosulate accuracy': 0.1466500060632825, 'consecutive overlap rate': 0.43407161310315134, 'overlap rate': 0.6687423035502433}
#
# Current epoch: 55,
# training performance: {'loss': 0.057886380795389415, 'abosulate accuracy': 0.7960000395774841, 'consecutive overlap rate': 0.9662312418222427, 'overlap rate': 0.9956477522850037}
# evaluation performance: {'loss': 0.24265577690675855, 'abosulate accuracy': 0.7214500330388546, 'consecutive overlap rate': 0.9144899904727936, 'overlap rate': 0.96414362937212}
#
# Current epoch: 60,
# training performance: {'loss': 0.025812341645359994, 'abosulate accuracy': 0.8985000297427177, 'consecutive overlap rate': 0.9937073826789856, 'overlap rate': 0.9992999747395516}
# evaluation performance: {'loss': 0.061022791313007474, 'abosulate accuracy': 0.8753000348806381, 'consecutive overlap rate': 0.9838482886552811, 'overlap rate': 0.993529298901558}
#
# Current epoch: 65,
# training performance: {'loss': 0.01714930864982307, 'abosulate accuracy': 0.9095000237226486, 'consecutive overlap rate': 0.9966727182269096, 'overlap rate': 0.9996471837162971}
# evaluation performance: {'loss': 0.03161167448852211, 'abosulate accuracy': 0.8990500271320343, 'consecutive overlap rate': 0.9937135055661201, 'overlap rate': 0.997276420891285}
#
# Current epoch: 70,
# training performance: {'loss': 0.011690294230356812, 'abosulate accuracy': 0.9156000152230263, 'consecutive overlap rate': 0.9983142331242562, 'overlap rate': 0.9998003885149955}
# evaluation performance: {'loss': 0.024482002784498035, 'abosulate accuracy': 0.9048500314354897, 'consecutive overlap rate': 0.9950436681509018, 'overlap rate': 0.9979094475507736}
#
# Current epoch: 75,
# training performance: {'loss': 0.011848020204342901, 'abosulate accuracy': 0.9121000275015831, 'consecutive overlap rate': 0.9973058179020882, 'overlap rate': 0.9996009439229965}
# evaluation performance: {'loss': 0.026834174199029802, 'abosulate accuracy': 0.9104000315070152, 'consecutive overlap rate': 0.9947687417268753, 'overlap rate': 0.9977488771080971}
#
# Current epoch: 80,
# training performance: {'loss': 0.008020158333238214, 'abosulate accuracy': 0.9209000125527382, 'consecutive overlap rate': 0.9993302881717682, 'overlap rate': 0.9999028369784355}
# evaluation performance: {'loss': 0.013065677578561008, 'abosulate accuracy': 0.9159500241279602, 'consecutive overlap rate': 0.9981375068426133, 'overlap rate': 0.9990782618522644}
#
# Current epoch: 85,
# training performance: {'loss': 0.009328639239538462, 'abosulate accuracy': 0.8925000160932541, 'consecutive overlap rate': 0.9964339807629585, 'overlap rate': 0.999262610077858}
# evaluation performance: {'loss': 0.07765231792582199, 'abosulate accuracy': 0.8163500256836415, 'consecutive overlap rate': 0.9852619886398315, 'overlap rate': 0.9901091665029526}
#
# Current epoch: 90,
# training performance: {'loss': 0.005234946310520172, 'abosulate accuracy': 0.9236000090837478, 'consecutive overlap rate': 0.9997933059930801, 'overlap rate': 0.9999738872051239}
# evaluation performance: {'loss': 0.00922368714818731, 'abosulate accuracy': 0.9197500228881836, 'consecutive overlap rate': 0.9988755270838737, 'overlap rate': 0.9994196996092797}
#
# Current epoch: 95,
# training performance: {'loss': 0.0037499394675251096, 'abosulate accuracy': 0.92430000603199, 'consecutive overlap rate': 0.9998978808522224, 'overlap rate': 0.9999872028827668}
# evaluation performance: {'loss': 0.007407070236513391, 'abosulate accuracy': 0.9204000189900399, 'consecutive overlap rate': 0.9991034924983978, 'overlap rate': 0.9995096281170845}
#
# Current epoch: 100,
# training performance: {'loss': 0.0029853292799089104, 'abosulate accuracy': 0.9247000038623809, 'consecutive overlap rate': 0.9999631911516189, 'overlap rate': 0.9999946370720864}
# evaluation performance: {'loss': 0.007355985033791512, 'abosulate accuracy': 0.9195000171661377, 'consecutive overlap rate': 0.9989978492259979, 'overlap rate': 0.9994399502873421}
#
# Experiments_Logs/Experiment#3/LSTM/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.9552220121026039, 'abosulate accuracy': 0.02630000119097531, 'consecutive overlap rate': 0.5375733399763704, 'overlap rate': 0.8621221743524075}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.006688584870425984, 'abosulate accuracy': 0.9198250278830529, 'consecutive overlap rate': 0.9990633800625801, 'overlap rate': 0.9995733246207237}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.6800258067346387, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.4299327673450593, 'overlap rate': 0.7926080076925216}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.5433869351216248, 'abosulate accuracy': 0.48252633260563016, 'consecutive overlap rate': 0.8601368095137572, 'overlap rate': 0.9030627835738031}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.9828252732753753, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.003152167526423, 'overlap rate': 0.13383561689406634}
# evaluation performance: {'loss': 3.0342062294483183, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0032971432490739973, 'overlap rate': 0.12730702627450227}
#
# Current epoch: 10,
# training performance: {'loss': 1.9963697135448455, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.016317938815336674, 'overlap rate': 0.41150192394852636}
# evaluation performance: {'loss': 2.6324558556079865, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01139697270700708, 'overlap rate': 0.19417627826333045}
#
# Current epoch: 15,
# training performance: {'loss': 1.3191055804491043, 'abosulate accuracy': 0.0004000000189989805, 'consecutive overlap rate': 0.05208546337671578, 'overlap rate': 0.622699424624443}
# evaluation performance: {'loss': 2.73650581240654, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028530819388106466, 'overlap rate': 0.23202177360653878}
#
# Current epoch: 20,
# training performance: {'loss': 0.5752136431634426, 'abosulate accuracy': 0.05340000237338245, 'consecutive overlap rate': 0.33153389357030394, 'overlap rate': 0.8541879311203957}
# evaluation performance: {'loss': 2.2286269545555113, 'abosulate accuracy': 0.001250000053551048, 'consecutive overlap rate': 0.16132427752017975, 'overlap rate': 0.46764736622571945}
#
# Current epoch: 25,
# training performance: {'loss': 1.3147259190678597, 'abosulate accuracy': 0.005400000279769302, 'consecutive overlap rate': 0.2012188581749797, 'overlap rate': 0.6398833893239498}
# evaluation performance: {'loss': 3.3824693620204926, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08583806254900991, 'overlap rate': 0.20838479921221734}
#
# Current epoch: 30,
# training performance: {'loss': 0.28192522898316386, 'abosulate accuracy': 0.2685000107623637, 'consecutive overlap rate': 0.6950565934181213, 'overlap rate': 0.9502760320901871}
# evaluation performance: {'loss': 1.3529672294855117, 'abosulate accuracy': 0.15710000796243548, 'consecutive overlap rate': 0.46566139385104177, 'overlap rate': 0.7211652889847755}
#
# Current epoch: 35,
# training performance: {'loss': 1.7764470085501671, 'abosulate accuracy': 0.004600000195205211, 'consecutive overlap rate': 0.20439184745773673, 'overlap rate': 0.515884667634964}
# evaluation performance: {'loss': 3.913311409950256, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04856109828688204, 'overlap rate': 0.08663451550528407}
#
# Current epoch: 40,
# training performance: {'loss': 3.0463520526885985, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0568656250834465, 'overlap rate': 0.17908066250383853}
# evaluation performance: {'loss': 3.186079812049866, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.06224933341145515, 'overlap rate': 0.13163880538195372}
#
# Current epoch: 45,
# training performance: {'loss': 2.8225323259830475, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08809616575017572, 'overlap rate': 0.22571922428905963}
# evaluation performance: {'loss': 3.0754091143608093, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08765991441905499, 'overlap rate': 0.16092899665236474}
#
# Current epoch: 50,
# training performance: {'loss': 2.6624707341194154, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11556858196854591, 'overlap rate': 0.27242684066295625}
# evaluation performance: {'loss': 2.9485672295093535, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.11568955769762397, 'overlap rate': 0.19810509588569403}
#
# Current epoch: 55,
# training performance: {'loss': 2.4457419753074645, 'abosulate accuracy': 0.0005000000121071935, 'consecutive overlap rate': 0.14471131879836321, 'overlap rate': 0.3354174491018057}
# evaluation performance: {'loss': 2.7590086221694947, 'abosulate accuracy': 0.001350000058300793, 'consecutive overlap rate': 0.1497511465102434, 'overlap rate': 0.25476019978523257}
#
# Current epoch: 60,
# training performance: {'loss': 2.173103791475296, 'abosulate accuracy': 0.003500000154599547, 'consecutive overlap rate': 0.1766429588198662, 'overlap rate': 0.4139916431158781}
# evaluation performance: {'loss': 2.554632207751274, 'abosulate accuracy': 0.005850000254577025, 'consecutive overlap rate': 0.18030618205666543, 'overlap rate': 0.3162996917963028}
#
# Current epoch: 65,
# training performance: {'loss': 1.9051891565322876, 'abosulate accuracy': 0.0048000002629123625, 'consecutive overlap rate': 0.16872251834720373, 'overlap rate': 0.4841718226671219}
# evaluation performance: {'loss': 2.38611401617527, 'abosulate accuracy': 0.00895000034943223, 'consecutive overlap rate': 0.18521997891366482, 'overlap rate': 0.367785769701004}
#
# Current epoch: 70,
# training performance: {'loss': 1.5110416904091835, 'abosulate accuracy': 0.020700001041404903, 'consecutive overlap rate': 0.23837925475090743, 'overlap rate': 0.5937840491533279}
# evaluation performance: {'loss': 2.214028099179268, 'abosulate accuracy': 0.016500000684754924, 'consecutive overlap rate': 0.20666315034031868, 'overlap rate': 0.4288908042013645}
#
# Current epoch: 75,
# training performance: {'loss': 1.1208011463284493, 'abosulate accuracy': 0.0504000021610409, 'consecutive overlap rate': 0.32378065921366217, 'overlap rate': 0.7029524877667427}
# evaluation performance: {'loss': 1.9405742555856704, 'abosulate accuracy': 0.04440000181784853, 'consecutive overlap rate': 0.2780973814427853, 'overlap rate': 0.5250829242169857}
#
# Current epoch: 80,
# training performance: {'loss': 0.77604461312294, 'abosulate accuracy': 0.10280000505736098, 'consecutive overlap rate': 0.4093830682337284, 'overlap rate': 0.7914267003536224}
# evaluation performance: {'loss': 1.8373492285609245, 'abosulate accuracy': 0.07605000354815275, 'consecutive overlap rate': 0.3430092874914408, 'overlap rate': 0.5842834495007991}
#
# Current epoch: 85,
# training performance: {'loss': 0.4990695834159851, 'abosulate accuracy': 0.16610000729560853, 'consecutive overlap rate': 0.49970119036734106, 'overlap rate': 0.8696344554424286}
# evaluation performance: {'loss': 1.5483611203730105, 'abosulate accuracy': 0.1293000065663364, 'consecutive overlap rate': 0.4481909804046154, 'overlap rate': 0.6721759237349033}
#
# Current epoch: 90,
# training performance: {'loss': 0.360639076307416, 'abosulate accuracy': 0.20650000909809024, 'consecutive overlap rate': 0.5730848431587219, 'overlap rate': 0.9081475034356117}
# evaluation performance: {'loss': 1.092093639075756, 'abosulate accuracy': 0.2011000103491824, 'consecutive overlap rate': 0.5248635977506637, 'overlap rate': 0.7760678127408027}
#
# Current epoch: 95,
# training performance: {'loss': 0.2035188963636756, 'abosulate accuracy': 0.383700019295793, 'consecutive overlap rate': 0.7415173545479774, 'overlap rate': 0.9570624902844429}
# evaluation performance: {'loss': 0.5887651115655899, 'abosulate accuracy': 0.36255001671961506, 'consecutive overlap rate': 0.7146980911493301, 'overlap rate': 0.8834715202450752}
#
# Current epoch: 100,
# training performance: {'loss': 2.662824445962906, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.09425895046442748, 'overlap rate': 0.2882342141121626}
# evaluation performance: {'loss': 2.955719143152237, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.07385099618695676, 'overlap rate': 0.19859245531260966}
#
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 3.1848749220371246, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.05023625052999705, 'overlap rate': 0.10867709424346686}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 2.9552262008190153, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.0738799340557307, 'overlap rate': 0.19828089736402035}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 3.0382092122108704, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.034507348075989756, 'overlap rate': 0.12668356010990758}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.0491551537262764, 'abosulate accuracy': 0.0002894736948962274, 'consecutive overlap rate': 0.053182671520564904, 'overlap rate': 0.16061910163415105}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.9542948484420775, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0037399275141069667, 'overlap rate': 0.14602652788162232}
# evaluation performance: {'loss': 3.0123381078243257, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0037320829869713634, 'overlap rate': 0.12414972018450499}
#
# Current epoch: 10,
# training performance: {'loss': 2.001286280155182, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.014497241599019616, 'overlap rate': 0.4132088288664818}
# evaluation performance: {'loss': 2.786521923542023, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00952662390191108, 'overlap rate': 0.15149845127016306}
#
# Current epoch: 15,
# training performance: {'loss': 1.194383515417576, 'abosulate accuracy': 0.0012000000686384737, 'consecutive overlap rate': 0.0751819874625653, 'overlap rate': 0.6588921822607517}
# evaluation performance: {'loss': 2.867518073320389, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04405132988467812, 'overlap rate': 0.22391822561621666}
#
# Current epoch: 20,
# training performance: {'loss': 1.0195947222411632, 'abosulate accuracy': 0.05180000232066959, 'consecutive overlap rate': 0.29908575769513845, 'overlap rate': 0.740178482979536}
# evaluation performance: {'loss': 3.7423297345638273, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0725516795180738, 'overlap rate': 0.1997745804488659}
#
# Current epoch: 25,
# training performance: {'loss': 0.23737102076411248, 'abosulate accuracy': 0.3946000172290951, 'consecutive overlap rate': 0.7688845381140709, 'overlap rate': 0.9618219688534737}
# evaluation performance: {'loss': 2.2512477695941926, 'abosulate accuracy': 0.0674500027904287, 'consecutive overlap rate': 0.3346049040555954, 'overlap rate': 0.5756242610514164}
#
# Current epoch: 30,
# training performance: {'loss': 0.505007979273796, 'abosulate accuracy': 0.06950000283541158, 'consecutive overlap rate': 0.4312550682574511, 'overlap rate': 0.8865870833396912}
# evaluation performance: {'loss': 2.6555753141641616, 'abosulate accuracy': 0.0223000007099472, 'consecutive overlap rate': 0.2298061590641737, 'overlap rate': 0.4709841854870319}
#
# Current epoch: 35,
# training performance: {'loss': 0.09636554894968867, 'abosulate accuracy': 0.7517000332474708, 'consecutive overlap rate': 0.9472988694906235, 'overlap rate': 0.992032314836979}
# evaluation performance: {'loss': 0.695451257005334, 'abosulate accuracy': 0.4614000231027603, 'consecutive overlap rate': 0.7418039932847023, 'overlap rate': 0.8835907012224198}
#
# Current epoch: 40,
# training performance: {'loss': 0.04622698798775673, 'abosulate accuracy': 0.86380003541708, 'consecutive overlap rate': 0.98487918227911, 'overlap rate': 0.9981728717684746}
# evaluation performance: {'loss': 0.14749550493434072, 'abosulate accuracy': 0.7940000385046005, 'consecutive overlap rate': 0.9509175509214401, 'overlap rate': 0.9803397461771965}
#
# Current epoch: 45,
# training performance: {'loss': 0.029959880001842975, 'abosulate accuracy': 0.8877000287175179, 'consecutive overlap rate': 0.992265023291111, 'overlap rate': 0.9990011349320411}
# evaluation performance: {'loss': 0.09417414464987814, 'abosulate accuracy': 0.8397000312805176, 'consecutive overlap rate': 0.9743308469653129, 'overlap rate': 0.9885048881173134}
#
# Current epoch: 50,
# training performance: {'loss': 2.9646476209163666, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07879368932917714, 'overlap rate': 0.16586432345211505}
# evaluation performance: {'loss': 3.1180266380310058, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.08706820970401168, 'overlap rate': 0.15003296136856079}
#
# Current epoch: 55,
# training performance: {'loss': 2.6836923867464066, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.12163131916895509, 'overlap rate': 0.23573567382991314}
# evaluation performance: {'loss': 2.925331509113312, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.12404509549960493, 'overlap rate': 0.19957802444696426}
#
# Current epoch: 60,
# training performance: {'loss': 2.4550962924957274, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.14875183589756488, 'overlap rate': 0.3036409802734852}
# evaluation performance: {'loss': 2.756924569606781, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.1528171744197607, 'overlap rate': 0.2482026197016239}
#
# Current epoch: 65,
# training performance: {'loss': 2.093544086813927, 'abosulate accuracy': 0.0020000000949949026, 'consecutive overlap rate': 0.1726552966982126, 'overlap rate': 0.40918547101318836}
# evaluation performance: {'loss': 2.5652720987796784, 'abosulate accuracy': 0.004250000178581103, 'consecutive overlap rate': 0.16944679748266936, 'overlap rate': 0.31154272295534613}
#
# Current epoch: 70,
# training performance: {'loss': 1.5498885601758956, 'abosulate accuracy': 0.01740000060526654, 'consecutive overlap rate': 0.1948544504120946, 'overlap rate': 0.5683262035250664}
# evaluation performance: {'loss': 2.3138048350811005, 'abosulate accuracy': 0.01900000108871609, 'consecutive overlap rate': 0.1713153176009655, 'overlap rate': 0.410372581705451}
#
# Current epoch: 75,
# training performance: {'loss': 1.074095619469881, 'abosulate accuracy': 0.02710000145016238, 'consecutive overlap rate': 0.23883302435278891, 'overlap rate': 0.7017801731824875}
# evaluation performance: {'loss': 2.818120741844177, 'abosulate accuracy': 0.0009000000485684722, 'consecutive overlap rate': 0.17013852149248124, 'overlap rate': 0.37812049835920336}
#
# Current epoch: 80,
# training performance: {'loss': 0.7850828625261783, 'abosulate accuracy': 0.10200000377371907, 'consecutive overlap rate': 0.39942695796489713, 'overlap rate': 0.786368365585804}
# evaluation performance: {'loss': 1.8338978379964828, 'abosulate accuracy': 0.027200001385062934, 'consecutive overlap rate': 0.37813574969768526, 'overlap rate': 0.5983012229204178}
#
# Current epoch: 85,
# training performance: {'loss': 0.39640336893498895, 'abosulate accuracy': 0.13840000695781782, 'consecutive overlap rate': 0.4919980335980654, 'overlap rate': 0.8949700206518173}
# evaluation performance: {'loss': 1.8489938393235206, 'abosulate accuracy': 0.07555000356514938, 'consecutive overlap rate': 0.3789690099656582, 'overlap rate': 0.6436926826834679}
#
# Current epoch: 90,
# training performance: {'loss': 1.2074115380644799, 'abosulate accuracy': 0.009800000465475023, 'consecutive overlap rate': 0.3293261531740427, 'overlap rate': 0.6845034524798393}
# evaluation performance: {'loss': 1.9282334342598915, 'abosulate accuracy': 0.08700000373646617, 'consecutive overlap rate': 0.38316135853528976, 'overlap rate': 0.5905784592032433}
#
# Current epoch: 95,
# training performance: {'loss': 2.089147397130728, 'abosulate accuracy': 0.010200000135228038, 'consecutive overlap rate': 0.25900062376167626, 'overlap rate': 0.4315467946231365}
# evaluation performance: {'loss': 2.1331048220396043, 'abosulate accuracy': 0.04225000249571167, 'consecutive overlap rate': 0.3478576108813286, 'overlap rate': 0.4342713911086321}
#
# Current epoch: 100,
# training performance: {'loss': 0.8578287735581398, 'abosulate accuracy': 0.06450000312179327, 'consecutive overlap rate': 0.39394324738532305, 'overlap rate': 0.759057791531086}
# evaluation performance: {'loss': 3.909959411621094, 'abosulate accuracy': 0.0017500000772997736, 'consecutive overlap rate': 0.16150788702070712, 'overlap rate': 0.26224533207714557}
#
# Experiments_Logs/Experiment#3/LSTM/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/LSTM/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.0871522091329098, 'abosulate accuracy': 0.07797500430606305, 'consecutive overlap rate': 0.2905216689221561, 'overlap rate': 0.6742321498692035}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.09636231535114348, 'abosulate accuracy': 0.8387250378727913, 'consecutive overlap rate': 0.9731518879532814, 'overlap rate': 0.9880765378475189}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 2.5207074273017147, 'abosulate accuracy': 0.005729032503140549, 'consecutive overlap rate': 0.20859150540444157, 'overlap rate': 0.6303164070652377}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.6549104701139425, 'abosulate accuracy': 0.4282631785823277, 'consecutive overlap rate': 0.8258361612495623, 'overlap rate': 0.8823650542058443}
# Experiments_Logs/Experiment#3/LSTM/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#3 with LSTM seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))
# Out:
# Experiments_Logs/Experiment#3/LSTM/hyperparameters.json saved!

# %%
from google.colab import runtime
runtime.unassign()
