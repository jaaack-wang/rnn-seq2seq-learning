# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 256
embd_dim = 128
num_layers = 1
rnn_type = "GRU"
dropout_rate = 0.0
bidirectional = False
use_attention = True
reduction_method = torch.sum

learning_rate = 5e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 3
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#3 created!
# ./Experiments_Logs/Experiment#3/GRU created!
# ./Experiments_Logs/Experiment#3/GRU/Training_Logs created!
# ./Experiments_Logs/Experiment#3/GRU/Testing_Logs created!
# ./Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#3/GRU/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 100 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#3 with GRU seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss':
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.017021196358837188, 'abosulate accuracy': 0.9151000335812569, 'consecutive overlap rate': 0.9934580430388451, 'overlap rate': 0.9982813209295273}
#
# Experiments_Logs/Experiment#3/GRU/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 6.114115828275681, 'abosulate accuracy': 0.0699000037042424, 'consecutive overlap rate': 0.1274337512906641, 'overlap rate': 0.29812127649784087}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.020414838381111623, 'abosulate accuracy': 0.9148000463843345, 'consecutive overlap rate': 0.9930626541376114, 'overlap rate': 0.9978960663080215}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.764449654856036, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01529049149924709, 'overlap rate': 0.17558860903786075}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.613869313187407, 'abosulate accuracy': 0.46992107459625815, 'consecutive overlap rate': 0.5213331238023544, 'overlap rate': 0.5684290838084722}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.6833980083465576, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0117705003824085, 'overlap rate': 0.20081859957426787}
# evaluation performance: {'loss': 2.8361185610294344, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013263111689593644, 'overlap rate': 0.13281000088900327}
#
# Current epoch: 10,
# training performance: {'loss': 1.8454962372779846, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02483411051798612, 'overlap rate': 0.3927199460566044}
# evaluation performance: {'loss': 2.606732630729675, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03426406311336905, 'overlap rate': 0.16871022302657365}
#
# Current epoch: 15,
# training performance: {'loss': 1.4312229990959167, 'abosulate accuracy': 0.01760000076610595, 'consecutive overlap rate': 0.1406310982303694, 'overlap rate': 0.6129682846367359}
# evaluation performance: {'loss': 2.7993512213230134, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.11251650480553507, 'overlap rate': 0.24940925166010858}
#
# Current epoch: 20,
# training performance: {'loss': 1.2737831354141236, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.11243791384622455, 'overlap rate': 0.5929325699806214}
# evaluation performance: {'loss': 2.7257791221141816, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.12807214437052608, 'overlap rate': 0.2862116523087025}
#
# Current epoch: 25,
# training performance: {'loss': 1.3649924650788308, 'abosulate accuracy': 0.04440000174799934, 'consecutive overlap rate': 0.228558530472219, 'overlap rate': 0.680652168393135}
# evaluation performance: {'loss': 2.835562926530838, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.1572816099971533, 'overlap rate': 0.30080447942018507}
#
# Current epoch: 30,
# training performance: {'loss': 0.3565809603780508, 'abosulate accuracy': 0.30850001339567823, 'consecutive overlap rate': 0.47064655981957915, 'overlap rate': 0.9205946385860443}
# training performance: {'loss': 0.007841961900703609, 'abosulate accuracy': 0.9156000211834907, 'consecutive overlap rate': 0.9929875552654266, 'overlap rate': 0.9997700065374374}
# evaluation performance: {'loss': 0.04855499784462154, 'abosulate accuracy': 0.9037000373005867, 'consecutive overlap rate': 0.984876249730587, 'overlap rate': 0.9944583609700203}
#
# Current epoch: 80,
# training performance: {'loss': 0.006326508242636919, 'abosulate accuracy': 0.9191000193357468, 'consecutive overlap rate': 0.9957755982875824, 'overlap rate': 0.9998559162020684}
# evaluation performance: {'loss': 0.043757780210580674, 'abosulate accuracy': 0.9060500368475914, 'consecutive overlap rate': 0.9868258878588676, 'overlap rate': 0.99505525380373}
#
# Current epoch: 85,
# training performance: {'loss': 0.005166599078802392, 'abosulate accuracy': 0.9210000172257423, 'consecutive overlap rate': 0.9972847908735275, 'overlap rate': 0.9999035090208054}
# evaluation performance: {'loss': 0.0433590158703737, 'abosulate accuracy': 0.9078000381588935, 'consecutive overlap rate': 0.9882384419441224, 'overlap rate': 0.9951165452599525}
#
# Current epoch: 90,
# training performance: {'loss': 0.004250518104527146, 'abosulate accuracy': 0.9223000153899192, 'consecutive overlap rate': 0.9983393654227257, 'overlap rate': 0.9999385982751846}
# evaluation performance: {'loss': 0.03927709879935719, 'abosulate accuracy': 0.9096500381827355, 'consecutive overlap rate': 0.989713168144226, 'overlap rate': 0.9956930965185166}
#
# Current epoch: 95,
# training performance: {'loss': 0.0035304087738040834, 'abosulate accuracy': 0.9234000131487846, 'consecutive overlap rate': 0.999013988673687, 'overlap rate': 0.9999646827578544}
# evaluation performance: {'loss': 0.03699489044956863, 'abosulate accuracy': 0.911050035059452, 'consecutive overlap rate': 0.990959070622921, 'overlap rate': 0.9959794521331787}
#
# Current epoch: 100,
# training performance: {'loss': 0.002956754030310549, 'abosulate accuracy': 0.9241000100970268, 'consecutive overlap rate': 0.9995146572589875, 'overlap rate': 0.9999804645776749}
# evaluation performance: {'loss': 0.036497685901122165, 'abosulate accuracy': 0.911750040948391, 'consecutive overlap rate': 0.9915381416678428, 'overlap rate': 0.9960559830069542}
#
# Experiments_Logs/Experiment#3/GRU/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 10.582064598798752, 'abosulate accuracy': 0.04210000202292576, 'consecutive overlap rate': 0.04379000036278739, 'overlap rate': 0.07780583787243814}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.033161429141182454, 'abosulate accuracy': 0.9111000388860703, 'consecutive overlap rate': 0.9916936784982682, 'overlap rate': 0.9964946299791336}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 10.552038758800876, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0027648450250947667, 'overlap rate': 0.07830065988725232}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 2.9974712175562193, 'abosulate accuracy': 0.6500526602827258, 'consecutive overlap rate': 0.6964450663347778, 'overlap rate': 0.7327609428841817}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.747833800315857, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012922477384563535, 'overlap rate': 0.19333975818008184}
# evaluation performance: {'loss': 2.8475696980953216, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013397690455894918, 'overlap rate': 0.13519093226641415}
#
# Current epoch: 10,
# training performance: {'loss': 1.964627954363823, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.030269446317106485, 'overlap rate': 0.37118127942085266}
# evaluation performance: {'loss': 2.661809903383255, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.022145744087174533, 'overlap rate': 0.14262557961046696}
#
# Current epoch: 15,
# training performance: {'loss': 1.2679518342018128, 'abosulate accuracy': 0.0003000000026077032, 'consecutive overlap rate': 0.06194160750601441, 'overlap rate': 0.5809326060116291}
# evaluation performance: {'loss': 2.350653076171875, 'abosulate accuracy': 0.0009000000369269401, 'consecutive overlap rate': 0.08736571166664361, 'overlap rate': 0.2738616269081831}
#
# Current epoch: 20,
# training performance: {'loss': 0.9659231647849083, 'abosulate accuracy': 0.0018000000738538802, 'consecutive overlap rate': 0.10969128482975066, 'overlap rate': 0.6987748637795448}
# evaluation performance: {'loss': 2.738545647263527, 'abosulate accuracy': 0.020350001007318496, 'consecutive overlap rate': 0.13494975944049656, 'overlap rate': 0.29056251887232065}
#
# Current epoch: 25,
# training performance: {'loss': 0.854847003519535, 'abosulate accuracy': 0.004000000120140612, 'consecutive overlap rate': 0.11927983881905675, 'overlap rate': 0.7353777199983597}
# evaluation performance: {'loss': 2.2623892605304716, 'abosulate accuracy': 0.019050000881543384, 'consecutive overlap rate': 0.1599122653249651, 'overlap rate': 0.365065585449338}
#
# Current epoch: 30,
# training performance: {'loss': 0.3073677495121956, 'abosulate accuracy': 0.19790000770008193, 'consecutive overlap rate': 0.35624400349333885, 'overlap rate': 0.928145632147789}
# evaluation performance: {'loss': 1.0450112879276277, 'abosulate accuracy': 0.260400010261219, 'consecutive overlap rate': 0.4313897009007633, 'overlap rate': 0.7431836165487766}
#
# Current epoch: 35,
# training performance: {'loss': 0.29064284488558767, 'abosulate accuracy': 0.159400006395299, 'consecutive overlap rate': 0.337214975990355, 'overlap rate': 0.9212371245026588}
# evaluation performance: {'loss': 1.89415442943573, 'abosulate accuracy': 0.2896500125702005, 'consecutive overlap rate': 0.46111510787159204, 'overlap rate': 0.6177799310535192}
#
# Current epoch: 40,
# training performance: {'loss': 0.07663662163540721, 'abosulate accuracy': 0.6627000294625759, 'consecutive overlap rate': 0.793043301999569, 'overlap rate': 0.9892132610082627}
# evaluation performance: {'loss': 0.6684191472828388, 'abosulate accuracy': 0.6141500331461429, 'consecutive overlap rate': 0.748832331597805, 'overlap rate': 0.899316468834877}
#
# Current epoch: 45,
# training performance: {'loss': 0.034900510171428326, 'abosulate accuracy': 0.8343000382184982, 'consecutive overlap rate': 0.9216468170285225, 'overlap rate': 0.9973239004611969}
# evaluation performance: {'loss': 0.12721343212760985, 'abosulate accuracy': 0.8264000430703163, 'consecutive overlap rate': 0.9202875763177871, 'overlap rate': 0.9832865729928016}
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.01776099527487531, 'abosulate accuracy': 0.9160500332713127, 'consecutive overlap rate': 0.9933826178312302, 'overlap rate': 0.9981936991214753}
#
# Current epoch: 100,
# training performance: {'loss': 0.00188194815418683, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.016541591112036257, 'abosulate accuracy': 0.916700029373169, 'consecutive overlap rate': 0.9939307898283005, 'overlap rate': 0.9983418881893158}
#
# Experiments_Logs/Experiment#3/GRU/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 6.596636557579041, 'abosulate accuracy': 0.06262500314041972, 'consecutive overlap rate': 0.13600666825659574, 'overlap rate': 0.3336496140807867}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.022097149438923224, 'abosulate accuracy': 0.9155750378966332, 'consecutive overlap rate': 0.993276247382164, 'overlap rate': 0.9977291405200959}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.81573086092549, 'abosulate accuracy': 0.0007741935851593171, 'consecutive overlap rate': 0.0164232924850958, 'overlap rate': 0.2184754288965656}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 4.727600579597301, 'abosulate accuracy': 0.4372631757777478, 'consecutive overlap rate': 0.49528692643109123, 'overlap rate': 0.5471587677143122}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.329538869857788, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01817009432706982, 'overlap rate': 0.2971011996269226}
# evaluation performance: {'loss': 2.6614667057991026, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010551399691030383, 'overlap rate': 0.15443116798996925}
#
# Current epoch: 10,
# training performance: {'loss': 1.5969241112470627, 'abosulate accuracy': 0.000800000037997961, 'consecutive overlap rate': 0.08872309322468937, 'overlap rate': 0.5355306096374989}
# evaluation performance: {'loss': 2.4485347092151644, 'abosulate accuracy': 0.0002500000118743628, 'consecutive overlap rate': 0.05581998289562762, 'overlap rate': 0.30329848974943163}
#
# Current epoch: 15,
# training performance: {'loss': 0.4438381604850292, 'abosulate accuracy': 0.08710000357823447, 'consecutive overlap rate': 0.514046795014292, 'overlap rate': 0.8795486882328987}
# evaluation performance: {'loss': 2.7250265330076218, 'abosulate accuracy': 0.0014000000606756656, 'consecutive overlap rate': 0.20225717583671213, 'overlap rate': 0.4141804311424494}
#
# Current epoch: 20,
# training performance: {'loss': 0.16559847425669433, 'abosulate accuracy': 0.4347000161651522, 'consecutive overlap rate': 0.8062383085489273, 'overlap rate': 0.9718258380889893}
# evaluation performance: {'loss': 0.7697172060608863, 'abosulate accuracy': 0.37180001810193064, 'consecutive overlap rate': 0.6811341136693955, 'overlap rate': 0.8565337240695954}
#
# Current epoch: 25,
# training performance: {'loss': 0.05783157702535391, 'abosulate accuracy': 0.7920000374317169, 'consecutive overlap rate': 0.9567926302552223, 'overlap rate': 0.9953640997409821}
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.004535028694954235, 'abosulate accuracy': 0.9202000185847282, 'consecutive overlap rate': 0.9993265688419342, 'overlap rate': 0.9996058538556098}
#
# Current epoch: 80,
# training performance: {'loss': 0.0011632385983830317, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0036771434257389045, 'abosulate accuracy': 0.9212500154972076, 'consecutive overlap rate': 0.9995335027575493, 'overlap rate': 0.9996936559677124}
#
# Current epoch: 85,
# training performance: {'loss': 0.0009703972129500471, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0029401778578176164, 'abosulate accuracy': 0.9222500130534173, 'consecutive overlap rate': 0.9997028693556785, 'overlap rate': 0.9997667729854584}
#
# Current epoch: 90,
# training performance: {'loss': 0.0008062085267738439, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.002315198407450225, 'abosulate accuracy': 0.9230000108480454, 'consecutive overlap rate': 0.9997809931635857, 'overlap rate': 0.9998283416032792}
#
# Current epoch: 95,
# training performance: {'loss': 0.0006648349088209215, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0020387823824421503, 'abosulate accuracy': 0.9234500080347061, 'consecutive overlap rate': 0.9998137593269348, 'overlap rate': 0.9998488530516625}
#
# Current epoch: 100,
# training performance: {'loss': 0.0005400254653068259, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0016405124733864795, 'abosulate accuracy': 0.923900006711483, 'consecutive overlap rate': 0.9998534262180329, 'overlap rate': 0.9998851299285889}
#
# Experiments_Logs/Experiment#3/GRU/Models_Logs/RedStr_1.pt saved!
#
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_1.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.006481510365847498, 'abosulate accuracy': 0.9981750179082155, 'consecutive overlap rate': 0.9995854202657938, 'overlap rate': 0.9999354414641857}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RedStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.0011615358052949887, 'abosulate accuracy': 0.9240500137209893, 'consecutive overlap rate': 0.9999076172709465, 'overlap rate': 0.9999352663755416}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RedStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.33520821938591616, 'abosulate accuracy': 0.4740709252895847, 'consecutive overlap rate': 0.8094742455790119, 'overlap rate': 0.9459392878317063}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RedStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.5124065572040548, 'abosulate accuracy': 0.5185789583299897, 'consecutive overlap rate': 0.8772532360530213, 'overlap rate': 0.9141277600275842}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RedStr_1_non_shuffled.json saved!
#
# ==================== testing on RedStr_1 finishes ====================
#
#
# ==================== training on RedStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.3395945012569426, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010926799499429762, 'overlap rate': 0.2798054598271847}
# evaluation performance: {'loss': 2.607997512817383, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.007207024877425283, 'overlap rate': 0.15625312849879264}
#
# Current epoch: 10,
# training performance: {'loss': 1.4843468472361565, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.05217082530725747, 'overlap rate': 0.6001648548990488}
# evaluation performance: {'loss': 2.8736986458301543, 'abosulate accuracy': 0.0007000000274274498, 'consecutive overlap rate': 0.03947965460829437, 'overlap rate': 0.21974184531718494}
#
# Current epoch: 15,
# training performance: {'loss': 0.032178613590076566, 'abosulate accuracy': 0.8494000345468521, 'consecutive overlap rate': 0.9773583054542542, 'overlap rate': 0.997899928689003}
# evaluation performance: {'loss': 0.18849056372418999, 'abosulate accuracy': 0.7325500339269638, 'consecutive overlap rate': 0.9169788211584091, 'overlap rate': 0.9729971200227737}
#
# Current epoch: 65,
# training performance: {'loss': 0.026688339863903822, 'abosulate accuracy': 0.8589000344276428, 'consecutive overlap rate': 0.9793595790863037, 'overlap rate': 0.9979318767786026}
# evaluation performance: {'loss': 0.21128869093954564, 'abosulate accuracy': 0.7896000370383263, 'consecutive overlap rate': 0.9300342455506325, 'overlap rate': 0.9718058422207833}
#
# Current epoch: 70,
# training performance: {'loss': 0.016759997245389967, 'abosulate accuracy': 0.8981000274419785, 'consecutive overlap rate': 0.9935578495264054, 'overlap rate': 0.9992914766073226}
# evaluation performance: {'loss': 0.16804153681732714, 'abosulate accuracy': 0.8194000393152236, 'consecutive overlap rate': 0.9433061093091964, 'overlap rate': 0.9788420647382736}
#
# Current epoch: 75,
# training performance: {'loss': 0.011553889664355665, 'abosulate accuracy': 0.9121000230312347, 'consecutive overlap rate': 0.9969616875052452, 'overlap rate': 0.9997076347470284}
# evaluation performance: {'loss': 0.02337223496288061, 'abosulate accuracy': 0.9003500327467918, 'consecutive overlap rate': 0.992029894888401, 'overlap rate': 0.9979794129729271}
#
# Current epoch: 80,
# training performance: {'loss': 0.009407079248921946, 'abosulate accuracy': 0.9152000233530998, 'consecutive overlap rate': 0.997722539305687, 'overlap rate': 0.9997709631919861}
# evaluation performance: {'loss': 0.017395351175218822, 'abosulate accuracy': 0.9050500303506851, 'consecutive overlap rate': 0.9941747590899468, 'overlap rate': 0.9985472187399864}
#
# Current epoch: 85,
# training performance: {'loss': 0.00730862173368223, 'abosulate accuracy': 0.9200000151991844, 'consecutive overlap rate': 0.9990733489394188, 'overlap rate': 0.9998979672789574}
# evaluation performance: {'loss': 0.014977599238045513, 'abosulate accuracy': 0.9057000294327736, 'consecutive overlap rate': 0.995207890868187, 'overlap rate': 0.9987186655402184}
#
# Current epoch: 90,
# training performance: {'loss': 0.005874865141231566, 'abosulate accuracy': 0.9224000096321106, 'consecutive overlap rate': 0.9995519459247589, 'overlap rate': 0.9999474465847016}
# evaluation performance: {'loss': 0.012898540386231616, 'abosulate accuracy': 0.9090000286698341, 'consecutive overlap rate': 0.995890948176384, 'overlap rate': 0.9989193856716156}
#
# Current epoch: 95,
# training performance: {'loss': 0.0049093686131527646, 'abosulate accuracy': 0.9226000100374222, 'consecutive overlap rate': 0.9995611548423767, 'overlap rate': 0.9999519020318985}
# evaluation performance: {'loss': 0.010322519642068073, 'abosulate accuracy': 0.9129000246524811, 'consecutive overlap rate': 0.9970838561654091, 'overlap rate': 0.9991873174905777}
#
# Current epoch: 100,
# training performance: {'loss': 0.004163177724694833, 'abosulate accuracy': 0.9238000065088272, 'consecutive overlap rate': 0.9998593538999557, 'overlap rate': 0.9999751970171928}
# evaluation performance: {'loss': 0.008437256416073069, 'abosulate accuracy': 0.9154000207781792, 'consecutive overlap rate': 0.9978399142622948, 'overlap rate': 0.9993825241923332}
#
# Experiments_Logs/Experiment#3/GRU/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 2.040437165647745, 'abosulate accuracy': 0.2325500098057091, 'consecutive overlap rate': 0.24402626072987915, 'overlap rate': 0.7778161253780127}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.008519654662813991, 'abosulate accuracy': 0.9164000242948532, 'consecutive overlap rate': 0.9981627911329269, 'overlap rate': 0.9993802428245544}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 4.055576087582496, 'abosulate accuracy': 2.5806452838643906e-05, 'consecutive overlap rate': 0.00922472033266639, 'overlap rate': 0.5631753833063187}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.3439249785641503, 'abosulate accuracy': 0.4521052801773246, 'consecutive overlap rate': 0.74472942889521, 'overlap rate': 0.8166652976682311}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.3431555926799774, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01589524504961446, 'overlap rate': 0.28365697972476484}
# evaluation performance: {'loss': 2.553772634267807, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010219153063371778, 'overlap rate': 0.18746979869902133}
#
# Current epoch: 10,
# training performance: {'loss': 0.9597664073109626, 'abosulate accuracy': 0.0029000000678934155, 'consecutive overlap rate': 0.14045063136145472, 'overlap rate': 0.7051561512053013}
# evaluation performance: {'loss': 2.0206974536180495, 'abosulate accuracy': 0.000800000032177195, 'consecutive overlap rate': 0.09386694431304932, 'overlap rate': 0.4274177685379982}
#
# Current epoch: 15,
# training performance: {'loss': 0.3187896028161049, 'abosulate accuracy': 0.14430000795982778, 'consecutive overlap rate': 0.6078527707606554, 'overlap rate': 0.9186328113079071}
# evaluation performance: {'loss': 1.8453914448618889, 'abosulate accuracy': 0.06410000297473743, 'consecutive overlap rate': 0.35946967378258704, 'overlap rate': 0.6256425760686397}
#
# Current epoch: 20,
# training performance: {'loss': 0.14550700914114714, 'abosulate accuracy': 0.4982000233605504, 'consecutive overlap rate': 0.8405321970582008, 'overlap rate': 0.976661404967308}
# evaluation performance: {'loss': 1.2088287681341172, 'abosulate accuracy': 0.29855001121759417, 'consecutive overlap rate': 0.600135862827301, 'overlap rate': 0.7852210104465485}
#
# Current epoch: 25,
# training performance: {'loss': 0.05967034879140556, 'abosulate accuracy': 0.7807000368833542, 'consecutive overlap rate': 0.954269464313984, 'overlap rate': 0.994393277168274}
# evaluation performance: {'loss': 0.26974388770759106, 'abosulate accuracy': 0.7046000331640243, 'consecutive overlap rate': 0.8951673105359077, 'overlap rate': 0.959286430478096}
#
# Current epoch: 30,
# training performance: {'loss': 0.028868306521326305, 'abosulate accuracy': 0.8840000286698342, 'consecutive overlap rate': 0.9888198718428611, 'overlap rate': 0.9985436052083969}
 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0022349918537656775, 'abosulate accuracy': 0.9236500069499016, 'consecutive overlap rate': 0.9997987642884254, 'overlap rate': 0.9998596280813217}
#
# Current epoch: 90,
# training performance: {'loss': 0.0008045832757488825, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0020645637094276028, 'abosulate accuracy': 0.9237000063061714, 'consecutive overlap rate': 0.9998228386044502, 'overlap rate': 0.999861478805542}
#
# Current epoch: 95,
# training performance: {'loss': 0.0006735637165547814, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.00144586464157328, 'abosulate accuracy': 0.923850005865097, 'consecutive overlap rate': 0.9998630329966545, 'overlap rate': 0.99991524964571}
#
# Current epoch: 100,
# training performance: {'loss': 0.0005670163227478042, 'abosulate accuracy': 0.925, 'consecutive overlap rate': 0.9999999985098839, 'overlap rate': 0.9999999955296517}
# evaluation performance: {'loss': 0.0013384042540565133, 'abosulate accuracy': 0.923850005865097, 'consecutive overlap rate': 0.9998630329966545, 'overlap rate': 0.99991524964571}
#
# Experiments_Logs/Experiment#3/GRU/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/GRU/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.012492928223218768, 'abosulate accuracy': 0.9980000179260969, 'consecutive overlap rate': 0.9995945878326893, 'overlap rate': 0.9998787719756365}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.0024804094682622235, 'abosulate accuracy': 0.9234000250697136, 'consecutive overlap rate': 0.999715442955494, 'overlap rate': 0.9998167127370834}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.45933769941329955, 'abosulate accuracy': 0.5185719789997224, 'consecutive overlap rate': 0.8509635233109997, 'overlap rate': 0.9313646504955907}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.6014865930498529, 'abosulate accuracy': 0.490868434187417, 'consecutive overlap rate': 0.8695134147511501, 'overlap rate': 0.9004621062623827}
# Experiments_Logs/Experiment#3/GRU/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#3 with GRU seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
