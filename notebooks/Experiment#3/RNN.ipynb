# %% [markdown]
# # Accessing the project directory on my Google Drive

# %%
import os
from google.colab import drive

drive.mount('/drive', force_remount=False)
project_dir = "/drive/My Drive/RNNSeq2Seq/"

# change working directory to project_dir
os.chdir(project_dir)
# Out:
# Mounted at /drive

# %% [markdown]
# # Dependencies

# %%
from scripts.model import *
from scripts.dataloader import create_dataloader
from scripts.utils import *
from scripts.pytorch_utils import *

# %% [markdown]
# # Initialize model

# %%
in_vocab = ascii_lowercase
out_vocab = ascii_lowercase
in_vocab_size = len(in_vocab) + 2
out_vocab_size = len(out_vocab) + 2

hidden_size = 256
embd_dim = 128
num_layers = 1
rnn_type = "RNN"
dropout_rate = 0.0
bidirectional = False
use_attention = True
reduction_method = torch.sum

learning_rate = 1e-4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training, testing, and logging

# %%
prefix = "data/"
experiment_num = 3
shuffle_batch = False

# must be the num of seq per seq length if shuffle_batch is False
# this "tr_batch_size" will be used for dev, and shuffled test sets
tr_batch_size = 250
dev_batch_size = 500 if not shuffle_batch else tr_batch_size

# num of seq per length for non-shuffled train sets
te_batch_size = 1000

log_folder, tr_log, te1_log, te2_log, mo_log = create_log_folders(experiment_num, rnn_type)
# Out:
# ./Experiments_Logs/Experiment#3/RNN created!
# ./Experiments_Logs/Experiment#3/RNN/Training_Logs created!
# ./Experiments_Logs/Experiment#3/RNN/Testing_Logs created!
# ./Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs created!
# ./Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs created!
# ./Experiments_Logs/Experiment#3/RNN/Models_Logs created!

# %%
# setups for training and evaluting

print_freq = 5
acc_threshold = 0.5 # for saving the best trained models 
max_epoch_num = 150 # max num of epoches 
train_acc_exit=0.9999 # train acc exit threshold (eval_acc_exit must also be met)
eval_acc_exit=0.995 # dev acc exit threshold (train_acc_exit must also be met)
teacher_forcing_ratio = 1.0 # probability of using real symbol from target sequence for training

print(f"Start experiment#{experiment_num} with {rnn_type} seq2seq...")

for lang in ["RevStr", "RedStr"]:
    
    for n in ["1", "2", "3"]:
        print(f"\n\n{'=' * 20} training on {lang}_{n} starts {'=' * 20}\n")
        folder = join(prefix, lang, n)
        
        # =========================== Initialize model ===========================
        encoder = Encoder(in_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type, 
                          dropout_rate, bidirectional, 
                          reduction_method)
        attention = Attention(hidden_size)
        decoder = Decoder(out_vocab_size, hidden_size, 
                          embd_dim, num_layers, rnn_type,
                          attention, use_attention, 
                          dropout_rate)

        model = Seq2Seq(encoder, decoder, device).to(device)
        model.apply(init_weights)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # =============================== Training ===============================
        train = read_data(join(folder, "train.txt"))
        dev = read_data(join(folder, "dev.txt"))
        saved_model_fp = join(mo_log, f"{lang}_{n}.pt")
        
        train_dl = create_dataloader(train, batch_size=tr_batch_size, shuffle=shuffle_batch)
        dev_dl = create_dataloader(dev, batch_size=dev_batch_size, shuffle=shuffle_batch)
        
        log = train_and_evaluate(model, train_dl, dev_dl, criterion, optimizer, 
                                 saved_model_fp, acc_threshold, print_freq, max_epoch_num, 
                                 train_acc_exit, eval_acc_exit, teacher_forcing_ratio)
        save_dict_as_json(log, join(tr_log, f"{lang}_{n}.json"))

        if shuffle_batch:
            train_dl = create_dataloader(train, batch_size=250, shuffle=False)
            dev_dl = create_dataloader(dev, batch_size=500, shuffle=False)

        _, train_perfms = evaluate(model, train_dl, criterion, True)
        save_dict_as_json(train_perfms, join(tr_log, f"{lang}_{n}_train_performance_per_seq_length.json"))
        _, dev_perfms = evaluate(model, dev_dl, criterion, True)
        save_dict_as_json(dev_perfms, join(tr_log, f"{lang}_{n}_dev_performance_per_seq_length.json"))
        
        
        # =============================== Testing ===============================
        
        # ++++++++++++++++++++++ Test set 1 (in distribution) ++++++++++++++++++++++
        test = read_data(join(folder, "test.txt"))
        test_dl_shuffled = create_dataloader(test, batch_size=tr_batch_size, shuffle=True)
        test_aggr_perf_shuffled = evaluate(model, test_dl_shuffled, criterion)
        print("\ntest's aggregate performace with shuffled batches:", test_aggr_perf_shuffled)
        save_dict_as_json(test_aggr_perf_shuffled, join(te1_log, f"{lang}_{n}_shuffled.json"))
        
        test_dl = create_dataloader(test, batch_size=te_batch_size, shuffle=False)
        test_aggr, test_perfms = evaluate(model, test_dl, criterion, True)
        print("\ntest's aggregate performace with non-shuffled batches:", test_aggr)
        save_dict_as_json(test_perfms, join(te1_log, f"{lang}_{n}_non_shuffled.json"))

        # ++++++++++++++++++++ Test set 2 (out of distribution) ++++++++++++++++++++
        test2 = read_data(join(folder, "test2.txt"))
        test2_dl_shuffled = create_dataloader(test2, batch_size=tr_batch_size, shuffle=True)
        test2_aggr_perf_shuffled = evaluate(model, test2_dl_shuffled, criterion)
        print("\ntest2's aggregate performace with shuffled batches:", test2_aggr_perf_shuffled)
        save_dict_as_json(test2_aggr_perf_shuffled, join(te2_log, f"{lang}_{n}_shuffled.json"))
        
        # This is ONLY SPECIFIC to my experimental setups where len(seq_len1/2) < te_batch_size
        seq_len1, seq_len2, seq_len3plus = test2[:26], test2[26:702], test2[702:]
        seq_len1_dl = create_dataloader(seq_len1, batch_size=te_batch_size)
        seq_len1_aggr_perf = evaluate(model, seq_len1_dl, criterion)
        
        seq_len2_dl = create_dataloader(seq_len2, batch_size=te_batch_size)
        seq_len2_aggr_perf = evaluate(model, seq_len2_dl, criterion)
        
        test2_dl = create_dataloader(seq_len3plus, batch_size=te_batch_size, shuffle=False)
        test_aggr2, test_perfms2 = evaluate(model, test2_dl, criterion, True)
        print("\ntest2's aggregate performace with non-shuffled batches:", test_aggr2)
    
        # append the testing performance of len-1 and len-2 to test_perfms2
        test_perfms2.update({"Len-1": seq_len1_aggr_perf, "Len-2": seq_len2_aggr_perf})    
        save_dict_as_json(test_perfms2, join(te2_log, f"{lang}_{n}_non_shuffled.json"))
        
        # =============================== End of loop ===============================
        print(f"\n{'=' * 20} testing on {lang}_{n} finishes {'=' * 20}")
    
print(f"\n\n...experiment#{experiment_num} with {rnn_type} seq2seq ends.")
# Out:
# Start experiment#3 with RNN seq2seq...
#
#
# ==================== training on RevStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.0204547464847566, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005727619928075, 'overlap rate': 0.1282324256375432}
# evaluation performance: {'loss': 3.02536261677742, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.006521433091256768, 'overlap rate': 0.13430178705602885}
#
# Current epoch: 10,
# training performance: {'loss': 2.6604393899440764, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011877372796880082, 'overlap rate': 0.22461291439831257}
# evaluation performance: {'loss': 2.81496325135231, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0121768421609886, 'overlap rate': 0.16923848520964385}
#
# Current epoch: 15,
# training performance: {'loss': 2.423384267091751, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018017849838361143, 'overlap rate': 0.2891304738819599}
# evaluation performance: {'loss': 2.7676464438438417, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.019252573046833275, 'overlap rate': 0.17619915194809438}
#
# Current epoch: 20,
# training performance: {'loss': 2.180790939927101, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02618697101715952, 'overlap rate': 0.3565871700644493}
# evaluation performance: {'loss': 2.6363456189632415, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028007284342311322, 'overlap rate': 0.2110099844634533}
#
# Current epoch: 25,
# training performance: {'loss': 2.121958556771278, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03781793850939721, 'overlap rate': 0.3884858686476946}
# evaluation performance: {'loss': 2.626889979839325, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.03372150093782693, 'overlap rate': 0.217606633156538}
#
# Current epoch: 30,
# training performance: {'loss': 1.854868695139885, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.04501084715593606, 'overlap rate': 0.45621112138032915}
# evaluation performance: {'loss': 2.5490210950374603, 'abosulate accuracy': 0.0001500000013038516, 'consecutive overlap rate': 0.04439509576186538, 'overlap rate': 0.24326821714639663}
#
# Current epoch: 35,
# training performance: {'loss': 1.966253823041916, 'abosulate accuracy': 0.00040000000735744833, 'consecutive overlap rate': 0.05281308991834521, 'overlap rate': 0.43354065120220187}
# evaluation performance: {'loss': 2.623555454611778, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05366562926210463, 'overlap rate': 0.22386765629053115}
#
# Current epoch: 40,
# training performance: {'loss': 2.0412121772766114, 'abosulate accuracy': 0.000700000044889748, 'consecutive overlap rate': 0.06523210438899696, 'overlap rate': 0.4478228434920311}
# evaluation performance: {'loss': 2.5472038805484774, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.05923226121813059, 'overlap rate': 0.2656614247709513}
#
# Current epoch: 45,
# training performance: {'loss': 1.868343710899353, 'abosulate accuracy': 0.0003000000026077032, 'consecutive overlap rate': 0.06854177555069327, 'overlap rate': 0.4575287543237209}
# evaluation performance: {'loss': 2.490160757303238, 'abosulate accuracy': 0.00020000000367872416, 'consecutive overlap rate': 0.0713215219322592, 'overlap rate': 0.26021153256297114}
#
# Current epoch: 50,
# training performance: {'loss': 1.6329144477844237, 'abosulate accuracy': 0.001000000024214387, 'consecutive overlap rate': 0.08436512225307524, 'overlap rate': 0.5331162549555302}
# evaluation performance: {'loss': 2.45932123363018, 'abosulate accuracy': 0.0015500000619795174, 'consecutive overlap rate': 0.0829368899576366, 'overlap rate': 0.2796294096857309}
#
# Current epoch: 55,
# training performance: {'loss': 1.298423570394516, 'abosulate accuracy': 0.004300000250805169, 'consecutive overlap rate': 0.09734425023198127, 'overlap rate': 0.6315033130347729}
# evaluation performance: {'loss': 2.36565023958683, 'abosulate accuracy': 0.003300000092713162, 'consecutive overlap rate': 0.09366686223074794, 'overlap rate': 0.30688974633812904}
#
# Current epoch: 60,
# training performance: {'loss': 1.7756076633930207, 'abosulate accuracy': 0.0011000000638887286, 'consecutive overlap rate': 0.09120468967594206, 'overlap rate': 0.4845906406641006}
# evaluation performance: {'loss': 2.4000275522470473, 'abosulate accuracy': 0.0016000000468920916, 'consecutive overlap rate': 0.09585046386346222, 'overlap rate': 0.30615187585353854}
#
# Current epoch: 65,
# training performance: {'loss': 1.786467382311821, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.09072628151625395, 'overlap rate': 0.4852575987577438}
# evaluation performance: {'loss': 2.409106972813606, 'abosulate accuracy': 0.0027000000583939253, 'consecutive overlap rate': 0.10882098423317074, 'overlap rate': 0.30691599287092686}
#
# Current epoch: 70,
# training performance: {'loss': 1.8948129683732986, 'abosulate accuracy': 0.0008000000147148967, 'consecutive overlap rate': 0.10227972185239195, 'overlap rate': 0.4583780139684677}
# evaluation performance: {'loss': 2.490466809272766, 'abosulate accuracy': 0.003400000190595165, 'consecutive overlap rate': 0.10380949741229414, 'overlap rate': 0.29482371248304845}
#
# Current epoch: 75,
# training performance: {'loss': 1.2266463935375214, 'abosulate accuracy': 0.018200000922661275, 'consecutive overlap rate': 0.1514187578111887, 'overlap rate': 0.6574174731969833}
# evaluation performance: {'loss': 2.348030614852905, 'abosulate accuracy': 0.011300000332994387, 'consecutive overlap rate': 0.14096744628623128, 'overlap rate': 0.34511380568146705}
#
# Current epoch: 80,
# training performance: {'loss': 2.338277077674866, 'abosulate accuracy': 0.02490000062389299, 'consecutive overlap rate': 0.15287219444289804, 'overlap rate': 0.4885362308472395}
# evaluation performance: {'loss': 3.5140921473503113, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.07561716330237686, 'overlap rate': 0.1958989467471838}
#
# Current epoch: 85,
# training performance: {'loss': 1.2566956222057342, 'abosulate accuracy': 0.008800000383052975, 'consecutive overlap rate': 0.134856241568923, 'overlap rate': 0.6361065156757831}
# evaluation performance: {'loss': 2.2882026463747023, 'abosulate accuracy': 0.009450000379001722, 'consecutive overlap rate': 0.13510831678286195, 'overlap rate': 0.34376293532550334}
#
# Current epoch: 90,
# training performance: {'loss': 1.314327897131443, 'abosulate accuracy': 0.0090000003692694, 'consecutive overlap rate': 0.15908540952950717, 'overlap rate': 0.6397592008113862}
# evaluation performance: {'loss': 2.2217136919498444, 'abosulate accuracy': 0.014750000659842045, 'consecutive overlap rate': 0.1518426716327667, 'overlap rate': 0.37146363146603106}
#
# Current epoch: 95,
# training performance: {'loss': 1.0336501389741897, 'abosulate accuracy': 0.02470000066095963, 'consecutive overlap rate': 0.1811036380007863, 'overlap rate': 0.7175545275211335}
# evaluation performance: {'loss': 1.9267938762903214, 'abosulate accuracy': 0.027000001887790857, 'consecutive overlap rate': 0.1746752517297864, 'overlap rate': 0.4486211910843849}
#
# Current epoch: 100,
# training performance: {'loss': 0.6034799508750439, 'abosulate accuracy': 0.07460000393912196, 'consecutive overlap rate': 0.25514639262109995, 'overlap rate': 0.8566589161753655}
# evaluation performance: {'loss': 1.294139914214611, 'abosulate accuracy': 0.07875000395579264, 'consecutive overlap rate': 0.26260841451585293, 'overlap rate': 0.6213158711791038}
#
# Current epoch: 105,
# training performance: {'loss': 0.41648216992616655, 'abosulate accuracy': 0.16080000618239865, 'consecutive overlap rate': 0.3759782759472728, 'overlap rate': 0.9168542504310608}
# evaluation performance: {'loss': 0.8793311432003975, 'abosulate accuracy': 0.1698500073631294, 'consecutive overlap rate': 0.3876020522788167, 'overlap rate': 0.7595000736415386}
#
# Current epoch: 110,
# training performance: {'loss': 0.3509206473827362, 'abosulate accuracy': 0.23580001023365185, 'consecutive overlap rate': 0.4612097259610891, 'overlap rate': 0.9296480998396873}
# evaluation performance: {'loss': 0.7134314566850662, 'abosulate accuracy': 0.24630001120385714, 'consecutive overlap rate': 0.47349998764693735, 'overlap rate': 0.8128325790166855}
#
# Current epoch: 115,
# training performance: {'loss': 0.26512322686612605, 'abosulate accuracy': 0.3086000136099756, 'consecutive overlap rate': 0.5494685553014278, 'overlap rate': 0.9561661511659623}
# evaluation performance: {'loss': 0.5262329693883657, 'abosulate accuracy': 0.32335001360625026, 'consecutive overlap rate': 0.5635015003383159, 'overlap rate': 0.8741108253598213}
#
# Current epoch: 120,
# training performance: {'loss': 0.2046555196866393, 'abosulate accuracy': 0.40100002149119973, 'consecutive overlap rate': 0.6444411963224411, 'overlap rate': 0.9670684069395066}
# evaluation performance: {'loss': 0.5932708527892828, 'abosulate accuracy': 0.3743000201648101, 'consecutive overlap rate': 0.6093406364321708, 'overlap rate': 0.8602858453989028}
#
# Current epoch: 125,
# training performance: {'loss': 0.20257140398025514, 'abosulate accuracy': 0.41250002179294826, 'consecutive overlap rate': 0.6749967567622661, 'overlap rate': 0.9645741954445839}
# evaluation performance: {'loss': 0.920272795855999, 'abosulate accuracy': 0.3401500149280764, 'consecutive overlap rate': 0.6398293547332287, 'overlap rate': 0.7874026954174042}
#
# Current epoch: 130,
# training performance: {'loss': 0.15658612214028836, 'abosulate accuracy': 0.49610002115368845, 'consecutive overlap rate': 0.728558873385191, 'overlap rate': 0.9780226573348045}
# evaluation performance: {'loss': 0.3418515698984265, 'abosulate accuracy': 0.5140000279992819, 'consecutive overlap rate': 0.7378066278994083, 'overlap rate': 0.9318967550992966}
#
# Current epoch: 135,
# training performance: {'loss': 0.09745556712150574, 'abosulate accuracy': 0.6727000303566456, 'consecutive overlap rate': 0.8438590228557586, 'overlap rate': 0.9900691747665405}
# evaluation performance: {'loss': 0.20687825996428727, 'abosulate accuracy': 0.6695000328123569, 'consecutive overlap rate': 0.8478076316416263, 'overlap rate': 0.9650996327400208}
#
# Current epoch: 140,
# training performance: {'loss': 0.07675883425399661, 'abosulate accuracy': 0.7379000335931778, 'consecutive overlap rate': 0.8933103293180465, 'overlap rate': 0.9932429760694503}
# evaluation performance: {'loss': 0.2133603986352682, 'abosulate accuracy': 0.7001000329852104, 'consecutive overlap rate': 0.8798492610454559, 'overlap rate': 0.9623124867677688}
#
# Current epoch: 145,
# training performance: {'loss': 0.06973893297836184, 'abosulate accuracy': 0.7583000376820564, 'consecutive overlap rate': 0.9069663599133492, 'overlap rate': 0.9928680568933487}
# evaluation performance: {'loss': 0.2817684936337173, 'abosulate accuracy': 0.677700025588274, 'consecutive overlap rate': 0.8778920724987984, 'overlap rate': 0.9457479849457741}
#
# Current epoch: 150,
# training performance: {'loss': 0.06305182343348861, 'abosulate accuracy': 0.7765000335872173, 'consecutive overlap rate': 0.9250638127326966, 'overlap rate': 0.9944282561540604}
# evaluation performance: {'loss': 0.11076993411406874, 'abosulate accuracy': 0.7758500337600708, 'consecutive overlap rate': 0.9163478836417198, 'overlap rate': 0.9834716930985451}
#
# Experiments_Logs/Experiment#3/RNN/Models_Logs/RevStr_1.pt saved!
#
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_1.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_1_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_1_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 5.793848285079003, 'abosulate accuracy': 0.016500000620726495, 'consecutive overlap rate': 0.021787916924222373, 'overlap rate': 0.14535084716044366}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RevStr_1_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.10867671044543385, 'abosulate accuracy': 0.7864750415086746, 'consecutive overlap rate': 0.9169153094291687, 'overlap rate': 0.9844091325998306}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RevStr_1_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 5.826399421691894, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0011550973830444196, 'overlap rate': 0.13318848186923612}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RevStr_1_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 1.1011866793820733, 'abosulate accuracy': 0.47205265529919416, 'consecutive overlap rate': 0.5435756219452933, 'overlap rate': 0.7899764180183411}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RevStr_1_non_shuffled.json saved!
#
# ==================== testing on RevStr_1 finishes ====================
#
#
# ==================== training on RevStr_2 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 2.9665980696678163, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005544801760697738, 'overlap rate': 0.14660651795566082}
# evaluation performance: {'loss': 2.9849582612514496, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005528420791961253, 'overlap rate': 0.1434196013957262}
#
# Current epoch: 10,
# training performance: {'loss': 2.5980396807193755, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011858598951948806, 'overlap rate': 0.24496158845722676}
# evaluation performance: {'loss': 2.79834098815918, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.011653128650505096, 'overlap rate': 0.17067112848162652}
#
# Current epoch: 15,
# training performance: {'loss': 2.4012407094240187, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01938717203447595, 'overlap rate': 0.3059637740254402}
# evaluation performance: {'loss': 2.7085980474948883, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02000348762376234, 'overlap rate': 0.2054239058867097}
#
# Current epoch: 20,
# training performance: {'loss': 2.1312971472740174, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.029118369403295218, 'overlap rate': 0.37765564024448395}
# evaluation performance: {'loss': 2.659388518333435, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.028154163016006352, 'overlap rate': 0.19930670261383057}
#
# Current epoch: 25,
# training performance: {'loss': 1.9802217751741409, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.03986447358038277, 'overlap rate': 0.42462378516793253}
# evaluation performance: {'loss': 2.6294493794441225, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.0381614220328629, 'overlap rate': 0.21887044571340084}
#
# Current epoch: 30,
# training performance: {'loss': 2.170745077729225, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.04629157930612564, 'overlap rate': 0.4006444584578276}
# evaluation performance: {'loss': 2.723894494771957, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.04328981062863022, 'overlap rate': 0.22024277951568366}
#
# Current epoch: 35,
# training performance: {'loss': 1.8582158982753754, 'abosulate accuracy': 0.0007000000216066838, 'consecutive overlap rate': 0.06252954346127808, 'overlap rate': 0.48548712506890296}
# evaluation performance: {'loss': 2.456192007660866, 'abosulate accuracy': 0.0006000000284984708, 'consecutive overlap rate': 0.05967972963117063, 'overlap rate': 0.2699744198471308}
#
# Current epoch: 40,
# training performance: {'loss': 1.3716833293437958, 'abosulate accuracy': 0.0016000000992789864, 'consecutive overlap rate': 0.07420751019380986, 'overlap rate': 0.610640998184681}
# evaluation performance: {'loss': 2.20274917781353, 'abosulate accuracy': 0.0024500000523403286, 'consecutive overlap rate': 0.07538179741241038, 'overlap rate': 0.34044302329421045}
#
# Current epoch: 45,
# training performance: {'loss': 1.1314603433012962, 'abosulate accuracy': 0.004700000211596489, 'consecutive overlap rate': 0.0999992894474417, 'overlap rate': 0.6995056763291359}
# evaluation performance: {'loss': 1.8952167093753816, 'abosulate accuracy': 0.005850000173086301, 'consecutive overlap rate': 0.10116387298330665, 'overlap rate': 0.4363248094916344}
#
# Current epoch: 50,
# training performance: {'loss': 1.1707790836691856, 'abosulate accuracy': 0.011300000245682895, 'consecutive overlap rate': 0.13032026286236942, 'overlap rate': 0.6971710495650768}
# evaluation performance: {'loss': 1.4754900649189948, 'abosulate accuracy': 0.01695000059553422, 'consecutive overlap rate': 0.1292713126167655, 'overlap rate': 0.5431286975741386}
#
# Current epoch: 55,
# training performance: {'loss': 0.6188712105154991, 'abosulate accuracy': 0.06920000239042565, 'consecutive overlap rate': 0.23822014788165688, 'overlap rate': 0.8684641763567924}
# evaluation performance: {'loss': 1.1368656545877456, 'abosulate accuracy': 0.07580000346642919, 'consecutive overlap rate': 0.24629113133996725, 'overlap rate': 0.6709006145596504}
#
# Current epoch: 60,
# training performance: {'loss': 0.45138221234083176, 'abosulate accuracy': 0.1310000052442774, 'consecutive overlap rate': 0.3349189359694719, 'overlap rate': 0.91652230322361}
# evaluation performance: {'loss': 0.74919688180089, 'abosulate accuracy': 0.15405000733444468, 'consecutive overlap rate': 0.3651307515799999, 'overlap rate': 0.8040730193257332}
#
# Current epoch: 65,
# training performance: {'loss': 0.3338118590414524, 'abosulate accuracy': 0.2441000095102936, 'consecutive overlap rate': 0.4731893841177225, 'overlap rate': 0.9448575600981712}
# evaluation performance: {'loss': 0.5815752379596233, 'abosulate accuracy': 0.2579000110272318, 'consecutive overlap rate': 0.47934939749538896, 'overlap rate': 0.8585066124796867}
#
# Current epoch: 70,
# training performance: {'loss': 0.29330496229231356, 'abosulate accuracy': 0.33180001814616844, 'consecutive overlap rate': 0.5649421498179436, 'overlap rate': 0.9492493256926536}
# evaluation performance: {'loss': 0.45805830918252466, 'abosulate accuracy': 0.3368000155314803, 'consecutive overlap rate': 0.5455492362380028, 'overlap rate': 0.893798591196537}
#
# Current epoch: 75,
# training performance: {'loss': 0.2967441935092211, 'abosulate accuracy': 0.28710001446306704, 'consecutive overlap rate': 0.5226471044123173, 'overlap rate': 0.9491787031292915}
# evaluation performance: {'loss': 0.6261530116200447, 'abosulate accuracy': 0.32750001568347215, 'consecutive overlap rate': 0.5506687127053738, 'overlap rate': 0.849786601960659}
#
# Current epoch: 80,
# training performance: {'loss': 0.1595686547458172, 'abosulate accuracy': 0.5214000247418881, 'consecutive overlap rate': 0.7266730800271034, 'overlap rate': 0.9811672165989875}
# evaluation performance: {'loss': 0.22946678213775157, 'abosulate accuracy': 0.5695500262081623, 'consecutive overlap rate': 0.7506720691919326, 'overlap rate': 0.9598459362983703}
#
# Current epoch: 85,
# training performance: {'loss': 0.10103807430714369, 'abosulate accuracy': 0.6991000331938266, 'consecutive overlap rate': 0.847587376832962, 'overlap rate': 0.9916667595505715}
# evaluation performance: {'loss': 0.15427271015942096, 'abosulate accuracy': 0.701800037920475, 'consecutive overlap rate': 0.8497343063354492, 'overlap rate': 0.9769728735089303}
#
# Current epoch: 90,
# training performance: {'loss': 0.07733512707054616, 'abosulate accuracy': 0.7680000349879265, 'consecutive overlap rate': 0.8970448479056359, 'overlap rate': 0.9945449322462082}
# evaluation performance: {'loss': 0.10211025197058916, 'abosulate accuracy': 0.7739000365138053, 'consecutive overlap rate': 0.8958608120679855, 'overlap rate': 0.9867239907383919}
#
# Current epoch: 95,
# training performance: {'loss': 0.05931542553007603, 'abosulate accuracy': 0.8270000353455543, 'consecutive overlap rate': 0.9339154615998269, 'overlap rate': 0.9968799680471421}
# evaluation performance: {'loss': 0.08049589116126299, 'abosulate accuracy': 0.8178500428795814, 'consecutive overlap rate': 0.9280165821313858, 'overlap rate': 0.9906243324279785}
#
# Current epoch: 100,
# training performance: {'loss': 0.045391909684985875, 'abosulate accuracy': 0.8683000415563583, 'consecutive overlap rate': 0.9599931180477143, 'overlap rate': 0.9982316449284554}
# evaluation performance: {'loss': 0.055741298478096724, 'abosulate accuracy': 0.8601000383496284, 'consecutive overlap rate': 0.9544347718358039, 'overlap rate': 0.9950232088565827}
#
# Current epoch: 105,
# training performance: {'loss': 0.036409492837265134, 'abosulate accuracy': 0.8845000386238098, 'consecutive overlap rate': 0.9709391012787819, 'overlap rate': 0.998787921667099}
# evaluation performance: {'loss': 0.04390429425984621, 'abosulate accuracy': 0.8805500417947769, 'consecutive overlap rate': 0.9689421206712723, 'overlap rate': 0.9966506138443947}
#
# Current epoch: 110,
# training performance: {'loss': 0.029668460553511977, 'abosulate accuracy': 0.8959000393748283, 'consecutive overlap rate': 0.9793436720967292, 'overlap rate': 0.9991414561867714}
# evaluation performance: {'loss': 0.035561885125935076, 'abosulate accuracy': 0.8925500392913819, 'consecutive overlap rate': 0.977599062025547, 'overlap rate': 0.9975668653845787}
#
# Current epoch: 115,
# training performance: {'loss': 0.024458586564287545, 'abosulate accuracy': 0.9059000387787819, 'consecutive overlap rate': 0.9866767063736915, 'overlap rate': 0.9994652703404426}
# evaluation performance: {'loss': 0.029735160013660788, 'abosulate accuracy': 0.9008500367403031, 'consecutive overlap rate': 0.9832756206393242, 'overlap rate': 0.9981439411640167}
#
# Current epoch: 120,
# training performance: {'loss': 0.020364167308434843, 'abosulate accuracy': 0.9108000367879867, 'consecutive overlap rate': 0.9895531535148621, 'overlap rate': 0.9996004611253738}
# evaluation performance: {'loss': 0.024443183001130818, 'abosulate accuracy': 0.9071500390768051, 'consecutive overlap rate': 0.987724506855011, 'overlap rate': 0.9986291587352752}
#
# Current epoch: 125,
# training performance: {'loss': 0.017087338725104928, 'abosulate accuracy': 0.9150000303983689, 'consecutive overlap rate': 0.9921916484832763, 'overlap rate': 0.9997134864330292}
# evaluation performance: {'loss': 0.020317767467349767, 'abosulate accuracy': 0.9111500352621078, 'consecutive overlap rate': 0.9905501291155815, 'overlap rate': 0.9989407762885094}
#
# Current epoch: 130,
# training performance: {'loss': 0.014415792678482831, 'abosulate accuracy': 0.9184000328183174, 'consecutive overlap rate': 0.9948362529277801, 'overlap rate': 0.999804149568081}
# evaluation performance: {'loss': 0.017388887889683246, 'abosulate accuracy': 0.9144500389695167, 'consecutive overlap rate': 0.9927026689052582, 'overlap rate': 0.999157989025116}
#
# Current epoch: 135,
# training performance: {'loss': 0.012216938473284245, 'abosulate accuracy': 0.9209000244736671, 'consecutive overlap rate': 0.9966148167848587, 'overlap rate': 0.9998819902539253}
# evaluation performance: {'loss': 0.014808854600414634, 'abosulate accuracy': 0.9166000366210938, 'consecutive overlap rate': 0.9942991107702255, 'overlap rate': 0.9993228524923324}
#
# Current epoch: 140,
# training performance: {'loss': 0.010396574856713414, 'abosulate accuracy': 0.921800023317337, 'consecutive overlap rate': 0.9973767504096032, 'overlap rate': 0.9999112159013748}
# evaluation performance: {'loss': 0.012806563335470856, 'abosulate accuracy': 0.9186500325798989, 'consecutive overlap rate': 0.9956507250666619, 'overlap rate': 0.9994438573718071}
#
# Current epoch: 145,
# training performance: {'loss': 0.00888029239140451, 'abosulate accuracy': 0.9226000174880028, 'consecutive overlap rate': 0.9980434998869896, 'overlap rate': 0.9999288335442543}
# evaluation performance: {'loss': 0.010793686239048838, 'abosulate accuracy': 0.9197500288486481, 'consecutive overlap rate': 0.9963835403323174, 'overlap rate': 0.9995557770133019}
#
# Current epoch: 150,
# training performance: {'loss': 0.007610178214963526, 'abosulate accuracy': 0.9234000131487846, 'consecutive overlap rate': 0.9986383929848671, 'overlap rate': 0.999956189095974}
# evaluation performance: {'loss': 0.00923825743375346, 'abosulate accuracy': 0.9206500262022018, 'consecutive overlap rate': 0.9970365896821022, 'overlap rate': 0.9996496856212616}
#
# Experiments_Logs/Experiment#3/RNN/Models_Logs/RevStr_2.pt saved!
#
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_2.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 7.499424496293068, 'abosulate accuracy': 0.02430000100575853, 'consecutive overlap rate': 0.02574291700439062, 'overlap rate': 0.1466250130906701}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RevStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.009216713381465524, 'abosulate accuracy': 0.920950037240982, 'consecutive overlap rate': 0.9971010461449623, 'overlap rate': 0.9996758997440338}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RevStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 8.554156617195375, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0014256339475151993, 'overlap rate': 0.08086198895208298}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RevStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 3.3725155427512763, 'abosulate accuracy': 0.52728950155372, 'consecutive overlap rate': 0.5766456061974168, 'overlap rate': 0.6281782163209036}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RevStr_2_non_shuffled.json saved!
#
# ==================== testing on RevStr_2 finishes ====================
#
#
# ==================== training on RevStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.0098855078220366, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005308573698857799, 'overlap rate': 0.12806733567267656}
# evaluation performance: {'loss': 3.0118323266506195, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0054100459034089, 'overlap rate': 0.12211861982941627}
#
# Current epoch: 10,
# training performance: {'loss': 2.709251481294632, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01049222387955524, 'overlap rate': 0.20629358030855655}
# evaluation performance: {'loss': 2.852162492275238, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010151909635169432, 'overlap rate': 0.146627352014184}
#
# Current epoch: 15,
# training performance: {'loss': 2.4967480838298797, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01535383944865316, 'overlap rate': 0.2658383805304766}
# evaluation performance: {'loss': 2.779321026802063, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01574898000108078, 'overlap rate': 0.17116688527166843}
#
# Current epoch: 20,
# training performance: {'loss': 2.2423959374427795, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.02156393767800182, 'overlap rate': 0.33964952938258647}
# evaluation performance: {'loss': 2.765327715873718, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02161863970104605, 'overlap rate': 0.17778374142944814}
#
# Current epoch: 25,
# training performance: {'loss': 2.10219888985157, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.029103228403255344, 'overlap rate': 0.38188943415880205}
# evaluation performance: {'loss': 2.744736462831497, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02693488048389554, 'overlap rate': 0.18484862931072712}
#
# Current epoch: 30,
# training performance: {'loss': 2.019386053085327, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03635859186761081, 'overlap rate': 0.4112564492970705}
# evaluation performance: {'loss': 2.775750035047531, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.034499112120829525, 'overlap rate': 0.181283775344491}
#
# Current epoch: 35,
# training performance: {'loss': 1.8766694337129592, 'abosulate accuracy': 0.0003000000026077032, 'consecutive overlap rate': 0.04300112989731133, 'overlap rate': 0.4499325841665268}
# evaluation performance: {'loss': 2.649338257312775, 'abosulate accuracy': 0.0003000000084284693, 'consecutive overlap rate': 0.04721471215598285, 'overlap rate': 0.2259755402803421}
#
# Current epoch: 40,
# training performance: {'loss': 1.7007539510726928, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.052137182187289, 'overlap rate': 0.49227405413985253}
# evaluation performance: {'loss': 2.6564928352832795, 'abosulate accuracy': 0.0002500000118743628, 'consecutive overlap rate': 0.05298773334361613, 'overlap rate': 0.23671034909784794}
#
# Current epoch: 45,
# training performance: {'loss': 1.737508362531662, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.055657542403787376, 'overlap rate': 0.48739622384309766}
# evaluation performance: {'loss': 2.608985099196434, 'abosulate accuracy': 0.00040000001317821445, 'consecutive overlap rate': 0.058299339609220624, 'overlap rate': 0.25287795476615427}
#
# Current epoch: 50,
# training performance: {'loss': 1.700532963871956, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.05841876952908933, 'overlap rate': 0.49989308193326}
# evaluation performance: {'loss': 2.4657487899065016, 'abosulate accuracy': 0.0009000000369269401, 'consecutive overlap rate': 0.06327984328381717, 'overlap rate': 0.271167828515172}
#
# Current epoch: 55,
# training performance: {'loss': 1.7801989659667015, 'abosulate accuracy': 0.0030000001308508216, 'consecutive overlap rate': 0.08157833646982908, 'overlap rate': 0.5163300763815641}
# evaluation performance: {'loss': 2.7102649569511414, 'abosulate accuracy': 0.00035000001662410796, 'consecutive overlap rate': 0.07115108883008361, 'overlap rate': 0.2606148425489664}
#
# Current epoch: 60,
# training performance: {'loss': 1.8030058532953261, 'abosulate accuracy': 0.0012000000453554094, 'consecutive overlap rate': 0.0825443783774972, 'overlap rate': 0.5046882260590791}
# evaluation performance: {'loss': 2.5111088663339616, 'abosulate accuracy': 0.001400000078137964, 'consecutive overlap rate': 0.07873527435585856, 'overlap rate': 0.2777759213000536}
#
# Current epoch: 65,
# training performance: {'loss': 1.3799726217985153, 'abosulate accuracy': 0.0005000000237487257, 'consecutive overlap rate': 0.08700269060209394, 'overlap rate': 0.601530747115612}
# evaluation performance: {'loss': 2.4508946567773817, 'abosulate accuracy': 0.003950000129407272, 'consecutive overlap rate': 0.0961858881637454, 'overlap rate': 0.30250007621943953}
#
# Current epoch: 70,
# training performance: {'loss': 1.2126900151371955, 'abosulate accuracy': 0.005000000155996531, 'consecutive overlap rate': 0.11381642329506576, 'overlap rate': 0.6564032435417175}
# evaluation performance: {'loss': 2.3017841219902038, 'abosulate accuracy': 0.007100000412901863, 'consecutive overlap rate': 0.11132502877153456, 'overlap rate': 0.34232933446764946}
#
# Current epoch: 75,
# training performance: {'loss': 2.1090959399938582, 'abosulate accuracy': 0.019800001045223326, 'consecutive overlap rate': 0.13744984432123603, 'overlap rate': 0.5215990990400314}
# evaluation performance: {'loss': 2.767917829751968, 'abosulate accuracy': 0.0008000000088941306, 'consecutive overlap rate': 0.09019698016345501, 'overlap rate': 0.2880011208355427}
#
# Current epoch: 80,
# training performance: {'loss': 0.9687648713588715, 'abosulate accuracy': 0.012700000649783761, 'consecutive overlap rate': 0.1397243901155889, 'overlap rate': 0.7386523500084877}
# evaluation performance: {'loss': 2.1081907361745835, 'abosulate accuracy': 0.017750000779051332, 'consecutive overlap rate': 0.156293052341789, 'overlap rate': 0.4128687661141157}
#
# Current epoch: 85,
# training performance: {'loss': 0.6909401953220368, 'abosulate accuracy': 0.04060000175377354, 'consecutive overlap rate': 0.20128851644694806, 'overlap rate': 0.8340648174285888}
# evaluation performance: {'loss': 1.2429617092013359, 'abosulate accuracy': 0.05855000258306973, 'consecutive overlap rate': 0.22489414075389505, 'overlap rate': 0.6386114351451397}
#
# Current epoch: 90,
# training performance: {'loss': 0.5017809219658375, 'abosulate accuracy': 0.13190000664908438, 'consecutive overlap rate': 0.328385678678751, 'overlap rate': 0.8964914202690124}
# evaluation performance: {'loss': 1.044418965280056, 'abosulate accuracy': 0.12060000657220371, 'consecutive overlap rate': 0.3183859147131443, 'overlap rate': 0.7104629561305046}
#
# Current epoch: 95,
# training performance: {'loss': 0.36465095803141595, 'abosulate accuracy': 0.19200000864220784, 'consecutive overlap rate': 0.41170076839625835, 'overlap rate': 0.9344727590680122}
# evaluation performance: {'loss': 0.6431955225765705, 'abosulate accuracy': 0.22125000874511896, 'consecutive overlap rate': 0.4422960810363293, 'overlap rate': 0.8407370910048485}
#
# Current epoch: 100,
# training performance: {'loss': 0.3234801284968853, 'abosulate accuracy': 0.2630000098492019, 'consecutive overlap rate': 0.5041994709521532, 'overlap rate': 0.9419543907046318}
# evaluation performance: {'loss': 1.022343135625124, 'abosulate accuracy': 0.238650010607671, 'consecutive overlap rate': 0.46206468194723127, 'overlap rate': 0.7488613896071911}
#
# Current epoch: 105,
# training performance: {'loss': 0.30822779759764674, 'abosulate accuracy': 0.30490001244470477, 'consecutive overlap rate': 0.5359633389860392, 'overlap rate': 0.9397042557597161}
# evaluation performance: {'loss': 0.8640595145523549, 'abosulate accuracy': 0.26385001491289584, 'consecutive overlap rate': 0.4958878308534622, 'overlap rate': 0.7917794659733772}
#
# Current epoch: 110,
# training performance: {'loss': 0.2919323105365038, 'abosulate accuracy': 0.26820001122541726, 'consecutive overlap rate': 0.5154098529368639, 'overlap rate': 0.9467540934681893}
# evaluation performance: {'loss': 0.5374292723834515, 'abosulate accuracy': 0.3562500158324838, 'consecutive overlap rate': 0.5705250449478626, 'overlap rate': 0.8800083413720131}
#
# Current epoch: 115,
# training performance: {'loss': 0.1753420202061534, 'abosulate accuracy': 0.49460002295672895, 'consecutive overlap rate': 0.709856154024601, 'overlap rate': 0.9757777780294419}
# evaluation performance: {'loss': 0.42026699557900427, 'abosulate accuracy': 0.4916000245139003, 'consecutive overlap rate': 0.699202724546194, 'overlap rate': 0.9111605539917946}
#
# Current epoch: 120,
# training performance: {'loss': 0.17880797181278468, 'abosulate accuracy': 0.513900024164468, 'consecutive overlap rate': 0.7360101655125618, 'overlap rate': 0.9687317326664925}
# evaluation performance: {'loss': 0.2984216619282961, 'abosulate accuracy': 0.5447000253945589, 'consecutive overlap rate': 0.7399706661701202, 'overlap rate': 0.9425470381975174}
#
# Current epoch: 125,
# training performance: {'loss': 0.15575991049408913, 'abosulate accuracy': 0.5320000261068344, 'consecutive overlap rate': 0.7430385664105416, 'overlap rate': 0.9778581261634827}
# evaluation performance: {'loss': 0.9142184602096677, 'abosulate accuracy': 0.3575500167440623, 'consecutive overlap rate': 0.6251684695482254, 'overlap rate': 0.8180426754057407}
#
# Current epoch: 130,
# training performance: {'loss': 0.08000754863023758, 'abosulate accuracy': 0.7614000372588634, 'consecutive overlap rate': 0.8944625690579414, 'overlap rate': 0.9946446597576142}
# evaluation performance: {'loss': 0.11631782241165638, 'abosulate accuracy': 0.7673000380396843, 'consecutive overlap rate': 0.8953353390097618, 'overlap rate': 0.9862017408013344}
#
# Current epoch: 135,
# training performance: {'loss': 0.06125084655359388, 'abosulate accuracy': 0.8180000379681587, 'consecutive overlap rate': 0.9332902237772942, 'overlap rate': 0.9967862457036972}
# evaluation performance: {'loss': 0.098011255543679, 'abosulate accuracy': 0.7876000344753266, 'consecutive overlap rate': 0.9170561045408249, 'overlap rate': 0.9879916667938232}
#
# Current epoch: 140,
# training performance: {'loss': 0.05420303028076887, 'abosulate accuracy': 0.8232000410556793, 'consecutive overlap rate': 0.9385727211833, 'overlap rate': 0.9968190521001816}
# evaluation performance: {'loss': 0.08570721633732319, 'abosulate accuracy': 0.8338500395417213, 'consecutive overlap rate': 0.9396846905350685, 'overlap rate': 0.9908550426363945}
#
# Current epoch: 145,
# training performance: {'loss': 0.04509507846087217, 'abosulate accuracy': 0.8570000365376472, 'consecutive overlap rate': 0.9604922235012054, 'overlap rate': 0.9979061216115952}
# evaluation performance: {'loss': 0.13874029088765383, 'abosulate accuracy': 0.8213000386953354, 'consecutive overlap rate': 0.9401612892746926, 'overlap rate': 0.9797420874238014}
#
# Current epoch: 150,
# training performance: {'loss': 0.040504293702542785, 'abosulate accuracy': 0.8539000377058983, 'consecutive overlap rate': 0.9627351313829422, 'overlap rate': 0.9978090107440949}
# evaluation performance: {'loss': 0.09726682300679386, 'abosulate accuracy': 0.8399500399827957, 'consecutive overlap rate': 0.9422880500555039, 'overlap rate': 0.9867967143654823}
#
# Experiments_Logs/Experiment#3/RNN/Models_Logs/RevStr_3.pt saved!
#
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_3.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RevStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 7.281590640544891, 'abosulate accuracy': 0.020050000803894363, 'consecutive overlap rate': 0.023886666991165838, 'overlap rate': 0.110480843950063}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RevStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.093422563187778, 'abosulate accuracy': 0.8439250409603118, 'consecutive overlap rate': 0.9459102302789688, 'overlap rate': 0.9875662073493003}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RevStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 7.5089824645749985, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.001945898205702824, 'overlap rate': 0.07826906856029264}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RevStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 2.8671217402933458, 'abosulate accuracy': 0.45881580979269193, 'consecutive overlap rate': 0.5128924622641582, 'overlap rate': 0.605876628897692}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RevStr_3_non_shuffled.json saved!
#
# ==================== testing on RevStr_3 finishes ====================
#
#
# ==================== training on RedStr_1 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.1165724635124206, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029194533082772976, 'overlap rate': 0.09114389102905988}
# evaluation performance: {'loss': 3.158643090724945, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0028140561087639073, 'overlap rate': 0.09539886526763439}
#
# Current epoch: 10,
# training performance: {'loss': 2.7514159858226774, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005175405539921485, 'overlap rate': 0.1772318683564663}
# evaluation performance: {'loss': 2.876386135816574, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.00413753489847295, 'overlap rate': 0.12295741271227598}
#
# Current epoch: 15,
# training performance: {'loss': 2.3610803306102754, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010524772491771727, 'overlap rate': 0.27715649008750914}
# evaluation performance: {'loss': 2.66545649766922, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010626919870264828, 'overlap rate': 0.1889256376773119}
#
# Current epoch: 20,
# training performance: {'loss': 2.603220683336258, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013148528477177023, 'overlap rate': 0.23370722606778144}
# evaluation performance: {'loss': 2.916062515974045, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01111921714618802, 'overlap rate': 0.15207750126719474}
#
# Current epoch: 25,
# training performance: {'loss': 1.9477288454771042, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.01989135283511132, 'overlap rate': 0.3965414859354496}
# evaluation performance: {'loss': 2.4007886588573455, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018887282139621674, 'overlap rate': 0.22839414849877357}
#
# Current epoch: 30,
# training performance: {'loss': 1.5541102647781373, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.030594477127306164, 'overlap rate': 0.5297690346837044}
# evaluation performance: {'loss': 3.0752104341983797, 'abosulate accuracy': 5.0000002374872565e-05, 'consecutive overlap rate': 0.03026911891065538, 'overlap rate': 0.15827744770795107}
#
# Current epoch: 35,
# training performance: {'loss': 1.3538618862628937, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.03714791121892631, 'overlap rate': 0.5930264487862587}
# evaluation performance: {'loss': 2.1659021407365797, 'abosulate accuracy': 0.0002500000118743628, 'consecutive overlap rate': 0.04076295709237456, 'overlap rate': 0.3155222963541746}
#
# Current epoch: 40,
# training performance: {'loss': 1.4548052251338959, 'abosulate accuracy': 0.0023000001325272023, 'consecutive overlap rate': 0.0584152577444911, 'overlap rate': 0.5847786143422127}
# evaluation performance: {'loss': 2.0958029955625532, 'abosulate accuracy': 0.002450000075623393, 'consecutive overlap rate': 0.06616215370595455, 'overlap rate': 0.36136408112943175}
#
# Current epoch: 45,
# training performance: {'loss': 0.9242040053009987, 'abosulate accuracy': 0.004700000211596489, 'consecutive overlap rate': 0.08470552293583751, 'overlap rate': 0.7426321804523468}
# evaluation performance: {'loss': 1.9097784876823425, 'abosulate accuracy': 0.0040000001841690395, 'consecutive overlap rate': 0.07442173110321164, 'overlap rate': 0.42897669672966005}
#
# Current epoch: 50,
# training performance: {'loss': 1.2227649718523026, 'abosulate accuracy': 0.017000001156702638, 'consecutive overlap rate': 0.12575797494500876, 'overlap rate': 0.688558854907751}
# evaluation performance: {'loss': 2.4107263892889024, 'abosulate accuracy': 0.0045000001846347, 'consecutive overlap rate': 0.09165505766868591, 'overlap rate': 0.3322616066783667}
#
# Current epoch: 55,
# training performance: {'loss': 0.7198509991168975, 'abosulate accuracy': 0.03300000173039734, 'consecutive overlap rate': 0.16435127276927233, 'overlap rate': 0.8127212390303612}
# evaluation performance: {'loss': 1.6552198648452758, 'abosulate accuracy': 0.04610000260872767, 'consecutive overlap rate': 0.1823822705075145, 'overlap rate': 0.5648231148719788}
#
# Current epoch: 60,
# training performance: {'loss': 0.47798490449786185, 'abosulate accuracy': 0.08640000392915681, 'consecutive overlap rate': 0.26766381449997423, 'overlap rate': 0.8977103009819984}
# evaluation performance: {'loss': 1.156896561384201, 'abosulate accuracy': 0.09445000439882278, 'consecutive overlap rate': 0.25596710909157994, 'overlap rate': 0.7130983307957649}
#
# Current epoch: 65,
# training performance: {'loss': 0.4762370139360428, 'abosulate accuracy': 0.12790000492241232, 'consecutive overlap rate': 0.3180305030196905, 'overlap rate': 0.888852821290493}
# evaluation performance: {'loss': 0.9671923369169235, 'abosulate accuracy': 0.15090000602649525, 'consecutive overlap rate': 0.36438116878271104, 'overlap rate': 0.7667808040976525}
#
# Current epoch: 70,
# training performance: {'loss': 0.3246140114963055, 'abosulate accuracy': 0.22640001020627096, 'consecutive overlap rate': 0.47560813203454017, 'overlap rate': 0.9406423136591912}
# evaluation performance: {'loss': 0.6758887723088265, 'abosulate accuracy': 0.2642000144987833, 'consecutive overlap rate': 0.4836093232035637, 'overlap rate': 0.8583666458725929}
#
# Current epoch: 75,
# training performance: {'loss': 0.24461471736431123, 'abosulate accuracy': 0.3247000164119527, 'consecutive overlap rate': 0.5923622637987137, 'overlap rate': 0.9626440078020095}
# evaluation performance: {'loss': 0.5313211970031262, 'abosulate accuracy': 0.35405001395847646, 'consecutive overlap rate': 0.5833726540207863, 'overlap rate': 0.8987276390194893}
#
# Current epoch: 80,
# training performance: {'loss': 0.1855872470885515, 'abosulate accuracy': 0.4620000211521983, 'consecutive overlap rate': 0.7176390945911407, 'overlap rate': 0.9766831204295159}
# evaluation performance: {'loss': 0.3961644362658262, 'abosulate accuracy': 0.45005002049729226, 'consecutive overlap rate': 0.6907735809683799, 'overlap rate': 0.9306538283824921}
#
# Current epoch: 85,
# training performance: {'loss': 0.14565037861466407, 'abosulate accuracy': 0.5752000287175179, 'consecutive overlap rate': 0.8056995928287506, 'overlap rate': 0.984898129105568}
# evaluation performance: {'loss': 0.3185565032064915, 'abosulate accuracy': 0.5260000251233578, 'consecutive overlap rate': 0.7633215025067329, 'overlap rate': 0.9480837523937226}
#
# Current epoch: 90,
# training performance: {'loss': 0.11867913976311684, 'abosulate accuracy': 0.6478000305593014, 'consecutive overlap rate': 0.861375667154789, 'overlap rate': 0.9892838343977928}
# evaluation performance: {'loss': 0.23052794374525548, 'abosulate accuracy': 0.6267500288784504, 'consecutive overlap rate': 0.8410783812403679, 'overlap rate': 0.9666746750473976}
#
# Current epoch: 95,
# training performance: {'loss': 0.0938493374735117, 'abosulate accuracy': 0.7178000342100859, 'consecutive overlap rate': 0.909246888756752, 'overlap rate': 0.9927523195743561}
# evaluation performance: {'loss': 0.2021864978596568, 'abosulate accuracy': 0.6600000359117985, 'consecutive overlap rate': 0.8662419810891151, 'overlap rate': 0.9713061705231667}
#
# Current epoch: 100,
# training performance: {'loss': 0.0804544011130929, 'abosulate accuracy': 0.753500034660101, 'consecutive overlap rate': 0.9264213606715203, 'overlap rate': 0.9943457782268524}
# evaluation performance: {'loss': 0.14249282665550708, 'abosulate accuracy': 0.7508500345051289, 'consecutive overlap rate': 0.9212916254997253, 'overlap rate': 0.9825663357973099}
#
# Current epoch: 105,
# training performance: {'loss': 0.06154008824378252, 'abosulate accuracy': 0.8077000349760055, 'consecutive overlap rate': 0.9578910052776337, 'overlap rate': 0.9964622050523758}
# evaluation performance: {'loss': 0.1314834224060178, 'abosulate accuracy': 0.7478500358760357, 'consecutive overlap rate': 0.9222602427005768, 'overlap rate': 0.9830507352948189}
#
# Current epoch: 110,
# training performance: {'loss': 0.054118288587778805, 'abosulate accuracy': 0.8252000406384468, 'consecutive overlap rate': 0.9626689031720161, 'overlap rate': 0.9969500869512558}
# evaluation performance: {'loss': 0.09431713568046689, 'abosulate accuracy': 0.817100040614605, 'consecutive overlap rate': 0.9534299924969674, 'overlap rate': 0.9897234007716179}
#
# Current epoch: 115,
# training performance: {'loss': 0.04108354174531996, 'abosulate accuracy': 0.855900040268898, 'consecutive overlap rate': 0.9801820918917656, 'overlap rate': 0.9981307178735733}
# evaluation performance: {'loss': 0.08315080553293228, 'abosulate accuracy': 0.8277500405907631, 'consecutive overlap rate': 0.9560127079486846, 'overlap rate': 0.9908160328865051}
#
# Current epoch: 120,
# training performance: {'loss': 0.03556235288269818, 'abosulate accuracy': 0.8706000342965126, 'consecutive overlap rate': 0.9818059712648392, 'overlap rate': 0.9985405549407005}
# evaluation performance: {'loss': 0.059030689671635626, 'abosulate accuracy': 0.8695500433444977, 'consecutive overlap rate': 0.9779556512832641, 'overlap rate': 0.9946393847465516}
#
# Current epoch: 125,
# ...
# evaluation performance: {'loss': 0.08415610650554299, 'abosulate accuracy': 0.8277000412344933, 'consecutive overlap rate': 0.9589682549238205, 'overlap rate': 0.991221833229065}
#
# Current epoch: 140,
# training performance: {'loss': 0.040419586934149265, 'abosulate accuracy': 0.8605000361800194, 'consecutive overlap rate': 0.9770037069916725, 'overlap rate': 0.9982154667377472}
# evaluation performance: {'loss': 0.07414744319394231, 'abosulate accuracy': 0.8407500386238098, 'consecutive overlap rate': 0.9655730739235878, 'overlap rate': 0.9925484180450439}
#
# Current epoch: 145,
# training performance: {'loss': 0.03551401286385954, 'abosulate accuracy': 0.8704000353813172, 'consecutive overlap rate': 0.9817976579070091, 'overlap rate': 0.9985323339700699}
# evaluation performance: {'loss': 0.0665018237195909, 'abosulate accuracy': 0.8520500421524048, 'consecutive overlap rate': 0.9716342106461525, 'overlap rate': 0.9934670552611351}
#
# Current epoch: 150,
# training performance: {'loss': 0.031209794152528048, 'abosulate accuracy': 0.8784000337123871, 'consecutive overlap rate': 0.9857052296400071, 'overlap rate': 0.9987827152013778}
# evaluation performance: {'loss': 0.058693338138982656, 'abosulate accuracy': 0.8607500433921814, 'consecutive overlap rate': 0.9759382382035255, 'overlap rate': 0.9943329304456711}
#
# Experiments_Logs/Experiment#3/RNN/Models_Logs/RedStr_2.pt saved!
#
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RedStr_2.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RedStr_2_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RedStr_2_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.5654562063515186, 'abosulate accuracy': 0.08195000402629375, 'consecutive overlap rate': 0.6080620262771845, 'overlap rate': 0.7958061285316944}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RedStr_2_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.05760479900054634, 'abosulate accuracy': 0.8612750470638275, 'consecutive overlap rate': 0.9771822765469551, 'overlap rate': 0.994481086730957}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RedStr_2_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 1.0582377218431043, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.4973857397033322, 'overlap rate': 0.705385446933008}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RedStr_2_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.568176567260372, 'abosulate accuracy': 0.48278949966985046, 'consecutive overlap rate': 0.8828334526011818, 'overlap rate': 0.9139673615756788}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RedStr_2_non_shuffled.json saved!
#
# ==================== testing on RedStr_2 finishes ====================
#
#
# ==================== training on RedStr_3 starts ====================
#
# Current epoch: 5,
# training performance: {'loss': 3.0880728483200075, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0028415001434041187, 'overlap rate': 0.09868813175708055}
# evaluation performance: {'loss': 3.108506220579147, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.0029008381650783123, 'overlap rate': 0.09652541428804398}
#
# Current epoch: 10,
# training performance: {'loss': 2.6989648163318636, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.005955084483139217, 'overlap rate': 0.1910552926361561}
# evaluation performance: {'loss': 3.076347452402115, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.004810086282668635, 'overlap rate': 0.09394620629027486}
#
# Current epoch: 15,
# training performance: {'loss': 2.3417118072509764, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010108947299886494, 'overlap rate': 0.2807410079985857}
# evaluation performance: {'loss': 2.8063273549079897, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.010051637201104312, 'overlap rate': 0.12206054516136647}
#
# Current epoch: 20,
# training performance: {'loss': 2.004611521959305, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.013413542765192688, 'overlap rate': 0.368364529311657}
# evaluation performance: {'loss': 2.6440467178821563, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.012160909036174417, 'overlap rate': 0.16958014145493508}
#
# Current epoch: 25,
# training performance: {'loss': 2.079127398133278, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.015373213146813215, 'overlap rate': 0.37913151681423185}
# evaluation performance: {'loss': 2.416487592458725, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.018126043153461068, 'overlap rate': 0.23331751264631748}
#
# Current epoch: 30,
# training performance: {'loss': 1.6698924511671067, 'abosulate accuracy': 0.0, 'consecutive overlap rate': 0.02556618673261255, 'overlap rate': 0.489758887141943}
# evaluation performance: {'loss': 2.356663626432419, 'abosulate accuracy': 0.00010000000474974513, 'consecutive overlap rate': 0.02682091814931482, 'overlap rate': 0.25802573300898074}
#
# Current epoch: 35,
# training performance: {'loss': 1.3381027549505233, 'abosulate accuracy': 0.0003000000142492354, 'consecutive overlap rate': 0.03428008863702416, 'overlap rate': 0.5895020708441734}
# evaluation performance: {'loss': 2.2501723378896714, 'abosulate accuracy': 0.0006000000168569386, 'consecutive overlap rate': 0.040111512830480936, 'overlap rate': 0.3096397526562214}
#
# Current epoch: 40,
# training performance: {'loss': 1.1555261999368667, 'abosulate accuracy': 0.00020000000949949026, 'consecutive overlap rate': 0.05359792909584939, 'overlap rate': 0.6659249678254128}
# evaluation performance: {'loss': 2.3795146107673646, 'abosulate accuracy': 0.0013500000524800271, 'consecutive overlap rate': 0.05732584469951689, 'overlap rate': 0.30396756865084174}
#
# Current epoch: 45,
# training performance: {'loss': 0.9320097208023072, 'abosulate accuracy': 0.004700000188313425, 'consecutive overlap rate': 0.08724979879334568, 'overlap rate': 0.7376041382551193}
# evaluation performance: {'loss': 1.7590452969074248, 'abosulate accuracy': 0.01030000062310137, 'consecutive overlap rate': 0.10446501271799206, 'overlap rate': 0.47965487614274027}
#
# Current epoch: 50,
# training performance: {'loss': 0.7403336316347122, 'abosulate accuracy': 0.016400000790599733, 'consecutive overlap rate': 0.13669232167303563, 'overlap rate': 0.8050158709287644}
# evaluation performance: {'loss': 1.5571398794651032, 'abosulate accuracy': 0.029450001259101556, 'consecutive overlap rate': 0.14865820668637753, 'overlap rate': 0.5705395199358463}
#
# Current epoch: 55,
# training performance: {'loss': 0.6331149935722351, 'abosulate accuracy': 0.03530000151367858, 'consecutive overlap rate': 0.1987525701522827, 'overlap rate': 0.8411667048931122}
# evaluation performance: {'loss': 1.4929043442010879, 'abosulate accuracy': 0.055400002468377355, 'consecutive overlap rate': 0.19994534812867643, 'overlap rate': 0.6177156917750836}
#
# Current epoch: 60,
# training performance: {'loss': 0.5657943211495876, 'abosulate accuracy': 0.05150000248104334, 'consecutive overlap rate': 0.2426856528967619, 'overlap rate': 0.8563905686140061}
# evaluation performance: {'loss': 1.2626252189278602, 'abosulate accuracy': 0.090500003634952, 'consecutive overlap rate': 0.2707760490477085, 'overlap rate': 0.6968879088759422}
#
# Current epoch: 65,
# training performance: {'loss': 0.410466318577528, 'abosulate accuracy': 0.13110000675078481, 'consecutive overlap rate': 0.35752865225076674, 'overlap rate': 0.9143405169248581}
# evaluation performance: {'loss': 0.9613460928201676, 'abosulate accuracy': 0.16020000744611024, 'consecutive overlap rate': 0.37268589772284033, 'overlap rate': 0.775895194709301}
#
# Current epoch: 70,
# training performance: {'loss': 0.3209782183170319, 'abosulate accuracy': 0.22830001125112176, 'consecutive overlap rate': 0.4788551665842533, 'overlap rate': 0.9417997747659683}
# evaluation performance: {'loss': 0.7141679525375366, 'abosulate accuracy': 0.2429000112810172, 'consecutive overlap rate': 0.4749456964433193, 'overlap rate': 0.8479941785335541}
#
# Current epoch: 75,
# training performance: {'loss': 0.26029358245432377, 'abosulate accuracy': 0.3166000130586326, 'consecutive overlap rate': 0.5899007678031921, 'overlap rate': 0.9576471224427223}
# evaluation performance: {'loss': 0.5959820002317429, 'abosulate accuracy': 0.3107000144198537, 'consecutive overlap rate': 0.5581904396414756, 'overlap rate': 0.8809504061937332}
#
# Current epoch: 80,
# training performance: {'loss': 0.21104221679270269, 'abosulate accuracy': 0.40590001791715624, 'consecutive overlap rate': 0.6817042864859104, 'overlap rate': 0.9691230997443199}
# evaluation performance: {'loss': 0.4697635628283024, 'abosulate accuracy': 0.40605002040974797, 'consecutive overlap rate': 0.6517336517572403, 'overlap rate': 0.9134460031986237}
#
# Current epoch: 85,
# training performance: {'loss': 0.1702698264271021, 'abosulate accuracy': 0.4875000210478902, 'consecutive overlap rate': 0.7582319036126137, 'overlap rate': 0.9780368208885193}
# evaluation performance: {'loss': 0.35313797406852243, 'abosulate accuracy': 0.5120000223629176, 'consecutive overlap rate': 0.7466793239116669, 'overlap rate': 0.9413574740290642}
#
# Current epoch: 90,
# training performance: {'loss': 0.1347043864428997, 'abosulate accuracy': 0.5828000258654356, 'consecutive overlap rate': 0.8305819928646088, 'overlap rate': 0.9854946330189704}
# evaluation performance: {'loss': 0.2763533815741539, 'abosulate accuracy': 0.6041000328958035, 'consecutive overlap rate': 0.8178035154938698, 'overlap rate': 0.9583367720246315}
#
# Current epoch: 95,
# training performance: {'loss': 0.10880254432559014, 'abosulate accuracy': 0.6527000315487385, 'consecutive overlap rate': 0.880455756187439, 'overlap rate': 0.9896556824445725}
# evaluation performance: {'loss': 0.2273039249703288, 'abosulate accuracy': 0.6643500305712223, 'consecutive overlap rate': 0.8623170629143715, 'overlap rate': 0.967963770031929}
#
# Current epoch: 100,
# training performance: {'loss': 0.08845832720398902, 'abosulate accuracy': 0.7133000329136848, 'consecutive overlap rate': 0.914508618414402, 'overlap rate': 0.9925559386610985}
# evaluation performance: {'loss': 0.18569197710603474, 'abosulate accuracy': 0.7210000298917294, 'consecutive overlap rate': 0.9004316717386246, 'overlap rate': 0.9755878016352654}
#
# Current epoch: 105,
# training performance: {'loss': 0.07197559392079711, 'abosulate accuracy': 0.7582000337541104, 'consecutive overlap rate': 0.9360096201300621, 'overlap rate': 0.9945512160658836}
# evaluation performance: {'loss': 0.1517045298591256, 'abosulate accuracy': 0.7685000389814377, 'consecutive overlap rate': 0.9320855483412742, 'overlap rate': 0.9813139513134956}
#
# Current epoch: 110,
# training performance: {'loss': 0.057700995728373526, 'abosulate accuracy': 0.8031000375747681, 'consecutive overlap rate': 0.955724760890007, 'overlap rate': 0.996304090321064}
# evaluation performance: {'loss': 0.13118910482153295, 'abosulate accuracy': 0.7970500409603118, 'consecutive overlap rate': 0.9475623428821563, 'overlap rate': 0.983871154487133}
#
# Current epoch: 115,
# training performance: {'loss': 0.048136163782328364, 'abosulate accuracy': 0.8242000371217728, 'consecutive overlap rate': 0.9641536563634873, 'overlap rate': 0.9969697147607803}
# evaluation performance: {'loss': 0.11430889545008541, 'abosulate accuracy': 0.8192000389099121, 'consecutive overlap rate': 0.9587918564677238, 'overlap rate': 0.9862228259444237}
#
# Current epoch: 120,
# training performance: {'loss': 0.03946304260753095, 'abosulate accuracy': 0.8453000351786614, 'consecutive overlap rate': 0.9715462133288384, 'overlap rate': 0.9977303341031074}
# evaluation performance: {'loss': 0.09179043378680944, 'abosulate accuracy': 0.8405000448226929, 'consecutive overlap rate': 0.9694735184311867, 'overlap rate': 0.9893690139055252}
#
# Current epoch: 125,
# training performance: {'loss': 0.03176638586446643, 'abosulate accuracy': 0.8660000294446946, 'consecutive overlap rate': 0.9795678541064262, 'overlap rate': 0.9984089314937592}
# evaluation performance: {'loss': 0.07617087839171291, 'abosulate accuracy': 0.8480500414967537, 'consecutive overlap rate': 0.9704451233148574, 'overlap rate': 0.9914838179945946}
#
# Current epoch: 130,
# training performance: {'loss': 0.02645217520184815, 'abosulate accuracy': 0.8789000362157822, 'consecutive overlap rate': 0.9847328186035156, 'overlap rate': 0.9987886354327202}
# evaluation performance: {'loss': 0.07649573613889515, 'abosulate accuracy': 0.8493000403046608, 'consecutive overlap rate': 0.970413102209568, 'overlap rate': 0.9912620887160302}
#
# Current epoch: 135,
# training performance: {'loss': 0.02328429468907416, 'abosulate accuracy': 0.8829000324010849, 'consecutive overlap rate': 0.9844559744000435, 'overlap rate': 0.9987771928310394}
# evaluation performance: {'loss': 0.07646469655446708, 'abosulate accuracy': 0.8506500363349915, 'consecutive overlap rate': 0.97073442786932, 'overlap rate': 0.9910585656762123}
#
# Current epoch: 140,
# training performance: {'loss': 0.022328596585430203, 'abosulate accuracy': 0.8743000268936157, 'consecutive overlap rate': 0.9794448018074036, 'overlap rate': 0.9982516437768936}
# evaluation performance: {'loss': 0.09442309970036149, 'abosulate accuracy': 0.8397000387310982, 'consecutive overlap rate': 0.9648882195353508, 'overlap rate': 0.9885038554668426}
#
# Current epoch: 145,
# training performance: {'loss': 1.8501700386404991, 'abosulate accuracy': 0.03260000125737861, 'consecutive overlap rate': 0.3504862252622843, 'overlap rate': 0.5763711061328649}
# evaluation performance: {'loss': 2.4540681183338164, 'abosulate accuracy': 0.059600002627121285, 'consecutive overlap rate': 0.34861679635941983, 'overlap rate': 0.4168450769037008}
#
# Current epoch: 150,
# training performance: {'loss': 0.6165348384529352, 'abosulate accuracy': 0.16490000586491077, 'consecutive overlap rate': 0.5252481419593096, 'overlap rate': 0.8730759665369987}
# evaluation performance: {'loss': 3.09604489505291, 'abosulate accuracy': 0.06645000262069516, 'consecutive overlap rate': 0.3365712895989418, 'overlap rate': 0.47508114129304885}
#
# Experiments_Logs/Experiment#3/RNN/Models_Logs/RedStr_3.pt saved!
#
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RedStr_3.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RedStr_3_train_performance_per_seq_length.json saved!
# Experiments_Logs/Experiment#3/RNN/Training_Logs/RedStr_3_dev_performance_per_seq_length.json saved!
#
# test's aggregate performace with shuffled batches: {'loss': 0.28802091982215644, 'abosulate accuracy': 0.16315000727772713, 'consecutive overlap rate': 0.5921125080436468, 'overlap rate': 0.922120500728488}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RedStr_3_shuffled.json saved!
#
# test's aggregate performace with non-shuffled batches: {'loss': 0.07197137633338571, 'abosulate accuracy': 0.8535500362515449, 'consecutive overlap rate': 0.9717416197061539, 'overlap rate': 0.9915936559438705}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test_Logs/RedStr_3_non_shuffled.json saved!
#
# test2's aggregate performace with shuffled batches: {'loss': 0.9169994946449034, 'abosulate accuracy': 0.025837113744308873, 'consecutive overlap rate': 0.502967809284887, 'overlap rate': 0.8161649800116016}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RedStr_3_shuffled.json saved!
#
# test2's aggregate performace with non-shuffled batches: {'loss': 0.5548832422416461, 'abosulate accuracy': 0.4865789696709008, 'consecutive overlap rate': 0.8827031050857744, 'overlap rate': 0.9179844322957491}
# Experiments_Logs/Experiment#3/RNN/Testing_Logs/Test2_Logs/RedStr_3_non_shuffled.json saved!
#
# ==================== testing on RedStr_3 finishes ====================
#
#
# ...experiment#3 with RNN seq2seq ends.

# %% [markdown]
# # Log Hyperparameters

# %%
hyperparameters = {"RNN type": rnn_type, 
                   "in vocab": in_vocab,
                   "out vocab": out_vocab,
                   "embedding size": embd_dim, 
                   "hidden size": hidden_size, 
                   "num of layers": num_layers, 
                   "dropout rate": dropout_rate,
                   "bidirectional": bidirectional, 
                   "use_attention": use_attention, 
                   "loss function": str(criterion), 
                   "optimizer": str(optimizer), 
                   "learning rate": learning_rate, 
                   "device type": device.type,
                   "torch version": torch.__version__,
                   "reduction method": reduction_method.__name__, 
                   "maximum number of epoches": max_epoch_num,
                   "teacher forcing ratio": teacher_forcing_ratio, 
                   "dev acc threshold for saving model": acc_threshold,
                   "train acc exist threshold": train_acc_exit,
                   "dev accu exist threshold": eval_acc_exit, 
                   "num of trainable parameters": count_parameters(model)}
                   
save_dict_as_json(hyperparameters, join(log_folder, "hyperparameters.json"))

# %%
from google.colab import runtime
runtime.unassign()
